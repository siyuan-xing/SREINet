# %% [markdown]
# ## **Triple-pendulum model by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG

# Tensowflow version should be 2.13.0 or
# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("*******************************|***************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()


opt_folder = 'output'
# Create the folder if it doesn't exist
os.makedirs(opt_folder, exist_ok=True)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# *******************************|***************

# %% [markdown]
# ### **1.2 Training Data**

# %%
def load_triple_pendulum_data(mat_path, downsample=1):
    """
    Loads triple pendulum data from a MATLAB .mat file and returns the relevant arrays, with optional downsampling.
    Args:
        mat_path (str): Path to the .mat file.
        downsample (int): Take every nth sample (default 1, i.e., no downsampling)
    Returns:
        my_data (np.ndarray): Concatenated array of [theta1, theta2, theta3, d_theta1, d_theta2, d_theta3], shape (N, 6)
        d_theta (np.ndarray): Concatenated array of [d_theta1, d_theta2, d_theta3], shape (N, 3)
        time (np.ndarray): Time array
        dt (float): Time step
    """
    from scipy.io import loadmat
    import numpy as np

    data = loadmat(mat_path)
    theta1 = data['Theta1'][::downsample]
    theta2 = data['Theta2'][::downsample]
    theta3 = data['Theta3'][::downsample]
    d_theta1 = data['dTheta1'][::downsample]
    d_theta2 = data['dTheta2'][::downsample]
    d_theta3 = data['dTheta3'][::downsample]

    my_data = np.concatenate([theta1, theta2, theta3, d_theta1, d_theta2, d_theta3], axis=1)
    d_theta = np.concatenate([d_theta1, d_theta2, d_theta3], axis=1)

    return my_data, d_theta

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_DATA_TYPE = 'float32'

SEED = 42  # set seed for random number generation
np.random.seed(SEED)

import scipy.io as sio
import numpy as np
from skimage.transform import resize
import matplotlib.pyplot as plt
import cmocean

from sklearn.preprocessing import MinMaxScaler

from scipy.signal import savgol_filter


#load data
from scipy.io import loadmat

data_1, d_theta_1 = load_triple_pendulum_data('../experiment_data/TriplePendulum_Data/TripleDataFreeSwing_1_Dt_0_0001.mat',downsample=100)
data_2, d_theta_2 = load_triple_pendulum_data('../experiment_data/TriplePendulum_Data/TripleDataFreeSwing_2_Dt_0_0001.mat',downsample=100)

my_data = np.concatenate([data_1, data_2], axis=0)

dt = 0.0001 * 100 #original dt



# Calculate derivative using Savitzky-Golay filter
window_length = 7  # Window length
polyorder = 2     # Polynomial order
dd_theta_1 = savgol_filter(d_theta_1, window_length, polyorder, delta=dt, deriv=1, axis=0)
dd_theta_2 = savgol_filter(d_theta_2, window_length, polyorder, delta=dt, deriv=1, axis=0)

derivative_data_1 = np.concatenate([d_theta_1, dd_theta_1], axis=1)
derivative_data_2 = np.concatenate([d_theta_2, dd_theta_2], axis=1)
derivative_data = np.concatenate([derivative_data_1, derivative_data_2], axis=0)

# %%
training_input = np.concatenate([my_data], axis=1)
training_output = derivative_data


print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Training input shape: (12002, 6)
# Training output shape: (12002, 6)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 32
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables)
dim = training_input.shape[1] 

guess_highest_order_polynomial = 2

layer_depth = guess_highest_order_polynomial
# The grid size of each dimension
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn)
# Out:
# [6, 6]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x,
                 lambda x:tf.cos(x),
                 lambda x:tf.sin(x),
                 lambda x:tf.cos(2*x),
                 lambda x:tf.sin(2*x),
                 ]

inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn, 1, 
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=1e-5, seed=SEED),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Trainer**

# %%
from sreinet_trainer import *

trainer = SREINetTrainer(model, my_optimizer, loss_fn, data_type='float32')

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# ### First three dimensions

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.6 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 10
PRUNING_EPOCHS_PER_PERIOD = 240
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

# Define the pruning schedule

pruning_scheduler = ps.PruningScheduler(steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                    num_periods=N_PERIODS,
                    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
                    ramp_type='sine',
                    zero_percentage=0.1,
                    ramp_percentage=0.75,
                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
EARLY_STOPPING_LOSS_THRESHOLD = 1e-8  # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.1

training_histories = []
weights_list = []
loss_list = []

# %%
for i in range(0, 3):
    print(f"Training dimension {i + 1}...")
    
    output = training_output[:, i:i+1]
    
    history = trainer.fit(training_input, output,
     batch_size=MINI_BATCH_SIZE, 
     validation_split=0.00,
     epochs=round(NUM_EPOCHS), 
     pruning_scheduler=pruning_scheduler,
     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
     verbose=1,
     print_every_n_epochs=10,
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
    loss_list.append(trainer.get_best_loss())

    #reset the model and trainer
    trainer.reset_trainer_and_model_weights(i)
# Out:
# Training dimension 1...
# Epoch   1 (Period 1):  Train Loss: 8.478e-02,  Epoch Time: 0.46s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 4.808e-03,  Epoch Time: 0.23s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 3.835e-03,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 2.102e-03,  Epoch Time: 0.23s,  Current Pruning Threshold: 0.0016618
# Epoch  41 (Period 1):  Train Loss: 1.129e-04,  Epoch Time: 0.24s,  Current Pruning Threshold: 0.011751
# Epoch  51 (Period 1):  Train Loss: 2.115e-06,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.030696
# Epoch  61 (Period 1):  Train Loss: 6.805e-06,  Epoch Time: 0.24s,  Current Pruning Threshold: 0.057915
# Epoch  71 (Period 1):  Train Loss: 1.939e-06,  Epoch Time: 0.23s,  Current Pruning Threshold: 0.092572
# Early stopping at epoch 80 as train loss 0.00000000000327 is below the threshold 0.00000001000000
# Training Stopped. Time elapsed: 20.04s
# Training dimension 2...
# Epoch   1 (Period 1):  Train Loss: 1.341e-01,  Epoch Time: 0.26s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 1.208e-02,  Epoch Time: 0.24s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 1.245e-02,  Epoch Time: 0.24s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 1.176e-03,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0016618
# Epoch  41 (Period 1):  Train Loss: 2.108e-04,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.011751
# Epoch  51 (Period 1):  Train Loss: 3.221e-06,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.030696
# Epoch  61 (Period 1):  Train Loss: 2.164e-05,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.057915
# Epoch  71 (Period 1):  Train Loss: 1.922e-06,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.092572
# Early stopping at epoch 80 as train loss 0.00000000002297 is below the threshold 0.00000001000000
# Training Stopped. Time elapsed: 18.01s
# Training dimension 3...
# Epoch   1 (Period 1):  Train Loss: 2.288e-01,  Epoch Time: 0.27s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 1.202e-02,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 3.200e-03,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 5.341e-05,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0016618
# Epoch  41 (Period 1):  Train Loss: 2.297e-04,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.011751
# Epoch  51 (Period 1):  Train Loss: 1.433e-05,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.030696
# Epoch  61 (Period 1):  Train Loss: 2.621e-05,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.057915
# Epoch  71 (Period 1):  Train Loss: 8.388e-06,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.092572
# Early stopping at epoch 79 as train loss 0.00000000977986 is below the threshold 0.00000001000000
# Training Stopped. Time elapsed: 16.98s

# %% [markdown]
# ### Last three dimensions

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.1 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 3
PRUNING_EPOCHS_PER_PERIOD = 200
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

# Define the pruning schedule

pruning_scheduler = ps.PruningScheduler(steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                    num_periods=N_PERIODS,
                    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
                    zero_percentage=0.15,
                    ramp_percentage=0.75,
                    show_plot=True)

# %%
EARLY_STOPPING_LOSS_THRESHOLD = 2.5e-1  # last three dimensions
EARLY_STOPPING_PRUNING_THRESHOLD = 0.02

# %%
#change 0 to a other number if you want to start training from other dimensions
for i in range(3, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    output = training_output[:, i:i+1]

    history = trainer.fit(training_input, output,
     batch_size=MINI_BATCH_SIZE, 
     validation_split=0.20,
     epochs=round(NUM_EPOCHS), 
     pruning_scheduler=pruning_scheduler,
     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
     verbose=1,
     print_every_n_epochs=10,
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
    loss_list.append(trainer.get_best_loss())

    #reset the model and trainer
    trainer.reset_trainer_and_model_weights(i)
# Out:
# Training dimension 4...
# Epoch   1 (Period 1):  Train Loss: 1.450e+02,  Validation Loss: 7.651e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 9.071e+00,  Validation Loss: 8.201e+00,  Epoch Time: 0.23s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 8.122e+00,  Validation Loss: 8.388e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 7.629e+00,  Validation Loss: 7.080e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch  41 (Period 1):  Train Loss: 7.374e+00,  Validation Loss: 7.229e+00,  Epoch Time: 0.25s,  Current Pruning Threshold: 0.0011073
# Epoch  51 (Period 1):  Train Loss: 6.991e+00,  Validation Loss: 6.415e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0043801
# Epoch  61 (Period 1):  Train Loss: 6.897e+00,  Validation Loss: 7.046e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0096734
# Epoch  71 (Period 1):  Train Loss: 6.773e+00,  Validation Loss: 6.303e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.016753
# Epoch  81 (Period 1):  Train Loss: 6.509e+00,  Validation Loss: 5.934e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.025305
# Epoch  91 (Period 1):  Train Loss: 6.790e+00,  Validation Loss: 5.964e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.034951
# Epoch 101 (Period 1):  Train Loss: 6.239e+00,  Validation Loss: 6.369e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.045263
# Epoch 111 (Period 1):  Train Loss: 5.974e+00,  Validation Loss: 5.400e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.055785
# Epoch 121 (Period 1):  Train Loss: 6.166e+00,  Validation Loss: 6.188e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.066051
# Epoch 131 (Period 1):  Train Loss: 5.931e+00,  Validation Loss: 5.317e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.075606
# Epoch 141 (Period 1):  Train Loss: 6.080e+00,  Validation Loss: 6.513e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.084027
# Epoch 151 (Period 1):  Train Loss: 5.852e+00,  Validation Loss: 6.222e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.090941
# Epoch 161 (Period 1):  Train Loss: 5.780e+00,  Validation Loss: 6.515e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.096041
# Epoch 171 (Period 1):  Train Loss: 5.610e+00,  Validation Loss: 4.907e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.099102
# Epoch 181 (Period 1):  Train Loss: 5.541e+00,  Validation Loss: 5.370e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 191 (Period 1):  Train Loss: 5.541e+00,  Validation Loss: 5.386e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 201 (Period 2):  Train Loss: 6.037e+00,  Validation Loss: 5.956e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 211 (Period 2):  Train Loss: 5.422e+00,  Validation Loss: 5.116e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 221 (Period 2):  Train Loss: 5.209e+00,  Validation Loss: 5.232e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 231 (Period 2):  Train Loss: 5.385e+00,  Validation Loss: 5.196e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 241 (Period 2):  Train Loss: 4.994e+00,  Validation Loss: 5.262e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0011073
# Epoch 251 (Period 2):  Train Loss: 4.962e+00,  Validation Loss: 4.713e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0043801
# Epoch 261 (Period 2):  Train Loss: 4.982e+00,  Validation Loss: 5.377e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0096734
# Epoch 271 (Period 2):  Train Loss: 4.907e+00,  Validation Loss: 4.810e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.016753
# Epoch 281 (Period 2):  Train Loss: 4.983e+00,  Validation Loss: 5.508e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.025305
# Epoch 291 (Period 2):  Train Loss: 4.724e+00,  Validation Loss: 4.362e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.034951
# Epoch 301 (Period 2):  Train Loss: 4.719e+00,  Validation Loss: 4.162e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.045263
# Epoch 311 (Period 2):  Train Loss: 4.738e+00,  Validation Loss: 4.533e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.055785
# Epoch 321 (Period 2):  Train Loss: 4.642e+00,  Validation Loss: 4.373e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.066051
# Epoch 331 (Period 2):  Train Loss: 4.714e+00,  Validation Loss: 4.728e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.075606
# Epoch 341 (Period 2):  Train Loss: 4.688e+00,  Validation Loss: 4.498e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.084027
# Epoch 351 (Period 2):  Train Loss: 4.561e+00,  Validation Loss: 4.424e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.090941
# Epoch 361 (Period 2):  Train Loss: 4.751e+00,  Validation Loss: 4.093e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.096041
# Epoch 371 (Period 2):  Train Loss: 4.461e+00,  Validation Loss: 4.636e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.099102
# Epoch 381 (Period 2):  Train Loss: 4.573e+00,  Validation Loss: 4.041e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.1
# Epoch 391 (Period 2):  Train Loss: 4.577e+00,  Validation Loss: 4.524e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 401 (Period 3):  Train Loss: 5.096e+00,  Validation Loss: 5.784e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 411 (Period 3):  Train Loss: 4.331e+00,  Validation Loss: 4.110e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 421 (Period 3):  Train Loss: 4.372e+00,  Validation Loss: 4.433e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 431 (Period 3):  Train Loss: 4.337e+00,  Validation Loss: 4.707e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 441 (Period 3):  Train Loss: 4.168e+00,  Validation Loss: 4.165e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0011073
# Epoch 451 (Period 3):  Train Loss: 4.026e+00,  Validation Loss: 3.415e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0043801
# Epoch 461 (Period 3):  Train Loss: 4.188e+00,  Validation Loss: 3.681e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0096734
# Epoch 471 (Period 3):  Train Loss: 4.018e+00,  Validation Loss: 4.217e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.016753
# Epoch 481 (Period 3):  Train Loss: 4.082e+00,  Validation Loss: 3.941e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.025305
# Epoch 491 (Period 3):  Train Loss: 3.935e+00,  Validation Loss: 3.512e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.034951
# Epoch 501 (Period 3):  Train Loss: 4.240e+00,  Validation Loss: 4.082e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.045263
# Epoch 511 (Period 3):  Train Loss: 3.838e+00,  Validation Loss: 4.737e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.055785
# Epoch 521 (Period 3):  Train Loss: 4.064e+00,  Validation Loss: 3.295e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.066051
# Epoch 531 (Period 3):  Train Loss: 3.962e+00,  Validation Loss: 4.231e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.075606
# Epoch 541 (Period 3):  Train Loss: 4.063e+00,  Validation Loss: 3.691e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.084027
# Epoch 551 (Period 3):  Train Loss: 4.074e+00,  Validation Loss: 3.784e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.090941
# Epoch 561 (Period 3):  Train Loss: 4.055e+00,  Validation Loss: 4.194e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.096041
# Epoch 571 (Period 3):  Train Loss: 3.842e+00,  Validation Loss: 3.682e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.099102
# Epoch 581 (Period 3):  Train Loss: 3.832e+00,  Validation Loss: 3.554e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 591 (Period 3):  Train Loss: 3.894e+00,  Validation Loss: 3.819e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 600 (Period 3):  Train Loss: 3.899e+00,  Validation Loss: 3.911e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Training Stopped. Time elapsed: 129.85s
# Training dimension 5...
# Epoch   1 (Period 1):  Train Loss: 1.847e+02,  Validation Loss: 9.338e+01,  Epoch Time: 0.29s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 1.604e+01,  Validation Loss: 1.479e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 1.498e+01,  Validation Loss: 1.534e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 1.417e+01,  Validation Loss: 1.498e+01,  Epoch Time: 0.24s,  Current Pruning Threshold: 0
# Epoch  41 (Period 1):  Train Loss: 1.433e+01,  Validation Loss: 1.264e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0011073
# Epoch  51 (Period 1):  Train Loss: 1.376e+01,  Validation Loss: 1.369e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0043801
# Epoch  61 (Period 1):  Train Loss: 1.294e+01,  Validation Loss: 1.229e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0096734
# Epoch  71 (Period 1):  Train Loss: 1.307e+01,  Validation Loss: 1.166e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.016753
# Epoch  81 (Period 1):  Train Loss: 1.237e+01,  Validation Loss: 1.128e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.025305
# Epoch  91 (Period 1):  Train Loss: 1.238e+01,  Validation Loss: 1.232e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.034951
# Epoch 101 (Period 1):  Train Loss: 1.263e+01,  Validation Loss: 1.136e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.045263
# Epoch 111 (Period 1):  Train Loss: 1.206e+01,  Validation Loss: 1.215e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.055785
# Epoch 121 (Period 1):  Train Loss: 1.237e+01,  Validation Loss: 1.062e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.066051
# Epoch 131 (Period 1):  Train Loss: 1.208e+01,  Validation Loss: 1.182e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.075606
# Epoch 141 (Period 1):  Train Loss: 1.187e+01,  Validation Loss: 1.158e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.084027
# Epoch 151 (Period 1):  Train Loss: 1.153e+01,  Validation Loss: 1.224e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.090941
# Epoch 161 (Period 1):  Train Loss: 1.182e+01,  Validation Loss: 1.181e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.096041
# Epoch 171 (Period 1):  Train Loss: 1.166e+01,  Validation Loss: 1.068e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.099102
# Epoch 181 (Period 1):  Train Loss: 1.140e+01,  Validation Loss: 1.020e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 191 (Period 1):  Train Loss: 1.141e+01,  Validation Loss: 1.076e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 201 (Period 2):  Train Loss: 1.214e+01,  Validation Loss: 1.150e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 211 (Period 2):  Train Loss: 1.095e+01,  Validation Loss: 1.043e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 221 (Period 2):  Train Loss: 1.115e+01,  Validation Loss: 9.714e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 231 (Period 2):  Train Loss: 1.093e+01,  Validation Loss: 1.062e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 241 (Period 2):  Train Loss: 1.030e+01,  Validation Loss: 1.113e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0011073
# Epoch 251 (Period 2):  Train Loss: 1.038e+01,  Validation Loss: 9.394e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0043801
# Epoch 261 (Period 2):  Train Loss: 1.026e+01,  Validation Loss: 9.583e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0096734
# Epoch 271 (Period 2):  Train Loss: 1.100e+01,  Validation Loss: 1.053e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.016753
# Epoch 281 (Period 2):  Train Loss: 1.056e+01,  Validation Loss: 1.135e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.025305
# Epoch 291 (Period 2):  Train Loss: 1.051e+01,  Validation Loss: 1.134e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.034951
# Epoch 301 (Period 2):  Train Loss: 1.025e+01,  Validation Loss: 9.573e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.045263
# Epoch 311 (Period 2):  Train Loss: 9.961e+00,  Validation Loss: 8.625e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.055785
# Epoch 321 (Period 2):  Train Loss: 9.907e+00,  Validation Loss: 1.027e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.066051
# Epoch 331 (Period 2):  Train Loss: 1.016e+01,  Validation Loss: 9.634e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.075606
# Epoch 341 (Period 2):  Train Loss: 1.028e+01,  Validation Loss: 1.015e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.084027
# Epoch 351 (Period 2):  Train Loss: 9.839e+00,  Validation Loss: 9.588e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.090941
# Epoch 361 (Period 2):  Train Loss: 9.738e+00,  Validation Loss: 1.063e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.096041
# Epoch 371 (Period 2):  Train Loss: 9.622e+00,  Validation Loss: 1.058e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.099102
# Epoch 381 (Period 2):  Train Loss: 9.952e+00,  Validation Loss: 9.116e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 391 (Period 2):  Train Loss: 9.574e+00,  Validation Loss: 9.700e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.1
# Epoch 401 (Period 3):  Train Loss: 1.056e+01,  Validation Loss: 9.320e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 411 (Period 3):  Train Loss: 9.532e+00,  Validation Loss: 8.836e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 421 (Period 3):  Train Loss: 9.543e+00,  Validation Loss: 1.080e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 431 (Period 3):  Train Loss: 9.378e+00,  Validation Loss: 9.699e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 441 (Period 3):  Train Loss: 9.544e+00,  Validation Loss: 8.036e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0011073
# Epoch 451 (Period 3):  Train Loss: 9.812e+00,  Validation Loss: 9.486e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0043801
# Epoch 461 (Period 3):  Train Loss: 9.307e+00,  Validation Loss: 8.087e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0096734
# Epoch 471 (Period 3):  Train Loss: 9.031e+00,  Validation Loss: 9.775e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.016753
# Epoch 481 (Period 3):  Train Loss: 9.637e+00,  Validation Loss: 9.804e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.025305
# Epoch 491 (Period 3):  Train Loss: 8.869e+00,  Validation Loss: 8.776e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.034951
# Epoch 501 (Period 3):  Train Loss: 9.175e+00,  Validation Loss: 8.690e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.045263
# Epoch 511 (Period 3):  Train Loss: 8.919e+00,  Validation Loss: 8.496e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.055785
# Epoch 521 (Period 3):  Train Loss: 8.772e+00,  Validation Loss: 9.114e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.066051
# Epoch 531 (Period 3):  Train Loss: 8.682e+00,  Validation Loss: 7.471e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.075606
# Epoch 541 (Period 3):  Train Loss: 9.167e+00,  Validation Loss: 9.053e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.084027
# Epoch 551 (Period 3):  Train Loss: 9.029e+00,  Validation Loss: 8.889e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.090941
# Epoch 561 (Period 3):  Train Loss: 9.887e+00,  Validation Loss: 9.949e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.096041
# Epoch 571 (Period 3):  Train Loss: 9.149e+00,  Validation Loss: 8.211e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.099102
# Epoch 581 (Period 3):  Train Loss: 9.012e+00,  Validation Loss: 8.008e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 591 (Period 3):  Train Loss: 8.716e+00,  Validation Loss: 8.918e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 600 (Period 3):  Train Loss: 9.018e+00,  Validation Loss: 8.412e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Training Stopped. Time elapsed: 129.32s
# Training dimension 6...
# Epoch   1 (Period 1):  Train Loss: 2.265e+02,  Validation Loss: 9.590e+01,  Epoch Time: 0.27s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 2.777e+01,  Validation Loss: 2.381e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 2.475e+01,  Validation Loss: 2.483e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 2.408e+01,  Validation Loss: 2.354e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch  41 (Period 1):  Train Loss: 2.285e+01,  Validation Loss: 2.397e+01,  Epoch Time: 0.24s,  Current Pruning Threshold: 0.0011073
# Epoch  51 (Period 1):  Train Loss: 2.323e+01,  Validation Loss: 2.140e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0043801
# Epoch  61 (Period 1):  Train Loss: 2.239e+01,  Validation Loss: 2.067e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0096734
# Epoch  71 (Period 1):  Train Loss: 2.225e+01,  Validation Loss: 2.656e+01,  Epoch Time: 0.24s,  Current Pruning Threshold: 0.016753
# Epoch  81 (Period 1):  Train Loss: 2.170e+01,  Validation Loss: 2.170e+01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025305
# Epoch  91 (Period 1):  Train Loss: 2.037e+01,  Validation Loss: 2.158e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.034951
# Epoch 101 (Period 1):  Train Loss: 2.135e+01,  Validation Loss: 2.210e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.045263
# Epoch 111 (Period 1):  Train Loss: 2.112e+01,  Validation Loss: 2.050e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.055785
# Epoch 121 (Period 1):  Train Loss: 2.107e+01,  Validation Loss: 2.036e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.066051
# Epoch 131 (Period 1):  Train Loss: 2.062e+01,  Validation Loss: 2.181e+01,  Epoch Time: 0.23s,  Current Pruning Threshold: 0.075606
# Epoch 141 (Period 1):  Train Loss: 2.029e+01,  Validation Loss: 2.187e+01,  Epoch Time: 0.25s,  Current Pruning Threshold: 0.084027
# Epoch 151 (Period 1):  Train Loss: 2.006e+01,  Validation Loss: 2.204e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.090941
# Epoch 161 (Period 1):  Train Loss: 2.018e+01,  Validation Loss: 1.913e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.096041
# Epoch 171 (Period 1):  Train Loss: 2.029e+01,  Validation Loss: 1.810e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.099102
# Epoch 181 (Period 1):  Train Loss: 1.914e+01,  Validation Loss: 1.863e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.1
# Epoch 191 (Period 1):  Train Loss: 1.994e+01,  Validation Loss: 2.191e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 201 (Period 2):  Train Loss: 2.074e+01,  Validation Loss: 1.809e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 211 (Period 2):  Train Loss: 1.914e+01,  Validation Loss: 2.165e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 221 (Period 2):  Train Loss: 1.891e+01,  Validation Loss: 1.792e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 231 (Period 2):  Train Loss: 1.807e+01,  Validation Loss: 2.030e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 241 (Period 2):  Train Loss: 1.849e+01,  Validation Loss: 1.822e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0011073
# Epoch 251 (Period 2):  Train Loss: 1.889e+01,  Validation Loss: 1.651e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0043801
# Epoch 261 (Period 2):  Train Loss: 1.871e+01,  Validation Loss: 1.853e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0096734
# Epoch 271 (Period 2):  Train Loss: 1.792e+01,  Validation Loss: 1.503e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.016753
# Epoch 281 (Period 2):  Train Loss: 1.776e+01,  Validation Loss: 1.784e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.025305
# Epoch 291 (Period 2):  Train Loss: 1.757e+01,  Validation Loss: 1.770e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.034951
# Epoch 301 (Period 2):  Train Loss: 1.757e+01,  Validation Loss: 1.688e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.045263
# Epoch 311 (Period 2):  Train Loss: 1.806e+01,  Validation Loss: 1.727e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.055785
# Epoch 321 (Period 2):  Train Loss: 1.784e+01,  Validation Loss: 1.813e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.066051
# Epoch 331 (Period 2):  Train Loss: 1.761e+01,  Validation Loss: 1.691e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.075606
# Epoch 341 (Period 2):  Train Loss: 1.739e+01,  Validation Loss: 1.573e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.084027
# Epoch 351 (Period 2):  Train Loss: 1.831e+01,  Validation Loss: 1.707e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.090941
# Epoch 361 (Period 2):  Train Loss: 1.791e+01,  Validation Loss: 1.797e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.096041
# Epoch 371 (Period 2):  Train Loss: 1.765e+01,  Validation Loss: 1.823e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.099102
# Epoch 381 (Period 2):  Train Loss: 1.741e+01,  Validation Loss: 1.452e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 391 (Period 2):  Train Loss: 1.789e+01,  Validation Loss: 1.666e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.1
# Epoch 401 (Period 3):  Train Loss: 1.902e+01,  Validation Loss: 1.890e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 411 (Period 3):  Train Loss: 1.755e+01,  Validation Loss: 1.652e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 421 (Period 3):  Train Loss: 1.731e+01,  Validation Loss: 1.717e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 431 (Period 3):  Train Loss: 1.687e+01,  Validation Loss: 1.687e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0
# Epoch 441 (Period 3):  Train Loss: 1.760e+01,  Validation Loss: 1.555e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0011073
# Epoch 451 (Period 3):  Train Loss: 1.727e+01,  Validation Loss: 1.438e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.0043801
# Epoch 461 (Period 3):  Train Loss: 1.654e+01,  Validation Loss: 1.737e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.0096734
# Epoch 471 (Period 3):  Train Loss: 1.694e+01,  Validation Loss: 1.704e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.016753
# Epoch 481 (Period 3):  Train Loss: 1.708e+01,  Validation Loss: 1.646e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.025305
# Epoch 491 (Period 3):  Train Loss: 1.718e+01,  Validation Loss: 1.506e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.034951
# Epoch 501 (Period 3):  Train Loss: 1.655e+01,  Validation Loss: 1.526e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.045263
# Epoch 511 (Period 3):  Train Loss: 1.677e+01,  Validation Loss: 1.612e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.055785
# Epoch 521 (Period 3):  Train Loss: 1.738e+01,  Validation Loss: 1.520e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.066051
# Epoch 531 (Period 3):  Train Loss: 1.687e+01,  Validation Loss: 1.659e+01,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.075606
# Epoch 541 (Period 3):  Train Loss: 1.715e+01,  Validation Loss: 1.556e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.084027
# Epoch 551 (Period 3):  Train Loss: 1.694e+01,  Validation Loss: 1.852e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.090941
# Epoch 561 (Period 3):  Train Loss: 1.740e+01,  Validation Loss: 1.819e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.096041
# Epoch 571 (Period 3):  Train Loss: 1.693e+01,  Validation Loss: 1.767e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.099102
# Epoch 581 (Period 3):  Train Loss: 1.707e+01,  Validation Loss: 1.623e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 591 (Period 3):  Train Loss: 1.715e+01,  Validation Loss: 1.631e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Epoch 600 (Period 3):  Train Loss: 1.755e+01,  Validation Loss: 1.623e+01,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.1
# Training Stopped. Time elapsed: 129.88s

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_layer_labels(N): # N is the number of neurons per layer
    num_terms = N // 5 # get the number of state variables. 

    return ['Constant'] + [f'x{i}' for i in range(1, num_terms+1)] + [f'cos(x{i})' for i in range(1, num_terms+1)] + [f'sin(x{i})' for i in range(1, num_terms+1)] + [f'cos(2*x{i})' for i in range(1, num_terms+1)] + [f'sin(2*x{i})' for i in range(1, num_terms+1)]

def generate_LHS_labels(N):
    num_terms = N // 5
    return [f"(x{i})'" for i in range(1, num_terms+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
from coefficient_reconstructor import *
cr = CoefficientReconstructor(generate_layer_labels, generate_LHS_labels)

# %%
np.mean(loss_list)
# Out:
# 3.941721

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
eq_str = []
for i in range(len(weights_list)):
    path_products = cr.reconstruct_coefficients(i,
                                               weights_list[i], 
                                            minimum_coefficient_threshold = 1e-3,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
        eq_str.append(dimension)
# Out:
# (x1)' = 0.9999991953*x4
# (x2)' = 0.9999990463*x5
# (x3)' = 1.000000685*x6
# (x4)' = 0.1721142232 + 0.41999349*x3 - 0.247729063*cos(x2) - 0.5972534418*cos(x3) + 0.4530134052*sin(x1) + 2.579266071*sin(x2) - 0.5457577109*cos(2*x1) + 0.2436059117*cos(2*x2) - 0.949491322*sin(2*x1) - 0.4113269299*sin(2*x2) + 0.3684860468*sin(2*x4) - 0.39697887*sin(2*x5) - 0.09682083875*x1^2 - 0.3191098869*x1*x2 + 0.2845752537*cos(x1)*x1 + 0.4873329401*cos(x2)*x1 - 0.3959718347*cos(x3)*x1 + 0.2759580016*cos(x5)*x1 + 0.4296978861*cos(x6)*x1 + 2.576751113*sin(x2)*x1 - 0.903791368*cos(2*x1)*x1 - 1.810489535*cos(2*x2)*x1 - 0.260817036*cos(2*x3)*x1 + 0.3314263821*cos(2*x6)*x1 - 0.7562647462*sin(2*x1)*x1 - 0.4317746609*sin(2*x2)*x1 + 0.5126099885*sin(2*x4)*x1 - 0.2388951182*x2^2 - 0.2304261476*cos(x1)*x2 - 0.3228648752*cos(x3)*x2 + 0.3504650593*sin(x1)*x2 + 2.466451645*sin(x2)*x2 - 0.6358004808*sin(x3)*x2 + 1.280870378*cos(2*x1)*x2 + 0.8186697066*cos(2*x2)*x2 + 0.4271497577*cos(2*x3)*x2 + 0.2990742773*cos(2*x6)*x2 - 0.754021436*sin(2*x1)*x2 - 0.4381657541*sin(2*x2)*x2 - 0.3976926357*sin(2*x3)*x2 + 0.2065525353*x3^2 - 0.3818661422*cos(x1)*x3 - 0.5775232017*cos(x3)*x3 + 0.4152636528*sin(x1)*x3 + 1.919838905*sin(x2)*x3 + 0.5737055838*cos(2*x1)*x3 - 0.5389496982*cos(2*x2)*x3 + 0.1143727489*cos(2*x4)*x3 - 0.7606243193*sin(2*x1)*x3 + 0.05950496718*x4^2 + 0.1343437359*cos(x6)*x4 - 0.9388489127*sin(x1)*x4 - 0.7658673823*sin(x2)*x4 + 0.307544291*sin(x4)*x4 - 0.1386332512*sin(x5)*x4 - 0.111654304*cos(2*x1)*x4 - 0.172089003*cos(2*x6)*x4 - 0.2010171711*sin(2*x1)*x4 - 0.619889915*sin(2*x2)*x4 - 0.161875397*sin(x6)*x5 + 0.5380269289*cos(x1)*cos(x6) - 0.9494966567*cos(x1)*sin(x1) + 2.456929326*cos(x1)*sin(x2) + 2.063000679*cos(x1)*sin(x3) + 0.250304997*cos(2*x1)*cos(x1) + 0.5608130991*cos(2*x6)*cos(x1) + 1.114221156*cos(x1)*sin(2*x1) - 5.013676882*cos(x1)*sin(2*x2) - 1.864955485*cos(x1)*sin(2*x3) + 0.1504702121*cos(x2)^2 + 0.486681819*cos(x2)*cos(x3) + 0.2644059956*cos(x2)*cos(x4) - 0.4486124218*cos(x2)*cos(x6) - 6.04607296*cos(x2)*sin(x1) - 0.4113264233*cos(x2)*sin(x2) - 2.092016816*cos(x2)*sin(x3) - 0.5738799572*cos(x2)*sin(x4) + 0.9775738716*cos(2*x1)*cos(x2) - 0.736523062*cos(2*x2)*cos(x2) + 7.599377632*cos(x2)*sin(2*x1) - 1.425110698*cos(x2)*sin(2*x2) + 2.399811625*cos(x2)*sin(2*x3) + 0.1779822856*cos(x3)^2 - 0.4166154563*cos(x3)*cos(x4) - 0.2504982352*cos(x3)*cos(x5) - 1.035693765*cos(x3)*cos(x6) - 0.8675889373*cos(x3)*sin(x1) - 0.7471948862*cos(x3)*sin(x2) + 1.692544103*cos(x3)*sin(x5) - 0.1505213082*cos(x3)*sin(x6) + 0.528023392*cos(2*x1)*cos(x3) - 0.3799706548*cos(2*x2)*cos(x3) - 0.1926746666*cos(2*x4)*cos(x3) + 0.2028445527*cos(2*x5)*cos(x3) + 0.1120900884*cos(2*x6)*cos(x3) + 1.406133294*cos(x3)*sin(2*x1) - 1.931382537*cos(x3)*sin(2*x2) + 0.3292703182*cos(x3)*sin(2*x5) + 0.4552339315*cos(x4)^2 - 0.2573738843*cos(x4)*cos(x6) - 2.135506153*cos(x4)*sin(x1) + 0.3741796762*cos(x4)*sin(x2) + 0.1274516508*cos(x4)*sin(x3) + 0.368517682*cos(x4)*sin(x4) + 1.408467889*cos(2*x1)*cos(x4) - 1.106171429*cos(2*x2)*cos(x4) + 0.1222541854*cos(2*x5)*cos(x4) + 1.003362358*cos(x4)*sin(2*x1) - 2.143965364*cos(x4)*sin(2*x2) + 0.1592174321*cos(x5)*cos(x6) - 4.389330149*cos(x5)*sin(x1) + 4.192526817*cos(x5)*sin(x2) - 0.6534186006*cos(x5)*sin(x3) - 0.2143052667*cos(x5)*sin(x4) - 0.396977976*cos(x5)*sin(x5) - 1.762032568*cos(2*x1)*cos(x5) + 0.6040243208*cos(2*x2)*cos(x5) + 0.6821444631*cos(x5)*sin(2*x1) - 0.9834251106*cos(x5)*sin(2*x2) - 0.3374376148*cos(x5)*sin(2*x3) + 0.1458458304*cos(x6)^2 - 0.4297503978*cos(x6)*sin(x1) - 0.3195697367*cos(x6)*sin(x2) - 0.2391684651*cos(x6)*sin(x3) - 0.2168116271*cos(x6)*sin(x4) + 0.2473786175*cos(x6)*sin(x5) - 2.884059668*cos(2*x1)*cos(x6) + 0.8964029253*cos(2*x2)*cos(x6) - 0.5178659558*cos(2*x3)*cos(x6) + 0.17867814*cos(2*x4)*cos(x6) - 0.1655722857*cos(2*x5)*cos(x6) - 0.6274561286*cos(x6)*sin(2*x1) - 0.2556922287*cos(x6)*sin(2*x2) - 0.309547767*cos(x6)*sin(2*x3) - 0.1214646287*cos(x6)*sin(2*x4) + 1.943223*sin(x1)^2 + 1.639384747*sin(x1)*sin(x2) + 1.395143688*sin(x1)*sin(x3) - 0.3502970636*sin(x1)*sin(x4) - 2.249945164*sin(x1 ...
# (x5)' = 0.06773427874 - 0.347565189*cos(x1) - 0.3885360509*cos(x6) + 1.314077139*sin(x1) - 1.307675302*sin(x2) + 1.361045361*sin(x3) + 0.2620429695*sin(x4) + 0.4723266363*sin(x5) + 0.6664843857*cos(2*x1) - 0.5655971766*cos(2*x2) + 0.3152786493*sin(2*x1) + 0.2271232828*sin(2*x3) - 0.1254535466*x1^2 - 0.3610181808*cos(x1)*x1 - 0.3330826461*cos(x2)*x1 + 0.523704499*cos(x3)*x1 + 1.345375657*sin(x1)*x1 - 1.334222496*sin(x2)*x1 + 1.276777685*sin(x3)*x1 + 1.006505132*cos(2*x1)*x1 + 1.07516551*cos(2*x2)*x1 - 0.4956354797*cos(2*x6)*x1 + 0.2773884535*sin(2*x1)*x1 + 0.2975967675*sin(2*x5)*x1 + 0.1233228967*x2^2 - 0.2735139281*x2*x3 + 0.2109539881*cos(x2)*x2 + 0.7377249897*cos(x3)*x2 + 0.3886192143*cos(x5)*x2 + 1.263027966*sin(x1)*x2 - 1.318109095*sin(x2)*x2 + 0.8655408919*sin(x3)*x2 + 0.1981209219*sin(x5)*x2 - 1.365962863*cos(2*x1)*x2 - 1.220716357*cos(2*x2)*x2 - 1.168390632*cos(2*x3)*x2 + 0.3019176871*sin(2*x1)*x2 + 0.4065657258*sin(2*x3)*x2 - 0.3666896671*cos(x2)*x3 - 0.5101755261*cos(x5)*x3 - 0.4367156327*cos(x6)*x3 - 1.014248669*sin(x2)*x3 + 0.4736602306*sin(x3)*x3 - 0.4756667912*cos(2*x1)*x3 + 1.753990233*cos(2*x2)*x3 + 0.3492273092*cos(2*x3)*x3 + 0.5562816858*sin(2*x1)*x3 - 0.4891017377*sin(2*x2)*x3 - 0.289264217*sin(2*x3)*x3 + 0.7927848697*sin(x1)*x4 - 0.3452638388*sin(x2)*x4 + 0.3506294489*sin(2*x1)*x4 + 1.347259164*sin(x2)*x5 - 0.5086597204*sin(x3)*x5 + 0.4373745471*cos(2*x1)*x5 - 0.4884466827*cos(2*x2)*x5 + 0.7274259031*sin(2*x2)*x5 - 0.2699969262*sin(2*x3)*x5 + 0.2386998981*cos(2*x1)*x6 - 0.2895027697*cos(2*x2)*x6 + 0.200403139*cos(x1)^2 - 1.049412906*cos(x1)*cos(x6) + 0.3152736425*cos(x1)*sin(x1) - 3.219275117*cos(x1)*sin(x2) - 2.884341836*cos(x1)*sin(x3) - 0.73559618*cos(x1)*sin(x4) + 0.4470961988*cos(x1)*sin(x5) - 0.3441432863*cos(2*x1)*cos(x1) - 1.439629257*cos(x1)*sin(2*x1) + 5.733680487*cos(x1)*sin(2*x2) + 0.8204925954*cos(x1)*sin(2*x3) + 0.3532535583*cos(x1)*sin(2*x5) + 0.605981648*cos(x2)*cos(x6) + 4.491053104*cos(x2)*sin(x1) + 2.700584412*cos(x2)*sin(x3) - 0.8722286522*cos(2*x1)*cos(x2) + 0.8754961193*cos(2*x2)*cos(x2) - 0.2959918976*cos(2*x3)*cos(x2) - 6.95665431*cos(x2)*sin(2*x1) + 1.86308533*cos(x2)*sin(2*x2) - 4.840109587*cos(x2)*sin(2*x3) + 0.3325904012*cos(x2)*sin(2*x6) + 1.080875456*cos(x3)*cos(x5) + 1.383210957*cos(x3)*cos(x6) - 0.7652469277*cos(x3)*sin(x2) + 0.2271309868*cos(x3)*sin(x3) - 2.313271403*cos(x3)*sin(x5) - 0.4310113639*cos(2*x1)*cos(x3) + 0.5822521448*cos(2*x2)*cos(x3) - 0.2984023243*cos(2*x3)*cos(x3) + 1.398573041*cos(2*x4)*cos(x3) - 0.3751080483*cos(2*x5)*cos(x3) - 1.552865207*cos(x3)*sin(2*x1) + 4.40081501*cos(x3)*sin(2*x2) + 1.140516818*cos(x3)*sin(2*x4) - 0.9346987903*cos(x3)*sin(2*x5) + 0.3527604192*cos(x4)*cos(x5) + 3.530120611*cos(x4)*sin(x1) - 1.141161323*cos(x4)*sin(x2) - 0.6072186232*cos(x4)*sin(x3) + 0.5246013999*cos(x4)*sin(x5) - 1.703887343*cos(2*x1)*cos(x4) + 1.792992115*cos(2*x2)*cos(x4) - 0.4519110024*cos(x4)*sin(2*x1) + 3.432243347*cos(x4)*sin(2*x2) - 1.643057585*cos(x4)*sin(2*x3) + 0.3100287169*cos(x4)*sin(2*x4) + 3.853595972*cos(x5)*sin(x1) - 4.243772984*cos(x5)*sin(x2) + 1.902566195*cos(x5)*sin(x3) - 0.5006705523*cos(x5)*sin(x4) + 2.124325156*cos(2*x1)*cos(x5) - 1.16952455*cos(2*x2)*cos(x5) + 0.6773507595*cos(2*x3)*cos(x5) - 0.2546464056*cos(2*x6)*cos(x5) + 0.6455486715*cos(x5)*sin(2*x2) - 0.5046319366*cos(x6)*sin(x1) - 1.15970552*cos(x6)*sin(x2) + 3.59113729*cos(2*x1)*cos(x6) - 1.408660233*cos(2*x2)*cos(x6) + 0.819044888*cos(2*x3)*cos(x6) + 1.533966482*cos(x6)*sin(2*x1) - 1.479017019*cos(x6)*sin(2*x2) - 1.182670355*sin(x1)^2 + 3.36455977*sin(x1)*sin(x5) - 0.2865860164*sin(x1)*sin(x6) - 5.010195494*cos(2*x1)*sin(x1) - 21.6929121*cos(2*x2)*sin(x1) - 3.642736197*cos(2*x3)*sin(x1) - 0.448053807*cos(2*x5)*sin(x1) + 1.586922944*cos(2*x6)*sin(x1) + 0.4484910667*sin(2*x2)*sin(x1) + 0.6705183983*sin(2*x4)*sin(x1) + 1.010935307*sin(x2)^2 - 1.160145819*sin(x2)*sin(x3) + 1.498997569*sin(x2)*sin(x4) + 1.299252331*sin(x2)*sin(x5) - 0.2676970214*sin(x2)*sin(x6) + 19.87794113*cos(2*x1)*sin(x ...
# (x6)' = 0.1749418974 + 0.3869739473*x1 + 0.2678510249*x2 - 0.3763137013*x3 + 0.006476765033*x4 + 0.006697177421*x5 + 0.01078931475*x6 - 0.3967884332*cos(x1) - 0.3971863687*cos(x2) - 0.5121608377*cos(x3) - 0.003700344241*cos(x4) - 0.532612592*cos(x5) - 0.01236208063*sin(x1) + 1.17641592*sin(x2) - 0.0789581202*sin(x3) - 0.6026608348*sin(x4) - 0.01605816837*sin(x5) + 0.01196150854*sin(x6) + 0.5026513338*cos(2*x1) + 0.6071485877*cos(2*x2) - 0.006280058762*cos(2*x3) + 0.01033610012*cos(2*x4) - 0.01022294257*cos(2*x5) - 0.002119636978*cos(2*x6) + 0.003086009761*sin(2*x1) - 0.02061581425*sin(2*x2) + 0.6627049446*sin(2*x3) - 0.01571990829*sin(2*x4) - 0.007079913281*sin(2*x5) - 0.004601435736*sin(2*x6) + 0.175246641*x1^2 + 0.2610589266*x1*x2 - 0.4440391511*x1*x3 + 0.01021118462*x1*x4 + 0.005207318813*x1*x5 + 0.009479358792*x1*x6 - 0.3981904685*cos(x1)*x1 - 0.3689525127*cos(x2)*x1 - 0.4511743933*cos(x3)*x1 - 0.001981304144*cos(x4)*x1 - 0.5943409204*cos(x5)*x1 - 0.003273224924*sin(x1)*x1 + 1.199237287*sin(x2)*x1 - 0.07746628672*sin(x3)*x1 - 0.01362619363*sin(x4)*x1 - 0.01745009143*sin(x5)*x1 + 0.01472765906*sin(x6)*x1 + 0.4707545638*cos(2*x1)*x1 + 0.6245869398*cos(2*x2)*x1 - 0.003695601714*cos(2*x3)*x1 + 0.01405184064*cos(2*x4)*x1 + 0.008694062475*cos(2*x5)*x1 - 0.002972569666*sin(2*x1)*x1 - 0.02667268366*sin(2*x2)*x1 + 0.6941119432*sin(2*x3)*x1 - 0.02165095881*sin(2*x4)*x1 - 0.008535444271*sin(2*x5)*x1 - 0.007101521827*sin(2*x6)*x1 + 0.004076591693*x2^2 - 0.335176155*x2*x3 + 0.01099677337*x2*x4 + 0.005408955971*x2*x5 + 0.01228848426*x2*x6 - 0.3836061507*cos(x1)*x2 - 0.4027998596*cos(x2)*x2 - 0.8256267905*cos(x3)*x2 - 0.9480753541*cos(x5)*x2 - 0.01393485349*cos(x6)*x2 - 0.004323170055*sin(x1)*x2 + 1.217612863*sin(x2)*x2 - 0.08140840009*sin(x3)*x2 - 0.01597644947*sin(x4)*x2 - 0.004754080437*sin(x5)*x2 - 0.001658780151*sin(x6)*x2 + 0.6552583575*cos(2*x1)*x2 + 0.9408994615*cos(2*x2)*x2 + 0.9746813774*cos(2*x3)*x2 + 0.007138134446*cos(2*x4)*x2 - 0.01707862597*cos(2*x5)*x2 - 0.004600731656*sin(2*x1)*x2 - 0.03063548636*sin(2*x2)*x2 + 0.5395029783*sin(2*x3)*x2 - 0.01378288399*sin(2*x4)*x2 - 0.01508920174*sin(2*x5)*x2 + 0.00670931791*sin(2*x6)*x2 - 0.421851784*x3^2 - 0.3216407299*x3*x4 + 0.02320271358*x3*x5 + 0.003711043624*x3*x6 + 0.5231481194*cos(x1)*x3 + 1.257562399*cos(x2)*x3 - 0.4122710377*cos(x3)*x3 + 0.007666873746*cos(x4)*x3 + 1.700182557*cos(x5)*x3 + 0.02310988959*cos(x6)*x3 - 0.005074900808*sin(x1)*x3 + 0.03735601157*sin(x2)*x3 - 0.08271471411*sin(x3)*x3 + 0.8114042282*sin(x4)*x3 + 0.009309144691*sin(x5)*x3 - 0.005562161095*sin(x6)*x3 - 0.8976155818*cos(2*x1)*x3 - 4.06738615*cos(2*x2)*x3 - 0.02951326035*cos(2*x3)*x3 + 0.03015539423*cos(2*x4)*x3 - 0.01217735186*cos(2*x5)*x3 - 0.01148514077*cos(2*x6)*x3 - 0.3133208752*sin(2*x1)*x3 + 0.9836556315*sin(2*x2)*x3 + 0.7054474354*sin(2*x3)*x3 + 0.4604259431*sin(2*x4)*x3 - 0.01212622924*sin(2*x5)*x3 - 0.01478389464*sin(2*x6)*x3 + 0.2573029697*x4^2 - 0.03656478971*x4*x5 + 0.08597946912*x4*x6 - 0.005163474474*cos(x1)*x4 - 0.01101890858*cos(x2)*x4 - 0.9318333268*cos(x3)*x4 - 0.4287329316*cos(x4)*x4 - 0.01308088051*cos(x5)*x4 + 0.0280099269*cos(x6)*x4 - 0.4294738472*sin(x1)*x4 - 0.2725507468*sin(x2)*x4 + 1.073214769*sin(x3)*x4 + 0.6346091032*sin(x4)*x4 + 0.3189750761*sin(x5)*x4 - 0.1066723056*sin(x6)*x4 + 0.00253548671*cos(2*x1)*x4 + 0.02115993109*cos(2*x2)*x4 - 0.01526262565*cos(2*x3)*x4 - 0.2987747192*cos(2*x4)*x4 + 0.07778656855*cos(2*x5)*x4 - 0.09421187639*cos(2*x6)*x4 - 0.4949718714*sin(2*x1)*x4 + 0.06137721799*sin(2*x2)*x4 + 0.7952755988*sin(2*x3)*x4 + 0.07598203793*sin(2*x4)*x4 + 0.05891420133*sin(2*x5)*x4 - 0.02163682878*sin(2*x6)*x4 - 0.05978386849*x5^2 - 0.008699940052*x5*x6 - 0.007176779211*cos(x1)*x5 + 0.009082677774*cos(x2)*x5 + 0.05931058526*cos(x3)*x5 + 0.01334597636*cos(x4)*x5 - 0.1078595519*cos(x5)*x5 - 0.1021684073*cos(x6)*x5 + 0.04194710776*sin(x1)*x5 - 0.9230626523*sin(x2)*x5 + 0.6360005438*sin(x3)*x5 - 0.03010251559*sin(x4)*x5 - 0.2838376909*sin(x5)*x5 + 0.08652479202*sin(x6)*x5 ...

# %% [markdown]
# ### Validation

# %%
import importlib

import model_reconstructor as mr

importlib.reload(mr)

recovered_model = mr.RecoveredModel()
recovered_model.parse_ode_equations(eq_str)


val_t_span = [0,10]
val_t_eval = np.arange(0,10,dt)

# x includes theta and d_theta
val_x, val_d_theta = load_triple_pendulum_data('../experiment_data/TriplePendulum_Data/TripleDataFreeSwing_3_Dt_0_0001.mat',downsample=100)

data_initial_conditions = val_x[0]
SREINet_pred = recovered_model.simulate(data_initial_conditions, t_span=val_t_span, t_eval=val_t_eval, method='RK45')

# %%
import matplotlib.pyplot as plt

plt.plot(SREINet_pred['t'], SREINet_pred['y'][0],label='SREINet')
plt.plot(val_t_eval, val_x[:val_t_eval.shape[0],0], '--', label='True')
plt.xlabel('Time, t')
plt.ylabel(r'$\theta_1$')
plt.title('Position of the 1st pendulum')
plt.legend()
plt.show()

plt.figure()
plt.plot(SREINet_pred['t'], SREINet_pred['y'][3],label='SREINet')
plt.plot(val_t_eval, val_x[:val_t_eval.shape[0],3], '--', label='True')
plt.xlabel('Time, t')
plt.ylabel(r'$\dot{\theta}_1$')
plt.title('Velocity of the 1st pendulum')
plt.legend()
plt.show()

# %%
#calculate derivatives 
pred_dx = recovered_model.predict_derivatives(SREINet_pred['y'].transpose())
pred_dx = pred_dx.transpose()

# Calculate derivative using Savitzky-Golay filter
window_length = 7  # Window length
polyorder = 2     # Polynomial order
val_dd_theta = savgol_filter(val_d_theta, window_length, polyorder, delta=dt, deriv=1, axis=0)

# %%
plt.plot(SREINet_pred['t'], pred_dx[4],label='SREINet')
plt.plot(val_t_eval, val_dd_theta[:val_t_eval.shape[0], 1], '--', label='True')
plt.xlabel('Time, t')
plt.ylabel(r'$\ddot{\theta_1}$')
plt.legend()
plt.title('Anuglar Acceleration of the 1st pendulum')
plt.show()

# %%
# Save output data to file
output_file = 'output/triple_pendulum_2layers_data.npz'
np.savez(output_file,
         SREINet_t=SREINet_pred['t'],
         SREINet_y=SREINet_pred['y'],
         val_t_eval=val_t_eval,
         val_x=val_x,
         pred_dx=pred_dx,
         val_dd_theta=val_dd_theta)
print(f"Data saved to {output_file}")
# Out:
# Data saved to output/triple_pendulum_2layers_data.npz
