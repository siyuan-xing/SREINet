# %% [markdown]
# ## **Double-pendulum model by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG

# Tensowflow version should be 2.13.0 or
# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("*******************************|***************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()


opt_folder = 'output'
# Create the folder if it doesn't exist
os.makedirs(opt_folder, exist_ok=True)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# *******************************|***************

# %% [markdown]
# ### **1.2 Training Data**

# %%
def load_double_pendulum_data(mat_path, downsample=1):
    """
    Loads double pendulum data from a MATLAB .mat file and returns the relevant arrays, with optional downsampling.
    Args:
        mat_path (str): Path to the .mat file.
        downsample (int): Take every nth sample (default 1, i.e., no downsampling)
    Returns:
        my_data (np.ndarray): Concatenated array of [theta1, theta2, d_theta1, d_theta2], shape (N, 4)
        d_theta (np.ndarray): Concatenated array of [d_theta1, d_theta2], shape (N, 2)
        time (np.ndarray): Time array
        dt (float): Time step
    """
    from scipy.io import loadmat
    import numpy as np

    data = loadmat(mat_path)
    theta1 = data['Theta1'][::downsample]
    theta2 = data['Theta2'][::downsample]
    d_theta1 = data['dTheta1'][::downsample]
    d_theta2 = data['dTheta2'][::downsample]

    my_data = np.concatenate([theta1, theta2, d_theta1, d_theta2], axis=1)
    d_theta = np.concatenate([d_theta1, d_theta2], axis=1)

    return my_data, d_theta

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_DATA_TYPE = 'float32'

SEED = 42  # set seed for random number generation
np.random.seed(SEED)

import scipy.io as sio
import numpy as np
from skimage.transform import resize
import matplotlib.pyplot as plt
import cmocean

from sklearn.preprocessing import MinMaxScaler

from scipy.signal import savgol_filter


#load data
from scipy.io import loadmat

data_1, d_theta_1 = load_double_pendulum_data('DoublePendulum_Data/DoubleDataFreeSwing_1_Dt_0_001.mat',downsample=20)
data_2, d_theta_2 = load_double_pendulum_data('DoublePendulum_Data/DoubleDataFreeSwing_2_Dt_0_001.mat',downsample=20)

my_data = np.concatenate([data_1, data_2], axis=0)

dt = 0.001 * 20 #original dt



# Calculate derivative using Savitzky-Golay filter
window_length = 7  # Window length
polyorder = 2     # Polynomial order
dd_theta_1 = savgol_filter(d_theta_1, window_length, polyorder, delta=dt, deriv=1, axis=0)
dd_theta_2 = savgol_filter(d_theta_2, window_length, polyorder, delta=dt, deriv=1, axis=0)

derivative_data_1 = np.concatenate([d_theta_1, dd_theta_1], axis=1)
derivative_data_2 = np.concatenate([d_theta_2, dd_theta_2], axis=1)
derivative_data = np.concatenate([derivative_data_1, derivative_data_2], axis=0)

# %%
training_input = my_data
training_output = derivative_data


print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Training input shape: (17669, 4)
# Training output shape: (17669, 4)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 32
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables)
dim = training_input.shape[1] 

guess_highest_order_polynomial = 3

layer_depth = guess_highest_order_polynomial
# The grid size of each dimension
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn)
# Out:
# [4, 4, 4]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x,
                 lambda x:tf.cos(x),
                 lambda x:tf.sin(x),
                 lambda x:tf.cos(2*x),
                 lambda x:tf.sin(2*x),
                 #lambda x:tf.cos(3*x),
                 #lambda x:tf.sin(3*x),
                 ]

inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn, 1, 
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=1e-5, seed=SEED),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Trainer**

# %%
from sreinet_trainer import *

trainer = SREINetTrainer(model, my_optimizer, loss_fn, data_type='float32')

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# ### First two dimensions

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.3 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 10
PRUNING_EPOCHS_PER_PERIOD = 240
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

# Define the pruning schedule

pruning_scheduler = ps.PruningScheduler(steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                    num_periods=N_PERIODS,
                    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
                    zero_percentage=0.1,
                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
EARLY_STOPPING_LOSS_THRESHOLD = 1e-8  # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.1

training_histories = []
weights_list = []
loss_list = []

# %%
for i in range(0, 2):
    print(f"Training dimension {i + 1}...")
    
    output = training_output[:, i:i+1]
    
    history = trainer.fit(training_input, output,
     batch_size=MINI_BATCH_SIZE, 
     validation_split=0.00,
     epochs=round(NUM_EPOCHS), 
     pruning_scheduler=pruning_scheduler,
     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
     verbose=1,
     print_every_n_epochs=10,
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
    loss_list.append(trainer.get_best_loss())

    #reset the model and trainer
    trainer.reset_trainer_and_model_weights(i)
# Out:
# Training dimension 1...
# Epoch   1 (Period 1):  Train Loss: 2.669e-01,  Epoch Time: 0.53s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 2.926e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 1.065e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 5.905e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083091
# Epoch  41 (Period 1):  Train Loss: 9.848e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0058754
# Epoch  51 (Period 1):  Train Loss: 4.688e-05,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.015348
# Epoch  61 (Period 1):  Train Loss: 2.647e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028958
# Epoch  71 (Period 1):  Train Loss: 4.330e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046286
# Epoch  81 (Period 1):  Train Loss: 3.501e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.066801
# Epoch  91 (Period 1):  Train Loss: 6.674e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.089873
# Epoch 101 (Period 1):  Train Loss: 7.330e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.11479
# Epoch 111 (Period 1):  Train Loss: 6.244e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.14079
# Epoch 121 (Period 1):  Train Loss: 9.562e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.16707
# Epoch 131 (Period 1):  Train Loss: 1.562e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.19283
# Epoch 141 (Period 1):  Train Loss: 1.318e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.21728
# Epoch 151 (Period 1):  Train Loss: 1.145e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.23965
# Epoch 161 (Period 1):  Train Loss: 6.333e-09,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.25927
# Early stopping at epoch 161 as train loss 0.00000000633309 is below the threshold 0.00000001000000
# Training Stopped. Time elapsed: 51.91s
# Training dimension 2...
# Epoch   1 (Period 1):  Train Loss: 2.412e-01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 1.159e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 8.816e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 7.091e-04,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.00083091
# Epoch  41 (Period 1):  Train Loss: 6.151e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0058754
# Epoch  51 (Period 1):  Train Loss: 1.854e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.015348
# Epoch  61 (Period 1):  Train Loss: 1.455e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028958
# Epoch  71 (Period 1):  Train Loss: 4.265e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046286
# Epoch  81 (Period 1):  Train Loss: 5.495e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.066801
# Epoch  91 (Period 1):  Train Loss: 6.148e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.089873
# Epoch 101 (Period 1):  Train Loss: 2.316e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.11479
# Epoch 111 (Period 1):  Train Loss: 1.287e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14079
# Epoch 121 (Period 1):  Train Loss: 6.322e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.16707
# Epoch 131 (Period 1):  Train Loss: 2.394e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.19283
# Epoch 141 (Period 1):  Train Loss: 1.723e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.21728
# Epoch 151 (Period 1):  Train Loss: 1.671e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.23965
# Epoch 161 (Period 1):  Train Loss: 1.686e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.25927
# Epoch 171 (Period 1):  Train Loss: 1.654e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.27554
# Epoch 181 (Period 1):  Train Loss: 1.547e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.28794
# Epoch 191 (Period 1):  Train Loss: 1.372e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.29611
# Epoch 201 (Period 1):  Train Loss: 1.478e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.29979
# Epoch 211 (Period 1):  Train Loss: 1.322e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.3
# Epoch 221 (Period 1):  Train Loss: 1.276e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.3
# Epoch 231 (Period 1):  Train Loss: 1.175e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.3
# Epoch 241 (Period 2):  Train Loss: 1.922e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 251 (Period 2):  Train Loss: 3.105e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 261 (Period 2):  Train Loss: 2.442e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 271 (Period 2):  Train Loss: 1.118e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083091
# Epoch 281 (Period 2):  Train Loss: 8.466e-06,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0058754
# Epoch 291 (Period 2):  Train Loss: 2.345e-06,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.015348
# Epoch 301 (Period 2):  Train Loss: 4.567e-06,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028958
# Epoch 311 (Period 2):  Train Loss: 4.153e-06,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046286
# Epoch 321 (Period 2):  Train Loss: 5.022e-06,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.066801
# Epoch 331 (Period 2):  Train Loss: 1.006e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.089873
# Epoch 341 (Period 2):  Train Loss: 8.773e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.11479
# Epoch 351 (Period 2):  Train Loss: 8.873e-05,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.14079
# Epoch 361 (Period 2):  Train Loss: 8.214e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.16707
# Epoch 371 (Period 2):  Train Loss: 7.013e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.19283
# Epoch 381 (Period 2):  Train Loss: 6.415e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.21728
# Epoch 391 (Period 2):  Train Loss: 2.933e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.23965
# Early stopping at epoch 396 as train loss 0.00000000000055 is below the threshold 0.00000001000000
# Training Stopped. Time elapsed: 127.92s

# %% [markdown]
# ### Last three dimensions

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.15 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 3
PRUNING_EPOCHS_PER_PERIOD = 200
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

# Define the pruning schedule

pruning_scheduler = ps.PruningScheduler(steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                    num_periods=N_PERIODS,
                    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
                    zero_percentage=0.15,
                    show_plot=True)

# %%
EARLY_STOPPING_LOSS_THRESHOLD = 2e-1  # Threshold for early stopping
EARLY_STOPPING_PRUNING_THRESHOLD = 0.05

# %%
# For double pendulum, we only have 2 dimensions, so this loop is not needed
# But keeping it for consistency with the structure
for i in range(2, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    output = training_output[:, i:i+1]

    history = trainer.fit(training_input, output,
     batch_size=MINI_BATCH_SIZE, 
     validation_split=0.20,
     epochs=round(NUM_EPOCHS), 
     pruning_scheduler=pruning_scheduler,
     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
     verbose=1,
     print_every_n_epochs=10,
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
    loss_list.append(trainer.get_best_loss())

    #reset the model and trainer
    trainer.reset_trainer_and_model_weights(i)
# Out:
# Training dimension 3...
# Epoch   1 (Period 1):  Train Loss: 5.339e+01,  Validation Loss: 1.040e+01,  Epoch Time: 0.47s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 8.498e-01,  Validation Loss: 6.451e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 5.216e-01,  Validation Loss: 5.367e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 4.450e-01,  Validation Loss: 3.431e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch  41 (Period 1):  Train Loss: 3.561e-01,  Validation Loss: 2.974e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.0016609
# Epoch  51 (Period 1):  Train Loss: 3.262e-01,  Validation Loss: 2.978e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.0065701
# Epoch  61 (Period 1):  Train Loss: 3.101e-01,  Validation Loss: 3.274e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.01451
# Epoch  71 (Period 1):  Train Loss: 3.181e-01,  Validation Loss: 3.347e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.025129
# Epoch  81 (Period 1):  Train Loss: 2.896e-01,  Validation Loss: 3.069e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.037957
# Epoch  91 (Period 1):  Train Loss: 2.809e-01,  Validation Loss: 2.078e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.052426
# Epoch 101 (Period 1):  Train Loss: 3.082e-01,  Validation Loss: 3.545e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.067895
# Epoch 111 (Period 1):  Train Loss: 3.271e-01,  Validation Loss: 2.940e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.083678
# Epoch 121 (Period 1):  Train Loss: 2.789e-01,  Validation Loss: 2.719e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099077
# Epoch 131 (Period 1):  Train Loss: 3.134e-01,  Validation Loss: 2.750e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.11341
# Epoch 141 (Period 1):  Train Loss: 4.136e-01,  Validation Loss: 3.312e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.12604
# Epoch 151 (Period 1):  Train Loss: 3.281e-01,  Validation Loss: 2.695e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.13641
# Epoch 161 (Period 1):  Train Loss: 3.253e-01,  Validation Loss: 3.317e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14406
# Epoch 171 (Period 1):  Train Loss: 3.025e-01,  Validation Loss: 2.555e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.14865
# Epoch 181 (Period 1):  Train Loss: 3.187e-01,  Validation Loss: 4.090e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.15
# Epoch 191 (Period 1):  Train Loss: 3.167e-01,  Validation Loss: 2.130e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.15
# Epoch 201 (Period 2):  Train Loss: 5.844e-01,  Validation Loss: 2.744e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch 211 (Period 2):  Train Loss: 3.153e-01,  Validation Loss: 3.549e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch 221 (Period 2):  Train Loss: 3.296e-01,  Validation Loss: 2.377e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch 231 (Period 2):  Train Loss: 2.992e-01,  Validation Loss: 2.874e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 241 (Period 2):  Train Loss: 2.602e-01,  Validation Loss: 2.241e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.0016609
# Epoch 251 (Period 2):  Train Loss: 2.664e-01,  Validation Loss: 2.300e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.0065701
# Epoch 261 (Period 2):  Train Loss: 2.596e-01,  Validation Loss: 3.574e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.01451
# Epoch 271 (Period 2):  Train Loss: 2.709e-01,  Validation Loss: 2.142e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.025129
# Epoch 281 (Period 2):  Train Loss: 2.609e-01,  Validation Loss: 3.446e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.037957
# Epoch 291 (Period 2):  Train Loss: 2.560e-01,  Validation Loss: 3.169e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.052426
# Epoch 301 (Period 2):  Train Loss: 2.642e-01,  Validation Loss: 2.355e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.067895
# Epoch 311 (Period 2):  Train Loss: 4.039e-01,  Validation Loss: 2.772e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.083678
# Epoch 321 (Period 2):  Train Loss: 2.916e-01,  Validation Loss: 3.357e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099077
# Epoch 331 (Period 2):  Train Loss: 2.739e-01,  Validation Loss: 2.829e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.11341
# Epoch 341 (Period 2):  Train Loss: 2.860e-01,  Validation Loss: 2.315e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12604
# Epoch 351 (Period 2):  Train Loss: 3.250e-01,  Validation Loss: 2.663e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13641
# Epoch 361 (Period 2):  Train Loss: 3.058e-01,  Validation Loss: 2.687e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14406
# Epoch 371 (Period 2):  Train Loss: 2.905e-01,  Validation Loss: 2.596e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14865
# Epoch 381 (Period 2):  Train Loss: 3.103e-01,  Validation Loss: 2.880e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.15
# Epoch 391 (Period 2):  Train Loss: 2.904e-01,  Validation Loss: 2.442e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.15
# Epoch 401 (Period 3):  Train Loss: 5.522e-01,  Validation Loss: 4.876e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch 411 (Period 3):  Train Loss: 2.779e-01,  Validation Loss: 1.928e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 421 (Period 3):  Train Loss: 2.596e-01,  Validation Loss: 3.227e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 431 (Period 3):  Train Loss: 2.751e-01,  Validation Loss: 4.183e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 441 (Period 3):  Train Loss: 2.314e-01,  Validation Loss: 2.106e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.0016609
# Epoch 451 (Period 3):  Train Loss: 2.519e-01,  Validation Loss: 1.952e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0065701
# Epoch 461 (Period 3):  Train Loss: 2.074e-01,  Validation Loss: 2.942e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.01451
# Epoch 471 (Period 3):  Train Loss: 2.472e-01,  Validation Loss: 2.443e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.025129
# Epoch 481 (Period 3):  Train Loss: 2.517e-01,  Validation Loss: 2.097e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.037957
# Epoch 491 (Period 3):  Train Loss: 2.471e-01,  Validation Loss: 3.346e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.052426
# Epoch 501 (Period 3):  Train Loss: 2.489e-01,  Validation Loss: 2.245e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.067895
# Epoch 511 (Period 3):  Train Loss: 2.496e-01,  Validation Loss: 2.431e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.083678
# Epoch 521 (Period 3):  Train Loss: 2.299e-01,  Validation Loss: 2.366e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099077
# Epoch 531 (Period 3):  Train Loss: 2.663e-01,  Validation Loss: 2.290e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.11341
# Epoch 541 (Period 3):  Train Loss: 2.165e-01,  Validation Loss: 2.316e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12604
# Epoch 551 (Period 3):  Train Loss: 2.531e-01,  Validation Loss: 2.152e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13641
# Epoch 561 (Period 3):  Train Loss: 2.525e-01,  Validation Loss: 2.267e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14406
# Epoch 571 (Period 3):  Train Loss: 2.674e-01,  Validation Loss: 2.357e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14865
# Epoch 581 (Period 3):  Train Loss: 2.599e-01,  Validation Loss: 2.200e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch 591 (Period 3):  Train Loss: 2.264e-01,  Validation Loss: 2.136e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch 600 (Period 3):  Train Loss: 2.313e-01,  Validation Loss: 2.588e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Training Stopped. Time elapsed: 190.56s
# Training dimension 4...
# Epoch   1 (Period 1):  Train Loss: 8.637e+01,  Validation Loss: 1.193e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 1.498e+00,  Validation Loss: 1.390e+00,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch  21 (Period 1):  Train Loss: 1.104e+00,  Validation Loss: 9.341e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  31 (Period 1):  Train Loss: 9.887e-01,  Validation Loss: 7.246e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  41 (Period 1):  Train Loss: 9.392e-01,  Validation Loss: 7.024e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0016609
# Epoch  51 (Period 1):  Train Loss: 8.238e-01,  Validation Loss: 7.619e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0065701
# Epoch  61 (Period 1):  Train Loss: 7.234e-01,  Validation Loss: 7.599e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.01451
# Epoch  71 (Period 1):  Train Loss: 7.575e-01,  Validation Loss: 8.283e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.025129
# Epoch  81 (Period 1):  Train Loss: 7.334e-01,  Validation Loss: 7.405e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.037957
# Epoch  91 (Period 1):  Train Loss: 7.307e-01,  Validation Loss: 6.077e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.052426
# Epoch 101 (Period 1):  Train Loss: 7.336e-01,  Validation Loss: 7.663e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.067895
# Epoch 111 (Period 1):  Train Loss: 6.952e-01,  Validation Loss: 5.792e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.083678
# Epoch 121 (Period 1):  Train Loss: 6.735e-01,  Validation Loss: 6.403e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099077
# Epoch 131 (Period 1):  Train Loss: 7.210e-01,  Validation Loss: 6.156e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.11341
# Epoch 141 (Period 1):  Train Loss: 6.886e-01,  Validation Loss: 6.447e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12604
# Epoch 151 (Period 1):  Train Loss: 7.018e-01,  Validation Loss: 5.677e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13641
# Epoch 161 (Period 1):  Train Loss: 9.428e-01,  Validation Loss: 9.480e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14406
# Epoch 171 (Period 1):  Train Loss: 9.296e-01,  Validation Loss: 1.027e+00,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14865
# Epoch 181 (Period 1):  Train Loss: 1.083e+00,  Validation Loss: 8.114e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch 191 (Period 1):  Train Loss: 9.108e-01,  Validation Loss: 7.661e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch 201 (Period 2):  Train Loss: 1.179e+00,  Validation Loss: 7.344e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 211 (Period 2):  Train Loss: 7.686e-01,  Validation Loss: 6.874e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 221 (Period 2):  Train Loss: 7.289e-01,  Validation Loss: 5.834e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 231 (Period 2):  Train Loss: 7.135e-01,  Validation Loss: 5.613e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch 241 (Period 2):  Train Loss: 6.956e-01,  Validation Loss: 6.075e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0016609
# Epoch 251 (Period 2):  Train Loss: 6.274e-01,  Validation Loss: 5.662e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.0065701
# Epoch 261 (Period 2):  Train Loss: 5.993e-01,  Validation Loss: 5.308e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.01451
# Epoch 271 (Period 2):  Train Loss: 5.990e-01,  Validation Loss: 6.732e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.025129
# Epoch 281 (Period 2):  Train Loss: 6.272e-01,  Validation Loss: 6.391e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.037957
# Epoch 291 (Period 2):  Train Loss: 5.770e-01,  Validation Loss: 5.396e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.052426
# Epoch 301 (Period 2):  Train Loss: 6.442e-01,  Validation Loss: 5.077e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.067895
# Epoch 311 (Period 2):  Train Loss: 7.210e-01,  Validation Loss: 6.394e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.083678
# Epoch 321 (Period 2):  Train Loss: 6.472e-01,  Validation Loss: 5.727e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099077
# Epoch 331 (Period 2):  Train Loss: 6.502e-01,  Validation Loss: 6.556e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.11341
# Epoch 341 (Period 2):  Train Loss: 6.425e-01,  Validation Loss: 5.422e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12604
# Epoch 351 (Period 2):  Train Loss: 6.614e-01,  Validation Loss: 5.660e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13641
# Epoch 361 (Period 2):  Train Loss: 6.195e-01,  Validation Loss: 6.298e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14406
# Epoch 371 (Period 2):  Train Loss: 6.706e-01,  Validation Loss: 6.561e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14865
# Epoch 381 (Period 2):  Train Loss: 6.507e-01,  Validation Loss: 5.525e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch 391 (Period 2):  Train Loss: 6.559e-01,  Validation Loss: 7.124e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch 401 (Period 3):  Train Loss: 9.942e-01,  Validation Loss: 6.971e-01,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch 411 (Period 3):  Train Loss: 6.719e-01,  Validation Loss: 6.398e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 421 (Period 3):  Train Loss: 6.258e-01,  Validation Loss: 7.021e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 431 (Period 3):  Train Loss: 6.621e-01,  Validation Loss: 6.620e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 441 (Period 3):  Train Loss: 6.405e-01,  Validation Loss: 6.454e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0016609
# Epoch 451 (Period 3):  Train Loss: 6.280e-01,  Validation Loss: 5.495e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0065701
# Epoch 461 (Period 3):  Train Loss: 5.904e-01,  Validation Loss: 4.813e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.01451
# Epoch 471 (Period 3):  Train Loss: 5.661e-01,  Validation Loss: 4.852e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.025129
# Epoch 481 (Period 3):  Train Loss: 5.977e-01,  Validation Loss: 5.293e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.037957
# Epoch 491 (Period 3):  Train Loss: 5.963e-01,  Validation Loss: 4.785e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.052426
# Epoch 501 (Period 3):  Train Loss: 6.034e-01,  Validation Loss: 5.783e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.067895
# Epoch 511 (Period 3):  Train Loss: 5.794e-01,  Validation Loss: 4.771e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.083678
# Epoch 521 (Period 3):  Train Loss: 5.689e-01,  Validation Loss: 5.764e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099077
# Epoch 531 (Period 3):  Train Loss: 5.591e-01,  Validation Loss: 5.860e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.11341
# Epoch 541 (Period 3):  Train Loss: 6.386e-01,  Validation Loss: 5.373e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12604
# Epoch 551 (Period 3):  Train Loss: 6.505e-01,  Validation Loss: 5.995e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13641
# Epoch 561 (Period 3):  Train Loss: 6.207e-01,  Validation Loss: 5.764e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14406
# Epoch 571 (Period 3):  Train Loss: 6.365e-01,  Validation Loss: 7.430e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14865
# Epoch 581 (Period 3):  Train Loss: 5.818e-01,  Validation Loss: 7.587e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch 591 (Period 3):  Train Loss: 6.202e-01,  Validation Loss: 7.671e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch 600 (Period 3):  Train Loss: 5.986e-01,  Validation Loss: 5.821e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Training Stopped. Time elapsed: 192.27s

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_layer_labels(N): # N is the number of neurons per layer
    num_terms = N // 5 # get the number of state variables. 

    return ['Constant'] + [f'x{i}' for i in range(1, num_terms+1)] + [f'cos(x{i})' for i in range(1, num_terms+1)] + [f'sin(x{i})' for i in range(1, num_terms+1)] + [f'cos(2*x{i})' for i in range(1, num_terms+1)] + [f'sin(2*x{i})' for i in range(1, num_terms+1)] 

def generate_LHS_labels(N):
    num_terms = N // 5
    return [f"(x{i})'" for i in range(1, num_terms+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
from coefficient_reconstructor import *
cr = CoefficientReconstructor(generate_layer_labels, generate_LHS_labels)

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
eq_str = []
for i in range(len(weights_list)):
    path_products = cr.reconstruct_coefficients(i,
                                               weights_list[i], 
                                            minimum_coefficient_threshold = 1e-3,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
        eq_str.append(dimension)
# Out:
# (x1)' = 1.000001169*x3
# (x2)' = 1.000000106*x4
# (x3)' = 0.2604689936 + 0.2950635791*x1 - 0.129873776*x2 + 0.07431053556*x3 + 0.6045620125*cos(x2) - 0.1807108979*cos(x3) + 0.02566818412*cos(x4) + 1.427914313*sin(x2) - 0.3895277209*sin(x3) - 0.03432671021*cos(2*x2) + 0.2282628848*sin(2*x1) + 0.6897657425*sin(2*x2) - 0.03610946584*sin(2*x3) + 0.008958843158*sin(2*x4) + 0.006594755429*x1*x4 + 0.005014900626*x3*x4 - 0.6269921547*sin(x1)*x4 + 0.1802569455*sin(x2)*x4 + 0.01429928306*sin(x3)*x4 - 0.02862233652*cos(2*x1)*x4 + 0.01364221668*cos(2*x2)*x4 + 0.1599678168*sin(2*x2)*x4 - 0.123285773*cos(x3)*x1 + 0.0692847571*cos(x3)*x2 - 0.002239741615*cos(x3)*x3 - 0.01819810854*cos(x1)*cos(x3) - 0.180979366*cos(x2)*cos(x3) - 0.007921164676*cos(x3)^2 + 0.03294010628*cos(x3)*cos(x4) - 0.4081854662*cos(x3)*sin(x1) + 0.3516996862*cos(x3)*sin(x2) + 0.05348265678*cos(x3)*sin(x3) - 0.02225516777*cos(x3)*sin(x4) + 0.09038277299*cos(2*x1)*cos(x3) - 0.001087330658*cos(2*x2)*cos(x3) - 0.002133162577*cos(2*x4)*cos(x3) + 0.4131242266*cos(x3)*sin(2*x1) - 0.2098484732*cos(x3)*sin(2*x2) + 0.02905446695*cos(x3)*sin(2*x3) + 0.00357687109*cos(x3)*sin(2*x4) + 0.01004716443*cos(x4)*x1 - 0.02539319095*cos(x4)*x2 - 0.001926376243*cos(x4)*x3 - 0.002058354983*cos(x4)*x4 + 0.05802529531*cos(x2)*cos(x4) - 0.03919734716*cos(x4)*sin(x1) + 0.1082187222*cos(x4)*sin(x2) + 0.05730006189*cos(2*x1)*cos(x4) + 0.003294395365*cos(2*x2)*cos(x4) + 0.007729717176*cos(2*x3)*cos(x4) + 0.005580801172*cos(2*x4)*cos(x4) + 0.001789776977*cos(x4)*sin(2*x1) + 0.06009325839*cos(x4)*sin(2*x2) - 0.005875571604*cos(x4)*sin(2*x4) + 1.671175688*sin(x1) + 1.97072367*sin(x1)*x1 + 1.48057019*sin(x1)*x2 - 0.09175117065*sin(x1)*x3 - 1.268502144*cos(x1)*sin(x1) - 1.261285237*cos(x2)*sin(x1) + 2.566938172*sin(x1)^2 + 3.675727565*sin(x1)*sin(x2) + 0.1189923702*sin(x1)*sin(x3) - 0.160970078*sin(x1)*sin(x4) - 1.054464518*cos(2*x1)*sin(x1) + 0.7096307144*cos(2*x2)*sin(x1) - 0.5675719194*sin(2*x1)*sin(x1) - 0.6488591393*sin(2*x2)*sin(x1) + 0.9735104051*sin(x2)*x1 + 0.0136939826*sin(x2)*x2 + 0.09031888775*sin(x2)*x3 + 0.3127377881*cos(x1)*sin(x2) + 1.406441106*cos(x2)*sin(x2) + 1.478031964*sin(x2)^2 - 1.003790384*sin(x2)*sin(x3) + 0.06600806277*sin(x2)*sin(x4) - 1.822940124*cos(2*x1)*sin(x2) - 0.6925125355*cos(2*x2)*sin(x2) + 0.5095069911*sin(2*x1)*sin(x2) + 2.042459273*sin(2*x2)*sin(x2) - 0.2485959675*sin(x3)*x1 - 0.04085201371*sin(x3)*x3 - 0.03328329097*cos(x1)*sin(x3) - 0.6409276182*cos(x2)*sin(x3) + 0.07523203351*sin(x3)^2 + 0.1644412118*cos(2*x1)*sin(x3) - 0.09027597426*cos(2*x2)*sin(x3) + 0.003021934442*cos(2*x3)*sin(x3) - 0.2336125618*sin(2*x1)*sin(x3) - 0.3950962543*sin(2*x2)*sin(x3) + 0.05600278975*sin(2*x3)*sin(x3) - 0.401530294*cos(2*x1) + 0.3349543833*cos(2*x1)*x2 + 0.008523152642*cos(2*x1)*cos(x1) + 0.1806709935*cos(2*x1)^2 - 0.4647468836*cos(2*x1)*sin(2*x1) + 0.9392457157*cos(2*x1)*sin(2*x2) - 0.01788912937*cos(2*x2)*x1 + 0.08286136001*cos(2*x2)*x2 - 0.07398395082*cos(2*x2)*cos(x2) - 0.1896506079*cos(2*x1)*cos(2*x2) - 0.01756432961*cos(2*x2)^2 - 1.41123788*cos(2*x2)*sin(2*x1) - 0.1493867822*cos(2*x2)*sin(2*x2) + 0.03729274096*sin(2*x1)*x1 + 0.01036008091*sin(2*x1)*x2 - 0.1877728219*sin(2*x1)*x4 + 0.3223717161*cos(x1)*sin(2*x1) + 0.7473354289*cos(x2)*sin(2*x1) + 0.01399817529*sin(2*x1)^2 - 0.5045417959*sin(2*x1)*sin(2*x2) - 0.02978151493*sin(2*x1)*sin(2*x3) - 0.002635166118*sin(2*x4)*x1 - 0.001528240136*sin(2*x4)*x2 + 0.01154207478*cos(x1)*sin(2*x4) + 0.0112808037*cos(x2)*sin(2*x4) - 0.07403955491*sin(2*x4)*sin(x3) + 0.005172752124*sin(2*x4)*sin(x4) + 0.07807809816*cos(2*x1)*sin(2*x4) - 0.03796916336*cos(2*x2)*sin(2*x4) - 0.002604339266*cos(2*x3)*sin(2*x4) + 0.02234597908*cos(2*x4)*sin(2*x4) + 0.02604205475*sin(2*x3)*sin(2*x4) + 0.01835572884*sin(2*x4)^2 + 0.08352366299*x1^2 - 0.07485561859*x1*x2 + 0.03249008552*x1*x3 + 0.3450200544*cos(x2)*x1 + 0.3898011279*sin(2*x2)*x1 - 0.02372634714*sin(2*x3)*x1 + 0.03148203302*cos(x1)*x1*x2 - 0.002401981832*cos(x2)*x1*x2 - 0.005123477757*cos(x3)*x1*x2 - 0.003923148023*cos(x4)*x1*x2 + 1.110123708*sin(x1) ...
# (x4)' = 0.0651170191 - 0.07260086653*x2 - 0.08653357383*cos(x1) + 0.2767843934*cos(x2) - 0.1502657266*cos(x3) - 0.02547680948*cos(x4) + 0.1760602397*sin(x1) + 0.2559201432*sin(x2) + 0.3085054803*sin(x3) + 0.4454060615*cos(2*x1) - 0.2167276092*cos(2*x2) + 0.01057170535*cos(2*x3) - 0.5397127188*sin(2*x1) + 0.3901109022*sin(2*x2) - 0.01446386294*sin(2*x3) + 0.01653051833*sin(2*x4) - 0.002221733958*x1*x4 - 0.002656662117*x3*x4 - 0.001566335256*x4^2 + 0.005091890949*cos(x4)*x4 + 0.2095393335*sin(x1)*x4 + 0.07227397963*sin(x2)*x4 + 0.127870118*cos(2*x2)*x4 - 0.006388547089*cos(2*x3)*x4 - 0.06366806489*sin(2*x1)*x4 + 0.03884976652*cos(x2)*x1 + 0.05120531409*cos(x2)*x3 + 0.00827162873*cos(x2)*x4 - 0.2872658989*cos(x1)*cos(x2) + 0.1765930638*cos(x2)^2 - 1.820311103*cos(x2)*cos(x3) - 0.07983637535*cos(x2)*cos(x4) + 1.4035256*cos(x2)*sin(x1) + 0.08652416539*cos(x2)*sin(x2) + 1.070067293*cos(x2)*sin(x3) + 0.08766164259*cos(x2)*sin(x4) + 0.03138145812*cos(2*x1)*cos(x2) + 0.3926931182*cos(2*x2)*cos(x2) + 0.08664745746*cos(2*x3)*cos(x2) + 0.003994597788*cos(2*x4)*cos(x2) - 3.296882265*cos(x2)*sin(2*x1) + 1.478165308*cos(x2)*sin(2*x2) - 0.1026711292*cos(x2)*sin(2*x3) + 0.05777896115*cos(x2)*sin(2*x4) - 0.2458503756*cos(x3)*x3 + 0.03697228445*cos(x3)*x4 + 0.08036163566*cos(x1)*cos(x3) + 0.1869521334*cos(x3)^2 - 0.2173632473*cos(x3)*cos(x4) - 1.247259422*cos(x3)*sin(x1) + 0.3552363713*cos(x3)*sin(x2) - 0.8530433831*cos(2*x1)*cos(x3) - 0.1716823829*cos(2*x2)*cos(x3) + 0.1681498709*cos(2*x3)*cos(x3) - 1.503411475*cos(x3)*sin(2*x1) + 0.6297721729*cos(x3)*sin(2*x2) + 0.01326965541*cos(x3)*sin(2*x3) + 0.1110540929*cos(x3)*sin(2*x4) - 0.01746148103*cos(x4)*x1 + 0.01340525505*cos(x4)*x2 + 0.02346332515*cos(x1)*cos(x4) - 0.0272433163*cos(x4)*sin(x1) - 0.05673033161*cos(x4)*sin(x2) - 0.07170765532*cos(x4)*sin(x3) + 0.01666195642*cos(x4)*sin(x4) - 0.05417333061*cos(2*x1)*cos(x4) + 0.01368884699*cos(2*x2)*cos(x4) - 0.007754484481*cos(2*x3)*cos(x4) + 0.06380776352*cos(x4)*sin(2*x1) - 0.06843366231*cos(x4)*sin(2*x2) - 0.00298453007*cos(x4)*sin(2*x3) + 0.2926022661*sin(x1)*x1 - 0.09787903491*sin(x1)*x2 - 0.1227553796*sin(x1)*x3 - 0.04667983091*cos(x1)*sin(x1) - 0.007157771647*sin(x1)^2 + 0.7121089279*sin(x1)*sin(x2) - 0.3323580878*sin(x1)*sin(x3) - 0.04031998891*sin(x1)*sin(x4) - 0.1053163878*cos(2*x1)*sin(x1) - 0.03159034994*cos(2*x3)*sin(x1) - 0.129203502*sin(2*x1)*sin(x1) - 0.1365935251*sin(2*x2)*sin(x1) + 0.1231962294*sin(2*x3)*sin(x1) + 0.01333274654*sin(2*x4)*sin(x1) + 0.1183122669*sin(x2)*x1 - 0.09707784456*sin(x2)*x2 + 0.1203007175*sin(x2)*x3 - 0.3761442288*cos(x1)*sin(x2) + 0.9563118365*sin(x2)*sin(x3) - 0.07890261415*sin(x2)*sin(x4) + 2.967816351*cos(2*x1)*sin(x2) + 0.1288246277*cos(2*x2)*sin(x2) - 0.001303084601*cos(2*x4)*sin(x2) - 1.000477651*sin(2*x1)*sin(x2) + 0.9448538768*sin(2*x2)*sin(x2) - 0.09497883933*sin(2*x3)*sin(x2) + 0.06123293286*sin(2*x4)*sin(x2) + 0.387264347*sin(x3)*x1 + 0.05134812716*sin(x3)*x3 + 0.008710153743*sin(x3)*x4 - 0.07969599331*cos(x1)*sin(x3) + 0.02931817977*sin(x3)^2 + 0.01986813857*sin(x3)*sin(x4) - 0.07638026762*cos(2*x1)*sin(x3) + 0.04232173828*cos(2*x2)*sin(x3) - 0.005908164674*cos(2*x4)*sin(x3) + 0.2610590968*sin(2*x1)*sin(x3) + 0.3812037289*sin(2*x2)*sin(x3) + 0.05693957023*sin(2*x3)*sin(x3) + 0.0171570874*sin(2*x4)*sin(x3) + 0.03280531082*sin(x4)*x1 - 0.00244922671*sin(x4)*x2 + 0.02199912332*cos(x1)*sin(x4) + 0.1245592421*cos(x3)*sin(x4) + 0.004555970231*sin(x4)^2 + 0.02393280048*cos(2*x1)*sin(x4) + 0.09553732474*cos(2*x2)*sin(x4) - 0.02744192751*cos(2*x3)*sin(x4) - 0.06475301712*sin(2*x1)*sin(x4) - 0.01692098672*sin(2*x2)*sin(x4) + 0.004323411528*sin(2*x4)*sin(x4) + 0.5297587859*cos(2*x1)*x1 - 0.2917476351*cos(2*x1)*x2 + 0.04995851116*cos(2*x1)*x3 - 0.07862009606*cos(2*x1)*x4 - 0.6013913588*cos(2*x1)*cos(x1) + 0.1772326052*cos(2*x1)^2 - 0.2218236744*cos(2*x1)*sin(2*x1) - 2.073797122*cos(2*x1)*sin(2*x2) + 0.03141444955*cos(2*x1)*sin(2*x3) - 0.2132761684*cos(2*x2)*x1 - 0.2094279307*cos(2*x2)*x2 - 0.01133313621*co ...

# %% [markdown]
# ### Validation

# %%
import importlib

import model_reconstructor as mr

importlib.reload(mr)

recovered_model = mr.RecoveredModel()
recovered_model.parse_ode_equations(eq_str)


val_t_span = [0,10]
val_t_eval = np.arange(0,10,dt)

# x includes theta and d_theta
val_x, val_d_theta = load_double_pendulum_data('DoublePendulum_Data/DoubleDataFreeSwing_4_Dt_0_001.mat',downsample=20)

data_initial_conditions = val_x[0]
SREINet_pred = recovered_model.simulate(data_initial_conditions, t_span=val_t_span, t_eval=val_t_eval, method='RK45')

# %%
import matplotlib.pyplot as plt

plt.plot(SREINet_pred['t'], SREINet_pred['y'][0],label='SREINet')
plt.plot(val_t_eval, val_x[:val_t_eval.shape[0],0], '--', label='True')
plt.xlabel('Time, t')
plt.ylabel(r'$\theta_1$')
plt.legend()
plt.show()


plt.plot(SREINet_pred['t'], SREINet_pred['y'][1],label='SREINet')
plt.plot(val_t_eval, val_x[:val_t_eval.shape[0],1], '--', label='True')
plt.xlabel('Time, t')
plt.ylabel(r'$\dot{\theta}_1$')
plt.legend()
plt.show()

# %%
#calculate derivatives 
pred_dx = recovered_model.predict_derivatives(SREINet_pred['y'].transpose())
pred_dx = pred_dx.transpose()

# Calculate derivative using Savitzky-Golay filter
window_length = 7  # Window length
polyorder = 2     # Polynomial order
val_dd_theta = savgol_filter(val_d_theta, window_length, polyorder, delta=dt, deriv=1, axis=0)

# %%
plt.plot(SREINet_pred['t'], pred_dx[2],label='SREINet')
plt.plot(val_t_eval, val_dd_theta[:val_t_eval.shape[0], 0], '--', label='True')
plt.xlabel('Time, t')
plt.ylabel(r'$\ddot{\theta_1}$')
plt.legend()
plt.title('Angular Acceleration of 1st pendulum')
plt.show()

# %%
# Plot theta2
plt.figure(figsize=(10, 6))
plt.plot(SREINet_pred['t'], SREINet_pred['y'][1],label='SREINet')
plt.plot(val_t_eval, val_x[:val_t_eval.shape[0],1], '--', label='True')
plt.xlabel('Time, t')
plt.ylabel(r'$\theta_2$')
plt.legend()
plt.title('Angular Position of 2nd pendulum')
plt.show()

# %%
# Plot angular acceleration of 2nd pendulum
plt.figure(figsize=(10, 6))
plt.plot(SREINet_pred['t'], pred_dx[3],label='SREINet')
plt.plot(val_t_eval, val_dd_theta[:val_t_eval.shape[0], 1], '--', label='True')
plt.xlabel('Time, t')
plt.ylabel(r'$\ddot{\theta_2}$')
plt.legend()
plt.title('Angular Acceleration of 2nd pendulum')
plt.show()
