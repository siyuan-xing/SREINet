# %% [markdown]
# ## **Lotka-Volterra Network Model Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append(os.path.abspath(".."))
sys.path.append(os.path.abspath("../../utilities"))

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
from lorenz_lotka_network.lotka_volterra_network import lotka_volterra_network
from lorenz_lotka_network.network_generator import generate_erdos_renyi_network

MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)

# Generate data based on the specified model type
n_nodes = 15
edge_probability = 0.4
seed = 123

edge_list, adjacency, degrees = generate_erdos_renyi_network(n_nodes, edge_probability, seed=seed)

print(f"Generated ER network with {n_nodes} nodes and {edge_list.shape[0]} edges")

np.random.seed(seed)
num_traj = 6

initial_conditions = []
for _ in range(num_traj):
    prey0 = np.random.uniform(0.5, 3, size=n_nodes)
    predator0 = np.random.uniform(0.5, 3, size=n_nodes)
    initial_state = np.concatenate([prey0, predator0])
    initial_conditions.append(initial_state)

data_T = 60.0       # Length of the data (T)
data_dt = 0.02      # Resolution of the data (dt)
myDG = DG.DataGenerator(initial_conditions, T=data_T, dt=data_dt, derivative_mode="exact")

def lotka_vector_field(t, state, edge_list):
    return lotka_volterra_network(
        t,
        state,
        edge_list,
        coupling_strength_prey=0.1,
        coupling_strength_predator=0.1,
    )

t_arr, x_train, dx_train = myDG.generate_dataset_by_custom_ODEs(
    lotka_vector_field,
    edge_list,
    method='RK45'
)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train
training_input_for_sim = training_input.copy()  # Save a copy for validation

print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)

MY_MODEL = "Lotka-Volterra network (ER)"
data_initial_conditions = initial_conditions
guess_highest_order_polynomial = 3
ode_function = lotka_vector_field
network_arguments = (edge_list,)
# Out:
# Generated ER network with 15 nodes and 39 edges
# Training input shape: (18000, 30)
# Training output shape: (18000, 30)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 32
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables)
dim = training_input.shape[1] 

guessed_multiplicative_order = 3
# The grid size of each dimension
layer_depth = guessed_multiplicative_order
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn) # these numbers exclude the constant term
# Out:
# [30, 30, 30]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn,
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=1e-5, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'lasso' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION, l1_regularization_strength=1e-7)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Trainer**

# %%
np.set_printoptions(threshold=np.inf)

from sreinet_trainer import SREINetTrainer

trainer = SREINetTrainer(
    model,
    my_optimizer,
    loss_fn,
    data_type=MY_DATA_TYPE,
    random_seed=42,
)

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.1 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 50
PRUNING_EPOCHS_PER_PERIOD = 30
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

pruning_scheduler = ps.PruningScheduler(
    steps_per_period=PRUNING_EPOCHS_PER_PERIOD,
    num_periods=N_PERIODS,
    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
    show_plot=True,
)

# %% [markdown]
# ### Training

# %%
#Setup
callbacks = []

EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.005

training_histories = []
weights_list = []

# %%
#change 0 to a other number if you want to start training from other dimensions
for i in range(0, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    trainer.reset_trainer_and_model_weights(i)
    output = training_output[:, i:i+1]

    history = trainer.fit(
        training_input,
        output,
        batch_size=MINI_BATCH_SIZE,
        validation_split=0.20,
        epochs=round(NUM_EPOCHS),
        pruning_scheduler=pruning_scheduler,
        callbacks=callbacks,
        early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
        early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
        shuffle_per_epoch=False,
        patience_periods=15,
        verbose=1,
    )

    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
# Out:
# Training dimension 1...
# Epoch   1 (Period 1):  Train Loss: 2.755e+00,  Validation Loss: 1.875e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 2.168e-01,  Validation Loss: 1.193e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 1.819e-01,  Validation Loss: 1.009e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 1.095e-01,  Validation Loss: 6.409e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 7.583e-02,  Validation Loss: 1.486e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 7.020e-02,  Validation Loss: 4.572e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 8.226e-02,  Validation Loss: 6.537e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 5.572e-02,  Validation Loss: 3.458e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00055846
# Epoch   9 (Period 1):  Train Loss: 9.203e-02,  Validation Loss: 1.026e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch  10 (Period 1):  Train Loss: 5.337e-02,  Validation Loss: 6.795e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch  11 (Period 1):  Train Loss: 4.459e-02,  Validation Loss: 2.454e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0086881
# Epoch  12 (Period 1):  Train Loss: 2.333e-01,  Validation Loss: 2.445e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013347
# Epoch  13 (Period 1):  Train Loss: 4.516e-02,  Validation Loss: 2.850e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.018826
# Epoch  14 (Period 1):  Train Loss: 1.061e-01,  Validation Loss: 2.346e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch  15 (Period 1):  Train Loss: 1.058e-01,  Validation Loss: 2.335e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.031733
# Epoch  16 (Period 1):  Train Loss: 7.059e-02,  Validation Loss: 2.289e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.038874
# Epoch  17 (Period 1):  Train Loss: 6.708e-02,  Validation Loss: 2.633e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046263
# Epoch  18 (Period 1):  Train Loss: 1.372e-01,  Validation Loss: 6.447e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.053737
# Epoch  19 (Period 1):  Train Loss: 1.370e-01,  Validation Loss: 5.619e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.061126
# Epoch  20 (Period 1):  Train Loss: 6.761e-02,  Validation Loss: 4.667e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.068267
# Epoch  21 (Period 1):  Train Loss: 4.362e-02,  Validation Loss: 4.313e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.075
# Epoch  22 (Period 1):  Train Loss: 5.534e-02,  Validation Loss: 3.705e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.081174
# Epoch  23 (Period 1):  Train Loss: 4.017e-02,  Validation Loss: 3.314e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.086653
# Epoch  24 (Period 1):  Train Loss: 3.342e-02,  Validation Loss: 3.279e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.091312
# Epoch  25 (Period 1):  Train Loss: 3.405e-02,  Validation Loss: 2.978e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.095048
# Epoch  26 (Period 1):  Train Loss: 2.958e-02,  Validation Loss: 2.917e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.097779
# Epoch  27 (Period 1):  Train Loss: 2.962e-02,  Validation Loss: 3.230e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.099442
# Epoch  28 (Period 1):  Train Loss: 2.815e-02,  Validation Loss: 2.823e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch  29 (Period 1):  Train Loss: 2.716e-02,  Validation Loss: 2.494e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch  30 (Period 1):  Train Loss: 2.640e-02,  Validation Loss: 2.375e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch  31 (Period 2):  Train Loss: 4.389e-01,  Validation Loss: 2.024e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  32 (Period 2):  Train Loss: 2.351e-02,  Validation Loss: 1.201e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  33 (Period 2):  Train Loss: 2.165e-02,  Validation Loss: 4.513e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  34 (Period 2):  Train Loss: 1.465e-02,  Validation Loss: 1.507e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  35 (Period 2):  Train Loss: 2.354e-02,  Validation Loss: 9.805e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  36 (Period 2):  Train Loss: 1.860e-02,  Validation Loss: 3.795e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  37 (Period 2):  Train Loss: 1.973e-02,  Validation Loss: 4.418e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  38 (Period 2):  Train Loss: 1.182e-02,  Validation Loss: 6.796e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00055846
# Epoch  39 (Period 2):  Train Loss: 1.476e-02,  Validation Loss: 5.531e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0022214
# Epoch  40 (Period 2):  Train Loss: 8.416e-03,  Validation Loss: 6.731e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch  41 (Period 2):  Train Loss: 7.957e-03,  Validation Loss: 7.778e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0086881
# Epoch  42 (Period 2):  Train Loss: 8.718e-03,  Validation Loss: 5.601e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013347
# Epoch  43 (Period 2):  Train Loss: 1.290e-02,  Validation Loss: 7.071e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.018826
# Epoch  44 (Period 2):  Train Loss: 8.685e-03,  Validation Loss: 7.456e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch  45 (Period 2):  Train Loss: 1.316e-02,  Validation Loss: 8.104e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.031733
# Epoch  46 (Period 2):  Train Loss: 1.104e-02,  Validation Loss: 8.278e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.038874
# Epoch  47 (Period 2):  Train Loss: 7.973e-03,  Validation Loss: 7.055e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.046263
# Epoch  48 (Period 2):  Train Loss: 6.719e-03,  Validation Loss: 7.382e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.053737
# Epoch  49 (Period 2):  Train Loss: 7.324e-03,  Validation Loss: 5.400e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.061126
# Epoch  50 (Period 2):  Train Loss: 7.018e-03,  Validation Loss: 6.319e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.068267
# Epoch  51 (Period 2):  Train Loss: 3.058e-02,  Validation Loss: 1.056e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.075
# Epoch  52 (Period 2):  Train Loss: 1.467e-02,  Validation Loss: 1.121e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.081174
# Epoch  53 (Period 2):  Train Loss: 1.006e-02,  Validation Loss: 9.676e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.086653
# Epoch  54 (Period 2):  Train Loss: 1.002e-02,  Validation Loss: 7.525e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch  55 (Period 2):  Train Loss: 6.875e-03,  Validation Loss: 6.349e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.095048
# Epoch  56 (Period 2):  Train Loss: 7.023e-03,  Validation Loss: 6.131e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.097779
# Epoch  57 (Period 2):  Train Loss: 5.916e-03,  Validation Loss: 6.185e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.099442
# Epoch  58 (Period 2):  Train Loss: 5.569e-03,  Validation Loss: 4.866e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch  59 (Period 2):  Train Loss: 4.800e-03,  Validation Loss: 4.297e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch  60 (Period 2):  Train Loss: 4.141e-03,  Validation Loss: 4.220e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch  61 (Period 3):  Train Loss: 4.355e-01,  Validation Loss: 7.706e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  62 (Period 3):  Train Loss: 6.262e-03,  Validation Loss: 4.534e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  63 (Period 3):  Train Loss: 4.204e-03,  Validation Loss: 3.696e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  64 (Period 3):  Train Loss: 3.194e-03,  Validation Loss: 2.329e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  65 (Period 3):  Train Loss: 2.710e-03,  Validation Loss: 2.098e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  66 (Period 3):  Train Loss: 2.811e-03,  Validation Loss: 1.454e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  67 (Period 3):  Train Loss: 3.019e-03,  Validation Loss: 2.211e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  68 (Period 3):  Train Loss: 2.331e-03,  Validation Loss: 1.172e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00055846
# Epoch  69 (Period 3):  Train Loss: 2.584e-03,  Validation Loss: 1.752e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch  70 (Period 3):  Train Loss: 4.663e-03,  Validation Loss: 1.520e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch  71 (Period 3):  Train Loss: 2.990e-03,  Validation Loss: 1.827e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0086881
# Epoch  72 (Period 3):  Train Loss: 6.050e-03,  Validation Loss: 2.865e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013347
# Epoch  73 (Period 3):  Train Loss: 2.800e-03,  Validation Loss: 3.010e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.018826
# Epoch  74 (Period 3):  Train Loss: 2.757e-03,  Validation Loss: 2.612e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch  75 (Period 3):  Train Loss: 2.661e-03,  Validation Loss: 2.338e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.031733
# Epoch  76 (Period 3):  Train Loss: 2.393e-03,  Validation Loss: 2.069e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.038874
# Epoch  77 (Period 3):  Train Loss: 2.140e-03,  Validation Loss: 2.361e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.046263
# Epoch  78 (Period 3):  Train Loss: 2.008e-03,  Validation Loss: 2.014e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.053737
# Epoch  79 (Period 3):  Train Loss: 1.810e-03,  Validation Loss: 1.792e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.061126
# Epoch  80 (Period 3):  Train Loss: 2.294e-03,  Validation Loss: 1.744e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.068267
# Epoch  81 (Period 3):  Train Loss: 1.668e-03,  Validation Loss: 1.480e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.075
# Epoch  82 (Period 3):  Train Loss: 1.788e-03,  Validation Loss: 1.070e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.081174
# Epoch  83 (Period 3):  Train Loss: 1.234e-03,  Validation Loss: 1.587e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.086653
# Epoch  84 (Period 3):  Train Loss: 1.132e-03,  Validation Loss: 9.831e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch  85 (Period 3):  Train Loss: 1.064e-03,  Validation Loss: 9.102e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.095048
# Epoch  86 (Period 3):  Train Loss: 9.996e-04,  Validation Loss: 8.177e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.097779
# Epoch  87 (Period 3):  Train Loss: 9.292e-04,  Validation Loss: 7.279e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.099442
# Epoch  88 (Period 3):  Train Loss: 8.944e-04,  Validation Loss: 8.883e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch  89 (Period 3):  Train Loss: 8.296e-04,  Validation Loss: 8.592e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch  90 (Period 3):  Train Loss: 7.952e-04,  Validation Loss: 5.871e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch  91 (Period 4):  Train Loss: 4.664e-01,  Validation Loss: 9.246e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  92 (Period 4):  Train Loss: 7.019e-04,  Validation Loss: 6.270e-04,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  93 (Period 4):  Train Loss: 4.553e-04,  Validation Loss: 5.489e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  94 (Period 4):  Train Loss: 3.562e-04,  Validation Loss: 2.459e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  95 (Period 4):  Train Loss: 2.861e-04,  Validation Loss: 2.698e-04,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch  96 (Period 4):  Train Loss: 3.408e-04,  Validation Loss: 2.185e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  97 (Period 4):  Train Loss: 3.081e-04,  Validation Loss: 2.373e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  98 (Period 4):  Train Loss: 3.371e-04,  Validation Loss: 2.011e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00055846
# Epoch  99 (Period 4):  Train Loss: 3.522e-04,  Validation Loss: 3.726e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch 100 (Period 4):  Train Loss: 6.980e-04,  Validation Loss: 4.424e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch 101 (Period 4):  Train Loss: 8.346e-03,  Validation Loss: 5.382e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0086881
# Epoch 102 (Period 4):  Train Loss: 1.314e-03,  Validation Loss: 7.156e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013347
# Epoch 103 (Period 4):  Train Loss: 6.323e-04,  Validation Loss: 7.814e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.018826
# Epoch 104 (Period 4):  Train Loss: 6.358e-04,  Validation Loss: 6.766e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch 105 (Period 4):  Train Loss: 6.660e-04,  Validation Loss: 6.013e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.031733
# Epoch 106 (Period 4):  Train Loss: 5.828e-04,  Validation Loss: 6.251e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.038874
# Epoch 107 (Period 4):  Train Loss: 5.963e-04,  Validation Loss: 5.565e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.046263
# Epoch 108 (Period 4):  Train Loss: 6.260e-04,  Validation Loss: 5.505e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.053737
# Epoch 109 (Period 4):  Train Loss: 5.746e-04,  Validation Loss: 5.029e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.061126
# Epoch 110 (Period 4):  Train Loss: 6.120e-04,  Validation Loss: 5.167e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.068267
# Epoch 111 (Period 4):  Train Loss: 5.643e-04,  Validation Loss: 4.639e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.075
# Epoch 112 (Period 4):  Train Loss: 5.434e-04,  Validation Loss: 5.084e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.081174
# Epoch 113 (Period 4):  Train Loss: 5.366e-04,  Validation Loss: 4.271e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.086653
# Epoch 114 (Period 4):  Train Loss: 4.951e-04,  Validation Loss: 3.782e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch 115 (Period 4):  Train Loss: 4.818e-04,  Validation Loss: 4.537e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.095048
# Epoch 116 (Period 4):  Train Loss: 4.675e-04,  Validation Loss: 5.592e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.097779
# Epoch 117 (Period 4):  Train Loss: 4.504e-04,  Validation Loss: 3.757e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.099442
# Epoch 118 (Period 4):  Train Loss: 4.314e-04,  Validation Loss: 4.259e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 119 (Period 4):  Train Loss: 4.330e-04,  Validation Loss: 4.147e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 120 (Period 4):  Train Loss: 4.118e-04,  Validation Loss: 4.903e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 121 (Period 5):  Train Loss: 2.513e-01,  Validation Loss: 1.185e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 122 (Period 5):  Train Loss: 1.009e-03,  Validation Loss: 4.978e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 123 (Period 5):  Train Loss: 8.000e-04,  Validation Loss: 8.219e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 124 (Period 5):  Train Loss: 5.533e-04,  Validation Loss: 5.193e-04,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch 125 (Period 5):  Train Loss: 4.811e-04,  Validation Loss: 6.072e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 126 (Period 5):  Train Loss: 6.359e-04,  Validation Loss: 2.817e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 127 (Period 5):  Train Loss: 4.177e-04,  Validation Loss: 3.440e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 128 (Period 5):  Train Loss: 1.448e-03,  Validation Loss: 5.425e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00055846
# Epoch 129 (Period 5):  Train Loss: 6.183e-04,  Validation Loss: 4.299e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch 130 (Period 5):  Train Loss: 9.638e-04,  Validation Loss: 3.660e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0049516
# Epoch 131 (Period 5):  Train Loss: 5.807e-04,  Validation Loss: 4.625e-04,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.0086881
# Epoch 132 (Period 5):  Train Loss: 4.609e-04,  Validation Loss: 3.645e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.013347
# Epoch 133 (Period 5):  Train Loss: 3.970e-04,  Validation Loss: 3.379e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.018826
# Epoch 134 (Period 5):  Train Loss: 3.621e-04,  Validation Loss: 3.500e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.025
# Epoch 135 (Period 5):  Train Loss: 3.665e-04,  Validation Loss: 3.278e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.031733
# Epoch 136 (Period 5):  Train Loss: 3.725e-04,  Validation Loss: 3.668e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.038874
# Epoch 137 (Period 5):  Train Loss: 3.537e-04,  Validation Loss: 3.450e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046263
# Epoch 138 (Period 5):  Train Loss: 3.437e-04,  Validation Loss: 3.660e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.053737
# Epoch 139 (Period 5):  Train Loss: 3.408e-04,  Validation Loss: 3.028e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.061126
# Epoch 140 (Period 5):  Train Loss: 3.815e-04,  Validation Loss: 2.809e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.068267
# Epoch 141 (Period 5):  Train Loss: 3.805e-04,  Validation Loss: 3.871e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.075
# Epoch 142 (Period 5):  Train Loss: 3.607e-04,  Validation Loss: 3.374e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.081174
# Epoch 143 (Period 5):  Train Loss: 3.398e-04,  Validation Loss: 3.516e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.086653
# Epoch 144 (Period 5):  Train Loss: 3.355e-04,  Validation Loss: 3.567e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch 145 (Period 5):  Train Loss: 3.115e-04,  Validation Loss: 3.516e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.095048
# Epoch 146 (Period 5):  Train Loss: 3.441e-04,  Validation Loss: 2.536e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.097779
# Epoch 147 (Period 5):  Train Loss: 2.938e-04,  Validation Loss: 3.299e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099442
# Epoch 148 (Period 5):  Train Loss: 3.366e-04,  Validation Loss: 1.998e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 149 (Period 5):  Train Loss: 2.994e-04,  Validation Loss: 3.956e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 150 (Period 5):  Train Loss: 3.217e-04,  Validation Loss: 2.752e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 151 (Period 6):  Train Loss: 1.445e-01,  Validation Loss: 3.584e-04,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch 152 (Period 6):  Train Loss: 2.886e-04,  Validation Loss: 1.604e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 153 (Period 6):  Train Loss: 2.054e-04,  Validation Loss: 1.024e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 154 (Period 6):  Train Loss: 1.523e-04,  Validation Loss: 1.916e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 155 (Period 6):  Train Loss: 4.285e-04,  Validation Loss: 1.803e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 156 (Period 6):  Train Loss: 1.583e-04,  Validation Loss: 2.864e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 157 (Period 6):  Train Loss: 1.334e-03,  Validation Loss: 2.379e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 158 (Period 6):  Train Loss: 4.207e-04,  Validation Loss: 1.355e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00055846
# Epoch 159 (Period 6):  Train Loss: 2.161e-04,  Validation Loss: 1.059e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0022214
# Epoch 160 (Period 6):  Train Loss: 3.578e-04,  Validation Loss: 1.749e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0049516
# Epoch 161 (Period 6):  Train Loss: 3.521e-04,  Validation Loss: 2.763e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0086881
# Epoch 162 (Period 6):  Train Loss: 2.575e-04,  Validation Loss: 2.319e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013347
# Epoch 163 (Period 6):  Train Loss: 2.507e-04,  Validation Loss: 2.453e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.018826
# Epoch 164 (Period 6):  Train Loss: 2.636e-04,  Validation Loss: 2.631e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch 165 (Period 6):  Train Loss: 2.585e-04,  Validation Loss: 2.696e-04,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.031733
# Epoch 166 (Period 6):  Train Loss: 2.662e-04,  Validation Loss: 2.279e-04,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.038874
# Epoch 167 (Period 6):  Train Loss: 2.792e-04,  Validation Loss: 2.524e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.046263
# Epoch 168 (Period 6):  Train Loss: 2.576e-04,  Validation Loss: 2.267e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.053737
# Epoch 169 (Period 6):  Train Loss: 2.634e-04,  Validation Loss: 2.592e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.061126
# Epoch 170 (Period 6):  Train Loss: 2.539e-04,  Validation Loss: 3.378e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.068267
# Epoch 171 (Period 6):  Train Loss: 2.622e-04,  Validation Loss: 2.701e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.075
# Epoch 172 (Period 6):  Train Loss: 2.475e-04,  Validation Loss: 2.046e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.081174
# Epoch 173 (Period 6):  Train Loss: 2.522e-04,  Validation Loss: 2.179e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.086653
# Epoch 174 (Period 6):  Train Loss: 2.504e-04,  Validation Loss: 2.223e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch 175 (Period 6):  Train Loss: 2.577e-04,  Validation Loss: 2.018e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.095048
# Epoch 176 (Period 6):  Train Loss: 2.207e-04,  Validation Loss: 2.166e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.097779
# Epoch 177 (Period 6):  Train Loss: 2.405e-04,  Validation Loss: 4.777e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.099442
# Epoch 178 (Period 6):  Train Loss: 2.195e-04,  Validation Loss: 1.854e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 179 (Period 6):  Train Loss: 2.243e-04,  Validation Loss: 1.863e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 180 (Period 6):  Train Loss: 2.179e-04,  Validation Loss: 1.955e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 181 (Period 7):  Train Loss: 4.271e-01,  Validation Loss: 1.944e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 182 (Period 7):  Train Loss: 1.193e-03,  Validation Loss: 7.424e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 183 (Period 7):  Train Loss: 6.913e-04,  Validation Loss: 5.482e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 184 (Period 7):  Train Loss: 5.232e-04,  Validation Loss: 4.337e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 185 (Period 7):  Train Loss: 4.437e-04,  Validation Loss: 3.545e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 186 (Period 7):  Train Loss: 3.403e-04,  Validation Loss: 2.588e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 187 (Period 7):  Train Loss: 3.241e-04,  Validation Loss: 1.952e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 188 (Period 7):  Train Loss: 3.017e-04,  Validation Loss: 3.833e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00055846
# Epoch 189 (Period 7):  Train Loss: 6.341e-04,  Validation Loss: 1.817e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch 190 (Period 7):  Train Loss: 1.450e-03,  Validation Loss: 5.540e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch 191 (Period 7):  Train Loss: 1.002e-03,  Validation Loss: 2.202e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0086881
# Epoch 192 (Period 7):  Train Loss: 3.953e-04,  Validation Loss: 2.275e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013347
# Epoch 193 (Period 7):  Train Loss: 2.208e-04,  Validation Loss: 1.744e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.018826
# Epoch 194 (Period 7):  Train Loss: 1.913e-04,  Validation Loss: 2.004e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch 195 (Period 7):  Train Loss: 2.028e-04,  Validation Loss: 1.786e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.031733
# Epoch 196 (Period 7):  Train Loss: 1.940e-04,  Validation Loss: 1.749e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.038874
# Epoch 197 (Period 7):  Train Loss: 2.090e-04,  Validation Loss: 2.270e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.046263
# Epoch 198 (Period 7):  Train Loss: 1.945e-04,  Validation Loss: 1.956e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.053737
# Epoch 199 (Period 7):  Train Loss: 2.023e-04,  Validation Loss: 2.167e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.061126
# Epoch 200 (Period 7):  Train Loss: 2.092e-04,  Validation Loss: 4.652e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.068267
# Epoch 201 (Period 7):  Train Loss: 2.146e-04,  Validation Loss: 1.551e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.075
# Epoch 202 (Period 7):  Train Loss: 2.112e-04,  Validation Loss: 1.908e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.081174
# Epoch 203 (Period 7):  Train Loss: 2.043e-04,  Validation Loss: 1.822e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.086653
# Epoch 204 (Period 7):  Train Loss: 7.077e-04,  Validation Loss: 2.268e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.091312
# Epoch 205 (Period 7):  Train Loss: 5.243e-04,  Validation Loss: 2.093e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.095048
# Epoch 206 (Period 7):  Train Loss: 1.791e-04,  Validation Loss: 1.719e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.097779
# Epoch 207 (Period 7):  Train Loss: 1.861e-04,  Validation Loss: 1.774e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099442
# Epoch 208 (Period 7):  Train Loss: 2.526e-04,  Validation Loss: 1.951e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 209 (Period 7):  Train Loss: 1.760e-04,  Validation Loss: 2.511e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 210 (Period 7):  Train Loss: 1.674e-04,  Validation Loss: 1.475e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 211 (Period 8):  Train Loss: 5.225e-01,  Validation Loss: 1.556e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 212 (Period 8):  Train Loss: 1.093e-03,  Validation Loss: 6.597e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 213 (Period 8):  Train Loss: 5.331e-04,  Validation Loss: 4.398e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 214 (Period 8):  Train Loss: 3.067e-04,  Validation Loss: 2.243e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 215 (Period 8):  Train Loss: 1.979e-04,  Validation Loss: 1.441e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 216 (Period 8):  Train Loss: 1.493e-04,  Validation Loss: 1.577e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 217 (Period 8):  Train Loss: 1.198e-04,  Validation Loss: 9.519e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 218 (Period 8):  Train Loss: 1.066e-04,  Validation Loss: 8.142e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00055846
# Epoch 219 (Period 8):  Train Loss: 3.819e-04,  Validation Loss: 1.052e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch 220 (Period 8):  Train Loss: 5.359e-04,  Validation Loss: 2.049e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch 221 (Period 8):  Train Loss: 1.649e-04,  Validation Loss: 1.605e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0086881
# Epoch 222 (Period 8):  Train Loss: 1.722e-04,  Validation Loss: 1.592e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013347
# Epoch 223 (Period 8):  Train Loss: 1.510e-04,  Validation Loss: 1.511e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.018826
# Epoch 224 (Period 8):  Train Loss: 1.530e-04,  Validation Loss: 1.285e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch 225 (Period 8):  Train Loss: 1.526e-04,  Validation Loss: 1.419e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.031733
# Epoch 226 (Period 8):  Train Loss: 1.533e-04,  Validation Loss: 1.648e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.038874
# Epoch 227 (Period 8):  Train Loss: 1.599e-04,  Validation Loss: 1.664e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046263
# Epoch 228 (Period 8):  Train Loss: 1.607e-04,  Validation Loss: 1.570e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.053737
# Epoch 229 (Period 8):  Train Loss: 1.624e-04,  Validation Loss: 1.425e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.061126
# Epoch 230 (Period 8):  Train Loss: 1.680e-04,  Validation Loss: 1.522e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.068267
# Epoch 231 (Period 8):  Train Loss: 1.714e-04,  Validation Loss: 1.612e-04,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.075
# Epoch 232 (Period 8):  Train Loss: 1.802e-04,  Validation Loss: 1.597e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.081174
# Epoch 233 (Period 8):  Train Loss: 1.818e-04,  Validation Loss: 1.477e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.086653
# Epoch 234 (Period 8):  Train Loss: 1.645e-04,  Validation Loss: 1.941e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch 235 (Period 8):  Train Loss: 1.712e-04,  Validation Loss: 1.639e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.095048
# Epoch 236 (Period 8):  Train Loss: 1.690e-04,  Validation Loss: 1.609e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.097779
# Epoch 237 (Period 8):  Train Loss: 1.794e-04,  Validation Loss: 1.408e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.099442
# Epoch 238 (Period 8):  Train Loss: 1.766e-04,  Validation Loss: 1.840e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.1
# Epoch 239 (Period 8):  Train Loss: 1.731e-04,  Validation Loss: 2.098e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.1
# Epoch 240 (Period 8):  Train Loss: 1.684e-04,  Validation Loss: 1.681e-04,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.1
# Epoch 241 (Period 9):  Train Loss: 1.817e-01,  Validation Loss: 1.165e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 242 (Period 9):  Train Loss: 7.108e-04,  Validation Loss: 3.192e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 243 (Period 9):  Train Loss: 2.938e-04,  Validation Loss: 1.664e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 244 (Period 9):  Train Loss: 2.333e-04,  Validation Loss: 1.356e-04,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch 245 (Period 9):  Train Loss: 1.577e-04,  Validation Loss: 1.687e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 246 (Period 9):  Train Loss: 2.471e-04,  Validation Loss: 8.256e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 247 (Period 9):  Train Loss: 4.166e-04,  Validation Loss: 3.198e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 248 (Period 9):  Train Loss: 2.799e-04,  Validation Loss: 1.119e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00055846
# Epoch 249 (Period 9):  Train Loss: 1.211e-04,  Validation Loss: 4.110e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch 250 (Period 9):  Train Loss: 4.493e-04,  Validation Loss: 1.208e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch 251 (Period 9):  Train Loss: 1.567e-04,  Validation Loss: 1.501e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0086881
# Epoch 252 (Period 9):  Train Loss: 1.589e-04,  Validation Loss: 1.570e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013347
# Epoch 253 (Period 9):  Train Loss: 1.515e-04,  Validation Loss: 1.630e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.018826
# Epoch 254 (Period 9):  Train Loss: 1.591e-04,  Validation Loss: 1.542e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch 255 (Period 9):  Train Loss: 1.608e-04,  Validation Loss: 1.470e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.031733
# Epoch 256 (Period 9):  Train Loss: 1.688e-04,  Validation Loss: 1.343e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.038874
# Epoch 257 (Period 9):  Train Loss: 1.698e-04,  Validation Loss: 1.705e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.046263
# Epoch 258 (Period 9):  Train Loss: 1.667e-04,  Validation Loss: 1.409e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.053737
# Epoch 259 (Period 9):  Train Loss: 1.732e-04,  Validation Loss: 1.479e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.061126
# Epoch 260 (Period 9):  Train Loss: 1.652e-04,  Validation Loss: 1.526e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.068267
# Epoch 261 (Period 9):  Train Loss: 1.724e-04,  Validation Loss: 2.198e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.075
# Epoch 262 (Period 9):  Train Loss: 1.779e-04,  Validation Loss: 1.452e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.081174
# Epoch 263 (Period 9):  Train Loss: 1.813e-04,  Validation Loss: 1.646e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.086653
# Epoch 264 (Period 9):  Train Loss: 1.747e-04,  Validation Loss: 1.523e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.091312
# Epoch 265 (Period 9):  Train Loss: 1.781e-04,  Validation Loss: 1.322e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.095048
# Epoch 266 (Period 9):  Train Loss: 1.689e-04,  Validation Loss: 2.121e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.097779
# Epoch 267 (Period 9):  Train Loss: 1.776e-04,  Validation Loss: 2.866e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.099442
# Epoch 268 (Period 9):  Train Loss: 1.760e-04,  Validation Loss: 2.065e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 269 (Period 9):  Train Loss: 1.797e-04,  Validation Loss: 1.581e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 270 (Period 9):  Train Loss: 1.748e-04,  Validation Loss: 1.508e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 271 (Period 10):  Train Loss: 1.911e-01,  Validation Loss: 7.792e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 272 (Period 10):  Train Loss: 4.630e-04,  Validation Loss: 3.351e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 273 (Period 10):  Train Loss: 2.388e-04,  Validation Loss: 1.821e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 274 (Period 10):  Train Loss: 1.567e-04,  Validation Loss: 1.249e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 275 (Period 10):  Train Loss: 1.421e-04,  Validation Loss: 1.015e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 276 (Period 10):  Train Loss: 1.415e-04,  Validation Loss: 1.013e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 277 (Period 10):  Train Loss: 1.334e-04,  Validation Loss: 2.720e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 278 (Period 10):  Train Loss: 1.301e-04,  Validation Loss: 5.793e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00055846
# Epoch 279 (Period 10):  Train Loss: 1.401e-04,  Validation Loss: 1.426e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch 280 (Period 10):  Train Loss: 2.285e-04,  Validation Loss: 1.579e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch 281 (Period 10):  Train Loss: 3.312e-04,  Validation Loss: 2.372e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0086881
# Epoch 282 (Period 10):  Train Loss: 1.688e-04,  Validation Loss: 1.793e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013347
# Epoch 283 (Period 10):  Train Loss: 1.605e-04,  Validation Loss: 1.224e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.018826
# Epoch 284 (Period 10):  Train Loss: 1.676e-04,  Validation Loss: 1.882e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch 285 (Period 10):  Train Loss: 1.541e-04,  Validation Loss: 1.630e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.031733
# Epoch 286 (Period 10):  Train Loss: 1.600e-04,  Validation Loss: 1.438e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.038874
# Epoch 287 (Period 10):  Train Loss: 1.738e-04,  Validation Loss: 1.877e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.046263
# Epoch 288 (Period 10):  Train Loss: 1.675e-04,  Validation Loss: 1.547e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.053737
# Epoch 289 (Period 10):  Train Loss: 1.712e-04,  Validation Loss: 1.669e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.061126
# Epoch 290 (Period 10):  Train Loss: 1.664e-04,  Validation Loss: 1.477e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.068267
# Epoch 291 (Period 10):  Train Loss: 1.841e-04,  Validation Loss: 1.970e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.075
# Epoch 292 (Period 10):  Train Loss: 1.714e-04,  Validation Loss: 2.007e-04,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.081174
# Epoch 293 (Period 10):  Train Loss: 1.678e-04,  Validation Loss: 1.580e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.086653
# Epoch 294 (Period 10):  Train Loss: 1.794e-04,  Validation Loss: 1.432e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch 295 (Period 10):  Train Loss: 1.811e-04,  Validation Loss: 1.535e-04,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.095048
# Epoch 296 (Period 10):  Train Loss: 1.698e-04,  Validation Loss: 1.565e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.097779
# Epoch 297 (Period 10):  Train Loss: 1.771e-04,  Validation Loss: 2.336e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.099442
# Epoch 298 (Period 10):  Train Loss: 1.747e-04,  Validation Loss: 2.012e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 299 (Period 10):  Train Loss: 1.761e-04,  Validation Loss: 1.710e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 300 (Period 10):  Train Loss: 1.808e-04,  Validation Loss: 1.406e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 301 (Period 11):  Train Loss: 1.829e-01,  Validation Loss: 3.420e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 302 (Period 11):  Train Loss: 2.976e-04,  Validation Loss: 2.637e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 303 (Period 11):  Train Loss: 1.981e-04,  Validation Loss: 1.299e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 304 (Period 11):  Train Loss: 1.780e-04,  Validation Loss: 1.916e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 305 (Period 11):  Train Loss: 1.738e-04,  Validation Loss: 1.210e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 306 (Period 11):  Train Loss: 1.365e-04,  Validation Loss: 7.776e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 307 (Period 11):  Train Loss: 1.433e-04,  Validation Loss: 7.150e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 308 (Period 11):  Train Loss: 9.358e-05,  Validation Loss: 1.018e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00055846
# Epoch 309 (Period 11):  Train Loss: 3.056e-04,  Validation Loss: 6.590e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch 310 (Period 11):  Train Loss: 1.920e-04,  Validation Loss: 1.620e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch 311 (Period 11):  Train Loss: 1.737e-04,  Validation Loss: 1.324e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0086881
# Epoch 312 (Period 11):  Train Loss: 1.512e-04,  Validation Loss: 1.572e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013347
# Epoch 313 (Period 11):  Train Loss: 1.572e-04,  Validation Loss: 1.521e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.018826
# Epoch 314 (Period 11):  Train Loss: 1.587e-04,  Validation Loss: 1.626e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.025
# Epoch 315 (Period 11):  Train Loss: 1.636e-04,  Validation Loss: 1.641e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.031733
# Epoch 316 (Period 11):  Train Loss: 1.469e-04,  Validation Loss: 1.482e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.038874
# Epoch 317 (Period 11):  Train Loss: 1.698e-04,  Validation Loss: 1.444e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046263
# Epoch 318 (Period 11):  Train Loss: 1.665e-04,  Validation Loss: 1.519e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.053737
# Epoch 319 (Period 11):  Train Loss: 1.649e-04,  Validation Loss: 1.705e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.061126
# Epoch 320 (Period 11):  Train Loss: 1.805e-04,  Validation Loss: 1.487e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.068267
# Epoch 321 (Period 11):  Train Loss: 1.781e-04,  Validation Loss: 1.362e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.075
# Epoch 322 (Period 11):  Train Loss: 1.662e-04,  Validation Loss: 1.616e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.081174
# Epoch 323 (Period 11):  Train Loss: 1.651e-04,  Validation Loss: 1.584e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.086653
# Epoch 324 (Period 11):  Train Loss: 1.663e-04,  Validation Loss: 1.495e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch 325 (Period 11):  Train Loss: 1.732e-04,  Validation Loss: 2.255e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.095048
# Epoch 326 (Period 11):  Train Loss: 1.732e-04,  Validation Loss: 1.798e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.097779
# Epoch 327 (Period 11):  Train Loss: 1.769e-04,  Validation Loss: 1.507e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099442
# Epoch 328 (Period 11):  Train Loss: 1.702e-04,  Validation Loss: 2.330e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 329 (Period 11):  Train Loss: 1.834e-04,  Validation Loss: 2.271e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 330 (Period 11):  Train Loss: 1.754e-04,  Validation Loss: 1.783e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 331 (Period 12):  Train Loss: 1.260e-01,  Validation Loss: 3.815e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 332 (Period 12):  Train Loss: 3.040e-04,  Validation Loss: 2.136e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 333 (Period 12):  Train Loss: 2.250e-04,  Validation Loss: 1.612e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 334 (Period 12):  Train Loss: 1.511e-04,  Validation Loss: 1.577e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 335 (Period 12):  Train Loss: 1.346e-04,  Validation Loss: 9.253e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 336 (Period 12):  Train Loss: 2.099e-04,  Validation Loss: 1.653e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 337 (Period 12):  Train Loss: 1.209e-04,  Validation Loss: 6.025e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 338 (Period 12):  Train Loss: 1.050e-03,  Validation Loss: 1.497e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00055846
# Epoch 339 (Period 12):  Train Loss: 3.461e-04,  Validation Loss: 4.709e-05,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0022214
# Epoch 340 (Period 12):  Train Loss: 1.428e-04,  Validation Loss: 1.831e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0049516
# Epoch 341 (Period 12):  Train Loss: 1.955e-04,  Validation Loss: 1.701e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0086881
# Epoch 342 (Period 12):  Train Loss: 1.585e-04,  Validation Loss: 1.445e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013347
# Epoch 343 (Period 12):  Train Loss: 1.523e-04,  Validation Loss: 1.507e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.018826
# Epoch 344 (Period 12):  Train Loss: 1.644e-04,  Validation Loss: 1.645e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.025
# Epoch 345 (Period 12):  Train Loss: 1.604e-04,  Validation Loss: 1.517e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.031733
# Epoch 346 (Period 12):  Train Loss: 1.670e-04,  Validation Loss: 1.877e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.038874
# Epoch 347 (Period 12):  Train Loss: 1.589e-04,  Validation Loss: 1.576e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046263
# Epoch 348 (Period 12):  Train Loss: 1.623e-04,  Validation Loss: 1.632e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.053737
# Epoch 349 (Period 12):  Train Loss: 1.673e-04,  Validation Loss: 1.753e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.061126
# Epoch 350 (Period 12):  Train Loss: 1.800e-04,  Validation Loss: 1.570e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.068267
# Epoch 351 (Period 12):  Train Loss: 1.748e-04,  Validation Loss: 1.752e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.075
# Epoch 352 (Period 12):  Train Loss: 1.680e-04,  Validation Loss: 1.450e-04,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.081174
# Epoch 353 (Period 12):  Train Loss: 1.849e-04,  Validation Loss: 2.844e-04,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.086653
# Epoch 354 (Period 12):  Train Loss: 1.728e-04,  Validation Loss: 1.141e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch 355 (Period 12):  Train Loss: 1.741e-04,  Validation Loss: 1.899e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.095048
# Epoch 356 (Period 12):  Train Loss: 1.753e-04,  Validation Loss: 1.672e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.097779
# Epoch 357 (Period 12):  Train Loss: 1.752e-04,  Validation Loss: 1.887e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.099442
# Epoch 358 (Period 12):  Train Loss: 1.748e-04,  Validation Loss: 2.358e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 359 (Period 12):  Train Loss: 1.755e-04,  Validation Loss: 1.640e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 360 (Period 12):  Train Loss: 1.699e-04,  Validation Loss: 1.706e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.1
# Epoch 361 (Period 13):  Train Loss: 1.128e-01,  Validation Loss: 4.837e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 362 (Period 13):  Train Loss: 2.365e-04,  Validation Loss: 1.460e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 363 (Period 13):  Train Loss: 1.466e-04,  Validation Loss: 1.023e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 364 (Period 13):  Train Loss: 1.468e-04,  Validation Loss: 9.898e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 365 (Period 13):  Train Loss: 1.079e-04,  Validation Loss: 5.760e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 366 (Period 13):  Train Loss: 9.578e-05,  Validation Loss: 5.932e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 367 (Period 13):  Train Loss: 1.873e-04,  Validation Loss: 1.567e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch 368 (Period 13):  Train Loss: 1.185e-04,  Validation Loss: 2.170e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00055846
# ...
# Epoch 552 (Period 19):  Train Loss: 1.533e-04,  Validation Loss: 1.758e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013347
# Epoch 553 (Period 19):  Train Loss: 1.471e-04,  Validation Loss: 1.371e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.018826
# Epoch 554 (Period 19):  Train Loss: 1.550e-04,  Validation Loss: 1.348e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.025
# Epoch 555 (Period 19):  Train Loss: 1.637e-04,  Validation Loss: 1.509e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.031733
# Epoch 556 (Period 19):  Train Loss: 1.537e-04,  Validation Loss: 1.624e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.038874
# Epoch 557 (Period 19):  Train Loss: 1.617e-04,  Validation Loss: 1.421e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046263
# Epoch 558 (Period 19):  Train Loss: 1.587e-04,  Validation Loss: 1.526e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.053737
# Epoch 559 (Period 19):  Train Loss: 1.661e-04,  Validation Loss: 1.737e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.061126
# Epoch 560 (Period 19):  Train Loss: 1.684e-04,  Validation Loss: 1.752e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.068267
# Epoch 561 (Period 19):  Train Loss: 1.650e-04,  Validation Loss: 1.551e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.075
# Epoch 562 (Period 19):  Train Loss: 1.689e-04,  Validation Loss: 1.426e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.081174
# Epoch 563 (Period 19):  Train Loss: 1.699e-04,  Validation Loss: 1.638e-04,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.086653
# Epoch 564 (Period 19):  Train Loss: 1.730e-04,  Validation Loss: 1.562e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.091312
# Epoch 565 (Period 19):  Train Loss: 1.920e-04,  Validation Loss: 2.015e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.095048
# Epoch 566 (Period 19):  Train Loss: 1.728e-04,  Validation Loss: 1.820e-04,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.097779
# Epoch 567 (Period 19):  Train Loss: 1.723e-04,  Validation Loss: 1.546e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.099442
# Epoch 568 (Period 19):  Train Loss: 1.725e-04,  Validation Loss: 1.576e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 569 (Period 19):  Train Loss: 1.726e-04,  Validation Loss: 1.482e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1
# Epoch 570 (Period 19):  Train Loss: 1.807e-04,  Validation Loss: 1.925e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 571 (Period 20):  Train Loss: 1.409e-01,  Validation Loss: 5.228e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 572 (Period 20):  Train Loss: 2.849e-04,  Validation Loss: 1.706e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 573 (Period 20):  Train Loss: 1.628e-04,  Validation Loss: 2.048e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 574 (Period 20):  Train Loss: 1.511e-04,  Validation Loss: 4.043e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 575 (Period 20):  Train Loss: 1.558e-04,  Validation Loss: 8.272e-05,  Epoch Time: 0.31s,  Current Pruning Threshold: 0
# Epoch 576 (Period 20):  Train Loss: 3.578e-04,  Validation Loss: 8.097e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 577 (Period 20):  Train Loss: 2.449e-04,  Validation Loss: 2.134e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch 578 (Period 20):  Train Loss: 1.002e-04,  Validation Loss: 5.685e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00055846
# Epoch 579 (Period 20):  Train Loss: 5.080e-04,  Validation Loss: 1.229e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0022214
# Epoch 580 (Period 20):  Train Loss: 2.346e-04,  Validation Loss: 1.660e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0049516
# Epoch 581 (Period 20):  Train Loss: 1.674e-04,  Validation Loss: 1.435e-04,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.0086881
# Epoch 582 (Period 20):  Train Loss: 1.626e-04,  Validation Loss: 1.643e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013347
# Epoch 583 (Period 20):  Train Loss: 1.605e-04,  Validation Loss: 1.486e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.018826
# Epoch 584 (Period 20):  Train Loss: 1.576e-04,  Validation Loss: 1.634e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.025
# Epoch 585 (Period 20):  Train Loss: 1.597e-04,  Validation Loss: 1.631e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.031733
# Epoch 586 (Period 20):  Train Loss: 1.672e-04,  Validation Loss: 1.445e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.038874
# Epoch 587 (Period 20):  Train Loss: 1.725e-04,  Validation Loss: 1.355e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.046263
# Epoch 588 (Period 20):  Train Loss: 1.687e-04,  Validation Loss: 2.364e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.053737
# Epoch 589 (Period 20):  Train Loss: 1.782e-04,  Validation Loss: 1.462e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.061126
# Epoch 590 (Period 20):  Train Loss: 1.685e-04,  Validation Loss: 1.551e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.068267
# Epoch 591 (Period 20):  Train Loss: 1.734e-04,  Validation Loss: 1.596e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.075
# Epoch 592 (Period 20):  Train Loss: 1.720e-04,  Validation Loss: 2.041e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.081174
# Epoch 593 (Period 20):  Train Loss: 1.857e-04,  Validation Loss: 1.581e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.086653
# Epoch 594 (Period 20):  Train Loss: 1.641e-04,  Validation Loss: 1.852e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091312
# Epoch 595 (Period 20):  Train Loss: 1.802e-04,  Validation Loss: 1.548e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.095048
# Epoch 596 (Period 20):  Train Loss: 1.749e-04,  Validation Loss: 1.403e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.097779
# Epoch 597 (Period 20):  Train Loss: 1.717e-04,  Validation Loss: 1.381e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.099442
# Epoch 598 (Period 20):  Train Loss: 1.677e-04,  Validation Loss: 1.527e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# Epoch 599 (Period 20):  Train Loss: 1.722e-04,  Validation Loss: 1.560e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 8
#       5 trainer.reset_trainer_and_model_weights(i)
#       6 output = training_output[:, i:i+1]
# ----> 8 history = trainer.fit(
#       9     training_input,
#      10     output,
#      11     batch_size=MINI_BATCH_SIZE,
#      12     validation_split=0.20,
#      13     epochs=round(NUM_EPOCHS),
#      14     pruning_scheduler=pruning_scheduler,
#      15     callbacks=callbacks,
#      16     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
#      17     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
#      18     shuffle_per_epoch=False,
#      19     patience_periods=15,
#      20     verbose=1,
#      21 )
#      23 training_histories.append(history)
#      25 # Retrieve the weights of the trained model
#
# File ~/Library/CloudStorage/GoogleDrive-siyuanxing9132@gmail.com/My Drive/A-Research/A-Cal Poly/2023-NN-SINDY/paper-NC/SREINet-Git/code/utilities/sreinet_trainer.py:180, in SREINetTrainer.fit(self, training_input, training_output, batch_size, validation_split, epochs, pruning_scheduler, callbacks, early_stopping_loss_threshold, early_stopping_pruning_threshold, patience_periods, improvement_threshold, verbose, print_every_n_epochs, shuffle_per_epoch)
#     178 for train_inputs, train_targets in epoch_train_dataset:
#     179     loss = self._train_step(train_inputs, train_targets, binary_mask)
# --> 180     train_loss(loss)
#     182 # Validation
#     183 for val_inputs, val_targets in val_dataset:
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/metrics/base_metric.py:216, in Metric.__call__(self, *args, **kwargs)
#     210         return result_t
#     212 from keras.src.distribute import (
#     213     distributed_training_utils,
#     214 )
# --> 216 return distributed_training_utils.call_replica_local_fn(
#     217     replica_local_fn, *args, **kwargs
#     218 )
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/distribute/distributed_training_utils.py:62, in call_replica_local_fn(fn, *args, **kwargs)
#      60     with strategy.scope():
#      61         return strategy.extended.call_for_each_replica(fn, args, kwargs)
# ---> 62 return fn(*args, **kwargs)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/metrics/base_metric.py:187, in Metric.__call__.<locals>.replica_local_fn(*args, **kwargs)
#     185     update_op = None
#     186 else:
# --> 187     update_op = self.update_state(*args, **kwargs)
#     188 update_ops = []
#     189 if update_op is not None:
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/utils/metrics_utils.py:77, in update_state_wrapper.<locals>.decorated(metric_obj, *args, **kwargs)
#      69         raise ValueError(
#      70             "Trying to run metric.update_state in replica context when "
#      71             "the metric was not created in TPUStrategy scope. "
#      72             "Make sure the keras Metric is created in TPUstrategy "
#      73             "scope. "
#      74         )
#      76 with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 77     result = update_state_fn(*args, **kwargs)
#      78 if not tf.executing_eagerly():
#      79     result = tf.compat.v1.get_default_graph().get_operations()[-1]
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/metrics/base_metric.py:140, in Metric.__new__.<locals>.update_state_fn(*args, **kwargs)
#     136 control_status = tf.__internal__.autograph.control_status_ctx()
#     137 ag_update_state = tf.__internal__.autograph.tf_convert(
#     138     obj_update_state, control_status
#     139 )
# --> 140 return ag_update_state(*args, **kwargs)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/metrics/base_metric.py:539, in Reduce.update_state(self, values, sample_weight)
#     537 elif self.reduction == metrics_utils.Reduction.WEIGHTED_MEAN:
#     538     if sample_weight is None:
# --> 539         num_values = tf.cast(tf.size(values), self._dtype)
#     540     else:
#     541         num_values = tf.reduce_sum(sample_weight)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py:799, in size_v2(input, out_type, name)
#     797   else:
#     798     out_type = dtypes.int32
# --> 799 return size(input, name, out_type)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py:838, in size(input, name, out_type)
#     836   else:
#     837     out_type = dtypes.int32
# --> 838 return size_internal(input, name, optimize=True, out_type=out_type)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/ops/array_ops.py:861, in size_internal(input, name, optimize, out_type)
#     859   input = ops.convert_to_tensor(input)
#     860   np_out_type = out_type.as_numpy_dtype
# --> 861   num_elements = np.prod(input._shape_tuple(), dtype=np_out_type)  # pylint: disable=protected-access
#     862   return ops.convert_to_tensor(num_elements, dtype=out_type)
#     863 with ops.name_scope(name, "Size", [input]) as name:
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3100, in prod(a, axis, dtype, out, keepdims, initial, where)
#    2979 @array_function_dispatch(_prod_dispatcher)
#    2980 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2981          initial=np._NoValue, where=np._NoValue):
#    2982     """
#    2983     Return the product of array elements over a given axis.
#    2984
#    (...)
#    3098     10
#    3099     """
# -> 3100     return _wrapreduction(a, np.multiply, 'prod', axis, dtype, out,
#    3101                           keepdims=keepdims, initial=initial, where=where)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/numpy/core/fromnumeric.py:71, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      60     except TypeError:
#      61         # A TypeError occurs if the object does have such a method in its
#      62         # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66         # Call _wrapit from within the except clause to ensure a potential
#      67         # exception has a traceback chain.
#      68         return _wrapit(obj, method, *args, **kwds)
# ---> 71 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
#      72     passkwargs = {k: v for k, v in kwargs.items()
#      73                   if v is not np._NoValue}
#      75     if type(obj) is not mu.ndarray:
#
# KeyboardInterrupt:

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_set_labels(N):
    labels = ['Constant']
    for i in range(1, N+1):
        labels.extend([f'x{i}', f'y{i}', f'z{i}'])
    return labels

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
def coefficient_reconstruction(dim_index,
                                weights, 
                                minimum_coefficient_threshold = 1e-5,
                                coefficient_output_digits = 10, 
                                enable_coefficient_sorting = False):
    
    max_neurons = max(max(len(layer) for layer in SREINet) for SREINet in weights)
    
    labels = generate_set_labels(max_neurons - 1) # number of states = number of neurons - 1

    def explore_path(SREINet_index, layer, neuron, weight_product, label_counts, non_zero_paths):
        """
        Recursively explores non-zero paths in a neural network.
        """
        if layer == len(weights[SREINet_index]) - 1:
            non_zero_paths.append((label_counts, weight_product))
            return

        for next_neuron, weight in enumerate(weights[SREINet_index][layer][neuron]):
            if abs(weight) <= 1e-15:
                # Skip recursion if the weight is zero (if one weight is zero, the whole path will be eliminated)
                continue  
            new_weight_product = weight_product * weight
            next_label_counts = label_counts.copy()
            next_label_counts[labels[next_neuron]] = next_label_counts.get(labels[next_neuron], 0) + 1
            explore_path(SREINet_index, layer + 1, next_neuron, new_weight_product, next_label_counts, non_zero_paths)
    
    #beginning of the algorithm
    all_SREINet_products = []
    for SREINet_index, _ in enumerate(weights):
        non_zero_paths = []
        #collect all non-zero paths
        for neuron_index in range(len(weights[SREINet_index][0])):
            label_counts = {labels[neuron_index]: 1}
            explore_path(SREINet_index, 0, neuron_index, 1, label_counts, non_zero_paths)
        
        #sum up the products with identical composite nonlinear/linear terms
        SREINet_products = {}
        for label_counts, weight_product in non_zero_paths:
            label_counts_key = frozenset(label_counts.items())
            if label_counts_key in SREINet_products:
                SREINet_products[label_counts_key] += weight_product
            else:
                SREINet_products[label_counts_key] = weight_product
        
        #remove the negligible composite terms
        SREINet_products = {k: v for k, v in SREINet_products.items() if abs(v) >= minimum_coefficient_threshold}
        
        if enable_coefficient_sorting:
            #sort the composite terms by their absolute values
            sorted_SREINet_products = dict(sorted(SREINet_products.items(), key=lambda item: abs(item[1]), reverse=True))
        else:
            sorted_SREINet_products = SREINet_products

        all_SREINet_products.append(sorted_SREINet_products)

    #output formatting
    labeled_all_SREINet_products = []
    for SREINet_index, sorted_SREINet_products in enumerate(all_SREINet_products):
        SREINet_product_strings = []
        for key, value in sorted_SREINet_products.items():
            labels_list = []
            only_constant = len(key) == 1 and any(label == 'Constant' for label, _ in key)
            
            for label, count in sorted(key):
                if label == 'Constant' and len(key) > 1:
                    continue
                if label != 'Constant' and count > 1:
                    labels_list.append(f"{label}^{count}")
                elif label == 'Constant' or count == 1:
                    labels_list.append(label if label != 'Constant' else '')
            
            label_str = '*'.join(filter(None, labels_list))
                        
            # Apply coefficient threshold if enabled
            formatted_value = f"{abs(value):.{coefficient_output_digits}g}"

            term_str = label_str if formatted_value == '1' else f"{formatted_value}*{label_str}" if not only_constant else formatted_value if formatted_value != '1' else ''
            sign = '+' if value >= 0 else '-'
            if SREINet_product_strings or value < 0:
                term_str = f" {sign} {term_str}"
            else:
                term_str = term_str
            SREINet_product_strings.append(term_str)

        formatted_output = ''.join(SREINet_product_strings)
        layer_prefix = f"(x{SREINet_index+dim_index+1})'= "
        full_output = layer_prefix + formatted_output
        labeled_all_SREINet_products.append(full_output)

    return labeled_all_SREINet_products

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
for i in range(len(weights_list)):
    path_products = coefficient_reconstruction(i,weights_list[i], 
                                            minimum_coefficient_threshold = 1e-5,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")

# %% [markdown]
# ### **Validation**

# %%
import matplotlib.pyplot as plt

# validation: need to draw the output of each dimension independently
dim_to_plot = 1
index = dim_to_plot - 1

#Form NN predictions
NN_output = np.zeros((dx_train.shape[0], dx_train.shape[1]))
for i, weight in enumerate(weights_list):
    model.set_weights(weight[0])
    output = model.predict(training_input_for_sim)
    NN_output[:,i:i+1] = output

#validate the first trajectory if there are many
plt.plot(t_arr, NN_output[:,index][:t_arr.shape[0]], 'r', label='NN Prediction')
plt.plot(t_arr, dx_train[:,index][:t_arr.shape[0]], 'k', label='Expected Output')

#pick the last point of the simulation output and use it as the initial condition for the next simulation
x0 = x_train[:t_arr.shape[0]][-1]
t0 = t_arr[-1]
validation_generator = DG.DataGenerator(x0, T=data_T + t0, dt=data_dt, t0=t0)
new_t_arr, new_x, new_dx = validation_generator.generate_dataset_by_custom_ODEs(
    ode_function,
    *network_arguments,
    method='RK45'
)

new_input = new_x

new_NN_output = np.zeros((new_dx.shape[0], new_dx.shape[1]))
for i, weight in enumerate(weights_list):
    model.set_weights(weight[0])
    output = model.predict(new_input)
    new_NN_output[:,i:i+1] = output

plt.plot(new_t_arr, new_NN_output[:,index], "r--", label='NN Prediction')
plt.plot(new_t_arr, new_dx[:,index], "k--", label='Expected Output')
plt.title("Response of dimension " + str(dim_to_plot))
plt.legend()
plt.show()

# %% [markdown]
# ## **VI. Output**

# %%
#save data
#NN configurations -> #NN layers, #NN neurons
#data configurations -> #data points, #data dimensions
#optimizer configurations -> #learning rate, #decay rate
#training configurations -> #NN training epochs, callbacks
#record loss values
#save the info into a spreadsheet

import pandas as pd

df = pd.DataFrame({
    'ODE model': [MY_MODEL],
    'data initial conditions': [data_initial_conditions],
    'data length (T)': [data_T],
    'data resolution (dt)': [data_dt],
    'learning rate': [learning_rate],
    'Guess highest-order polynomial': [guess_highest_order_polynomial],
    'input dimension': [x_train.shape[1]],
    'mini_batch_size': [MINI_BATCH_SIZE],
    'Layer Neurons per activation fns': [layer_neuron_nums_per_act_fn],
    'Data Points': [training_input.shape[0]],
    'loss function': [LOSS_FUNCTION],
    'Total Training Epochs': [NUM_EPOCHS],
    'last lost value': [history['loss'][-1]],
    'weight threshold for pruning': [PRUNING_WEIGHT_THRESHOLD],
    'loss threshold for early stopping': [EARLY_STOPPING_LOSS_THRESHOLD],
})

# %%
#write df to the first sheet of the excel file
#write to folder named data

opt_folder = 'output'
# Create the folder if it doesn't exist
os.makedirs(opt_folder, exist_ok=True)

with pd.ExcelWriter(os.path.join(opt_folder,'nn_configurations.xlsx')) as writer:

    df.to_excel(writer, sheet_name='configuration', index=False)

    #save the loss and validation history to the second sheet of the excel file
    df2 = pd.DataFrame(history)
    df2.to_excel(writer, sheet_name='loss_history', index=False)

    #save reconstructed weights to the third sheet of the excel file

    df3 = []

    for i in range(len(weights_list)):
        path_products = coefficient_reconstruction(i,
                                                    weights_list[i], 
                                                    minimum_coefficient_threshold = 1e-4,
                                                    coefficient_output_digits = 10, 
                                                    enable_coefficient_sorting = False)


        # Convert path_products to a DataFrame
        temp_df = pd.DataFrame(path_products)

        # Append temp_df to df3
        df3.append(temp_df)

    df3 = pd.concat(df3, ignore_index=True)
    df3.to_excel(writer, sheet_name='reconstructed_weights', index=False)

# %%
from scipy.io import savemat
#concatenate t_arr, x_train, dx_train, and NN_output and save it as a mat file

#pate t_arr such that it has the same shape as x_train, dx_train, and NN_output
tem_t_arr = t_arr
for i in range(num_traj-1):
    tem_t_arr = np.concatenate((tem_t_arr, t_arr), axis=0) 
t_arr = tem_t_arr

m_data = np.concatenate((t_arr, x_train, dx_train, NN_output), axis=1)
savemat(os.path.join(opt_folder,'train_data.mat'), {'data': m_data})

v_data = np.concatenate((new_t_arr, new_x, new_dx, new_NN_output), axis=1)
savemat(os.path.join(opt_folder,'validation_data.mat'), {'data': v_data})
