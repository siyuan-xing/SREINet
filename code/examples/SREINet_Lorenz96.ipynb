# %% [markdown]
# ## **Lorenz 96 Model Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG

# Tensowflow version should be 2.13.0 or
# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("*******************************|***************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()


opt_folder = 'output'
# Create the folder if it doesn't exist
os.makedirs(opt_folder, exist_ok=True)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.10.0              *
# *                                            *
# *******************************|***************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_MODEL = 'Lorenz_96' 
MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)  

# Generate data based on the specified model type
LORENZ96_DIM = 100  #Change this value to your desired number of elements
# Generate N random numbers from a normal distribution (mean=0, std=1)

num_traj = 6
data_initial_conditions = DG.DataGenerator.generate_initial_conditions(LORENZ96_DIM, num_traj, seed=42) #np.random.normal(1, 2, LORENZ96_DIM

#data_initial_conditions = np.random.normal(0.0, 1.0, LORENZ96_DIM)
data_T =  10.0       # Length of the data (T)
data_dt = 0.001       # Resolution of the data (dt)
myDG = DG.DataGenerator(data_initial_conditions,T=data_T, dt=data_dt, derivative_mode="exact")
t_arr, x_train, dx_train, guess_highest_order_polynomial = myDG.generate_dataset_by_model_name(MY_MODEL, method='DOP853')

print("Guess highest order polynomial:", guess_highest_order_polynomial)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train
# Optionally, save a copy of the training input for simulation
training_input_for_sim = training_input.copy() # Saving a copy of training input for simulation (Before shuffling)

training_input, training_output = myDG.shuffleData(training_input, training_output)

print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Guess highest order polynomial: 2
# Training input shape: (60000, 100)
# Training output shape: (60000, 100)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 128
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables, including the added constant 1)
dim = training_input.shape[1] 

# The grid size of each dimension
layer_neuron_nums_per_act_fn = [dim] * guess_highest_order_polynomial
print(layer_neuron_nums_per_act_fn)
# Out:
# [100, 100]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn, 1, 
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=0.001, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

def reinitialize_model_weights(model):
    if hasattr(model.layers[1], 'reinitialize_weights'):
            tf.random.set_seed(np.random.randint(10000))
            model.layers[1].reinitialize_weights()
    else:
        print("SREINet does not have a reinitialize_weights() function.")

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate

# %% [markdown]
# ### **2.4 Training with Pruning**

# %%
import time
np.set_printoptions(threshold=np.inf)

# Define a training step function
@tf.function
def train_step(model, optimizer, loss_fn, inputs, targets, binary_mask):        
    with tf.GradientTape() as tape:
        # Generate predictions and calculate loss
        predictions = model(inputs, training=False)
        loss = loss_fn(targets, predictions)   
        
    # Calculate gradients and update model weights
    gradients = tape.gradient(loss, model.trainable_variables)        

    # Assuming binary_masks_ones is a list of binary masks created for each trainable variable
    masked_gradients = [tf.multiply(grad, mask) for grad, mask in zip(gradients, binary_mask)]

    optimizer.apply_gradients(zip(masked_gradients, model.trainable_variables))

    return loss

# Define a validation step function
@tf.function
def val_step(model, loss_fn, inputs, targets):
    # Generate predictions and calculate loss for validation data
    predictions = model(inputs, training=False)
    # predictions = model(inputs, training=False) 
    v_loss = loss_fn(targets, predictions)
    # Record the validation loss
    return v_loss   

def SREINet_fit_w_pruning(
    model,              # TensorFlow model to be trained
    training_input,     # Input features for training
    training_output,    # Target outputs for training
    batch_size,         # Number of samples per batch of computation
    validation_split,   # Fraction of data to be used as validation set
    epochs,             # Number of complete passes through the training dataset
    optimizer,          # Optimization algorithm for updating weights
    loss_fn,            # Loss function to measure model's performance
    pruning_schedule,   # Pruning schedule for gradually increasing the sparsity level
    data_type='float32',    # Data type of the tensors (default: 'float32')
    callbacks=None,         # List of callbacks for custom actions at various stages of training
    early_stopping_loss_threshold=0,       # Threshold for early stopping based on training and validation loss
    early_stopping_pruning_threshold=0,    # Threshold for early stopping based on pruning schedule
    verbose=0               # Verbosity mode (0 = silent, 1 = progress bar, etc.)
):
    # Cast the training input and output to the specified data type
    training_input = tf.cast(training_input, data_type)
    training_output = tf.cast(training_output, data_type)

    # Shuffle and batch the dataset, then split it into training and validation sets
    full_dataset = tf.data.Dataset.from_tensor_slices((training_input, training_output)).shuffle(buffer_size=1024)
    total_samples = training_input.shape[0]
    train_samples = int(total_samples * (1 - validation_split))
    
    # Apply the data type casting for each batch in the datasets
    train_dataset = full_dataset.take(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))
    val_dataset = full_dataset.skip(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))

    # Initialize metrics for tracking training and validation loss
    train_loss = tf.keras.metrics.Mean(name='train_loss', dtype=data_type)
    val_loss = tf.keras.metrics.Mean(name='val_loss', dtype=data_type)
    
    # Parameters initialization
    binary_mask = [tf.ones_like(var) for var in model.trainable_variables]

    def generate_binary_mask_and_prune_weight(model, pruning_weight_threshold):
        binary_masks = []  # Initialize list to hold binary masks
        
        # Iterate over each variable to apply the pruning threshold and generate masks
        for var in model.trainable_variables:
            # Generate a binary mask where weights above the PRUNING_WEIGHT_THRESHOLD are marked with 1, others with 0
            mask = tf.cast(tf.abs(var) >= pruning_weight_threshold, var.dtype)

            # Update the mask at position (0, 0) to be 1 using tf.tensor_scatter_nd_update (To Avoid the constant term being pruned)
            indices = tf.constant([[0, 0]])  # Specify the indices to update
            updates = tf.constant([1], dtype=mask.dtype)  # Specify the value to update
            mask = tf.tensor_scatter_nd_update(mask, indices, updates)

            binary_masks.append(mask)  # Add the generated mask to the list            

            # Apply mask to modify weights by setting weights below PRUNING_WEIGHT_THRESHOLD to zero
            modified_weight = var * mask
            var.assign(modified_weight)            
        return binary_masks

    # Prepare a dictionary to track the training history
    history = {'loss': [], 'val_loss': []}

    # Before the training loop starts
    if callbacks:
        for callback in callbacks:
            # Assign the model to the callback
            callback.set_model(model)

            # Manually setting params before calling any methods that might depend on them
            callback.params = {
                'epochs': epochs,  # Number of epochs
                # You can add more parameters here as needed
            }

            # Now call on_train_begin with all properties set
            callback.on_train_begin(logs={'loss_threshold': early_stopping_loss_threshold})

    training_start_time = time.time()
    # Execute the training loop
    for epoch in range(epochs):
        # Notify callbacks that the epoch has started
        if callbacks:
            epoch_logs = {}
            for callback in callbacks:
                callback.on_epoch_begin(epoch, logs=epoch_logs)

        if verbose: 
            eopoch_start_time = time.time()

        # Reset state of metrics at the start of each epoch
        train_loss.reset_states()
        val_loss.reset_states()

        # Retrieve the current pruning schedule threshold
        current_pruning_threshold = pruning_schedule[epoch]
        binary_mask = generate_binary_mask_and_prune_weight(model, current_pruning_threshold)
        
        layer_losses_sum = None
        layer_indices = [i for i, layer in enumerate(model.layers) if layer.trainable]
        # Process each batch in the training dataset
        for train_inputs, train_targets in train_dataset:           
            loss = train_step(model = model, 
                            optimizer = optimizer, 
                            loss_fn = loss_fn,
                            inputs = train_inputs, 
                            targets = train_targets, 
                            binary_mask = binary_mask)    
            # Record the loss
            train_loss(loss)

        # Process each batch in the validation dataset
        for val_inputs, val_targets in val_dataset:
            v_loss = val_step(model = model, 
                                loss_fn = loss_fn,
                                inputs = val_inputs, 
                                targets = val_targets)
            val_loss(v_loss)

        # Append the average losses for this epoch to the history
        history['loss'].append(train_loss.result().numpy())
        history['val_loss'].append(val_loss.result().numpy())
        #calculate the average of val_loss
        
        # Current Losses
        current_train_loss = train_loss.result().numpy()
        current_val_loss = val_loss.result().numpy()

        # Notify callbacks that the epoch has ended
        epoch_logs = {'loss': current_train_loss, 'val_loss': current_val_loss}
        if callbacks:
            for callback in callbacks:
                callback.on_epoch_end(epoch, logs=epoch_logs)
    
        if verbose:
            epoch_time = time.time() - eopoch_start_time
            total_layers = len(model.layers)
            trainable_layer_count = sum(1 for layer in model.layers if layer.trainable)
            print(f"Epoch {epoch + 1:3.0f}:"
                f"  Train Loss: {current_train_loss:9.4e}"
                f",  Validation Loss: {current_val_loss:9.4e}"
                # f",  Trainable Layers ({trainable_layer_count}/{total_layers})"
                f",  Epoch Time: {epoch_time:.2f}s"  
                f",  Current Pruning Threshold: {current_pruning_threshold:.5g}")    
            
        if model.stop_training: # Stop training if all the layers are untrianable
            break   

        # Check for early stopping
        if current_train_loss < early_stopping_loss_threshold and current_pruning_threshold > early_stopping_pruning_threshold:
            print(f"Early stopping at epoch {epoch+1} as train loss {current_val_loss:.12f} is below the threshold {early_stopping_loss_threshold:.12f}")
            break


    # After the training loop ends
    training_time = time.time() - training_start_time
    print(f'Traininng Stopped. Time elapsed: {training_time:.2f}s')
    if callbacks:
        for callback in callbacks:
            callback.on_train_end(logs={'final_loss': current_train_loss, 'final_val_loss': current_val_loss})
    

    # Return the history containing training and validation losses
    return history

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
PRUNING_WEIGHT_THRESHOLD = 0.30 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 50
PRUNING_EPOCHS_PER_PERIOD = 40
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_schedule as ps

# Define the pruning schedule
pruning_schedule = ps.pruning_schedule_ramp(maximum_threshold=PRUNING_WEIGHT_THRESHOLD, 
                                                    steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                                                    num_periods=N_PERIODS, 
                                                    #zero_percentage=0.10,
                                                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
callbacks = []

EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.1

training_histories = []
weights_list = []

# %%
#change 0 to a other number if you want to start training from other dimensions
for i in range(0, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    reinitialize_model_weights(model)
    output = training_output[:, i:i+1]

    history = SREINet_fit_w_pruning(
        model,                   # Model to train
        training_input,             # Input data for training
        output,                     # Output data for training
        batch_size=MINI_BATCH_SIZE, # Number of samples per gradient update
        validation_split=0.20,      # Fraction of the training data to be used as validation data
        epochs=round(NUM_EPOCHS),   # Number of times the entire training dataset is passed through the model
        optimizer=my_optimizer,     # Optimizer to use for training
        pruning_schedule = pruning_schedule, # Pruning schedule for gradually increasing the sparsity level
        loss_fn=loss_fn,            # Loss function to use for training
        data_type=MY_DATA_TYPE,     # Data type to use for training
        callbacks= callbacks,       # List of callbacks to apply during training
        early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,# Threshold for early stopping (Layer Based)
        early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD, # Threshold for early stopping (Pruning Based)
        verbose=1                   # Hide the epoch steps
    )
    
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([model.get_layer('SREINet').get_weights()])
# Out:
# Training dimension 1...
# Epoch   1:  Train Loss: 2.7847e+01,  Validation Loss: 1.1074e+01,  Epoch Time: 0.70s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 3.6945e+01,  Validation Loss: 6.0581e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 8.9691e+00,  Validation Loss: 7.4203e-01,  Epoch Time: 0.49s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 9.7229e+01,  Validation Loss: 1.2794e+02,  Epoch Time: 0.47s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 3.9440e+00,  Validation Loss: 5.8448e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 4.6937e-01,  Validation Loss: 6.1969e-01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 6.8295e-01,  Validation Loss: 9.2362e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 1.1257e+01,  Validation Loss: 9.2871e+00,  Epoch Time: 0.49s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 1.4007e+01,  Validation Loss: 4.6265e-01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 1.6359e+00,  Validation Loss: 4.8419e-01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.00087931
# Epoch  11:  Train Loss: 1.4582e+00,  Validation Loss: 2.6008e-01,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.0035069
# Epoch  12:  Train Loss: 6.5491e+00,  Validation Loss: 1.3479e+00,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.007852
# Epoch  13:  Train Loss: 3.7900e+00,  Validation Loss: 2.0665e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.013864
# Epoch  14:  Train Loss: 5.1494e+00,  Validation Loss: 3.0211e+00,  Epoch Time: 0.55s,  Current Pruning Threshold: 0.021471
# Epoch  15:  Train Loss: 6.0458e+00,  Validation Loss: 4.0209e+00,  Epoch Time: 0.60s,  Current Pruning Threshold: 0.030586
# Epoch  16:  Train Loss: 6.2610e+00,  Validation Loss: 6.1408e+00,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.041101
# Epoch  17:  Train Loss: 6.4116e+00,  Validation Loss: 6.3226e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.052892
# Epoch  18:  Train Loss: 7.0007e+00,  Validation Loss: 6.7419e+00,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.065822
# Epoch  19:  Train Loss: 7.5628e+00,  Validation Loss: 7.4358e+00,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.079739
# Epoch  20:  Train Loss: 7.8136e+00,  Validation Loss: 7.5306e+00,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.094479
# Epoch  21:  Train Loss: 7.5306e+00,  Validation Loss: 7.2949e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.10987
# Epoch  22:  Train Loss: 6.9708e+00,  Validation Loss: 6.8405e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.12573
# Epoch  23:  Train Loss: 6.6858e+00,  Validation Loss: 6.5542e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.14188
# Epoch  24:  Train Loss: 1.0606e+01,  Validation Loss: 1.0284e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.15812
# Epoch  25:  Train Loss: 1.0507e+01,  Validation Loss: 1.0227e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.17427
# Epoch  26:  Train Loss: 1.0645e+01,  Validation Loss: 1.0212e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.19013
# Epoch  27:  Train Loss: 1.0369e+01,  Validation Loss: 1.0052e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.20552
# Epoch  28:  Train Loss: 1.3137e+01,  Validation Loss: 1.2433e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.22026
# Epoch  29:  Train Loss: 1.2514e+01,  Validation Loss: 1.2047e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.23418
# Epoch  30:  Train Loss: 1.2227e+01,  Validation Loss: 1.1930e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.24711
# Epoch  31:  Train Loss: 1.2103e+01,  Validation Loss: 1.1820e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.2589
# Epoch  32:  Train Loss: 1.2046e+01,  Validation Loss: 1.1802e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.26941
# Epoch  33:  Train Loss: 1.2033e+01,  Validation Loss: 1.1719e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.27853
# Epoch  34:  Train Loss: 1.2013e+01,  Validation Loss: 1.1737e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.28614
# Epoch  35:  Train Loss: 1.1995e+01,  Validation Loss: 1.1765e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.29215
# Epoch  36:  Train Loss: 1.2009e+01,  Validation Loss: 1.1721e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.29649
# Epoch  37:  Train Loss: 1.1984e+01,  Validation Loss: 1.1805e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.29912
# Epoch  38:  Train Loss: 1.2005e+01,  Validation Loss: 1.1735e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  39:  Train Loss: 1.1996e+01,  Validation Loss: 1.1754e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  40:  Train Loss: 1.1993e+01,  Validation Loss: 1.1732e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  41:  Train Loss: 1.1417e+03,  Validation Loss: 7.2405e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 3.3371e-01,  Validation Loss: 1.9312e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 1.4653e-01,  Validation Loss: 1.1245e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 9.5683e-02,  Validation Loss: 7.9665e-02,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 7.2096e-02,  Validation Loss: 6.5039e-02,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 5.9909e-02,  Validation Loss: 5.1518e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 5.1014e-02,  Validation Loss: 4.7224e-02,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 4.4286e-02,  Validation Loss: 4.2146e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 3.9493e-02,  Validation Loss: 4.1234e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 8.2600e-02,  Validation Loss: 3.3410e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.00087931
# Epoch  51:  Train Loss: 1.4479e+00,  Validation Loss: 5.7699e-01,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.0035069
# Epoch  52:  Train Loss: 8.9423e-01,  Validation Loss: 7.5680e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.007852
# Epoch  53:  Train Loss: 1.6843e+00,  Validation Loss: 1.0042e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.013864
# Epoch  54:  Train Loss: 9.2948e-01,  Validation Loss: 8.0505e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.021471
# Epoch  55:  Train Loss: 9.4820e-01,  Validation Loss: 8.2987e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.030586
# Epoch  56:  Train Loss: 8.9757e-01,  Validation Loss: 8.2287e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.041101
# Epoch  57:  Train Loss: 1.0092e+00,  Validation Loss: 8.9074e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.052892
# Epoch  58:  Train Loss: 8.8988e-01,  Validation Loss: 7.5500e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.065822
# Epoch  59:  Train Loss: 6.3935e-01,  Validation Loss: 5.3897e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.079739
# Epoch  60:  Train Loss: 5.7503e-01,  Validation Loss: 4.3490e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.094479
# Epoch  61:  Train Loss: 4.0344e-01,  Validation Loss: 2.6912e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.10987
# Epoch  62:  Train Loss: 1.9191e-01,  Validation Loss: 1.2321e-01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.12573
# Epoch  63:  Train Loss: 8.4225e-02,  Validation Loss: 5.0407e-02,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.14188
# Epoch  64:  Train Loss: 3.2481e-02,  Validation Loss: 1.7610e-02,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.15812
# Epoch  65:  Train Loss: 1.0549e-02,  Validation Loss: 5.0685e-03,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.17427
# Epoch  66:  Train Loss: 2.7509e-03,  Validation Loss: 1.1277e-03,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.19013
# Epoch  67:  Train Loss: 5.4815e-04,  Validation Loss: 1.8365e-04,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.20552
# Epoch  68:  Train Loss: 7.8583e-05,  Validation Loss: 2.0310e-05,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.22026
# Epoch  69:  Train Loss: 7.5362e-06,  Validation Loss: 1.4058e-06,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.23418
# Epoch  70:  Train Loss: 4.4817e-07,  Validation Loss: 5.5469e-08,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.24711
# Epoch  71:  Train Loss: 1.5019e-08,  Validation Loss: 9.1430e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.2589
# Epoch  72:  Train Loss: 7.8624e-10,  Validation Loss: 6.3754e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.26941
# Epoch  73:  Train Loss: 5.3513e-10,  Validation Loss: 4.3153e-10,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.27853
# Epoch  74:  Train Loss: 3.7312e-10,  Validation Loss: 3.1165e-10,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.28614
# Epoch  75:  Train Loss: 2.5091e-10,  Validation Loss: 1.9929e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.29215
# Epoch  76:  Train Loss: 1.7275e-10,  Validation Loss: 1.3746e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.29649
# Epoch  77:  Train Loss: 1.1827e-10,  Validation Loss: 9.3751e-11,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.29912
# Epoch  78:  Train Loss: 8.0919e-11,  Validation Loss: 6.6665e-11,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.3
# Early stopping at epoch 78 as train loss 0.000000000067 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 32.59s
# Training dimension 2...
# Epoch   1:  Train Loss: 7.8276e+02,  Validation Loss: 3.5828e+00,  Epoch Time: 0.48s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 2.7421e+00,  Validation Loss: 2.1091e+00,  Epoch Time: 0.43s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.6707e+00,  Validation Loss: 1.3638e+00,  Epoch Time: 0.45s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.2393e+00,  Validation Loss: 1.0922e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 9.8214e-01,  Validation Loss: 9.5577e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 8.4786e-01,  Validation Loss: 8.2588e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 8.2289e-01,  Validation Loss: 8.6182e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 1.0732e+00,  Validation Loss: 2.0455e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 1.4330e+00,  Validation Loss: 8.9321e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 2.9811e+00,  Validation Loss: 6.6606e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.00087931
# Epoch  11:  Train Loss: 4.6122e+00,  Validation Loss: 4.1982e-01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.0035069
# Epoch  12:  Train Loss: 1.1761e+01,  Validation Loss: 1.6368e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.007852
# Epoch  13:  Train Loss: 5.0026e+00,  Validation Loss: 2.6558e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.013864
# Epoch  14:  Train Loss: 5.7675e+00,  Validation Loss: 3.7209e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.021471
# Epoch  15:  Train Loss: 8.4824e+00,  Validation Loss: 7.8880e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.030586
# Epoch  16:  Train Loss: 8.2433e+00,  Validation Loss: 8.1918e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.041101
# Epoch  17:  Train Loss: 8.9004e+00,  Validation Loss: 8.9084e+00,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.052892
# Epoch  18:  Train Loss: 9.0947e+00,  Validation Loss: 8.9822e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.065822
# Epoch  19:  Train Loss: 8.8301e+00,  Validation Loss: 8.7215e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.079739
# Epoch  20:  Train Loss: 8.8908e+00,  Validation Loss: 8.7478e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.094479
# Epoch  21:  Train Loss: 1.1106e+01,  Validation Loss: 1.0922e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.10987
# Epoch  22:  Train Loss: 1.1593e+01,  Validation Loss: 1.1398e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.12573
# Epoch  23:  Train Loss: 1.1108e+01,  Validation Loss: 1.1099e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.14188
# Epoch  24:  Train Loss: 1.0763e+01,  Validation Loss: 1.0804e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.15812
# Epoch  25:  Train Loss: 1.0801e+01,  Validation Loss: 1.0735e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.17427
# Epoch  26:  Train Loss: 1.0841e+01,  Validation Loss: 1.0655e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.19013
# Epoch  27:  Train Loss: 1.0458e+01,  Validation Loss: 1.0334e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.20552
# Epoch  28:  Train Loss: 1.0261e+01,  Validation Loss: 1.0249e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.22026
# Epoch  29:  Train Loss: 1.0170e+01,  Validation Loss: 1.0226e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.23418
# Epoch  30:  Train Loss: 1.3157e+01,  Validation Loss: 1.2762e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.24711
# Epoch  31:  Train Loss: 1.2471e+01,  Validation Loss: 1.2265e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.2589
# Epoch  32:  Train Loss: 1.2250e+01,  Validation Loss: 1.2137e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.26941
# Epoch  33:  Train Loss: 1.2178e+01,  Validation Loss: 1.2133e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.27853
# Epoch  34:  Train Loss: 1.2147e+01,  Validation Loss: 1.2080e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.28614
# Epoch  35:  Train Loss: 1.2130e+01,  Validation Loss: 1.2056e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.29215
# Epoch  36:  Train Loss: 1.2138e+01,  Validation Loss: 1.2115e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.29649
# Epoch  37:  Train Loss: 1.2132e+01,  Validation Loss: 1.2089e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.29912
# Epoch  38:  Train Loss: 1.2135e+01,  Validation Loss: 1.2080e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.3
# Epoch  39:  Train Loss: 1.2139e+01,  Validation Loss: 1.2085e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.3
# Epoch  40:  Train Loss: 1.2141e+01,  Validation Loss: 1.2119e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.3
# Epoch  41:  Train Loss: 6.9627e+02,  Validation Loss: 3.4855e-01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 2.0448e-01,  Validation Loss: 1.2962e-01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 9.7307e-02,  Validation Loss: 7.9692e-02,  Epoch Time: 0.47s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 6.6980e-02,  Validation Loss: 5.9524e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 5.3228e-02,  Validation Loss: 4.7943e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 4.3153e-02,  Validation Loss: 3.9467e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 3.8949e-02,  Validation Loss: 3.4882e-02,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 3.6816e-02,  Validation Loss: 4.1510e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 2.7804e-01,  Validation Loss: 5.7910e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 3.6216e-01,  Validation Loss: 2.9949e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.00087931
# Epoch  51:  Train Loss: 1.5539e+00,  Validation Loss: 5.5739e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.0035069
# Epoch  52:  Train Loss: 8.5153e-01,  Validation Loss: 6.3411e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.007852
# Epoch  53:  Train Loss: 1.1177e+00,  Validation Loss: 7.2319e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.013864
# Epoch  54:  Train Loss: 1.0949e+00,  Validation Loss: 9.1805e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.021471
# Epoch  55:  Train Loss: 8.4092e-01,  Validation Loss: 7.9227e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.030586
# Epoch  56:  Train Loss: 9.5977e-01,  Validation Loss: 8.4602e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.041101
# Epoch  57:  Train Loss: 8.3403e-01,  Validation Loss: 7.2145e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.052892
# Epoch  58:  Train Loss: 1.0716e+00,  Validation Loss: 8.0749e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.065822
# Epoch  59:  Train Loss: 6.3619e-01,  Validation Loss: 4.7750e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.079739
# Epoch  60:  Train Loss: 3.6967e-01,  Validation Loss: 2.7004e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.094479
# Epoch  61:  Train Loss: 2.4319e-01,  Validation Loss: 1.5602e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.10987
# Epoch  62:  Train Loss: 1.0114e-01,  Validation Loss: 5.9995e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.12573
# Epoch  63:  Train Loss: 3.7228e-02,  Validation Loss: 2.0091e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.14188
# Epoch  64:  Train Loss: 1.1483e-02,  Validation Loss: 5.4537e-03,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.15812
# Epoch  65:  Train Loss: 2.8374e-03,  Validation Loss: 1.1379e-03,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.17427
# Epoch  66:  Train Loss: 5.2635e-04,  Validation Loss: 1.7262e-04,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.19013
# Epoch  67:  Train Loss: 6.9574e-05,  Validation Loss: 1.7215e-05,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.20552
# Epoch  68:  Train Loss: 6.0155e-06,  Validation Loss: 1.0512e-06,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.22026
# Epoch  69:  Train Loss: 3.1288e-07,  Validation Loss: 3.4050e-08,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.23418
# Epoch  70:  Train Loss: 8.9379e-09,  Validation Loss: 9.2442e-10,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.24711
# Epoch  71:  Train Loss: 7.6148e-10,  Validation Loss: 6.2888e-10,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.2589
# Epoch  72:  Train Loss: 5.2657e-10,  Validation Loss: 4.1062e-10,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.26941
# Epoch  73:  Train Loss: 3.5724e-10,  Validation Loss: 2.7956e-10,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.27853
# Epoch  74:  Train Loss: 2.3719e-10,  Validation Loss: 2.1290e-10,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.28614
# Epoch  75:  Train Loss: 1.7425e-10,  Validation Loss: 1.4634e-10,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.29215
# Epoch  76:  Train Loss: 1.1424e-10,  Validation Loss: 8.9995e-11,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.29649
# Epoch  77:  Train Loss: 7.8926e-11,  Validation Loss: 5.2373e-11,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.29912
# Early stopping at epoch 77 as train loss 0.000000000052 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 31.49s
# Training dimension 3...
# Epoch   1:  Train Loss: 6.3576e+02,  Validation Loss: 3.6142e+00,  Epoch Time: 0.43s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 2.5201e+00,  Validation Loss: 1.8120e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.5303e+00,  Validation Loss: 1.3441e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.1024e+00,  Validation Loss: 9.2567e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 8.7439e-01,  Validation Loss: 8.5487e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 7.3657e-01,  Validation Loss: 1.0771e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 8.1283e-01,  Validation Loss: 1.0322e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 9.1216e-01,  Validation Loss: 7.3716e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 3.8619e+00,  Validation Loss: 4.8905e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 1.6260e+01,  Validation Loss: 6.6979e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.00087931
# Epoch  11:  Train Loss: 2.2446e+00,  Validation Loss: 3.2884e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.0035069
# Epoch  12:  Train Loss: 7.0731e+00,  Validation Loss: 1.7297e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.007852
# Epoch  13:  Train Loss: 3.9367e+00,  Validation Loss: 2.0927e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.013864
# Epoch  14:  Train Loss: 6.0827e+00,  Validation Loss: 2.9756e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.021471
# Epoch  15:  Train Loss: 5.8889e+00,  Validation Loss: 5.0807e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.030586
# Epoch  16:  Train Loss: 6.5271e+00,  Validation Loss: 6.5452e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.041101
# Epoch  17:  Train Loss: 7.0350e+00,  Validation Loss: 7.0246e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.052892
# Epoch  18:  Train Loss: 7.1968e+00,  Validation Loss: 7.0877e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.065822
# Epoch  19:  Train Loss: 1.4224e+01,  Validation Loss: 1.3640e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.079739
# Epoch  20:  Train Loss: 1.3938e+01,  Validation Loss: 1.3674e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.094479
# Epoch  21:  Train Loss: 1.3870e+01,  Validation Loss: 1.3379e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.10987
# Epoch  22:  Train Loss: 1.3400e+01,  Validation Loss: 1.3067e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.12573
# Epoch  23:  Train Loss: 1.3061e+01,  Validation Loss: 1.2757e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.14188
# Epoch  24:  Train Loss: 1.3221e+01,  Validation Loss: 1.2781e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.15812
# Epoch  25:  Train Loss: 1.2822e+01,  Validation Loss: 1.2551e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.17427
# Epoch  26:  Train Loss: 1.4020e+01,  Validation Loss: 1.3503e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.19013
# Epoch  27:  Train Loss: 1.3452e+01,  Validation Loss: 1.3213e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.20552
# Epoch  28:  Train Loss: 1.3167e+01,  Validation Loss: 1.2977e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.22026
# Epoch  29:  Train Loss: 1.3035e+01,  Validation Loss: 1.2881e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.23418
# Epoch  30:  Train Loss: 1.5529e+01,  Validation Loss: 1.5052e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.24711
# Epoch  31:  Train Loss: 1.5119e+01,  Validation Loss: 1.4773e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.2589
# Epoch  32:  Train Loss: 1.4976e+01,  Validation Loss: 1.4826e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.26941
# Epoch  33:  Train Loss: 1.4918e+01,  Validation Loss: 1.4685e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.27853
# Epoch  34:  Train Loss: 1.4893e+01,  Validation Loss: 1.4747e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.28614
# Epoch  35:  Train Loss: 1.4884e+01,  Validation Loss: 1.4801e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.29215
# Epoch  36:  Train Loss: 1.4896e+01,  Validation Loss: 1.4770e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.29649
# Epoch  37:  Train Loss: 1.4868e+01,  Validation Loss: 1.4708e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.29912
# Epoch  38:  Train Loss: 1.4885e+01,  Validation Loss: 1.4715e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.3
# Epoch  39:  Train Loss: 1.4889e+01,  Validation Loss: 1.4805e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.3
# Epoch  40:  Train Loss: 1.4904e+01,  Validation Loss: 1.4672e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.3
# Epoch  41:  Train Loss: 5.8549e+02,  Validation Loss: 4.6894e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 3.0017e-01,  Validation Loss: 1.7443e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 1.2516e-01,  Validation Loss: 9.4932e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 8.1070e-02,  Validation Loss: 6.6511e-02,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 6.1281e-02,  Validation Loss: 5.4485e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 5.3345e-02,  Validation Loss: 8.2412e-02,  Epoch Time: 0.43s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 5.1255e-02,  Validation Loss: 4.4829e-02,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 6.2989e-02,  Validation Loss: 8.3882e-02,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 2.1060e+01,  Validation Loss: 3.5292e+01,  Epoch Time: 0.43s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 2.4334e+00,  Validation Loss: 5.6175e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.00087931
# Epoch  51:  Train Loss: 1.9692e+00,  Validation Loss: 4.3133e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.0035069
# Epoch  52:  Train Loss: 1.7068e+00,  Validation Loss: 1.0687e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.007852
# Epoch  53:  Train Loss: 1.3345e+00,  Validation Loss: 8.4921e-01,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.013864
# Epoch  54:  Train Loss: 1.1849e+00,  Validation Loss: 1.0237e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.021471
# Epoch  55:  Train Loss: 9.8984e-01,  Validation Loss: 8.9799e-01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.030586
# Epoch  56:  Train Loss: 1.1130e+00,  Validation Loss: 9.7026e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.041101
# Epoch  57:  Train Loss: 1.0137e+00,  Validation Loss: 8.6695e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.052892
# Epoch  58:  Train Loss: 1.0982e+00,  Validation Loss: 8.7273e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.065822
# Epoch  59:  Train Loss: 7.3928e-01,  Validation Loss: 5.8165e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.079739
# Epoch  60:  Train Loss: 7.0934e-01,  Validation Loss: 4.8683e-01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.094479
# Epoch  61:  Train Loss: 3.5169e-01,  Validation Loss: 2.3606e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.10987
# Epoch  62:  Train Loss: 1.6354e-01,  Validation Loss: 1.0404e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.12573
# Epoch  63:  Train Loss: 6.8619e-02,  Validation Loss: 4.0236e-02,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.14188
# Epoch  64:  Train Loss: 2.4873e-02,  Validation Loss: 1.3232e-02,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.15812
# Epoch  65:  Train Loss: 7.4843e-03,  Validation Loss: 3.4497e-03,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.17427
# Epoch  66:  Train Loss: 1.7726e-03,  Validation Loss: 6.8940e-04,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.19013
# Epoch  67:  Train Loss: 3.1469e-04,  Validation Loss: 9.7748e-05,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.20552
# Epoch  68:  Train Loss: 3.9027e-05,  Validation Loss: 9.0974e-06,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.22026
# Epoch  69:  Train Loss: 3.1551e-06,  Validation Loss: 5.1178e-07,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.23418
# Epoch  70:  Train Loss: 1.5197e-07,  Validation Loss: 1.6028e-08,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.24711
# Epoch  71:  Train Loss: 4.2221e-09,  Validation Loss: 9.1054e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.2589
# Epoch  72:  Train Loss: 7.4046e-10,  Validation Loss: 5.6805e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.26941
# Epoch  73:  Train Loss: 5.0315e-10,  Validation Loss: 3.9446e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.27853
# Epoch  74:  Train Loss: 3.4060e-10,  Validation Loss: 3.0010e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.28614
# Epoch  75:  Train Loss: 2.4541e-10,  Validation Loss: 1.7420e-10,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.29215
# Epoch  76:  Train Loss: 1.6088e-10,  Validation Loss: 1.3828e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.29649
# Epoch  77:  Train Loss: 1.1410e-10,  Validation Loss: 9.1737e-11,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.29912
# Epoch  78:  Train Loss: 7.9792e-11,  Validation Loss: 5.3825e-11,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.3
# Early stopping at epoch 78 as train loss 0.000000000054 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 31.07s
# Training dimension 4...
# Epoch   1:  Train Loss: 1.0203e+03,  Validation Loss: 5.4029e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 3.4412e+00,  Validation Loss: 2.3155e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.9172e+00,  Validation Loss: 1.5014e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.3166e+00,  Validation Loss: 1.1265e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 1.0502e+00,  Validation Loss: 9.2196e-01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 9.0924e-01,  Validation Loss: 7.7952e-01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 7.5622e-01,  Validation Loss: 6.5867e-01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 7.7839e-01,  Validation Loss: 6.7253e-01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 7.7173e-01,  Validation Loss: 1.5500e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 6.7254e-01,  Validation Loss: 7.8027e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.00087931
# Epoch  11:  Train Loss: 9.7748e-01,  Validation Loss: 4.2939e-01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.0035069
# Epoch  12:  Train Loss: 6.6322e+00,  Validation Loss: 1.3028e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.007852
# Epoch  13:  Train Loss: 4.7382e+00,  Validation Loss: 2.3649e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.013864
# Epoch  14:  Train Loss: 7.3896e+00,  Validation Loss: 4.1427e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.021471
# Epoch  15:  Train Loss: 7.3195e+00,  Validation Loss: 5.3012e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.030586
# Epoch  16:  Train Loss: 8.1824e+00,  Validation Loss: 7.8463e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.041101
# Epoch  17:  Train Loss: 7.8437e+00,  Validation Loss: 7.7826e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.052892
# Epoch  18:  Train Loss: 8.3542e+00,  Validation Loss: 8.2545e+00,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.065822
# Epoch  19:  Train Loss: 8.9557e+00,  Validation Loss: 8.6709e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.079739
# Epoch  20:  Train Loss: 9.8972e+00,  Validation Loss: 9.8555e+00,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.094479
# Epoch  21:  Train Loss: 9.9967e+00,  Validation Loss: 9.9435e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.10987
# Epoch  22:  Train Loss: 1.0083e+01,  Validation Loss: 9.8613e+00,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.12573
# Epoch  23:  Train Loss: 9.5751e+00,  Validation Loss: 9.5000e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.14188
# Epoch  24:  Train Loss: 9.2467e+00,  Validation Loss: 9.2252e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.15812
# Epoch  25:  Train Loss: 9.0304e+00,  Validation Loss: 9.0302e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.17427
# Epoch  26:  Train Loss: 8.8833e+00,  Validation Loss: 8.8975e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.19013
# Epoch  27:  Train Loss: 1.1300e+01,  Validation Loss: 1.1017e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.20552
# Epoch  28:  Train Loss: 1.0704e+01,  Validation Loss: 1.0589e+01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.22026
# Epoch  29:  Train Loss: 1.2882e+01,  Validation Loss: 1.2520e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.23418
# Epoch  30:  Train Loss: 1.2215e+01,  Validation Loss: 1.1995e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.24711
# Epoch  31:  Train Loss: 1.1938e+01,  Validation Loss: 1.1907e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.2589
# Epoch  32:  Train Loss: 1.1830e+01,  Validation Loss: 1.1823e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.26941
# Epoch  33:  Train Loss: 1.1790e+01,  Validation Loss: 1.1825e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.27853
# Epoch  34:  Train Loss: 1.1761e+01,  Validation Loss: 1.1769e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.28614
# Epoch  35:  Train Loss: 1.1766e+01,  Validation Loss: 1.1796e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.29215
# Epoch  36:  Train Loss: 1.1766e+01,  Validation Loss: 1.1765e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.29649
# Epoch  37:  Train Loss: 1.1765e+01,  Validation Loss: 1.1792e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.29912
# Epoch  38:  Train Loss: 1.1754e+01,  Validation Loss: 1.1752e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  39:  Train Loss: 1.1761e+01,  Validation Loss: 1.1787e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  40:  Train Loss: 1.1763e+01,  Validation Loss: 1.1719e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  41:  Train Loss: 3.6867e+02,  Validation Loss: 2.1477e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 1.2795e-01,  Validation Loss: 7.9385e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 6.1691e-02,  Validation Loss: 4.6610e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 4.2830e-02,  Validation Loss: 3.9077e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 3.5750e-02,  Validation Loss: 3.9833e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 3.8382e-02,  Validation Loss: 4.0257e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 5.1160e-02,  Validation Loss: 5.3070e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 1.2830e+01,  Validation Loss: 8.7495e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 4.3568e+01,  Validation Loss: 4.3716e+00,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 6.1911e-01,  Validation Loss: 3.9553e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.00087931
# Epoch  51:  Train Loss: 3.3299e+00,  Validation Loss: 1.6363e+00,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.0035069
# Epoch  52:  Train Loss: 1.2618e+00,  Validation Loss: 8.5353e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.007852
# Epoch  53:  Train Loss: 7.9910e-01,  Validation Loss: 6.8777e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.013864
# Epoch  54:  Train Loss: 9.0877e-01,  Validation Loss: 8.5625e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.021471
# Epoch  55:  Train Loss: 9.6893e-01,  Validation Loss: 9.0493e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.030586
# Epoch  56:  Train Loss: 8.2290e-01,  Validation Loss: 7.6536e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.041101
# Epoch  57:  Train Loss: 1.3676e+00,  Validation Loss: 1.1220e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.052892
# Epoch  58:  Train Loss: 9.2162e-01,  Validation Loss: 7.5863e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.065822
# Epoch  59:  Train Loss: 7.8211e-01,  Validation Loss: 5.7896e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.079739
# Epoch  60:  Train Loss: 4.3050e-01,  Validation Loss: 3.1224e-01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.094479
# Epoch  61:  Train Loss: 2.2590e-01,  Validation Loss: 1.5633e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.10987
# Epoch  62:  Train Loss: 1.0875e-01,  Validation Loss: 7.0773e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.12573
# Epoch  63:  Train Loss: 4.6410e-02,  Validation Loss: 2.7672e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.14188
# Epoch  64:  Train Loss: 1.7006e-02,  Validation Loss: 9.1688e-03,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.15812
# Epoch  65:  Train Loss: 5.1649e-03,  Validation Loss: 2.4292e-03,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.17427
# Epoch  66:  Train Loss: 1.2329e-03,  Validation Loss: 4.8572e-04,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.19013
# Epoch  67:  Train Loss: 2.1983e-04,  Validation Loss: 6.9175e-05,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.20552
# Epoch  68:  Train Loss: 2.7492e-05,  Validation Loss: 6.5071e-06,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.22026
# Epoch  69:  Train Loss: 2.2383e-06,  Validation Loss: 3.6880e-07,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.23418
# Epoch  70:  Train Loss: 1.0977e-07,  Validation Loss: 1.1421e-08,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.24711
# Epoch  71:  Train Loss: 3.2902e-09,  Validation Loss: 8.7545e-10,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.2589
# Epoch  72:  Train Loss: 7.1442e-10,  Validation Loss: 6.2005e-10,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.26941
# Epoch  73:  Train Loss: 4.9137e-10,  Validation Loss: 4.0063e-10,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.27853
# Epoch  74:  Train Loss: 3.2253e-10,  Validation Loss: 2.6274e-10,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.28614
# Epoch  75:  Train Loss: 2.1947e-10,  Validation Loss: 1.8006e-10,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.29215
# Epoch  76:  Train Loss: 1.5772e-10,  Validation Loss: 1.3639e-10,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.29649
# Epoch  77:  Train Loss: 1.1019e-10,  Validation Loss: 8.6125e-11,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.29912
# Epoch  78:  Train Loss: 7.2460e-11,  Validation Loss: 4.6793e-11,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Early stopping at epoch 78 as train loss 0.000000000047 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 28.49s
# Training dimension 5...
# Epoch   1:  Train Loss: 4.3881e+02,  Validation Loss: 3.4079e+00,  Epoch Time: 0.46s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 2.5444e+00,  Validation Loss: 1.8385e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.5932e+00,  Validation Loss: 1.3964e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.1940e+00,  Validation Loss: 1.0581e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 1.1438e+00,  Validation Loss: 8.5185e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 7.8860e-01,  Validation Loss: 7.6939e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 1.6178e+00,  Validation Loss: 3.0662e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 2.0548e+01,  Validation Loss: 4.2087e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 1.1827e+01,  Validation Loss: 2.8942e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 3.3701e+00,  Validation Loss: 2.5698e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.00087931
# Epoch  11:  Train Loss: 1.6252e+00,  Validation Loss: 3.9200e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.0035069
# Epoch  12:  Train Loss: 4.7650e+00,  Validation Loss: 8.9692e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.007852
# Epoch  13:  Train Loss: 4.6305e+00,  Validation Loss: 1.8560e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.013864
# Epoch  14:  Train Loss: 5.9490e+00,  Validation Loss: 2.6743e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.021471
# Epoch  15:  Train Loss: 6.4601e+00,  Validation Loss: 5.2249e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.030586
# Epoch  16:  Train Loss: 6.3145e+00,  Validation Loss: 6.1730e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.041101
# Epoch  17:  Train Loss: 9.5187e+00,  Validation Loss: 9.1150e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.052892
# Epoch  18:  Train Loss: 1.0312e+01,  Validation Loss: 9.6098e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.065822
# Epoch  19:  Train Loss: 9.6311e+00,  Validation Loss: 9.1181e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.079739
# Epoch  20:  Train Loss: 9.6365e+00,  Validation Loss: 9.1007e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.094479
# Epoch  21:  Train Loss: 9.4386e+00,  Validation Loss: 8.9200e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.10987
# Epoch  22:  Train Loss: 1.3208e+01,  Validation Loss: 1.2493e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.12573
# Epoch  23:  Train Loss: 1.3634e+01,  Validation Loss: 1.2732e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.14188
# Epoch  24:  Train Loss: 1.2639e+01,  Validation Loss: 1.2084e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.15812
# Epoch  25:  Train Loss: 1.2051e+01,  Validation Loss: 1.1623e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.17427
# Epoch  26:  Train Loss: 1.3030e+01,  Validation Loss: 1.2352e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.19013
# Epoch  27:  Train Loss: 1.2232e+01,  Validation Loss: 1.1797e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.20552
# Epoch  28:  Train Loss: 1.1790e+01,  Validation Loss: 1.1498e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.22026
# Epoch  29:  Train Loss: 1.1549e+01,  Validation Loss: 1.1333e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.23418
# Epoch  30:  Train Loss: 1.1405e+01,  Validation Loss: 1.1254e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.24711
# Epoch  31:  Train Loss: 1.1333e+01,  Validation Loss: 1.1343e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.2589
# Epoch  32:  Train Loss: 1.1303e+01,  Validation Loss: 1.1256e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.26941
# Epoch  33:  Train Loss: 1.1297e+01,  Validation Loss: 1.1210e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.27853
# Epoch  34:  Train Loss: 1.1295e+01,  Validation Loss: 1.1247e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.28614
# Epoch  35:  Train Loss: 1.1292e+01,  Validation Loss: 1.1232e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.29215
# Epoch  36:  Train Loss: 1.1301e+01,  Validation Loss: 1.1198e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.29649
# Epoch  37:  Train Loss: 1.1290e+01,  Validation Loss: 1.1199e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.29912
# Epoch  38:  Train Loss: 1.1289e+01,  Validation Loss: 1.1218e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.3
# Epoch  39:  Train Loss: 1.1288e+01,  Validation Loss: 1.1266e+01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.3
# Epoch  40:  Train Loss: 1.1300e+01,  Validation Loss: 1.1208e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.3
# Epoch  41:  Train Loss: 5.0065e+02,  Validation Loss: 3.5007e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 1.8459e-01,  Validation Loss: 9.8969e-02,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 8.0338e-02,  Validation Loss: 5.9490e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 5.6188e-02,  Validation Loss: 4.7996e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 4.4486e-02,  Validation Loss: 4.5400e-02,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 4.3318e-02,  Validation Loss: 3.4811e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 4.2222e-02,  Validation Loss: 5.9349e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 3.1739e-01,  Validation Loss: 4.6698e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 1.0549e+02,  Validation Loss: 6.1692e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 2.7319e+00,  Validation Loss: 1.7410e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.00087931
# Epoch  51:  Train Loss: 3.2038e+00,  Validation Loss: 1.6623e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.0035069
# Epoch  52:  Train Loss: 1.7818e+00,  Validation Loss: 1.3119e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.007852
# Epoch  53:  Train Loss: 1.3532e+00,  Validation Loss: 1.0329e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.013864
# Epoch  54:  Train Loss: 1.2060e+00,  Validation Loss: 8.2191e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.021471
# Epoch  55:  Train Loss: 9.9540e-01,  Validation Loss: 9.0479e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.030586
# Epoch  56:  Train Loss: 9.6121e-01,  Validation Loss: 8.8872e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.041101
# Epoch  57:  Train Loss: 8.6124e-01,  Validation Loss: 7.9015e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.052892
# Epoch  58:  Train Loss: 2.1422e+00,  Validation Loss: 1.6401e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.065822
# Epoch  59:  Train Loss: 1.3925e+00,  Validation Loss: 1.1006e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.079739
# Epoch  60:  Train Loss: 9.1847e-01,  Validation Loss: 7.1477e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.094479
# Epoch  61:  Train Loss: 5.8391e-01,  Validation Loss: 4.4152e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.10987
# Epoch  62:  Train Loss: 3.5206e-01,  Validation Loss: 2.5737e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.12573
# Epoch  63:  Train Loss: 1.9815e-01,  Validation Loss: 1.3823e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.14188
# Epoch  64:  Train Loss: 1.0207e-01,  Validation Loss: 6.7089e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.15812
# Epoch  65:  Train Loss: 4.6899e-02,  Validation Loss: 2.8496e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.17427
# Epoch  66:  Train Loss: 1.8728e-02,  Validation Loss: 1.0326e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.19013
# Epoch  67:  Train Loss: 6.2549e-03,  Validation Loss: 3.0612e-03,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.20552
# Epoch  68:  Train Loss: 1.6832e-03,  Validation Loss: 7.0395e-04,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.22026
# Epoch  69:  Train Loss: 3.4613e-04,  Validation Loss: 1.1804e-04,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.23418
# Epoch  70:  Train Loss: 5.1515e-05,  Validation Loss: 1.3577e-05,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.24711
# Epoch  71:  Train Loss: 5.1687e-06,  Validation Loss: 9.9531e-07,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.2589
# Epoch  72:  Train Loss: 3.2323e-07,  Validation Loss: 4.1240e-08,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.26941
# Epoch  73:  Train Loss: 1.1785e-08,  Validation Loss: 9.4778e-10,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.27853
# Epoch  74:  Train Loss: 8.1806e-10,  Validation Loss: 6.7201e-10,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.28614
# Epoch  75:  Train Loss: 5.6276e-10,  Validation Loss: 4.2192e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.29215
# Epoch  76:  Train Loss: 3.7656e-10,  Validation Loss: 2.9216e-10,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.29649
# Epoch  77:  Train Loss: 2.6609e-10,  Validation Loss: 2.1538e-10,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.29912
# Epoch  78:  Train Loss: 1.8124e-10,  Validation Loss: 1.5038e-10,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.3
# Epoch  79:  Train Loss: 1.2695e-10,  Validation Loss: 9.9949e-11,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.3
# Epoch  80:  Train Loss: 8.7592e-11,  Validation Loss: 6.8371e-11,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.3
# Early stopping at epoch 80 as train loss 0.000000000068 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 31.74s
# ...
# Epoch  23:  Train Loss: 8.8757e+00,  Validation Loss: 8.5982e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.14188
# Epoch  24:  Train Loss: 9.4330e+00,  Validation Loss: 8.9460e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.15812
# Epoch  25:  Train Loss: 9.0053e+00,  Validation Loss: 8.5570e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.17427
# Epoch  26:  Train Loss: 8.5714e+00,  Validation Loss: 8.2740e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.19013
# Epoch  27:  Train Loss: 8.3374e+00,  Validation Loss: 8.1025e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.20552
# Epoch  28:  Train Loss: 8.1985e+00,  Validation Loss: 7.9895e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.22026
# Epoch  29:  Train Loss: 1.0859e+01,  Validation Loss: 1.0377e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.23418
# Epoch  30:  Train Loss: 1.0323e+01,  Validation Loss: 1.0023e+01,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.24711
# Epoch  31:  Train Loss: 1.0126e+01,  Validation Loss: 9.9261e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.2589
# Epoch  32:  Train Loss: 1.0053e+01,  Validation Loss: 9.8820e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.26941
# Epoch  33:  Train Loss: 1.0011e+01,  Validation Loss: 9.8740e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.27853
# Epoch  34:  Train Loss: 1.0017e+01,  Validation Loss: 9.8436e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.28614
# Epoch  35:  Train Loss: 1.0005e+01,  Validation Loss: 9.8474e+00,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.29215
# Epoch  36:  Train Loss: 1.0004e+01,  Validation Loss: 9.8882e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.29649
# Epoch  37:  Train Loss: 1.0005e+01,  Validation Loss: 9.8801e+00,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.29912
# Epoch  38:  Train Loss: 1.0013e+01,  Validation Loss: 9.8319e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  39:  Train Loss: 9.9980e+00,  Validation Loss: 9.8668e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  40:  Train Loss: 1.0004e+01,  Validation Loss: 9.9059e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  41:  Train Loss: 7.5609e+02,  Validation Loss: 5.5310e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 2.8220e-01,  Validation Loss: 1.4299e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 1.0542e-01,  Validation Loss: 8.2320e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 6.5895e-02,  Validation Loss: 5.6401e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 5.0290e-02,  Validation Loss: 4.5130e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 4.1454e-02,  Validation Loss: 4.4122e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 3.6592e-02,  Validation Loss: 3.1212e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 3.1398e-02,  Validation Loss: 3.0507e-02,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 3.7870e-02,  Validation Loss: 7.6479e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 1.9562e-01,  Validation Loss: 2.2457e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.00087931
# Epoch  51:  Train Loss: 2.2211e+00,  Validation Loss: 1.1745e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.0035069
# Epoch  52:  Train Loss: 1.1045e+00,  Validation Loss: 8.2180e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.007852
# Epoch  53:  Train Loss: 9.9743e-01,  Validation Loss: 7.5184e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.013864
# Epoch  54:  Train Loss: 7.0943e-01,  Validation Loss: 6.5258e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.021471
# Epoch  55:  Train Loss: 1.1217e+00,  Validation Loss: 1.0113e+00,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.030586
# Epoch  56:  Train Loss: 9.1280e-01,  Validation Loss: 8.3029e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.041101
# Epoch  57:  Train Loss: 1.3370e+00,  Validation Loss: 1.0539e+00,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.052892
# Epoch  58:  Train Loss: 8.8403e-01,  Validation Loss: 7.0355e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.065822
# Epoch  59:  Train Loss: 7.2739e-01,  Validation Loss: 5.3632e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.079739
# Epoch  60:  Train Loss: 4.0113e-01,  Validation Loss: 2.8855e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.094479
# Epoch  61:  Train Loss: 2.1025e-01,  Validation Loss: 1.4445e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.10987
# Epoch  62:  Train Loss: 1.0122e-01,  Validation Loss: 6.5625e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.12573
# Epoch  63:  Train Loss: 4.3273e-02,  Validation Loss: 2.5768e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.14188
# Epoch  64:  Train Loss: 1.5914e-02,  Validation Loss: 8.5497e-03,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.15812
# Epoch  65:  Train Loss: 4.8338e-03,  Validation Loss: 2.2621e-03,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.17427
# Epoch  66:  Train Loss: 1.1561e-03,  Validation Loss: 4.5268e-04,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.19013
# Epoch  67:  Train Loss: 2.0741e-04,  Validation Loss: 6.4885e-05,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.20552
# Epoch  68:  Train Loss: 2.6143e-05,  Validation Loss: 6.2056e-06,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.22026
# Epoch  69:  Train Loss: 2.1530e-06,  Validation Loss: 3.6112e-07,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.23418
# Epoch  70:  Train Loss: 1.0507e-07,  Validation Loss: 1.0479e-08,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.24711
# Epoch  71:  Train Loss: 3.0219e-09,  Validation Loss: 7.7886e-10,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.2589
# Epoch  72:  Train Loss: 6.6044e-10,  Validation Loss: 5.4723e-10,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.26941
# Epoch  73:  Train Loss: 4.4947e-10,  Validation Loss: 3.4108e-10,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.27853
# Epoch  74:  Train Loss: 2.9687e-10,  Validation Loss: 2.4919e-10,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.28614
# Epoch  75:  Train Loss: 2.1101e-10,  Validation Loss: 1.6614e-10,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.29215
# Epoch  76:  Train Loss: 1.4364e-10,  Validation Loss: 1.2102e-10,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.29649
# Epoch  77:  Train Loss: 9.8740e-11,  Validation Loss: 7.8682e-11,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.29912
# Early stopping at epoch 77 as train loss 0.000000000079 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 29.49s
# Training dimension 100...
# Epoch   1:  Train Loss: 8.4978e+02,  Validation Loss: 3.0244e+00,  Epoch Time: 0.44s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 2.1888e+00,  Validation Loss: 1.7643e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.3820e+00,  Validation Loss: 1.1872e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.0319e+00,  Validation Loss: 9.6695e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 8.1071e-01,  Validation Loss: 7.5767e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 6.9570e-01,  Validation Loss: 5.9665e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 5.7759e-01,  Validation Loss: 5.5833e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 5.9486e-01,  Validation Loss: 5.6611e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 3.5078e+00,  Validation Loss: 1.4157e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 4.9362e+00,  Validation Loss: 6.3758e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.00087931
# Epoch  11:  Train Loss: 4.2112e+00,  Validation Loss: 3.8158e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.0035069
# Epoch  12:  Train Loss: 7.0181e+00,  Validation Loss: 1.8278e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.007852
# Epoch  13:  Train Loss: 3.8679e+00,  Validation Loss: 2.2328e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.013864
# Epoch  14:  Train Loss: 5.3114e+00,  Validation Loss: 2.9146e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.021471
# Epoch  15:  Train Loss: 4.7652e+00,  Validation Loss: 3.1486e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.030586
# Epoch  16:  Train Loss: 4.3683e+00,  Validation Loss: 4.1940e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.041101
# Epoch  17:  Train Loss: 6.1484e+00,  Validation Loss: 5.8249e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.052892
# Epoch  18:  Train Loss: 6.1028e+00,  Validation Loss: 5.8697e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.065822
# Epoch  19:  Train Loss: 5.4826e+00,  Validation Loss: 5.3005e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.079739
# Epoch  20:  Train Loss: 5.7265e+00,  Validation Loss: 5.3979e+00,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.094479
# Epoch  21:  Train Loss: 5.0294e+00,  Validation Loss: 4.7978e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.10987
# Epoch  22:  Train Loss: 6.4834e+00,  Validation Loss: 5.8197e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.12573
# Epoch  23:  Train Loss: 6.0305e+00,  Validation Loss: 5.4828e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.14188
# Epoch  24:  Train Loss: 5.1227e+00,  Validation Loss: 4.6892e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.15812
# Epoch  25:  Train Loss: 4.3652e+00,  Validation Loss: 3.9820e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.17427
# Epoch  26:  Train Loss: 5.1767e+00,  Validation Loss: 4.5064e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.19013
# Epoch  27:  Train Loss: 4.1083e+00,  Validation Loss: 3.5990e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.20552
# Epoch  28:  Train Loss: 5.2672e+00,  Validation Loss: 4.3721e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.22026
# Epoch  29:  Train Loss: 3.8050e+00,  Validation Loss: 3.1860e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.23418
# Epoch  30:  Train Loss: 2.8074e+00,  Validation Loss: 2.3407e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.24711
# Epoch  31:  Train Loss: 2.0554e+00,  Validation Loss: 1.6914e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.2589
# Epoch  32:  Train Loss: 1.4744e+00,  Validation Loss: 1.2026e+00,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.26941
# Epoch  33:  Train Loss: 1.0269e+00,  Validation Loss: 8.2145e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.27853
# Epoch  34:  Train Loss: 6.8898e-01,  Validation Loss: 5.4306e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.28614
# Epoch  35:  Train Loss: 4.4165e-01,  Validation Loss: 3.3492e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.29215
# Epoch  36:  Train Loss: 2.6573e-01,  Validation Loss: 1.9325e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.29649
# Epoch  37:  Train Loss: 1.4823e-01,  Validation Loss: 1.0345e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.29912
# Epoch  38:  Train Loss: 7.4960e-02,  Validation Loss: 4.8836e-02,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.3
# Epoch  39:  Train Loss: 3.3641e-02,  Validation Loss: 2.0155e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.3
# Epoch  40:  Train Loss: 1.3001e-02,  Validation Loss: 7.0659e-03,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.3
# Epoch  41:  Train Loss: 1.0634e+03,  Validation Loss: 5.9890e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 2.6506e-01,  Validation Loss: 9.5463e-02,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 5.9488e-02,  Validation Loss: 3.6808e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 2.4478e-02,  Validation Loss: 1.8396e-02,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 1.2898e-02,  Validation Loss: 1.3199e-02,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 8.4551e-03,  Validation Loss: 6.0663e-03,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 4.5230e-03,  Validation Loss: 2.8499e-03,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 4.2122e-03,  Validation Loss: 2.8773e-03,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 2.5890e-03,  Validation Loss: 1.6971e-03,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 1.1105e-02,  Validation Loss: 9.6867e-03,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.00087931
# Epoch  51:  Train Loss: 6.1673e-03,  Validation Loss: 5.3321e-03,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.0035069
# Epoch  52:  Train Loss: 4.8986e-03,  Validation Loss: 4.2637e-03,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.007852
# Epoch  53:  Train Loss: 3.8320e-03,  Validation Loss: 3.2375e-03,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.013864
# Epoch  54:  Train Loss: 2.8479e-03,  Validation Loss: 2.3419e-03,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.021471
# Epoch  55:  Train Loss: 1.9934e-03,  Validation Loss: 1.5776e-03,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.030586
# Epoch  56:  Train Loss: 1.2962e-03,  Validation Loss: 9.7770e-04,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.041101
# Epoch  57:  Train Loss: 7.7118e-04,  Validation Loss: 5.5265e-04,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.052892
# Epoch  58:  Train Loss: 4.1282e-04,  Validation Loss: 2.7531e-04,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.065822
# Epoch  59:  Train Loss: 1.9420e-04,  Validation Loss: 1.1941e-04,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.079739
# Epoch  60:  Train Loss: 7.8439e-05,  Validation Loss: 4.3606e-05,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.094479
# Epoch  61:  Train Loss: 2.6196e-05,  Validation Loss: 1.2752e-05,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.10987
# Epoch  62:  Train Loss: 6.9971e-06,  Validation Loss: 2.9018e-06,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.12573
# Epoch  63:  Train Loss: 1.4138e-06,  Validation Loss: 4.7148e-07,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.14188
# Epoch  64:  Train Loss: 2.0143e-07,  Validation Loss: 5.3730e-08,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.15812
# Epoch  65:  Train Loss: 2.0413e-08,  Validation Loss: 3.8779e-09,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.17427
# Epoch  66:  Train Loss: 1.7756e-09,  Validation Loss: 1.2927e-09,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.19013
# Epoch  67:  Train Loss: 1.1638e-09,  Validation Loss: 9.3282e-10,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.20552
# Epoch  68:  Train Loss: 7.7594e-10,  Validation Loss: 6.4422e-10,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.22026
# Epoch  69:  Train Loss: 5.3421e-10,  Validation Loss: 4.2077e-10,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.23418
# Epoch  70:  Train Loss: 3.6151e-10,  Validation Loss: 2.7726e-10,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.24711
# Epoch  71:  Train Loss: 2.5069e-10,  Validation Loss: 1.9242e-10,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.2589
# Epoch  72:  Train Loss: 1.7172e-10,  Validation Loss: 1.2937e-10,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.26941
# Epoch  73:  Train Loss: 1.1706e-10,  Validation Loss: 9.2398e-11,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.27853
# Epoch  74:  Train Loss: 8.2372e-11,  Validation Loss: 6.3406e-11,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.28614
# Early stopping at epoch 74 as train loss 0.000000000063 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 28.96s

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_set_labels(N):
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
def coefficient_reconstruction(dim_index,
                                weights, 
                                minimum_coefficient_threshold = 1e-5,
                                coefficient_output_digits = 10, 
                                enable_coefficient_sorting = False):
    
    max_neurons = max(max(len(layer) for layer in SREINet) for SREINet in weights)
    
    labels = generate_set_labels(max_neurons - 1) # number of states = number of neurons - 1

    def explore_path(SREINet_index, layer, neuron, weight_product, label_counts, non_zero_paths):
        """
        Recursively explores non-zero paths in a neural network.
        """
        if layer == len(weights[SREINet_index]) - 1:
            non_zero_paths.append((label_counts, weight_product))
            return

        for next_neuron, weight in enumerate(weights[SREINet_index][layer][neuron]):
            if abs(weight) <= 1e-15:
                # Skip recursion if the weight is zero (if one weight is zero, the whole path will be eliminated)
                continue  
            new_weight_product = weight_product * weight
            next_label_counts = label_counts.copy()
            next_label_counts[labels[next_neuron]] = next_label_counts.get(labels[next_neuron], 0) + 1
            explore_path(SREINet_index, layer + 1, next_neuron, new_weight_product, next_label_counts, non_zero_paths)
    
    #beginning of the algorithm
    all_SREINet_products = []
    for SREINet_index, _ in enumerate(weights):
        non_zero_paths = []
        #collect all non-zero paths
        for neuron_index in range(len(weights[SREINet_index][0])):
            label_counts = {labels[neuron_index]: 1}
            explore_path(SREINet_index, 0, neuron_index, 1, label_counts, non_zero_paths)
        
        #sum up the products with identical composite nonlinear/linear terms
        SREINet_products = {}
        for label_counts, weight_product in non_zero_paths:
            label_counts_key = frozenset(label_counts.items())
            if label_counts_key in SREINet_products:
                SREINet_products[label_counts_key] += weight_product
            else:
                SREINet_products[label_counts_key] = weight_product
        
        #remove the negligible composite terms
        SREINet_products = {k: v for k, v in SREINet_products.items() if abs(v) >= minimum_coefficient_threshold}
        
        if enable_coefficient_sorting:
            #sort the composite terms by their absolute values
            sorted_SREINet_products = dict(sorted(SREINet_products.items(), key=lambda item: abs(item[1]), reverse=True))
        else:
            sorted_SREINet_products = SREINet_products

        all_SREINet_products.append(sorted_SREINet_products)

    #output formatting
    labeled_all_SREINet_products = []
    for SREINet_index, sorted_SREINet_products in enumerate(all_SREINet_products):
        SREINet_product_strings = []
        for key, value in sorted_SREINet_products.items():
            labels_list = []
            only_constant = len(key) == 1 and any(label == 'Constant' for label, _ in key)
            
            for label, count in sorted(key):
                if label == 'Constant' and len(key) > 1:
                    continue
                if label != 'Constant' and count > 1:
                    labels_list.append(f"{label}^{count}")
                elif label == 'Constant' or count == 1:
                    labels_list.append(label if label != 'Constant' else '')
            
            label_str = '*'.join(filter(None, labels_list))
                        
            # Apply coefficient threshold if enabled
            formatted_value = f"{abs(value):.{coefficient_output_digits}g}"

            term_str = label_str if formatted_value == '1' else f"{formatted_value}*{label_str}" if not only_constant else formatted_value if formatted_value != '1' else ''
            sign = '+' if value >= 0 else '-'
            if SREINet_product_strings or value < 0:
                term_str = f" {sign} {term_str}"
            else:
                term_str = term_str
            SREINet_product_strings.append(term_str)

        formatted_output = ''.join(SREINet_product_strings)
        layer_prefix = f"(x{SREINet_index+dim_index+1})'= "
        full_output = layer_prefix + formatted_output
        labeled_all_SREINet_products.append(full_output)

    return labeled_all_SREINet_products

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
for i in range(len(weights_list)):
    path_products = coefficient_reconstruction(i,weights_list[i], 
                                            minimum_coefficient_threshold = 0,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
# Out:
# (x1)'= 7.999989033 - 0.9999986291*x1 + 1.00000003*x100*x2 - 0.9999997318*x100*x99
# (x2)'= 7.99999094 - 0.9999988079*x2 + 0.9999998808*x1*x3 - 0.9999997914*x1*x100
# (x3)'= 7.99999094 - 0.9999989271*x3 - 0.9999999106*x1*x2 + 0.9999999404*x2*x4
# (x4)'= 7.999991417 - 0.9999990761*x4 - 0.9999998212*x2*x3 + x3*x5
# (x5)'= 7.999989033 - 0.9999985397*x5 - 0.9999997914*x3*x4 + 0.9999999702*x4*x6
# (x6)'= 7.999989033 - 0.9999987483*x6 - 0.9999997616*x4*x5 + 0.9999998212*x5*x7
# (x7)'= 7.99998951 - 0.9999987185*x7 - 0.9999996424*x5*x6 + 0.999999851*x6*x8
# (x8)'= 7.999989033 - 0.9999987185*x8 - 0.999999851*x6*x7 + 1.00000006*x7*x9
# (x9)'= 7.99998951 - 0.9999988079*x9 - 0.9999997318*x7*x8 + 0.999999851*x10*x8
# (x10)'= 7.999989986 - 0.9999987483*x10 - 0.9999999106*x8*x9 + x11*x9
# (x11)'= 7.999988079 - 0.9999985993*x11 - 0.9999998808*x10*x9 + 1.000000119*x10*x12
# (x12)'= 7.99998951 - 0.9999984205*x12 - 0.999999702*x10*x11 + 0.9999996722*x11*x13
# (x13)'= 7.999990463 - 0.9999990463*x13 - 0.9999997914*x11*x12 + 0.9999999702*x12*x14
# (x14)'= 7.999989986 - 0.9999987483*x14 - 0.999999851*x12*x13 + 0.9999999404*x13*x15
# (x15)'= 7.99998951 - 0.9999987483*x15 - 0.9999997318*x13*x14 + x14*x16
# (x16)'= 7.999989033 - 0.9999985099*x16 - 0.9999997616*x14*x15 + x15*x17
# (x17)'= 7.999988556 - 0.9999985397*x17 - 0.9999998212*x15*x16 + x16*x18
# (x18)'= 7.999989033 - 0.9999986291*x18 - 0.999999553*x16*x17 + 0.999999851*x17*x19
# (x19)'= 7.999989033 - 0.9999987185*x19 - 0.9999997616*x17*x18 + 1.00000006*x18*x20
# (x20)'= 7.999989033 - 0.9999985695*x20 - 0.9999998212*x18*x19 + 0.9999999702*x19*x21
# (x21)'= 7.99998951 - 0.9999986887*x21 - 0.999999851*x19*x20 + 0.9999999404*x20*x22
# (x22)'= 7.99998951 - 0.9999988675*x22 - 0.9999997616*x20*x21 + 0.9999999106*x21*x23
# (x23)'= 7.999989033 - 0.9999985099*x23 - 0.9999997914*x21*x22 + 0.9999999106*x22*x24
# (x24)'= 7.99998951 - 0.9999986589*x24 - 0.999999851*x22*x23 + 0.999999702*x23*x25
# (x25)'= 7.999990463 - 0.9999986887*x25 - 0.9999997318*x23*x24 + 0.9999999106*x24*x26
# (x26)'= 7.99998951 - 0.9999990165*x26 - 0.999999851*x24*x25 + 1.00000003*x25*x27
# (x27)'= 7.999989986 - 0.9999987185*x27 - 0.9999999106*x25*x26 + 0.9999998212*x26*x28
# (x28)'= 7.999988556 - 0.9999984503*x28 - 0.9999997616*x26*x27 + 0.9999997914*x27*x29
# (x29)'= 7.999989986 - 0.9999990165*x29 - 0.9999998808*x27*x28 + 0.9999998808*x28*x30
# (x30)'= 7.999990463 - 0.9999987483*x30 - 0.9999998808*x28*x29 + 0.9999999106*x29*x31
# (x31)'= 7.999989986 - 0.9999988377*x31 - 0.9999999106*x29*x30 + 0.9999998212*x30*x32
# (x32)'= 7.99998951 - 0.9999987781*x32 - 0.9999997616*x30*x31 + 1.00000006*x31*x33
# (x33)'= 7.999987602 - 0.9999982715*x33 - 0.9999997318*x31*x32 + 1.000000089*x32*x34
# (x34)'= 7.99998951 - 0.9999986291*x34 - 0.9999997914*x32*x33 + 0.9999999404*x33*x35
# (x35)'= 7.999989033 - 0.9999988079*x35 - 0.9999997616*x33*x34 + 0.9999999702*x34*x36
# (x36)'= 7.99998951 - 0.9999985695*x36 - 0.9999997318*x34*x35 + 0.9999999106*x35*x37
# (x37)'= 7.99998951 - 0.9999986887*x37 - 0.999999702*x35*x36 + 0.9999999106*x36*x38
# (x38)'= 7.999988556 - 0.9999985695*x38 - 0.9999999106*x36*x37 + 0.9999999106*x37*x39
# (x39)'= 7.999988556 - 0.9999986291*x39 - 0.9999997616*x37*x38 + 0.9999999702*x38*x40
# (x40)'= 7.99998951 - 0.9999984801*x40 - 0.9999997914*x38*x39 + 0.9999999106*x39*x41
# (x41)'= 7.99998951 - 0.9999987781*x41 - 0.9999997914*x39*x40 + 0.9999999702*x40*x42
# (x42)'= 7.999989033 - 0.9999986887*x42 - 0.9999996722*x40*x41 + 1.00000003*x41*x43
# (x43)'= 7.999989033 - 0.9999985099*x43 - 0.9999997914*x41*x42 + 0.9999999404*x42*x44
# (x44)'= 7.99998951 - 0.9999986887*x44 - 0.9999997914*x42*x43 + 0.9999999404*x43*x45
# (x45)'= 7.999988079 - 0.9999986589*x45 - 0.9999997318*x43*x44 + x44*x46
# (x46)'= 7.99998951 - 0.9999987483*x46 - 0.9999997914*x44*x45 + 0.9999999106*x45*x47
# (x47)'= 7.99998951 - 0.9999988377*x47 - 0.9999997914*x45*x46 + 0.999999851*x46*x48
# (x48)'= 7.99998951 - 0.9999987781*x48 - 0.9999997914*x46*x47 + 0.9999998808*x47*x49
# (x49)'= 7.999988556 - 0.9999986589*x49 - 0.999999702*x47*x48 + x48*x50
# (x50)'= 7.99999094 - 0.9999987483*x50 - 0.9999997616*x48*x49 + 1.000000149*x49*x51
# (x51)'= 7.99998951 - 0.9999986291*x51 - 0.9999997318*x49*x50 + 1.00000006*x50*x52
# (x52)'= 7.99998951 - 0.9999987483*x52 - 0.9999997616*x50*x51 + 0.9999999702*x51*x53
# (x53)'= 7.999989033 - 0.9999987483*x53 - 0.9999996722*x51*x52 + 0.9999997914*x52*x54
# (x54)'= 7.999989986 - 0.9999988079*x54 - 0.9999998212*x52*x53 + 1.000000119*x53*x55
# (x55)'= 7.999989033 - 0.9999984503*x55 - 0.9999997914*x53*x54 + 1.00000006*x54*x56
# (x56)'= 7.999990463 - 0.9999988377*x56 - 0.999999851*x54*x55 + x55*x57
# (x57)'= 7.999989033 - 0.9999986589*x57 - 0.9999998808*x55*x56 + 1.00000003*x56*x58
# (x58)'= 7.999989033 - 0.9999986887*x58 - 0.9999996424*x56*x57 + 0.9999998212*x57*x59
# (x59)'= 7.999988556 - 0.9999987185*x59 - 0.999999851*x57*x58 + 0.9999998808*x58*x60
# (x60)'= 7.999990463 - 0.9999987483*x60 - 0.999999851*x58*x59 + 1.00000003*x59*x61
# (x61)'= 7.999988556 - 0.9999986291*x61 - 0.9999997318*x59*x60 + 0.9999997318*x60*x62
# (x62)'= 7.99998951 - 0.9999986589*x62 - 0.9999998212*x60*x61 + 0.9999999404*x61*x63
# (x63)'= 7.999988079 - 0.9999987483*x63 - 0.9999999404*x61*x62 + 0.9999998808*x62*x64
# (x64)'= 7.999990463 - 0.9999989271*x64 - 0.9999998212*x62*x63 + 0.9999999404*x63*x65
# (x65)'= 7.999989033 - 0.9999985695*x65 - 0.9999997914*x63*x64 + 1.000000238*x64*x66
# (x66)'= 7.999988556 - 0.9999986887*x66 - 0.9999998212*x64*x65 + 0.9999999404*x65*x67
# (x67)'= 7.999989033 - 0.9999984503*x67 - 0.999999851*x65*x66 + x66*x68
# (x68)'= 7.999988556 - 0.9999985993*x68 - 0.9999997914*x66*x67 + 0.9999999702*x67*x69
# (x69)'= 7.999989986 - 0.9999987185*x69 - 0.9999998212*x67*x68 + 1.00000003*x68*x70
# (x70)'= 7.999988556 - 0.9999987781*x70 - 0.9999997616*x68*x69 + 0.9999998808*x69*x71
# (x71)'= 7.999988079 - 0.9999982715*x71 - 0.9999996126*x69*x70 + 0.9999999702*x70*x72
# (x72)'= 7.999988556 - 0.9999988675*x72 - 0.999999851*x70*x71 + 0.9999999702*x71*x73
# (x73)'= 7.99999094 - 0.9999989867*x73 - 0.9999997914*x71*x72 + x72*x74
# (x74)'= 7.999988556 - 0.9999985099*x74 - 0.9999999404*x72*x73 + 1.000000089*x73*x75
# (x75)'= 7.999990463 - 0.9999989569*x75 - 0.999999702*x73*x74 + 1.00000003*x74*x76
# (x76)'= 7.999990463 - 0.9999988973*x76 - 0.9999999106*x74*x75 + 0.9999999404*x75*x77
# (x77)'= 7.99999094 - 0.9999989271*x77 - 0.9999999404*x75*x76 + 1.00000003*x76*x78
# (x78)'= 7.99998951 - 0.9999987483*x78 - 0.999999851*x76*x77 + 0.9999999404*x77*x79
# (x79)'= 7.99998951 - 0.9999987483*x79 - 0.9999997616*x77*x78 + 1.000000089*x78*x80
# (x80)'= 7.999988556 - 0.9999983609*x80 - 0.9999998808*x78*x79 + 0.9999999702*x79*x81
# (x81)'= 7.99998951 - 0.9999988675*x81 - x79*x80 + 0.9999999404*x80*x82
# (x82)'= 7.999989986 - 0.9999988973*x82 - 0.9999997616*x80*x81 + x81*x83
# (x83)'= 7.999989986 - 0.9999987185*x83 - 0.9999998212*x81*x82 + 0.9999997616*x82*x84
# (x84)'= 7.999988079 - 0.9999986887*x84 - 0.999999702*x82*x83 + 0.9999999404*x83*x85
# (x85)'= 7.99998951 - 0.9999988079*x85 - 0.9999998212*x83*x84 + 0.9999998212*x84*x86
# (x86)'= 7.999988556 - 0.9999988675*x86 - 0.9999997616*x84*x85 + 0.9999999404*x85*x87
# (x87)'= 7.999989986 - 0.9999986887*x87 - 0.9999998808*x85*x86 + 0.9999999404*x86*x88
# (x88)'= 7.999990463 - 0.9999987185*x88 - 0.9999998212*x86*x87 + 0.9999999404*x87*x89
# (x89)'= 7.999989033 - 0.9999987185*x89 - 0.9999997914*x87*x88 + 1.00000006*x88*x90
# (x90)'= 7.999990463 - 0.9999988675*x90 - 0.9999997914*x88*x89 + 0.9999999106*x89*x91
# (x91)'= 7.999989986 - 0.9999986291*x91 - 0.9999997318*x89*x90 + 1.00000003*x90*x92
# (x92)'= 7.999989033 - 0.9999986291*x92 - 0.9999997616*x90*x91 + 0.9999999404*x91*x93
# (x93)'= 7.999988556 - 0.9999988079*x93 - 0.999999851*x91*x92 + 0.9999999702*x92*x94
# (x94)'= 7.999989986 - 0.9999986887*x94 - 0.9999997914*x92*x93 + 1.000000119*x93*x95
# (x95)'= 7.99998951 - 0.9999986291*x95 - 0.9999999106*x93*x94 + 0.9999998212*x94*x96
# (x96)'= 7.999988079 - 0.9999986291*x96 - 0.9999996424*x94*x95 + 0.9999999702*x95*x97
# (x97)'= 7.999990463 - 0.9999987483*x97 - 0.9999998808*x95*x96 + 0.9999998808*x96*x98
# (x98)'= 7.999988079 - 0.9999984205*x98 - 0.9999998808*x96*x97 + 0.9999999702*x97*x99
# (x99)'= 7.999988556 - 0.9999984205*x99 - 0.999999702*x97*x98 + 0.999999702*x100*x98
# (x100)'= 7.99998951 - 0.9999986291*x100 + 0.9999999404*x1*x99 - 0.9999998808*x98*x99

# %% [markdown]
# ### **Validation**

# %%
import matplotlib.pyplot as plt

# validation: need to draw the output of each dimension independently
dim_to_plot = 1
index = dim_to_plot - 1

#Form NN predictions
NN_output = np.zeros((dx_train.shape[0], dx_train.shape[1]))
for i, weight in enumerate(weights_list):
    model.get_layer('SREINet').set_weights(weight[0])
    output = model.predict(training_input_for_sim)
    NN_output[:,i:i+1] = output


#validate the first trajoctory if there are many
plt.plot(t_arr, NN_output[:,index][:t_arr.shape[0]], 'r', label='NN Prediction')
plt.plot(t_arr, dx_train[:,index][:t_arr.shape[0]], 'k', label='Expected Output')


#pick the last point of the simulation output and use it as the initial condition for the next simulation
x0 = x_train[:t_arr.shape[0]][-1]
t0= t_arr[-1]
myDG = DG.DataGenerator(x0,T=data_T+t0, dt=data_dt, t0=t0)
new_t_arr, new_x, new_dx, guess_highest_order_polynomial = myDG.generate_dataset_by_model_name(MY_MODEL)

new_input = new_x

new_NN_output= np.zeros((new_dx.shape[0], new_dx.shape[1]))
for i, weight in enumerate(weights_list):
    model.get_layer('SREINet').set_weights(weight[0])
    output = model.predict(new_input)
    new_NN_output[:,i:i+1] = output


#new_NN_output = model.predict(new_input)
plt.plot(new_t_arr, new_NN_output[:,index], "r--", label='NN Prediction')
plt.plot(new_t_arr, new_dx[:,index], "k--", label='Expected Output')
plt.title("Response of dimension " + str(dim_to_plot))
plt.show()
# Out:
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 189us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 173us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 173us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 174us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 190us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 189us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 176us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 313/313 [==============================] - 0s 182us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 182us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 182us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 181us/step
# 313/313 [==============================] - 0s 179us/step

# %% [markdown]
# ## **VI. Output**

# %%
#save data
#NN configurations -> #NN layers, #NN neurons
#data configurations -> #data points, #data dimensions
#optimizer configurations -> #learning rate, #decay rate
#training configurations -> #NN training epochs, callbacks
#record loss values
#save the info into a spreadsheet

import pandas as pd

df = pd.DataFrame({
    'ODE model': [MY_MODEL],
    'data initial conditions': [data_initial_conditions],
    'data length (T)': [data_T],
    'data resolution (dt)': [data_dt],
    'learning rate': [learning_rate],
    'Guess highest-order polynomial': [guess_highest_order_polynomial],
    'input dimension': [x_train.shape[1]],
    'mini_batch_size': [MINI_BATCH_SIZE],
    'Layer Neurons per activation fns': [layer_neuron_nums_per_act_fn],
    'Data Points': [training_input.shape[0]],
    'loss function': [LOSS_FUNCTION],
    'Total Training Epochs': [NUM_EPOCHS],
    'last lost value': [history['loss'][-1]],
    'weight threshold for pruning': [PRUNING_WEIGHT_THRESHOLD],
    'loss threshold for early stopping': [EARLY_STOPPING_LOSS_THRESHOLD],
})

# %%
#write df to the first sheet of the excel file
#write to folder named data

opt_folder = 'output'
# Create the folder if it doesn't exist
os.makedirs(opt_folder, exist_ok=True)

with pd.ExcelWriter(os.path.join(opt_folder,'nn_configurations.xlsx')) as writer:

    df.to_excel(writer, sheet_name='configuration', index=False)

    #save the loss and validation history to the second sheet of the excel file
    df2 = pd.DataFrame(history)
    df2.to_excel(writer, sheet_name='loss_history', index=False)

    #save reconstructed weights to the third sheet of the excel file

    df3 = []

    for i in range(len(weights_list)):
        path_products = coefficient_reconstruction(i,
                                                    weights_list[i], 
                                                    minimum_coefficient_threshold = 1e-4,
                                                    coefficient_output_digits = 10, 
                                                    enable_coefficient_sorting = False)


        # Convert path_products to a DataFrame
        temp_df = pd.DataFrame(path_products)

        # Append temp_df to df3
        df3.append(temp_df)

    df3 = pd.concat(df3, ignore_index=True)
    df3.to_excel(writer, sheet_name='reconstructed_weights', index=False)

# %%
from scipy.io import savemat
#concatenate t_arr, x_train, dx_train, and NN_output and save it as a mat file

#pate t_arr such that it has the same shape as x_train, dx_train, and NN_output
tem_t_arr = t_arr
for i in range(num_traj-1):
    tem_t_arr = np.concatenate((tem_t_arr, t_arr), axis=0) 
t_arr = tem_t_arr

m_data = np.concatenate((t_arr, x_train, dx_train, NN_output), axis=1)
savemat(os.path.join(opt_folder,'train_data.mat'), {'data': m_data})

v_data = np.concatenate((new_t_arr, new_x, new_dx, new_NN_output), axis=1)
savemat(os.path.join(opt_folder,'validation_data.mat'), {'data': v_data})
