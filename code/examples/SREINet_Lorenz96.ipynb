# %% [markdown]
# ## **Lorenz 96 Model Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_MODEL = 'Lorenz_96' 
MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)  

# Generate data based on the specified model type
LORENZ96_DIM = 100  #set up the dimension of the Lorenz 96 model

num_traj = 6
data_initial_conditions = DG.DataGenerator.generate_initial_conditions(LORENZ96_DIM, num_traj, seed=42) #np.random.normal(1, 2, LORENZ96_DIM

data_T =  10.0       # Length of the data (T)
data_dt = 0.001       # Resolution of the data (dt)
myDG = DG.DataGenerator(data_initial_conditions, T=data_T, dt=data_dt, derivative_mode="exact")
t_arr, x_train, dx_train, default_guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL, method='DOP853')

print("Guessed highest order polynomial:", default_guessed_multiplicative_order)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train #data will be shuffled in the trainer


print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Guessed highest order polynomial: 2
# Training input shape: (60000, 100)
# Training output shape: (60000, 100)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 128
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
dim = training_input.shape[1] # the number of input state variables

# The grid size of each dimension
layer_depth = default_guessed_multiplicative_order
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn) # these numbers exclude the constant term
# Out:
# [100, 100]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn,
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=0.001, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Trainer**

# %%
from sreinet_trainer import *

trainer = SREINetTrainer(model, my_optimizer, loss_fn, data_type='float32')

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.30 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 50
PRUNING_EPOCHS_PER_PERIOD = 40
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

pruning_scheduler = ps.PruningScheduler(steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                    num_periods=N_PERIODS,
                    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.05

training_histories = []
weights_list = []
loss_list = []

# %%
for i in range(training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    output = training_output[:, i:i+1]
    
    history = trainer.fit(training_input, output,
     batch_size=MINI_BATCH_SIZE, 
     validation_split=0.20,
     epochs=round(NUM_EPOCHS), 
     pruning_scheduler=pruning_scheduler,
     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
     shuffle_per_epoch=False,
     patience_periods=15,
     verbose=1,
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
    loss_list.append(trainer.get_best_loss())

    #reset the model and trainer
    trainer.reset_trainer_and_model_weights(i)
# Out:
# Training dimension 1...
# Epoch   1 (Period 1):  Train Loss: 3.405e+01,  Validation Loss: 3.399e+00,  Epoch Time: 0.87s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 7.274e+00,  Validation Loss: 2.529e+01,  Epoch Time: 0.62s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 4.064e+01,  Validation Loss: 2.445e+00,  Epoch Time: 0.51s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 1.258e+00,  Validation Loss: 1.852e+00,  Epoch Time: 0.50s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 3.329e+01,  Validation Loss: 1.501e+00,  Epoch Time: 0.52s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 4.327e+00,  Validation Loss: 2.780e+01,  Epoch Time: 0.53s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 2.949e+01,  Validation Loss: 1.288e+00,  Epoch Time: 0.51s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 1.213e+01,  Validation Loss: 1.045e+02,  Epoch Time: 0.52s,  Current Pruning Threshold: 0
# Epoch   9 (Period 1):  Train Loss: 1.951e+01,  Validation Loss: 9.802e+00,  Epoch Time: 0.57s,  Current Pruning Threshold: 0
# Epoch  10 (Period 1):  Train Loss: 1.345e+00,  Validation Loss: 5.064e+00,  Epoch Time: 0.50s,  Current Pruning Threshold: 0.00087931
# Epoch  11 (Period 1):  Train Loss: 1.325e+00,  Validation Loss: 2.857e-01,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.0035069
# Epoch  12 (Period 1):  Train Loss: 7.893e+00,  Validation Loss: 1.391e+00,  Epoch Time: 0.54s,  Current Pruning Threshold: 0.007852
# Epoch  13 (Period 1):  Train Loss: 4.127e+00,  Validation Loss: 2.025e+00,  Epoch Time: 0.49s,  Current Pruning Threshold: 0.013864
# Epoch  14 (Period 1):  Train Loss: 5.240e+00,  Validation Loss: 2.303e+00,  Epoch Time: 0.50s,  Current Pruning Threshold: 0.021471
# Epoch  15 (Period 1):  Train Loss: 6.783e+00,  Validation Loss: 5.204e+00,  Epoch Time: 0.47s,  Current Pruning Threshold: 0
-01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.00087931
# Epoch  11 (Period 1):  Train Loss: 1.860e+00,  Validation Loss: 2.824e-01,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.0035069
# Epoch  12 (Period 1):  Train Loss: 9.627e+00,  Validation Loss: 2.422e+00,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.007852
# Epoch  13 (Period 1):  Train Loss: 5.105e+00,  Validation Loss: 2.911e+00,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.013864
# Epoch  14 (Period 1):  Train Loss: 7.344e+00,  Validation Loss: 4.352e+00,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.021471
# Epoch  15 (Period 1):  Train Loss: 8.125e+00,  Validation Loss: 6.817e+00,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.030586
# Epoch  16 (Period 1):  Train Loss: 9.425e+00,  Validation Loss: 9.126e+00,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.041101
# Epoch  17 (Period 1):  Train Loss: 1.019e+01,  Validation Loss: 9.874e+00,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.052892
# Epoch  18 (Period 1):  Train Loss: 1.075e+01,  Validation Loss: 1.021e+01,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.065822
# Epoch  19 (Period 1):  Train Loss: 1.036e+01,  Validation Loss: 9.899e+00,  Epoch Time: 0.49s,  Current Pruning Threshold: 0.079739
# Epoch  20 (Period 1):  Train Loss: 1.112e+01,  Validation Loss: 1.058e+01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.094479
# Epoch  21 (Period 1):  Train Loss: 1.068e+01,  Validation Loss: 1.049e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.10987
# Epoch  22 (Period 1):  Train Loss: 1.300e+01,  Validation Loss: 1.272e+01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.12573
# Epoch  23 (Period 1):  Train Loss: 1.243e+01,  Validation Loss: 1.207e+01,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.14188
# Epoch  24 (Period 1):  Train Loss: 1.442e+01,  Validation Loss: 1.380e+01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.15812
# Epoch  25 (Period 1):  Train Loss: 1.329e+01,  Validation Loss: 1.281e+01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.17427
# Epoch  26 (Period 1):  Train Loss: 1.250e+01,  Validation Loss: 1.236e+01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.19013
# Epoch  27 (Period 1):  Train Loss: 1.240e+01,  Validation Loss: 1.222e+01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.20552
# Epoch  28 (Period 1):  Train Loss: 1.175e+01,  Validation Loss: 1.158e+01,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.22026
# Epoch  29 (Period 1):  Train Loss: 1.135e+01,  Validation Loss: 1.137e+01,  Epoch Time: 0.50s,  Current Pruning Threshold: 0.23418
# Epoch  30 (Period 1):  Train Loss: 1.115e+01,  Validation Loss: 1.104e+01,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.24711
# Epoch  31 (Period 1):  Train Loss: 1.112e+01,  Validation Loss: 1.088e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.2589
# Epoch  32 (Period 1):  Train Loss: 1.104e+01,  Validation Loss: 1.126e+01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.26941
# Epoch  33 (Period 1):  Train Loss: 1.097e+01,  Validation Loss: 1.104e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.27853
# Epoch  34 (Period 1):  Train Loss: 1.094e+01,  Validation Loss: 1.077e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.28614
# Epoch  35 (Period 1):  Train Loss: 1.094e+01,  Validation Loss: 1.075e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.29215
# Epoch  36 (Period 1):  Train Loss: 1.096e+01,  Validation Loss: 1.112e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.29649
# Epoch  37 (Period 1):  Train Loss: 1.107e+01,  Validation Loss: 1.092e+01,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.29912
# Epoch  38 (Period 1):  Train Loss: 1.093e+01,  Validation Loss: 1.082e+01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.3
# Epoch  39 (Period 1):  Train Loss: 1.101e+01,  Validation Loss: 1.081e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.3
# Epoch  40 (Period 1):  Train Loss: 1.093e+01,  Validation Loss: 1.089e+01,  Epoch Time: 0.50s,  Current Pruning Threshold: 0.3
# Epoch  41 (Period 2):  Train Loss: 5.969e+02,  Validation Loss: 4.472e-01,  Epoch Time: 0.43s,  Current Pruning Threshold: 0
# Epoch  42 (Period 2):  Train Loss: 2.407e-01,  Validation Loss: 1.421e-01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epo
  Epoch Time: 0.45s,  Current Pruning Threshold: 0.23418
# Epoch  70 (Period 2):  Train Loss: 8.342e-06,  Validation Loss: 1.649e-06,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.24711
# Epoch  71 (Period 2):  Train Loss: 5.243e-07,  Validation Loss: 7.304e-08,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.2589
# Epoch  72 (Period 2):  Train Loss: 1.966e-08,  Validation Loss: 1.314e-09,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.26941
# Epoch  73 (Period 2):  Train Loss: 7.938e-10,  Validation Loss: 6.109e-10,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.27853
# Epoch  74 (Period 2):  Train Loss: 5.293e-10,  Validation Loss: 4.798e-10,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.28614
# Epoch  75 (Period 2):  Train Loss: 3.616e-10,  Validation Loss: 3.037e-10,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.29215
# Epoch  76 (Period 2):  Train Loss: 2.575e-10,  Validation Loss: 2.114e-10,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.29649
# Epoch  77 (Period 2):  Train Loss: 1.683e-10,  Validation Loss: 1.438e-10,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.29912
# Epoch  78 (Period 2):  Train Loss: 1.183e-10,  Validation Loss: 1.059e-10,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.3
# Epoch  79 (Period 2):  Train Loss: 8.083e-11,  Validation Loss: 6.980e-11,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.3
# Early stopping at epoch 79 as train loss 0.00000000008083 is below the threshold 0.00000000010000
# Training Stopped. Time elapsed: 35.85s
# Final model saved as best with loss: 6.979818e-11

# %% [markdown]
# ## **IV. Coefficient Reconstructor**

# %% [markdown]
# #### `generate_set_labels`
#
# The section below generates the layer labels that will be used to recontruct the symbolic of the right hand side (RHS) of governing equations. In addition, it also generates LHS labels.

# %%
def generate_layer_labels(N):
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)]

def generate_LHS_labels(N):
    return [f"(x{i})'" for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
from coefficient_reconstructor import *
cr = CoefficientReconstructor(generate_layer_labels, generate_LHS_labels)

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
eq_str = []
for i in range(len(weights_list)):
    path_products = cr.reconstruct_coefficients(i,
                                               weights_list[i], 
                                            minimum_coefficient_threshold = 1e-3,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
        eq_str.append(dimension)
# Out:
# (x1)' = 7.99998951 - 0.9999988079*x1 + x100*x2 - 0.9999997914*x100*x99
# (x2)' = 7.99998951 - 0.9999985695*x2 + 0.9999999404*x1*x3 - 0.999999851*x1*x100
# (x3)' = 7.999989033 - 0.9999988079*x3 - 0.9999998808*x1*x2 + 0.9999999702*x2*x4
# (x4)' = 7.99998951 - 0.9999986589*x4 - 0.9999995232*x2*x3 + 1.00000006*x3*x5
# (x5)' = 7.99999094 - 0.9999989271*x5 - 0.9999997616*x3*x4 + x4*x6
# (x6)' = 7.99998951 - 0.9999986887*x6 - 0.9999998808*x4*x5 + 0.9999999404*x5*x7
# (x7)' = 7.999988079 - 0.9999984503*x7 - 0.9999998212*x5*x6 + 0.9999998808*x6*x8
# (x8)' = 7.99998951 - 0.9999989867*x8 - 0.999999851*x6*x7 + 0.9999998808*x7*x9
# (x9)' = 7.99998951 - 0.9999985993*x9 - 0.999999851*x7*x8 + 1.000000089*x10*x8
# (x10)' = 7.999988556 - 0.9999985099*x10 - 0.9999998212*x8*x9 + x11*x9
# (x11)' = 7.999988556 - 0.9999986589*x11 - 0.9999997318*x10*x9 + 0.9999999106*x10*x12
# (x12)' = 7.999988556 - 0.9999984503*x12 - 0.9999998212*x10*x11 + 0.9999997616*x11*x13
# (x13)' = 7.999990463 - 0.9999988973*x13 - 0.9999998212*x11*x12 + 0.9999999702*x12*x14
# (x14)' = 7.999990463 - 0.9999989867*x14 - 0.9999997616*x12*x13 + 0.999999702*x13*x15
# (x15)' = 7.999989033 - 0.9999986589*x15 - 0.9999997914*x13*x14 + 0.9999998212*x14*x16
# (x16)' = 7.999990463 - 0.9999986887*x16 - 0.9999999404*x14*x15 + 0.9999999106*x15*x17
# (x17)' = 7.99998951 - 0.9999989271*x17 - 0.9999997616*x15*x16 + x16*x18
# (x18)' = 7.99998951 - 0.9999987781*x18 - 0.9999998212*x16*x17 + 0.9999999404*x17*x19
# (x19)' = 7.999988079 - 0.9999986291*x19 - 0.9999996722*x17*x18 + 1.00000006*x18*x20
# (x20)' = 7.99998951 - 0.9999987185*x20 - 0.9999999404*x18*x19 + 0.9999998808*x19*x21
# (x21)' = 7.999988556 - 0.9999984503*x21 - 0.9999997914*x19*x20 + 1.000000089*x20*x22
# (x22)' = 7.99998951 - 0.9999987781*x22 - 0.9999997914*x20*x21 + 0.9999999404*x21*x23
# (x23)' = 7.999989986 - 0.9999988973*x23 - 0.9999997914*x21*x22 + 0.9999999404*x22*x24
# (x24)' = 7.999988079 - 0.9999984801*x24 - 0.9999998212*x22*x23 + x23*x25
# (x25)' = 7.999988556 - 0.9999984801*x25 - 0.9999999106*x23*x24 + 0.9999999404*x24*x26
# (x26)' = 7.999989033 - 0.9999986291*x26 - 0.9999997616*x24*x25 + 0.9999996722*x25*x27
# (x27)' = 7.999989986 - 0.9999987781*x27 - 0.9999999106*x25*x26 + 0.9999999404*x26*x28
# (x28)' = 7.99998951 - 0.9999987483*x28 - 0.999999851*x26*x27 + 0.9999999106*x27*x29
# (x29)' = 7.999989986 - 0.9999986589*x29 - 0.9999997914*x27*x28 + 0.9999999702*x28*x30
# (x30)' = 7.999990463 - 0.9999989271*x30 - 0.9999997318*x28*x29 + 1.000000089*x29*x31
# (x31)' = 7.999989986 - 0.9999987185*x31 - 0.999999851*x29*x30 + 1.000000089*x30*x32
# (x32)' = 7.99998951 - 0.9999985695*x32 - x30*x31 + 0.9999998808*x31*x33
# (x33)' = 7.99998951 - 0.9999988973*x33 - 0.9999997914*x31*x32 + 1.00000003*x32*x34
# (x34)' = 7.999990463 - 0.9999988377*x34 - x32*x33 + 0.9999999702*x33*x35
# (x35)' = 7.99998951 - 0.9999985397*x35 - 0.9999999404*x33*x34 + 1.00000003*x34*x36
# (x36)' = 7.999991417 - 0.9999990463*x36 - 0.9999999106*x34*x35 + 1.00000003*x35*x37
# (x37)' = 7.999990463 - 0.9999988377*x37 - 0.9999997914*x35*x36 + 0.9999999702*x36*x38
# (x38)' = 7.99998951 - 0.9999984503*x38 - 0.9999997914*x36*x37 + 0.999999851*x37*x39
# (x39)' = 7.99998951 - 0.9999987483*x39 - 0.9999997914*x37*x38 + 0.9999997914*x38*x40
# (x40)' = 7.999989033 - 0.9999988079*x40 - 0.9999997914*x38*x39 + 1.000000089*x39*x41
# (x41)' = 7.999990463 - 0.9999988973*x41 - 0.9999998212*x39*x40 + 0.9999999702*x40*x42
# (x42)' = 7.999989986 - 0.9999987781*x42 - 0.9999998808*x40*x41 + 0.999999851*x41*x43
# (x43)' = 7.999988556 - 0.9999985397*x43 - 0.9999997318*x41*x42 + 0.9999999404*x42*x44
# (x44)' = 7.99998951 - 0.9999987483*x44 - 0.9999997914*x42*x43 + 1.00000006*x43*x45
# (x45)' = 7.999989986 - 0.9999985099*x45 - 0.9999998808*x43*x44 + 0.9999997616*x44*x46
# (x46)' = 7.99998951 - 0.9999985993*x46 - 0.9999997616*x44*x45 + 0.9999997914*x45*x47
# (x47)' = 7.999988556 - 0.9999986291*x47 - 0.9999998212*x45*x46 + 0.9999999404*x46*x48
# (x48)' = 7.999989986 - 0.9999988079*x48 - 0.9999997616*x46*x47 + 0.9999998808*x47*x49
# (x49)' = 7.999989033 - 0.9999986291*x49 - 0.9999997616*x47*x48 + 0.9999998212*x48*x50
# (x50)' = 7.999989986 - 0.9999989569*x50 - 0.9999998808*x48*x49 + 1.00000003*x49*x51
# (x51)' = 7.999989033 - 0.9999987185*x51 - 0.9999997616*x49*x50 + 0.999999851*x50*x52
# (x52)' = 7.999989033 - 0.9999987483*x52 - 0.999999851*x50*x51 + 0.9999999702*x51*x53
# (x53)' = 7.99998951 - 0.9999986589*x53 - 0.9999999404*x51*x52 + 0.9999998212*x52*x54
# (x54)' = 7.999988556 - 0.9999986887*x54 - 0.9999997914*x52*x53 + 0.9999997914*x53*x55
# (x55)' = 7.999989033 - 0.9999985993*x55 - 0.9999997914*x53*x54 + 0.9999999106*x54*x56
# (x56)' = 7.999988079 - 0.9999986589*x56 - 0.9999997616*x54*x55 + 0.9999999106*x55*x57
# (x57)' = 7.999990463 - 0.9999989271*x57 - 0.9999998808*x55*x56 + 1.00000006*x56*x58
# (x58)' = 7.99998951 - 0.9999989271*x58 - 0.9999997914*x56*x57 + 1.000000119*x57*x59
# (x59)' = 7.999989986 - 0.9999988377*x59 - 0.9999998212*x57*x58 + 0.9999999702*x58*x60
# (x60)' = 7.999989986 - 0.9999986589*x60 - 0.999999851*x58*x59 + 0.9999998808*x59*x61
# (x61)' = 7.999989033 - 0.9999988079*x61 - 0.999999851*x59*x60 + 1.000000209*x60*x62
# (x62)' = 7.999989986 - 0.9999987781*x62 - 0.9999997616*x60*x61 + 1.00000006*x61*x63
# (x63)' = 7.99998951 - 0.9999987185*x63 - 0.999999702*x61*x62 + 0.9999999404*x62*x64
# (x64)' = 7.999989033 - 0.9999985099*x64 - 0.9999997914*x62*x63 + x63*x65
# (x65)' = 7.999990463 - 0.9999989867*x65 - 0.9999998808*x63*x64 + 0.9999999702*x64*x66
# (x66)' = 7.99998951 - 0.9999985099*x66 - 0.9999998212*x64*x65 + x65*x67
# (x67)' = 7.99998951 - 0.9999986291*x67 - 0.9999997616*x65*x66 + 0.9999997616*x66*x68
# (x68)' = 7.999989986 - 0.9999988675*x68 - 0.9999997914*x66*x67 + 0.9999999702*x67*x69
# (x69)' = 7.999989986 - 0.9999988377*x69 - 0.9999998212*x67*x68 + 1.00000006*x68*x70
# (x70)' = 7.999989986 - 0.9999987483*x70 - 0.9999998808*x68*x69 + 1.00000003*x69*x71
# (x71)' = 7.999989986 - 0.9999986887*x71 - 0.9999998212*x69*x70 + 1.000000089*x70*x72
# (x72)' = 7.999989033 - 0.9999989569*x72 - 0.9999998212*x70*x71 + 0.9999998808*x71*x73
# (x73)' = 7.99998951 - 0.9999987781*x73 - 0.9999998212*x71*x72 + 0.9999999702*x72*x74
# (x74)' = 7.99998951 - 0.9999984503*x74 - 0.9999998212*x72*x73 + 0.999999851*x73*x75
# (x75)' = 7.99998951 - 0.9999986887*x75 - 0.9999997318*x73*x74 + x74*x76
# (x76)' = 7.99998951 - 0.9999985695*x76 - 0.9999998212*x74*x75 + x75*x77
# (x77)' = 7.99998951 - 0.9999987483*x77 - 0.9999997914*x75*x76 + 0.9999999702*x76*x78
# (x78)' = 7.999988556 - 0.9999987483*x78 - 0.9999997914*x76*x77 + 1.000000089*x77*x79
# (x79)' = 7.999989986 - 0.9999988079*x79 - 0.999999851*x77*x78 + 0.9999999404*x78*x80
# (x80)' = 7.999989986 - 0.9999985695*x80 - 0.9999996424*x78*x79 + 0.9999999702*x79*x81
# (x81)' = 7.999989986 - 0.9999986291*x81 - 0.9999996722*x79*x80 + 0.9999998808*x80*x82
# (x82)' = 7.999988556 - 0.9999987781*x82 - 0.9999997616*x80*x81 + 0.9999999404*x81*x83
# (x83)' = 7.99998951 - 0.9999986291*x83 - 0.999999851*x81*x82 + 0.9999997616*x82*x84
# (x84)' = 7.99998951 - 0.9999988675*x84 - 0.9999999702*x82*x83 + x83*x85
# (x85)' = 7.999989986 - 0.9999986589*x85 - 0.9999997616*x83*x84 + 1.000000089*x84*x86
# (x86)' = 7.999988556 - 0.9999990463*x86 - 0.9999997616*x84*x85 + 1.00000006*x85*x87
# (x87)' = 7.999989033 - 0.9999983609*x87 - 0.9999997616*x85*x86 + 1.00000006*x86*x88
# (x88)' = 7.999988079 - 0.9999983609*x88 - 0.9999998212*x86*x87 + 0.9999997914*x87*x89
# (x89)' = 7.999989033 - 0.9999988079*x89 - 0.9999998212*x87*x88 + 0.9999999106*x88*x90
# (x90)' = 7.999988556 - 0.9999985397*x90 - 0.9999997914*x88*x89 + 0.9999999702*x89*x91
# (x91)' = 7.99998951 - 0.9999988079*x91 - 0.999999851*x89*x90 + 0.9999999702*x90*x92
# (x92)' = 7.99998951 - 0.9999989569*x92 - 0.9999997318*x90*x91 + 1.00000006*x91*x93
# (x93)' = 7.999988556 - 0.9999986291*x93 - 0.9999997914*x91*x92 + 0.9999997914*x92*x94
# (x94)' = 7.999989986 - 0.9999988675*x94 - 0.9999998212*x92*x93 + x93*x95
# (x95)' = 7.999989986 - 0.9999989569*x95 - 0.9999997616*x93*x94 + 0.9999998808*x94*x96
# (x96)' = 7.999989033 - 0.9999987483*x96 - 0.9999997616*x94*x95 + 1.000000149*x95*x97
# (x97)' = 7.999990463 - 0.9999988377*x97 - 0.9999998212*x95*x96 + x96*x98
# (x98)' = 7.999989033 - 0.9999986291*x98 - 0.9999996424*x96*x97 + 0.9999998808*x97*x99
# (x99)' = 7.999989986 - 0.9999986589*x99 - 0.9999997318*x97*x98 + 1.000000089*x100*x98
# (x100)' = 7.999989033 - 0.9999983907*x100 + 0.9999999106*x1*x99 - 0.9999998808*x98*x99

# %% [markdown]
# ### **Validation**

# %%
import model_reconstructor as mr

recovered_model = mr.RecoveredModel()
recovered_model.parse_ode_equations(eq_str);

# %% [markdown]
# ### Comparing vector field

# %%
pred_x_dot = recovered_model.predict_derivatives(x_train)

val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

import matplotlib.pyplot as plt

plt.plot(val_t_eval, pred_x_dot[:val_t_eval.shape[0], 0],label='SREINet')
plt.plot(val_t_eval, dx_train[:val_t_eval.shape[0],0], '--', label='True')
plt.xlabel('Time')
plt.ylabel(r'$\dot{x}_1$')
plt.legend()
plt.show()

# %% [markdown]
# ### Comparing response

# %%
val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

validation_result = recovered_model.simulate(data_initial_conditions[0], t_span=val_t_span,t_eval=val_t_eval, method='DOP853')

# %%
import matplotlib.pyplot as plt

plt.plot(validation_result['t'], validation_result['y'][0],label='SREINet')
plt.plot(val_t_eval, x_train[:val_t_eval.shape[0],0], '--', label='True')
plt.xlabel('Time')
plt.ylabel('x1')
plt.legend()
plt.show()

# %%
score =recovered_model.score(x_train[:val_t_eval.shape[0]], dx_train[:val_t_eval.shape[0]])
print(f"Score: {score}")

complexity = recovered_model.calculate_complexity()
print(f"Complexity: {complexity}")

complexity_per_dimension = complexity//dim
print(f"Complexity per dimension: {complexity_per_dimension}")
# Out:
# Score: 0.9999999999998209
# Complexity: 400
# Complexity per dimension: 4

# %% [markdown]
# ## **VI. Output**

# %%
#save hyperparameters
import pandas as pd

df = pd.DataFrame({
    'ODE model': [MY_MODEL],
    'data initial conditions': [data_initial_conditions],
    'data length (T)': [data_T],
    'data resolution (dt)': [data_dt],
    'learning rate': [learning_rate],
    'layer depth': [layer_depth],
    'input dimension': [x_train.shape[1]],
    'mini_batch_size': [MINI_BATCH_SIZE],
    'Layer Neurons per activation fns': [layer_neuron_nums_per_act_fn],
    'Data Points': [training_input.shape[0]],
    'Total Training Epochs': [NUM_EPOCHS],
    'loss function': [LOSS_FUNCTION],
    'Best loss values': [str(loss_list)], 
    'max weight threshold for pruning': [MAX_WEIGHT_PRUNING_THRESHOLD],
    'loss threshold for early stopping': [EARLY_STOPPING_LOSS_THRESHOLD],
    'pruning epochs per period': [PRUNING_EPOCHS_PER_PERIOD],
    'number of training periods': [N_PERIODS],
})

# %%
# Import the output helper module
import output_helper as opt_helper

# Save all results to Excel using the helper function
filepath = opt_helper.save_sreinet_results_to_excel(
    config_df=df,
    training_histories=training_histories,
    recovered_model=recovered_model,
    filename='lorenz96_nn_configurations.xlsx',
    output_dir='output'
)
# Out:
# Successfully saved SREINet results to: output/lorenz96_nn_configurations.xlsx
