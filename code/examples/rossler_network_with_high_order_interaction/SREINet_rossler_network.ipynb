# %% [markdown]
# ## **Rossler Netowrk Model Learned by SREINet**
#
# A sparse network including non-local connections and high-order interactions

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
from rossler_hoi import *

from network_loader import load_zachary_network

MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)  

# Generate data based on the specified model type

network_data, edge_list, triangle_list, N = load_zachary_network()
    
print(f"Loaded network with {N} nodes")
# Generate random initial conditions
np.random.seed(42)
num_traj = 1

inintial_conditions = []
for i in range(num_traj):
    x0 =  np.random.rand(N) 
    y0 =  np.random.rand(N) 
    z0 =  np.random.rand(N)
    new_IC = np.concatenate([x0, y0, z0])
    inintial_conditions.append(new_IC)

data_T = 50.0       # Length of the data (T)
data_dt = 0.01       # Resolution of the data (dt)
myDG = DG.DataGenerator(inintial_conditions,T=data_T, dt=data_dt, derivative_mode="exact")

t_arr, x_train, dx_train = myDG.generate_dataset_by_custom_ODEs(rossler_hoi, edge_list, triangle_list, method='DOP853')


#x_train_mean = np.mean(x_train, axis=0)
#x_train_std = np.std(x_train, axis=0) + 1e-8

#x_train_standardized = (x_train - x_train_mean) / x_train_std

# Scale dx by the same std (preserving the derivative relationship)
#dx_train_standardized = dx_train / x_train_std


#x_train = x_train_standardized
#dx_train = dx_train_standardized

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train
# Optionally, save a copy of the training input for simulation
#training_input_for_sim = training_input.copy() # Saving a copy of training input for simulation (Before shuffling)

#training_input, training_output = myDG.shuffleData(training_input, training_output)

print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Network loaded: 34 nodes, 78 edges, 45 triangles
# Loaded network with 34 nodes
# Training input shape: (5000, 102)
# Training output shape: (5000, 102)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 32
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables)
dim = training_input.shape[1] 

guessed_multiplicative_order = 3
# The grid size of each dimension
layer_depth = guessed_multiplicative_order
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn) # these numbers exclude the constant term
# Out:
# [102, 102, 102]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn,
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=1e-5, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

def reinitialize_model_weights(model):
    if hasattr(model.layers[1], 'reinitialize_weights'):
            tf.random.set_seed(np.random.randint(10000))
            model.layers[1].reinitialize_weights()
    else:
        print("SREINet does not have a reinitialize_weights() function.")

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Training with Pruning**

# %%
import time
np.set_printoptions(threshold=np.inf)

# Define a training step function
@tf.function
def train_step(model, optimizer, loss_fn, inputs, targets, binary_mask):        
    with tf.GradientTape() as tape:
        # Generate predictions and calculate loss
        predictions = model(inputs, training=False)
        loss = loss_fn(targets, predictions)   
        
    # Calculate gradients and update model weights
    gradients = tape.gradient(loss, model.trainable_variables)        

    # Assuming binary_masks_ones is a list of binary masks created for each trainable variable
    masked_gradients = [tf.multiply(grad, mask) for grad, mask in zip(gradients, binary_mask)]

    optimizer.apply_gradients(zip(masked_gradients, model.trainable_variables))

    return loss

# Define a validation step function
@tf.function
def val_step(model, loss_fn, inputs, targets):
    # Generate predictions and calculate loss for validation data
    predictions = model(inputs, training=False)
    # predictions = model(inputs, training=False) 
    v_loss = loss_fn(targets, predictions)
    # Record the validation loss
    return v_loss   

def SREINet_fit_w_pruning(
    model,              # TensorFlow model to be trained
    training_input,     # Input features for training
    training_output,    # Target outputs for training
    batch_size,         # Number of samples per batch of computation
    validation_split,   # Fraction of data to be used as validation set
    epochs,             # Number of complete passes through the training dataset
    optimizer,          # Optimization algorithm for updating weights
    loss_fn,            # Loss function to measure model's performance
    pruning_schedule,   # Pruning schedule for gradually increasing the sparsity level
    data_type='float32',    # Data type of the tensors (default: 'float32')
    callbacks=None,         # List of callbacks for custom actions at various stages of training
    early_stopping_loss_threshold=0,       # Threshold for early stopping based on training and validation loss
    early_stopping_pruning_threshold=0,    # Threshold for early stopping based on pruning schedule
    verbose=0               # Verbosity mode (0 = silent, 1 = progress bar, etc.)
):
    # Cast the training input and output to the specified data type
    training_input = tf.cast(training_input, data_type)
    training_output = tf.cast(training_output, data_type)

    # Shuffle and batch the dataset, then split it into training and validation sets
    full_dataset = tf.data.Dataset.from_tensor_slices((training_input, training_output)).shuffle(buffer_size=1024)
    total_samples = training_input.shape[0]
    train_samples = int(total_samples * (1 - validation_split))
    
    # Apply the data type casting for each batch in the datasets
    train_dataset = full_dataset.take(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))
    val_dataset = full_dataset.skip(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))

    # Initialize metrics for tracking training and validation loss
    train_loss = tf.keras.metrics.Mean(name='train_loss', dtype=data_type)
    val_loss = tf.keras.metrics.Mean(name='val_loss', dtype=data_type)
    
    # Parameters initialization
    binary_mask = [tf.ones_like(var) for var in model.trainable_variables]

    def generate_binary_mask_and_prune_weight(model, pruning_weight_threshold):
        binary_masks = []  # Initialize list to hold binary masks
        
        # Iterate over each variable to apply the pruning threshold and generate masks
        for var in model.trainable_variables:
            # Generate a binary mask where weights above the PRUNING_WEIGHT_THRESHOLD are marked with 1, others with 0
            mask = tf.cast(tf.abs(var) >= pruning_weight_threshold, var.dtype)

            # Update the mask at position (0, 0) to be 1 using tf.tensor_scatter_nd_update (To Avoid the constant term being pruned)
            indices = tf.constant([[0, 0]])  # Specify the indices to update
            updates = tf.constant([1], dtype=mask.dtype)  # Specify the value to update
            mask = tf.tensor_scatter_nd_update(mask, indices, updates)

            binary_masks.append(mask)  # Add the generated mask to the list            

            # Apply mask to modify weights by setting weights below PRUNING_WEIGHT_THRESHOLD to zero
            modified_weight = var * mask
            var.assign(modified_weight)            
        return binary_masks

    # Prepare a dictionary to track the training history
    history = {'loss': [], 'val_loss': []}

    # Before the training loop starts
    if callbacks:
        for callback in callbacks:
            # Assign the model to the callback
            callback.set_model(model)

            # Manually setting params before calling any methods that might depend on them
            callback.params = {
                'epochs': epochs,  # Number of epochs
                # You can add more parameters here as needed
            }

            # Now call on_train_begin with all properties set
            callback.on_train_begin(logs={'loss_threshold': early_stopping_loss_threshold})

    training_start_time = time.time()
    # Execute the training loop
    for epoch in range(epochs):
        # Notify callbacks that the epoch has started
        if callbacks:
            epoch_logs = {}
            for callback in callbacks:
                callback.on_epoch_begin(epoch, logs=epoch_logs)

        if verbose: 
            eopoch_start_time = time.time()

        # Reset state of metrics at the start of each epoch
        train_loss.reset_states()
        val_loss.reset_states()

        # Retrieve the current pruning schedule threshold
        current_pruning_threshold = pruning_schedule[epoch]
        binary_mask = generate_binary_mask_and_prune_weight(model, current_pruning_threshold)
        
        layer_losses_sum = None
        layer_indices = [i for i, layer in enumerate(model.layers) if layer.trainable]
        # Process each batch in the training dataset
        for train_inputs, train_targets in train_dataset:           
            loss = train_step(model = model, 
                            optimizer = optimizer, 
                            loss_fn = loss_fn,
                            inputs = train_inputs, 
                            targets = train_targets, 
                            binary_mask = binary_mask)    
            # Record the loss
            train_loss(loss)

        # Process each batch in the validation dataset
        for val_inputs, val_targets in val_dataset:
            v_loss = val_step(model = model, 
                                loss_fn = loss_fn,
                                inputs = val_inputs, 
                                targets = val_targets)
            val_loss(v_loss)

        # Append the average losses for this epoch to the history
        history['loss'].append(train_loss.result().numpy())
        history['val_loss'].append(val_loss.result().numpy())
        #calculate the average of val_loss
        
        # Current Losses
        current_train_loss = train_loss.result().numpy()
        current_val_loss = val_loss.result().numpy()

        # Notify callbacks that the epoch has ended
        epoch_logs = {'loss': current_train_loss, 'val_loss': current_val_loss}
        if callbacks:
            for callback in callbacks:
                callback.on_epoch_end(epoch, logs=epoch_logs)
    
        if verbose:
            epoch_time = time.time() - eopoch_start_time
            total_layers = len(model.layers)
            trainable_layer_count = sum(1 for layer in model.layers if layer.trainable)
            print(f"Epoch {epoch + 1:3.0f}:"
                f"  Train Loss: {current_train_loss:9.4e}"
                f",  Validation Loss: {current_val_loss:9.4e}"
                # f",  Trainable Layers ({trainable_layer_count}/{total_layers})"
                f",  Epoch Time: {epoch_time:.2f}s"  
                f",  Current Pruning Threshold: {current_pruning_threshold:.5g}")    
            
        if model.stop_training: # Stop training if all the layers are untrianable
            break   

        # Check for early stopping
        if current_train_loss < early_stopping_loss_threshold and current_pruning_threshold > early_stopping_pruning_threshold:
            print(f"Early stopping at epoch {epoch+1} as train loss {current_val_loss:.12f} is below the threshold {early_stopping_loss_threshold:.12f}")
            break


    # After the training loop ends
    training_time = time.time() - training_start_time
    print(f'Traininng Stopped. Time elapsed: {training_time:.2f}s')
    if callbacks:
        for callback in callbacks:
            callback.on_train_end(logs={'final_loss': current_train_loss, 'final_val_loss': current_val_loss})
    

    # Return the history containing training and validation losses
    return history

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.02 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 50
PRUNING_EPOCHS_PER_PERIOD = 50
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

# Define the pruning schedule
pruning_schedule = ps.pruning_schedule_ramp(maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD, 
                                                    steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                                                    num_periods=N_PERIODS, 
                                                    #zero_percentage=0.10,
                                                    show_plot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 9
#       6 import pruning_scheduler as ps
#       8 # Define the pruning schedule
# ----> 9 pruning_schedule = ps.pruning_schedule_ramp(maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
#      10                                                     steps_per_period=PRUNING_EPOCHS_PER_PERIOD,
#      11                                                     num_periods=N_PERIODS,
#      12                                                     #zero_percentage=0.10,
#      13                                                     show_plot=True)
#
# AttributeError: module 'pruning_scheduler' has no attribute 'pruning_schedule_ramp'

# %% [markdown]
# ### Training

# %%
#Setup
callbacks = []

EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.005

training_histories = []
weights_list = []

# %%
#change 0 to a other number if you want to start training from other dimensions
for i in range(0, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    reinitialize_model_weights(model)
    output = training_output[:, i:i+1]

    history = SREINet_fit_w_pruning(
        model,                   # Model to train
        training_input,             # Input data for training
        output,                     # Output data for training
        batch_size=MINI_BATCH_SIZE, # Number of samples per gradient update
        validation_split=0.20,      # Fraction of the training data to be used as validation data
        epochs=round(NUM_EPOCHS),   # Number of times the entire training dataset is passed through the model
        optimizer=my_optimizer,     # Optimizer to use for training
        pruning_schedule = pruning_schedule, # Pruning schedule for gradually increasing the sparsity level
        loss_fn=loss_fn,            # Loss function to use for training
        data_type=MY_DATA_TYPE,     # Data type to use for training
        callbacks= callbacks,       # List of callbacks to apply during training
        early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,# Threshold for early stopping (Layer Based)
        early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD, # Threshold for early stopping (Pruning Based)
        verbose=1                   # Hide the epoch steps
    )
    
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([model.get_layer('SREINet').get_weights()])
# Out:
# Training dimension 1...
# Epoch   1:  Train Loss: 5.1959e+01,  Validation Loss: 2.1059e+01,  Epoch Time: 0.28s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.1107e+01,  Validation Loss: 3.5430e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.3992e+00,  Validation Loss: 1.8529e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 3.4875e-01,  Validation Loss: 4.1077e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 2.6811e-01,  Validation Loss: 4.1399e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 2.2414e-01,  Validation Loss: 3.1899e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 2.2605e-01,  Validation Loss: 3.3279e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 2.7967e-01,  Validation Loss: 5.3052e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 2.1952e-01,  Validation Loss: 2.3496e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 1.9911e-01,  Validation Loss: 2.5701e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  11:  Train Loss: 1.7755e-01,  Validation Loss: 2.8127e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  12:  Train Loss: 1.8319e-01,  Validation Loss: 2.2472e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 3.8053e-05
# Epoch  13:  Train Loss: 1.7939e-01,  Validation Loss: 2.0370e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00015192
# Epoch  14:  Train Loss: 1.6822e-01,  Validation Loss: 2.2330e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00034074
# Epoch  15:  Train Loss: 1.8208e-01,  Validation Loss: 2.6907e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00060307
# Epoch  16:  Train Loss: 1.4695e-01,  Validation Loss: 2.0226e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00093692
# Epoch  17:  Train Loss: 1.3101e-01,  Validation Loss: 1.4978e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0013397
# Epoch  18:  Train Loss: 2.6089e-01,  Validation Loss: 2.9747e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0018085
# Epoch  19:  Train Loss: 3.4018e-01,  Validation Loss: 2.1624e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0023396
# Epoch  20:  Train Loss: 1.2584e+00,  Validation Loss: 4.3892e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0029289
# Epoch  21:  Train Loss: 1.6065e-01,  Validation Loss: 1.3907e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0035721
# Epoch  22:  Train Loss: 1.2828e-01,  Validation Loss: 2.1420e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0042642
# Epoch  23:  Train Loss: 3.2154e-01,  Validation Loss: 2.2025e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.005
# Epoch  24:  Train Loss: 5.3726e-01,  Validation Loss: 2.6217e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0057738
# Epoch  25:  Train Loss: 3.3225e-01,  Validation Loss: 1.5142e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0065798
# Epoch  26:  Train Loss: 9.7221e-02,  Validation Loss: 1.3049e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0074118
# Epoch  27:  Train Loss: 1.1819e-01,  Validation Loss: 1.5084e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0082635
# Epoch  28:  Train Loss: 9.4323e-02,  Validation Loss: 1.4044e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0091284
# Epoch  29:  Train Loss: 7.1132e-02,  Validation Loss: 6.8745e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01
# Epoch  30:  Train Loss: 1.0680e-01,  Validation Loss: 7.3271e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.010872
# Epoch  31:  Train Loss: 5.0767e-02,  Validation Loss: 3.4695e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch  32:  Train Loss: 6.4940e-02,  Validation Loss: 5.1949e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.012588
# Epoch  33:  Train Loss: 7.3838e-02,  Validation Loss: 6.7304e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01342
# Epoch  34:  Train Loss: 1.3283e-01,  Validation Loss: 1.5739e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.014226
# Epoch  35:  Train Loss: 4.8744e-02,  Validation Loss: 3.8720e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015
# Epoch  36:  Train Loss: 3.8601e-02,  Validation Loss: 3.4765e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015736
# Epoch  37:  Train Loss: 3.4866e-02,  Validation Loss: 2.8261e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.016428
# Epoch  38:  Train Loss: 3.3491e-02,  Validation Loss: 2.9127e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.017071
# Epoch  39:  Train Loss: 2.7148e-02,  Validation Loss: 2.2784e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01766
# Epoch  40:  Train Loss: 3.1610e-02,  Validation Loss: 2.2273e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.018192
# Epoch  41:  Train Loss: 2.4419e-02,  Validation Loss: 1.7412e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01866
# Epoch  42:  Train Loss: 2.2652e-02,  Validation Loss: 1.6009e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019063
# Epoch  43:  Train Loss: 2.1287e-02,  Validation Loss: 1.4354e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019397
# Epoch  44:  Train Loss: 2.0285e-02,  Validation Loss: 1.6058e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019659
# Epoch  45:  Train Loss: 1.9512e-02,  Validation Loss: 1.4973e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019848
# Epoch  46:  Train Loss: 1.7102e-02,  Validation Loss: 1.2055e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019962
# Epoch  47:  Train Loss: 1.5815e-02,  Validation Loss: 1.2584e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02
# Epoch  48:  Train Loss: 1.4378e-02,  Validation Loss: 1.1801e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch  49:  Train Loss: 1.3284e-02,  Validation Loss: 1.1578e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch  50:  Train Loss: 1.2243e-02,  Validation Loss: 9.8432e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02
# Epoch  51:  Train Loss: 1.7867e-02,  Validation Loss: 2.1189e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  52:  Train Loss: 1.5474e-02,  Validation Loss: 1.3094e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  53:  Train Loss: 1.3329e-02,  Validation Loss: 9.0011e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  54:  Train Loss: 1.2103e-02,  Validation Loss: 8.2589e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  55:  Train Loss: 9.5040e-03,  Validation Loss: 7.1719e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  56:  Train Loss: 1.0346e-02,  Validation Loss: 3.0294e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  57:  Train Loss: 1.3484e-02,  Validation Loss: 1.3185e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  58:  Train Loss: 7.6883e-03,  Validation Loss: 7.6982e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  59:  Train Loss: 3.7503e-03,  Validation Loss: 5.0517e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  60:  Train Loss: 4.5007e-03,  Validation Loss: 3.5641e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  61:  Train Loss: 3.2535e-03,  Validation Loss: 1.8132e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  62:  Train Loss: 4.1526e-03,  Validation Loss: 6.2788e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 3.8053e-05
# Epoch  63:  Train Loss: 3.3581e-03,  Validation Loss: 2.7080e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00015192
# Epoch  64:  Train Loss: 2.3631e-03,  Validation Loss: 1.8708e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00034074
# Epoch  65:  Train Loss: 1.6985e-03,  Validation Loss: 1.7708e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00060307
# Epoch  66:  Train Loss: 2.5771e-03,  Validation Loss: 4.7881e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00093692
# Epoch  67:  Train Loss: 1.7830e-03,  Validation Loss: 1.9103e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0013397
# Epoch  68:  Train Loss: 1.9811e-03,  Validation Loss: 2.2771e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0018085
# Epoch  69:  Train Loss: 1.5706e-03,  Validation Loss: 1.1226e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0023396
# Epoch  70:  Train Loss: 1.4837e-03,  Validation Loss: 1.1670e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0029289
# Epoch  71:  Train Loss: 2.0609e-03,  Validation Loss: 1.0675e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0035721
# Epoch  72:  Train Loss: 2.9767e-03,  Validation Loss: 2.6649e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0042642
# Epoch  73:  Train Loss: 5.5647e-03,  Validation Loss: 4.1952e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.005
# Epoch  74:  Train Loss: 2.3406e-03,  Validation Loss: 2.5030e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0057738
# Epoch  75:  Train Loss: 1.6574e-03,  Validation Loss: 2.0516e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0065798
# Epoch  76:  Train Loss: 1.4846e-03,  Validation Loss: 1.7689e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074118
# Epoch  77:  Train Loss: 1.3668e-03,  Validation Loss: 1.3865e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0082635
# Epoch  78:  Train Loss: 1.3693e-03,  Validation Loss: 1.3479e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0091284
# Epoch  79:  Train Loss: 1.3148e-03,  Validation Loss: 1.5149e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.01
# Epoch  80:  Train Loss: 1.4441e-03,  Validation Loss: 1.2362e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.010872
# Epoch  81:  Train Loss: 2.0204e-03,  Validation Loss: 1.4427e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch  82:  Train Loss: 2.0563e-03,  Validation Loss: 1.5749e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.012588
# Epoch  83:  Train Loss: 1.1774e-03,  Validation Loss: 1.2234e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01342
# Epoch  84:  Train Loss: 8.1291e-04,  Validation Loss: 1.1122e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.014226
# Epoch  85:  Train Loss: 8.7935e-04,  Validation Loss: 1.0397e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015
# Epoch  86:  Train Loss: 7.4180e-04,  Validation Loss: 9.1060e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015736
# Epoch  87:  Train Loss: 9.9173e-04,  Validation Loss: 9.3257e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016428
# Epoch  88:  Train Loss: 1.5672e-03,  Validation Loss: 1.8429e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.017071
# Epoch  89:  Train Loss: 3.2009e-03,  Validation Loss: 2.0867e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01766
# Epoch  90:  Train Loss: 3.2731e-03,  Validation Loss: 2.1529e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.018192
# Epoch  91:  Train Loss: 1.0004e-03,  Validation Loss: 1.4502e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01866
# Epoch  92:  Train Loss: 5.3617e-04,  Validation Loss: 8.7727e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019063
# Epoch  93:  Train Loss: 4.8130e-04,  Validation Loss: 7.4505e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019397
# Epoch  94:  Train Loss: 1.3296e-03,  Validation Loss: 1.3454e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019659
# Epoch  95:  Train Loss: 1.0964e-03,  Validation Loss: 2.0589e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.019848
# Epoch  96:  Train Loss: 6.2413e-04,  Validation Loss: 9.6688e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019962
# Epoch  97:  Train Loss: 4.5231e-04,  Validation Loss: 8.4954e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch  98:  Train Loss: 4.1888e-04,  Validation Loss: 6.2049e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch  99:  Train Loss: 3.8287e-04,  Validation Loss: 4.6775e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02
# Epoch 100:  Train Loss: 3.8380e-04,  Validation Loss: 4.9212e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02
# Epoch 101:  Train Loss: 3.4928e-02,  Validation Loss: 9.3262e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 102:  Train Loss: 8.0667e+01,  Validation Loss: 2.3665e+02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 103:  Train Loss: 3.5686e+02,  Validation Loss: 2.3438e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 104:  Train Loss: 3.2975e+01,  Validation Loss: 1.9087e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 105:  Train Loss: 2.5090e+00,  Validation Loss: 1.1404e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 106:  Train Loss: 3.4526e-01,  Validation Loss: 2.7829e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 107:  Train Loss: 2.1321e-01,  Validation Loss: 2.1168e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 108:  Train Loss: 1.0721e-01,  Validation Loss: 8.9838e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 109:  Train Loss: 6.7416e-02,  Validation Loss: 7.2207e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 110:  Train Loss: 5.8796e-02,  Validation Loss: 4.4719e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 111:  Train Loss: 4.6567e-02,  Validation Loss: 4.5568e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 112:  Train Loss: 4.1184e-02,  Validation Loss: 3.5778e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 3.8053e-05
# Epoch 113:  Train Loss: 3.6515e-02,  Validation Loss: 3.4642e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00015192
# Epoch 114:  Train Loss: 3.5099e-02,  Validation Loss: 3.3750e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00034074
# Epoch 115:  Train Loss: 3.1881e-02,  Validation Loss: 3.0391e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00060307
# Epoch 116:  Train Loss: 2.7940e-02,  Validation Loss: 2.4583e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00093692
# Epoch 117:  Train Loss: 2.7160e-02,  Validation Loss: 2.3964e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0013397
# Epoch 118:  Train Loss: 3.5929e-02,  Validation Loss: 2.8408e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0018085
# Epoch 119:  Train Loss: 5.7032e-02,  Validation Loss: 3.1207e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0023396
# Epoch 120:  Train Loss: 3.5940e-02,  Validation Loss: 7.7814e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0029289
# Epoch 121:  Train Loss: 3.7748e-02,  Validation Loss: 4.3510e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0035721
# Epoch 122:  Train Loss: 4.2662e-02,  Validation Loss: 3.8351e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0042642
# Epoch 123:  Train Loss: 4.7465e-02,  Validation Loss: 3.3872e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.005
# Epoch 124:  Train Loss: 3.7773e-02,  Validation Loss: 3.4449e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0057738
# Epoch 125:  Train Loss: 7.9721e-02,  Validation Loss: 7.2953e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0065798
# Epoch 126:  Train Loss: 1.6746e-01,  Validation Loss: 2.0914e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0074118
# Epoch 127:  Train Loss: 1.0496e-01,  Validation Loss: 1.3926e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0082635
# Epoch 128:  Train Loss: 5.7295e-02,  Validation Loss: 9.8546e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0091284
# Epoch 129:  Train Loss: 6.0410e-02,  Validation Loss: 8.4652e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01
# Epoch 130:  Train Loss: 4.0775e-02,  Validation Loss: 5.7146e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.010872
# Epoch 131:  Train Loss: 4.3368e-02,  Validation Loss: 4.8677e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch 132:  Train Loss: 4.3169e-02,  Validation Loss: 5.7809e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.012588
# Epoch 133:  Train Loss: 1.3717e-01,  Validation Loss: 9.8993e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01342
# Epoch 134:  Train Loss: 2.8942e-01,  Validation Loss: 1.0294e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.014226
# Epoch 135:  Train Loss: 4.2054e-01,  Validation Loss: 3.6566e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015
# Epoch 136:  Train Loss: 7.3775e-03,  Validation Loss: 1.2924e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015736
# Epoch 137:  Train Loss: 5.5944e-03,  Validation Loss: 1.6906e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.016428
# Epoch 138:  Train Loss: 4.4217e-03,  Validation Loss: 8.7843e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.017071
# Epoch 139:  Train Loss: 3.2278e-03,  Validation Loss: 7.4012e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01766
# Epoch 140:  Train Loss: 2.7311e-03,  Validation Loss: 6.8320e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.018192
# Epoch 141:  Train Loss: 2.3926e-03,  Validation Loss: 5.9089e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01866
# Epoch 142:  Train Loss: 2.1458e-03,  Validation Loss: 6.4833e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019063
# Epoch 143:  Train Loss: 2.2157e-03,  Validation Loss: 6.3393e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019397
# Epoch 144:  Train Loss: 1.7688e-03,  Validation Loss: 4.2660e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.019659
# Epoch 145:  Train Loss: 1.7327e-03,  Validation Loss: 3.9505e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019848
# Epoch 146:  Train Loss: 1.6557e-03,  Validation Loss: 4.3088e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.019962
# Epoch 147:  Train Loss: 1.6174e-03,  Validation Loss: 3.9963e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02
# Epoch 148:  Train Loss: 1.5142e-03,  Validation Loss: 4.2966e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 149:  Train Loss: 1.4542e-03,  Validation Loss: 3.1511e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 150:  Train Loss: 1.3916e-03,  Validation Loss: 3.3253e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 151:  Train Loss: 1.2448e-03,  Validation Loss: 1.3049e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 152:  Train Loss: 6.6661e-04,  Validation Loss: 4.1620e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 153:  Train Loss: 1.3796e-03,  Validation Loss: 1.0892e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 154:  Train Loss: 3.1073e-03,  Validation Loss: 1.2746e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 155:  Train Loss: 1.2607e-03,  Validation Loss: 8.6892e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 156:  Train Loss: 9.4934e-04,  Validation Loss: 2.3728e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 157:  Train Loss: 1.6612e-03,  Validation Loss: 2.1548e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 158:  Train Loss: 9.3679e-04,  Validation Loss: 7.0960e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 159:  Train Loss: 5.9577e-04,  Validation Loss: 2.9795e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 160:  Train Loss: 1.4073e-03,  Validation Loss: 3.2262e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 161:  Train Loss: 3.6267e-03,  Validation Loss: 1.1179e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 162:  Train Loss: 1.6314e-03,  Validation Loss: 2.1764e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 3.8053e-05
# Epoch 163:  Train Loss: 7.7236e-03,  Validation Loss: 1.7803e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00015192
# Epoch 164:  Train Loss: 9.7554e-03,  Validation Loss: 1.8739e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00034074
# Epoch 165:  Train Loss: 2.5261e-02,  Validation Loss: 2.0906e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00060307
# Epoch 166:  Train Loss: 8.0840e-02,  Validation Loss: 1.0892e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00093692
# Epoch 167:  Train Loss: 2.0679e-02,  Validation Loss: 1.5516e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0013397
# Epoch 168:  Train Loss: 8.2397e-03,  Validation Loss: 4.2217e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0018085
# Epoch 169:  Train Loss: 4.6832e-03,  Validation Loss: 2.2347e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0023396
# Epoch 170:  Train Loss: 2.1126e-03,  Validation Loss: 2.1110e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0029289
# Epoch 171:  Train Loss: 2.0296e-03,  Validation Loss: 1.6508e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0035721
# Epoch 172:  Train Loss: 1.7430e-03,  Validation Loss: 2.3516e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042642
# Epoch 173:  Train Loss: 1.7838e-03,  Validation Loss: 3.6194e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.005
# Epoch 174:  Train Loss: 4.1470e-03,  Validation Loss: 5.0873e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0057738
# Epoch 175:  Train Loss: 1.5066e-02,  Validation Loss: 2.5658e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0065798
# Epoch 176:  Train Loss: 7.7846e-03,  Validation Loss: 5.5758e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0074118
# Epoch 177:  Train Loss: 9.3404e-04,  Validation Loss: 1.3517e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0082635
# Epoch 178:  Train Loss: 6.9999e-04,  Validation Loss: 8.3864e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0091284
# Epoch 179:  Train Loss: 5.7566e-04,  Validation Loss: 8.2757e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.01
# Epoch 180:  Train Loss: 5.4285e-04,  Validation Loss: 9.2918e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.010872
# Epoch 181:  Train Loss: 5.7505e-04,  Validation Loss: 9.5161e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch 182:  Train Loss: 5.7587e-04,  Validation Loss: 9.5220e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.012588
# Epoch 183:  Train Loss: 1.2488e-03,  Validation Loss: 1.6268e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.01342
# Epoch 184:  Train Loss: 7.2850e-04,  Validation Loss: 9.1998e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.014226
# Epoch 185:  Train Loss: 5.7525e-04,  Validation Loss: 9.7407e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015
# Epoch 186:  Train Loss: 5.6003e-04,  Validation Loss: 7.9807e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.015736
# Epoch 187:  Train Loss: 5.6696e-04,  Validation Loss: 8.0550e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016428
# Epoch 188:  Train Loss: 5.6240e-04,  Validation Loss: 8.1026e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.017071
# Epoch 189:  Train Loss: 5.7071e-04,  Validation Loss: 9.1035e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01766
# Epoch 190:  Train Loss: 1.0407e-03,  Validation Loss: 1.6225e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.018192
# Epoch 191:  Train Loss: 1.4513e-03,  Validation Loss: 2.9731e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.01866
# Epoch 192:  Train Loss: 1.0224e-03,  Validation Loss: 1.6919e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.019063
# Epoch 193:  Train Loss: 6.3034e-03,  Validation Loss: 5.3676e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019397
# Epoch 194:  Train Loss: 7.8688e-04,  Validation Loss: 1.3539e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019659
# Epoch 195:  Train Loss: 9.2637e-04,  Validation Loss: 1.6425e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.019848
# Epoch 196:  Train Loss: 8.7744e-04,  Validation Loss: 1.5248e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019962
# Epoch 197:  Train Loss: 8.5754e-04,  Validation Loss: 1.2519e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 198:  Train Loss: 8.3534e-04,  Validation Loss: 1.2899e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 199:  Train Loss: 7.8703e-04,  Validation Loss: 1.1672e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 200:  Train Loss: 7.7157e-04,  Validation Loss: 1.2127e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 201:  Train Loss: 5.7435e-04,  Validation Loss: 3.3185e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 202:  Train Loss: 1.5930e-03,  Validation Loss: 3.5191e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 203:  Train Loss: 2.9476e-03,  Validation Loss: 8.3879e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 204:  Train Loss: 2.4812e-03,  Validation Loss: 1.8583e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 205:  Train Loss: 1.3968e-03,  Validation Loss: 2.0490e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 206:  Train Loss: 7.2605e-04,  Validation Loss: 1.4976e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 207:  Train Loss: 5.7945e-04,  Validation Loss: 7.7047e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 208:  Train Loss: 9.8452e-04,  Validation Loss: 8.1252e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 209:  Train Loss: 1.8364e-03,  Validation Loss: 5.8155e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 210:  Train Loss: 1.2543e-03,  Validation Loss: 2.6937e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 211:  Train Loss: 1.2529e-03,  Validation Loss: 2.6984e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 212:  Train Loss: 7.9473e-04,  Validation Loss: 1.3092e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 3.8053e-05
# Epoch 213:  Train Loss: 1.0566e-03,  Validation Loss: 5.0453e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00015192
# Epoch 214:  Train Loss: 3.9262e-04,  Validation Loss: 3.9828e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00034074
# Epoch 215:  Train Loss: 3.7139e-04,  Validation Loss: 3.2411e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00060307
# Epoch 216:  Train Loss: 4.6922e-04,  Validation Loss: 1.0958e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00093692
# Epoch 217:  Train Loss: 4.6085e-04,  Validation Loss: 3.0120e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0013397
# Epoch 218:  Train Loss: 4.6941e-04,  Validation Loss: 3.6760e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0018085
# Epoch 219:  Train Loss: 7.0973e-04,  Validation Loss: 8.2619e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0023396
# Epoch 220:  Train Loss: 5.0887e-04,  Validation Loss: 6.1880e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0029289
# Epoch 221:  Train Loss: 4.6880e-04,  Validation Loss: 6.0409e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0035721
# Epoch 222:  Train Loss: 4.8544e-04,  Validation Loss: 5.2534e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0042642
# Epoch 223:  Train Loss: 4.9688e-04,  Validation Loss: 6.5879e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.005
# Epoch 224:  Train Loss: 4.5038e-04,  Validation Loss: 5.7307e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0057738
# Epoch 225:  Train Loss: 4.2862e-04,  Validation Loss: 4.6711e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0065798
# Epoch 226:  Train Loss: 4.1158e-04,  Validation Loss: 4.6349e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0074118
# Epoch 227:  Train Loss: 4.1580e-04,  Validation Loss: 5.3511e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0082635
# Epoch 228:  Train Loss: 4.1724e-04,  Validation Loss: 4.4150e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0091284
# Epoch 229:  Train Loss: 3.8909e-04,  Validation Loss: 4.0589e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01
# Epoch 230:  Train Loss: 3.6949e-04,  Validation Loss: 4.1538e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.010872
# Epoch 231:  Train Loss: 3.6249e-04,  Validation Loss: 3.6200e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch 232:  Train Loss: 3.9293e-04,  Validation Loss: 4.0247e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.012588
# Epoch 233:  Train Loss: 3.6181e-04,  Validation Loss: 3.9879e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01342
# Epoch 234:  Train Loss: 3.6066e-04,  Validation Loss: 3.3752e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.014226
# Epoch 235:  Train Loss: 3.3298e-04,  Validation Loss: 3.4257e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015
# Epoch 236:  Train Loss: 3.2385e-04,  Validation Loss: 3.2807e-04,  Epoch Time: 0.11s,  Current Pruning Threshold: 0.015736
# Epoch 237:  Train Loss: 3.1705e-04,  Validation Loss: 3.1927e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.016428
# Epoch 238:  Train Loss: 3.0320e-04,  Validation Loss: 2.9734e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.017071
# Epoch 239:  Train Loss: 2.8776e-04,  Validation Loss: 2.8376e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01766
# Epoch 240:  Train Loss: 2.9262e-04,  Validation Loss: 2.5859e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.018192
# Epoch 241:  Train Loss: 2.8358e-04,  Validation Loss: 2.7272e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01866
# Epoch 242:  Train Loss: 2.8497e-04,  Validation Loss: 2.6987e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019063
# Epoch 243:  Train Loss: 2.7156e-04,  Validation Loss: 2.4586e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019397
# Epoch 244:  Train Loss: 2.7635e-04,  Validation Loss: 2.5187e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019659
# Epoch 245:  Train Loss: 2.7002e-04,  Validation Loss: 2.3154e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019848
# Epoch 246:  Train Loss: 2.6561e-04,  Validation Loss: 2.4859e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019962
# Epoch 247:  Train Loss: 2.6167e-04,  Validation Loss: 2.4327e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 248:  Train Loss: 2.5515e-04,  Validation Loss: 2.2101e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 249:  Train Loss: 2.5664e-04,  Validation Loss: 2.0885e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 250:  Train Loss: 2.5465e-04,  Validation Loss: 2.1702e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 251:  Train Loss: 1.6091e-01,  Validation Loss: 5.6747e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 252:  Train Loss: 3.3120e+01,  Validation Loss: 4.5566e+01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 253:  Train Loss: 9.7627e+00,  Validation Loss: 7.2123e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 254:  Train Loss: 3.1969e-01,  Validation Loss: 1.9171e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 255:  Train Loss: 8.5936e-02,  Validation Loss: 6.6815e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 256:  Train Loss: 3.7864e-02,  Validation Loss: 4.1592e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 257:  Train Loss: 3.0206e-02,  Validation Loss: 3.3853e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 258:  Train Loss: 2.1602e-02,  Validation Loss: 2.7496e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 259:  Train Loss: 1.6331e-02,  Validation Loss: 1.9645e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 260:  Train Loss: 1.4391e-02,  Validation Loss: 1.9731e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 261:  Train Loss: 1.0442e-02,  Validation Loss: 8.0674e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 262:  Train Loss: 1.0214e-02,  Validation Loss: 1.4672e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 3.8053e-05
# Epoch 263:  Train Loss: 6.5074e-03,  Validation Loss: 5.0449e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00015192
# Epoch 264:  Train Loss: 5.7265e-03,  Validation Loss: 4.7089e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00034074
# Epoch 265:  Train Loss: 5.8748e-03,  Validation Loss: 4.7017e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00060307
# Epoch 266:  Train Loss: 3.8845e-03,  Validation Loss: 2.9709e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00093692
# Epoch 267:  Train Loss: 3.5570e-03,  Validation Loss: 3.5557e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0013397
# Epoch 268:  Train Loss: 4.8037e-03,  Validation Loss: 3.0181e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0018085
# Epoch 269:  Train Loss: 5.3967e-03,  Validation Loss: 2.9975e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0023396
# Epoch 270:  Train Loss: 1.3466e-02,  Validation Loss: 4.8020e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0029289
# Epoch 271:  Train Loss: 1.0409e-02,  Validation Loss: 1.5679e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0035721
# Epoch 272:  Train Loss: 2.0198e-02,  Validation Loss: 1.8567e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0042642
# Epoch 273:  Train Loss: 1.7083e-02,  Validation Loss: 1.5928e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.005
# Epoch 274:  Train Loss: 2.1891e-02,  Validation Loss: 1.1673e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0057738
# Epoch 275:  Train Loss: 1.9644e-02,  Validation Loss: 3.1702e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0065798
# Epoch 276:  Train Loss: 1.2760e-02,  Validation Loss: 1.8172e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0074118
# Epoch 277:  Train Loss: 2.0358e-02,  Validation Loss: 2.2748e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0082635
# Epoch 278:  Train Loss: 3.4934e-03,  Validation Loss: 2.2859e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0091284
# Epoch 279:  Train Loss: 1.8958e-03,  Validation Loss: 4.2172e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01
# Epoch 280:  Train Loss: 9.1767e-04,  Validation Loss: 1.9916e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.010872
# Epoch 281:  Train Loss: 6.2965e-04,  Validation Loss: 1.2546e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch 282:  Train Loss: 3.7470e-04,  Validation Loss: 5.4110e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.012588
# Epoch 283:  Train Loss: 3.5405e-04,  Validation Loss: 5.3262e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01342
# Epoch 284:  Train Loss: 3.4702e-04,  Validation Loss: 5.4784e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.014226
# Epoch 285:  Train Loss: 3.4578e-04,  Validation Loss: 4.8094e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015
# Epoch 286:  Train Loss: 3.3493e-04,  Validation Loss: 4.5142e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015736
# Epoch 287:  Train Loss: 3.4373e-04,  Validation Loss: 4.6576e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.016428
# Epoch 288:  Train Loss: 3.3625e-04,  Validation Loss: 4.4842e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.017071
# Epoch 289:  Train Loss: 4.0923e-04,  Validation Loss: 7.0680e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01766
# Epoch 290:  Train Loss: 4.1179e-04,  Validation Loss: 6.8422e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.018192
# Epoch 291:  Train Loss: 4.0489e-04,  Validation Loss: 6.2069e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01866
# Epoch 292:  Train Loss: 3.6942e-04,  Validation Loss: 5.5145e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019063
# Epoch 293:  Train Loss: 3.7092e-04,  Validation Loss: 5.4303e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019397
# Epoch 294:  Train Loss: 3.7925e-04,  Validation Loss: 5.5740e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019659
# Epoch 295:  Train Loss: 3.7210e-04,  Validation Loss: 5.6184e-04,  Epoch Time: 0.11s,  Current Pruning Threshold: 0.019848
# Epoch 296:  Train Loss: 3.6700e-04,  Validation Loss: 4.8298e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019962
# Epoch 297:  Train Loss: 3.6376e-04,  Validation Loss: 4.9796e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 298:  Train Loss: 3.5889e-04,  Validation Loss: 4.9521e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 299:  Train Loss: 3.5777e-04,  Validation Loss: 4.6746e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 300:  Train Loss: 3.5154e-04,  Validation Loss: 4.5528e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 301:  Train Loss: 2.5983e-04,  Validation Loss: 1.9450e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 302:  Train Loss: 2.7586e-04,  Validation Loss: 3.2604e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 303:  Train Loss: 2.8764e-04,  Validation Loss: 2.1287e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 304:  Train Loss: 2.1257e-04,  Validation Loss: 2.5922e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 305:  Train Loss: 2.0509e-04,  Validation Loss: 1.7714e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 306:  Train Loss: 1.8317e-04,  Validation Loss: 1.2055e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 307:  Train Loss: 1.9434e-04,  Validation Loss: 1.6384e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 308:  Train Loss: 1.9282e-04,  Validation Loss: 1.8662e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 309:  Train Loss: 1.9001e-04,  Validation Loss: 1.4225e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 310:  Train Loss: 1.8257e-04,  Validation Loss: 1.3479e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 311:  Train Loss: 2.0495e-04,  Validation Loss: 1.3780e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 312:  Train Loss: 1.8023e-04,  Validation Loss: 1.2831e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 3.8053e-05
# Epoch 313:  Train Loss: 1.8054e-04,  Validation Loss: 1.5329e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00015192
# Epoch 314:  Train Loss: 1.9318e-04,  Validation Loss: 1.7738e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00034074
# Epoch 315:  Train Loss: 2.6587e-04,  Validation Loss: 3.4843e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00060307
# Epoch 316:  Train Loss: 2.5132e-04,  Validation Loss: 3.0136e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00093692
# Epoch 317:  Train Loss: 2.4796e-04,  Validation Loss: 2.8605e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0013397
# Epoch 318:  Train Loss: 2.6457e-04,  Validation Loss: 3.4158e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0018085
# Epoch 319:  Train Loss: 2.7975e-04,  Validation Loss: 3.2473e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0023396
# Epoch 320:  Train Loss: 2.6246e-04,  Validation Loss: 3.3571e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0029289
# Epoch 321:  Train Loss: 2.6125e-04,  Validation Loss: 3.0314e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0035721
# Epoch 322:  Train Loss: 2.5273e-04,  Validation Loss: 3.2135e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0042642
# Epoch 323:  Train Loss: 2.8512e-04,  Validation Loss: 3.2138e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.005
# Epoch 324:  Train Loss: 2.8127e-04,  Validation Loss: 3.2422e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0057738
# Epoch 325:  Train Loss: 2.7359e-04,  Validation Loss: 3.3771e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0065798
# Epoch 326:  Train Loss: 2.5876e-04,  Validation Loss: 2.9374e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0074118
# Epoch 327:  Train Loss: 2.5361e-04,  Validation Loss: 2.9178e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0082635
# Epoch 328:  Train Loss: 2.4790e-04,  Validation Loss: 2.9845e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0091284
# Epoch 329:  Train Loss: 2.5341e-04,  Validation Loss: 3.1494e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01
# Epoch 330:  Train Loss: 2.4150e-04,  Validation Loss: 2.8256e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.010872
# Epoch 331:  Train Loss: 2.3530e-04,  Validation Loss: 2.7915e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch 332:  Train Loss: 2.3327e-04,  Validation Loss: 2.7027e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.012588
# Epoch 333:  Train Loss: 2.3303e-04,  Validation Loss: 2.9737e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01342
# Epoch 334:  Train Loss: 2.9410e-04,  Validation Loss: 3.3416e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.014226
# Epoch 335:  Train Loss: 2.9058e-04,  Validation Loss: 3.1568e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015
# Epoch 336:  Train Loss: 2.8849e-04,  Validation Loss: 3.3364e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015736
# Epoch 337:  Train Loss: 2.8199e-04,  Validation Loss: 3.2454e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.016428
# Epoch 338:  Train Loss: 2.8018e-04,  Validation Loss: 2.8808e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.017071
# Epoch 339:  Train Loss: 2.8223e-04,  Validation Loss: 2.9267e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01766
# Epoch 340:  Train Loss: 2.6130e-04,  Validation Loss: 3.0580e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.018192
# Epoch 341:  Train Loss: 2.6739e-04,  Validation Loss: 2.8556e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01866
# Epoch 342:  Train Loss: 2.6725e-04,  Validation Loss: 3.2215e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019063
# Epoch 343:  Train Loss: 2.5935e-04,  Validation Loss: 3.2294e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019397
# Epoch 344:  Train Loss: 2.6174e-04,  Validation Loss: 2.8750e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019659
# Epoch 345:  Train Loss: 2.6344e-04,  Validation Loss: 2.6840e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019848
# Epoch 346:  Train Loss: 2.5598e-04,  Validation Loss: 2.6670e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019962
# Epoch 347:  Train Loss: 2.6253e-04,  Validation Loss: 2.6620e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 348:  Train Loss: 2.5608e-04,  Validation Loss: 2.5432e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 349:  Train Loss: 2.5917e-04,  Validation Loss: 2.3866e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 350:  Train Loss: 2.5692e-04,  Validation Loss: 2.7387e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 351:  Train Loss: 1.1631e-02,  Validation Loss: 1.0894e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 352:  Train Loss: 1.5141e-02,  Validation Loss: 6.1951e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 353:  Train Loss: 3.3836e-02,  Validation Loss: 1.7030e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 354:  Train Loss: 2.0417e-02,  Validation Loss: 2.5497e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 355:  Train Loss: 4.4335e-03,  Validation Loss: 9.4924e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 356:  Train Loss: 2.5933e-03,  Validation Loss: 2.7928e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 357:  Train Loss: 9.3856e-04,  Validation Loss: 2.2733e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 358:  Train Loss: 8.5072e-04,  Validation Loss: 7.3191e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 359:  Train Loss: 4.5673e-04,  Validation Loss: 2.9067e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 360:  Train Loss: 2.8190e-04,  Validation Loss: 2.4011e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 361:  Train Loss: 2.7049e-04,  Validation Loss: 1.9133e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 362:  Train Loss: 8.8003e-04,  Validation Loss: 4.5131e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 3.8053e-05
# Epoch 363:  Train Loss: 5.5153e-04,  Validation Loss: 2.8136e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00015192
# Epoch 364:  Train Loss: 3.4149e-04,  Validation Loss: 6.3763e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00034074
# Epoch 365:  Train Loss: 3.0595e-04,  Validation Loss: 2.7094e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00060307
# Epoch 366:  Train Loss: 5.1972e-04,  Validation Loss: 3.5065e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00093692
# Epoch 367:  Train Loss: 3.9512e-04,  Validation Loss: 3.6248e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0013397
# Epoch 368:  Train Loss: 4.9573e-04,  Validation Loss: 3.5655e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0018085
# Epoch 369:  Train Loss: 4.4967e-04,  Validation Loss: 3.1382e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0023396
# Epoch 370:  Train Loss: 2.3730e-04,  Validation Loss: 1.8073e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0029289
# Epoch 371:  Train Loss: 2.3662e-04,  Validation Loss: 2.9746e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0035721
# Epoch 372:  Train Loss: 2.0237e-04,  Validation Loss: 1.9189e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0042642
# Epoch 373:  Train Loss: 1.8046e-04,  Validation Loss: 1.7506e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.005
# Epoch 374:  Train Loss: 1.7974e-04,  Validation Loss: 1.6839e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0057738
# Epoch 375:  Train Loss: 2.3308e-04,  Validation Loss: 3.3202e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0065798
# Epoch 376:  Train Loss: 1.8980e-04,  Validation Loss: 1.9109e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0074118
# Epoch 377:  Train Loss: 1.9724e-04,  Validation Loss: 2.0260e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0082635
# Epoch 378:  Train Loss: 1.8457e-04,  Validation Loss: 1.9759e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0091284
# Epoch 379:  Train Loss: 2.8308e-04,  Validation Loss: 2.3746e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01
# Epoch 380:  Train Loss: 2.5568e-04,  Validation Loss: 2.0914e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.010872
# Epoch 381:  Train Loss: 2.3729e-04,  Validation Loss: 3.5543e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch 382:  Train Loss: 2.3850e-04,  Validation Loss: 2.4338e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.012588
# Epoch 383:  Train Loss: 2.2979e-04,  Validation Loss: 1.7451e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01342
# Epoch 384:  Train Loss: 2.2787e-04,  Validation Loss: 2.1254e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.014226
# Epoch 385:  Train Loss: 2.2518e-04,  Validation Loss: 1.8780e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015
# Epoch 386:  Train Loss: 2.1049e-04,  Validation Loss: 1.7700e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015736
# Epoch 387:  Train Loss: 2.2469e-04,  Validation Loss: 1.6568e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.016428
# Epoch 388:  Train Loss: 2.2096e-04,  Validation Loss: 2.0865e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.017071
# Epoch 389:  Train Loss: 2.1245e-04,  Validation Loss: 2.0423e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01766
# Epoch 390:  Train Loss: 2.1768e-04,  Validation Loss: 1.7710e-04,  Epoch Time: 0.10s,  Current Pruning Threshold: 0.018192
# Epoch 391:  Train Loss: 2.1836e-04,  Validation Loss: 1.5674e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01866
# Epoch 392:  Train Loss: 2.1306e-04,  Validation Loss: 1.7504e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019063
# Epoch 393:  Train Loss: 2.0947e-04,  Validation Loss: 2.3874e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019397
# Epoch 394:  Train Loss: 2.1742e-04,  Validation Loss: 1.6390e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019659
# Epoch 395:  Train Loss: 2.1059e-04,  Validation Loss: 1.6154e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019848
# ...
# Epoch 831:  Train Loss: 2.8126e-03,  Validation Loss: 3.9652e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch 832:  Train Loss: 1.5423e-03,  Validation Loss: 2.1091e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.012588
# Epoch 833:  Train Loss: 1.0623e-03,  Validation Loss: 1.3504e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01342
# Epoch 834:  Train Loss: 8.9757e-04,  Validation Loss: 1.1563e-03,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.014226
# Epoch 835:  Train Loss: 7.4611e-04,  Validation Loss: 9.3441e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015
# Epoch 836:  Train Loss: 7.2522e-04,  Validation Loss: 7.9161e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.015736
# Epoch 837:  Train Loss: 6.0865e-04,  Validation Loss: 7.6579e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.016428
# Epoch 838:  Train Loss: 6.3990e-04,  Validation Loss: 6.1374e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.017071
# Epoch 839:  Train Loss: 5.9500e-04,  Validation Loss: 5.7803e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01766
# Epoch 840:  Train Loss: 7.9427e-04,  Validation Loss: 5.8918e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.018192
# Epoch 841:  Train Loss: 6.0441e-04,  Validation Loss: 8.1905e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.01866
# Epoch 842:  Train Loss: 5.9640e-04,  Validation Loss: 8.1079e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019063
# Epoch 843:  Train Loss: 6.4879e-04,  Validation Loss: 6.9423e-04,  Epoch Time: 0.11s,  Current Pruning Threshold: 0.019397
# Epoch 844:  Train Loss: 7.9517e-04,  Validation Loss: 1.1237e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019659
# Epoch 845:  Train Loss: 8.1845e-04,  Validation Loss: 8.6452e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019848
# Epoch 846:  Train Loss: 7.1223e-04,  Validation Loss: 6.6960e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019962
# Epoch 847:  Train Loss: 6.4774e-04,  Validation Loss: 6.0968e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 848:  Train Loss: 6.7041e-04,  Validation Loss: 8.8162e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 849:  Train Loss: 6.3034e-04,  Validation Loss: 6.0514e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 850:  Train Loss: 5.9403e-04,  Validation Loss: 5.7248e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 851:  Train Loss: 5.6606e-04,  Validation Loss: 6.6735e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 852:  Train Loss: 5.2397e-04,  Validation Loss: 5.5126e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 853:  Train Loss: 4.9543e-04,  Validation Loss: 5.3544e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 854:  Train Loss: 4.6320e-04,  Validation Loss: 3.9923e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 855:  Train Loss: 4.5680e-04,  Validation Loss: 4.2507e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 856:  Train Loss: 4.4135e-04,  Validation Loss: 3.8500e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 857:  Train Loss: 4.4112e-04,  Validation Loss: 3.6144e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 858:  Train Loss: 4.3696e-04,  Validation Loss: 3.4211e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 859:  Train Loss: 4.3062e-04,  Validation Loss: 3.6294e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0
# Epoch 860:  Train Loss: 4.6492e-04,  Validation Loss: 3.6488e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 861:  Train Loss: 4.3303e-04,  Validation Loss: 4.3691e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0
# Epoch 862:  Train Loss: 4.6017e-04,  Validation Loss: 4.0769e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 3.8053e-05
# Epoch 863:  Train Loss: 4.5608e-04,  Validation Loss: 3.8381e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00015192
# Epoch 864:  Train Loss: 4.7396e-04,  Validation Loss: 5.4056e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00034074
# Epoch 865:  Train Loss: 4.7217e-04,  Validation Loss: 5.6858e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.00060307
# Epoch 866:  Train Loss: 4.6064e-04,  Validation Loss: 5.4124e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00093692
# Epoch 867:  Train Loss: 4.7778e-04,  Validation Loss: 5.5426e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0013397
# Epoch 868:  Train Loss: 4.5550e-04,  Validation Loss: 5.1379e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0018085
# Epoch 869:  Train Loss: 4.7339e-04,  Validation Loss: 5.0482e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0023396
# Epoch 870:  Train Loss: 4.5834e-04,  Validation Loss: 4.9462e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0029289
# Epoch 871:  Train Loss: 4.5725e-04,  Validation Loss: 5.0781e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0035721
# Epoch 872:  Train Loss: 4.5045e-04,  Validation Loss: 4.7544e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0042642
# Epoch 873:  Train Loss: 4.3966e-04,  Validation Loss: 4.9958e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.005
# Epoch 874:  Train Loss: 4.4493e-04,  Validation Loss: 4.8218e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0057738
# Epoch 875:  Train Loss: 4.4895e-04,  Validation Loss: 4.9015e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0065798
# Epoch 876:  Train Loss: 4.4562e-04,  Validation Loss: 4.3674e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074118
# Epoch 877:  Train Loss: 4.4815e-04,  Validation Loss: 4.7384e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0082635
# Epoch 878:  Train Loss: 4.3457e-04,  Validation Loss: 4.7771e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0091284
# Epoch 879:  Train Loss: 4.4050e-04,  Validation Loss: 4.6749e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.01
# Epoch 880:  Train Loss: 4.3132e-04,  Validation Loss: 5.0608e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.010872
# Epoch 881:  Train Loss: 4.4115e-04,  Validation Loss: 4.6493e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.011736
# Epoch 882:  Train Loss: 4.3384e-04,  Validation Loss: 4.6184e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.012588
# Epoch 883:  Train Loss: 4.3470e-04,  Validation Loss: 4.1878e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.01342
# Epoch 884:  Train Loss: 4.2681e-04,  Validation Loss: 4.3453e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.014226
# Epoch 885:  Train Loss: 4.3546e-04,  Validation Loss: 4.3025e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.015
# Epoch 886:  Train Loss: 4.3251e-04,  Validation Loss: 4.1613e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.015736
# Epoch 887:  Train Loss: 4.2545e-04,  Validation Loss: 4.0853e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.016428
# Epoch 888:  Train Loss: 4.3270e-04,  Validation Loss: 4.8398e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.017071
# Epoch 889:  Train Loss: 4.2599e-04,  Validation Loss: 4.1020e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.01766
# Epoch 890:  Train Loss: 4.3197e-04,  Validation Loss: 3.9795e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.018192
# Epoch 891:  Train Loss: 4.2522e-04,  Validation Loss: 4.0124e-04,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.01866
# Epoch 892:  Train Loss: 4.2305e-04,  Validation Loss: 3.8060e-04,  Epoch Time: 0.11s,  Current Pruning Threshold: 0.019063
# Epoch 893:  Train Loss: 4.2603e-04,  Validation Loss: 4.4623e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019397
# Epoch 894:  Train Loss: 4.1009e-04,  Validation Loss: 3.8818e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019659
# Epoch 895:  Train Loss: 4.2041e-04,  Validation Loss: 4.2680e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019848
# Epoch 896:  Train Loss: 4.6653e-04,  Validation Loss: 4.0876e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.019962
# Epoch 897:  Train Loss: 4.1634e-04,  Validation Loss: 4.2822e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 898:  Train Loss: 4.1972e-04,  Validation Loss: 3.9161e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 899:  Train Loss: 4.1575e-04,  Validation Loss: 3.9916e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 900:  Train Loss: 4.1681e-04,  Validation Loss: 3.8978e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.02
# Epoch 901:  Train Loss: 5.5488e-04,  Validation Loss: 4.5463e-04,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 902:  Train Loss: 5.2533e-03,  Validation Loss: 1.1267e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 903:  Train Loss: 5.1982e-03,  Validation Loss: 1.3044e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 904:  Train Loss: 1.3121e-02,  Validation Loss: 2.3265e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 8
#       5 reinitialize_model_weights(model)
#       6 output = training_output[:, i:i+1]
# ----> 8 history = SREINet_fit_w_pruning(
#       9     model,                   # Model to train
#      10     training_input,             # Input data for training
#      11     output,                     # Output data for training
#      12     batch_size=MINI_BATCH_SIZE, # Number of samples per gradient update
#      13     validation_split=0.20,      # Fraction of the training data to be used as validation data
#      14     epochs=round(NUM_EPOCHS),   # Number of times the entire training dataset is passed through the model
#      15     optimizer=my_optimizer,     # Optimizer to use for training
#      16     pruning_schedule = pruning_schedule, # Pruning schedule for gradually increasing the sparsity level
#      17     loss_fn=loss_fn,            # Loss function to use for training
#      18     data_type=MY_DATA_TYPE,     # Data type to use for training
#      19     callbacks= callbacks,       # List of callbacks to apply during training
#      20     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,# Threshold for early stopping (Layer Based)
#      21     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD, # Threshold for early stopping (Pruning Based)
#      22     verbose=1                   # Hide the epoch steps
#      23 )
#      25 training_histories.append(history)
#      27 # Retrieve the weights of the trained model
#
# Cell In[12], line 137, in SREINet_fit_w_pruning(model, training_input, training_output, batch_size, validation_split, epochs, optimizer, loss_fn, pruning_schedule, data_type, callbacks, early_stopping_loss_threshold, early_stopping_pruning_threshold, verbose)
#     130     loss = train_step(model = model,
#     131                     optimizer = optimizer,
#     132                     loss_fn = loss_fn,
#     133                     inputs = train_inputs,
#     134                     targets = train_targets,
#     135                     binary_mask = binary_mask)
#     136     # Record the loss
# --> 137     train_loss(loss)
#     139 # Process each batch in the validation dataset
#     140 for val_inputs, val_targets in val_dataset:
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/metrics/base_metric.py:216, in Metric.__call__(self, *args, **kwargs)
#     210         return result_t
#     212 from keras.src.distribute import (
#     213     distributed_training_utils,
#     214 )
# --> 216 return distributed_training_utils.call_replica_local_fn(
#     217     replica_local_fn, *args, **kwargs
#     218 )
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/distribute/distributed_training_utils.py:62, in call_replica_local_fn(fn, *args, **kwargs)
#      60     with strategy.scope():
#      61         return strategy.extended.call_for_each_replica(fn, args, kwargs)
# ---> 62 return fn(*args, **kwargs)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/metrics/base_metric.py:187, in Metric.__call__.<locals>.replica_local_fn(*args, **kwargs)
#     185     update_op = None
#     186 else:
# --> 187     update_op = self.update_state(*args, **kwargs)
#     188 update_ops = []
#     189 if update_op is not None:
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/utils/metrics_utils.py:77, in update_state_wrapper.<locals>.decorated(metric_obj, *args, **kwargs)
#      69         raise ValueError(
#      70             "Trying to run metric.update_state in replica context when "
#      71             "the metric was not created in TPUStrategy scope. "
#      72             "Make sure the keras Metric is created in TPUstrategy "
#      73             "scope. "
#      74         )
#      76 with tf_utils.graph_context_for_symbolic_tensors(*args, **kwargs):
# ---> 77     result = update_state_fn(*args, **kwargs)
#      78 if not tf.executing_eagerly():
#      79     result = tf.compat.v1.get_default_graph().get_operations()[-1]
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/metrics/base_metric.py:140, in Metric.__new__.<locals>.update_state_fn(*args, **kwargs)
#     136 control_status = tf.__internal__.autograph.control_status_ctx()
#     137 ag_update_state = tf.__internal__.autograph.tf_convert(
#     138     obj_update_state, control_status
#     139 )
# --> 140 return ag_update_state(*args, **kwargs)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/keras/src/metrics/base_metric.py:527, in Reduce.update_state(self, values, sample_weight)
#     524     values = tf.multiply(values, sample_weight)
#     526 value_sum = tf.reduce_sum(values)
# --> 527 with tf.control_dependencies([value_sum]):
#     528     update_total_op = self.total.assign_add(value_sum)
#     530 # Exit early if the reduction doesn't have a denominator.
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/framework/ops.py:4425, in control_dependencies(control_inputs)
#    4418 @deprecation.deprecated(
#    4419     date=None, instructions="Colocations handled automatically by placer.")
#    4420 @tf_export(v1=["colocate_with"])
#    4421 def _colocate_with(op, ignore_existing=False):
#    4422   return colocate_with(op, ignore_existing)
# -> 4425 @tf_export("control_dependencies")
#    4426 def control_dependencies(control_inputs):
#    4427   """Wrapper for `Graph.control_dependencies()` using the default graph.
#    4428
#    4429   See `tf.Graph.control_dependencies` for more details.
#    (...)
#    4485    operations constructed within the context.
#    4486   """
#    4487   if context.executing_eagerly():
#
# KeyboardInterrupt:

# %%
model.get_layer('SREINet').get_weights()[0]
# Out:
# array([[-1.51034156e-02, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  8.02861620e-03,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  2.80070186e-01,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -4.53990936e-01,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  9.19115618e-02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00],
#        [-1.22839110e-02,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.65307625e-07, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  1.52523471e-02,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          2.23957300e-02,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [ 0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -1.47598572e-02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          1.72849060e-08,  2.46533956e-02, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00],
#        [ 0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -1.57308634e-02,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00],
#        [ 0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  1.09856785e-07,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -6.02307955e-06, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.95062794e-02,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          2.53495779e-02, -3.33044136e-06,  0.00000000e+00,
#          0.00000000e+00, -6.55935679e-08, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -1.24419834e-02, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -1.63662322e-02, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  1.06470678e-02,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -1.17870085e-02, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          6.53167209e-03, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -3.27266235e-07,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -1.25467544e-02,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -6.65560378e-07, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -1.05766483e-01,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          7.22057962e-07,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -1.69447780e-01,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          2.34039184e-02,  6.86493877e-07,  0.00000000e+00,
#         -3.40248160e-02, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  5.60490415e-02,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -8.61914232e-02,
#          1.21494848e-02,  2.17580646e-02,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -6.86389487e-03,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  2.08846889e-02,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  3.28239912e-06,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          2.09832806e-02,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          2.49371771e-02, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -1.67519303e-07, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -9.45935585e-03, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          2.33035851e-02, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -1.18901914e-06, -0.00000000e+00,
#          1.11933826e-02, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -8.61123204e-03,
#          9.94615927e-02, -1.38698099e-02, -0.00000000e+00,
#          0.00000000e+00,  2.26838097e-06, -0.00000000e+00,
#         -0.00000000e+00],
#        [ 0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
# ...
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -4.86379815e-03,  5.64615402e-06, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          3.77554670e-02, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  3.43521833e-02,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -3.29484940e-02,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -9.93172307e-07, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.18386762e-02,
#         -0.00000000e+00, -0.00000000e+00, -1.71493087e-02,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  5.21852337e-02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -8.95526711e-08,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          3.68149355e-02,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -3.03268731e-02,
#          1.08892061e-02, -0.00000000e+00,  2.13701911e-02,
#         -0.00000000e+00,  5.71699957e-07, -0.00000000e+00,
#          1.84371620e-02, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -3.09271883e-07,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  1.89657416e-02,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -1.16548911e-02,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -1.51752057e-02,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -3.58665809e-02, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -1.75428223e-02, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -3.42420936e-02,
#         -0.00000000e+00,  2.12073270e-02, -6.04420900e-02,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -3.44096225e-06,  2.34426148e-02, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          7.50209168e-02,  0.00000000e+00,  0.00000000e+00,
#         -2.53875069e-02,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -3.21569985e-07,  0.00000000e+00,
#          1.80966575e-02,  0.00000000e+00, -2.79054102e-02,
#          1.14780962e-02, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          2.72956192e-02, -2.01405492e-02,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  3.13780047e-02,  2.44602431e-02,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  5.93344942e-02,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          3.53252217e-02, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00],
#        [-0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  2.24295892e-02,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -2.24441960e-02, -0.00000000e+00, -0.00000000e+00,
#          1.41217886e-02, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  3.48308384e-02,
#          0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         -0.00000000e+00, -9.93860662e-02, -0.00000000e+00,
#          6.49815276e-02,  0.00000000e+00,  0.00000000e+00,
#         -4.07379232e-02,  0.00000000e+00, -0.00000000e+00,
#          0.00000000e+00]], dtype=float32)

# %%
weights_list.append([model.get_layer('SREINet').get_weights()])

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_set_labels(N):
    labels = ['Constant']
    for i in range(1, N+1):
        labels.extend([f'x{i}', f'y{i}', f'z{i}'])
    return labels

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
def coefficient_reconstruction(dim_index,
                                weights, 
                                minimum_coefficient_threshold = 1e-5,
                                coefficient_output_digits = 10, 
                                enable_coefficient_sorting = False):
    
    max_neurons = max(max(len(layer) for layer in SREINet) for SREINet in weights)
    
    labels = generate_set_labels(max_neurons - 1) # number of states = number of neurons - 1

    def explore_path(SREINet_index, layer, neuron, weight_product, label_counts, non_zero_paths):
        """
        Recursively explores non-zero paths in a neural network.
        """
        if layer == len(weights[SREINet_index]) - 1:
            non_zero_paths.append((label_counts, weight_product))
            return

        for next_neuron, weight in enumerate(weights[SREINet_index][layer][neuron]):
            if abs(weight) <= 1e-15:
                # Skip recursion if the weight is zero (if one weight is zero, the whole path will be eliminated)
                continue  
            new_weight_product = weight_product * weight
            next_label_counts = label_counts.copy()
            next_label_counts[labels[next_neuron]] = next_label_counts.get(labels[next_neuron], 0) + 1
            explore_path(SREINet_index, layer + 1, next_neuron, new_weight_product, next_label_counts, non_zero_paths)
    
    #beginning of the algorithm
    all_SREINet_products = []
    for SREINet_index, _ in enumerate(weights):
        non_zero_paths = []
        #collect all non-zero paths
        for neuron_index in range(len(weights[SREINet_index][0])):
            label_counts = {labels[neuron_index]: 1}
            explore_path(SREINet_index, 0, neuron_index, 1, label_counts, non_zero_paths)
        
        #sum up the products with identical composite nonlinear/linear terms
        SREINet_products = {}
        for label_counts, weight_product in non_zero_paths:
            label_counts_key = frozenset(label_counts.items())
            if label_counts_key in SREINet_products:
                SREINet_products[label_counts_key] += weight_product
            else:
                SREINet_products[label_counts_key] = weight_product
        
        #remove the negligible composite terms
        SREINet_products = {k: v for k, v in SREINet_products.items() if abs(v) >= minimum_coefficient_threshold}
        
        if enable_coefficient_sorting:
            #sort the composite terms by their absolute values
            sorted_SREINet_products = dict(sorted(SREINet_products.items(), key=lambda item: abs(item[1]), reverse=True))
        else:
            sorted_SREINet_products = SREINet_products

        all_SREINet_products.append(sorted_SREINet_products)

    #output formatting
    labeled_all_SREINet_products = []
    for SREINet_index, sorted_SREINet_products in enumerate(all_SREINet_products):
        SREINet_product_strings = []
        for key, value in sorted_SREINet_products.items():
            labels_list = []
            only_constant = len(key) == 1 and any(label == 'Constant' for label, _ in key)
            
            for label, count in sorted(key):
                if label == 'Constant' and len(key) > 1:
                    continue
                if label != 'Constant' and count > 1:
                    labels_list.append(f"{label}^{count}")
                elif label == 'Constant' or count == 1:
                    labels_list.append(label if label != 'Constant' else '')
            
            label_str = '*'.join(filter(None, labels_list))
                        
            # Apply coefficient threshold if enabled
            formatted_value = f"{abs(value):.{coefficient_output_digits}g}"

            term_str = label_str if formatted_value == '1' else f"{formatted_value}*{label_str}" if not only_constant else formatted_value if formatted_value != '1' else ''
            sign = '+' if value >= 0 else '-'
            if SREINet_product_strings or value < 0:
                term_str = f" {sign} {term_str}"
            else:
                term_str = term_str
            SREINet_product_strings.append(term_str)

        formatted_output = ''.join(SREINet_product_strings)
        layer_prefix = f"(x{SREINet_index+dim_index+1})'= "
        full_output = layer_prefix + formatted_output
        labeled_all_SREINet_products.append(full_output)

    return labeled_all_SREINet_products

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
for i in range(len(weights_list)):
    path_products = coefficient_reconstruction(i,weights_list[i], 
                                            minimum_coefficient_threshold = 1e-5,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
# Out:
# (x1)'=  - 0.01835376525 - 0.358632458*z23 - 0.0001358123206*y11*z24 - 0.04464933112*y24*z23 - 0.003764091881*x26*y24 - 0.005329441173*y24*y28 - 0.004531702353*y24*z30 - 0.0005586126833*x32*y24 + 0.01204567683*x34*y24 - 0.1880348638*y29 - 0.06036674423*x1*y29 + 0.02688105136*y29*z6 - 0.005833795185*x9*y29 + 0.006364517273*y11*y29 + 0.05592479721*y14*y29 - 0.04870160177*y29*z20 - 0.04577046531*x21*y29 + 0.1090427088*y21*y29 + 0.008087288475*y29*z21 + 0.02919866325*y25*y29 - 0.005251828415*y29*z25 + 0.01361964713*x26*y29 + 0.01227855378*y27*y29 - 0.02075862525*x28*y29 - 0.02386071746*x29*y29 + 0.01901413962*y29*y30 + 0.01561864343*y29*z30 + 0.07630505535*x31*y29 - 0.04664961352*y29*z31 + 0.03005212789*x32*y29 + 0.02403307837*y29*y32 - 0.01776204662*x34*y29 + 0.001155802575*x33*z6 - 0.009407535627*x25*x33 + 0.0002937403961*x33*y27 + 0.005042577767*x32*x33 + 0.0042376799*x33*y34 - 0.01492748561*x1 - 0.001186061062*x1*z23 - 0.0002687955383*x1*x25*y31 + 0.00021794399*x1*x25*z33 - 0.0001527746379*x1*x5*y27 + 0.002306927572*x1*y27*z23 - 0.0005854560038*x1*y27*z24 + 0.000295648094*x1*y25*y27 + 0.001234346118*x1*y27*z25 - 0.0001383368089*x1*y26*y27 + 0.0008022942544*x1*x28*y27 + 0.0004029714283*x1*y27*z28 - 0.0002516587257*x1*x29*y27 - 0.000310617909*x1*x31*y27 - 0.0002518406899*x1*y27*z31 + 0.0003762395387*x1*y27*y32 - 0.0002038106796*x1*x33*y27 + 0.0002040893363*x1*x34*y27 - 0.002134309153*x1*z23*z33 - 0.0002213493799*x1*z26*z33 - 0.0007727639627*x1*x28*z33 - 0.004409694469*x1*y29*z33 - 0.003697945689*x1*x30*z33 - 0.0001856075627*x33*y1*z6 + 0.001510733577*x25*x33*y1 - 4.622637038e-05*x33*y1*y27 - 0.0008097754662*x32*x33*y1 - 0.0006805188488*x33*y1*y34 + 9.052586298e-05*x24*x28*z1 - 0.001886042591*x28*z1*z24 - 0.001486363726*x28*z1*z25 - 0.0007382124352*x28*z1*z26 + 3.612959681e-05*x28*y29*z1 + 0.001241855375*x28*x31*z1 + 0.0003071836487*x28*z1*z34 - 0.0001856940785*x1*y2*z29 + 0.0001713367269*y2*z1*z29 + 0.0001501378224*y10*y2*z29 + 0.0001809385528*x17*y2*z29 + 0.0001486532717*y2*z22*z29 - 0.0001962154875*y2*z23*z29 + 0.000875087515*y2*z25*z29 - 0.001396869234*y2*y26*z29 - 0.0004536221922*y2*z27*z29 + 0.0002324076635*y2*y29*z29 + 0.001138586868*x31*y2*z29 - 0.000210730669*y2*z29*z31 + 0.0002947325371*x33*y2*z29 - 0.0002991724615*y2*z29*z33 + 0.001378900796*x34*y2*z29 + 0.0003790195135*y1*y3*z23 + 0.000145861338*y3^2*z23 - 0.0001993437214*x4*y3*z23 - 0.0009829922948*x5*y3*z23 + 4.888068997e-05*y3*y5*z23 - 0.0001364729828*y3*z23*z5 + 0.0005465997445*y3*y6*z23 - 0.0004629377923*y3*z23*z6 + 0.0002157702138*y3*y8*z23 + 0.0001008676643*y10*y3*z23 - 0.0002905334515*y12*y3*z23 + 0.0001012855587*y13*y3*z23 - 0.000684547999*x15*y3*z23 - 0.0002261249433*y3*z15*z23 - 0.0005412228509*y3*z16*z23 - 0.0004640967148*x17*y3*z23 + 0.0002503233961*y17*y3*z23 + 0.001877091583*x19*y3*z23 - 0.0009869884466*y23*y3*z23 + 0.0001801931961*x24*y3*z23 + 0.0004179834159*y3*z23*z25 - 0.0003783879685*y3*z23*z26 + 0.001370375947*y3*z23*z27 - 0.0001806799934*y3*z23*z28 - 0.0005890822782*x29*y3*z23 - 0.001793122789*y3*z23*z31 + 0.0001658522819*x32*y3*z23 + 0.0008907034819*x34*y3*z23 + 0.000645637684*y3*z23*z34 + 0.0004925585496*y1*z23*z3 + 0.0001895555414*y3*z23*z3 - 0.0002590591006*x4*z23*z3 - 0.001277457339*x5*z23*z3 - 0.0001773548118*z23*z3*z5 + 0.001738142627*y6*z23*z3 - 0.0006016153771*z23*z3*z6 + 0.0002804063109*y8*z23*z3 - 0.0003775656144*y12*z23*z3 - 0.0008896111084*x15*z23*z3 - 0.0002938629019*z15*z23*z3 - 0.0007033514976*z16*z23*z3 - 0.0006031214663*x17*z23*z3 + 0.00032531024*y17*z23*z3 + 0.002535932202*x19*z23*z3 - 0.001282650577*y23*z23*z3 + 0.0002342082353*x24*z23*z3 + 0.0003641908746*z23*z25*z3 - 0.0004917378191*z23*z26*z3 + 0.001780885587*z23*z27*z3 - 0.0008526990932*x29*z23*z3 - 0.001744289371*z23*z3*z31 - 0.0006208798336*x32*z23*z3 + 0.00042849416*x34*z23*z3 + 0.001057150064*z23*z3*z34 + 0.0001677341836*x24*x29*z3 - 0.0001265790349*x1*x29*z3 + 0.0001314835601*x2*x29*z3 + 0.0001302526895*x29*z3^2 - 0.0002068197729*x29*x7*z3 - 0.0002326253209*x29*y7*z3 - ...

# %% [markdown]
# ### **Validation**

# %%
import matplotlib.pyplot as plt

# validation: need to draw the output of each dimension independently
dim_to_plot = 1
index = dim_to_plot - 1

#Form NN predictions
NN_output = np.zeros((dx_train.shape[0], dx_train.shape[1]))
for i, weight in enumerate(weights_list):
    model.get_layer('SREINet').set_weights(weight[0])
    output = model.predict(training_input_for_sim)
    NN_output[:,i:i+1] = output


#validate the first trajoctory if there are many
plt.plot(t_arr, NN_output[:,index][:t_arr.shape[0]], 'r', label='NN Prediction')
plt.plot(t_arr, dx_train[:,index][:t_arr.shape[0]], 'k', label='Expected Output')


#pick the last point of the simulation output and use it as the initial condition for the next simulation
x0 = x_train[:t_arr.shape[0]][-1]
t0= t_arr[-1]
myDG = DG.DataGenerator(x0,T=data_T+t0, dt=data_dt, t0=t0)
new_t_arr, new_x, new_dx, guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL)

new_input = new_x

new_NN_output= np.zeros((new_dx.shape[0], new_dx.shape[1]))
for i, weight in enumerate(weights_list):
    model.get_layer('SREINet').set_weights(weight[0])
    output = model.predict(new_input)
    new_NN_output[:,i:i+1] = output


#new_NN_output = model.predict(new_input)
plt.plot(new_t_arr, new_NN_output[:,index], "r--", label='NN Prediction')
plt.plot(new_t_arr, new_dx[:,index], "k--", label='Expected Output')
plt.title("Response of dimension " + str(dim_to_plot))
plt.show()

# %% [markdown]
# ## **VI. Output**

# %%
#save data
#NN configurations -> #NN layers, #NN neurons
#data configurations -> #data points, #data dimensions
#optimizer configurations -> #learning rate, #decay rate
#training configurations -> #NN training epochs, callbacks
#record loss values
#save the info into a spreadsheet

import pandas as pd

df = pd.DataFrame({
    'ODE model': [MY_MODEL],
    'data initial conditions': [data_initial_conditions],
    'data length (T)': [data_T],
    'data resolution (dt)': [data_dt],
    'learning rate': [learning_rate],
    'Guess highest-order polynomial': [guess_highest_order_polynomial],
    'input dimension': [x_train.shape[1]],
    'mini_batch_size': [MINI_BATCH_SIZE],
    'Layer Neurons per activation fns': [layer_neuron_nums_per_act_fn],
    'Data Points': [training_input.shape[0]],
    'loss function': [LOSS_FUNCTION],
    'Total Training Epochs': [NUM_EPOCHS],
    'last lost value': [history['loss'][-1]],
    'weight threshold for pruning': [PRUNING_WEIGHT_THRESHOLD],
    'loss threshold for early stopping': [EARLY_STOPPING_LOSS_THRESHOLD],
})

# %%
#write df to the first sheet of the excel file
#write to folder named data

opt_folder = 'output'
# Create the folder if it doesn't exist
os.makedirs(opt_folder, exist_ok=True)

with pd.ExcelWriter(os.path.join(opt_folder,'nn_configurations.xlsx')) as writer:

    df.to_excel(writer, sheet_name='configuration', index=False)

    #save the loss and validation history to the second sheet of the excel file
    df2 = pd.DataFrame(history)
    df2.to_excel(writer, sheet_name='loss_history', index=False)

    #save reconstructed weights to the third sheet of the excel file

    df3 = []

    for i in range(len(weights_list)):
        path_products = coefficient_reconstruction(i,
                                                    weights_list[i], 
                                                    minimum_coefficient_threshold = 1e-4,
                                                    coefficient_output_digits = 10, 
                                                    enable_coefficient_sorting = False)


        # Convert path_products to a DataFrame
        temp_df = pd.DataFrame(path_products)

        # Append temp_df to df3
        df3.append(temp_df)

    df3 = pd.concat(df3, ignore_index=True)
    df3.to_excel(writer, sheet_name='reconstructed_weights', index=False)

# %%
from scipy.io import savemat
#concatenate t_arr, x_train, dx_train, and NN_output and save it as a mat file

#pate t_arr such that it has the same shape as x_train, dx_train, and NN_output
tem_t_arr = t_arr
for i in range(num_traj-1):
    tem_t_arr = np.concatenate((tem_t_arr, t_arr), axis=0) 
t_arr = tem_t_arr

m_data = np.concatenate((t_arr, x_train, dx_train, NN_output), axis=1)
savemat(os.path.join(opt_folder,'train_data.mat'), {'data': m_data})

v_data = np.concatenate((new_t_arr, new_x, new_dx, new_NN_output), axis=1)
savemat(os.path.join(opt_folder,'validation_data.mat'), {'data': v_data})
