# %% [markdown]
# ## **Sparse identification of nonlinear dynamics (SINDy) with CombOpNet and periodic pruning**
#
#
# We take inspirations from the materials below to develop this notebook.
#
# - SINDy Wikipedia: ([Link](https://en.wikipedia.org/wiki/Sparse_identification_of_non-linear_dynamics))
# - PySINDy (Python): ([Link](https://github.com/dynamicslab/pysindy))
# - SINDy-Pi (MatLab): ([Link](https://github.com/dynamicslab/SINDy-PI))

# %% [markdown]
# ## **I. SETUP AND PREPROCESSING**
#
# This section of the code handles the initial setup, data loading, and preprocessing steps required before training the machine learning model. It includes importing necessary Python packages, loading training data, and any preprocessing steps such as data normalization or feature engineering. The code also initializes and configures the hyperparameters necessary for training the machine learning model.
#
# For this project, I will be approximating the results of the SINDy algorithm using the CombOpnet structure

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from CombOpNet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) > version.parse('2.10.0'):
    print("Error: Tensorflow version is higher than 2.10. Please use Tensorflow 2.10 or lower.")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.10.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**
#
# Training data is loaded from MATLAB files, including input and output data. The data is then converted into TensorFlow constant tensors for further processing.

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_MODEL = 'discrete_phi_quartic' # discrete sine Gordon model 

# Generate data based on the specified model type
node_num = 10
C = 2.0 #coupling strength

#initial conditions for Simulation
xn = np.linspace(-node_num/2/np.sqrt(C), node_num/2/np.sqrt(C), node_num)

#x0 = np.tanh(xn/np.sqrt(1-v**2))  
num_traj = 5 
v = np.linspace(0.0, 0.99, num_traj)
data_initial_conditions= []
for i in range(num_traj):
        #x0 =  np.tanh(xn/np.sqrt(1-v[i]**2))
        #d_x0 = 1/np.sqrt(1-v[i]**2) * (1 - np.tanh(xn/np.sqrt(1-v[i]**2))**2)
        x0 = np.random.normal(0, 0.1, size=xn.shape) 
        d_x0 = np.random.normal(0, 0.1, size=xn.shape)  
        new_IC = np.concatenate((x0, d_x0), axis=0) # add velocity
        data_initial_conditions.append(new_IC)


data_T =  50.0       # Length of the data (T)
data_dt = 0.01      # Resolution of the data (dt)
myDG = DG.DataGenerator(data_initial_conditions,T=data_T, dt=data_dt, noise_level=0.10)

t_arr, x_train, dx_train, guess_highest_order_polynomial = myDG.generate_dataset_by_model_name(MY_MODEL, C, node_num)

print("Guess highest order polynomial:", guess_highest_order_polynomial)

#plot x_train and dx_train
import matplotlib.pyplot as plt
print(x_train.shape)
plt.scatter(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train
# Optionally, save a copy of the training input for simulation
training_input_for_sim = training_input.copy() # Saving a copy of training input for simulation (Before shuffling)

training_input, training_output = myDG.shuffleData(training_input, training_output)

print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Guess highest order polynomial: 3
# (25000, 20)
# Training input shape: (25000, 20)
# Training output shape: (25000, 20)

# %%
import seaborn as sns

#plot the data of the first set
heatmap_t_arr = t_arr

heatmap_x_train = x_train[:t_arr.shape[0], :node_num]
print(heatmap_t_arr.shape)
print(heatmap_x_train.shape)

#downsample
plt.figure(figsize=(10, 6))
#a1= sns.heatmap(heat_map_dx_train, cmap='viridis', xticklabels=heatmap_t_arr, yticklabels=np.arange(heat_map_dx_train.shape[0]))
#a1.set_xticks([0,2.5, 5, 7.5, 10.])
#plt.imshow(heat_map_dx_train, aspect='auto', cmap='viridis', extent=[heatmap_t_arr[0], heatmap_t_arr[-1], 0, heat_map_dx_train.shape[0]])

import matplotlib.colors as mcolors

plt.imshow(heatmap_x_train.transpose(), aspect='auto', cmap='plasma')

step = 400

plt.colorbar(label='Data Value')
plt.gca().invert_yaxis()

plt.show()
# Out:
# (5000, 1)
# (5000, 10)

# %% [markdown]
# ### **1.3 Hyperparameters**
#
# **Hyperparameters** are configuration settings that are external to the model and are not learned from the data during training. Instead, they are set before the training process begins and directly impact the behavior and performance of the model. Examples of hyperparameters include the learning rate, mini-batch size, number of epochs, regularization strength, network architecture, and activation functions.

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 128
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**
#
# The data type for computations is set, and the architecture of the neural network is defined. This includes specifying the number of neurons in each layer, the dimensions of the model, and initializing untrainable layers.

# %% [markdown]
# **CombOpNet Parameters**
#
# Used to specifly the structure of the neural network

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables, including the added constant 1)
dim = training_input.shape[1] 

# The grid size of each dimension
layer_neuron_nums_per_act_fn = [dim] * guess_highest_order_polynomial
print(layer_neuron_nums_per_act_fn)
# Out:
# [20, 20, 20]

# %% [markdown]
# ## **II. Model Training and Execution**
#
# This section of the code contains the implementation of the machine learning model training and evaluation process. After configuring the hyperparameters in the preceding section, this part of the code defines the model architecture, prepares the data, and executes the training process using the specified hyperparameters.

# %% [markdown]
# ### **2.1 Create the CombOpNet Model**

# %%
activation_fns = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = CombOpNet(layer_neuron_nums_per_act_fn, 
                     activations=activation_fns,
                     data_type=MY_DATA_TYPE,
                     weight_initializer=tf.initializers.random_normal(stddev=1e-4),
                     name='CombOpNet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

def reinitialize_model_weights(model):
    if hasattr(model.layers[1], 'reinitialize_weights'):
            model.layers[1].reinitialize_weights()
    else:
        print("CombOpNet does not have a reinitialize_weights() function.")
# Out:
# /opt/anaconda3/envs/tf/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %% [markdown]
# ### **2.2 Loss Function**
#
# Loss functions, also known as cost functions, play a crucial role in the training of neural networks. They measure the difference between the predicted outputs of the network and the actual target values. The goal of training is to minimize this loss, which guides the network towards making more accurate predictions.

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)
 
from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**
#
#
# An optimizer refers to an algorithm or method used to update the parameters (weights and biases) of the model during the training process. The goal of optimization is to minimize a predefined loss function, which measures the discrepancy between the model's predictions and the actual targets.

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate

# %% [markdown]
# ### **2.4 Training with Pruning**
# Gradual pruning is a technique used to reduce the size of a neural network and increase its inference speed without significantly compromising its accuracy. By slowly increasing the sparsity, the network has time to adjust its remaining weights to compensate for the pruned connections, ideally preserving its performance.
#
# **Example Usage**
# - **Overview**: The example demonstrates how to integrate the gradual pruning process into a typical training loop of a TensorFlow model.
# - **Key Steps**:
#   1. A sparsity schedule is initialized using the `gradual_pruning_schedule` function.
#   2. For each training step, the current sparsity level is calculated using the schedule.
#   3. For each dense layer in the model, a binary mask is created using the `create_binary_mask` function with the current sparsity level.
#   4. This mask is applied to the layer's weights using the `prune_weights` function.
#   5. The model undergoes a typical training step, including calculating the loss and updating the weights based on gradients. However, here, an additional step involves applying the binary mask to the gradients as well, ensuring that the pruned connections do not contribute to the gradient updates.
#   6. Periodically, the script prints the current sparsity level to track the progress of pruning.

# %% [markdown]
# ### **2.5 Fit_w_pruning**

# %%
import time
np.set_printoptions(threshold=np.inf)

# Define a training step function
@tf.function
def train_step(model, optimizer, loss_fn, inputs, targets, binary_mask):        
    with tf.GradientTape() as tape:
        # Generate predictions and calculate loss
        predictions = model(inputs, training=False)
        loss = loss_fn(targets, predictions)   
        
    # Calculate gradients and update model weights
    gradients = tape.gradient(loss, model.trainable_variables)        

    # Assuming binary_masks_ones is a list of binary masks created for each trainable variable
    masked_gradients = [tf.multiply(grad, mask) for grad, mask in zip(gradients, binary_mask)]

    optimizer.apply_gradients(zip(masked_gradients, model.trainable_variables))

    return loss

# Define a validation step function
@tf.function
def val_step(model, loss_fn, inputs, targets):
    # Generate predictions and calculate loss for validation data
    predictions = model(inputs, training=False)
    # predictions = model(inputs, training=False) 
    v_loss = loss_fn(targets, predictions)
    # Record the validation loss
    return v_loss   

def CombOPNet_fit_w_pruning(
    model,              # TensorFlow model to be trained
    training_input,     # Input features for training
    training_output,    # Target outputs for training
    batch_size,         # Number of samples per batch of computation
    validation_split,   # Fraction of data to be used as validation set
    epochs,             # Number of complete passes through the training dataset
    optimizer,          # Optimization algorithm for updating weights
    loss_fn,            # Loss function to measure model's performance
    pruning_schedule,   # Pruning schedule for gradually increasing the sparsity level
    data_type='float32',    # Data type of the tensors (default: 'float32')
    callbacks=None,         # List of callbacks for custom actions at various stages of training
    early_stopping_loss_threshold=0,       # Threshold for early stopping based on training and validation loss
    early_stopping_pruning_threshold=0,    # Threshold for early stopping based on pruning schedule
    verbose=0               # Verbosity mode (0 = silent, 1 = progress bar, etc.)
):
    # Cast the training input and output to the specified data type
    training_input = tf.cast(training_input, data_type)
    training_output = tf.cast(training_output, data_type)

    # Shuffle and batch the dataset, then split it into training and validation sets
    full_dataset = tf.data.Dataset.from_tensor_slices((training_input, training_output)).shuffle(buffer_size=1024)
    total_samples = training_input.shape[0]
    train_samples = int(total_samples * (1 - validation_split))
    
    # Apply the data type casting for each batch in the datasets
    train_dataset = full_dataset.take(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))
    val_dataset = full_dataset.skip(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))

    # Initialize metrics for tracking training and validation loss
    train_loss = tf.keras.metrics.Mean(name='train_loss', dtype=data_type)
    val_loss = tf.keras.metrics.Mean(name='val_loss', dtype=data_type)
    
    # Parameters initialization
    binary_mask = [tf.ones_like(var) for var in model.trainable_variables]

    def generate_binary_mask_and_prune_weight(model, pruning_weight_threshold):
        binary_masks = []  # Initialize list to hold binary masks
        
        # Iterate over each variable to apply the pruning threshold and generate masks
        for var in model.trainable_variables:
            # Generate a binary mask where weights above the PRUNING_WEIGHT_THRESHOLD are marked with 1, others with 0
            mask = tf.cast(tf.abs(var) >= pruning_weight_threshold, var.dtype)

            # Update the mask at position (0, 0) to be 1 using tf.tensor_scatter_nd_update (To Avoid the constant term being pruned)
            indices = tf.constant([[0, 0]])  # Specify the indices to update
            updates = tf.constant([1], dtype=mask.dtype)  # Specify the value to update
            mask = tf.tensor_scatter_nd_update(mask, indices, updates)

            binary_masks.append(mask)  # Add the generated mask to the list            

            # Apply mask to modify weights by setting weights below PRUNING_WEIGHT_THRESHOLD to zero
            modified_weight = var * mask
            var.assign(modified_weight)            
        return binary_masks

    # Prepare a dictionary to track the training history
    history = {'loss': [], 'val_loss': []}

    # Before the training loop starts
    if callbacks:
        for callback in callbacks:
            # Assign the model to the callback
            callback.set_model(model)

            # Manually setting params before calling any methods that might depend on them
            callback.params = {
                'epochs': epochs,  # Number of epochs
                # You can add more parameters here as needed
            }

            # Now call on_train_begin with all properties set
            callback.on_train_begin(logs={'loss_threshold': early_stopping_loss_threshold})

    training_start_time = time.time()
    # Execute the training loop
    for epoch in range(epochs):
        # Notify callbacks that the epoch has started
        if callbacks:
            epoch_logs = {}
            for callback in callbacks:
                callback.on_epoch_begin(epoch, logs=epoch_logs)

        if verbose: 
            eopoch_start_time = time.time()

        # Reset state of metrics at the start of each epoch
        train_loss.reset_states()
        val_loss.reset_states()

        # Retrieve the current pruning schedule threshold
        current_pruning_threshold = pruning_schedule[epoch]
        binary_mask = generate_binary_mask_and_prune_weight(model, current_pruning_threshold)
        
        layer_losses_sum = None
        layer_indices = [i for i, layer in enumerate(model.layers) if layer.trainable]
        # Process each batch in the training dataset
        for train_inputs, train_targets in train_dataset:           
            loss = train_step(model = model, 
                            optimizer = optimizer, 
                            loss_fn = loss_fn,
                            inputs = train_inputs, 
                            targets = train_targets, 
                            binary_mask = binary_mask)    
            # Record the loss
            train_loss(loss)

        # Process each batch in the validation dataset
        for val_inputs, val_targets in val_dataset:
            v_loss = val_step(model = model, 
                                loss_fn = loss_fn,
                                inputs = val_inputs, 
                                targets = val_targets)
            val_loss(v_loss)

        # Append the average losses for this epoch to the history
        history['loss'].append(train_loss.result().numpy())
        history['val_loss'].append(val_loss.result().numpy())
        #calculate the average of val_loss
        
        # Current Losses
        current_train_loss = train_loss.result().numpy()
        current_val_loss = val_loss.result().numpy()

        # Notify callbacks that the epoch has ended
        epoch_logs = {'loss': current_train_loss, 'val_loss': current_val_loss}
        if callbacks:
            for callback in callbacks:
                callback.on_epoch_end(epoch, logs=epoch_logs)
    
        if verbose:
            epoch_time = time.time() - eopoch_start_time
            total_layers = len(model.layers)
            trainable_layer_count = sum(1 for layer in model.layers if layer.trainable)
            print(f"Epoch {epoch + 1:3.0f}:"
                f"  Train Loss: {current_train_loss:9.4e}"
                f",  Validation Loss: {current_val_loss:9.4e}"
                # f",  Trainable Layers ({trainable_layer_count}/{total_layers})"
                f",  Epoch Time: {epoch_time:.2f}s"  
                f",  Current Pruning Threshold: {current_pruning_threshold:.5g}")    
            
        if model.stop_training: # Stop training if all the layers are untrianable
            break   

        # Check for early stopping
        if current_train_loss < early_stopping_loss_threshold and current_pruning_threshold > early_stopping_pruning_threshold:
            print(f"Early stopping at epoch {epoch+1} as train loss {current_val_loss:.4f} is below the threshold {early_stopping_loss_threshold:.4f}")
            break


    # After the training loop ends
    training_time = time.time() - training_start_time
    print(f'Traininng Stopped. Time elapsed: {training_time:.2f}s')
    if callbacks:
        for callback in callbacks:
            callback.on_train_end(logs={'final_loss': current_train_loss, 'final_val_loss': current_val_loss})
    

    # Return the history containing training and validation losses
    return history

# %% [markdown]
# ## **III.Training the Model**
#
# The model is trained using the provided training data, batch size, validation split, number of epochs, callbacks, and optimizer. The training progress is monitored, but verbose output is suppressed to keep the output clean.

# %% [markdown]
# #### **Custom Tensorflow Training Loop**
#
# Using the tensorflow steps. This function also includes callback functions

# %%
PRUNING_WEIGHT_THRESHOLD = 0.8 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 6
PRUNING_EPOCHS_PER_PERIOD = 70
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_schedule as ps

# Define the pruning schedule
pruning_schedule = ps.pruning_schedule_ramp(maximum_threshold=PRUNING_WEIGHT_THRESHOLD, 
                                                    steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                                                    num_periods=N_PERIODS, 
                                                    zero_percentage=0.15,
                                                    show_plot=True)

# %%
#Setup
callbacks = []

EARLY_STOPPING_LOSS_THRESHOLD =  0.1  # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.6

training_histories = []
weights_list = []
print(f"Data Size: {training_output.shape}")
# Out:
# Data Size: (25000, 20)

# %%
print(f"Total Dimensions: {training_output.shape[1]}")
for i in range(10, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    reinitialize_model_weights(model)
    output = training_output[:, i:i+1]

    history = CombOPNet_fit_w_pruning(
        model,                   # Model to train
        training_input,             # Input data for training
        output,                     # Output data for training
        batch_size=MINI_BATCH_SIZE, # Number of samples per gradient update
        validation_split=0.20,      # Fraction of the training data to be used as validation data
        epochs=round(NUM_EPOCHS),   # Number of times the entire training dataset is passed through the model
        optimizer=my_optimizer,     # Optimizer to use for training
        pruning_schedule = pruning_schedule, # Pruning schedule for gradually increasing the sparsity level
        loss_fn=loss_fn,            # Loss function to use for training
        data_type=MY_DATA_TYPE,     # Data type to use for training
        callbacks= callbacks,       # List of callbacks to apply during training
        early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,# Threshold for early stopping (Layer Based)
        early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD, # Threshold for early stopping (Pruning Based)
        verbose=1,                   # Hide the epoch steps
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([model.get_layer('CombOpNet').get_weights()])
    #reset the weights
# Out:
# Total Dimensions: 20
# Training dimension 11...
# Epoch   1:  Train Loss: 4.4884e+00,  Validation Loss: 2.0043e+00,  Epoch Time: 0.20s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.5872e+00,  Validation Loss: 1.3656e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.2408e+00,  Validation Loss: 1.1998e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.0754e+00,  Validation Loss: 1.0894e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 9.8888e-01,  Validation Loss: 9.5983e-01,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 9.2178e-01,  Validation Loss: 9.0271e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 8.6423e-01,  Validation Loss: 8.7561e-01,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 8.3880e-01,  Validation Loss: 8.7277e-01,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 8.1187e-01,  Validation Loss: 8.1974e-01,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 7.9617e-01,  Validation Loss: 8.0114e-01,  Epoch Time: 0.18s,  Current Pruning Threshold: 0
# Epoch  11:  Train Loss: 7.8317e-01,  Validation Loss: 8.0618e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  12:  Train Loss: 7.6396e-01,  Validation Loss: 8.0250e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.00075867
# Epoch  13:  Train Loss: 7.5526e-01,  Validation Loss: 7.5337e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0030318
# Epoch  14:  Train Loss: 7.4165e-01,  Validation Loss: 7.3947e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0068108
# Epoch  15:  Train Loss: 7.2889e-01,  Validation Loss: 7.5649e-01,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.012081
# Epoch  16:  Train Loss: 7.1489e-01,  Validation Loss: 7.3402e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.018823
# Epoch  17:  Train Loss: 7.1334e-01,  Validation Loss: 7.2586e-01,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.027011
# Epoch  18:  Train Loss: 7.3402e-01,  Validation Loss: 7.5013e-01,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.036614
# Epoch  19:  Train Loss: 7.5249e-01,  Validation Loss: 7.7994e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.047595
# Epoch  20:  Train Loss: 8.3767e-01,  Validation Loss: 7.9362e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.059913
# Epoch  21:  Train Loss: 9.5174e-01,  Validation Loss: 9.0459e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.073521
# Epoch  22:  Train Loss: 1.1357e+00,  Validation Loss: 1.0313e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.088368
# Epoch  23:  Train Loss: 1.1478e+00,  Validation Loss: 1.0598e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.1044
# Epoch  24:  Train Loss: 1.3035e+00,  Validation Loss: 1.2134e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.12155
# Epoch  25:  Train Loss: 1.2414e+00,  Validation Loss: 1.2380e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.13975
# Epoch  26:  Train Loss: 1.2651e+00,  Validation Loss: 1.1792e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.15895
# Epoch  27:  Train Loss: 1.2286e+00,  Validation Loss: 1.2054e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.17905
# Epoch  28:  Train Loss: 1.2279e+00,  Validation Loss: 1.1743e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.2
# Epoch  29:  Train Loss: 1.2027e+00,  Validation Loss: 1.1766e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.2217
# Epoch  30:  Train Loss: 1.1757e+00,  Validation Loss: 1.1513e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.24409
# Epoch  31:  Train Loss: 1.1597e+00,  Validation Loss: 1.0756e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.26706
# Epoch  32:  Train Loss: 1.1648e+00,  Validation Loss: 1.1314e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.29053
# Epoch  33:  Train Loss: 1.1504e+00,  Validation Loss: 1.1575e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.31443
# Epoch  34:  Train Loss: 1.1452e+00,  Validation Loss: 1.0797e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.33864
# Epoch  35:  Train Loss: 1.2156e+00,  Validation Loss: 1.1905e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.36309
# Epoch  36:  Train Loss: 1.1782e+00,  Validation Loss: 1.1423e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.38768
# Epoch  37:  Train Loss: 1.1842e+00,  Validation Loss: 1.1483e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.41232
# Epoch  38:  Train Loss: 1.1798e+00,  Validation Loss: 1.1317e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.43691
# Epoch  39:  Train Loss: 1.1819e+00,  Validation Loss: 1.1579e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.46136
# Epoch  40:  Train Loss: 1.1673e+00,  Validation Loss: 1.1502e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.48557
# Epoch  41:  Train Loss: 1.1842e+00,  Validation Loss: 1.1639e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.50947
# Epoch  42:  Train Loss: 1.1718e+00,  Validation Loss: 1.1527e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.53294
# Epoch  43:  Train Loss: 1.1846e+00,  Validation Loss: 1.1835e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.55591
# Epoch  44:  Train Loss: 1.1775e+00,  Validation Loss: 1.1186e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.5783
# Epoch  45:  Train Loss: 1.1773e+00,  Validation Loss: 1.2058e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.6
# Epoch  46:  Train Loss: 1.1811e+00,  Validation Loss: 1.1543e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.62095
# Epoch  47:  Train Loss: 1.1831e+00,  Validation Loss: 1.1707e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.64105
# Epoch  48:  Train Loss: 1.1798e+00,  Validation Loss: 1.1389e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.66025
# Epoch  49:  Train Loss: 1.1737e+00,  Validation Loss: 1.1823e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.67845
# Epoch  50:  Train Loss: 1.1897e+00,  Validation Loss: 1.1108e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.6956
# Epoch  51:  Train Loss: 1.1797e+00,  Validation Loss: 1.1418e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.71163
# Epoch  52:  Train Loss: 1.1775e+00,  Validation Loss: 1.1570e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.72648
# Epoch  53:  Train Loss: 1.1740e+00,  Validation Loss: 1.1036e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.74009
# Epoch  54:  Train Loss: 1.1827e+00,  Validation Loss: 1.1126e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.7524
# Epoch  55:  Train Loss: 1.1762e+00,  Validation Loss: 1.2115e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.76339
# Epoch  56:  Train Loss: 1.1730e+00,  Validation Loss: 1.1650e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.77299
# Epoch  57:  Train Loss: 1.1768e+00,  Validation Loss: 1.1232e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.78118
# Epoch  58:  Train Loss: 1.1829e+00,  Validation Loss: 1.2132e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.78792
# Epoch  59:  Train Loss: 1.1859e+00,  Validation Loss: 1.1482e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79319
# Epoch  60:  Train Loss: 1.1747e+00,  Validation Loss: 1.1072e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79697
# Epoch  61:  Train Loss: 1.1853e+00,  Validation Loss: 1.1575e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79924
# Epoch  62:  Train Loss: 1.1685e+00,  Validation Loss: 1.1698e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch  63:  Train Loss: 1.1795e+00,  Validation Loss: 1.2042e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch  64:  Train Loss: 1.1710e+00,  Validation Loss: 1.1671e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch  65:  Train Loss: 1.1744e+00,  Validation Loss: 1.2099e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch  66:  Train Loss: 1.1785e+00,  Validation Loss: 1.1468e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch  67:  Train Loss: 1.1724e+00,  Validation Loss: 1.1812e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch  68:  Train Loss: 1.1770e+00,  Validation Loss: 1.1388e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch  69:  Train Loss: 1.1806e+00,  Validation Loss: 1.1414e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.8
# Epoch  70:  Train Loss: 1.1780e+00,  Validation Loss: 1.1335e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch  71:  Train Loss: 1.2188e+00,  Validation Loss: 1.1172e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  72:  Train Loss: 1.1889e+00,  Validation Loss: 1.1134e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  73:  Train Loss: 1.1593e+00,  Validation Loss: 1.1613e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  74:  Train Loss: 1.1606e+00,  Validation Loss: 1.1275e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  75:  Train Loss: 1.1495e+00,  Validation Loss: 1.1241e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  76:  Train Loss: 1.1482e+00,  Validation Loss: 1.1350e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  77:  Train Loss: 1.1610e+00,  Validation Loss: 1.0980e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  78:  Train Loss: 1.1619e+00,  Validation Loss: 1.1660e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  79:  Train Loss: 1.1502e+00,  Validation Loss: 1.1080e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  80:  Train Loss: 1.1404e+00,  Validation Loss: 1.1064e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  81:  Train Loss: 1.1412e+00,  Validation Loss: 1.1266e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  82:  Train Loss: 1.1469e+00,  Validation Loss: 1.1173e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.00075867
# Epoch  83:  Train Loss: 1.1421e+00,  Validation Loss: 1.0885e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0030318
# Epoch  84:  Train Loss: 1.1360e+00,  Validation Loss: 1.1024e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0068108
# Epoch  85:  Train Loss: 1.1285e+00,  Validation Loss: 1.0806e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.012081
# Epoch  86:  Train Loss: 1.1342e+00,  Validation Loss: 1.1260e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.018823
# Epoch  87:  Train Loss: 1.1501e+00,  Validation Loss: 1.1396e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.027011
# Epoch  88:  Train Loss: 1.1446e+00,  Validation Loss: 1.1710e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.036614
# Epoch  89:  Train Loss: 1.1528e+00,  Validation Loss: 1.1269e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.047595
# Epoch  90:  Train Loss: 1.1843e+00,  Validation Loss: 1.1155e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.059913
# Epoch  91:  Train Loss: 1.1608e+00,  Validation Loss: 1.1297e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.073521
# Epoch  92:  Train Loss: 1.1448e+00,  Validation Loss: 1.1071e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.088368
# Epoch  93:  Train Loss: 1.1531e+00,  Validation Loss: 1.1890e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.1044
# Epoch  94:  Train Loss: 1.1486e+00,  Validation Loss: 1.1287e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.12155
# Epoch  95:  Train Loss: 1.1496e+00,  Validation Loss: 1.1161e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.13975
# Epoch  96:  Train Loss: 1.1457e+00,  Validation Loss: 1.2751e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.15895
# Epoch  97:  Train Loss: 1.1523e+00,  Validation Loss: 1.1451e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.17905
# Epoch  98:  Train Loss: 1.1491e+00,  Validation Loss: 1.1464e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2
# Epoch  99:  Train Loss: 1.1876e+00,  Validation Loss: 1.1792e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2217
# Epoch 100:  Train Loss: 1.1810e+00,  Validation Loss: 1.2197e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.24409
# Epoch 101:  Train Loss: 1.1771e+00,  Validation Loss: 1.1426e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.26706
# Epoch 102:  Train Loss: 1.1768e+00,  Validation Loss: 1.1170e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.29053
# Epoch 103:  Train Loss: 1.1743e+00,  Validation Loss: 1.1579e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.31443
# Epoch 104:  Train Loss: 1.1749e+00,  Validation Loss: 1.1870e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.33864
# Epoch 105:  Train Loss: 1.2107e+00,  Validation Loss: 1.3395e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.36309
# Epoch 106:  Train Loss: 1.1823e+00,  Validation Loss: 1.1447e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.38768
# Epoch 107:  Train Loss: 1.1792e+00,  Validation Loss: 1.2015e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.41232
# Epoch 108:  Train Loss: 1.1719e+00,  Validation Loss: 1.1420e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.43691
# Epoch 109:  Train Loss: 1.1839e+00,  Validation Loss: 1.2147e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.46136
# Epoch 110:  Train Loss: 1.1725e+00,  Validation Loss: 1.1738e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0.48557
# Epoch 111:  Train Loss: 1.1740e+00,  Validation Loss: 1.1801e+00,  Epoch Time: 0.20s,  Current Pruning Threshold: 0.50947
# Epoch 112:  Train Loss: 1.1774e+00,  Validation Loss: 1.1806e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.53294
# Epoch 113:  Train Loss: 1.1797e+00,  Validation Loss: 1.1989e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.55591
# Epoch 114:  Train Loss: 1.1801e+00,  Validation Loss: 1.1377e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.5783
# Epoch 115:  Train Loss: 1.1732e+00,  Validation Loss: 1.1472e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.6
# Epoch 116:  Train Loss: 1.1754e+00,  Validation Loss: 1.1301e+00,  Epoch Time: 0.20s,  Current Pruning Threshold: 0.62095
# Epoch 117:  Train Loss: 1.1717e+00,  Validation Loss: 1.1443e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0.64105
# Epoch 118:  Train Loss: 1.1704e+00,  Validation Loss: 1.1432e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.66025
# Epoch 119:  Train Loss: 1.1738e+00,  Validation Loss: 1.2255e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0.67845
# Epoch 120:  Train Loss: 1.1963e+00,  Validation Loss: 1.1498e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0.6956
# Epoch 121:  Train Loss: 1.1765e+00,  Validation Loss: 1.1602e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0.71163
# Epoch 122:  Train Loss: 1.1659e+00,  Validation Loss: 1.1820e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0.72648
# Epoch 123:  Train Loss: 1.1798e+00,  Validation Loss: 1.1157e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.74009
# Epoch 124:  Train Loss: 1.1793e+00,  Validation Loss: 1.1289e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.7524
# Epoch 125:  Train Loss: 1.1720e+00,  Validation Loss: 1.1986e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.76339
# Epoch 126:  Train Loss: 1.1854e+00,  Validation Loss: 1.2264e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.77299
# Epoch 127:  Train Loss: 1.1821e+00,  Validation Loss: 1.1394e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.78118
# Epoch 128:  Train Loss: 1.1719e+00,  Validation Loss: 1.2851e+00,  Epoch Time: 0.26s,  Current Pruning Threshold: 0.78792
# Epoch 129:  Train Loss: 1.1681e+00,  Validation Loss: 1.1273e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.79319
# Epoch 130:  Train Loss: 1.1832e+00,  Validation Loss: 1.1754e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.79697
# Epoch 131:  Train Loss: 1.1698e+00,  Validation Loss: 1.1299e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.79924
# Epoch 132:  Train Loss: 1.1881e+00,  Validation Loss: 1.1368e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 133:  Train Loss: 1.1908e+00,  Validation Loss: 1.2307e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 134:  Train Loss: 1.1761e+00,  Validation Loss: 1.1551e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 135:  Train Loss: 1.1753e+00,  Validation Loss: 1.1747e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 136:  Train Loss: 1.1900e+00,  Validation Loss: 1.1688e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 137:  Train Loss: 1.1802e+00,  Validation Loss: 1.1241e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 138:  Train Loss: 1.1843e+00,  Validation Loss: 1.2487e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 139:  Train Loss: 1.1926e+00,  Validation Loss: 1.3327e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 140:  Train Loss: 1.1795e+00,  Validation Loss: 1.1683e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0.8
# Epoch 141:  Train Loss: 1.2063e+00,  Validation Loss: 1.1447e+00,  Epoch Time: 0.22s,  Current Pruning Threshold: 0
# Epoch 142:  Train Loss: 1.1732e+00,  Validation Loss: 1.1908e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0
# Epoch 143:  Train Loss: 1.1697e+00,  Validation Loss: 1.1295e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0
# Epoch 144:  Train Loss: 1.1652e+00,  Validation Loss: 1.1710e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 145:  Train Loss: 1.1530e+00,  Validation Loss: 1.1185e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 146:  Train Loss: 1.1595e+00,  Validation Loss: 1.0815e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 147:  Train Loss: 1.1480e+00,  Validation Loss: 1.1895e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 148:  Train Loss: 1.1501e+00,  Validation Loss: 1.1447e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 149:  Train Loss: 1.1519e+00,  Validation Loss: 1.1049e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 150:  Train Loss: 1.1520e+00,  Validation Loss: 1.1201e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 151:  Train Loss: 1.1525e+00,  Validation Loss: 1.1151e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 152:  Train Loss: 1.1579e+00,  Validation Loss: 1.1034e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.00075867
# Epoch 153:  Train Loss: 1.1460e+00,  Validation Loss: 1.0792e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0030318
# Epoch 154:  Train Loss: 1.1437e+00,  Validation Loss: 1.1269e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0068108
# Epoch 155:  Train Loss: 1.1349e+00,  Validation Loss: 1.0653e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.012081
# Epoch 156:  Train Loss: 1.1428e+00,  Validation Loss: 1.1349e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.018823
# Epoch 157:  Train Loss: 1.1373e+00,  Validation Loss: 1.0794e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.027011
# Epoch 158:  Train Loss: 1.1551e+00,  Validation Loss: 1.1357e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.036614
# Epoch 159:  Train Loss: 1.1456e+00,  Validation Loss: 1.1351e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.047595
# Epoch 160:  Train Loss: 1.1562e+00,  Validation Loss: 1.1207e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0.059913
# Epoch 161:  Train Loss: 1.1612e+00,  Validation Loss: 1.1042e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.073521
# Epoch 162:  Train Loss: 1.1515e+00,  Validation Loss: 1.0902e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.088368
# Epoch 163:  Train Loss: 1.1631e+00,  Validation Loss: 1.1583e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.1044
# Epoch 164:  Train Loss: 1.1557e+00,  Validation Loss: 1.0920e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.12155
# Epoch 165:  Train Loss: 1.1508e+00,  Validation Loss: 1.1072e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.13975
# Epoch 166:  Train Loss: 1.1512e+00,  Validation Loss: 1.1477e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.15895
# Epoch 167:  Train Loss: 1.1570e+00,  Validation Loss: 1.1320e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.17905
# Epoch 168:  Train Loss: 1.1474e+00,  Validation Loss: 1.2364e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2
# Epoch 169:  Train Loss: 1.1532e+00,  Validation Loss: 1.1098e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2217
# Epoch 170:  Train Loss: 1.1756e+00,  Validation Loss: 1.1614e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.24409
# Epoch 171:  Train Loss: 1.1851e+00,  Validation Loss: 1.1519e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.26706
# Epoch 172:  Train Loss: 1.1789e+00,  Validation Loss: 1.1212e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.29053
# Epoch 173:  Train Loss: 1.1801e+00,  Validation Loss: 1.1630e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.31443
# Epoch 174:  Train Loss: 1.1718e+00,  Validation Loss: 1.1560e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.33864
# Epoch 175:  Train Loss: 1.1862e+00,  Validation Loss: 1.2272e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.36309
# Epoch 176:  Train Loss: 1.1748e+00,  Validation Loss: 1.1442e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.38768
# Epoch 177:  Train Loss: 1.1846e+00,  Validation Loss: 1.1172e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.41232
# Epoch 178:  Train Loss: 1.1760e+00,  Validation Loss: 1.1273e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.43691
# Epoch 179:  Train Loss: 1.1830e+00,  Validation Loss: 1.1633e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.46136
# Epoch 180:  Train Loss: 1.1820e+00,  Validation Loss: 1.1374e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.48557
# Epoch 181:  Train Loss: 1.1782e+00,  Validation Loss: 1.1383e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.50947
# Epoch 182:  Train Loss: 1.1736e+00,  Validation Loss: 1.1781e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.53294
# Epoch 183:  Train Loss: 1.1783e+00,  Validation Loss: 1.1031e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.55591
# Epoch 184:  Train Loss: 1.1749e+00,  Validation Loss: 1.1539e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.5783
# Epoch 185:  Train Loss: 1.1807e+00,  Validation Loss: 1.2141e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.6
# Epoch 186:  Train Loss: 1.1700e+00,  Validation Loss: 1.1449e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.62095
# Epoch 187:  Train Loss: 1.1781e+00,  Validation Loss: 1.1447e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.64105
# Epoch 188:  Train Loss: 1.1778e+00,  Validation Loss: 1.1575e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.66025
# Epoch 189:  Train Loss: 1.1835e+00,  Validation Loss: 1.1688e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.67845
# Epoch 190:  Train Loss: 1.1933e+00,  Validation Loss: 1.1855e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.6956
# Epoch 191:  Train Loss: 1.1795e+00,  Validation Loss: 1.1629e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.71163
# Epoch 192:  Train Loss: 1.1795e+00,  Validation Loss: 1.1920e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.72648
# Epoch 193:  Train Loss: 1.2051e+00,  Validation Loss: 1.1248e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.74009
# Epoch 194:  Train Loss: 1.1823e+00,  Validation Loss: 1.2057e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.7524
# Epoch 195:  Train Loss: 1.1815e+00,  Validation Loss: 1.1669e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.76339
# Epoch 196:  Train Loss: 1.1763e+00,  Validation Loss: 1.1648e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.77299
# Epoch 197:  Train Loss: 1.1787e+00,  Validation Loss: 1.1426e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.78118
# Epoch 198:  Train Loss: 1.1709e+00,  Validation Loss: 1.1903e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.78792
# Epoch 199:  Train Loss: 1.1754e+00,  Validation Loss: 1.1490e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79319
# Epoch 200:  Train Loss: 1.1844e+00,  Validation Loss: 1.1767e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79697
# Epoch 201:  Train Loss: 1.1814e+00,  Validation Loss: 1.1283e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79924
# Epoch 202:  Train Loss: 1.1792e+00,  Validation Loss: 1.1511e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 203:  Train Loss: 1.1749e+00,  Validation Loss: 1.1359e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 204:  Train Loss: 1.1762e+00,  Validation Loss: 1.1855e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 205:  Train Loss: 1.1843e+00,  Validation Loss: 1.1648e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 206:  Train Loss: 1.1761e+00,  Validation Loss: 1.1584e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 207:  Train Loss: 1.1829e+00,  Validation Loss: 1.1816e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 208:  Train Loss: 1.2092e+00,  Validation Loss: 1.1806e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 209:  Train Loss: 1.1726e+00,  Validation Loss: 1.2263e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 210:  Train Loss: 1.1878e+00,  Validation Loss: 1.1187e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.8
# Epoch 211:  Train Loss: 1.2204e+00,  Validation Loss: 1.1309e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 212:  Train Loss: 1.1564e+00,  Validation Loss: 1.1499e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 213:  Train Loss: 1.1635e+00,  Validation Loss: 1.1361e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 214:  Train Loss: 1.1602e+00,  Validation Loss: 1.0832e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 215:  Train Loss: 1.1608e+00,  Validation Loss: 1.1186e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0
# Epoch 216:  Train Loss: 1.1511e+00,  Validation Loss: 1.1888e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 217:  Train Loss: 1.1468e+00,  Validation Loss: 1.1394e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 218:  Train Loss: 1.1458e+00,  Validation Loss: 1.1124e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 219:  Train Loss: 1.1437e+00,  Validation Loss: 1.0941e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 220:  Train Loss: 1.1493e+00,  Validation Loss: 1.1359e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 221:  Train Loss: 1.1385e+00,  Validation Loss: 1.1307e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 222:  Train Loss: 1.1453e+00,  Validation Loss: 1.1098e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.00075867
# Epoch 223:  Train Loss: 1.1393e+00,  Validation Loss: 1.1118e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0030318
# Epoch 224:  Train Loss: 1.1312e+00,  Validation Loss: 1.1107e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.0068108
# Epoch 225:  Train Loss: 1.1363e+00,  Validation Loss: 1.1589e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.012081
# Epoch 226:  Train Loss: 1.1354e+00,  Validation Loss: 1.2408e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.018823
# Epoch 227:  Train Loss: 1.1419e+00,  Validation Loss: 1.1248e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.027011
# Epoch 228:  Train Loss: 1.1484e+00,  Validation Loss: 1.1613e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.036614
# Epoch 229:  Train Loss: 1.1629e+00,  Validation Loss: 1.1521e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.047595
# Epoch 230:  Train Loss: 1.1513e+00,  Validation Loss: 1.0902e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.059913
# Epoch 231:  Train Loss: 1.1495e+00,  Validation Loss: 1.1082e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0.073521
# Epoch 232:  Train Loss: 1.1501e+00,  Validation Loss: 1.0930e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.088368
# Epoch 233:  Train Loss: 1.1532e+00,  Validation Loss: 1.1018e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.1044
# Epoch 234:  Train Loss: 1.1400e+00,  Validation Loss: 1.1414e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.12155
# Epoch 235:  Train Loss: 1.1461e+00,  Validation Loss: 1.1477e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.13975
# Epoch 236:  Train Loss: 1.1675e+00,  Validation Loss: 1.1243e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.15895
# Epoch 237:  Train Loss: 1.1459e+00,  Validation Loss: 1.1315e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.17905
# Epoch 238:  Train Loss: 1.1574e+00,  Validation Loss: 1.1094e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2
# Epoch 239:  Train Loss: 1.1481e+00,  Validation Loss: 1.1188e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2217
# Epoch 240:  Train Loss: 1.2054e+00,  Validation Loss: 1.1317e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.24409
# Epoch 241:  Train Loss: 1.1797e+00,  Validation Loss: 1.1660e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.26706
# Epoch 242:  Train Loss: 1.1741e+00,  Validation Loss: 1.2145e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.29053
# Epoch 243:  Train Loss: 1.1734e+00,  Validation Loss: 1.1607e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.31443
# Epoch 244:  Train Loss: 1.1810e+00,  Validation Loss: 1.1194e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.33864
# Epoch 245:  Train Loss: 1.1733e+00,  Validation Loss: 1.2228e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.36309
# Epoch 246:  Train Loss: 1.1773e+00,  Validation Loss: 1.1741e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.38768
# Epoch 247:  Train Loss: 1.1850e+00,  Validation Loss: 1.1371e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.41232
# Epoch 248:  Train Loss: 1.1725e+00,  Validation Loss: 1.1706e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.43691
# Epoch 249:  Train Loss: 1.1733e+00,  Validation Loss: 1.1458e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.46136
# Epoch 250:  Train Loss: 1.1726e+00,  Validation Loss: 1.1446e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.48557
# Epoch 251:  Train Loss: 1.1711e+00,  Validation Loss: 1.1213e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.50947
# Epoch 252:  Train Loss: 1.1765e+00,  Validation Loss: 1.1438e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.53294
# Epoch 253:  Train Loss: 1.1848e+00,  Validation Loss: 1.1822e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.55591
# Epoch 254:  Train Loss: 1.1826e+00,  Validation Loss: 1.1543e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.5783
# Epoch 255:  Train Loss: 1.1737e+00,  Validation Loss: 1.1541e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.6
# Epoch 256:  Train Loss: 1.1783e+00,  Validation Loss: 1.1688e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.62095
# Epoch 257:  Train Loss: 1.1851e+00,  Validation Loss: 1.1885e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.64105
# Epoch 258:  Train Loss: 1.1715e+00,  Validation Loss: 1.1592e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.66025
# Epoch 259:  Train Loss: 1.1805e+00,  Validation Loss: 1.1557e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.67845
# Epoch 260:  Train Loss: 1.1771e+00,  Validation Loss: 1.2700e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.6956
# Epoch 261:  Train Loss: 1.1685e+00,  Validation Loss: 1.1176e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.71163
# Epoch 262:  Train Loss: 1.1744e+00,  Validation Loss: 1.1466e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.72648
# Epoch 263:  Train Loss: 1.1707e+00,  Validation Loss: 1.1865e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.74009
# Epoch 264:  Train Loss: 1.1795e+00,  Validation Loss: 1.1402e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.7524
# Epoch 265:  Train Loss: 1.1846e+00,  Validation Loss: 1.1101e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.76339
# Epoch 266:  Train Loss: 1.1794e+00,  Validation Loss: 1.1464e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.77299
# Epoch 267:  Train Loss: 1.1929e+00,  Validation Loss: 1.1680e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.78118
# Epoch 268:  Train Loss: 1.1783e+00,  Validation Loss: 1.1698e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.78792
# Epoch 269:  Train Loss: 1.1799e+00,  Validation Loss: 1.1659e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79319
# Epoch 270:  Train Loss: 1.1724e+00,  Validation Loss: 1.2019e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79697
# Epoch 271:  Train Loss: 1.1892e+00,  Validation Loss: 1.1670e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79924
# Epoch 272:  Train Loss: 1.1762e+00,  Validation Loss: 1.1221e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 273:  Train Loss: 1.1763e+00,  Validation Loss: 1.2889e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 274:  Train Loss: 1.1764e+00,  Validation Loss: 1.1458e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 275:  Train Loss: 1.1921e+00,  Validation Loss: 1.1594e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 276:  Train Loss: 1.1755e+00,  Validation Loss: 1.1029e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 277:  Train Loss: 1.1767e+00,  Validation Loss: 1.1332e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 278:  Train Loss: 1.1726e+00,  Validation Loss: 1.1274e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 279:  Train Loss: 1.1876e+00,  Validation Loss: 1.1142e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.8
# Epoch 280:  Train Loss: 1.1656e+00,  Validation Loss: 1.1441e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 281:  Train Loss: 1.2093e+00,  Validation Loss: 1.1261e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 282:  Train Loss: 1.1796e+00,  Validation Loss: 1.1155e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 283:  Train Loss: 1.1665e+00,  Validation Loss: 1.1572e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 284:  Train Loss: 1.1595e+00,  Validation Loss: 1.1336e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 285:  Train Loss: 1.1498e+00,  Validation Loss: 1.1426e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 286:  Train Loss: 1.1573e+00,  Validation Loss: 1.2443e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 287:  Train Loss: 1.1403e+00,  Validation Loss: 1.0921e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 288:  Train Loss: 1.1393e+00,  Validation Loss: 1.1402e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 289:  Train Loss: 1.1327e+00,  Validation Loss: 1.1039e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 290:  Train Loss: 1.1806e+00,  Validation Loss: 1.0696e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 291:  Train Loss: 1.1555e+00,  Validation Loss: 1.1304e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 292:  Train Loss: 1.1624e+00,  Validation Loss: 1.0995e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.00075867
# Epoch 293:  Train Loss: 1.1381e+00,  Validation Loss: 1.2152e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0030318
# Epoch 294:  Train Loss: 1.1417e+00,  Validation Loss: 1.0922e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0068108
# Epoch 295:  Train Loss: 1.1286e+00,  Validation Loss: 1.1886e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.012081
# Epoch 296:  Train Loss: 1.1428e+00,  Validation Loss: 1.1631e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.018823
# Epoch 297:  Train Loss: 1.1464e+00,  Validation Loss: 1.0920e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.027011
# Epoch 298:  Train Loss: 1.1458e+00,  Validation Loss: 1.1199e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.036614
# Epoch 299:  Train Loss: 1.1491e+00,  Validation Loss: 1.0786e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.047595
# Epoch 300:  Train Loss: 1.1603e+00,  Validation Loss: 1.1008e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.059913
# Epoch 301:  Train Loss: 1.1547e+00,  Validation Loss: 1.1837e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.073521
# Epoch 302:  Train Loss: 1.1525e+00,  Validation Loss: 1.1172e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.088368
# Epoch 303:  Train Loss: 1.1626e+00,  Validation Loss: 1.1056e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.1044
# Epoch 304:  Train Loss: 1.1552e+00,  Validation Loss: 1.1522e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.12155
# Epoch 305:  Train Loss: 1.1569e+00,  Validation Loss: 1.1367e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.13975
# Epoch 306:  Train Loss: 1.1601e+00,  Validation Loss: 1.1127e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.15895
# Epoch 307:  Train Loss: 1.1531e+00,  Validation Loss: 1.1413e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.17905
# Epoch 308:  Train Loss: 1.1537e+00,  Validation Loss: 1.1013e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2
# Epoch 309:  Train Loss: 1.1630e+00,  Validation Loss: 1.1194e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2217
# Epoch 310:  Train Loss: 1.1955e+00,  Validation Loss: 1.1629e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.24409
# Epoch 311:  Train Loss: 1.1748e+00,  Validation Loss: 1.0923e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.26706
# Epoch 312:  Train Loss: 1.1820e+00,  Validation Loss: 1.1386e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.29053
# Epoch 313:  Train Loss: 1.1685e+00,  Validation Loss: 1.1406e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.31443
# Epoch 314:  Train Loss: 1.1841e+00,  Validation Loss: 1.1948e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.33864
# Epoch 315:  Train Loss: 1.1973e+00,  Validation Loss: 1.1508e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.36309
# Epoch 316:  Train Loss: 1.1860e+00,  Validation Loss: 1.1158e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.38768
# Epoch 317:  Train Loss: 1.1767e+00,  Validation Loss: 1.1491e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.41232
# Epoch 318:  Train Loss: 1.2072e+00,  Validation Loss: 1.1980e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.43691
# Epoch 319:  Train Loss: 1.1783e+00,  Validation Loss: 1.1595e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.46136
# Epoch 320:  Train Loss: 1.1831e+00,  Validation Loss: 1.1644e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.48557
# Epoch 321:  Train Loss: 1.1819e+00,  Validation Loss: 1.1520e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.50947
# Epoch 322:  Train Loss: 1.1729e+00,  Validation Loss: 1.1448e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.53294
# Epoch 323:  Train Loss: 1.1724e+00,  Validation Loss: 1.1351e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.55591
# Epoch 324:  Train Loss: 1.1987e+00,  Validation Loss: 1.2208e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.5783
# Epoch 325:  Train Loss: 1.1710e+00,  Validation Loss: 1.1342e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.6
# Epoch 326:  Train Loss: 1.1842e+00,  Validation Loss: 1.1695e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.62095
# Epoch 327:  Train Loss: 1.1745e+00,  Validation Loss: 1.1502e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.64105
# Epoch 328:  Train Loss: 1.1800e+00,  Validation Loss: 1.1369e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.66025
# Epoch 329:  Train Loss: 1.1900e+00,  Validation Loss: 1.1018e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.67845
# Epoch 330:  Train Loss: 1.1822e+00,  Validation Loss: 1.2020e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.6956
# Epoch 331:  Train Loss: 1.1681e+00,  Validation Loss: 1.1652e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.71163
# Epoch 332:  Train Loss: 1.1858e+00,  Validation Loss: 1.1516e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.72648
# Epoch 333:  Train Loss: 1.1713e+00,  Validation Loss: 1.2065e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.74009
# Epoch 334:  Train Loss: 1.1827e+00,  Validation Loss: 1.1254e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.7524
# Epoch 335:  Train Loss: 1.1808e+00,  Validation Loss: 1.2304e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.76339
# Epoch 336:  Train Loss: 1.1851e+00,  Validation Loss: 1.1645e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.77299
# Epoch 337:  Train Loss: 1.1723e+00,  Validation Loss: 1.1707e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.78118
# Epoch 338:  Train Loss: 1.1753e+00,  Validation Loss: 1.2425e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.78792
# Epoch 339:  Train Loss: 1.1834e+00,  Validation Loss: 1.0996e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79319
# Epoch 340:  Train Loss: 1.1769e+00,  Validation Loss: 1.1455e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79697
# Epoch 341:  Train Loss: 1.1774e+00,  Validation Loss: 1.1662e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79924
# Epoch 342:  Train Loss: 1.1772e+00,  Validation Loss: 1.2103e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.8
# Epoch 343:  Train Loss: 1.1927e+00,  Validation Loss: 1.1308e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 344:  Train Loss: 1.1739e+00,  Validation Loss: 1.1137e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 345:  Train Loss: 1.1639e+00,  Validation Loss: 1.1026e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 346:  Train Loss: 1.1843e+00,  Validation Loss: 1.1188e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 347:  Train Loss: 1.1841e+00,  Validation Loss: 1.1585e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 348:  Train Loss: 1.1706e+00,  Validation Loss: 1.1630e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 349:  Train Loss: 1.1605e+00,  Validation Loss: 1.1798e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 350:  Train Loss: 1.1818e+00,  Validation Loss: 1.1287e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 351:  Train Loss: 1.2063e+00,  Validation Loss: 1.1688e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 352:  Train Loss: 1.1729e+00,  Validation Loss: 1.1688e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 353:  Train Loss: 1.1561e+00,  Validation Loss: 1.0947e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch 354:  Train Loss: 1.1652e+00,  Validation Loss: 1.0828e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 355:  Train Loss: 1.1673e+00,  Validation Loss: 1.0969e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 356:  Train Loss: 1.1502e+00,  Validation Loss: 1.1832e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 357:  Train Loss: 1.1420e+00,  Validation Loss: 1.1577e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 358:  Train Loss: 1.1418e+00,  Validation Loss: 1.1071e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 359:  Train Loss: 1.1334e+00,  Validation Loss: 1.2319e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 360:  Train Loss: 1.1367e+00,  Validation Loss: 1.1014e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 361:  Train Loss: 1.1505e+00,  Validation Loss: 1.0799e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch 362:  Train Loss: 1.1571e+00,  Validation Loss: 1.0906e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.00075867
# Epoch 363:  Train Loss: 1.1401e+00,  Validation Loss: 1.1481e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0030318
# Epoch 364:  Train Loss: 1.1418e+00,  Validation Loss: 1.1259e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.0068108
# Epoch 365:  Train Loss: 1.1415e+00,  Validation Loss: 1.0807e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.012081
# Epoch 366:  Train Loss: 1.1434e+00,  Validation Loss: 1.1131e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.018823
# Epoch 367:  Train Loss: 1.1453e+00,  Validation Loss: 1.0756e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.027011
# Epoch 368:  Train Loss: 1.1492e+00,  Validation Loss: 1.0713e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.036614
# Epoch 369:  Train Loss: 1.1656e+00,  Validation Loss: 1.1645e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.047595
# Epoch 370:  Train Loss: 1.1597e+00,  Validation Loss: 1.1484e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.059913
# Epoch 371:  Train Loss: 1.1532e+00,  Validation Loss: 1.1032e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.073521
# Epoch 372:  Train Loss: 1.1466e+00,  Validation Loss: 1.1715e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.088368
# Epoch 373:  Train Loss: 1.1526e+00,  Validation Loss: 1.0890e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.1044
# Epoch 374:  Train Loss: 1.1450e+00,  Validation Loss: 1.3012e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.12155
# Epoch 375:  Train Loss: 1.1554e+00,  Validation Loss: 1.0930e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.13975
# Epoch 376:  Train Loss: 1.1483e+00,  Validation Loss: 1.1513e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.15895
# Epoch 377:  Train Loss: 1.1541e+00,  Validation Loss: 1.1270e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.17905
# Epoch 378:  Train Loss: 1.1512e+00,  Validation Loss: 1.1003e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2
# Epoch 379:  Train Loss: 1.1534e+00,  Validation Loss: 1.1201e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.2217
# Epoch 380:  Train Loss: 1.1942e+00,  Validation Loss: 1.1533e+00,  Epoch Time: 0.20s,  Current Pruning Threshold: 0.24409
# Epoch 381:  Train Loss: 1.1819e+00,  Validation Loss: 1.1349e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.26706
# Epoch 382:  Train Loss: 1.1835e+00,  Validation Loss: 1.2204e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.29053
# Epoch 383:  Train Loss: 1.1808e+00,  Validation Loss: 1.1640e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.31443
# Epoch 384:  Train Loss: 1.1839e+00,  Validation Loss: 1.1726e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.33864
# Epoch 385:  Train Loss: 1.1754e+00,  Validation Loss: 1.1253e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.36309
# Epoch 386:  Train Loss: 1.1754e+00,  Validation Loss: 1.1983e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.38768
# Epoch 387:  Train Loss: 1.1784e+00,  Validation Loss: 1.1854e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.41232
# Epoch 388:  Train Loss: 1.1780e+00,  Validation Loss: 1.1536e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.43691
# Epoch 389:  Train Loss: 1.1758e+00,  Validation Loss: 1.1785e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.46136
# Epoch 390:  Train Loss: 1.1778e+00,  Validation Loss: 1.1341e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.48557
# Epoch 391:  Train Loss: 1.1711e+00,  Validation Loss: 1.1586e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.50947
# Epoch 392:  Train Loss: 1.1726e+00,  Validation Loss: 1.1730e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.53294
# Epoch 393:  Train Loss: 1.1801e+00,  Validation Loss: 1.1369e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.55591
# Epoch 394:  Train Loss: 1.1870e+00,  Validation Loss: 1.1674e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.5783
# Epoch 395:  Train Loss: 1.1788e+00,  Validation Loss: 1.1439e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.6
# Epoch 396:  Train Loss: 1.1728e+00,  Validation Loss: 1.1635e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.62095
# Epoch 397:  Train Loss: 1.1739e+00,  Validation Loss: 1.1170e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.64105
# Epoch 398:  Train Loss: 1.1711e+00,  Validation Loss: 1.1184e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.66025
# Epoch 399:  Train Loss: 1.1847e+00,  Validation Loss: 1.1846e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.67845
# Epoch 400:  Train Loss: 1.1782e+00,  Validation Loss: 1.2711e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.6956
# Epoch 401:  Train Loss: 1.1763e+00,  Validation Loss: 1.1782e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.71163
# Epoch 402:  Train Loss: 1.1856e+00,  Validation Loss: 1.1157e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.72648
# Epoch 403:  Train Loss: 1.1666e+00,  Validation Loss: 1.1466e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.74009
# Epoch 404:  Train Loss: 1.1811e+00,  Validation Loss: 1.1443e+00,  Epoch Time: 0.19s,  Current Pruning Threshold: 0.7524
# Epoch 405:  Train Loss: 1.1828e+00,  Validation Loss: 1.1386e+00,  Epoch Time: 0.21s,  Current Pruning Threshold: 0.76339
# Epoch 406:  Train Loss: 1.1963e+00,  Validation Loss: 1.0940e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.77299
# Epoch 407:  Train Loss: 1.1882e+00,  Validation Loss: 1.2266e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.78118
# Epoch 408:  Train Loss: 1.1753e+00,  Validation Loss: 1.0871e+00,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.78792
# Epoch 409:  Train Loss: 1.1897e+00,  Validation Loss: 1.1642e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0.79319
# Epoch 410:  Train Loss: 1.1711e+00,  Validation Loss: 1.1382e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79697
# Epoch 411:  Train Loss: 1.1857e+00,  Validation Loss: 1.1797e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.79924
# Epoch 412:  Train Loss: 1.1796e+00,  Validation Loss: 1.3285e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 413:  Train Loss: 1.1757e+00,  Validation Loss: 1.1596e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 414:  Train Loss: 1.1839e+00,  Validation Loss: 1.1279e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 415:  Train Loss: 1.1836e+00,  Validation Loss: 1.1592e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 416:  Train Loss: 1.1916e+00,  Validation Loss: 1.1417e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 417:  Train Loss: 1.1737e+00,  Validation Loss: 1.1502e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 418:  Train Loss: 1.1706e+00,  Validation Loss: 1.1888e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 419:  Train Loss: 1.1813e+00,  Validation Loss: 1.1373e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Epoch 420:  Train Loss: 1.1722e+00,  Validation Loss: 1.1151e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.8
# Traininng Stopped. Time elapsed: 69.72s
# Training dimension 12...
# Epoch   1:  Train Loss: 5.0894e+00,  Validation Loss: 1.9928e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.6530e+00,  Validation Loss: 1.4921e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.3590e+00,  Validation Loss: 1.3033e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.2263e+00,  Validation Loss: 1.2143e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 1.1542e+00,  Validation Loss: 1.1596e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 1.0935e+00,  Validation Loss: 1.1263e+00,  Epoch Time: 0.17s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 1.0500e+00,  Validation Loss: 1.0779e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 1.0204e+00,  Validation Loss: 1.0241e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 9.8777e-01,  Validation Loss: 1.0250e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 9.7240e-01,  Validation Loss: 1.0335e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  11:  Train Loss: 9.6145e-01,  Validation Loss: 1.0087e+00,  Epoch Time: 0.16s,  Current Pruning Threshold: 0
# Epoch  12:  Train Loss: 9.3784e-01,  Validation Loss: 9.6554e-01,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.00075867
# Epoch  13:  Train Loss: 9.2602e-01,  Validation Loss: 9.7736e-01,  Epoch Time: 0.18s,  Current Pruning Threshold: 0.0030318
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 7
#       4 reinitialize_model_weights(model)
#       5 output = training_output[:, i:i+1]
# ----> 7 history = CombOPNet_fit_w_pruning(
#       8     model,                   # Model to train
#       9     training_input,             # Input data for training
#      10     output,                     # Output data for training
#      11     batch_size=MINI_BATCH_SIZE, # Number of samples per gradient update
#      12     validation_split=0.20,      # Fraction of the training data to be used as validation data
#      13     epochs=round(NUM_EPOCHS),   # Number of times the entire training dataset is passed through the model
#      14     optimizer=my_optimizer,     # Optimizer to use for training
#      15     pruning_schedule = pruning_schedule, # Pruning schedule for gradually increasing the sparsity level
#      16     loss_fn=loss_fn,            # Loss function to use for training
#      17     data_type=MY_DATA_TYPE,     # Data type to use for training
#      18     callbacks= callbacks,       # List of callbacks to apply during training
#      19     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,# Threshold for early stopping (Layer Based)
#      20     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD, # Threshold for early stopping (Pruning Based)
#      21     verbose=1,                   # Hide the epoch steps
#      22 )
#      23 training_histories.append(history)
#      25 # Retrieve the weights of the trained model
#
# Cell In[43], line 141, in CombOPNet_fit_w_pruning(model, training_input, training_output, batch_size, validation_split, epochs, optimizer, loss_fn, pruning_schedule, data_type, callbacks, early_stopping_loss_threshold, early_stopping_pruning_threshold, verbose)
#     139 # Process each batch in the validation dataset
#     140 for val_inputs, val_targets in val_dataset:
# --> 141     v_loss = val_step(model = model,
#     142                         loss_fn = loss_fn,
#     143                         inputs = val_inputs,
#     144                         targets = val_targets)
#     145     val_loss(v_loss)
#     147 # Append the average losses for this epoch to the history
#
# File /opt/anaconda3/envs/tf/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/anaconda3/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File /opt/anaconda3/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /opt/anaconda3/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/anaconda3/envs/tf/lib/python3.10/site-packages/tensorflow/python/eager/function.py:536, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     527         outputs = functional_ops.partitioned_call(
#     528             args=args,
#     529             f=self,
#    (...)
#     532             config=config,
#     533             executor_type=executor_type)
#     535 for i, func_graph_output in enumerate(self._func_graph_outputs):
# --> 536   handle_data_util.copy_handle_data(func_graph_output, outputs[i])
#     537 if executing_eagerly:
#     538   return outputs
#
# File /opt/anaconda3/envs/tf/lib/python3.10/site-packages/tensorflow/python/ops/handle_data_util.py:41, in copy_handle_data(source_t, target_t)
#      25 def copy_handle_data(source_t, target_t):
#      26   """Copies HandleData for variant and resource type tensors if available.
#      27
#      28   The CppShapeInferenceResult::HandleData proto contains information about the
#    (...)
#      38     target_t: The tensor to copy HandleData to.
#      39   """
#      40   if (target_t.dtype == dtypes.resource or
# ---> 41       target_t.dtype == dtypes.variant):
#      42     if isinstance(source_t, ops.EagerTensor):
#      43       handle_data = source_t._handle_data  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualizing weights during training

# %% [markdown]
# ## **IV. Analysis**
#
# In this section, the code displays the results of the trained machine learning model, including performance metrics, visualizations, and any comparisons to the actual SINDy network or other relevant discussions. It may include visualizations of model predictions, comparisons between predicted and actual values, and discussions on the model's strengths, limitations, and potential areas for improvement.

# %% [markdown]
# ### **Coefficient Reconstructor (CombOpNet)**
#
# This function is designed to extract and represent the multiplicative relationships between neurons across layers in a neural network, focusing on the paths that contribute significantly to the network's output.

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_set_labels(N):
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`
# 1. **Input Structure Handling**: The function takes `combopnet_weights`, a nested list that represents the weights of a segmented or parallel neural network (combopnet). This list is structured to encapsulate multiple combopnets, each containing multiple layers, where each layer consists of neurons connected to the next layer through weights.
#
# 2. **Unique Prime Number Assignment**:
#     - Each neuron in the network is assigned a unique prime number, not based on its layer or combopnet index but purely on its neuron index across the entire network. This assignment is crucial for generating unique keys in the output dictionary, representing different paths through the network.
#
# 3. **Path Exploration and Weight Product Calculation**:
#     - The function recursively explores all possible paths from the input layer to the output layer across each combopnet.
#     - For each path, it calculates two products:
#         a. **Prime Product**: The product of the unique prime numbers assigned to each neuron along the path.
#         b. **Weight Product**: The product of the weights of connections along the path.
#
# 4. **Global Flags and Thresholds**:
#     - **ENABLE_MINIMUM_WEIGHT_FILTER**: A flag that, when enabled, allows the function to ignore any path containing a weight below a specified threshold (`MINIMUM_WEIGHT_THRESHOLD`).
#     - **MINIMUM_WEIGHT_THRESHOLD**: The minimum weight threshold used to filter paths when `ENABLE_MINIMUM_WEIGHT_FILTER` is enabled.
#     - **ENABLE_COEFFICIENT_SORTING**: A flag that, when enabled, sorts the final products within each combopnet based on the absolute value of the weight product, in descending order.
#
# 5. **Output Format**:
#     - The function outputs a list of dictionaries, one for each combopnet. Each dictionary represents the possible paths through the network:
#         - **Keys**: The product of prime numbers representing each neuron along the path. This serves as a unique identifier for the path through the network.
#         - **Values**: The product of the weights along the corresponding path.
#
# 6. **Recursive Exploration**:
#     - A recursive helper function (`explore_path`) is used to traverse the network. This function updates the current product of weights and prime numbers as it progresses from the input layer to the output layer, accumulating results in a list.
#
# 7. **Adjustments for Real-World Use Cases**:
#     - The function includes placeholders for additional features that might be relevant for certain applications, such as thresholding based on weight magnitudes and sorting the paths based on their significance (as measured by the product of weights).

# %%
def coefficient_reconstruction(dim_index,
                               num_activation_fns,
                                weights, 
                                minimum_coefficient_threshold = 1e-5,
                                coefficient_output_digits = 10, 
                                enable_coefficient_sorting = False):
    
    max_neurons = int((max(max(len(layer) for layer in combopnet) for combopnet in weights) - 1)/num_activation_fns)
    
    labels = generate_set_labels(max_neurons) # number of states = number of neurons - 1

    def explore_path(combopnet_index, layer, neuron, weight_product, label_counts, non_zero_paths):
        """
        Recursively explores non-zero paths in a neural network.
        """
        if layer == len(weights[combopnet_index]) - 1:
            non_zero_paths.append((label_counts, weight_product))
            return

        for next_neuron, weight in enumerate(weights[combopnet_index][layer][neuron]):
            if abs(weight) <= 1e-15:
                # Skip recursion if the weight is zero (if one weight is zero, the whole path will be eliminated)
                continue  
            new_weight_product = weight_product * weight
            next_label_counts = label_counts.copy()
            next_label_counts[labels[next_neuron]] = next_label_counts.get(labels[next_neuron], 0) + 1
            explore_path(combopnet_index, layer + 1, next_neuron, new_weight_product, next_label_counts, non_zero_paths)
    
    #beginning of the algorithm
    all_combopnet_products = []
    for combopnet_index, _ in enumerate(weights):
        non_zero_paths = []
        #collect all non-zero paths
        for neuron_index in range(len(weights[combopnet_index][0])):
            label_counts = {labels[neuron_index]: 1}
            explore_path(combopnet_index, 0, neuron_index, 1, label_counts, non_zero_paths)
        
        #sum up the products with identical composite nonlinear/linear terms
        combopnet_products = {}
        for label_counts, weight_product in non_zero_paths:
            label_counts_key = frozenset(label_counts.items())
            if label_counts_key in combopnet_products:
                combopnet_products[label_counts_key] += weight_product
            else:
                combopnet_products[label_counts_key] = weight_product
        
        #remove the negligible composite terms
        combopnet_products = {k: v for k, v in combopnet_products.items() if abs(v) >= minimum_coefficient_threshold}
        
        if enable_coefficient_sorting:
            #sort the composite terms by their absolute values
            sorted_combopnet_products = dict(sorted(combopnet_products.items(), key=lambda item: abs(item[1]), reverse=True))
        else:
            sorted_combopnet_products = combopnet_products

        all_combopnet_products.append(sorted_combopnet_products)

    #output formatting
    labeled_all_combopnet_products = []
    for combopnet_index, sorted_combopnet_products in enumerate(all_combopnet_products):
        combopnet_product_strings = []
        for key, value in sorted_combopnet_products.items():
            labels_list = []
            only_constant = len(key) == 1 and any(label == 'Constant' for label, _ in key)
            
            for label, count in sorted(key):
                if label == 'Constant' and len(key) > 1:
                    continue
                if label != 'Constant' and count > 1:
                    labels_list.append(f"{label}^{count}")
                elif label == 'Constant' or count == 1:
                    labels_list.append(label if label != 'Constant' else '')
            
            label_str = '*'.join(filter(None, labels_list))
                        
            # Apply coefficient threshold if enabled
            formatted_value = f"{abs(value):.{coefficient_output_digits}g}"

            term_str = label_str if formatted_value == '1' else f"{formatted_value}*{label_str}" if not only_constant else formatted_value if formatted_value != '1' else ''
            sign = '+' if value >= 0 else '-'
            if combopnet_product_strings or value < 0:
                term_str = f" {sign} {term_str}"
            else:
                term_str = term_str
            combopnet_product_strings.append(term_str)

        formatted_output = ''.join(combopnet_product_strings)
        layer_prefix = f"(x{combopnet_index+dim_index+1})'= "
        full_output = layer_prefix + formatted_output
        labeled_all_combopnet_products.append(full_output)

    return labeled_all_combopnet_products

# %% [markdown]
# ## **V. Results Display and Discussions**
# ### **CombOpNet Results**

# %%
"""
path_products = coefficient_reconstruction(i,
                                               len(activation_fns),
                                               weights_list[11], 
                                            minimum_coefficient_threshold = 2e-2,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
for index, dimension in enumerate(path_products):
    print(f"{dimension}")
"""
# Out:
# '\npath_products = coefficient_reconstruction(i,\n                                               len(activation_fns),\n                                               weights_list[11], \n                                            minimum_coefficient_threshold = 2e-2,\n                                            coefficient_output_digits = 10, \n                                            enable_coefficient_sorting = False)\n    \nfor index, dimension in enumerate(path_products):\n    print(f"{dimension}")\n'

# %%
for i in range(len(weights_list)):
    path_products = coefficient_reconstruction(i,
                                               len(activation_fns),
                                               weights_list[i], 
                                            minimum_coefficient_threshold = 5e-2,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
# Out:
# (x1)'= 0.9953091344*x11
# (x2)'=  - 1.798022924*x1^3 + 1.837715754*x2

# %%
import os
import re

opt_folder = 'output'
# Create the folder if it doesn't exist
os.makedirs(opt_folder, exist_ok=True)

# Base filename and file extension for the text file
base_filename = 'output'
file_extension = '.txt'

# Regex pattern to match existing files with the base name and an optional index
pattern = re.compile(rf"{base_filename}(_(\d+))?{file_extension}")

# Initialize the highest index
max_index = -1

# Search for the highest index
for filename in os.listdir(opt_folder):
    match = pattern.match(filename)
    if match:
        # Extract the index from the filename, if present
        index = int(match.group(2)) if match.group(2) else 0
        max_index = max(max_index, index)

# Increment the highest index found
new_index = max_index + 1
if new_index == 0:
    # If no indexed files were found, use the base filename
    file_path = os.path.join(opt_folder, f"{base_filename}_1{file_extension}")
else:
    # If indexed files were found, append the new index to the filename
    file_path = os.path.join(opt_folder, f"{base_filename}_{new_index}{file_extension}")

# %%
with open(file_path, "w") as text_file:
    for i in range(len(weights_list)):
        path_products = coefficient_reconstruction(i,len(activation_fns),
                                                weights_list[i], 
                                                minimum_coefficient_threshold=0.2,
                                                coefficient_output_digits=10, 
                                                enable_coefficient_sorting=False)
        
        for index, dimension in enumerate(path_products):
            text_file.write(f"{dimension}")
