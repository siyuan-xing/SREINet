# %% [markdown]
# ## **Rational Nonlinearity Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_MODEL = 'lorenz96_sin' 
MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)  

# Generate data based on the specified model
dim = 10
num_traj = 6
data_initial_conditions = DG.DataGenerator.generate_initial_conditions(dim, num_traj, seed=42) #np.random.normal(1, 2, LORENZ96_DIM

data_T =  5.0       # Length of the data (T)
data_dt = 0.001       # Resolution of the data (dt)
myDG = DG.DataGenerator(data_initial_conditions, T=data_T, dt=data_dt, derivative_mode="exact")


t_arr, x_train, dx_train, guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL, method='RK45', F=5.0, alpha=0.3)

print("Guessed multiplicative_order:", guessed_multiplicative_order)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train
# Optionally, save a copy of the training input for simulation
training_input_for_sim = training_input.copy() # Saving a copy of training input for simulation (Before shuffling)

training_input, training_output = myDG.shuffleData(training_input, training_output)

print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py:621: UserWarning: The following arguments have no effect for a chosen solver: `F`, `alpha`.
#   solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
# Guessed multiplicative_order: 2
# Training input shape: (30000, 10)
# Training output shape: (30000, 10)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 64
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables)
dim = training_input.shape[1] 

# The grid size of each dimension
layer_depth = guessed_multiplicative_order


n_second_order_terms = dim * (dim + 1) // 2  
lifting_output_dim = dim + n_second_order_terms  

layer_neuron_nums_per_act_fn = [lifting_output_dim] * layer_depth

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
class LiftingLayer(tf.keras.layers.Layer):
    """
    Simple transformation layer that generates input to SREINet. This layer allows for incorporating 
    custom transformation functions such as 1/(ax+b) and xi*xj.
    """
    
    def __init__(self, **kwargs):
        """
        Args:
            input_dim: Input dimension (number of input features)
            delta: Small constant to prevent division by zero
            seed: Random seed
        """
        super(LiftingLayer, self).__init__(**kwargs)
    
    def build(self, input_shape):
        self.input_dim = input_shape[-1]
        
        indices_pairs = []
        for i in range(self.input_dim):
            for j in range(i, self.input_dim):
               indices_pairs.append([i, j])
        
        self.indices_pairs = tf.constant(indices_pairs, dtype=tf.int32)


    def call(self, inputs):
        """
        Apply transformations: [original_coords, 1/(ax+b), custom_transforms]
        """
        input_dim = inputs.shape[-1]
        tensor_prod = tf.einsum('bi,bj->bij', inputs, inputs) 
        

        B = tf.shape(tensor_prod)[0]  
        indices = tf.tile(self.indices_pairs[None, :, :], [B, 1, 1])  # (B, 15, 2)

        second_order = tf.gather_nd(tensor_prod, indices, batch_dims=1)

        sine_second_order = tf.sin(second_order)
    
        return tf.concat([inputs, sine_second_order], axis=-1)

# %%
def create_extended_sreinet_model(dim, layer_neuron_nums_per_act_fn, activation_functions=[lambda x:x], 
                        weight_std=0.001, delta=1e-5, seed=42, data_type='float32'):
    """
    Create and initialize a SREINet model.
    
    Args:
        dim (int): Input dimension (number of input variables)
        layer_neuron_nums_per_act_fn (list): Number of neurons per activation function in each hidden layer
        activation_functions (list, optional): List of activation functions. Defaults to [lambda x:x]
        weight_std (float, optional): Standard deviation for weight initialization. Defaults to 0.001
        delta: small constant to avoid division by zero
        seed (int, optional): Random seed for reproducible initialization. Defaults to 42
        data_type (str, optional): Data type for the model. Defaults to 'float32'
    
    Returns:
        tf.keras.Model: Configured SREINet model
    """
    
    # Create input layer
    inputs = tf.keras.layers.Input(shape=(dim,), dtype=data_type)
    # Apply flexible transformation layer (includes original coordinates + transformations)
    lifting_layer = LiftingLayer(
        name='lifting_layer'
    ) #DO NOT CHANGE THIS NAME
    
    # Get transformed features (includes original coordinates automatically)
    transformed_inputs = lifting_layer(inputs)


    # Calculate output dimension for SREINet layers
    #need to revise, confusing
    
    # Create SREINet model
    sreinet = SREINet(layer_neuron_nums_per_act_fn,
                      activations=activation_functions,
                      weight_initializer=tf.initializers.random_normal(stddev=0.001, seed=seed),
                      data_type=data_type,
                      name='SREINet') #DO NOT CHANGE THIS NAME
    
    # Apply the SREINet to transformed inputs
    output = sreinet(transformed_inputs)
    
    # Create the final model
    model = tf.keras.Model(inputs=inputs, outputs=output)
    
    return model

model = create_extended_sreinet_model(dim, layer_neuron_nums_per_act_fn)


def reinitialize_model_weights(model):
    """
    Reinitialize weights of the SREINet model.
    
    Args:
        model (tf.keras.Model): The SREINet model to reinitialize
    """
    #need to update here

    if hasattr(model.layers[1], 'reinitialize_weights'):
        tf.random.set_seed(np.random.randint(10000))
        model.layers[1].reinitialize_weights()
    else:
        print("SREINet does not have a reinitialize_weights() function.")

# %%
model.summary()
# Out:
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_10 (InputLayer)       [(None, 10)]              0
#
#  lifting_layer (LiftingLaye  (None, 65)                0
#  r)
#
#  SREINet (SREINet)           (None, 1)                 4422
#
# =================================================================
# Total params: 4422 (17.27 KB)
# Trainable params: 4356 (17.02 KB)
# Non-trainable params: 66 (264.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Training with Pruning**

# %%
import time
np.set_printoptions(threshold=np.inf)

# Define a training step function
@tf.function
def train_step(model, optimizer, loss_fn, inputs, targets, binary_mask):        
    with tf.GradientTape() as tape:
        # Generate predictions and calculate loss
        predictions = model(inputs, training=False)
        loss = loss_fn(targets, predictions)   
        
    # Calculate gradients and update model weights
    gradients = tape.gradient(loss, model.trainable_variables)        

    # Assuming binary_masks_ones is a list of binary masks created for each trainable variable
    masked_gradients = [tf.multiply(grad, mask) for grad, mask in zip(gradients, binary_mask)]

    optimizer.apply_gradients(zip(masked_gradients, model.trainable_variables))

    return loss

# Define a validation step function
@tf.function
def val_step(model, loss_fn, inputs, targets):
    # Generate predictions and calculate loss for validation data
    predictions = model(inputs, training=False)
    # predictions = model(inputs, training=False) 
    v_loss = loss_fn(targets, predictions)
    # Record the validation loss
    return v_loss   

def SREINet_fit_w_pruning(
    model,              # TensorFlow model to be trained
    training_input,     # Input features for training
    training_output,    # Target outputs for training
    batch_size,         # Number of samples per batch of computation
    validation_split,   # Fraction of data to be used as validation set
    epochs,             # Number of complete passes through the training dataset
    optimizer,          # Optimization algorithm for updating weights
    loss_fn,            # Loss function to measure model's performance
    pruning_schedule,   # Pruning schedule for gradually increasing the sparsity level
    data_type='float32',    # Data type of the tensors (default: 'float32')
    callbacks=None,         # List of callbacks for custom actions at various stages of training
    early_stopping_loss_threshold=0,       # Threshold for early stopping based on training and validation loss
    early_stopping_pruning_threshold=0,    # Threshold for early stopping based on pruning schedule
    verbose=0               # Verbosity mode (0 = silent, 1 = progress bar, etc.)
):
    # Cast the training input and output to the specified data type
    training_input = tf.cast(training_input, data_type)
    training_output = tf.cast(training_output, data_type)

    # Shuffle and batch the dataset, then split it into training and validation sets
    full_dataset = tf.data.Dataset.from_tensor_slices((training_input, training_output)).shuffle(buffer_size=1024)
    total_samples = training_input.shape[0]
    train_samples = int(total_samples * (1 - validation_split))
    
    # Apply the data type casting for each batch in the datasets
    train_dataset = full_dataset.take(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))
    val_dataset = full_dataset.skip(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))

    # Initialize metrics for tracking training and validation loss
    train_loss = tf.keras.metrics.Mean(name='train_loss', dtype=data_type)
    val_loss = tf.keras.metrics.Mean(name='val_loss', dtype=data_type)
    
    # Parameters initialization
    binary_mask = [tf.ones_like(var) for var in model.trainable_variables]

    def generate_binary_mask_and_prune_weight(model, pruning_weight_threshold):
        binary_masks = [tf.ones_like(var) for var in model.get_layer('lifting_layer').trainable_variables]  # Initialize list to hold binary masks
        
        # Iterate over each variable to apply the pruning threshold and generate masks
        for var in model.get_layer('SREINet').trainable_variables:
            # Generate a binary mask where weights above the PRUNING_WEIGHT_THRESHOLD are marked with 1, others with 0
            mask = tf.cast(tf.abs(var) >= pruning_weight_threshold, var.dtype)

            # Update the mask at position (0, 0) to be 1 using tf.tensor_scatter_nd_update (To Avoid the constant term being pruned)
            indices = tf.constant([[0, 0]])  # Specify the indices to update
            updates = tf.constant([1], dtype=mask.dtype)  # Specify the value to update
            mask = tf.tensor_scatter_nd_update(mask, indices, updates)

            binary_masks.append(mask)  # Add the generated mask to the list            

            # Apply mask to modify weights by setting weights below PRUNING_WEIGHT_THRESHOLD to zero
            modified_weight = var * mask
            var.assign(modified_weight)            
        return binary_masks

    # Prepare a dictionary to track the training history
    history = {'loss': [], 'val_loss': []}

    # Before the training loop starts
    if callbacks:
        for callback in callbacks:
            # Assign the model to the callback
            callback.set_model(model)

            # Manually setting params before calling any methods that might depend on them
            callback.params = {
                'epochs': epochs,  # Number of epochs
                # You can add more parameters here as needed
            }

            # Now call on_train_begin with all properties set
            callback.on_train_begin(logs={'loss_threshold': early_stopping_loss_threshold})

    training_start_time = time.time()
    # Execute the training loop
    for epoch in range(epochs):
        # Notify callbacks that the epoch has started
        if callbacks:
            epoch_logs = {}
            for callback in callbacks:
                callback.on_epoch_begin(epoch, logs=epoch_logs)

        if verbose: 
            eopoch_start_time = time.time()

        # Reset state of metrics at the start of each epoch
        train_loss.reset_states()
        val_loss.reset_states()

        # Retrieve the current pruning schedule threshold
        current_pruning_threshold = pruning_schedule[epoch]
        binary_mask = generate_binary_mask_and_prune_weight(model, current_pruning_threshold)
        
        layer_losses_sum = None
        layer_indices = [i for i, layer in enumerate(model.layers) if layer.trainable]
        # Process each batch in the training dataset
        for train_inputs, train_targets in train_dataset:           
            loss = train_step(model = model, 
                            optimizer = optimizer, 
                            loss_fn = loss_fn,
                            inputs = train_inputs, 
                            targets = train_targets, 
                            binary_mask = binary_mask)    
            # Record the loss
            train_loss(loss)

        # Process each batch in the validation dataset
        for val_inputs, val_targets in val_dataset:
            v_loss = val_step(model = model, 
                                loss_fn = loss_fn,
                                inputs = val_inputs, 
                                targets = val_targets)
            val_loss(v_loss)

        # Append the average losses for this epoch to the history
        history['loss'].append(train_loss.result().numpy())
        history['val_loss'].append(val_loss.result().numpy())
        #calculate the average of val_loss
        
        # Current Losses
        current_train_loss = train_loss.result().numpy()
        current_val_loss = val_loss.result().numpy()

        # Notify callbacks that the epoch has ended
        epoch_logs = {'loss': current_train_loss, 'val_loss': current_val_loss}
        if callbacks:
            for callback in callbacks:
                callback.on_epoch_end(epoch, logs=epoch_logs)
    
        if verbose:
            epoch_time = time.time() - eopoch_start_time
            total_layers = len(model.layers)
            trainable_layer_count = sum(1 for layer in model.layers if layer.trainable)
            print(f"Epoch {epoch + 1:3.0f}:"
                f"  Train Loss: {current_train_loss:9.4e}"
                f",  Validation Loss: {current_val_loss:9.4e}"
                # f",  Trainable Layers ({trainable_layer_count}/{total_layers})"
                f",  Epoch Time: {epoch_time:.2f}s"  
                f",  Current Pruning Threshold: {current_pruning_threshold:.5g}")    
            
        if model.stop_training: # Stop training if all the layers are untrianable
            break   

        # Check for early stopping
        if current_train_loss < early_stopping_loss_threshold and current_pruning_threshold > early_stopping_pruning_threshold:
            print(f"Early stopping at epoch {epoch+1} as train loss {current_val_loss:.12f} is below the threshold {early_stopping_loss_threshold:.12f}")
            break


    # After the training loop ends
    training_time = time.time() - training_start_time
    print(f'Traininng Stopped. Time elapsed: {training_time:.2f}s')
    if callbacks:
        for callback in callbacks:
            callback.on_train_end(logs={'final_loss': current_train_loss, 'final_val_loss': current_val_loss})
    

    # Return the history containing training and validation losses
    return history

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.15 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 15
PRUNING_EPOCHS_PER_PERIOD = 30
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_schedule as ps

# Define the pruning schedule
pruning_schedule = ps.pruning_schedule_ramp(maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD, 
                                                    steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                                                    num_periods=N_PERIODS, 
                                                    #zero_percentage=0.10,
                                                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
callbacks = []

EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.02

training_histories = []
weights_list = []

# %%
#change 0 to a other number if you want to start training from other dimensions
for i in range(0, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    reinitialize_model_weights(model)
    output = training_output[:, i:i+1]

    history = SREINet_fit_w_pruning(
        model,                   # Model to train
        training_input,             # Input data for training
        output,                     # Output data for training
        batch_size=MINI_BATCH_SIZE, # Number of samples per gradient update
        validation_split=0.20,      # Fraction of the training data to be used as validation data
        epochs=round(NUM_EPOCHS),   # Number of times the entire training dataset is passed through the model
        optimizer=my_optimizer,     # Optimizer to use for training
        pruning_schedule = pruning_schedule, # Pruning schedule for gradually increasing the sparsity level
        loss_fn=loss_fn,            # Loss function to use for training
        data_type=MY_DATA_TYPE,     # Data type to use for training
        callbacks= callbacks,       # List of callbacks to apply during training
        early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,# Threshold for early stopping (Layer Based)
        early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD, # Threshold for early stopping (Pruning Based)
        verbose=1                   # Hide the epoch steps
    )
    
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([model.get_layer('SREINet').get_weights()])
# Out:
# Training dimension 1...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 5.5757e-01,  Validation Loss: 6.3377e-02,  Epoch Time: 0.53s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 4.2809e-02,  Validation Loss: 3.3018e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 2.4445e-02,  Validation Loss: 3.9181e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 2.4382e-02,  Validation Loss: 1.4725e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 1.3926e-02,  Validation Loss: 1.9377e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 4.6718e-02,  Validation Loss: 9.8700e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 1.0239e-02,  Validation Loss: 9.3136e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 1.1938e-02,  Validation Loss: 1.0631e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 9.2010e-03,  Validation Loss: 7.1599e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 8.3742e-03,  Validation Loss: 4.6034e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.4489e-02,  Validation Loss: 5.6478e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 2.4034e-02,  Validation Loss: 7.9976e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 5.9625e-02,  Validation Loss: 3.1483e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 6.0661e-02,  Validation Loss: 4.0717e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 7.3758e-02,  Validation Loss: 5.7450e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 9.1514e-02,  Validation Loss: 7.9436e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 1.4419e-01,  Validation Loss: 1.2724e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 1.7414e-01,  Validation Loss: 1.4708e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 1.9287e-01,  Validation Loss: 1.4342e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 2.4093e-01,  Validation Loss: 2.3036e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 2.3717e-01,  Validation Loss: 2.3187e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 2.3459e-01,  Validation Loss: 2.3280e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 2.5942e-01,  Validation Loss: 2.3126e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 5.2195e-01,  Validation Loss: 5.0297e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 4.9532e-01,  Validation Loss: 4.9136e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 4.9424e-01,  Validation Loss: 4.9215e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 4.9544e-01,  Validation Loss: 4.9541e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 4.9341e-01,  Validation Loss: 4.9188e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 4.9537e-01,  Validation Loss: 4.9661e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 4.9515e-01,  Validation Loss: 4.9375e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 1.9945e-01,  Validation Loss: 7.8427e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 7.4426e-03,  Validation Loss: 5.0510e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 5.2926e-03,  Validation Loss: 3.5840e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 4.4221e-03,  Validation Loss: 2.9582e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 8.9008e-02,  Validation Loss: 2.1448e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 2.8644e-03,  Validation Loss: 1.9929e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 2.8365e-03,  Validation Loss: 2.4060e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 3.8065e-03,  Validation Loss: 1.7802e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 2.3334e-03,  Validation Loss: 2.1608e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 9.5179e-03,  Validation Loss: 2.4458e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 1.1335e-02,  Validation Loss: 6.4304e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 2.0356e-02,  Validation Loss: 1.4983e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 2.6370e-02,  Validation Loss: 2.3626e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 3.7003e-02,  Validation Loss: 3.4018e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0375
# Epoch  45:  Train Loss: 4.5877e-02,  Validation Loss: 4.2175e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.047599
# Epoch  46:  Train Loss: 5.1663e-02,  Validation Loss: 5.1668e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.058311
# Epoch  47:  Train Loss: 1.0179e-01,  Validation Loss: 9.3088e-02,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.069395
# Epoch  48:  Train Loss: 9.5496e-02,  Validation Loss: 9.6389e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.080605
# Epoch  49:  Train Loss: 9.3328e-02,  Validation Loss: 9.4543e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.091689
# Epoch  50:  Train Loss: 9.3065e-02,  Validation Loss: 9.3775e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1024
# Epoch  51:  Train Loss: 9.2722e-02,  Validation Loss: 9.3931e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1125
# Epoch  52:  Train Loss: 9.2949e-02,  Validation Loss: 9.3801e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12176
# Epoch  53:  Train Loss: 4.6024e-01,  Validation Loss: 4.4451e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.12998
# Epoch  54:  Train Loss: 4.7164e-01,  Validation Loss: 4.8267e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13697
# Epoch  55:  Train Loss: 4.7084e-01,  Validation Loss: 4.6809e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14257
# Epoch  56:  Train Loss: 4.7155e-01,  Validation Loss: 4.8148e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14667
# Epoch  57:  Train Loss: 4.7296e-01,  Validation Loss: 4.7918e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14916
# Epoch  58:  Train Loss: 4.7055e-01,  Validation Loss: 4.7775e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  59:  Train Loss: 4.7198e-01,  Validation Loss: 4.8194e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  60:  Train Loss: 4.7172e-01,  Validation Loss: 4.7589e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  61:  Train Loss: 2.1402e-01,  Validation Loss: 3.0223e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  62:  Train Loss: 2.3194e-03,  Validation Loss: 2.0599e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  63:  Train Loss: 1.5640e-03,  Validation Loss: 1.2934e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  64:  Train Loss: 1.2671e-03,  Validation Loss: 1.1234e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  65:  Train Loss: 2.4100e-03,  Validation Loss: 7.7967e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  66:  Train Loss: 1.8481e-03,  Validation Loss: 1.2479e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  67:  Train Loss: 7.8434e-03,  Validation Loss: 3.5808e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  68:  Train Loss: 1.4515e-02,  Validation Loss: 9.4950e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch  69:  Train Loss: 3.0192e-03,  Validation Loss: 6.2309e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  70:  Train Loss: 1.5589e-02,  Validation Loss: 3.4266e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  71:  Train Loss: 1.2649e-02,  Validation Loss: 9.7800e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  72:  Train Loss: 1.3570e-02,  Validation Loss: 1.0915e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.020021
# Epoch  73:  Train Loss: 2.9611e-02,  Validation Loss: 2.0826e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  74:  Train Loss: 2.1055e-02,  Validation Loss: 1.5856e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0375
# Epoch  75:  Train Loss: 1.3478e-02,  Validation Loss: 9.4992e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.047599
# Epoch  76:  Train Loss: 1.8318e-02,  Validation Loss: 3.8854e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.058311
# Epoch  77:  Train Loss: 1.8134e-03,  Validation Loss: 3.0804e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.069395
# Epoch  78:  Train Loss: 6.7610e-05,  Validation Loss: 4.5189e-07,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.080605
# Epoch  79:  Train Loss: 2.3773e-08,  Validation Loss: 1.4539e-11,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.091689
# Epoch  80:  Train Loss: 1.4568e-11,  Validation Loss: 1.3493e-11,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1024
# Early stopping at epoch 80 as train loss 0.000000000013 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 26.32s
# Training dimension 2...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 8.8948e-01,  Validation Loss: 2.4355e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.5700e-02,  Validation Loss: 8.5496e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 7.8432e-03,  Validation Loss: 6.4659e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 6.2977e-03,  Validation Loss: 7.0063e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 5.3295e-03,  Validation Loss: 3.9866e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 1.0454e-02,  Validation Loss: 1.3708e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 3.5792e-02,  Validation Loss: 4.3201e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 1.9761e-02,  Validation Loss: 2.9605e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 3.1750e-03,  Validation Loss: 6.0928e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 3.3679e-03,  Validation Loss: 1.8222e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.4646e-02,  Validation Loss: 2.3074e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 2.7633e-02,  Validation Loss: 8.0808e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 5.5157e-02,  Validation Loss: 2.3097e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 7.5775e-02,  Validation Loss: 5.0830e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 1.0148e-01,  Validation Loss: 6.8987e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 1.1595e-01,  Validation Loss: 7.0274e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 8.0296e-02,  Validation Loss: 7.0710e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 1.2660e-01,  Validation Loss: 1.1376e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 1.2651e-01,  Validation Loss: 1.1111e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 1.2759e-01,  Validation Loss: 1.1456e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 1.2077e-01,  Validation Loss: 1.1069e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 1.0528e-01,  Validation Loss: 1.0725e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 1.0477e-01,  Validation Loss: 1.0609e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 1.4501e-01,  Validation Loss: 1.0006e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 1.0775e-01,  Validation Loss: 1.0554e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 1.0407e-01,  Validation Loss: 1.0365e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 1.0399e-01,  Validation Loss: 1.0366e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 1.0380e-01,  Validation Loss: 1.0389e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 1.1969e-01,  Validation Loss: 1.0614e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 1.0796e-01,  Validation Loss: 1.0734e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 1.8725e-01,  Validation Loss: 7.2335e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 4.1746e-04,  Validation Loss: 2.9482e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 2.2529e-04,  Validation Loss: 1.8863e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 2.4484e-04,  Validation Loss: 2.2426e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 7.4217e-03,  Validation Loss: 1.9672e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 2.3714e-02,  Validation Loss: 1.2512e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 1.9509e-03,  Validation Loss: 3.3513e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 1.6094e-04,  Validation Loss: 4.7476e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 1.7241e-03,  Validation Loss: 4.7209e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 1.1302e-03,  Validation Loss: 4.0059e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 3.0159e-04,  Validation Loss: 4.7098e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 7.0327e-06,  Validation Loss: 3.5044e-08,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 4.9715e-09,  Validation Loss: 9.3117e-13,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 9.3538e-13,  Validation Loss: 9.3539e-13,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0375
# Early stopping at epoch 44 as train loss 0.000000000001 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 14.17s
# Training dimension 3...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 8.4670e-01,  Validation Loss: 2.9793e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.9435e-02,  Validation Loss: 1.3407e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 9.9327e-03,  Validation Loss: 7.5785e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 8.5519e-03,  Validation Loss: 5.0920e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 7.6360e-03,  Validation Loss: 5.5710e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 1.6459e-02,  Validation Loss: 6.7043e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 8.7636e-03,  Validation Loss: 1.1217e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 1.6083e-02,  Validation Loss: 1.4057e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 7.0941e-03,  Validation Loss: 1.9047e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 6.3559e-03,  Validation Loss: 1.8384e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.3520e-02,  Validation Loss: 4.3269e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 3.1133e-02,  Validation Loss: 7.8220e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 5.5580e-02,  Validation Loss: 2.5629e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 6.8254e-02,  Validation Loss: 3.9625e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 1.0791e-01,  Validation Loss: 7.9309e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 1.0024e-01,  Validation Loss: 9.3657e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 1.6265e-01,  Validation Loss: 1.3078e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 1.7061e-01,  Validation Loss: 1.4291e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 1.5300e-01,  Validation Loss: 1.4188e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 2.7211e-01,  Validation Loss: 1.6333e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 1.5867e-01,  Validation Loss: 1.3613e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 1.3885e-01,  Validation Loss: 1.1745e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 1.5618e-01,  Validation Loss: 1.1664e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 1.1324e-01,  Validation Loss: 1.1118e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 1.1302e-01,  Validation Loss: 1.1088e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 1.1291e-01,  Validation Loss: 1.1045e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 1.1263e-01,  Validation Loss: 1.1212e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 1.1288e-01,  Validation Loss: 1.1171e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 1.1283e-01,  Validation Loss: 1.1094e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 1.1317e-01,  Validation Loss: 1.1052e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 2.8303e-01,  Validation Loss: 8.0149e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 4.5812e-04,  Validation Loss: 2.3864e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 1.8791e-04,  Validation Loss: 1.6597e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 2.2749e-04,  Validation Loss: 1.0440e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 7.6319e-04,  Validation Loss: 7.4231e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 4.6495e-03,  Validation Loss: 4.5830e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 1.9577e-02,  Validation Loss: 1.9766e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 4.1397e-04,  Validation Loss: 4.3241e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 1.8774e-03,  Validation Loss: 6.8878e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 8.2904e-04,  Validation Loss: 4.4888e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 3.8494e-04,  Validation Loss: 1.9386e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 1.6843e-04,  Validation Loss: 1.4580e-07,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 7.3768e-09,  Validation Loss: 5.7016e-10,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 3.2374e-11,  Validation Loss: 1.5665e-12,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0375
# Early stopping at epoch 44 as train loss 0.000000000002 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 14.16s
# Training dimension 4...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 8.5429e-01,  Validation Loss: 4.2045e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 2.1402e-02,  Validation Loss: 1.2985e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.0109e-02,  Validation Loss: 8.6125e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 7.1887e-03,  Validation Loss: 5.9768e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 8.0287e-03,  Validation Loss: 4.9778e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 5.4328e-02,  Validation Loss: 2.6386e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 2.4043e-03,  Validation Loss: 2.2492e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 3.2416e-03,  Validation Loss: 2.3698e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 2.7790e-03,  Validation Loss: 5.0401e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 6.1526e-03,  Validation Loss: 1.6949e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.3859e-02,  Validation Loss: 3.0212e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 1.9053e-02,  Validation Loss: 5.5964e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 3.8056e-02,  Validation Loss: 1.5176e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 7.0424e-02,  Validation Loss: 3.8918e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 1.4033e-01,  Validation Loss: 6.3833e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 8.7744e-02,  Validation Loss: 6.4840e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 7.8438e-02,  Validation Loss: 6.4449e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 9.9452e-02,  Validation Loss: 7.5740e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 1.2928e-01,  Validation Loss: 1.2697e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 1.3730e-01,  Validation Loss: 1.3025e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 1.4748e-01,  Validation Loss: 1.2831e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 1.2470e-01,  Validation Loss: 1.2137e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 1.4826e-01,  Validation Loss: 1.1203e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 1.1656e-01,  Validation Loss: 1.1562e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 2.0774e-01,  Validation Loss: 1.2761e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 1.5917e-01,  Validation Loss: 1.1699e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 1.1570e-01,  Validation Loss: 1.1661e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 1.1567e-01,  Validation Loss: 1.1669e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 1.1542e-01,  Validation Loss: 1.1603e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 1.1564e-01,  Validation Loss: 1.1642e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 3.1488e-01,  Validation Loss: 5.8455e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 3.5525e-04,  Validation Loss: 1.9225e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 1.4070e-04,  Validation Loss: 9.0537e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 8.7229e-05,  Validation Loss: 8.0391e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 7.6726e-05,  Validation Loss: 1.0247e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 7.4468e-05,  Validation Loss: 1.2203e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 1.7190e-04,  Validation Loss: 5.9211e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 5.8268e-04,  Validation Loss: 1.4416e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 3.1792e-03,  Validation Loss: 4.7935e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 8.9340e-04,  Validation Loss: 4.6112e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 5.3213e-04,  Validation Loss: 2.4869e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 2.3374e-04,  Validation Loss: 6.5161e-06,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 1.2010e-06,  Validation Loss: 1.3715e-08,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 8.7334e-10,  Validation Loss: 6.3757e-12,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0375
# Epoch  45:  Train Loss: 5.3058e-12,  Validation Loss: 5.0887e-12,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.047599
# Early stopping at epoch 45 as train loss 0.000000000005 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 14.57s
# Training dimension 5...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 6.9193e-01,  Validation Loss: 2.4061e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.7212e-02,  Validation Loss: 1.2185e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.5901e-02,  Validation Loss: 6.9060e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 5.8052e-03,  Validation Loss: 5.0065e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 6.7066e-03,  Validation Loss: 6.6171e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 1.3830e-02,  Validation Loss: 1.0093e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 6.8063e-02,  Validation Loss: 3.3410e-03,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 2.0519e-03,  Validation Loss: 2.1134e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 1.9524e-03,  Validation Loss: 2.2726e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 4.1342e-03,  Validation Loss: 1.9308e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.6919e-02,  Validation Loss: 2.6568e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 2.2499e-02,  Validation Loss: 5.6617e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 4.7021e-02,  Validation Loss: 2.3394e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 7.4411e-02,  Validation Loss: 3.9351e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 8.8856e-02,  Validation Loss: 6.1980e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 9.1644e-02,  Validation Loss: 6.9775e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 1.0291e-01,  Validation Loss: 7.0432e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 8.9014e-02,  Validation Loss: 6.5540e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 9.2980e-02,  Validation Loss: 7.1438e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 1.6228e-01,  Validation Loss: 1.5679e-01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 1.5007e-01,  Validation Loss: 1.4295e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 1.4235e-01,  Validation Loss: 1.3761e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 1.5195e-01,  Validation Loss: 1.2440e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 1.1400e-01,  Validation Loss: 1.1187e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 1.1225e-01,  Validation Loss: 1.1114e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 1.6287e-01,  Validation Loss: 1.1689e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 1.1671e-01,  Validation Loss: 1.1716e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 1.1671e-01,  Validation Loss: 1.1706e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 1.1654e-01,  Validation Loss: 1.1643e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 1.3185e-01,  Validation Loss: 1.1844e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 1.7967e-01,  Validation Loss: 4.0669e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 2.6954e-04,  Validation Loss: 2.0804e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 1.6635e-04,  Validation Loss: 1.2437e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 1.7359e-04,  Validation Loss: 1.0026e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 1.0464e-03,  Validation Loss: 3.2779e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 1.7372e-02,  Validation Loss: 1.4524e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 3.8621e-02,  Validation Loss: 6.8333e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 6.1779e-04,  Validation Loss: 8.5519e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 1.6804e-03,  Validation Loss: 5.6144e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 1.0877e-03,  Validation Loss: 5.0451e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 2.6675e-04,  Validation Loss: 1.1726e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 9.1474e-05,  Validation Loss: 3.9872e-07,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 2.9680e-08,  Validation Loss: 6.5885e-12,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 6.4816e-12,  Validation Loss: 6.5517e-12,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0375
# Early stopping at epoch 44 as train loss 0.000000000007 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 14.41s
# Training dimension 6...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 7.7523e-01,  Validation Loss: 2.3795e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.5834e-02,  Validation Loss: 1.0002e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.0509e-02,  Validation Loss: 6.8261e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 7.4161e-03,  Validation Loss: 1.0123e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 9.4234e-03,  Validation Loss: 1.6430e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 6.9763e-02,  Validation Loss: 1.4278e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 3.2959e-03,  Validation Loss: 2.7871e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 3.1738e-03,  Validation Loss: 2.7960e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 3.6174e-03,  Validation Loss: 4.2749e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 4.7200e-03,  Validation Loss: 2.0981e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.1462e-02,  Validation Loss: 2.9536e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 2.7325e-02,  Validation Loss: 9.6947e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 3.3268e-02,  Validation Loss: 1.7133e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 5.9019e-02,  Validation Loss: 3.4583e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 8.9540e-02,  Validation Loss: 5.2641e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 9.8969e-02,  Validation Loss: 7.7690e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 1.1000e-01,  Validation Loss: 8.5626e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 1.6693e-01,  Validation Loss: 1.3500e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 1.3691e-01,  Validation Loss: 1.2874e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 1.5047e-01,  Validation Loss: 1.3149e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 1.3061e-01,  Validation Loss: 1.2537e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 1.2781e-01,  Validation Loss: 1.1353e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 1.8735e-01,  Validation Loss: 1.3026e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 1.3368e-01,  Validation Loss: 1.1907e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 1.1751e-01,  Validation Loss: 1.1835e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 1.1759e-01,  Validation Loss: 1.1889e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 1.1768e-01,  Validation Loss: 1.1911e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 1.1772e-01,  Validation Loss: 1.1977e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 1.1758e-01,  Validation Loss: 1.1796e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 1.1798e-01,  Validation Loss: 1.1929e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 3.5264e-01,  Validation Loss: 5.3730e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 3.2641e-04,  Validation Loss: 1.9829e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 1.4302e-04,  Validation Loss: 9.9891e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 7.9892e-05,  Validation Loss: 7.1529e-05,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 6.6159e-05,  Validation Loss: 7.1082e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 6.4131e-05,  Validation Loss: 1.7504e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 4.6333e-04,  Validation Loss: 3.7586e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 6.4273e-04,  Validation Loss: 6.4043e-05,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 1.7507e-03,  Validation Loss: 5.3739e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 7.0765e-04,  Validation Loss: 3.7389e-04,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 3.4111e-04,  Validation Loss: 5.5574e-06,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 4.2270e-07,  Validation Loss: 2.0109e-08,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 3.0207e-09,  Validation Loss: 1.3824e-12,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 1.4319e-12,  Validation Loss: 1.3872e-12,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0375
# Early stopping at epoch 44 as train loss 0.000000000001 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 14.27s
# Training dimension 7...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 7.4349e-01,  Validation Loss: 2.7072e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.4023e-02,  Validation Loss: 8.9655e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 6.9414e-03,  Validation Loss: 5.9615e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 5.8870e-03,  Validation Loss: 4.5213e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 6.5523e-03,  Validation Loss: 9.1005e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 7.0789e-02,  Validation Loss: 1.7494e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 1.7014e-03,  Validation Loss: 1.7266e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 1.5723e-03,  Validation Loss: 2.0737e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 1.7343e-03,  Validation Loss: 1.3097e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 4.8326e-03,  Validation Loss: 1.2302e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.5588e-02,  Validation Loss: 2.9931e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 3.4661e-02,  Validation Loss: 9.4493e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 6.4510e-02,  Validation Loss: 2.4329e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 6.4329e-02,  Validation Loss: 4.0081e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 8.3400e-02,  Validation Loss: 7.3627e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 1.5595e-01,  Validation Loss: 1.2156e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 1.3495e-01,  Validation Loss: 1.2914e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 2.1081e-01,  Validation Loss: 1.9203e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 2.0177e-01,  Validation Loss: 1.8699e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 1.9082e-01,  Validation Loss: 1.9103e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 3.0055e-01,  Validation Loss: 2.7170e-01,  Epoch Time: 0.50s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 2.9473e-01,  Validation Loss: 2.7165e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 3.9944e-01,  Validation Loss: 3.9402e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 4.1280e-01,  Validation Loss: 4.0133e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 4.2679e-01,  Validation Loss: 4.1014e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 5.0121e-01,  Validation Loss: 4.6938e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 4.5271e-01,  Validation Loss: 4.7036e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 4.5188e-01,  Validation Loss: 4.6853e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 4.5219e-01,  Validation Loss: 4.6907e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 4.5147e-01,  Validation Loss: 4.6371e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 1.6061e-01,  Validation Loss: 5.5459e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 4.7592e-03,  Validation Loss: 2.5012e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 5.0994e-03,  Validation Loss: 4.5956e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 7.3798e-03,  Validation Loss: 3.7182e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 3.8715e-02,  Validation Loss: 1.4516e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 3.4723e-03,  Validation Loss: 1.3253e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 1.4287e-02,  Validation Loss: 1.2462e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 2.0362e-03,  Validation Loss: 8.0016e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 2.0462e-03,  Validation Loss: 1.0500e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 7.2282e-03,  Validation Loss: 2.4970e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 9.9762e-03,  Validation Loss: 5.0815e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 1.3141e-02,  Validation Loss: 9.5757e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 1.8588e-02,  Validation Loss: 1.4531e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 2.7560e-02,  Validation Loss: 2.0620e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0375
# Epoch  45:  Train Loss: 4.9169e-02,  Validation Loss: 2.0973e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.047599
# Epoch  46:  Train Loss: 1.8764e-02,  Validation Loss: 1.0004e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.058311
# Epoch  47:  Train Loss: 9.3376e-03,  Validation Loss: 7.8060e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.069395
# Epoch  48:  Train Loss: 2.2161e-02,  Validation Loss: 7.1826e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.080605
# Epoch  49:  Train Loss: 1.9342e-02,  Validation Loss: 8.8943e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091689
# Epoch  50:  Train Loss: 7.3754e-03,  Validation Loss: 6.4201e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1024
# Epoch  51:  Train Loss: 1.7824e-02,  Validation Loss: 3.4157e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1125
# Epoch  52:  Train Loss: 8.4182e-03,  Validation Loss: 7.8029e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.12176
# Epoch  53:  Train Loss: 1.9950e-04,  Validation Loss: 8.8283e-07,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.12998
# Epoch  54:  Train Loss: 1.7102e-07,  Validation Loss: 3.1952e-11,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.13697
# Epoch  55:  Train Loss: 2.8834e-11,  Validation Loss: 2.5759e-11,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.14257
# Early stopping at epoch 55 as train loss 0.000000000026 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 18.30s
# Training dimension 8...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 7.9030e-01,  Validation Loss: 2.2682e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.5252e-02,  Validation Loss: 9.1359e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.0212e-02,  Validation Loss: 8.3696e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 6.4421e-03,  Validation Loss: 7.7477e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 8.3675e-03,  Validation Loss: 1.1288e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 1.2597e-02,  Validation Loss: 9.2574e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 5.9547e-02,  Validation Loss: 4.6775e-02,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 6.3235e-03,  Validation Loss: 6.7516e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 2.2332e-03,  Validation Loss: 1.3361e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 4.2700e-03,  Validation Loss: 1.2467e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.8249e-02,  Validation Loss: 3.2653e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 3.1418e-02,  Validation Loss: 9.2106e-03,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 3.8570e-02,  Validation Loss: 2.1961e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 6.2065e-02,  Validation Loss: 3.3867e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 8.6998e-02,  Validation Loss: 5.8446e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 9.6267e-02,  Validation Loss: 7.5550e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 1.0751e-01,  Validation Loss: 8.0294e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 1.6580e-01,  Validation Loss: 1.3411e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 1.5898e-01,  Validation Loss: 1.1947e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 1.2984e-01,  Validation Loss: 1.2043e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 1.2404e-01,  Validation Loss: 1.1955e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 1.1834e-01,  Validation Loss: 1.1385e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 1.1702e-01,  Validation Loss: 1.1032e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 1.5935e-01,  Validation Loss: 1.2373e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 1.1809e-01,  Validation Loss: 1.1690e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 1.1731e-01,  Validation Loss: 1.1541e-01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 1.1695e-01,  Validation Loss: 1.1555e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 1.1724e-01,  Validation Loss: 1.1557e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 1.1734e-01,  Validation Loss: 1.1590e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 1.1748e-01,  Validation Loss: 1.1582e-01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 1.4692e-01,  Validation Loss: 5.0073e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 3.2494e-04,  Validation Loss: 1.8836e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 4.7457e-04,  Validation Loss: 4.6563e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 2.4286e-03,  Validation Loss: 1.4296e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 1.4319e-01,  Validation Loss: 4.4193e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 1.9424e-04,  Validation Loss: 9.3217e-05,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 8.0063e-05,  Validation Loss: 2.4730e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 6.1474e-05,  Validation Loss: 3.1120e-05,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 2.2996e-03,  Validation Loss: 7.4514e-04,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 1.3006e-03,  Validation Loss: 5.8758e-04,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 4.9826e-04,  Validation Loss: 2.9112e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 2.9110e-04,  Validation Loss: 7.7926e-07,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 5.5171e-09,  Validation Loss: 4.2946e-09,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 2.6004e-10,  Validation Loss: 2.8886e-12,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.0375
# Epoch  45:  Train Loss: 2.8387e-12,  Validation Loss: 2.8998e-12,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.047599
# Early stopping at epoch 45 as train loss 0.000000000003 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 15.39s
# Training dimension 9...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 1.0034e+00,  Validation Loss: 3.5657e-02,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.9879e-02,  Validation Loss: 1.5495e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 9.5259e-03,  Validation Loss: 7.5133e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 6.3392e-03,  Validation Loss: 6.3181e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 2.0079e-02,  Validation Loss: 7.9077e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 5.9493e-03,  Validation Loss: 3.6763e-03,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 6.7303e-03,  Validation Loss: 3.0452e-03,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 1.4427e-02,  Validation Loss: 1.4099e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 6.8023e-03,  Validation Loss: 7.8075e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 6.2172e-03,  Validation Loss: 3.8325e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.3070e-02,  Validation Loss: 3.8829e-03,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 3.4333e-02,  Validation Loss: 6.0828e-03,  Epoch Time: 0.51s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 5.6516e-02,  Validation Loss: 2.8669e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 5.8669e-02,  Validation Loss: 3.4221e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 9.0196e-02,  Validation Loss: 6.2473e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 1.1290e-01,  Validation Loss: 8.9063e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 1.2925e-01,  Validation Loss: 9.1965e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 1.2284e-01,  Validation Loss: 1.1229e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 1.0481e-01,  Validation Loss: 9.7260e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 2.7005e-01,  Validation Loss: 1.4602e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 4.0405e-01,  Validation Loss: 1.4204e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 1.4578e-01,  Validation Loss: 1.3894e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 1.3671e-01,  Validation Loss: 1.3266e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 1.3196e-01,  Validation Loss: 1.2884e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 1.4519e-01,  Validation Loss: 1.1704e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 1.1781e-01,  Validation Loss: 1.1792e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 1.1777e-01,  Validation Loss: 1.1701e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 1.1798e-01,  Validation Loss: 1.1724e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 1.1780e-01,  Validation Loss: 1.1700e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 1.1778e-01,  Validation Loss: 1.1825e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 4.2646e-01,  Validation Loss: 7.8945e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 4.3069e-04,  Validation Loss: 2.4844e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 1.7301e-04,  Validation Loss: 1.1153e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 9.8607e-05,  Validation Loss: 8.2875e-05,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 8.7122e-05,  Validation Loss: 6.1052e-05,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 7.2953e-05,  Validation Loss: 4.8426e-05,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 7.4200e-05,  Validation Loss: 5.3173e-05,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 2.5457e-04,  Validation Loss: 2.6066e-05,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 2.2804e-03,  Validation Loss: 9.1423e-04,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 7.7644e-04,  Validation Loss: 3.0180e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 1.9313e-04,  Validation Loss: 9.8605e-05,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 5.6935e-05,  Validation Loss: 3.1663e-05,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 1.2434e-05,  Validation Loss: 7.3991e-09,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 2.0486e-09,  Validation Loss: 2.3331e-13,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0375
# Epoch  45:  Train Loss: 2.3525e-13,  Validation Loss: 2.3005e-13,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.047599
# Early stopping at epoch 45 as train loss 0.000000000000 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 15.81s
# Training dimension 10...
# SREINet does not have a reinitialize_weights() function.
# Epoch   1:  Train Loss: 7.8261e-01,  Validation Loss: 2.4871e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.5399e-02,  Validation Loss: 9.3132e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 9.5002e-03,  Validation Loss: 1.3924e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 9.0781e-03,  Validation Loss: 1.1781e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 1.2400e-02,  Validation Loss: 5.5459e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 8.2919e-03,  Validation Loss: 3.7479e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 2.0883e-02,  Validation Loss: 1.1010e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 9.5631e-03,  Validation Loss: 4.6482e-03,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.00083769
# Epoch   9:  Train Loss: 1.2669e-02,  Validation Loss: 1.9817e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.003332
# Epoch  10:  Train Loss: 7.4546e-03,  Validation Loss: 1.9987e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0074273
# Epoch  11:  Train Loss: 1.2798e-02,  Validation Loss: 2.8885e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.013032
# Epoch  12:  Train Loss: 3.1704e-02,  Validation Loss: 8.3599e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.020021
# Epoch  13:  Train Loss: 3.7156e-02,  Validation Loss: 1.7028e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.028238
# Epoch  14:  Train Loss: 4.8832e-02,  Validation Loss: 2.6573e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.0375
# Epoch  15:  Train Loss: 6.7527e-02,  Validation Loss: 4.6116e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.047599
# Epoch  16:  Train Loss: 1.0394e-01,  Validation Loss: 8.3594e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.058311
# Epoch  17:  Train Loss: 1.1718e-01,  Validation Loss: 9.3053e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.069395
# Epoch  18:  Train Loss: 1.4836e-01,  Validation Loss: 1.2206e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.080605
# Epoch  19:  Train Loss: 1.5176e-01,  Validation Loss: 1.1196e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.091689
# Epoch  20:  Train Loss: 1.1637e-01,  Validation Loss: 1.1244e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1024
# Epoch  21:  Train Loss: 1.2557e-01,  Validation Loss: 1.2476e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.1125
# Epoch  22:  Train Loss: 1.1988e-01,  Validation Loss: 1.1876e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.12176
# Epoch  23:  Train Loss: 1.4893e-01,  Validation Loss: 1.1615e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.12998
# Epoch  24:  Train Loss: 1.1291e-01,  Validation Loss: 1.1114e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.13697
# Epoch  25:  Train Loss: 1.1079e-01,  Validation Loss: 1.1037e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.14257
# Epoch  26:  Train Loss: 1.0917e-01,  Validation Loss: 1.0842e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.14667
# Epoch  27:  Train Loss: 1.7962e-01,  Validation Loss: 1.2052e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.14916
# Epoch  28:  Train Loss: 1.1571e-01,  Validation Loss: 1.1300e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  29:  Train Loss: 1.4524e-01,  Validation Loss: 1.1357e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  30:  Train Loss: 1.1477e-01,  Validation Loss: 1.1424e-01,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.15
# Epoch  31:  Train Loss: 1.6380e-01,  Validation Loss: 4.2343e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 3.2455e-04,  Validation Loss: 2.9744e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 1.8922e-04,  Validation Loss: 1.0636e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 5.0893e-02,  Validation Loss: 1.3448e+00,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 2.6842e-02,  Validation Loss: 1.0728e-04,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 7.5324e-05,  Validation Loss: 5.6190e-05,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 6.0055e-05,  Validation Loss: 6.4205e-05,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 1.8191e-04,  Validation Loss: 2.6674e-05,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00083769
# Epoch  39:  Train Loss: 1.4860e-03,  Validation Loss: 4.8250e-04,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.003332
# Epoch  40:  Train Loss: 9.7270e-04,  Validation Loss: 4.6732e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0074273
# Epoch  41:  Train Loss: 3.7695e-04,  Validation Loss: 9.6639e-05,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.013032
# Epoch  42:  Train Loss: 3.4308e-05,  Validation Loss: 1.8837e-07,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.020021
# Epoch  43:  Train Loss: 1.8936e-08,  Validation Loss: 5.0428e-12,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.028238
# Epoch  44:  Train Loss: 4.9851e-12,  Validation Loss: 5.0680e-12,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0375
# Early stopping at epoch 44 as train loss 0.000000000005 is below the threshold 0.000000000100
# Traininng Stopped. Time elapsed: 14.85s

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_set_labels(N):
    N = dim
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)] + [f'sin(x{i}*x{j})' for i in range(1, N+1) for j in range(i, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
def coefficient_reconstruction(dim_index,
                                weights, 
                                minimum_coefficient_threshold = 1e-5,
                                coefficient_output_digits = 10, 
                                enable_coefficient_sorting = False):
    
    max_neurons = max(max(len(layer) for layer in SREINet) for SREINet in weights)
    
    labels = generate_set_labels(max_neurons - 1) # number of states = number of neurons - 1

    def explore_path(SREINet_index, layer, neuron, weight_product, label_counts, non_zero_paths):
        """
        Recursively explores non-zero paths in a neural network.
        """
        if layer == len(weights[SREINet_index]) - 1:
            non_zero_paths.append((label_counts, weight_product))
            return

        for next_neuron, weight in enumerate(weights[SREINet_index][layer][neuron]):
            if abs(weight) <= 1e-15:
                # Skip recursion if the weight is zero (if one weight is zero, the whole path will be eliminated)
                continue  
            new_weight_product = weight_product * weight
            next_label_counts = label_counts.copy()
            next_label_counts[labels[next_neuron]] = next_label_counts.get(labels[next_neuron], 0) + 1
            explore_path(SREINet_index, layer + 1, next_neuron, new_weight_product, next_label_counts, non_zero_paths)
    
    #beginning of the algorithm
    all_SREINet_products = []
    for SREINet_index, _ in enumerate(weights):
        non_zero_paths = []
        #collect all non-zero paths
        for neuron_index in range(len(weights[SREINet_index][0])):
            label_counts = {labels[neuron_index]: 1}
            explore_path(SREINet_index, 0, neuron_index, 1, label_counts, non_zero_paths)
        
        #sum up the products with identical composite nonlinear/linear terms
        SREINet_products = {}
        for label_counts, weight_product in non_zero_paths:
            label_counts_key = frozenset(label_counts.items())
            if label_counts_key in SREINet_products:
                SREINet_products[label_counts_key] += weight_product
            else:
                SREINet_products[label_counts_key] = weight_product
        
        #remove the negligible composite terms
        SREINet_products = {k: v for k, v in SREINet_products.items() if abs(v) >= minimum_coefficient_threshold}
        
        if enable_coefficient_sorting:
            #sort the composite terms by their absolute values
            sorted_SREINet_products = dict(sorted(SREINet_products.items(), key=lambda item: abs(item[1]), reverse=True))
        else:
            sorted_SREINet_products = SREINet_products

        all_SREINet_products.append(sorted_SREINet_products)

    #output formatting
    labeled_all_SREINet_products = []
    for SREINet_index, sorted_SREINet_products in enumerate(all_SREINet_products):
        SREINet_product_strings = []
        for key, value in sorted_SREINet_products.items():
            labels_list = []
            only_constant = len(key) == 1 and any(label == 'Constant' for label, _ in key)
            
            for label, count in sorted(key):
                if label == 'Constant' and len(key) > 1:
                    continue
                if label != 'Constant' and count > 1:
                    labels_list.append(f"{label}^{count}")
                elif label == 'Constant' or count == 1:
                    labels_list.append(label if label != 'Constant' else '')
            
            label_str = '*'.join(filter(None, labels_list))
                        
            # Apply coefficient threshold if enabled
            formatted_value = f"{abs(value):.{coefficient_output_digits}g}"

            term_str = label_str if formatted_value == '1' else f"{formatted_value}*{label_str}" if not only_constant else formatted_value if formatted_value != '1' else ''
            sign = '+' if value >= 0 else '-'
            if SREINet_product_strings or value < 0:
                term_str = f" {sign} {term_str}"
            else:
                term_str = term_str
            SREINet_product_strings.append(term_str)

        formatted_output = ''.join(SREINet_product_strings)
        layer_prefix = f"(x{SREINet_index+dim_index+1})'= "
        full_output = layer_prefix + formatted_output
        labeled_all_SREINet_products.append(full_output)

    return labeled_all_SREINet_products

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
for i in range(len(weights_list)):
    path_products = coefficient_reconstruction(i,weights_list[i], 
                                            minimum_coefficient_threshold = 1e-2,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
# Out:
# (x1)'= 2.999992609 - 0.9999988973*x1 + 0.4999991506*sin(x1*x2) + 0.9999998212*x2*x8 - 0.9999994636*x7*x8
# (x2)'= 2.999993801 - 0.9999976754*x2 + 0.4999997914*sin(x2*x3) + 0.9999995232*x1*x3 - 0.9999995232*x1*x8
# (x3)'= 2.999993324 - 0.9999975562*x3 + 0.5000001788*sin(x3*x4) - 0.9999995828*x1*x2 + 0.9999997318*x2*x4
# (x4)'= 2.999998569 - 0.9999996424*x4 + 0.5000000894*sin(x4*x5) - 0.9999998808*x2*x3 + x3*x5
# (x5)'= 3.000000477 - 1.000000238*x5 + 0.500000149*sin(x5*x6) - x3*x4 + x4*x6
# (x6)'= 2.999994993 - 0.9999982715*x6 + 0.4999997616*sin(x6*x7) - 0.9999996424*x4*x5 + 0.9999998212*x5*x7
# (x7)'= 2.999992847 - 0.9999976158*x7 + 0.5000003576*sin(x7*x8) - 0.9999994636*x5*x6 + 0.9999997616*x6*x8
# (x8)'= 3.000011206 - 1.00000304*x8 + 0.499999851*sin(x1*x8) + 1.000000179*x1*x7 - 1.000000954*x6*x7

# %%
for i in range(len(denominator_SREIENet_weights_list)):
    path_products = coefficient_reconstruction(i,denominator_SREIENet_weights_list[i], 
                                            minimum_coefficient_threshold = 0,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 for i in range(len(denominator_SREIENet_weights_list)):
#       2     path_products = coefficient_reconstruction(i,denominator_SREIENet_weights_list[i],
#       3                                             minimum_coefficient_threshold = 0,
#       4                                             coefficient_output_digits = 10,
#       5                                             enable_coefficient_sorting = False)
#       7     for index, dimension in enumerate(path_products):
#
# NameError: name 'denominator_SREIENet_weights_list' is not defined

# %% [markdown]
# ### **Validation**

# %%
import matplotlib.pyplot as plt

# validation: need to draw the output of each dimension independently
dim_to_plot = 1
index = dim_to_plot - 1

#Form NN predictions
NN_output = np.zeros((dx_train.shape[0], dx_train.shape[1]))
for i, weight in enumerate(weights_list):
    model.get_layer('SREINet').set_weights(weight[0])
    output = model.predict(training_input_for_sim)
    NN_output[:,i:i+1] = output


#validate the first trajoctory if there are many
plt.plot(t_arr, NN_output[:,index][:t_arr.shape[0]], 'r', label='NN Prediction')
plt.plot(t_arr, dx_train[:,index][:t_arr.shape[0]], 'k', label='Expected Output')


#pick the last point of the simulation output and use it as the initial condition for the next simulation
x0 = x_train[:t_arr.shape[0]][-1]
t0= t_arr[-1]
myDG = DG.DataGenerator(x0,T=data_T+t0, dt=data_dt, t0=t0)
new_t_arr, new_x, new_dx, guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL)

new_input = new_x

new_NN_output= np.zeros((new_dx.shape[0], new_dx.shape[1]))
for i, weight in enumerate(weights_list):
    model.get_layer('SREINet').set_weights(weight[0])
    output = model.predict(new_input)
    new_NN_output[:,i:i+1] = output


#new_NN_output = model.predict(new_input)
plt.plot(new_t_arr, new_NN_output[:,index], "r--", label='NN Prediction')
plt.plot(new_t_arr, new_dx[:,index], "k--", label='Expected Output')
plt.title("Response of dimension " + str(dim_to_plot))
plt.show()
# Out:
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 189us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 173us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 173us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 174us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 190us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 189us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 176us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 313/313 [==============================] - 0s 182us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 182us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 182us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 181us/step
# 313/313 [==============================] - 0s 179us/step
