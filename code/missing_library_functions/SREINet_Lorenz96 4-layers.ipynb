# %% [markdown]
# ## **Lorenz 96 Model Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_MODEL = 'Lorenz_96' 
MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)  

# Generate data based on the specified model type
LORENZ96_DIM = 10  #set up the dimension of the Lorenz 96 model

num_traj = 1
data_initial_conditions = DG.DataGenerator.generate_initial_conditions(LORENZ96_DIM, num_traj, seed=42) #np.random.normal(1, 2, LORENZ96_DIM

data_T =  30.0       # Length of the data (T)
data_dt = 0.01       # Resolution of the data (dt)
myDG = DG.DataGenerator(data_initial_conditions, T=data_T, dt=data_dt, derivative_mode="exact")
t_arr, x_train, dx_train, default_guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL, method='DOP853')

print("Guessed highest order polynomial:", default_guessed_multiplicative_order)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train #data will be shuffled in the trainer


print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Guessed highest order polynomial: 2
# Training input shape: (3000, 10)
# Training output shape: (3000, 10)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 32
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
dim = training_input.shape[1] # the number of input state variables

# The grid size of each dimension
layer_depth = default_guessed_multiplicative_order + 2
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn) # these numbers exclude the constant term
# Out:
# [10, 10, 10, 10]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn,
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=0.01, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Trainer**

# %%
from sreinet_trainer import *

trainer = SREINetTrainer(model, my_optimizer, loss_fn, data_type='float32')

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.12 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 50
PRUNING_EPOCHS_PER_PERIOD = 35
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

pruning_scheduler = ps.PruningScheduler(steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                    num_periods=N_PERIODS,
                    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
                    #ramp_type='sigmoid',
                    #sigmoid_steepness = 20,
                    #sigmoid_jitter_seed=42,
                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.05

training_histories = []
weights_list = []
loss_list = []

# %%
for i in range(training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    output = training_output[:, i:i+1]
    
    history = trainer.fit(training_input, output,
     batch_size=MINI_BATCH_SIZE, 
     validation_split=0.20,
     epochs=round(NUM_EPOCHS), 
     pruning_scheduler=pruning_scheduler,
     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
     shuffle_per_epoch=False,
     patience_periods=15,
     verbose=1,
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
    loss_list.append(trainer.get_best_loss())

    #reset the model and trainer
    trainer.reset_trainer_and_model_weights(i)
# Out:
# Training dimension 1...
# Epoch   1 (Period 1):  Train Loss: 2.649e+02,  Validation Loss: 8.601e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 5.624e+01,  Validation Loss: 4.426e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 3.176e+01,  Validation Loss: 2.739e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 2.374e+01,  Validation Loss: 1.987e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 1.861e+01,  Validation Loss: 1.458e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 1.533e+01,  Validation Loss: 1.251e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 1.289e+01,  Validation Loss: 9.864e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 1.134e+01,  Validation Loss: 9.813e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   9 (Period 1):  Train Loss: 9.187e+00,  Validation Loss: 8.597e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00047312
# Epoch  10 (Period 1):  Train Loss: 8.327e+00,  Validation Loss: 7.182e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch  11 (Period 1):  Train Loss: 7.056e+00,  Validation Loss: 6.691e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch  12 (Period 1):  Train Loss: 6.568e+00,  Validation Loss: 5.284e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch  13 (Period 1):  Train Loss: 6.151e+00,  Validation Loss: 5.553e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch  14 (Period 1):  Train Loss: 5.586e+00,  Validation Loss: 4.759e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch  15 (Period 1):  Train Loss: 6.381e+00,  Validation Loss: 4.979e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch  16 (Period 1):  Train Loss: 5.250e+00,  Validation Loss: 4.493e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch  17 (Period 1):  Train Loss: 6.129e+00,  Validation Loss: 5.032e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch  18 (Period 1):  Train Loss: 7.757e+00,  Validation Loss: 5.646e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch  19 (Period 1):  Train Loss: 8.324e+00,  Validation Loss: 5.768e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch  20 (Period 1):  Train Loss: 8.014e+00,  Validation Loss: 5.914e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch  21 (Period 1):  Train Loss: 1.249e+01,  Validation Loss: 9.094e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch  22 (Period 1):  Train Loss: 1.519e+01,  Validation Loss: 1.337e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch  23 (Period 1):  Train Loss: 1.808e+01,  Validation Loss: 1.228e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch  24 (Period 1):  Train Loss: 1.960e+01,  Validation Loss: 1.606e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch  25 (Period 1):  Train Loss: 1.527e+01,  Validation Loss: 1.270e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch  26 (Period 1):  Train Loss: 1.545e+01,  Validation Loss: 1.546e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch  27 (Period 1):  Train Loss: 1.486e+01,  Validation Loss: 1.483e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch  28 (Period 1):  Train Loss: 2.022e+01,  Validation Loss: 1.621e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch  29 (Period 1):  Train Loss: 1.803e+01,  Validation Loss: 1.861e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch  30 (Period 1):  Train Loss: 1.908e+01,  Validation Loss: 1.691e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch  31 (Period 1):  Train Loss: 1.520e+01,  Validation Loss: 1.577e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch  32 (Period 1):  Train Loss: 1.526e+01,  Validation Loss: 1.626e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch  33 (Period 1):  Train Loss: 1.454e+01,  Validation Loss: 1.428e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  34 (Period 1):  Train Loss: 2.002e+01,  Validation Loss: 1.482e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  35 (Period 1):  Train Loss: 1.526e+01,  Validation Loss: 1.334e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  36 (Period 2):  Train Loss: 7.242e+00,  Validation Loss: 3.990e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  37 (Period 2):  Train Loss: 3.197e+00,  Validation Loss: 2.964e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  38 (Period 2):  Train Loss: 2.216e+00,  Validation Loss: 2.046e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  39 (Period 2):  Train Loss: 1.898e+00,  Validation Loss: 1.341e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  40 (Period 2):  Train Loss: 1.575e+00,  Validation Loss: 1.511e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  41 (Period 2):  Train Loss: 1.330e+00,  Validation Loss: 1.323e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  42 (Period 2):  Train Loss: 1.190e+00,  Validation Loss: 1.029e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  43 (Period 2):  Train Loss: 1.138e+00,  Validation Loss: 1.140e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  44 (Period 2):  Train Loss: 1.065e+00,  Validation Loss: 1.108e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch  45 (Period 2):  Train Loss: 9.184e-01,  Validation Loss: 9.043e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch  46 (Period 2):  Train Loss: 8.648e-01,  Validation Loss: 7.004e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch  47 (Period 2):  Train Loss: 8.051e-01,  Validation Loss: 7.234e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch  48 (Period 2):  Train Loss: 9.462e-01,  Validation Loss: 8.315e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch  49 (Period 2):  Train Loss: 1.299e+00,  Validation Loss: 9.361e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch  50 (Period 2):  Train Loss: 1.747e+00,  Validation Loss: 1.268e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.021755
# Epoch  51 (Period 2):  Train Loss: 2.212e+00,  Validation Loss: 1.602e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch  52 (Period 2):  Train Loss: 1.957e+00,  Validation Loss: 1.532e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch  53 (Period 2):  Train Loss: 1.947e+00,  Validation Loss: 1.527e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch  54 (Period 2):  Train Loss: 3.112e+00,  Validation Loss: 2.820e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch  55 (Period 2):  Train Loss: 4.198e+00,  Validation Loss: 3.367e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch  56 (Period 2):  Train Loss: 4.601e+00,  Validation Loss: 3.923e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch  57 (Period 2):  Train Loss: 6.081e+00,  Validation Loss: 5.103e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch  58 (Period 2):  Train Loss: 6.399e+00,  Validation Loss: 5.440e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch  59 (Period 2):  Train Loss: 5.627e+00,  Validation Loss: 4.338e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch  60 (Period 2):  Train Loss: 5.611e+00,  Validation Loss: 5.213e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch  61 (Period 2):  Train Loss: 5.176e+00,  Validation Loss: 4.971e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch  62 (Period 2):  Train Loss: 5.911e+00,  Validation Loss: 5.425e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch  63 (Period 2):  Train Loss: 5.850e+00,  Validation Loss: 4.826e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch  64 (Period 2):  Train Loss: 8.046e+00,  Validation Loss: 6.824e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch  65 (Period 2):  Train Loss: 1.108e+01,  Validation Loss: 1.088e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch  66 (Period 2):  Train Loss: 1.012e+01,  Validation Loss: 8.287e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch  67 (Period 2):  Train Loss: 9.562e+00,  Validation Loss: 8.821e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch  68 (Period 2):  Train Loss: 8.953e+00,  Validation Loss: 8.130e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  69 (Period 2):  Train Loss: 9.123e+00,  Validation Loss: 8.993e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  70 (Period 2):  Train Loss: 9.106e+00,  Validation Loss: 9.561e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  71 (Period 3):  Train Loss: 3.596e+00,  Validation Loss: 2.046e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  72 (Period 3):  Train Loss: 1.441e+00,  Validation Loss: 1.203e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  73 (Period 3):  Train Loss: 9.798e-01,  Validation Loss: 7.803e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  74 (Period 3):  Train Loss: 6.924e-01,  Validation Loss: 6.273e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  75 (Period 3):  Train Loss: 5.449e-01,  Validation Loss: 3.780e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  76 (Period 3):  Train Loss: 4.912e-01,  Validation Loss: 4.561e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  77 (Period 3):  Train Loss: 5.262e-01,  Validation Loss: 5.125e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  78 (Period 3):  Train Loss: 4.499e-01,  Validation Loss: 4.449e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  79 (Period 3):  Train Loss: 4.173e-01,  Validation Loss: 2.827e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch  80 (Period 3):  Train Loss: 3.471e-01,  Validation Loss: 3.056e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch  81 (Period 3):  Train Loss: 3.243e-01,  Validation Loss: 3.170e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch  82 (Period 3):  Train Loss: 4.457e-01,  Validation Loss: 2.487e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch  83 (Period 3):  Train Loss: 4.358e-01,  Validation Loss: 2.514e-01,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.011459
# Epoch  84 (Period 3):  Train Loss: 5.009e-01,  Validation Loss: 4.037e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch  85 (Period 3):  Train Loss: 7.730e-01,  Validation Loss: 5.197e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch  86 (Period 3):  Train Loss: 1.143e+00,  Validation Loss: 7.757e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch  87 (Period 3):  Train Loss: 1.423e+00,  Validation Loss: 1.282e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch  88 (Period 3):  Train Loss: 1.746e+00,  Validation Loss: 1.533e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch  89 (Period 3):  Train Loss: 2.103e+00,  Validation Loss: 1.624e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch  90 (Period 3):  Train Loss: 1.863e+00,  Validation Loss: 1.883e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch  91 (Period 3):  Train Loss: 2.139e+00,  Validation Loss: 2.082e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch  92 (Period 3):  Train Loss: 3.789e+00,  Validation Loss: 3.244e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch  93 (Period 3):  Train Loss: 3.262e+00,  Validation Loss: 3.052e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.078541
# Epoch  94 (Period 3):  Train Loss: 2.905e+00,  Validation Loss: 2.675e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch  95 (Period 3):  Train Loss: 2.879e+00,  Validation Loss: 2.878e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch  96 (Period 3):  Train Loss: 2.802e+00,  Validation Loss: 2.925e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch  97 (Period 3):  Train Loss: 3.786e+00,  Validation Loss: 3.377e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch  98 (Period 3):  Train Loss: 3.421e+00,  Validation Loss: 3.785e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch  99 (Period 3):  Train Loss: 3.478e+00,  Validation Loss: 4.165e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.11258
# Epoch 100 (Period 3):  Train Loss: 3.532e+00,  Validation Loss: 3.312e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch 101 (Period 3):  Train Loss: 3.491e+00,  Validation Loss: 3.470e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch 102 (Period 3):  Train Loss: 3.533e+00,  Validation Loss: 3.504e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch 103 (Period 3):  Train Loss: 3.501e+00,  Validation Loss: 3.052e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 104 (Period 3):  Train Loss: 3.507e+00,  Validation Loss: 3.278e+00,  Epoch Time: 0.09s,  Current Pruning Threshold: 0.12
# Epoch 105 (Period 3):  Train Loss: 3.488e+00,  Validation Loss: 3.441e+00,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.12
# Epoch 106 (Period 4):  Train Loss: 2.683e+00,  Validation Loss: 2.471e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 107 (Period 4):  Train Loss: 7.404e-01,  Validation Loss: 3.789e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 108 (Period 4):  Train Loss: 3.935e-01,  Validation Loss: 3.401e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 109 (Period 4):  Train Loss: 3.518e-01,  Validation Loss: 3.631e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 110 (Period 4):  Train Loss: 3.649e-01,  Validation Loss: 3.866e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 111 (Period 4):  Train Loss: 3.160e-01,  Validation Loss: 2.988e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 112 (Period 4):  Train Loss: 3.067e-01,  Validation Loss: 2.230e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 113 (Period 4):  Train Loss: 2.993e-01,  Validation Loss: 2.490e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 114 (Period 4):  Train Loss: 2.727e-01,  Validation Loss: 2.094e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch 115 (Period 4):  Train Loss: 2.608e-01,  Validation Loss: 1.797e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch 116 (Period 4):  Train Loss: 2.427e-01,  Validation Loss: 1.917e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch 117 (Period 4):  Train Loss: 2.812e-01,  Validation Loss: 1.581e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch 118 (Period 4):  Train Loss: 4.185e-01,  Validation Loss: 2.796e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch 119 (Period 4):  Train Loss: 5.765e-01,  Validation Loss: 4.132e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch 120 (Period 4):  Train Loss: 7.318e-01,  Validation Loss: 6.404e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch 121 (Period 4):  Train Loss: 7.401e-01,  Validation Loss: 6.604e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch 122 (Period 4):  Train Loss: 7.929e-01,  Validation Loss: 7.876e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch 123 (Period 4):  Train Loss: 1.002e+00,  Validation Loss: 9.674e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch 124 (Period 4):  Train Loss: 1.126e+00,  Validation Loss: 8.962e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch 125 (Period 4):  Train Loss: 1.561e+00,  Validation Loss: 1.376e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch 126 (Period 4):  Train Loss: 1.657e+00,  Validation Loss: 1.581e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch 127 (Period 4):  Train Loss: 2.250e+00,  Validation Loss: 2.239e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch 128 (Period 4):  Train Loss: 2.105e+00,  Validation Loss: 1.940e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch 129 (Period 4):  Train Loss: 2.162e+00,  Validation Loss: 2.173e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch 130 (Period 4):  Train Loss: 2.250e+00,  Validation Loss: 2.138e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch 131 (Period 4):  Train Loss: 2.211e+00,  Validation Loss: 2.251e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.098245
# Epoch 132 (Period 4):  Train Loss: 2.337e+00,  Validation Loss: 2.172e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.10374
# Epoch 133 (Period 4):  Train Loss: 2.518e+00,  Validation Loss: 2.481e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch 134 (Period 4):  Train Loss: 2.468e+00,  Validation Loss: 2.301e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch 135 (Period 4):  Train Loss: 4.926e+00,  Validation Loss: 4.545e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch 136 (Period 4):  Train Loss: 4.494e+00,  Validation Loss: 4.683e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch 137 (Period 4):  Train Loss: 4.289e+00,  Validation Loss: 4.192e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch 138 (Period 4):  Train Loss: 4.731e+00,  Validation Loss: 4.439e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 139 (Period 4):  Train Loss: 4.397e+00,  Validation Loss: 4.123e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 140 (Period 4):  Train Loss: 4.429e+00,  Validation Loss: 4.376e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 141 (Period 5):  Train Loss: 1.980e+00,  Validation Loss: 6.978e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 142 (Period 5):  Train Loss: 5.682e-01,  Validation Loss: 3.598e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 143 (Period 5):  Train Loss: 4.330e-01,  Validation Loss: 2.868e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 144 (Period 5):  Train Loss: 3.657e-01,  Validation Loss: 4.101e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 145 (Period 5):  Train Loss: 3.328e-01,  Validation Loss: 4.627e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 146 (Period 5):  Train Loss: 2.903e-01,  Validation Loss: 2.942e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 147 (Period 5):  Train Loss: 3.113e-01,  Validation Loss: 4.009e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 148 (Period 5):  Train Loss: 2.993e-01,  Validation Loss: 1.806e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 149 (Period 5):  Train Loss: 2.433e-01,  Validation Loss: 2.520e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch 150 (Period 5):  Train Loss: 2.858e-01,  Validation Loss: 2.382e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch 151 (Period 5):  Train Loss: 2.151e-01,  Validation Loss: 2.550e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch 152 (Period 5):  Train Loss: 2.054e-01,  Validation Loss: 2.167e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch 153 (Period 5):  Train Loss: 3.509e-01,  Validation Loss: 3.260e-01,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.011459
# Epoch 154 (Period 5):  Train Loss: 4.731e-01,  Validation Loss: 2.845e-01,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.016262
# Epoch 155 (Period 5):  Train Loss: 6.265e-01,  Validation Loss: 5.007e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch 156 (Period 5):  Train Loss: 6.063e-01,  Validation Loss: 4.097e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch 157 (Period 5):  Train Loss: 1.030e+00,  Validation Loss: 7.149e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch 158 (Period 5):  Train Loss: 1.759e+00,  Validation Loss: 1.370e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.041459
# Epoch 159 (Period 5):  Train Loss: 1.466e+00,  Validation Loss: 1.234e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.048757
# Epoch 160 (Period 5):  Train Loss: 2.034e+00,  Validation Loss: 2.076e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch 161 (Period 5):  Train Loss: 1.895e+00,  Validation Loss: 1.659e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch 162 (Period 5):  Train Loss: 1.821e+00,  Validation Loss: 1.833e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch 163 (Period 5):  Train Loss: 2.141e+00,  Validation Loss: 2.001e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch 164 (Period 5):  Train Loss: 2.199e+00,  Validation Loss: 2.054e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch 165 (Period 5):  Train Loss: 2.123e+00,  Validation Loss: 2.038e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch 166 (Period 5):  Train Loss: 2.102e+00,  Validation Loss: 2.144e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch 167 (Period 5):  Train Loss: 2.450e+00,  Validation Loss: 2.399e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch 168 (Period 5):  Train Loss: 2.370e+00,  Validation Loss: 2.462e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch 169 (Period 5):  Train Loss: 2.879e+00,  Validation Loss: 2.691e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch 170 (Period 5):  Train Loss: 2.750e+00,  Validation Loss: 2.760e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch 171 (Period 5):  Train Loss: 2.815e+00,  Validation Loss: 3.075e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch 172 (Period 5):  Train Loss: 2.829e+00,  Validation Loss: 2.771e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch 173 (Period 5):  Train Loss: 2.811e+00,  Validation Loss: 2.815e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 174 (Period 5):  Train Loss: 2.784e+00,  Validation Loss: 2.902e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.12
# Epoch 175 (Period 5):  Train Loss: 2.751e+00,  Validation Loss: 2.689e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 176 (Period 6):  Train Loss: 1.505e+00,  Validation Loss: 7.568e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 177 (Period 6):  Train Loss: 7.627e-01,  Validation Loss: 4.654e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 178 (Period 6):  Train Loss: 4.153e-01,  Validation Loss: 2.859e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 179 (Period 6):  Train Loss: 3.025e-01,  Validation Loss: 3.316e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 180 (Period 6):  Train Loss: 2.858e-01,  Validation Loss: 2.205e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 181 (Period 6):  Train Loss: 2.646e-01,  Validation Loss: 1.713e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 182 (Period 6):  Train Loss: 2.611e-01,  Validation Loss: 1.844e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 183 (Period 6):  Train Loss: 2.180e-01,  Validation Loss: 1.913e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 184 (Period 6):  Train Loss: 1.827e-01,  Validation Loss: 1.788e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch 185 (Period 6):  Train Loss: 2.209e-01,  Validation Loss: 1.676e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch 186 (Period 6):  Train Loss: 1.783e-01,  Validation Loss: 1.633e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch 187 (Period 6):  Train Loss: 3.133e-01,  Validation Loss: 2.423e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch 188 (Period 6):  Train Loss: 3.315e-01,  Validation Loss: 2.946e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch 189 (Period 6):  Train Loss: 3.211e-01,  Validation Loss: 2.478e-01,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.016262
# Epoch 190 (Period 6):  Train Loss: 6.122e-01,  Validation Loss: 4.735e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch 191 (Period 6):  Train Loss: 9.599e-01,  Validation Loss: 8.553e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch 192 (Period 6):  Train Loss: 1.441e+00,  Validation Loss: 1.051e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch 193 (Period 6):  Train Loss: 1.253e+00,  Validation Loss: 1.175e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch 194 (Period 6):  Train Loss: 1.736e+00,  Validation Loss: 1.362e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.048757
# Epoch 195 (Period 6):  Train Loss: 1.490e+00,  Validation Loss: 1.415e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch 196 (Period 6):  Train Loss: 1.615e+00,  Validation Loss: 1.415e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch 197 (Period 6):  Train Loss: 1.532e+00,  Validation Loss: 1.345e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch 198 (Period 6):  Train Loss: 1.604e+00,  Validation Loss: 1.367e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch 199 (Period 6):  Train Loss: 1.701e+00,  Validation Loss: 1.667e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch 200 (Period 6):  Train Loss: 1.705e+00,  Validation Loss: 1.579e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch 201 (Period 6):  Train Loss: 1.752e+00,  Validation Loss: 1.618e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch 202 (Period 6):  Train Loss: 1.696e+00,  Validation Loss: 1.737e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch 203 (Period 6):  Train Loss: 1.810e+00,  Validation Loss: 1.726e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch 204 (Period 6):  Train Loss: 2.856e+00,  Validation Loss: 2.680e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch 205 (Period 6):  Train Loss: 3.041e+00,  Validation Loss: 2.981e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch 206 (Period 6):  Train Loss: 2.864e+00,  Validation Loss: 2.633e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch 207 (Period 6):  Train Loss: 4.396e+00,  Validation Loss: 4.164e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch 208 (Period 6):  Train Loss: 4.076e+00,  Validation Loss: 4.174e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 209 (Period 6):  Train Loss: 3.850e+00,  Validation Loss: 3.696e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 210 (Period 6):  Train Loss: 3.792e+00,  Validation Loss: 3.801e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 211 (Period 7):  Train Loss: 1.826e+00,  Validation Loss: 8.193e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch 212 (Period 7):  Train Loss: 6.055e-01,  Validation Loss: 5.384e-01,  Epoch Time: 0.14s,  Current Pruning Threshold: 0
# Epoch 213 (Period 7):  Train Loss: 4.449e-01,  Validation Loss: 3.619e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 214 (Period 7):  Train Loss: 3.500e-01,  Validation Loss: 2.099e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 215 (Period 7):  Train Loss: 2.807e-01,  Validation Loss: 3.534e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 216 (Period 7):  Train Loss: 2.408e-01,  Validation Loss: 1.617e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 217 (Period 7):  Train Loss: 2.448e-01,  Validation Loss: 2.642e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 218 (Period 7):  Train Loss: 2.234e-01,  Validation Loss: 1.661e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 219 (Period 7):  Train Loss: 1.959e-01,  Validation Loss: 1.930e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch 220 (Period 7):  Train Loss: 1.894e-01,  Validation Loss: 1.747e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch 221 (Period 7):  Train Loss: 1.834e-01,  Validation Loss: 1.544e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch 222 (Period 7):  Train Loss: 2.136e-01,  Validation Loss: 1.584e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch 223 (Period 7):  Train Loss: 2.099e-01,  Validation Loss: 1.895e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch 224 (Period 7):  Train Loss: 2.841e-01,  Validation Loss: 2.006e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch 225 (Period 7):  Train Loss: 5.279e-01,  Validation Loss: 3.553e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch 226 (Period 7):  Train Loss: 8.068e-01,  Validation Loss: 5.491e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch 227 (Period 7):  Train Loss: 1.036e+00,  Validation Loss: 7.057e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch 228 (Period 7):  Train Loss: 6.944e-01,  Validation Loss: 6.855e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch 229 (Period 7):  Train Loss: 9.061e-01,  Validation Loss: 7.888e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch 230 (Period 7):  Train Loss: 1.516e+00,  Validation Loss: 1.175e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.056233
# Epoch 231 (Period 7):  Train Loss: 1.759e+00,  Validation Loss: 1.640e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.063767
# Epoch 232 (Period 7):  Train Loss: 1.920e+00,  Validation Loss: 1.865e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch 233 (Period 7):  Train Loss: 1.846e+00,  Validation Loss: 1.884e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch 234 (Period 7):  Train Loss: 1.633e+00,  Validation Loss: 1.642e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch 235 (Period 7):  Train Loss: 2.621e+00,  Validation Loss: 1.656e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch 236 (Period 7):  Train Loss: 1.802e+00,  Validation Loss: 1.747e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch 237 (Period 7):  Train Loss: 2.976e+00,  Validation Loss: 2.268e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch 238 (Period 7):  Train Loss: 2.301e+00,  Validation Loss: 2.113e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch 239 (Period 7):  Train Loss: 1.912e+00,  Validation Loss: 1.637e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch 240 (Period 7):  Train Loss: 2.514e+00,  Validation Loss: 1.613e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch 241 (Period 7):  Train Loss: 1.368e+00,  Validation Loss: 1.181e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch 242 (Period 7):  Train Loss: 9.323e-01,  Validation Loss: 7.732e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch 243 (Period 7):  Train Loss: 6.450e-01,  Validation Loss: 5.474e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 244 (Period 7):  Train Loss: 4.323e-01,  Validation Loss: 3.590e-01,  Epoch Time: 0.11s,  Current Pruning Threshold: 0.12
# Epoch 245 (Period 7):  Train Loss: 3.090e-01,  Validation Loss: 2.142e-01,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.12
# Epoch 246 (Period 8):  Train Loss: 2.474e-01,  Validation Loss: 3.561e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 247 (Period 8):  Train Loss: 1.619e-01,  Validation Loss: 4.901e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 248 (Period 8):  Train Loss: 4.324e-02,  Validation Loss: 2.027e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 249 (Period 8):  Train Loss: 1.523e-02,  Validation Loss: 8.722e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 250 (Period 8):  Train Loss: 1.302e-02,  Validation Loss: 1.471e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 251 (Period 8):  Train Loss: 1.800e-02,  Validation Loss: 2.278e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 252 (Period 8):  Train Loss: 1.292e-02,  Validation Loss: 1.984e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 253 (Period 8):  Train Loss: 1.724e-02,  Validation Loss: 2.133e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 254 (Period 8):  Train Loss: 1.376e-02,  Validation Loss: 9.616e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch 255 (Period 8):  Train Loss: 1.540e-02,  Validation Loss: 8.210e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch 256 (Period 8):  Train Loss: 6.032e-02,  Validation Loss: 1.440e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch 257 (Period 8):  Train Loss: 2.810e-02,  Validation Loss: 1.588e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch 258 (Period 8):  Train Loss: 2.284e-02,  Validation Loss: 1.821e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch 259 (Period 8):  Train Loss: 4.181e-02,  Validation Loss: 2.708e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch 260 (Period 8):  Train Loss: 4.004e-02,  Validation Loss: 3.063e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch 261 (Period 8):  Train Loss: 4.594e-02,  Validation Loss: 3.192e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch 262 (Period 8):  Train Loss: 2.864e-02,  Validation Loss: 2.438e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch 263 (Period 8):  Train Loss: 2.576e-02,  Validation Loss: 1.881e-02,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.041459
# Epoch 264 (Period 8):  Train Loss: 2.279e-02,  Validation Loss: 1.350e-02,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.048757
# Epoch 265 (Period 8):  Train Loss: 1.039e-02,  Validation Loss: 7.782e-03,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.056233
# Epoch 266 (Period 8):  Train Loss: 6.492e-03,  Validation Loss: 6.025e-03,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.063767
# Epoch 267 (Period 8):  Train Loss: 4.610e-03,  Validation Loss: 4.869e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch 268 (Period 8):  Train Loss: 5.233e-03,  Validation Loss: 3.908e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch 269 (Period 8):  Train Loss: 1.612e-04,  Validation Loss: 3.383e-06,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.085547
# Epoch 270 (Period 8):  Train Loss: 1.155e-07,  Validation Loss: 2.729e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch 271 (Period 8):  Train Loss: 5.699e-11,  Validation Loss: 3.428e-11,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Early stopping at epoch 271 as train loss 0.00000000005699 is below the threshold 0.00000000010000
# Training Stopped. Time elapsed: 16.19s
# Final model saved as best with loss: 3.427502e-11
# Training dimension 2...
# Epoch   1 (Period 1):  Train Loss: 9.970e+01,  Validation Loss: 2.477e+01,  Epoch Time: 0.11s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 1.863e+01,  Validation Loss: 1.508e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 9.961e+00,  Validation Loss: 8.467e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 6.809e+00,  Validation Loss: 5.390e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 5.523e+00,  Validation Loss: 3.703e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 3.888e+00,  Validation Loss: 3.809e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 3.366e+00,  Validation Loss: 3.059e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 2.886e+00,  Validation Loss: 2.846e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   9 (Period 1):  Train Loss: 2.696e+00,  Validation Loss: 2.570e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch  10 (Period 1):  Train Loss: 2.496e+00,  Validation Loss: 2.005e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch  11 (Period 1):  Train Loss: 1.986e+00,  Validation Loss: 1.668e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch  12 (Period 1):  Train Loss: 1.916e+00,  Validation Loss: 1.770e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch  13 (Period 1):  Train Loss: 1.763e+00,  Validation Loss: 1.408e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch  14 (Period 1):  Train Loss: 2.121e+00,  Validation Loss: 1.486e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch  15 (Period 1):  Train Loss: 1.782e+00,  Validation Loss: 1.662e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch  16 (Period 1):  Train Loss: 3.014e+00,  Validation Loss: 2.172e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch  17 (Period 1):  Train Loss: 2.721e+00,  Validation Loss: 1.752e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch  18 (Period 1):  Train Loss: 3.388e+00,  Validation Loss: 2.696e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch  19 (Period 1):  Train Loss: 4.618e+00,  Validation Loss: 3.238e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch  20 (Period 1):  Train Loss: 8.518e+00,  Validation Loss: 6.023e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch  21 (Period 1):  Train Loss: 1.322e+01,  Validation Loss: 7.956e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch  22 (Period 1):  Train Loss: 1.045e+01,  Validation Loss: 8.882e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch  23 (Period 1):  Train Loss: 1.050e+01,  Validation Loss: 8.959e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch  24 (Period 1):  Train Loss: 1.072e+01,  Validation Loss: 9.794e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch  25 (Period 1):  Train Loss: 1.222e+01,  Validation Loss: 1.020e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch  26 (Period 1):  Train Loss: 1.656e+01,  Validation Loss: 1.432e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch  27 (Period 1):  Train Loss: 1.887e+01,  Validation Loss: 1.798e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch  28 (Period 1):  Train Loss: 1.678e+01,  Validation Loss: 1.592e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch  29 (Period 1):  Train Loss: 1.591e+01,  Validation Loss: 1.514e+01,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.11258
# Epoch  30 (Period 1):  Train Loss: 1.410e+01,  Validation Loss: 1.370e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch  31 (Period 1):  Train Loss: 1.607e+01,  Validation Loss: 1.676e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch  32 (Period 1):  Train Loss: 2.141e+01,  Validation Loss: 1.734e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch  33 (Period 1):  Train Loss: 1.547e+01,  Validation Loss: 1.365e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  34 (Period 1):  Train Loss: 1.362e+01,  Validation Loss: 1.308e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  35 (Period 1):  Train Loss: 1.638e+01,  Validation Loss: 1.280e+01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  36 (Period 2):  Train Loss: 5.157e+00,  Validation Loss: 2.808e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0
# Epoch  37 (Period 2):  Train Loss: 1.687e+00,  Validation Loss: 1.211e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  38 (Period 2):  Train Loss: 9.668e-01,  Validation Loss: 9.115e-01,  Epoch Time: 0.08s,  Current Pruning Threshold: 0
# Epoch  39 (Period 2):  Train Loss: 7.578e-01,  Validation Loss: 7.925e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  40 (Period 2):  Train Loss: 7.536e-01,  Validation Loss: 5.481e-01,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  41 (Period 2):  Train Loss: 6.253e-01,  Validation Loss: 5.223e-01,  Epoch Time: 0.11s,  Current Pruning Threshold: 0
# Epoch  42 (Period 2):  Train Loss: 5.232e-01,  Validation Loss: 6.334e-01,  Epoch Time: 0.08s,  Current Pruning Threshold: 0
# Epoch  43 (Period 2):  Train Loss: 4.539e-01,  Validation Loss: 5.042e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  44 (Period 2):  Train Loss: 4.807e-01,  Validation Loss: 3.301e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch  45 (Period 2):  Train Loss: 4.214e-01,  Validation Loss: 3.833e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.001885
# Epoch  46 (Period 2):  Train Loss: 4.260e-01,  Validation Loss: 4.551e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0042134
# Epoch  47 (Period 2):  Train Loss: 4.408e-01,  Validation Loss: 3.207e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch  48 (Period 2):  Train Loss: 7.303e-01,  Validation Loss: 4.942e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch  49 (Period 2):  Train Loss: 8.050e-01,  Validation Loss: 6.202e-01,  Epoch Time: 0.10s,  Current Pruning Threshold: 0.016262
# Epoch  50 (Period 2):  Train Loss: 1.063e+00,  Validation Loss: 8.849e-01,  Epoch Time: 0.08s,  Current Pruning Threshold: 0.021755
# Epoch  51 (Period 2):  Train Loss: 9.696e-01,  Validation Loss: 8.783e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch  52 (Period 2):  Train Loss: 1.901e+00,  Validation Loss: 1.408e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch  53 (Period 2):  Train Loss: 2.225e+00,  Validation Loss: 2.052e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch  54 (Period 2):  Train Loss: 2.853e+00,  Validation Loss: 2.199e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch  55 (Period 2):  Train Loss: 2.244e+00,  Validation Loss: 1.883e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch  56 (Period 2):  Train Loss: 3.937e+00,  Validation Loss: 2.874e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch  57 (Period 2):  Train Loss: 2.810e+00,  Validation Loss: 2.965e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch  58 (Period 2):  Train Loss: 2.568e+00,  Validation Loss: 2.487e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch  59 (Period 2):  Train Loss: 3.841e+00,  Validation Loss: 2.853e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch  60 (Period 2):  Train Loss: 3.363e+00,  Validation Loss: 3.247e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch  61 (Period 2):  Train Loss: 3.093e+00,  Validation Loss: 3.046e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch  62 (Period 2):  Train Loss: 2.632e+00,  Validation Loss: 2.419e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch  63 (Period 2):  Train Loss: 2.672e+00,  Validation Loss: 2.426e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch  64 (Period 2):  Train Loss: 2.196e+00,  Validation Loss: 1.966e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch  65 (Period 2):  Train Loss: 2.503e+00,  Validation Loss: 2.447e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch  66 (Period 2):  Train Loss: 2.663e+00,  Validation Loss: 2.312e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch  67 (Period 2):  Train Loss: 2.181e+00,  Validation Loss: 1.940e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch  68 (Period 2):  Train Loss: 2.102e+00,  Validation Loss: 1.492e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  69 (Period 2):  Train Loss: 1.252e+00,  Validation Loss: 1.087e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  70 (Period 2):  Train Loss: 1.001e+00,  Validation Loss: 9.459e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch  71 (Period 3):  Train Loss: 2.674e-01,  Validation Loss: 8.750e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  72 (Period 3):  Train Loss: 6.685e-02,  Validation Loss: 6.516e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  73 (Period 3):  Train Loss: 5.373e-02,  Validation Loss: 5.499e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  74 (Period 3):  Train Loss: 4.081e-02,  Validation Loss: 3.923e-02,  Epoch Time: 0.05s,  Current Pruning Threshold: 0
# Epoch  75 (Period 3):  Train Loss: 3.879e-02,  Validation Loss: 2.382e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  76 (Period 3):  Train Loss: 3.267e-02,  Validation Loss: 3.305e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  77 (Period 3):  Train Loss: 4.100e-02,  Validation Loss: 2.305e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  78 (Period 3):  Train Loss: 2.791e-02,  Validation Loss: 1.724e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch  79 (Period 3):  Train Loss: 2.221e-02,  Validation Loss: 2.173e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch  80 (Period 3):  Train Loss: 2.078e-02,  Validation Loss: 1.958e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch  81 (Period 3):  Train Loss: 6.057e-02,  Validation Loss: 2.782e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch  82 (Period 3):  Train Loss: 4.831e-02,  Validation Loss: 4.120e-02,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.0074216
# Epoch  83 (Period 3):  Train Loss: 3.011e-01,  Validation Loss: 1.751e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch  84 (Period 3):  Train Loss: 2.634e-01,  Validation Loss: 2.104e-01,  Epoch Time: 0.14s,  Current Pruning Threshold: 0.016262
# Epoch  85 (Period 3):  Train Loss: 2.461e-01,  Validation Loss: 2.239e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch  86 (Period 3):  Train Loss: 2.540e-01,  Validation Loss: 2.604e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch  87 (Period 3):  Train Loss: 2.632e-01,  Validation Loss: 2.056e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.034453
# Epoch  88 (Period 3):  Train Loss: 2.176e-01,  Validation Loss: 2.011e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch  89 (Period 3):  Train Loss: 1.637e-01,  Validation Loss: 1.694e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch  90 (Period 3):  Train Loss: 1.774e-01,  Validation Loss: 1.630e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch  91 (Period 3):  Train Loss: 1.946e-01,  Validation Loss: 1.576e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch  92 (Period 3):  Train Loss: 1.362e-01,  Validation Loss: 1.084e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch  93 (Period 3):  Train Loss: 1.653e-01,  Validation Loss: 1.232e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch  94 (Period 3):  Train Loss: 9.545e-02,  Validation Loss: 6.895e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch  95 (Period 3):  Train Loss: 6.540e-02,  Validation Loss: 4.417e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch  96 (Period 3):  Train Loss: 3.464e-02,  Validation Loss: 2.668e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# ...
# Epoch 295 (Period 9):  Train Loss: 1.893e-01,  Validation Loss: 1.165e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch 296 (Period 9):  Train Loss: 2.965e-01,  Validation Loss: 1.973e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch 297 (Period 9):  Train Loss: 3.092e-01,  Validation Loss: 2.530e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch 298 (Period 9):  Train Loss: 2.751e-01,  Validation Loss: 2.490e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch 299 (Period 9):  Train Loss: 2.936e-01,  Validation Loss: 2.578e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch 300 (Period 9):  Train Loss: 4.248e-01,  Validation Loss: 3.481e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch 301 (Period 9):  Train Loss: 4.421e-01,  Validation Loss: 3.887e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch 302 (Period 9):  Train Loss: 6.542e-01,  Validation Loss: 5.833e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch 303 (Period 9):  Train Loss: 6.872e-01,  Validation Loss: 6.274e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch 304 (Period 9):  Train Loss: 6.927e-01,  Validation Loss: 6.449e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch 305 (Period 9):  Train Loss: 6.604e-01,  Validation Loss: 6.010e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch 306 (Period 9):  Train Loss: 6.256e-01,  Validation Loss: 6.250e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch 307 (Period 9):  Train Loss: 9.480e-01,  Validation Loss: 9.116e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch 308 (Period 9):  Train Loss: 1.088e+00,  Validation Loss: 9.811e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.10854
# Epoch 309 (Period 9):  Train Loss: 1.008e+00,  Validation Loss: 9.586e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch 310 (Period 9):  Train Loss: 9.669e-01,  Validation Loss: 1.020e+00,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch 311 (Period 9):  Train Loss: 9.437e-01,  Validation Loss: 8.796e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch 312 (Period 9):  Train Loss: 9.012e-01,  Validation Loss: 8.952e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch 313 (Period 9):  Train Loss: 1.053e+00,  Validation Loss: 9.801e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 314 (Period 9):  Train Loss: 9.292e-01,  Validation Loss: 9.243e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 315 (Period 9):  Train Loss: 8.705e-01,  Validation Loss: 8.638e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 316 (Period 10):  Train Loss: 2.585e+00,  Validation Loss: 9.703e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 317 (Period 10):  Train Loss: 5.872e-01,  Validation Loss: 1.722e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 318 (Period 10):  Train Loss: 8.254e-02,  Validation Loss: 4.882e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 319 (Period 10):  Train Loss: 3.979e-02,  Validation Loss: 2.383e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 320 (Period 10):  Train Loss: 3.077e-02,  Validation Loss: 2.209e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 321 (Period 10):  Train Loss: 2.949e-02,  Validation Loss: 2.422e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 322 (Period 10):  Train Loss: 2.214e-02,  Validation Loss: 2.248e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 323 (Period 10):  Train Loss: 2.404e-02,  Validation Loss: 2.077e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 324 (Period 10):  Train Loss: 2.135e-02,  Validation Loss: 1.271e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch 325 (Period 10):  Train Loss: 2.477e-02,  Validation Loss: 1.596e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch 326 (Period 10):  Train Loss: 2.959e-02,  Validation Loss: 1.797e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch 327 (Period 10):  Train Loss: 2.839e-02,  Validation Loss: 2.422e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch 328 (Period 10):  Train Loss: 7.544e-02,  Validation Loss: 3.727e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch 329 (Period 10):  Train Loss: 1.038e-01,  Validation Loss: 6.207e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch 330 (Period 10):  Train Loss: 1.984e-01,  Validation Loss: 1.369e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch 331 (Period 10):  Train Loss: 2.181e-01,  Validation Loss: 1.580e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch 332 (Period 10):  Train Loss: 1.739e-01,  Validation Loss: 1.375e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch 333 (Period 10):  Train Loss: 1.985e-01,  Validation Loss: 1.827e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch 334 (Period 10):  Train Loss: 2.657e-01,  Validation Loss: 2.306e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch 335 (Period 10):  Train Loss: 3.076e-01,  Validation Loss: 2.669e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch 336 (Period 10):  Train Loss: 5.559e-01,  Validation Loss: 4.451e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch 337 (Period 10):  Train Loss: 7.153e-01,  Validation Loss: 6.313e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch 338 (Period 10):  Train Loss: 6.526e-01,  Validation Loss: 5.857e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch 339 (Period 10):  Train Loss: 6.336e-01,  Validation Loss: 6.708e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch 340 (Period 10):  Train Loss: 5.954e-01,  Validation Loss: 5.869e-01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.09215
# Epoch 341 (Period 10):  Train Loss: 5.406e-01,  Validation Loss: 4.992e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch 342 (Period 10):  Train Loss: 4.900e-01,  Validation Loss: 4.287e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch 343 (Period 10):  Train Loss: 4.571e-01,  Validation Loss: 3.793e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch 344 (Period 10):  Train Loss: 4.085e-01,  Validation Loss: 4.173e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch 345 (Period 10):  Train Loss: 4.608e-01,  Validation Loss: 3.925e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch 346 (Period 10):  Train Loss: 4.399e-01,  Validation Loss: 4.372e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch 347 (Period 10):  Train Loss: 3.678e-01,  Validation Loss: 3.041e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch 348 (Period 10):  Train Loss: 3.060e-01,  Validation Loss: 2.614e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 349 (Period 10):  Train Loss: 2.619e-01,  Validation Loss: 2.536e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 350 (Period 10):  Train Loss: 1.198e+00,  Validation Loss: 2.306e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 351 (Period 11):  Train Loss: 2.761e+00,  Validation Loss: 5.117e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 352 (Period 11):  Train Loss: 2.336e-01,  Validation Loss: 6.949e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 353 (Period 11):  Train Loss: 3.033e-02,  Validation Loss: 1.976e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 354 (Period 11):  Train Loss: 1.879e-02,  Validation Loss: 2.048e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 355 (Period 11):  Train Loss: 1.146e-02,  Validation Loss: 4.437e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 356 (Period 11):  Train Loss: 5.101e-03,  Validation Loss: 7.067e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 357 (Period 11):  Train Loss: 4.986e-03,  Validation Loss: 4.103e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 358 (Period 11):  Train Loss: 3.184e-03,  Validation Loss: 2.334e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 359 (Period 11):  Train Loss: 2.691e-03,  Validation Loss: 1.895e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch 360 (Period 11):  Train Loss: 3.210e-02,  Validation Loss: 1.376e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch 361 (Period 11):  Train Loss: 2.955e-02,  Validation Loss: 5.261e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch 362 (Period 11):  Train Loss: 5.186e-02,  Validation Loss: 8.936e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch 363 (Period 11):  Train Loss: 9.701e-03,  Validation Loss: 4.446e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch 364 (Period 11):  Train Loss: 1.860e-02,  Validation Loss: 8.121e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch 365 (Period 11):  Train Loss: 1.786e-02,  Validation Loss: 6.896e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021755
# Epoch 366 (Period 11):  Train Loss: 5.788e-03,  Validation Loss: 4.784e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch 367 (Period 11):  Train Loss: 4.377e-03,  Validation Loss: 3.932e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch 368 (Period 11):  Train Loss: 5.335e-02,  Validation Loss: 5.044e-02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.041459
# Epoch 369 (Period 11):  Train Loss: 1.728e-01,  Validation Loss: 1.299e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch 370 (Period 11):  Train Loss: 1.254e-01,  Validation Loss: 8.773e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch 371 (Period 11):  Train Loss: 1.040e-01,  Validation Loss: 9.763e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch 372 (Period 11):  Train Loss: 8.163e-02,  Validation Loss: 6.429e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch 373 (Period 11):  Train Loss: 7.001e-02,  Validation Loss: 6.263e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch 374 (Period 11):  Train Loss: 1.235e+00,  Validation Loss: 9.479e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch 375 (Period 11):  Train Loss: 6.303e-02,  Validation Loss: 4.558e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch 376 (Period 11):  Train Loss: 3.063e-02,  Validation Loss: 4.893e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch 377 (Period 11):  Train Loss: 1.374e-03,  Validation Loss: 1.500e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch 378 (Period 11):  Train Loss: 5.144e-05,  Validation Loss: 5.465e-06,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch 379 (Period 11):  Train Loss: 1.462e-06,  Validation Loss: 1.729e-07,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Epoch 380 (Period 11):  Train Loss: 4.366e-08,  Validation Loss: 4.098e-09,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11579
# Epoch 381 (Period 11):  Train Loss: 1.384e-09,  Validation Loss: 2.836e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11811
# Epoch 382 (Period 11):  Train Loss: 2.802e-10,  Validation Loss: 2.701e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11953
# Epoch 383 (Period 11):  Train Loss: 2.661e-10,  Validation Loss: 2.666e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 384 (Period 11):  Train Loss: 2.563e-10,  Validation Loss: 2.440e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 385 (Period 11):  Train Loss: 2.251e-10,  Validation Loss: 1.873e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.12
# Epoch 386 (Period 12):  Train Loss: 3.229e-05,  Validation Loss: 4.306e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 387 (Period 12):  Train Loss: 1.700e+00,  Validation Loss: 8.394e-01,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 388 (Period 12):  Train Loss: 1.943e-01,  Validation Loss: 6.659e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 389 (Period 12):  Train Loss: 5.661e-02,  Validation Loss: 3.407e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 390 (Period 12):  Train Loss: 1.131e-01,  Validation Loss: 2.955e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 391 (Period 12):  Train Loss: 1.135e-02,  Validation Loss: 9.085e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 392 (Period 12):  Train Loss: 6.303e-03,  Validation Loss: 3.058e-02,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 393 (Period 12):  Train Loss: 1.769e-02,  Validation Loss: 4.123e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0
# Epoch 394 (Period 12):  Train Loss: 8.788e-03,  Validation Loss: 6.022e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.00047312
# Epoch 395 (Period 12):  Train Loss: 9.209e-03,  Validation Loss: 2.953e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.001885
# Epoch 396 (Period 12):  Train Loss: 2.057e-02,  Validation Loss: 2.993e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0042134
# Epoch 397 (Period 12):  Train Loss: 4.300e-02,  Validation Loss: 2.583e-03,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0074216
# Epoch 398 (Period 12):  Train Loss: 2.204e-02,  Validation Loss: 3.708e-04,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.011459
# Epoch 399 (Period 12):  Train Loss: 7.049e-03,  Validation Loss: 7.935e-05,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.016262
# Epoch 400 (Period 12):  Train Loss: 8.323e-06,  Validation Loss: 2.203e-07,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.021755
# Epoch 401 (Period 12):  Train Loss: 9.167e-09,  Validation Loss: 6.460e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.02785
# Epoch 402 (Period 12):  Train Loss: 4.130e-10,  Validation Loss: 4.056e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.034453
# Epoch 403 (Period 12):  Train Loss: 3.775e-10,  Validation Loss: 3.718e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041459
# Epoch 404 (Period 12):  Train Loss: 3.619e-10,  Validation Loss: 3.525e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.048757
# Epoch 405 (Period 12):  Train Loss: 3.424e-10,  Validation Loss: 3.043e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.056233
# Epoch 406 (Period 12):  Train Loss: 2.356e-10,  Validation Loss: 1.499e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.063767
# Epoch 407 (Period 12):  Train Loss: 1.628e-10,  Validation Loss: 1.726e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.071243
# Epoch 408 (Period 12):  Train Loss: 1.607e-10,  Validation Loss: 1.570e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.078541
# Epoch 409 (Period 12):  Train Loss: 1.603e-10,  Validation Loss: 1.647e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.085547
# Epoch 410 (Period 12):  Train Loss: 1.582e-10,  Validation Loss: 1.572e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.09215
# Epoch 411 (Period 12):  Train Loss: 1.598e-10,  Validation Loss: 1.529e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.098245
# Epoch 412 (Period 12):  Train Loss: 1.634e-10,  Validation Loss: 1.600e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10374
# Epoch 413 (Period 12):  Train Loss: 1.392e-10,  Validation Loss: 1.043e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.10854
# Epoch 414 (Period 12):  Train Loss: 9.973e-11,  Validation Loss: 9.393e-11,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.11258
# Early stopping at epoch 414 as train loss 0.00000000009973 is below the threshold 0.00000000010000
# Training Stopped. Time elapsed: 23.86s
# Final model saved as best with loss: 9.393110e-11

# %%
loss_list
# Out:
# [3.427502e-11,
#  4.9378375e-12,
#  2.8485133e-11,
#  8.271709e-12,
#  2.7624684e-12,
#  7.425539e-12,
#  3.0728982e-11,
#  2.6255114e-11,
#  3.3066726e-11,
#  9.39311e-11]

# %% [markdown]
# ## **IV. Coefficient Reconstructor**

# %% [markdown]
# ## **IV. Coefficient Reconstructor**

# %% [markdown]
# #### `generate_set_labels`
#
# The section below generates the layer labels that will be used to recontruct the symbolic of the right hand side (RHS) of governing equations. In addition, it also generates LHS labels.

# %%
def generate_layer_labels(N):
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)]

def generate_LHS_labels(N):
    return [f"(x{i})'" for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
from coefficient_reconstructor import *
cr = CoefficientReconstructor(generate_layer_labels, generate_LHS_labels)

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
eq_str = []
for i in range(len(weights_list)):
    path_products = cr.reconstruct_coefficients(i,
                                               weights_list[i], 
                                            minimum_coefficient_threshold = 3e-2,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
        eq_str.append(dimension)
# Out:
# (x1)' = 8.000007976 - 1.000000132*x1 - 0.9999997893*x10*x9 + 1.000000169*x10*x2
# (x2)' = 7.999998609 - 0.999999934*x2 + 1.000000067*x1*x3 - 1.000000024*x1*x10
# (x3)' = 7.999995663 - 0.9999974737*x3 - 0.9999997649*x1*x2 + 1.000000031*x2*x4
# (x4)' = 8.000002578 - 0.9999999714*x2*x3 + 1.000000021*x3*x5 - 1.000000211*x4
# (x5)' = 7.999999689 - 1.000000078*x5 - 0.9999999644*x3*x4 + 1.00000004*x4*x6
# (x6)' = 7.999997515 - 0.999999978*x4*x5 + 0.9999999054*x5*x7 - 0.9999996893*x6
# (x7)' = 8.00000782 - 1.000000977*x7 - 1.000000111*x5*x6 + 1.000000068*x6*x8
# (x8)' = 8.000006061 - 1.000000098*x6*x7 + 1.000000021*x7*x9 - 1.000000577*x8
# (x9)' = 8.000009183 - 1.000000075*x7*x8 + 1.00000013*x10*x8 - 1.00000151*x9
# (x10)' = 8.000013486 - 0.9999995211*x10 + 1.000000412*x1*x9 - 0.9999996766*x8*x9

# %% [markdown]
# ### **Validation**

# %%
import model_reconstructor as mr

recovered_model = mr.RecoveredModel()
recovered_model.parse_ode_equations(eq_str);

# %% [markdown]
# ### Comparing vector field

# %%
pred_x_dot = recovered_model.predict_derivatives(x_train)

val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

import matplotlib.pyplot as plt

plt.plot(val_t_eval, pred_x_dot[:val_t_eval.shape[0], 0],label='SREINet')
plt.plot(val_t_eval, dx_train[:val_t_eval.shape[0],0], '--', label='True')
plt.xlabel('Time')
plt.ylabel(r'$\dot{x}_1$')
plt.legend()
plt.show()

# %% [markdown]
# ### Comparing response

# %%
val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

validation_result = recovered_model.simulate(data_initial_conditions[0], t_span=val_t_span,t_eval=val_t_eval, method='DOP853')

# %%
import matplotlib.pyplot as plt

val_avg = np.mean(validation_result['y'], axis=0)
x_train_avg = np.mean(x_train, axis=1)

plt.figure(figsize=(4,3))

plt.plot(validation_result['t'], val_avg,label='SREINet')
plt.plot(val_t_eval, x_train_avg, '--', label='True')
plt.xlabel('Time')
plt.ylabel(r'$\bar{x}$')
plt.xlim(0, 6)
#plt.legend()
plt.show()
#plt.savefig('SREINet_Lorenz96_4-layers.png', dpi=600)

# %%
score =recovered_model.score(x_train[:val_t_eval.shape[0]], dx_train[:val_t_eval.shape[0]])
print(f"Score: {score}")

complexity = recovered_model.calculate_complexity()
print(f"Complexity: {complexity}")

complexity_per_dimension = complexity//dim
print(f"Complexity per dimension: {complexity_per_dimension}")
# Out:
# Score: 0.9999999999998247
# Complexity: 40
# Complexity per dimension: 4
