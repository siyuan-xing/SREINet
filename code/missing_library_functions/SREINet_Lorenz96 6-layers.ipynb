# %% [markdown]
# ## **Lorenz 96 Model Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_MODEL = 'Lorenz_96' 
MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)  

# Generate data based on the specified model type
LORENZ96_DIM = 10  #set up the dimension of the Lorenz 96 model

num_traj = 3
data_initial_conditions = DG.DataGenerator.generate_initial_conditions(LORENZ96_DIM, num_traj, seed=42) #np.random.normal(1, 2, LORENZ96_DIM

data_T =  50.0       # Length of the data (T)
data_dt = 0.01       # Resolution of the data (dt)
myDG = DG.DataGenerator(data_initial_conditions, T=data_T, dt=data_dt, derivative_mode="exact")
t_arr, x_train, dx_train, default_guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL, method='DOP853')

print("Guessed highest order polynomial:", default_guessed_multiplicative_order)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train #data will be shuffled in the trainer


print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Guessed highest order polynomial: 2
# Training input shape: (15000, 10)
# Training output shape: (15000, 10)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 32
learning_rate = 0.01

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
dim = training_input.shape[1] # the number of input state variables

# The grid size of each dimension
layer_depth = default_guessed_multiplicative_order + 4
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn) # these numbers exclude the constant term
# Out:
# [10, 10, 10, 10, 10, 10]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn,
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=0.01, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Trainer**

# %%
from sreinet_trainer import *

trainer = SREINetTrainer(model, my_optimizer, loss_fn, data_type='float32')

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.06
N_PERIODS = 50
PRUNING_EPOCHS_PER_PERIOD = 45
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

pruning_scheduler = ps.PruningScheduler(steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                    num_periods=N_PERIODS,
                    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
                    #ramp_type='sigmoid',
                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.05

training_histories = []
weights_list = []
loss_list = []

# %%
for i in range(training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    output = training_output[:, i:i+1]
    
    history = trainer.fit(training_input, output,
     batch_size=MINI_BATCH_SIZE, 
     validation_split=0.20,
     epochs=round(NUM_EPOCHS), 
     pruning_scheduler=pruning_scheduler,
     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
     shuffle_per_epoch=False,
     patience_periods=15,
     verbose=1,
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
    loss_list.append(trainer.get_best_loss())

    #reset the model and trainer
    trainer.reset_trainer_and_model_weights(i)
# Out:
# Training dimension 1...
# Epoch   1 (Period 1):  Train Loss: 9.623e+01,  Validation Loss: 1.837e+01,  Epoch Time: 1.10s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 9.663e+00,  Validation Loss: 7.812e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 6.768e+00,  Validation Loss: 5.515e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 3.648e+00,  Validation Loss: 3.704e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 3.873e+00,  Validation Loss: 3.483e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 3.511e+00,  Validation Loss: 4.812e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 1.530e+05,  Validation Loss: 1.482e+04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 2.447e+03,  Validation Loss: 9.496e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   9 (Period 1):  Train Loss: 6.899e+02,  Validation Loss: 5.437e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  10 (Period 1):  Train Loss: 4.456e+02,  Validation Loss: 3.866e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 3.255e+02,  Validation Loss: 2.801e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00014446
# Epoch  12 (Period 1):  Train Loss: 2.593e+02,  Validation Loss: 2.261e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00057644
# Epoch  13 (Period 1):  Train Loss: 2.180e+02,  Validation Loss: 1.974e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0012918
# Epoch  14 (Period 1):  Train Loss: 1.824e+02,  Validation Loss: 1.744e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0022836
# Epoch  15 (Period 1):  Train Loss: 1.562e+02,  Validation Loss: 1.497e+02,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.0035424
# Epoch  16 (Period 1):  Train Loss: 1.397e+02,  Validation Loss: 1.255e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0050559
# Epoch  17 (Period 1):  Train Loss: 1.268e+02,  Validation Loss: 1.215e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0068097
# Epoch  18 (Period 1):  Train Loss: 1.162e+02,  Validation Loss: 1.053e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0087868
# Epoch  19 (Period 1):  Train Loss: 1.047e+02,  Validation Loss: 1.010e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.010968
# Epoch  20 (Period 1):  Train Loss: 9.614e+01,  Validation Loss: 9.130e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.013333
# Epoch  21 (Period 1):  Train Loss: 8.960e+01,  Validation Loss: 8.776e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.015858
# Epoch  22 (Period 1):  Train Loss: 8.362e+01,  Validation Loss: 7.619e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.018519
# Epoch  23 (Period 1):  Train Loss: 7.880e+01,  Validation Loss: 7.283e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.021291
# Epoch  24 (Period 1):  Train Loss: 7.071e+01,  Validation Loss: 6.283e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.024147
# Epoch  25 (Period 1):  Train Loss: 6.658e+01,  Validation Loss: 5.993e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.027059
# Epoch  26 (Period 1):  Train Loss: 6.449e+01,  Validation Loss: 5.382e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.03
# Epoch  27 (Period 1):  Train Loss: 5.740e+01,  Validation Loss: 5.441e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.032941
# Epoch  28 (Period 1):  Train Loss: 5.425e+01,  Validation Loss: 5.087e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.035853
# Epoch  29 (Period 1):  Train Loss: 5.372e+01,  Validation Loss: 4.808e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.038709
# Epoch  30 (Period 1):  Train Loss: 4.956e+01,  Validation Loss: 4.333e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.041481
# Epoch  31 (Period 1):  Train Loss: 4.709e+01,  Validation Loss: 4.564e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.044142
# Epoch  32 (Period 1):  Train Loss: 4.234e+01,  Validation Loss: 4.025e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.046667
# Epoch  33 (Period 1):  Train Loss: 3.879e+01,  Validation Loss: 3.337e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.049032
# Epoch  34 (Period 1):  Train Loss: 3.730e+01,  Validation Loss: 3.318e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.051213
# Epoch  35 (Period 1):  Train Loss: 3.567e+01,  Validation Loss: 3.518e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.05319
# Epoch  36 (Period 1):  Train Loss: 3.396e+01,  Validation Loss: 3.111e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.054944
# Epoch  37 (Period 1):  Train Loss: 3.419e+01,  Validation Loss: 2.941e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.056458
# Epoch  38 (Period 1):  Train Loss: 2.950e+01,  Validation Loss: 2.697e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.057716
# Epoch  39 (Period 1):  Train Loss: 2.546e+01,  Validation Loss: 2.167e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.058708
# Epoch  40 (Period 1):  Train Loss: 2.227e+01,  Validation Loss: 2.017e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.059424
# Epoch  41 (Period 1):  Train Loss: 1.989e+01,  Validation Loss: 1.997e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.059856
# Epoch  42 (Period 1):  Train Loss: 1.946e+01,  Validation Loss: 1.901e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch  43 (Period 1):  Train Loss: 1.946e+01,  Validation Loss: 1.833e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch  44 (Period 1):  Train Loss: 1.950e+01,  Validation Loss: 1.888e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch  45 (Period 1):  Train Loss: 1.997e+01,  Validation Loss: 1.944e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch  46 (Period 2):  Train Loss: 4.094e+05,  Validation Loss: 5.321e+03,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  47 (Period 2):  Train Loss: 3.378e+03,  Validation Loss: 2.168e+03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  48 (Period 2):  Train Loss: 1.687e+03,  Validation Loss: 1.344e+03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  49 (Period 2):  Train Loss: 1.121e+03,  Validation Loss: 9.188e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  50 (Period 2):  Train Loss: 7.801e+02,  Validation Loss: 6.489e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  51 (Period 2):  Train Loss: 5.978e+02,  Validation Loss: 4.958e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  52 (Period 2):  Train Loss: 4.696e+02,  Validation Loss: 4.192e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  53 (Period 2):  Train Loss: 3.767e+02,  Validation Loss: 3.395e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  54 (Period 2):  Train Loss: 3.123e+02,  Validation Loss: 2.925e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  55 (Period 2):  Train Loss: 2.666e+02,  Validation Loss: 2.269e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  56 (Period 2):  Train Loss: 2.288e+02,  Validation Loss: 2.092e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00014446
# Epoch  57 (Period 2):  Train Loss: 1.982e+02,  Validation Loss: 1.884e+02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00057644
# Epoch  58 (Period 2):  Train Loss: 1.758e+02,  Validation Loss: 1.638e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0012918
# Epoch  59 (Period 2):  Train Loss: 1.545e+02,  Validation Loss: 1.387e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0022836
# Epoch  60 (Period 2):  Train Loss: 1.386e+02,  Validation Loss: 1.338e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0035424
# Epoch  61 (Period 2):  Train Loss: 1.239e+02,  Validation Loss: 1.224e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.0050559
# Epoch  62 (Period 2):  Train Loss: 1.108e+02,  Validation Loss: 1.128e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0068097
# Epoch  63 (Period 2):  Train Loss: 1.034e+02,  Validation Loss: 9.615e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0087868
# Epoch  64 (Period 2):  Train Loss: 9.289e+01,  Validation Loss: 8.794e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.010968
# Epoch  65 (Period 2):  Train Loss: 8.514e+01,  Validation Loss: 8.732e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.013333
# Epoch  66 (Period 2):  Train Loss: 8.146e+01,  Validation Loss: 7.024e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.015858
# Epoch  67 (Period 2):  Train Loss: 7.626e+01,  Validation Loss: 7.165e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.018519
# Epoch  68 (Period 2):  Train Loss: 7.054e+01,  Validation Loss: 6.153e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.021291
# Epoch  69 (Period 2):  Train Loss: 6.681e+01,  Validation Loss: 5.828e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.024147
# Epoch  70 (Period 2):  Train Loss: 6.439e+01,  Validation Loss: 5.368e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.027059
# Epoch  71 (Period 2):  Train Loss: 5.341e+01,  Validation Loss: 4.653e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.03
# Epoch  72 (Period 2):  Train Loss: 5.158e+01,  Validation Loss: 4.367e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.032941
# Epoch  73 (Period 2):  Train Loss: 4.679e+01,  Validation Loss: 4.080e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.035853
# Epoch  74 (Period 2):  Train Loss: 4.405e+01,  Validation Loss: 3.849e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.038709
# Epoch  75 (Period 2):  Train Loss: 3.782e+01,  Validation Loss: 3.386e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.041481
# Epoch  76 (Period 2):  Train Loss: 3.212e+01,  Validation Loss: 2.859e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.044142
# Epoch  77 (Period 2):  Train Loss: 3.335e+01,  Validation Loss: 2.984e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.046667
# Epoch  78 (Period 2):  Train Loss: 2.793e+01,  Validation Loss: 2.839e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.049032
# Epoch  79 (Period 2):  Train Loss: 2.789e+01,  Validation Loss: 2.593e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.051213
# Epoch  80 (Period 2):  Train Loss: 2.872e+01,  Validation Loss: 2.767e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.05319
# Epoch  81 (Period 2):  Train Loss: 2.474e+01,  Validation Loss: 2.341e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.054944
# Epoch  82 (Period 2):  Train Loss: 2.413e+01,  Validation Loss: 2.163e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.056458
# Epoch  83 (Period 2):  Train Loss: 2.313e+01,  Validation Loss: 2.358e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.057716
# Epoch  84 (Period 2):  Train Loss: 2.213e+01,  Validation Loss: 2.109e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.058708
# Epoch  85 (Period 2):  Train Loss: 2.257e+01,  Validation Loss: 2.295e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.059424
# Epoch  86 (Period 2):  Train Loss: 2.335e+01,  Validation Loss: 2.362e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.059856
# Epoch  87 (Period 2):  Train Loss: 2.351e+01,  Validation Loss: 2.199e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch  88 (Period 2):  Train Loss: 2.274e+01,  Validation Loss: 2.173e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch  89 (Period 2):  Train Loss: 2.390e+01,  Validation Loss: 2.309e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch  90 (Period 2):  Train Loss: 2.269e+01,  Validation Loss: 2.151e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch  91 (Period 3):  Train Loss: 6.348e+04,  Validation Loss: 6.203e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  92 (Period 3):  Train Loss: 4.330e+02,  Validation Loss: 3.276e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  93 (Period 3):  Train Loss: 2.692e+02,  Validation Loss: 2.227e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  94 (Period 3):  Train Loss: 2.007e+02,  Validation Loss: 1.704e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  95 (Period 3):  Train Loss: 1.564e+02,  Validation Loss: 1.530e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  96 (Period 3):  Train Loss: 1.308e+02,  Validation Loss: 1.161e+02,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch  97 (Period 3):  Train Loss: 1.111e+02,  Validation Loss: 1.003e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  98 (Period 3):  Train Loss: 9.368e+01,  Validation Loss: 8.721e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  99 (Period 3):  Train Loss: 7.973e+01,  Validation Loss: 7.353e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch 100 (Period 3):  Train Loss: 6.806e+01,  Validation Loss: 6.485e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 101 (Period 3):  Train Loss: 5.895e+01,  Validation Loss: 5.494e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00014446
# Epoch 102 (Period 3):  Train Loss: 5.146e+01,  Validation Loss: 5.094e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00057644
# Epoch 103 (Period 3):  Train Loss: 4.578e+01,  Validation Loss: 4.425e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0012918
# Epoch 104 (Period 3):  Train Loss: 4.066e+01,  Validation Loss: 3.933e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0022836
# Epoch 105 (Period 3):  Train Loss: 3.656e+01,  Validation Loss: 3.342e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0035424
# Epoch 106 (Period 3):  Train Loss: 3.384e+01,  Validation Loss: 3.364e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0050559
# Epoch 107 (Period 3):  Train Loss: 3.094e+01,  Validation Loss: 2.969e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0068097
# Epoch 108 (Period 3):  Train Loss: 2.827e+01,  Validation Loss: 2.845e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0087868
# Epoch 109 (Period 3):  Train Loss: 2.607e+01,  Validation Loss: 2.901e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.010968
# Epoch 110 (Period 3):  Train Loss: 2.656e+01,  Validation Loss: 2.257e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.013333
# Epoch 111 (Period 3):  Train Loss: 2.532e+01,  Validation Loss: 2.241e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.015858
# Epoch 112 (Period 3):  Train Loss: 2.368e+01,  Validation Loss: 2.191e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.018519
# Epoch 113 (Period 3):  Train Loss: 2.433e+01,  Validation Loss: 1.996e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.021291
# Epoch 114 (Period 3):  Train Loss: 2.269e+01,  Validation Loss: 2.019e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.024147
# Epoch 115 (Period 3):  Train Loss: 2.403e+01,  Validation Loss: 2.036e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.027059
# Epoch 116 (Period 3):  Train Loss: 2.234e+01,  Validation Loss: 2.244e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.03
# Epoch 117 (Period 3):  Train Loss: 2.173e+01,  Validation Loss: 2.403e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.032941
# Epoch 118 (Period 3):  Train Loss: 3.002e+01,  Validation Loss: 2.869e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.035853
# Epoch 119 (Period 3):  Train Loss: 2.093e+01,  Validation Loss: 1.606e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.038709
# Epoch 120 (Period 3):  Train Loss: 1.593e+01,  Validation Loss: 1.566e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.041481
# Epoch 121 (Period 3):  Train Loss: 1.353e+01,  Validation Loss: 1.144e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.044142
# Epoch 122 (Period 3):  Train Loss: 1.068e+01,  Validation Loss: 6.421e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.046667
# Epoch 123 (Period 3):  Train Loss: 5.389e+00,  Validation Loss: 3.713e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.049032
# Epoch 124 (Period 3):  Train Loss: 4.307e+00,  Validation Loss: 2.849e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.051213
# Epoch 125 (Period 3):  Train Loss: 4.070e+00,  Validation Loss: 3.337e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.05319
# Epoch 126 (Period 3):  Train Loss: 2.886e+00,  Validation Loss: 2.651e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.054944
# Epoch 127 (Period 3):  Train Loss: 2.842e+00,  Validation Loss: 2.548e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.056458
# Epoch 128 (Period 3):  Train Loss: 3.827e+00,  Validation Loss: 3.747e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.057716
# Epoch 129 (Period 3):  Train Loss: 3.983e+00,  Validation Loss: 3.944e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.058708
# Epoch 130 (Period 3):  Train Loss: 4.002e+00,  Validation Loss: 3.863e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.059424
# Epoch 131 (Period 3):  Train Loss: 3.992e+00,  Validation Loss: 3.788e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.059856
# Epoch 132 (Period 3):  Train Loss: 4.144e+00,  Validation Loss: 3.821e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 133 (Period 3):  Train Loss: 4.168e+00,  Validation Loss: 4.050e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 134 (Period 3):  Train Loss: 4.138e+00,  Validation Loss: 3.931e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 135 (Period 3):  Train Loss: 4.122e+00,  Validation Loss: 3.848e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 136 (Period 4):  Train Loss: 4.609e+04,  Validation Loss: 4.183e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 137 (Period 4):  Train Loss: 2.983e+02,  Validation Loss: 2.298e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 138 (Period 4):  Train Loss: 1.945e+02,  Validation Loss: 1.664e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 139 (Period 4):  Train Loss: 1.447e+02,  Validation Loss: 1.363e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 140 (Period 4):  Train Loss: 1.189e+02,  Validation Loss: 1.073e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch 141 (Period 4):  Train Loss: 9.939e+01,  Validation Loss: 8.527e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 142 (Period 4):  Train Loss: 8.113e+01,  Validation Loss: 7.708e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 143 (Period 4):  Train Loss: 6.700e+01,  Validation Loss: 6.296e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 144 (Period 4):  Train Loss: 5.818e+01,  Validation Loss: 5.492e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 145 (Period 4):  Train Loss: 4.958e+01,  Validation Loss: 4.603e+01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch 146 (Period 4):  Train Loss: 4.297e+01,  Validation Loss: 3.886e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.00014446
# Epoch 147 (Period 4):  Train Loss: 3.697e+01,  Validation Loss: 3.419e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00057644
# Epoch 148 (Period 4):  Train Loss: 3.226e+01,  Validation Loss: 2.881e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0012918
# Epoch 149 (Period 4):  Train Loss: 2.791e+01,  Validation Loss: 2.647e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0022836
# Epoch 150 (Period 4):  Train Loss: 2.447e+01,  Validation Loss: 2.432e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.0035424
# Epoch 151 (Period 4):  Train Loss: 2.169e+01,  Validation Loss: 2.088e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0050559
# Epoch 152 (Period 4):  Train Loss: 1.933e+01,  Validation Loss: 1.826e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0068097
# Epoch 153 (Period 4):  Train Loss: 1.681e+01,  Validation Loss: 1.895e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0087868
# Epoch 154 (Period 4):  Train Loss: 1.531e+01,  Validation Loss: 1.340e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.010968
# Epoch 155 (Period 4):  Train Loss: 1.313e+01,  Validation Loss: 1.174e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.013333
# Epoch 156 (Period 4):  Train Loss: 1.311e+01,  Validation Loss: 1.012e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.015858
# Epoch 157 (Period 4):  Train Loss: 1.137e+01,  Validation Loss: 9.978e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.018519
# Epoch 158 (Period 4):  Train Loss: 1.024e+01,  Validation Loss: 8.575e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.021291
# Epoch 159 (Period 4):  Train Loss: 8.210e+00,  Validation Loss: 7.227e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.024147
# Epoch 160 (Period 4):  Train Loss: 8.182e+00,  Validation Loss: 6.709e+00,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.027059
# Epoch 161 (Period 4):  Train Loss: 9.013e+00,  Validation Loss: 7.253e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.03
# Epoch 162 (Period 4):  Train Loss: 6.914e+00,  Validation Loss: 5.855e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.032941
# Epoch 163 (Period 4):  Train Loss: 5.712e+00,  Validation Loss: 4.969e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.035853
# Epoch 164 (Period 4):  Train Loss: 5.822e+00,  Validation Loss: 5.042e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.038709
# Epoch 165 (Period 4):  Train Loss: 5.806e+00,  Validation Loss: 4.485e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.041481
# Epoch 166 (Period 4):  Train Loss: 4.841e+00,  Validation Loss: 4.363e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.044142
# Epoch 167 (Period 4):  Train Loss: 3.959e+00,  Validation Loss: 3.220e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.046667
# Epoch 168 (Period 4):  Train Loss: 3.006e+00,  Validation Loss: 2.585e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.049032
# Epoch 169 (Period 4):  Train Loss: 2.504e+00,  Validation Loss: 2.445e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.051213
# Epoch 170 (Period 4):  Train Loss: 2.406e+00,  Validation Loss: 2.236e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.05319
# Epoch 171 (Period 4):  Train Loss: 2.293e+00,  Validation Loss: 2.015e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.054944
# Epoch 172 (Period 4):  Train Loss: 2.347e+00,  Validation Loss: 2.077e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.056458
# Epoch 173 (Period 4):  Train Loss: 2.544e+00,  Validation Loss: 2.269e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.057716
# Epoch 174 (Period 4):  Train Loss: 2.709e+00,  Validation Loss: 2.988e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.058708
# Epoch 175 (Period 4):  Train Loss: 2.722e+00,  Validation Loss: 2.736e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.059424
# Epoch 176 (Period 4):  Train Loss: 2.847e+00,  Validation Loss: 2.791e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.059856
# Epoch 177 (Period 4):  Train Loss: 2.841e+00,  Validation Loss: 2.874e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 178 (Period 4):  Train Loss: 2.899e+00,  Validation Loss: 2.830e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 179 (Period 4):  Train Loss: 2.883e+00,  Validation Loss: 4.363e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 180 (Period 4):  Train Loss: 2.737e+00,  Validation Loss: 2.958e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 181 (Period 5):  Train Loss: 1.850e+05,  Validation Loss: 1.931e+03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 182 (Period 5):  Train Loss: 1.264e+03,  Validation Loss: 8.253e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 183 (Period 5):  Train Loss: 6.705e+02,  Validation Loss: 5.387e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 184 (Period 5):  Train Loss: 4.554e+02,  Validation Loss: 3.856e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 185 (Period 5):  Train Loss: 3.481e+02,  Validation Loss: 3.077e+02,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch 186 (Period 5):  Train Loss: 2.740e+02,  Validation Loss: 2.486e+02,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch 187 (Period 5):  Train Loss: 2.302e+02,  Validation Loss: 1.994e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 188 (Period 5):  Train Loss: 1.906e+02,  Validation Loss: 1.749e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch 189 (Period 5):  Train Loss: 1.665e+02,  Validation Loss: 1.494e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 190 (Period 5):  Train Loss: 1.433e+02,  Validation Loss: 1.281e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 191 (Period 5):  Train Loss: 1.272e+02,  Validation Loss: 1.153e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00014446
# Epoch 192 (Period 5):  Train Loss: 1.115e+02,  Validation Loss: 1.028e+02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00057644
# Epoch 193 (Period 5):  Train Loss: 9.897e+01,  Validation Loss: 8.851e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0012918
# Epoch 194 (Period 5):  Train Loss: 8.729e+01,  Validation Loss: 8.072e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0022836
# Epoch 195 (Period 5):  Train Loss: 7.896e+01,  Validation Loss: 7.125e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0035424
# Epoch 196 (Period 5):  Train Loss: 6.870e+01,  Validation Loss: 6.503e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0050559
# Epoch 197 (Period 5):  Train Loss: 6.243e+01,  Validation Loss: 5.936e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0068097
# Epoch 198 (Period 5):  Train Loss: 5.601e+01,  Validation Loss: 5.196e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.0087868
# Epoch 199 (Period 5):  Train Loss: 4.945e+01,  Validation Loss: 4.838e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.010968
# Epoch 200 (Period 5):  Train Loss: 4.429e+01,  Validation Loss: 4.102e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.013333
# Epoch 201 (Period 5):  Train Loss: 4.131e+01,  Validation Loss: 3.704e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.015858
# Epoch 202 (Period 5):  Train Loss: 3.669e+01,  Validation Loss: 3.355e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.018519
# Epoch 203 (Period 5):  Train Loss: 3.257e+01,  Validation Loss: 2.998e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.021291
# Epoch 204 (Period 5):  Train Loss: 3.037e+01,  Validation Loss: 2.913e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.024147
# Epoch 205 (Period 5):  Train Loss: 2.730e+01,  Validation Loss: 2.562e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.027059
# Epoch 206 (Period 5):  Train Loss: 2.654e+01,  Validation Loss: 2.495e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.03
# Epoch 207 (Period 5):  Train Loss: 2.551e+01,  Validation Loss: 2.373e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.032941
# Epoch 208 (Period 5):  Train Loss: 2.543e+01,  Validation Loss: 2.174e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.035853
# Epoch 209 (Period 5):  Train Loss: 2.474e+01,  Validation Loss: 2.143e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.038709
# Epoch 210 (Period 5):  Train Loss: 2.340e+01,  Validation Loss: 2.110e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.041481
# Epoch 211 (Period 5):  Train Loss: 2.209e+01,  Validation Loss: 1.886e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.044142
# Epoch 212 (Period 5):  Train Loss: 2.102e+01,  Validation Loss: 1.894e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.046667
# Epoch 213 (Period 5):  Train Loss: 1.855e+01,  Validation Loss: 1.564e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.049032
# Epoch 214 (Period 5):  Train Loss: 1.712e+01,  Validation Loss: 1.446e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.051213
# Epoch 215 (Period 5):  Train Loss: 1.265e+01,  Validation Loss: 9.206e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.05319
# Epoch 216 (Period 5):  Train Loss: 8.017e+00,  Validation Loss: 6.450e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.054944
# Epoch 217 (Period 5):  Train Loss: 5.689e+00,  Validation Loss: 2.852e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.056458
# Epoch 218 (Period 5):  Train Loss: 1.714e+00,  Validation Loss: 5.178e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.057716
# Epoch 219 (Period 5):  Train Loss: 2.880e-01,  Validation Loss: 1.692e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.058708
# Epoch 220 (Period 5):  Train Loss: 7.944e-02,  Validation Loss: 5.040e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.059424
# Epoch 221 (Period 5):  Train Loss: 3.071e-02,  Validation Loss: 2.378e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.059856
# Epoch 222 (Period 5):  Train Loss: 2.017e-02,  Validation Loss: 1.501e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.06
# Epoch 223 (Period 5):  Train Loss: 1.019e-02,  Validation Loss: 9.813e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 224 (Period 5):  Train Loss: 7.780e-03,  Validation Loss: 5.508e-03,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.06
# Epoch 225 (Period 5):  Train Loss: 3.981e-03,  Validation Loss: 3.098e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch 226 (Period 6):  Train Loss: 5.113e+04,  Validation Loss: 6.066e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 227 (Period 6):  Train Loss: 4.094e+02,  Validation Loss: 2.872e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 228 (Period 6):  Train Loss: 2.483e+02,  Validation Loss: 2.160e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 229 (Period 6):  Train Loss: 1.804e+02,  Validation Loss: 1.581e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 230 (Period 6):  Train Loss: 1.393e+02,  Validation Loss: 1.176e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 231 (Period 6):  Train Loss: 1.127e+02,  Validation Loss: 9.862e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 232 (Period 6):  Train Loss: 9.413e+01,  Validation Loss: 8.729e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch 233 (Period 6):  Train Loss: 8.019e+01,  Validation Loss: 7.260e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch 234 (Period 6):  Train Loss: 7.082e+01,  Validation Loss: 6.637e+01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0
# Epoch 235 (Period 6):  Train Loss: 6.327e+01,  Validation Loss: 5.529e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch 236 (Period 6):  Train Loss: 5.614e+01,  Validation Loss: 5.343e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.00014446
# Epoch 237 (Period 6):  Train Loss: 5.049e+01,  Validation Loss: 4.636e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.00057644
# Epoch 238 (Period 6):  Train Loss: 4.600e+01,  Validation Loss: 4.238e+01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.0012918
# Epoch 239 (Period 6):  Train Loss: 4.114e+01,  Validation Loss: 3.930e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.0022836
# Epoch 240 (Period 6):  Train Loss: 3.698e+01,  Validation Loss: 3.386e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.0035424
# Epoch 241 (Period 6):  Train Loss: 3.332e+01,  Validation Loss: 3.175e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.0050559
# Epoch 242 (Period 6):  Train Loss: 3.000e+01,  Validation Loss: 2.774e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.0068097
# Epoch 243 (Period 6):  Train Loss: 2.688e+01,  Validation Loss: 2.371e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.0087868
# Epoch 244 (Period 6):  Train Loss: 2.388e+01,  Validation Loss: 2.227e+01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.010968
# Epoch 245 (Period 6):  Train Loss: 2.086e+01,  Validation Loss: 2.018e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.013333
# Epoch 246 (Period 6):  Train Loss: 1.968e+01,  Validation Loss: 1.714e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.015858
# Epoch 247 (Period 6):  Train Loss: 1.788e+01,  Validation Loss: 1.634e+01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.018519
# Epoch 248 (Period 6):  Train Loss: 1.664e+01,  Validation Loss: 1.638e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.021291
# Epoch 249 (Period 6):  Train Loss: 1.626e+01,  Validation Loss: 1.301e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.024147
# Epoch 250 (Period 6):  Train Loss: 1.381e+01,  Validation Loss: 1.205e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.027059
# Epoch 251 (Period 6):  Train Loss: 1.170e+01,  Validation Loss: 9.436e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.03
# Epoch 252 (Period 6):  Train Loss: 8.701e+00,  Validation Loss: 6.502e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.032941
# Epoch 253 (Period 6):  Train Loss: 6.078e+00,  Validation Loss: 4.177e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.035853
# Epoch 254 (Period 6):  Train Loss: 3.804e+00,  Validation Loss: 2.106e+00,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.038709
# Epoch 255 (Period 6):  Train Loss: 1.585e+00,  Validation Loss: 8.189e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.041481
# Epoch 256 (Period 6):  Train Loss: 6.786e-01,  Validation Loss: 4.364e-01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.044142
# Epoch 257 (Period 6):  Train Loss: 4.730e-01,  Validation Loss: 1.587e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.046667
# Epoch 258 (Period 6):  Train Loss: 1.316e-01,  Validation Loss: 5.486e-02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.049032
# Epoch 259 (Period 6):  Train Loss: 4.117e-02,  Validation Loss: 2.956e-02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.051213
# Epoch 260 (Period 6):  Train Loss: 7.341e-03,  Validation Loss: 6.120e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.05319
# Epoch 261 (Period 6):  Train Loss: 3.660e-03,  Validation Loss: 2.112e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.054944
# Epoch 262 (Period 6):  Train Loss: 1.968e-03,  Validation Loss: 1.247e-03,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.056458
# Epoch 263 (Period 6):  Train Loss: 1.681e-05,  Validation Loss: 5.428e-08,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.057716
# Epoch 264 (Period 6):  Train Loss: 1.956e-09,  Validation Loss: 3.463e-12,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.058708
# Epoch 265 (Period 6):  Train Loss: 4.413e-12,  Validation Loss: 3.075e-12,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.059424
# Early stopping at epoch 265 as train loss 0.00000000000441 is below the threshold 0.00000000010000
# Training Stopped. Time elapsed: 91.86s
# Final model saved as best with loss: 3.074501e-12
# Training dimension 2...
# Epoch   1 (Period 1):  Train Loss: 5.044e+04,  Validation Loss: 1.288e+03,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 5.875e+02,  Validation Loss: 3.598e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 2.894e+02,  Validation Loss: 2.255e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 2.029e+02,  Validation Loss: 1.801e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 1.568e+02,  Validation Loss: 1.394e+02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 1.265e+02,  Validation Loss: 1.137e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 1.069e+02,  Validation Loss: 9.991e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 9.207e+01,  Validation Loss: 8.795e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   9 (Period 1):  Train Loss: 7.984e+01,  Validation Loss: 7.094e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  10 (Period 1):  Train Loss: 7.009e+01,  Validation Loss: 6.419e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 6.208e+01,  Validation Loss: 5.584e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.00014446
# Epoch  12 (Period 1):  Train Loss: 5.457e+01,  Validation Loss: 4.833e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00057644
# Epoch  13 (Period 1):  Train Loss: 4.630e+01,  Validation Loss: 4.183e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0012918
# Epoch  14 (Period 1):  Train Loss: 4.049e+01,  Validation Loss: 3.796e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0022836
# Epoch  15 (Period 1):  Train Loss: 3.545e+01,  Validation Loss: 3.365e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0035424
# Epoch  16 (Period 1):  Train Loss: 3.243e+01,  Validation Loss: 2.983e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0050559
# Epoch  17 (Period 1):  Train Loss: 2.915e+01,  Validation Loss: 2.765e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0068097
# Epoch  18 (Period 1):  Train Loss: 2.639e+01,  Validation Loss: 2.419e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.0087868
# Epoch  19 (Period 1):  Train Loss: 2.437e+01,  Validation Loss: 2.488e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.010968
# Epoch  20 (Period 1):  Train Loss: 2.319e+01,  Validation Loss: 2.281e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.013333
# Epoch  21 (Period 1):  Train Loss: 2.284e+01,  Validation Loss: 2.048e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.015858
# Epoch  22 (Period 1):  Train Loss: 1.993e+01,  Validation Loss: 1.919e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.018519
# Epoch  23 (Period 1):  Train Loss: 1.825e+01,  Validation Loss: 1.711e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.021291
# Epoch  24 (Period 1):  Train Loss: 1.870e+01,  Validation Loss: 1.511e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.024147
# Epoch  25 (Period 1):  Train Loss: 1.663e+01,  Validation Loss: 1.358e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.027059
# Epoch  26 (Period 1):  Train Loss: 1.452e+01,  Validation Loss: 1.552e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.03
# Epoch  27 (Period 1):  Train Loss: 1.269e+01,  Validation Loss: 8.755e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.032941
# Epoch  28 (Period 1):  Train Loss: 1.057e+01,  Validation Loss: 7.111e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.035853
# Epoch  29 (Period 1):  Train Loss: 7.589e+00,  Validation Loss: 5.232e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.038709
# Epoch  30 (Period 1):  Train Loss: 4.897e+00,  Validation Loss: 3.775e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.041481
# Epoch  31 (Period 1):  Train Loss: 4.168e+00,  Validation Loss: 3.340e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.044142
# Epoch  32 (Period 1):  Train Loss: 3.706e+00,  Validation Loss: 3.363e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.046667
# Epoch  33 (Period 1):  Train Loss: 3.380e+00,  Validation Loss: 3.120e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.049032
# Epoch  34 (Period 1):  Train Loss: 3.040e+00,  Validation Loss: 3.006e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.051213
# Epoch  35 (Period 1):  Train Loss: 3.242e+00,  Validation Loss: 2.772e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.05319
# Epoch  36 (Period 1):  Train Loss: 3.205e+00,  Validation Loss: 2.823e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.054944
# Epoch  37 (Period 1):  Train Loss: 2.942e+00,  Validation Loss: 2.865e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.056458
# Epoch  38 (Period 1):  Train Loss: 3.089e+00,  Validation Loss: 3.125e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.057716
# Epoch  39 (Period 1):  Train Loss: 2.996e+00,  Validation Loss: 2.885e+00,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.058708
# Epoch  40 (Period 1):  Train Loss: 3.131e+00,  Validation Loss: 2.996e+00,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.059424
# Epoch  41 (Period 1):  Train Loss: 3.258e+00,  Validation Loss: 3.595e+00,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.059856
# Epoch  42 (Period 1):  Train Loss: 3.130e+00,  Validation Loss: 2.976e+00,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.06
# Epoch  43 (Period 1):  Train Loss: 3.193e+00,  Validation Loss: 2.870e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.06
# Epoch  44 (Period 1):  Train Loss: 3.647e+00,  Validation Loss: 3.270e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.06
# Epoch  45 (Period 1):  Train Loss: 3.447e+00,  Validation Loss: 3.331e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.06
# Epoch  46 (Period 2):  Train Loss: 3.772e+04,  Validation Loss: 4.624e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  47 (Period 2):  Train Loss: 3.277e+02,  Validation Loss: 2.604e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  48 (Period 2):  Train Loss: 2.077e+02,  Validation Loss: 1.681e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  49 (Period 2):  Train Loss: 1.602e+02,  Validation Loss: 1.366e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  50 (Period 2):  Train Loss: 1.285e+02,  Validation Loss: 1.202e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  51 (Period 2):  Train Loss: 1.097e+02,  Validation Loss: 9.996e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  52 (Period 2):  Train Loss: 9.239e+01,  Validation Loss: 8.554e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  53 (Period 2):  Train Loss: 7.985e+01,  Validation Loss: 7.513e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  54 (Period 2):  Train Loss: 7.015e+01,  Validation Loss: 6.866e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch  55 (Period 2):  Train Loss: 6.316e+01,  Validation Loss: 5.880e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  56 (Period 2):  Train Loss: 5.667e+01,  Validation Loss: 5.226e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00014446
# Epoch  57 (Period 2):  Train Loss: 5.146e+01,  Validation Loss: 4.812e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00057644
# Epoch  58 (Period 2):  Train Loss: 4.889e+01,  Validation Loss: 4.577e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0012918
# Epoch  59 (Period 2):  Train Loss: 4.215e+01,  Validation Loss: 3.782e+01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.0022836
# Epoch  60 (Period 2):  Train Loss: 3.750e+01,  Validation Loss: 3.859e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0035424
# Epoch  61 (Period 2):  Train Loss: 3.241e+01,  Validation Loss: 2.657e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0050559
# Epoch  62 (Period 2):  Train Loss: 2.929e+01,  Validation Loss: 2.364e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0068097
# Epoch  63 (Period 2):  Train Loss: 2.780e+01,  Validation Loss: 2.535e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0087868
# Epoch  64 (Period 2):  Train Loss: 2.452e+01,  Validation Loss: 2.441e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.010968
# Epoch  65 (Period 2):  Train Loss: 2.348e+01,  Validation Loss: 2.542e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.013333
# Epoch  66 (Period 2):  Train Loss: 2.137e+01,  Validation Loss: 1.797e+01,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.015858
# Epoch  67 (Period 2):  Train Loss: 1.731e+01,  Validation Loss: 1.629e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.018519
# Epoch  68 (Period 2):  Train Loss: 1.696e+01,  Validation Loss: 1.245e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.021291
# Epoch  69 (Period 2):  Train Loss: 1.235e+01,  Validation Loss: 9.648e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.024147
# Epoch  70 (Period 2):  Train Loss: 1.179e+01,  Validation Loss: 9.532e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.027059
# Epoch  71 (Period 2):  Train Loss: 1.041e+01,  Validation Loss: 9.610e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.03
# Epoch  72 (Period 2):  Train Loss: 8.330e+00,  Validation Loss: 6.809e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.032941
# Epoch  73 (Period 2):  Train Loss: 8.502e+00,  Validation Loss: 8.382e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.035853
# Epoch  74 (Period 2):  Train Loss: 6.916e+00,  Validation Loss: 5.294e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.038709
# Epoch  75 (Period 2):  Train Loss: 6.660e+00,  Validation Loss: 5.291e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.041481
# Epoch  76 (Period 2):  Train Loss: 5.329e+00,  Validation Loss: 3.728e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.044142
# Epoch  77 (Period 2):  Train Loss: 4.505e+00,  Validation Loss: 3.679e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.046667
# Epoch  78 (Period 2):  Train Loss: 4.521e+00,  Validation Loss: 3.883e+00,  Epoch Time: 0.35s,  Current Pruning Threshold: 0.049032
# Epoch  79 (Period 2):  Train Loss: 3.546e+00,  Validation Loss: 2.658e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.051213
# Epoch  80 (Period 2):  Train Loss: 1.722e+00,  Validation Loss: 8.067e-01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.05319
# Epoch  81 (Period 2):  Train Loss: 4.304e-01,  Validation Loss: 3.017e-02,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.054944
# Epoch  82 (Period 2):  Train Loss: 1.949e-03,  Validation Loss: 2.381e-04,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.056458
# Epoch  83 (Period 2):  Train Loss: 4.400e-06,  Validation Loss: 2.845e-12,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.057716
# Epoch  84 (Period 2):  Train Loss: 3.117e-12,  Validation Loss: 2.971e-12,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.058708
# Early stopping at epoch 84 as train loss 0.00000000000312 is below the threshold 0.00000000010000
# Training Stopped. Time elapsed: 29.03s
# Final model saved as best with loss: 2.971464e-12
# Training dimension 3...
# Epoch   1 (Period 1):  Train Loss: 6.002e+04,  Validation Loss: 1.092e+03,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 6.056e+02,  Validation Loss: 3.929e+02,  Epoch Time: 0.35s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 3.247e+02,  Validation Loss: 2.673e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 2.448e+02,  Validation Loss: 2.184e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 1.922e+02,  Validation Loss: 1.744e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 1.593e+02,  Validation Loss: 1.433e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 1.353e+02,  Validation Loss: 1.149e+02,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 1.111e+02,  Validation Loss: 9.875e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch   9 (Period 1):  Train Loss: 9.258e+01,  Validation Loss: 8.574e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  10 (Period 1):  Train Loss: 7.701e+01,  Validation Loss: 7.066e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 6.804e+01,  Validation Loss: 6.399e+01,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.00014446
# Epoch  12 (Period 1):  Train Loss: 6.063e+01,  Validation Loss: 6.028e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.00057644
# Epoch  13 (Period 1):  Train Loss: 5.468e+01,  Validation Loss: 4.945e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0012918
# Epoch  14 (Period 1):  Train Loss: 4.976e+01,  Validation Loss: 4.506e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0022836
# Epoch  15 (Period 1):  Train Loss: 4.509e+01,  Validation Loss: 4.208e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0035424
# Epoch  16 (Period 1):  Train Loss: 4.212e+01,  Validation Loss: 3.924e+01,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.0050559
# ...
# Epoch 144 (Period 4):  Train Loss: 1.258e+02,  Validation Loss: 1.123e+02,  Epoch Time: 0.43s,  Current Pruning Threshold: 0
# Epoch 145 (Period 4):  Train Loss: 1.027e+02,  Validation Loss: 9.379e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0
# Epoch 146 (Period 4):  Train Loss: 8.683e+01,  Validation Loss: 7.808e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.00014446
# Epoch 147 (Period 4):  Train Loss: 7.481e+01,  Validation Loss: 6.982e+01,  Epoch Time: 0.84s,  Current Pruning Threshold: 0.00057644
# Epoch 148 (Period 4):  Train Loss: 6.500e+01,  Validation Loss: 6.121e+01,  Epoch Time: 0.64s,  Current Pruning Threshold: 0.0012918
# Epoch 149 (Period 4):  Train Loss: 5.670e+01,  Validation Loss: 5.214e+01,  Epoch Time: 0.62s,  Current Pruning Threshold: 0.0022836
# Epoch 150 (Period 4):  Train Loss: 5.056e+01,  Validation Loss: 4.857e+01,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.0035424
# Epoch 151 (Period 4):  Train Loss: 4.491e+01,  Validation Loss: 4.260e+01,  Epoch Time: 0.51s,  Current Pruning Threshold: 0.0050559
# Epoch 152 (Period 4):  Train Loss: 4.013e+01,  Validation Loss: 3.820e+01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.0068097
# Epoch 153 (Period 4):  Train Loss: 3.670e+01,  Validation Loss: 3.565e+01,  Epoch Time: 0.48s,  Current Pruning Threshold: 0.0087868
# Epoch 154 (Period 4):  Train Loss: 3.370e+01,  Validation Loss: 3.159e+01,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.010968
# Epoch 155 (Period 4):  Train Loss: 3.205e+01,  Validation Loss: 3.020e+01,  Epoch Time: 0.55s,  Current Pruning Threshold: 0.013333
# Epoch 156 (Period 4):  Train Loss: 2.858e+01,  Validation Loss: 2.540e+01,  Epoch Time: 0.50s,  Current Pruning Threshold: 0.015858
# Epoch 157 (Period 4):  Train Loss: 2.664e+01,  Validation Loss: 2.718e+01,  Epoch Time: 0.49s,  Current Pruning Threshold: 0.018519
# Epoch 158 (Period 4):  Train Loss: 2.565e+01,  Validation Loss: 2.151e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.021291
# Epoch 159 (Period 4):  Train Loss: 2.269e+01,  Validation Loss: 2.145e+01,  Epoch Time: 0.48s,  Current Pruning Threshold: 0.024147
# Epoch 160 (Period 4):  Train Loss: 2.377e+01,  Validation Loss: 1.973e+01,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.027059
# Epoch 161 (Period 4):  Train Loss: 1.817e+01,  Validation Loss: 1.471e+01,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.03
# Epoch 162 (Period 4):  Train Loss: 1.468e+01,  Validation Loss: 1.164e+01,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.032941
# Epoch 163 (Period 4):  Train Loss: 1.313e+01,  Validation Loss: 9.766e+00,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.035853
# Epoch 164 (Period 4):  Train Loss: 1.078e+01,  Validation Loss: 8.459e+00,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.038709
# Epoch 165 (Period 4):  Train Loss: 9.525e+00,  Validation Loss: 7.683e+00,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.041481
# Epoch 166 (Period 4):  Train Loss: 9.045e+00,  Validation Loss: 7.639e+00,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.044142
# Epoch 167 (Period 4):  Train Loss: 7.327e+00,  Validation Loss: 6.693e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.046667
# Epoch 168 (Period 4):  Train Loss: 7.294e+00,  Validation Loss: 6.323e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.049032
# Epoch 169 (Period 4):  Train Loss: 6.427e+00,  Validation Loss: 5.716e+00,  Epoch Time: 0.55s,  Current Pruning Threshold: 0.051213
# Epoch 170 (Period 4):  Train Loss: 5.768e+00,  Validation Loss: 4.893e+00,  Epoch Time: 0.44s,  Current Pruning Threshold: 0.05319
# Epoch 171 (Period 4):  Train Loss: 6.221e+00,  Validation Loss: 5.158e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.054944
# Epoch 172 (Period 4):  Train Loss: 6.555e+00,  Validation Loss: 6.139e+00,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.056458
# Epoch 173 (Period 4):  Train Loss: 7.923e+00,  Validation Loss: 7.350e+00,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.057716
# Epoch 174 (Period 4):  Train Loss: 7.379e+00,  Validation Loss: 6.466e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.058708
# Epoch 175 (Period 4):  Train Loss: 5.412e+00,  Validation Loss: 2.045e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.059424
# Epoch 176 (Period 4):  Train Loss: 6.743e-01,  Validation Loss: 1.594e-01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.059856
# Epoch 177 (Period 4):  Train Loss: 7.114e-02,  Validation Loss: 7.821e-03,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.06
# Epoch 178 (Period 4):  Train Loss: 3.237e-03,  Validation Loss: 2.201e-03,  Epoch Time: 0.47s,  Current Pruning Threshold: 0.06
# Epoch 179 (Period 4):  Train Loss: 8.458e-04,  Validation Loss: 7.694e-04,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.06
# Epoch 180 (Period 4):  Train Loss: 6.090e-04,  Validation Loss: 1.091e-03,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.06
# Epoch 181 (Period 5):  Train Loss: 4.285e+04,  Validation Loss: 5.190e+02,  Epoch Time: 0.43s,  Current Pruning Threshold: 0
# Epoch 182 (Period 5):  Train Loss: 3.730e+02,  Validation Loss: 2.670e+02,  Epoch Time: 0.44s,  Current Pruning Threshold: 0
# Epoch 183 (Period 5):  Train Loss: 2.305e+02,  Validation Loss: 1.936e+02,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch 184 (Period 5):  Train Loss: 1.740e+02,  Validation Loss: 1.483e+02,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch 185 (Period 5):  Train Loss: 1.403e+02,  Validation Loss: 1.211e+02,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch 186 (Period 5):  Train Loss: 1.191e+02,  Validation Loss: 1.091e+02,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch 187 (Period 5):  Train Loss: 1.004e+02,  Validation Loss: 9.678e+01,  Epoch Time: 0.43s,  Current Pruning Threshold: 0
# Epoch 188 (Period 5):  Train Loss: 8.919e+01,  Validation Loss: 8.418e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch 189 (Period 5):  Train Loss: 7.714e+01,  Validation Loss: 7.014e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0
# Epoch 190 (Period 5):  Train Loss: 6.653e+01,  Validation Loss: 6.126e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch 191 (Period 5):  Train Loss: 5.862e+01,  Validation Loss: 5.267e+01,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.00014446
# Epoch 192 (Period 5):  Train Loss: 5.062e+01,  Validation Loss: 4.637e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.00057644
# Epoch 193 (Period 5):  Train Loss: 4.374e+01,  Validation Loss: 3.794e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.0012918
# Epoch 194 (Period 5):  Train Loss: 4.231e+01,  Validation Loss: 3.318e+01,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.0022836
# Epoch 195 (Period 5):  Train Loss: 3.419e+01,  Validation Loss: 3.316e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.0035424
# Epoch 196 (Period 5):  Train Loss: 2.949e+01,  Validation Loss: 2.557e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.0050559
# Epoch 197 (Period 5):  Train Loss: 2.700e+01,  Validation Loss: 2.708e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.0068097
# Epoch 198 (Period 5):  Train Loss: 2.354e+01,  Validation Loss: 2.533e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.0087868
# Epoch 199 (Period 5):  Train Loss: 3.396e+01,  Validation Loss: 2.530e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.010968
# Epoch 200 (Period 5):  Train Loss: 1.875e+01,  Validation Loss: 1.372e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.013333
# Epoch 201 (Period 5):  Train Loss: 1.495e+01,  Validation Loss: 1.448e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.015858
# Epoch 202 (Period 5):  Train Loss: 1.114e+01,  Validation Loss: 7.963e+00,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.018519
# Epoch 203 (Period 5):  Train Loss: 8.184e+00,  Validation Loss: 2.065e+01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.021291
# Epoch 204 (Period 5):  Train Loss: 7.970e+00,  Validation Loss: 4.181e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.024147
# Epoch 205 (Period 5):  Train Loss: 4.678e+00,  Validation Loss: 3.716e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.027059
# Epoch 206 (Period 5):  Train Loss: 4.719e+00,  Validation Loss: 2.642e+00,  Epoch Time: 0.51s,  Current Pruning Threshold: 0.03
# Epoch 207 (Period 5):  Train Loss: 4.755e+00,  Validation Loss: 1.718e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.032941
# Epoch 208 (Period 5):  Train Loss: 2.111e+00,  Validation Loss: 1.138e+00,  Epoch Time: 0.46s,  Current Pruning Threshold: 0.035853
# Epoch 209 (Period 5):  Train Loss: 1.161e+00,  Validation Loss: 5.034e-01,  Epoch Time: 0.45s,  Current Pruning Threshold: 0.038709
# Epoch 210 (Period 5):  Train Loss: 4.807e-01,  Validation Loss: 1.694e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.041481
# Epoch 211 (Period 5):  Train Loss: 1.129e-01,  Validation Loss: 7.095e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.044142
# Epoch 212 (Period 5):  Train Loss: 1.825e-01,  Validation Loss: 1.057e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.046667
# Epoch 213 (Period 5):  Train Loss: 7.423e-02,  Validation Loss: 3.788e-02,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.049032
# Epoch 214 (Period 5):  Train Loss: 3.004e-02,  Validation Loss: 1.494e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.051213
# Epoch 215 (Period 5):  Train Loss: 3.504e-01,  Validation Loss: 1.507e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.05319
# Epoch 216 (Period 5):  Train Loss: 9.482e-03,  Validation Loss: 5.474e-03,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.054944
# Epoch 217 (Period 5):  Train Loss: 1.993e-03,  Validation Loss: 8.425e-04,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.056458
# Epoch 218 (Period 5):  Train Loss: 1.996e-05,  Validation Loss: 8.488e-08,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.057716
# Epoch 219 (Period 5):  Train Loss: 1.975e-09,  Validation Loss: 5.062e-12,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.058708
# Epoch 220 (Period 5):  Train Loss: 1.404e-11,  Validation Loss: 1.131e-10,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.059424
# Early stopping at epoch 220 as train loss 0.00000000001404 is below the threshold 0.00000000010000
# Training Stopped. Time elapsed: 97.85s
# Training dimension 10...
# Epoch   1 (Period 1):  Train Loss: 5.889e+03,  Validation Loss: 1.837e+02,  Epoch Time: 0.46s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 1.283e+02,  Validation Loss: 9.145e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 7.721e+01,  Validation Loss: 6.626e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 5.470e+01,  Validation Loss: 4.957e+01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 4.323e+01,  Validation Loss: 3.956e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 3.612e+01,  Validation Loss: 3.345e+01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 3.156e+01,  Validation Loss: 2.766e+01,  Epoch Time: 0.44s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 2.743e+01,  Validation Loss: 2.535e+01,  Epoch Time: 0.44s,  Current Pruning Threshold: 0
# Epoch   9 (Period 1):  Train Loss: 2.505e+01,  Validation Loss: 2.476e+01,  Epoch Time: 0.40s,  Current Pruning Threshold: 0
# Epoch  10 (Period 1):  Train Loss: 2.142e+01,  Validation Loss: 1.863e+01,  Epoch Time: 0.39s,  Current Pruning Threshold: 0
# Epoch  11 (Period 1):  Train Loss: 2.084e+01,  Validation Loss: 1.488e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.00014446
# Epoch  12 (Period 1):  Train Loss: 1.490e+01,  Validation Loss: 1.181e+01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.00057644
# Epoch  13 (Period 1):  Train Loss: 1.080e+01,  Validation Loss: 9.145e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.0012918
# Epoch  14 (Period 1):  Train Loss: 8.864e+00,  Validation Loss: 6.941e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.0022836
# Epoch  15 (Period 1):  Train Loss: 6.732e+00,  Validation Loss: 6.788e+00,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.0035424
# Epoch  16 (Period 1):  Train Loss: 5.135e+00,  Validation Loss: 4.803e+00,  Epoch Time: 0.43s,  Current Pruning Threshold: 0.0050559
# Epoch  17 (Period 1):  Train Loss: 3.638e+00,  Validation Loss: 3.386e+00,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.0068097
# Epoch  18 (Period 1):  Train Loss: 3.053e+00,  Validation Loss: 2.541e+00,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.0087868
# Epoch  19 (Period 1):  Train Loss: 2.398e+00,  Validation Loss: 2.502e+00,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.010968
# Epoch  20 (Period 1):  Train Loss: 1.833e+00,  Validation Loss: 1.466e+00,  Epoch Time: 0.56s,  Current Pruning Threshold: 0.013333
# Epoch  21 (Period 1):  Train Loss: 1.584e+00,  Validation Loss: 9.180e-01,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.015858
# Epoch  22 (Period 1):  Train Loss: 1.008e+00,  Validation Loss: 5.399e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.018519
# Epoch  23 (Period 1):  Train Loss: 7.062e-01,  Validation Loss: 4.234e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.021291
# Epoch  24 (Period 1):  Train Loss: 6.095e-01,  Validation Loss: 2.275e-01,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.024147
# Epoch  25 (Period 1):  Train Loss: 3.408e-01,  Validation Loss: 2.291e-01,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.027059
# Epoch  26 (Period 1):  Train Loss: 1.235e-01,  Validation Loss: 4.833e-02,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.03
# Epoch  27 (Period 1):  Train Loss: 3.753e-02,  Validation Loss: 2.124e-02,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.032941
# Epoch  28 (Period 1):  Train Loss: 5.551e-03,  Validation Loss: 7.080e-03,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.035853
# Epoch  29 (Period 1):  Train Loss: 7.707e-03,  Validation Loss: 5.284e-03,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.038709
# Epoch  30 (Period 1):  Train Loss: 5.739e-03,  Validation Loss: 2.487e-03,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.041481
# Epoch  31 (Period 1):  Train Loss: 4.254e-02,  Validation Loss: 3.101e-03,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.044142
# Epoch  32 (Period 1):  Train Loss: 1.793e-03,  Validation Loss: 2.586e-03,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.046667
# Epoch  33 (Period 1):  Train Loss: 1.643e-03,  Validation Loss: 1.643e-03,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.049032
# Epoch  34 (Period 1):  Train Loss: 1.703e-03,  Validation Loss: 4.734e-04,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.051213
# Epoch  35 (Period 1):  Train Loss: 3.356e-03,  Validation Loss: 7.499e-04,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.05319
# Epoch  36 (Period 1):  Train Loss: 2.549e-02,  Validation Loss: 1.040e-08,  Epoch Time: 0.38s,  Current Pruning Threshold: 0.054944
# Epoch  37 (Period 1):  Train Loss: 6.241e-10,  Validation Loss: 7.850e-12,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.056458
# Epoch  38 (Period 1):  Train Loss: 1.315e-10,  Validation Loss: 8.583e-12,  Epoch Time: 0.39s,  Current Pruning Threshold: 0.057716
# Epoch  39 (Period 1):  Train Loss: 4.460e-07,  Validation Loss: 6.031e-07,  Epoch Time: 0.37s,  Current Pruning Threshold: 0.058708
# Epoch  40 (Period 1):  Train Loss: 6.588e-05,  Validation Loss: 9.819e-04,  Epoch Time: 0.42s,  Current Pruning Threshold: 0.059424
# Epoch  41 (Period 1):  Train Loss: 2.210e-01,  Validation Loss: 9.246e-10,  Epoch Time: 0.41s,  Current Pruning Threshold: 0.059856
# Epoch  42 (Period 1):  Train Loss: 2.815e-11,  Validation Loss: 3.535e-12,  Epoch Time: 0.40s,  Current Pruning Threshold: 0.06
# Early stopping at epoch 42 as train loss 0.00000000002815 is below the threshold 0.00000000010000
# Training Stopped. Time elapsed: 16.59s
# Final model saved as best with loss: 3.534543e-12

# %% [markdown]
# ## **IV. Coefficient Reconstructor**

# %% [markdown]
# #### `generate_set_labels`
#
# The section below generates the layer labels that will be used to recontruct the symbolic of the right hand side (RHS) of governing equations. In addition, it also generates LHS labels.

# %%
def generate_layer_labels(N):
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)]

def generate_LHS_labels(N):
    return [f"(x{i})'" for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
from coefficient_reconstructor import *
cr = CoefficientReconstructor(generate_layer_labels, generate_LHS_labels)

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
eq_str = []
for i in range(len(weights_list)):
    path_products = cr.reconstruct_coefficients(i,
                                               weights_list[i], 
                                            minimum_coefficient_threshold = 1e-2,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
        eq_str.append(dimension)
# Out:
# (x1)' = 8.000000208 - 0.9999999476*x1 - 1.000000049*x10*x9 + 1.000000018*x10*x2
# (x2)' = 7.9999995 - 0.9999998238*x2 + 0.9999999879*x1*x3 - 0.9999999673*x1*x10
# (x3)' = 8.000000191 - 1.000000026*x1*x2 + 1.000000026*x2*x4 - 1.000000084*x3
# (x4)' = 7.999998089 - 1.000000469*x2*x3 + 1.000000421*x3*x5 - 1.000000034*x4
# (x5)' = 8.000001644 - 0.9999994029*x5 - 1.000000169*x3*x4 + 1.000000169*x4*x6
# (x6)' = 7.999999187 - 1.000000005*x4*x5 - 0.9999999773*x6 + 1.000000005*x5*x7
# (x7)' = 8.000000026 - 1.000000153*x5*x6 + 0.9999999818*x6*x8 - 0.999999993*x7
# (x8)' = 7.999999961 - 0.9999999952*x8 - 0.9999999675*x6*x7 + 0.9999999675*x7*x9
# (x9)' = 8.00000055 - 0.9999995271*x7*x8 + 1.000000069*x10*x8 - 0.9999997233*x9
# (x10)' = 7.999999984 - 0.999999998*x10 + 0.9999999904*x1*x9 - 0.9999999124*x8*x9

# %%
loss_list
# Out:
# [3.0745012e-12,
#  2.9714644e-12,
#  1.9159932e-12,
#  1.2099135e-11,
#  4.4889228e-11,
#  2.9414398e-12,
#  8.027341e-12,
#  2.0181873e-12,
#  1.40395915e-11,
#  3.5345429e-12]

# %% [markdown]
# ### **Validation**

# %%
import model_reconstructor as mr

recovered_model = mr.RecoveredModel()
recovered_model.parse_ode_equations(eq_str);

# %% [markdown]
# ### Comparing vector field

# %%
pred_x_dot = recovered_model.predict_derivatives(x_train)

val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

import matplotlib.pyplot as plt

plt.plot(val_t_eval, pred_x_dot[:val_t_eval.shape[0], 0],label='SREINet')
plt.plot(val_t_eval, dx_train[:val_t_eval.shape[0],0], '--', label='True')
plt.xlabel('Time')
plt.ylabel(r'$\dot{x}_1$')
plt.legend()
plt.show()

# %% [markdown]
# ### Comparing response

# %%
val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

validation_result = recovered_model.simulate(data_initial_conditions[0], t_span=val_t_span,t_eval=val_t_eval, method='DOP853')

# %%
import matplotlib.pyplot as plt

#plot average of validation_result['y']
val_avg = np.mean(validation_result['y'], axis=0)
x_train_avg = np.mean(x_train, axis=1)

figure_size = (4,3)
plt.figure(figsize=figure_size)
plt.plot(validation_result['t'], val_avg,label='SREINet')
plt.plot(val_t_eval, x_train_avg[:val_t_eval.shape[0]], '--', label='True')
plt.xlabel('Time')
plt.ylabel(r'$\bar{x}$')
plt.xlim(0, 6)
#plt.legend()
plt.show()
#plt.savefig('SREINet_Lorenz96_5-layers_x3.png',dpi=600)

# %%
score =recovered_model.score(x_train[:val_t_eval.shape[0]], dx_train[:val_t_eval.shape[0]])
print(f"Score: {score}")

complexity = recovered_model.calculate_complexity()
print(f"Complexity: {complexity}")

complexity_per_dimension = complexity//dim
print(f"Complexity per dimension: {complexity_per_dimension}")
# Out:
# Score: 0.9999999999999416
# Complexity: 40
# Complexity per dimension: 4

# %% [markdown]
# ## **VI. Output**

# %%
# Output validation results to numpy file
np.savez_compressed('output/validation_results_6layers.npz',
                    t=validation_result['t'],
                    val_avg=val_avg,
                    val_t_eval=val_t_eval,
                    x_train_avg=x_train_avg)
print("Validation results saved to 'validation_results_6layers.npz'")
# Out:
# Validation results saved to 'validation_results_6layers.npz'
