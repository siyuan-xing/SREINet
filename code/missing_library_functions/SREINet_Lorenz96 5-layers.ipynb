# %% [markdown]
# ## **Lorenz 96 Model Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_MODEL = 'Lorenz_96' 
MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)  

# Generate data based on the specified model type
LORENZ96_DIM = 10  #set up the dimension of the Lorenz 96 model

num_traj = 3
data_initial_conditions = DG.DataGenerator.generate_initial_conditions(LORENZ96_DIM, num_traj, seed=42) #np.random.normal(1, 2, LORENZ96_DIM

data_T =  40.0       # Length of the data (T)
data_dt = 0.01       # Resolution of the data (dt)
myDG = DG.DataGenerator(data_initial_conditions, T=data_T, dt=data_dt, derivative_mode="exact")
t_arr, x_train, dx_train, default_guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL, method='DOP853')

print("Guessed highest order polynomial:", default_guessed_multiplicative_order)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train #data will be shuffled in the trainer


print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Guessed highest order polynomial: 2
# Training input shape: (12000, 10)
# Training output shape: (12000, 10)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 32
learning_rate = 0.01

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
dim = training_input.shape[1] # the number of input state variables

# The grid size of each dimension
layer_depth = default_guessed_multiplicative_order + 3
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn) # these numbers exclude the constant term
# Out:
# [10, 10, 10, 10, 10]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn,
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=0.01, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Trainer**

# %%
from sreinet_trainer import *

trainer = SREINetTrainer(model, my_optimizer, loss_fn, data_type='float32')

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.08 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 50
PRUNING_EPOCHS_PER_PERIOD = 30
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

pruning_scheduler = ps.PruningScheduler(steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                    num_periods=N_PERIODS,
                    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
                    #ramp_type='sigmoid',
                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.05

training_histories = []
weights_list = []
loss_list = []

# %%
for i in range(training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    output = training_output[:, i:i+1]
    
    history = trainer.fit(training_input, output,
     batch_size=MINI_BATCH_SIZE, 
     validation_split=0.20,
     epochs=round(NUM_EPOCHS), 
     pruning_scheduler=pruning_scheduler,
     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
     shuffle_per_epoch=False,
     patience_periods=15,
     verbose=1,
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
    loss_list.append(trainer.get_best_loss())

    #reset the model and trainer
    trainer.reset_trainer_and_model_weights(i)
# Out:
# Training dimension 1...
# Epoch   1 (Period 1):  Train Loss: 6.049e+01,  Validation Loss: 1.509e+01,  Epoch Time: 0.50s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 1.079e+01,  Validation Loss: 6.246e+00,  Epoch Time: 0.27s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 6.049e+00,  Validation Loss: 5.897e+00,  Epoch Time: 0.30s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 4.355e+00,  Validation Loss: 3.770e+00,  Epoch Time: 0.26s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 3.910e+00,  Validation Loss: 3.637e+00,  Epoch Time: 0.27s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 3.518e+00,  Validation Loss: 2.654e+00,  Epoch Time: 0.27s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 1.838e+00,  Validation Loss: 1.367e+00,  Epoch Time: 0.28s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 1.783e+00,  Validation Loss: 1.015e+00,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.00044677
# Epoch   9 (Period 1):  Train Loss: 2.614e+00,  Validation Loss: 2.048e+00,  Epoch Time: 0.36s,  Current Pruning Threshold: 0.0017771
# Epoch  10 (Period 1):  Train Loss: 2.066e+00,  Validation Loss: 7.653e+00,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.0039612
# Epoch  11 (Period 1):  Train Loss: 2.983e+00,  Validation Loss: 1.476e+00,  Epoch Time: 0.27s,  Current Pruning Threshold: 0.0069504
# Epoch  12 (Period 1):  Train Loss: 2.600e+00,  Validation Loss: 1.203e+00,  Epoch Time: 0.27s,  Current Pruning Threshold: 0.010678
# Epoch  13 (Period 1):  Train Loss: 1.154e+00,  Validation Loss: 1.578e+00,  Epoch Time: 0.26s,  Current Pruning Threshold: 0.01506
# Epoch  14 (Period 1):  Train Loss: 1.021e+00,  Validation Loss: 6.867e-01,  Epoch Time: 0.27s,  Current Pruning Threshold: 0.02
# Epoch  15 (Period 1):  Train Loss: 8.584e-01,  Validation Loss: 6.140e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0
  Epoch Time: 0.31s,  Current Pruning Threshold: 0.02
# Epoch 285 (Period 10):  Train Loss: 4.839e+00,  Validation Loss: 4.076e+00,  Epoch Time: 0.34s,  Current Pruning Threshold: 0.025386
# Epoch 286 (Period 10):  Train Loss: 3.971e+00,  Validation Loss: 3.464e+00,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.031099
# Epoch 287 (Period 10):  Train Loss: 4.494e+00,  Validation Loss: 3.376e+00,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.037011
# Epoch 288 (Period 10):  Train Loss: 5.774e+00,  Validation Loss: 3.116e+00,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.042989
# Epoch 289 (Period 10):  Train Loss: 2.907e+00,  Validation Loss: 1.907e+00,  Epoch Time: 0.31s,  Current Pruning Threshold: 0.048901
# Epoch 290 (Period 10):  Train Loss: 2.176e+00,  Validation Loss: 1.509e+00,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.054614
# Epoch 291 (Period 10):  Train Loss: 1.274e+00,  Validation Loss: 9.628e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.06
# Epoch 292 (Period 10):  Train Loss: 9.049e-01,  Validation Loss: 1.013e+00,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.06494
# Epoch 293 (Period 10):  Train Loss: 8.595e-01,  Validation Loss: 4.564e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.069322
# Epoch 294 (Period 10):  Train Loss: 5.225e-01,  Validation Loss: 2.181e-01,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.07305
# Epoch 295 (Period 10):  Train Loss: 6.813e-01,  Validation Loss: 1.185e-02,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.076039
# Epoch 296 (Period 10):  Train Loss: 8.435e-03,  Validation Loss: 9.373e-03,  Epoch Time: 0.33s,  Current Pruning Threshold: 0.078223
# Epoch 297 (Period 10):  Train Loss: 1.905e-04,  Validation Loss: 2.833e-08,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.079553
# Epoch 298 (Period 10):  Train Loss: 2.987e-10,  Validation Loss: 5.555e-12,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.08
# Epoch 299 (Period 10):  Train Loss: 4.813e-12,  Validation Loss: 4.050e-12,  Epoch Time: 0.32s,  Current Pruning Threshold: 0.08
# Early stopping at epoch 299 as train loss 0.00000000000481 is below the threshold 0.00000000010000
# Training Stopped. Time elapsed: 103.09s
# Final model saved as best with loss: 4.050120e-12

# %%
loss_list
# Out:
# [2.794202e-12,
#  1.9113407e-12,
#  1.877923e-12,
#  3.0246582e-12,
#  2.2589003e-12,
#  9.404456e-12,
#  2.2328207e-12,
#  3.5137778e-11,
#  1.9164777e-11,
#  4.0501205e-12]

# %% [markdown]
# ## **IV. Coefficient Reconstructor**

# %% [markdown]
# #### `generate_set_labels`
#
# The section below generates the layer labels that will be used to recontruct the symbolic of the right hand side (RHS) of governing equations. In addition, it also generates LHS labels.

# %%
def generate_layer_labels(N):
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)]

def generate_LHS_labels(N):
    return [f"(x{i})'" for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
from coefficient_reconstructor import *
cr = CoefficientReconstructor(generate_layer_labels, generate_LHS_labels)

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
eq_str = []
for i in range(len(weights_list)):
    path_products = cr.reconstruct_coefficients(i,
                                               weights_list[i], 
                                            minimum_coefficient_threshold = 1e-3,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
        eq_str.append(dimension)
# Out:
# (x1)' = 7.999999597 - 1.000000114*x1 + 1.000000017*x10*x2 - 1.000000016*x10*x9
# (x2)' = 7.999999711 - 1.000000001*x1*x10 - 0.9999999639*x2 + 0.9999999982*x1*x3
# (x3)' = 8.000000367 - 1.000000046*x3 - 1.000000021*x1*x2 + 1.000000021*x2*x4
# (x4)' = 8.000000516 - 1.000000101*x2*x3 + 0.9999999789*x3*x5 - 1.000000065*x4
# (x5)' = 7.999999825 - 0.9999998795*x5 - 0.9999999445*x3*x4 + 0.9999999445*x4*x6
# (x6)' = 7.999998832 - 0.9999996494*x6 - 0.9999999034*x4*x5 + 0.9999999342*x5*x7
# (x7)' = 8.000000297 - 0.9999999624*x5*x6 - 1.000000016*x7 + 0.999999984*x6*x8
# (x8)' = 8.000000358 - 1.000000045*x8 - 1.000000156*x6*x7 + 1.000000272*x7*x9
# (x9)' = 7.999999187 - 1.000000306*x7*x8 + 0.9999999929*x10*x8 - 0.9999996939*x9
# (x10)' = 7.999999372 - 0.9999999215*x10 - 0.9999999884*x8*x9 + 0.999999983*x1*x9

# %%
loss_list
# Out:
# [2.794202e-12,
#  1.9113407e-12,
#  1.877923e-12,
#  3.0246582e-12,
#  2.2589003e-12,
#  9.404456e-12,
#  2.2328207e-12,
#  3.5137778e-11,
#  1.9164777e-11,
#  4.0501205e-12]

# %% [markdown]
# ### **Validation**

# %%
import model_reconstructor as mr

recovered_model = mr.RecoveredModel()
recovered_model.parse_ode_equations(eq_str);

# %% [markdown]
# ### Comparing vector field

# %%
pred_x_dot = recovered_model.predict_derivatives(x_train)

val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

import matplotlib.pyplot as plt

plt.plot(val_t_eval, pred_x_dot[:val_t_eval.shape[0], 0],label='SREINet')
plt.plot(val_t_eval, dx_train[:val_t_eval.shape[0],0], '--', label='True')
plt.xlabel('Time')
plt.ylabel(r'$\dot{x}_1$')
plt.legend()
plt.show()

# %% [markdown]
# ### Comparing response

# %%
val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

validation_result = recovered_model.simulate(data_initial_conditions[0], t_span=val_t_span,t_eval=val_t_eval, method='DOP853')

# %%
print(val_t_eval.shape)
print(x_train_avg.shape)
# Out:
# (4000,)
# (12000,)

# %%
import matplotlib.pyplot as plt

#plot average of validation_result['y']
val_avg = np.mean(validation_result['y'], axis=0)
x_train_avg = np.mean(x_train, axis=1)

figure_size = (4,3)
plt.figure(figsize=figure_size)
plt.plot(validation_result['t'], val_avg,label='SREINet')
plt.plot(val_t_eval, x_train_avg[:val_t_eval.shape[0]], '--', label='True')
plt.xlabel('Time')
plt.ylabel(r'$\bar{x}$')
plt.xlim(0, 6)
#plt.legend()
plt.show()
#plt.savefig('SREINet_Lorenz96_5-layers_x3.png',dpi=600)

# %%
score =recovered_model.score(x_train[:val_t_eval.shape[0]], dx_train[:val_t_eval.shape[0]])
print(f"Score: {score}")

complexity = recovered_model.calculate_complexity()
print(f"Complexity: {complexity}")

complexity_per_dimension = complexity//dim
print(f"Complexity per dimension: {complexity_per_dimension}")
# Out:
# Score: 0.9999999999999815
# Complexity: 40
# Complexity per dimension: 4
