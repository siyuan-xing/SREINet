# %% [markdown]
# ## **Lorenz 96 Model Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_MODEL = 'Lorenz_96' 
MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)  

# Generate data based on the specified model type
LORENZ96_DIM = 10  #set up the dimension of the Lorenz 96 model

num_traj = 1
data_initial_conditions = DG.DataGenerator.generate_initial_conditions(LORENZ96_DIM, num_traj, seed=42) #np.random.normal(1, 2, LORENZ96_DIM

data_T =  20.0       # Length of the data (T)
data_dt = 0.01       # Resolution of the data (dt)
myDG = DG.DataGenerator(data_initial_conditions, T=data_T, dt=data_dt, derivative_mode="exact")
t_arr, x_train, dx_train, default_guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL, method='DOP853')

print("Guessed highest order polynomial:", default_guessed_multiplicative_order)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train #data will be shuffled in the trainer


print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Guessed highest order polynomial: 2
# Training input shape: (2000, 10)
# Training output shape: (2000, 10)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 16
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
dim = training_input.shape[1] # the number of input state variables

# The grid size of each dimension
layer_depth = default_guessed_multiplicative_order
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn) # these numbers exclude the constant term
# Out:
# [10, 10]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn,
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=0.001, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Trainer**

# %%
from sreinet_trainer import *

trainer = SREINetTrainer(model, my_optimizer, loss_fn, data_type='float32')

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.30 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 50
PRUNING_EPOCHS_PER_PERIOD = 40
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

pruning_scheduler = ps.PruningScheduler(steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                    num_periods=N_PERIODS,
                    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.15

training_histories = []
weights_list = []
loss_list = []

# %%
for i in range(training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    output = training_output[:, i:i+1]
    
    history = trainer.fit(training_input, output,
     batch_size=MINI_BATCH_SIZE, 
     validation_split=0.20,
     epochs=round(NUM_EPOCHS), 
     pruning_scheduler=pruning_scheduler,
     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
     shuffle_per_epoch=False,
     patience_periods=15,
     verbose=1,
    )
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
    loss_list.append(trainer.get_best_loss())

    #reset the model and trainer
    trainer.reset_trainer_and_model_weights(i)
# Out:
# Training dimension 1...
# Epoch   1 (Period 1):  Train Loss: 2.532e+02,  Validation Loss: 1.667e+02,  Epoch Time: 0.24s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 1.283e+02,  Validation Loss: 1.053e+02,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   3 (Period 1):  Train Loss: 8.463e+01,  Validation Loss: 6.364e+01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   4 (Period 1):  Train Loss: 5.749e+01,  Validation Loss: 5.026e+01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   5 (Period 1):  Train Loss: 3.912e+01,  Validation Loss: 3.109e+01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   6 (Period 1):  Train Loss: 2.896e+01,  Validation Loss: 2.347e+01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   7 (Period 1):  Train Loss: 2.312e+01,  Validation Loss: 1.761e+01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   8 (Period 1):  Train Loss: 1.586e+01,  Validation Loss: 1.310e+01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch   9 (Period 1):  Train Loss: 1.216e+01,  Validation Loss: 1.047e+01,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
# Epoch  10 (Period 1):  Train Loss: 9.569e+00,  Validation Loss: 8.155e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.00087931
# Epoch  11 (Period 1):  Train Loss: 7.310e+00,  Validation Loss: 6.247e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.0035069
# Epoch  12 (Period 1):  Train Loss: 6.154e+00,  Validation Loss: 5.901e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.007852
# Epoch  13 (Period 1):  Train Loss: 5.165e+00,  Validation Loss: 4.486e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.013864
# Epoch  14 (Period 1):  Train Loss: 4.927e+00,  Validation Loss: 4.038e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.021471
# Epoch  15 (Period 1):  Train Loss: 6.165e+00,  Validation Loss: 4.415e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.030586
# Epoch  16 (Period 1):  Train Loss: 9.702e+00,  Validation Loss: 6.958e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.041101
# Epoch  17 (Period 1):  Train Loss: 7.454e+00,  Validation Loss: 6.859e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.052892
# Epoch  18 (Period 1):  Train Loss: 1.149e+01,  Validation Loss: 9.560e+00,  Epoch Time: 0.07s,  Current Pruning Threshold: 0
  Epoch Time: 0.07s,  Current Pruning Threshold: 0.007852
# Epoch 173 (Period 5):  Train Loss: 5.139e-05,  Validation Loss: 1.269e-05,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.013864
# Epoch 174 (Period 5):  Train Loss: 8.744e-07,  Validation Loss: 3.139e-07,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.021471
# Epoch 175 (Period 5):  Train Loss: 1.637e-07,  Validation Loss: 6.315e-08,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.030586
# Epoch 176 (Period 5):  Train Loss: 2.918e-08,  Validation Loss: 1.004e-08,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.041101
# Epoch 177 (Period 5):  Train Loss: 4.899e-09,  Validation Loss: 1.532e-09,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.052892
# Epoch 178 (Period 5):  Train Loss: 6.870e-10,  Validation Loss: 3.388e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.065822
# Epoch 179 (Period 5):  Train Loss: 3.226e-10,  Validation Loss: 3.091e-10,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.079739
# Epoch 180 (Period 5):  Train Loss: 2.720e-10,  Validation Loss: 2.663e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.094479
# Epoch 181 (Period 5):  Train Loss: 2.535e-10,  Validation Loss: 2.606e-10,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.10987
# Epoch 182 (Period 5):  Train Loss: 2.330e-10,  Validation Loss: 2.173e-10,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.12573
# Epoch 183 (Period 5):  Train Loss: 1.882e-10,  Validation Loss: 1.442e-10,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.14188
# Epoch 184 (Period 5):  Train Loss: 1.588e-10,  Validation Loss: 1.557e-10,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.15812
# Epoch 185 (Period 5):  Train Loss: 1.559e-10,  Validation Loss: 1.409e-10,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.17427
# Epoch 186 (Period 5):  Train Loss: 1.498e-10,  Validation Loss: 1.335e-10,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.19013
# Epoch 187 (Period 5):  Train Loss: 1.329e-10,  Validation Loss: 1.232e-10,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.20552
# Epoch 188 (Period 5):  Train Loss: 1.118e-10,  Validation Loss: 1.108e-10,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.22026
# Epoch 189 (Period 5):  Train Loss: 1.102e-10,  Validation Loss: 1.087e-10,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.23418
# Epoch 190 (Period 5):  Train Loss: 9.974e-11,  Validation Loss: 9.233e-11,  Epoch Time: 0.07s,  Current Pruning Threshold: 0.24711
# Early stopping at epoch 190 as train loss 0.00000000009974 is below the threshold 0.00000000010000
# Training Stopped. Time elapsed: 12.49s
# Final model saved as best with loss: 9.233123e-11

# %%
loss_list
# Out:
# [8.403482e-11,
#  7.41827e-11,
#  8.682487e-11,
#  8.818136e-11,
#  8.340256e-11,
#  6.153852e-11,
#  7.343075e-11,
#  5.533937e-11,
#  9.619473e-11,
#  9.233123e-11]

# %% [markdown]
# ## **IV. Coefficient Reconstructor**

# %% [markdown]
# #### `generate_set_labels`
#
# The section below generates the layer labels that will be used to recontruct the symbolic of the right hand side (RHS) of governing equations. In addition, it also generates LHS labels.

# %%
def generate_layer_labels(N):
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)]

def generate_LHS_labels(N):
    return [f"(x{i})'" for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
from coefficient_reconstructor import *
cr = CoefficientReconstructor(generate_layer_labels, generate_LHS_labels)

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
eq_str = []
for i in range(len(weights_list)):
    path_products = cr.reconstruct_coefficients(i,
                                               weights_list[i], 
                                            minimum_coefficient_threshold = 3e-1,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
        eq_str.append(dimension)
# Out:
# (x1)' = 7.999989033 - 0.9999987483*x1 + 0.9999998212*x10*x2 - 0.9999996722*x10*x9
# (x2)' = 7.999988556 - 0.9999982715*x2 + 0.9999999702*x1*x3 - 0.9999997318*x1*x10
# (x3)' = 7.999987125 - 0.999998033*x3 - 0.9999994934*x1*x2 + 0.9999999106*x2*x4
# (x4)' = 7.999988556 - 0.9999991655*x4 - 0.9999996424*x2*x3 + 0.9999999106*x3*x5
# (x5)' = 8.000011444 - 1.000001371*x5 - 1.000000238*x3*x4 + 0.9999998808*x4*x6
# (x6)' = 7.999989986 - 0.9999988079*x6 - 0.9999997616*x4*x5 + 0.9999998808*x5*x7
# (x7)' = 7.999989033 - 0.9999989867*x7 - 0.9999997616*x5*x6 + 1.00000003*x6*x8
# (x8)' = 8.000008583 - 1.000001073*x8 - 1.000000238*x6*x7 + 1.000000149*x7*x9
# (x9)' = 7.999987125 - 0.9999983907*x9 - 0.9999997318*x7*x8 + 1.00000003*x10*x8
# (x10)' = 7.999988556 - 0.9999985695*x10 + 0.9999999106*x1*x9 - 0.9999997318*x8*x9

# %% [markdown]
# ### **Validation**

# %%
import model_reconstructor as mr

recovered_model = mr.RecoveredModel()
recovered_model.parse_ode_equations(eq_str);

# %% [markdown]
# ### Comparing vector field

# %%
pred_x_dot = recovered_model.predict_derivatives(x_train)

val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

import matplotlib.pyplot as plt

plt.plot(val_t_eval, pred_x_dot[:val_t_eval.shape[0], 0],label='SREINet')
plt.plot(val_t_eval, dx_train[:val_t_eval.shape[0],0], '--', label='True')
plt.xlabel('Time')
plt.ylabel(r'$\dot{x}_1$')
plt.legend()
plt.show()

# %% [markdown]
# ### Comparing response

# %%
val_t_span = [0,data_T]
val_t_eval = np.arange(0,data_T,data_dt)

validation_result = recovered_model.simulate(data_initial_conditions[0], t_span=val_t_span,t_eval=val_t_eval, method='DOP853')

# %%
import matplotlib.pyplot as plt
val_avg = np.mean(validation_result['y'], axis=0)
x_train_avg = np.mean(x_train, axis=1)
plt.figure(figsize=(4,3))

plt.plot(validation_result['t'], val_avg,label='SREINet')
plt.plot(val_t_eval, x_train_avg, '--', label='True')
plt.xlabel('Time')
plt.ylabel(r'$\bar{x}$')
plt.xlim(0, 6)
plt.legend()
plt.show()
#plt.savefig('SREINet_Lorenz96_2-layers.png', dpi=600)

# %%
score =recovered_model.score(x_train[:val_t_eval.shape[0]], dx_train[:val_t_eval.shape[0]])
print(f"Score: {score}")

complexity = recovered_model.calculate_complexity()
print(f"Complexity: {complexity}")

complexity_per_dimension = complexity//dim
print(f"Complexity per dimension: {complexity_per_dimension}")
# Out:
# Score: 0.9999999999998012
# Complexity: 40
# Complexity per dimension: 4

# %% [markdown]
# ## **VI. Output**

# %%
# Output validation results to numpy file
np.savez_compressed('output/validation_results_2layers.npz',
                    t=validation_result['t'],
                    val_avg=val_avg,
                    val_t_eval=val_t_eval,
                    x_train_avg=x_train_avg)
print("Validation results saved to 'validation_results_2layers.npz'")
# Out:
# Validation results saved to 'validation_results_2layers.npz'
