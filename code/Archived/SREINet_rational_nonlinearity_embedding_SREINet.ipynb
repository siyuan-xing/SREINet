# %% [markdown]
# ## **Rational Nonlinearity Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
MY_MODEL = 'rosenzweig_macArthur' 
MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)  

# Generate data based on the specified model
dim = 2
num_traj = 1
data_initial_conditions = DG.DataGenerator.generate_initial_conditions(dim, num_traj, seed=42) #np.random.normal(1, 2, LORENZ96_DIM

data_T =  100.0       # Length of the data (T)
data_dt = 0.05       # Resolution of the data (dt)
myDG = DG.DataGenerator(data_initial_conditions, T=data_T, dt=data_dt, derivative_mode="exact")



t_arr, x_train, dx_train, guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL, method='RK45')

print("Guessed multiplicative_order:", guessed_multiplicative_order)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train
# Optionally, save a copy of the training input for simulation
training_input_for_sim = training_input.copy() # Saving a copy of training input for simulation (Before shuffling)

training_input, training_output = myDG.shuffleData(training_input, training_output)

print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Guessed multiplicative_order: 3
# Training input shape: (2000, 2)
# Training output shape: (2000, 2)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 32
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables)
dim = training_input.shape[1] 

# The grid size of each dimension
layer_depth = guessed_multiplicative_order
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn) # these numbers exclude the constant term
# Out:
# [2, 2, 2]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]

def create_sreinet_model(dim, activation_fns, layer_neuron_nums_per_act_fn, activation_functions=None, 
                        weight_std=0.001, delta=1e-5, seed=42, data_type='float32'):
    """
    Create and initialize a SREINet model.
    
    Args:
        dim (int): Input dimension (number of input variables)
        layer_neuron_nums_per_act_fn (list): Number of neurons per activation function in each hidden layer
        activation_functions (list, optional): List of activation functions. Defaults to [lambda x:x]
        weight_std (float, optional): Standard deviation for weight initialization. Defaults to 0.001
        delta: small constant to avoid division by zero
        seed (int, optional): Random seed for reproducible initialization. Defaults to 42
        data_type (str, optional): Data type for the model. Defaults to 'float32'
    
    Returns:
        tf.keras.Model: Configured SREINet model
    """
    # Set default activation if not provided
    activation_functions = activation_fns
    
    # Create input layer
    inputs = tf.keras.layers.Input(shape=(dim,), dtype=data_type)

    denominator_sreinet = SREINet([2],
                      activations=activation_functions,
                      weight_initializer=tf.initializers.random_normal(stddev=weight_std, seed=seed),
                      data_type=data_type,
                      name='embedding_denominator_SREINet')
    
    denominator_output = denominator_sreinet(inputs)

    rational_output = denominator_output / (denominator_output**2 + delta)
    
    new_inputs = tf.keras.layers.Concatenate()([inputs, rational_output])

    # add each element in layer_neuron_nums_per_act_fn by the number of elements in rational_nonlinearity(inputs)
    layer_neuron_nums_per_act_fn = [new_inputs.shape[1] for x in layer_neuron_nums_per_act_fn]
    
    # Create SREINet model
    sreinet = SREINet(layer_neuron_nums_per_act_fn,
                      activations=activation_functions,
                      weight_initializer=tf.initializers.random_normal(stddev=0.5, seed=seed),
                      data_type=data_type,
                      name='SREINet')
    
    # Apply the SREINet to inputs
    output = sreinet(new_inputs)
    
    # Create the final model
    model = tf.keras.Model(inputs=inputs, outputs=output)
    
    return model


model = create_sreinet_model(dim, my_activation, layer_neuron_nums_per_act_fn)


def reinitialize_model_weights(model):
    """
    Reinitialize weights of the SREINet model.
    
    Args:
        model (tf.keras.Model): The SREINet model to reinitialize
    """
    #need to update here

    if hasattr(model.layers[1], 'reinitialize_weights'):
        tf.random.set_seed(np.random.randint(10000))
        model.layers[1].reinitialize_weights()
    else:
        print("SREINet does not have a reinitialize_weights() function.")

# %%
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 2)]                  0         []
#
#  embedding_denominator_SREI  (None, 1)                    3         ['input_11[0][0]']
#  Net (SREINet)
#
#  tf.math.pow_9 (TFOpLambda)  (None, 1)                    0         ['embedding_denominator_SREINe
#                                                                     t[0][0]']
#
#  tf.__operators__.add_9 (TF  (None, 1)                    0         ['tf.math.pow_9[0][0]']
#  OpLambda)
#
#  tf.math.truediv_9 (TFOpLam  (None, 1)                    0         ['embedding_denominator_SREINe
#  bda)                                                               t[0][0]',
#                                                                      'tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  concatenate_10 (Concatenat  (None, 3)                    0         ['input_11[0][0]',
#  e)                                                                  'tf.math.truediv_9[0][0]']
#
#  SREINet (SREINet)           (None, 1)                    36        ['concatenate_10[0][0]']
#
# ==================================================================================================
# Total params: 39 (156.00 Byte)
# Trainable params: 35 (140.00 Byte)
# Non-trainable params: 4 (16.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Training with Pruning**

# %%
import time
np.set_printoptions(threshold=np.inf)

# Define a training step function
@tf.function
def train_step(model, optimizer, loss_fn, inputs, targets, binary_mask):        
    with tf.GradientTape() as tape:
        # Generate predictions and calculate loss
        predictions = model(inputs, training=False)
        loss = loss_fn(targets, predictions)   
        
    # Calculate gradients and update model weights
    gradients = tape.gradient(loss, model.trainable_variables)        

    # Assuming binary_masks_ones is a list of binary masks created for each trainable variable
    masked_gradients = [tf.multiply(grad, mask) for grad, mask in zip(gradients, binary_mask)]

    optimizer.apply_gradients(zip(masked_gradients, model.trainable_variables))

    return loss

# Define a validation step function
@tf.function
def val_step(model, loss_fn, inputs, targets):
    # Generate predictions and calculate loss for validation data
    predictions = model(inputs, training=False)
    # predictions = model(inputs, training=False) 
    v_loss = loss_fn(targets, predictions)
    # Record the validation loss
    return v_loss   

def SREINet_fit_w_pruning(
    model,              # TensorFlow model to be trained
    training_input,     # Input features for training
    training_output,    # Target outputs for training
    batch_size,         # Number of samples per batch of computation
    validation_split,   # Fraction of data to be used as validation set
    epochs,             # Number of complete passes through the training dataset
    optimizer,          # Optimization algorithm for updating weights
    loss_fn,            # Loss function to measure model's performance
    pruning_schedule,   # Pruning schedule for gradually increasing the sparsity level
    data_type='float32',    # Data type of the tensors (default: 'float32')
    callbacks=None,         # List of callbacks for custom actions at various stages of training
    early_stopping_loss_threshold=0,       # Threshold for early stopping based on training and validation loss
    early_stopping_pruning_threshold=0,    # Threshold for early stopping based on pruning schedule
    verbose=0               # Verbosity mode (0 = silent, 1 = progress bar, etc.)
):
    # Cast the training input and output to the specified data type
    training_input = tf.cast(training_input, data_type)
    training_output = tf.cast(training_output, data_type)

    # Shuffle and batch the dataset, then split it into training and validation sets
    full_dataset = tf.data.Dataset.from_tensor_slices((training_input, training_output)).shuffle(buffer_size=1024)
    total_samples = training_input.shape[0]
    train_samples = int(total_samples * (1 - validation_split))
    
    # Apply the data type casting for each batch in the datasets
    train_dataset = full_dataset.take(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))
    val_dataset = full_dataset.skip(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))

    # Initialize metrics for tracking training and validation loss
    train_loss = tf.keras.metrics.Mean(name='train_loss', dtype=data_type)
    val_loss = tf.keras.metrics.Mean(name='val_loss', dtype=data_type)
    
    # Parameters initialization
    binary_mask = [tf.ones_like(var) for var in model.trainable_variables]

    def generate_binary_mask_and_prune_weight(model, pruning_weight_threshold):
        binary_masks = []  # Initialize list to hold binary masks
        
        # Iterate over each variable to apply the pruning threshold and generate masks
        for var in model.trainable_variables:
            # Generate a binary mask where weights above the PRUNING_WEIGHT_THRESHOLD are marked with 1, others with 0
            mask = tf.cast(tf.abs(var) >= pruning_weight_threshold, var.dtype)

            # Update the mask at position (0, 0) to be 1 using tf.tensor_scatter_nd_update (To Avoid the constant term being pruned)
            indices = tf.constant([[0, 0]])  # Specify the indices to update
            updates = tf.constant([1], dtype=mask.dtype)  # Specify the value to update
            mask = tf.tensor_scatter_nd_update(mask, indices, updates)

            binary_masks.append(mask)  # Add the generated mask to the list            

            # Apply mask to modify weights by setting weights below PRUNING_WEIGHT_THRESHOLD to zero
            modified_weight = var * mask
            var.assign(modified_weight)            
        return binary_masks

    # Prepare a dictionary to track the training history
    history = {'loss': [], 'val_loss': []}

    # Before the training loop starts
    if callbacks:
        for callback in callbacks:
            # Assign the model to the callback
            callback.set_model(model)

            # Manually setting params before calling any methods that might depend on them
            callback.params = {
                'epochs': epochs,  # Number of epochs
                # You can add more parameters here as needed
            }

            # Now call on_train_begin with all properties set
            callback.on_train_begin(logs={'loss_threshold': early_stopping_loss_threshold})

    training_start_time = time.time()
    # Execute the training loop
    for epoch in range(epochs):
        # Notify callbacks that the epoch has started
        if callbacks:
            epoch_logs = {}
            for callback in callbacks:
                callback.on_epoch_begin(epoch, logs=epoch_logs)

        if verbose: 
            eopoch_start_time = time.time()

        # Reset state of metrics at the start of each epoch
        train_loss.reset_states()
        val_loss.reset_states()

        # Retrieve the current pruning schedule threshold
        current_pruning_threshold = pruning_schedule[epoch]
        binary_mask = generate_binary_mask_and_prune_weight(model, current_pruning_threshold)
        
        layer_losses_sum = None
        layer_indices = [i for i, layer in enumerate(model.layers) if layer.trainable]
        # Process each batch in the training dataset
        for train_inputs, train_targets in train_dataset:           
            loss = train_step(model = model, 
                            optimizer = optimizer, 
                            loss_fn = loss_fn,
                            inputs = train_inputs, 
                            targets = train_targets, 
                            binary_mask = binary_mask)    
            # Record the loss
            train_loss(loss)

        # Process each batch in the validation dataset
        for val_inputs, val_targets in val_dataset:
            v_loss = val_step(model = model, 
                                loss_fn = loss_fn,
                                inputs = val_inputs, 
                                targets = val_targets)
            val_loss(v_loss)

        # Append the average losses for this epoch to the history
        history['loss'].append(train_loss.result().numpy())
        history['val_loss'].append(val_loss.result().numpy())
        #calculate the average of val_loss
        
        # Current Losses
        current_train_loss = train_loss.result().numpy()
        current_val_loss = val_loss.result().numpy()

        # Notify callbacks that the epoch has ended
        epoch_logs = {'loss': current_train_loss, 'val_loss': current_val_loss}
        if callbacks:
            for callback in callbacks:
                callback.on_epoch_end(epoch, logs=epoch_logs)
    
        if verbose:
            epoch_time = time.time() - eopoch_start_time
            total_layers = len(model.layers)
            trainable_layer_count = sum(1 for layer in model.layers if layer.trainable)
            print(f"Epoch {epoch + 1:3.0f}:"
                f"  Train Loss: {current_train_loss:9.4e}"
                f",  Validation Loss: {current_val_loss:9.4e}"
                # f",  Trainable Layers ({trainable_layer_count}/{total_layers})"
                f",  Epoch Time: {epoch_time:.2f}s"  
                f",  Current Pruning Threshold: {current_pruning_threshold:.5g}")    
            
        if model.stop_training: # Stop training if all the layers are untrianable
            break   

        # Check for early stopping
        if current_train_loss < early_stopping_loss_threshold and current_pruning_threshold > early_stopping_pruning_threshold:
            print(f"Early stopping at epoch {epoch+1} as train loss {current_val_loss:.12f} is below the threshold {early_stopping_loss_threshold:.12f}")
            break


    # After the training loop ends
    training_time = time.time() - training_start_time
    print(f'Traininng Stopped. Time elapsed: {training_time:.2f}s')
    if callbacks:
        for callback in callbacks:
            callback.on_train_end(logs={'final_loss': current_train_loss, 'final_val_loss': current_val_loss})
    

    # Return the history containing training and validation losses
    return history

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.08 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 10
PRUNING_EPOCHS_PER_PERIOD = 30
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_schedule as ps

# Define the pruning schedule
pruning_schedule = ps.pruning_schedule_ramp(maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD, 
                                                    steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                                                    num_periods=N_PERIODS, 
                                                    #zero_percentage=0.10,
                                                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
callbacks = []

EARLY_STOPPING_LOSS_THRESHOLD = 1e-8   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.02

training_histories = []
weights_list = []
denominator_SREIENet_weights_list = []

# %%
#change 0 to a other number if you want to start training from other dimensions
for i in range(0, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    reinitialize_model_weights(model)
    output = training_output[:, i:i+1]

    history = SREINet_fit_w_pruning(
        model,                   # Model to train
        training_input,             # Input data for training
        output,                     # Output data for training
        batch_size=MINI_BATCH_SIZE, # Number of samples per gradient update
        validation_split=0.20,      # Fraction of the training data to be used as validation data
        epochs=round(NUM_EPOCHS),   # Number of times the entire training dataset is passed through the model
        optimizer=my_optimizer,     # Optimizer to use for training
        pruning_schedule = pruning_schedule, # Pruning schedule for gradually increasing the sparsity level
        loss_fn=loss_fn,            # Loss function to use for training
        data_type=MY_DATA_TYPE,     # Data type to use for training
        callbacks= callbacks,       # List of callbacks to apply during training
        early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,# Threshold for early stopping (Layer Based)
        early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD, # Threshold for early stopping (Pruning Based)
        verbose=1                   # Hide the epoch steps
    )
    
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([model.get_layer('SREINet').get_weights()])
    denominator_SREIENet_weights_list.append([model.get_layer('embedding_denominator_SREINet').get_weights()])
# Out:
# Training dimension 1...
# Epoch   1:  Train Loss: 5.4188e+06,  Validation Loss: 2.0648e+05,  Epoch Time: 0.24s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.8916e+05,  Validation Loss: 1.7501e+05,  Epoch Time: 0.05s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.6046e+05,  Validation Loss: 1.4955e+05,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.3714e+05,  Validation Loss: 1.2740e+05,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 1.1824e+05,  Validation Loss: 1.1105e+05,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 1.0284e+05,  Validation Loss: 9.5511e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 9.0590e+04,  Validation Loss: 8.5569e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 8.0039e+04,  Validation Loss: 7.5602e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch   9:  Train Loss: 7.1793e+04,  Validation Loss: 6.9217e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch  10:  Train Loss: 6.5045e+04,  Validation Loss: 6.2532e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch  11:  Train Loss: 5.9246e+04,  Validation Loss: 5.7289e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch  12:  Train Loss: 1.8679e+05,  Validation Loss: 7.1549e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch  13:  Train Loss: 4.3271e+03,  Validation Loss: 2.1402e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch  14:  Train Loss: 2.2858e+03,  Validation Loss: 2.4944e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch  15:  Train Loss: 2.2856e+03,  Validation Loss: 2.1816e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch  16:  Train Loss: 2.3068e+03,  Validation Loss: 2.4485e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch  17:  Train Loss: 2.2552e+03,  Validation Loss: 2.4332e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch  18:  Train Loss: 2.1781e+03,  Validation Loss: 1.9306e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch  19:  Train Loss: 8.6770e+05,  Validation Loss: 1.7896e+05,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch  20:  Train Loss: 1.3859e+05,  Validation Loss: 1.1860e+05,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch  21:  Train Loss: 1.0558e+05,  Validation Loss: 9.4633e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch  22:  Train Loss: 8.6450e+04,  Validation Loss: 7.9037e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch  23:  Train Loss: 7.3183e+04,  Validation Loss: 6.7884e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch  24:  Train Loss: 6.3122e+04,  Validation Loss: 5.8755e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch  25:  Train Loss: 5.5408e+04,  Validation Loss: 5.1868e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch  26:  Train Loss: 4.9145e+04,  Validation Loss: 4.6247e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch  27:  Train Loss: 4.3999e+04,  Validation Loss: 4.1479e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch  28:  Train Loss: 3.9614e+04,  Validation Loss: 3.7733e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  29:  Train Loss: 3.5847e+04,  Validation Loss: 3.4073e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  30:  Train Loss: 3.2648e+04,  Validation Loss: 3.1272e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  31:  Train Loss: 2.8941e+04,  Validation Loss: 2.6648e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 2.4563e+04,  Validation Loss: 2.2676e+04,  Epoch Time: 0.05s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 2.1265e+04,  Validation Loss: 1.9747e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 1.8684e+04,  Validation Loss: 1.7436e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 1.6627e+04,  Validation Loss: 1.5720e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 1.4945e+04,  Validation Loss: 1.4153e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 1.3496e+04,  Validation Loss: 1.2827e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 1.2314e+04,  Validation Loss: 1.1746e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch  39:  Train Loss: 1.3535e+04,  Validation Loss: 1.2940e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch  40:  Train Loss: 1.6236e+04,  Validation Loss: 1.5426e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch  41:  Train Loss: 1.5166e+04,  Validation Loss: 1.4359e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch  42:  Train Loss: 1.3936e+04,  Validation Loss: 1.3362e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch  43:  Train Loss: 1.2804e+04,  Validation Loss: 1.2236e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch  44:  Train Loss: 1.1722e+04,  Validation Loss: 1.1257e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch  45:  Train Loss: 1.0861e+04,  Validation Loss: 1.0427e+04,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch  46:  Train Loss: 9.9880e+03,  Validation Loss: 9.5067e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch  47:  Train Loss: 9.1969e+03,  Validation Loss: 8.7883e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch  48:  Train Loss: 8.5015e+03,  Validation Loss: 8.0174e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch  49:  Train Loss: 7.8179e+03,  Validation Loss: 7.4656e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch  50:  Train Loss: 7.2165e+03,  Validation Loss: 6.9589e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch  51:  Train Loss: 6.6262e+03,  Validation Loss: 6.3969e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch  52:  Train Loss: 6.0591e+03,  Validation Loss: 5.8407e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch  53:  Train Loss: 5.5841e+03,  Validation Loss: 5.3837e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch  54:  Train Loss: 5.1052e+03,  Validation Loss: 4.9029e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch  55:  Train Loss: 4.6804e+03,  Validation Loss: 4.5563e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch  56:  Train Loss: 4.2562e+03,  Validation Loss: 4.1151e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch  57:  Train Loss: 3.9069e+03,  Validation Loss: 3.6534e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch  58:  Train Loss: 3.5528e+03,  Validation Loss: 3.3648e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  59:  Train Loss: 3.2198e+03,  Validation Loss: 3.0693e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  60:  Train Loss: 2.9479e+03,  Validation Loss: 2.8173e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  61:  Train Loss: 2.6301e+03,  Validation Loss: 2.4641e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  62:  Train Loss: 2.3273e+03,  Validation Loss: 2.1755e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  63:  Train Loss: 2.0653e+03,  Validation Loss: 1.9623e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  64:  Train Loss: 1.8102e+03,  Validation Loss: 1.6865e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  65:  Train Loss: 1.6094e+03,  Validation Loss: 1.4692e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  66:  Train Loss: 1.4109e+03,  Validation Loss: 1.3348e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  67:  Train Loss: 1.2520e+03,  Validation Loss: 1.1196e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  68:  Train Loss: 1.2494e+03,  Validation Loss: 1.2026e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch  69:  Train Loss: 1.1036e+03,  Validation Loss: 1.0221e+03,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch  70:  Train Loss: 9.7678e+02,  Validation Loss: 9.0614e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch  71:  Train Loss: 8.5845e+02,  Validation Loss: 7.8400e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch  72:  Train Loss: 7.5441e+02,  Validation Loss: 7.1379e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch  73:  Train Loss: 6.5813e+02,  Validation Loss: 6.0048e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch  74:  Train Loss: 5.8238e+02,  Validation Loss: 5.2722e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch  75:  Train Loss: 5.0170e+02,  Validation Loss: 4.9109e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch  76:  Train Loss: 4.4249e+02,  Validation Loss: 3.9666e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch  77:  Train Loss: 3.8676e+02,  Validation Loss: 3.8301e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch  78:  Train Loss: 3.4355e+02,  Validation Loss: 3.0158e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch  79:  Train Loss: 2.9863e+02,  Validation Loss: 2.7551e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch  80:  Train Loss: 2.5361e+02,  Validation Loss: 2.2758e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch  81:  Train Loss: 2.3181e+02,  Validation Loss: 2.1914e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch  82:  Train Loss: 2.0383e+02,  Validation Loss: 1.8059e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch  83:  Train Loss: 1.8266e+02,  Validation Loss: 1.5548e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch  84:  Train Loss: 1.6041e+02,  Validation Loss: 1.4510e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch  85:  Train Loss: 1.4519e+02,  Validation Loss: 1.4345e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch  86:  Train Loss: 1.2823e+02,  Validation Loss: 1.3127e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch  87:  Train Loss: 1.2351e+02,  Validation Loss: 1.1189e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch  88:  Train Loss: 1.1747e+02,  Validation Loss: 8.7466e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  89:  Train Loss: 1.0507e+02,  Validation Loss: 1.0437e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  90:  Train Loss: 9.7152e+01,  Validation Loss: 1.0174e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  91:  Train Loss: 9.7154e+01,  Validation Loss: 8.1301e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  92:  Train Loss: 9.6481e+01,  Validation Loss: 8.7501e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  93:  Train Loss: 8.6927e+01,  Validation Loss: 7.8981e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  94:  Train Loss: 8.7219e+01,  Validation Loss: 8.0452e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  95:  Train Loss: 8.2330e+01,  Validation Loss: 9.1383e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  96:  Train Loss: 8.0186e+01,  Validation Loss: 8.0883e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  97:  Train Loss: 8.3537e+01,  Validation Loss: 9.1263e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  98:  Train Loss: 8.5860e+01,  Validation Loss: 6.4023e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch  99:  Train Loss: 8.0449e+01,  Validation Loss: 8.3629e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 100:  Train Loss: 8.1033e+01,  Validation Loss: 7.0070e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 101:  Train Loss: 8.0101e+01,  Validation Loss: 7.9615e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 102:  Train Loss: 8.0766e+01,  Validation Loss: 8.0509e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch 103:  Train Loss: 8.0900e+01,  Validation Loss: 7.4686e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 104:  Train Loss: 8.1886e+01,  Validation Loss: 7.9622e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 105:  Train Loss: 7.8834e+01,  Validation Loss: 6.6001e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 106:  Train Loss: 7.8148e+01,  Validation Loss: 7.5874e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 107:  Train Loss: 8.1038e+01,  Validation Loss: 7.9081e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 108:  Train Loss: 7.6154e+01,  Validation Loss: 8.6756e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 109:  Train Loss: 7.8949e+01,  Validation Loss: 7.7549e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 110:  Train Loss: 7.9077e+01,  Validation Loss: 7.9930e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 111:  Train Loss: 7.8944e+01,  Validation Loss: 7.7727e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 112:  Train Loss: 7.9913e+01,  Validation Loss: 8.3739e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 113:  Train Loss: 7.5149e+01,  Validation Loss: 7.1851e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 114:  Train Loss: 8.1551e+01,  Validation Loss: 8.0615e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 115:  Train Loss: 7.9855e+01,  Validation Loss: 8.0517e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 116:  Train Loss: 7.8339e+01,  Validation Loss: 7.0669e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 117:  Train Loss: 7.9538e+01,  Validation Loss: 6.9005e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 118:  Train Loss: 7.5498e+01,  Validation Loss: 6.9437e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 119:  Train Loss: 7.6956e+01,  Validation Loss: 6.5507e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 120:  Train Loss: 7.5941e+01,  Validation Loss: 8.5748e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 121:  Train Loss: 7.3628e+01,  Validation Loss: 6.6039e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 122:  Train Loss: 7.5489e+01,  Validation Loss: 8.0208e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 123:  Train Loss: 7.5415e+01,  Validation Loss: 6.6233e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 124:  Train Loss: 7.3993e+01,  Validation Loss: 7.9777e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 125:  Train Loss: 7.5153e+01,  Validation Loss: 7.8866e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 126:  Train Loss: 7.7599e+01,  Validation Loss: 6.8385e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 127:  Train Loss: 7.7088e+01,  Validation Loss: 8.1330e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 128:  Train Loss: 7.6522e+01,  Validation Loss: 7.0422e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 129:  Train Loss: 7.5559e+01,  Validation Loss: 7.2375e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 130:  Train Loss: 7.6124e+01,  Validation Loss: 7.4331e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 131:  Train Loss: 7.5938e+01,  Validation Loss: 8.1508e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 132:  Train Loss: 7.6267e+01,  Validation Loss: 8.6838e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch 133:  Train Loss: 7.2930e+01,  Validation Loss: 6.9616e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 134:  Train Loss: 7.3287e+01,  Validation Loss: 6.8127e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 135:  Train Loss: 7.3792e+01,  Validation Loss: 7.9850e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 136:  Train Loss: 7.2752e+01,  Validation Loss: 6.1376e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 137:  Train Loss: 7.3731e+01,  Validation Loss: 6.2976e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 138:  Train Loss: 7.7167e+01,  Validation Loss: 8.0159e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 139:  Train Loss: 7.5259e+01,  Validation Loss: 7.2746e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 140:  Train Loss: 6.9237e+01,  Validation Loss: 7.8881e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 141:  Train Loss: 7.6317e+01,  Validation Loss: 7.5108e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 142:  Train Loss: 7.2656e+01,  Validation Loss: 7.6611e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 143:  Train Loss: 7.2172e+01,  Validation Loss: 9.2052e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 144:  Train Loss: 7.2599e+01,  Validation Loss: 7.2277e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 145:  Train Loss: 7.0059e+01,  Validation Loss: 6.6949e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 146:  Train Loss: 7.5229e+01,  Validation Loss: 5.9932e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 147:  Train Loss: 7.0155e+01,  Validation Loss: 6.0585e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 148:  Train Loss: 6.8639e+01,  Validation Loss: 7.5772e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 149:  Train Loss: 7.1312e+01,  Validation Loss: 7.3465e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 150:  Train Loss: 7.2471e+01,  Validation Loss: 5.8312e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 151:  Train Loss: 7.3732e+01,  Validation Loss: 6.4207e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 152:  Train Loss: 7.3949e+01,  Validation Loss: 7.1127e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 153:  Train Loss: 7.2754e+01,  Validation Loss: 6.1891e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 154:  Train Loss: 6.8169e+01,  Validation Loss: 6.4708e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 155:  Train Loss: 7.0222e+01,  Validation Loss: 6.5704e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 156:  Train Loss: 6.6704e+01,  Validation Loss: 7.2440e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 157:  Train Loss: 6.8738e+01,  Validation Loss: 7.0814e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 158:  Train Loss: 6.6532e+01,  Validation Loss: 7.8769e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 159:  Train Loss: 7.2826e+01,  Validation Loss: 6.4612e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 160:  Train Loss: 7.2641e+01,  Validation Loss: 6.3700e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 161:  Train Loss: 6.6646e+01,  Validation Loss: 6.5302e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 162:  Train Loss: 6.8605e+01,  Validation Loss: 6.9509e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch 163:  Train Loss: 6.9018e+01,  Validation Loss: 6.3583e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 164:  Train Loss: 6.9086e+01,  Validation Loss: 5.8068e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 165:  Train Loss: 6.7926e+01,  Validation Loss: 6.4424e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 166:  Train Loss: 6.8167e+01,  Validation Loss: 5.7828e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 167:  Train Loss: 6.7581e+01,  Validation Loss: 6.4438e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 168:  Train Loss: 6.9309e+01,  Validation Loss: 6.4045e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 169:  Train Loss: 6.4025e+01,  Validation Loss: 6.9575e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 170:  Train Loss: 6.2320e+01,  Validation Loss: 5.4176e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 171:  Train Loss: 6.8678e+01,  Validation Loss: 7.0764e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 172:  Train Loss: 6.6443e+01,  Validation Loss: 6.9972e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 173:  Train Loss: 6.1795e+01,  Validation Loss: 6.4763e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 174:  Train Loss: 6.5974e+01,  Validation Loss: 5.2880e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 175:  Train Loss: 6.3318e+01,  Validation Loss: 6.0692e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 176:  Train Loss: 6.4164e+01,  Validation Loss: 6.3878e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 177:  Train Loss: 6.2360e+01,  Validation Loss: 7.1010e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 178:  Train Loss: 6.2936e+01,  Validation Loss: 6.4767e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 179:  Train Loss: 6.4525e+01,  Validation Loss: 6.8028e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 180:  Train Loss: 6.4360e+01,  Validation Loss: 7.3382e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 181:  Train Loss: 6.0123e+01,  Validation Loss: 5.8252e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 182:  Train Loss: 6.3036e+01,  Validation Loss: 5.0790e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 183:  Train Loss: 6.0526e+01,  Validation Loss: 5.7606e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 184:  Train Loss: 5.8269e+01,  Validation Loss: 6.7538e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 185:  Train Loss: 5.7335e+01,  Validation Loss: 5.4857e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 186:  Train Loss: 5.8071e+01,  Validation Loss: 4.9407e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 187:  Train Loss: 5.6162e+01,  Validation Loss: 6.2282e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 188:  Train Loss: 5.8152e+01,  Validation Loss: 5.9902e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 189:  Train Loss: 5.5710e+01,  Validation Loss: 6.6039e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 190:  Train Loss: 5.8634e+01,  Validation Loss: 6.0021e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 191:  Train Loss: 5.6433e+01,  Validation Loss: 4.1825e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 192:  Train Loss: 5.6878e+01,  Validation Loss: 4.5179e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch 193:  Train Loss: 5.5686e+01,  Validation Loss: 5.3858e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 194:  Train Loss: 5.5760e+01,  Validation Loss: 5.2983e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 195:  Train Loss: 5.7120e+01,  Validation Loss: 5.0818e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 196:  Train Loss: 5.5596e+01,  Validation Loss: 4.9291e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 197:  Train Loss: 5.6322e+01,  Validation Loss: 5.2294e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 198:  Train Loss: 5.7840e+01,  Validation Loss: 4.5775e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 199:  Train Loss: 5.4408e+01,  Validation Loss: 6.6678e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 200:  Train Loss: 5.5029e+01,  Validation Loss: 6.3795e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 201:  Train Loss: 5.2976e+01,  Validation Loss: 4.4610e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 202:  Train Loss: 5.1031e+01,  Validation Loss: 5.0632e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 203:  Train Loss: 5.1663e+01,  Validation Loss: 5.4810e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 204:  Train Loss: 5.2051e+01,  Validation Loss: 4.3450e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 205:  Train Loss: 5.2091e+01,  Validation Loss: 4.5878e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 206:  Train Loss: 4.9088e+01,  Validation Loss: 5.4316e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 207:  Train Loss: 5.0749e+01,  Validation Loss: 4.0822e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 208:  Train Loss: 5.0998e+01,  Validation Loss: 5.8231e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 209:  Train Loss: 4.9501e+01,  Validation Loss: 5.1761e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 210:  Train Loss: 4.9730e+01,  Validation Loss: 5.2613e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 211:  Train Loss: 4.5070e+01,  Validation Loss: 5.1359e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 212:  Train Loss: 4.7086e+01,  Validation Loss: 4.1350e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 213:  Train Loss: 4.6862e+01,  Validation Loss: 4.8600e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 214:  Train Loss: 4.5785e+01,  Validation Loss: 4.5864e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 215:  Train Loss: 4.4507e+01,  Validation Loss: 3.1715e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 216:  Train Loss: 4.2838e+01,  Validation Loss: 3.6150e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 217:  Train Loss: 4.1719e+01,  Validation Loss: 3.3330e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 218:  Train Loss: 4.3402e+01,  Validation Loss: 4.4895e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 219:  Train Loss: 4.2764e+01,  Validation Loss: 5.1438e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 220:  Train Loss: 4.3837e+01,  Validation Loss: 4.6008e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 221:  Train Loss: 4.2192e+01,  Validation Loss: 3.3059e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 222:  Train Loss: 4.0026e+01,  Validation Loss: 3.8246e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch 223:  Train Loss: 4.0755e+01,  Validation Loss: 4.2740e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 224:  Train Loss: 3.8907e+01,  Validation Loss: 3.6004e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 225:  Train Loss: 3.9365e+01,  Validation Loss: 4.5783e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 226:  Train Loss: 3.7485e+01,  Validation Loss: 4.1563e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 227:  Train Loss: 4.1693e+01,  Validation Loss: 3.6512e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 228:  Train Loss: 4.0187e+01,  Validation Loss: 3.5585e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 229:  Train Loss: 3.9088e+01,  Validation Loss: 3.8956e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 230:  Train Loss: 3.7934e+01,  Validation Loss: 3.9474e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 231:  Train Loss: 3.5889e+01,  Validation Loss: 3.7520e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 232:  Train Loss: 3.7867e+01,  Validation Loss: 3.5999e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 233:  Train Loss: 3.5480e+01,  Validation Loss: 3.6896e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 234:  Train Loss: 3.6856e+01,  Validation Loss: 3.3623e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 235:  Train Loss: 3.6651e+01,  Validation Loss: 3.1780e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 236:  Train Loss: 3.3797e+01,  Validation Loss: 3.0354e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 237:  Train Loss: 3.5562e+01,  Validation Loss: 3.1073e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 238:  Train Loss: 3.2324e+01,  Validation Loss: 2.8126e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 239:  Train Loss: 3.3081e+01,  Validation Loss: 3.2165e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 240:  Train Loss: 3.1791e+01,  Validation Loss: 2.9662e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 241:  Train Loss: 3.2086e+01,  Validation Loss: 3.3702e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 242:  Train Loss: 3.0943e+01,  Validation Loss: 3.1915e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 243:  Train Loss: 2.9645e+01,  Validation Loss: 2.5224e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 244:  Train Loss: 2.7644e+01,  Validation Loss: 3.1469e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 245:  Train Loss: 2.5857e+01,  Validation Loss: 2.5649e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 246:  Train Loss: 2.6051e+01,  Validation Loss: 2.2504e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 247:  Train Loss: 2.5324e+01,  Validation Loss: 2.3559e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 248:  Train Loss: 2.6070e+01,  Validation Loss: 2.1542e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 249:  Train Loss: 2.7209e+01,  Validation Loss: 2.2827e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 250:  Train Loss: 2.7178e+01,  Validation Loss: 2.4282e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 251:  Train Loss: 2.5385e+01,  Validation Loss: 2.5802e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 252:  Train Loss: 2.3696e+01,  Validation Loss: 2.3702e+01,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.010678
# Epoch 253:  Train Loss: 2.3157e+01,  Validation Loss: 2.1221e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 254:  Train Loss: 2.4057e+01,  Validation Loss: 1.9420e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 255:  Train Loss: 2.2675e+01,  Validation Loss: 2.2392e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 256:  Train Loss: 2.1639e+01,  Validation Loss: 2.5031e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 257:  Train Loss: 2.1351e+01,  Validation Loss: 1.9675e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 258:  Train Loss: 2.1447e+01,  Validation Loss: 1.8336e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 259:  Train Loss: 1.9177e+01,  Validation Loss: 1.8390e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 260:  Train Loss: 1.9423e+01,  Validation Loss: 1.9384e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 261:  Train Loss: 1.9771e+01,  Validation Loss: 1.7910e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 262:  Train Loss: 1.8825e+01,  Validation Loss: 1.8523e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 263:  Train Loss: 1.8708e+01,  Validation Loss: 1.8625e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 264:  Train Loss: 1.7602e+01,  Validation Loss: 1.7587e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 265:  Train Loss: 1.7005e+01,  Validation Loss: 1.7183e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 266:  Train Loss: 1.6928e+01,  Validation Loss: 1.8428e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 267:  Train Loss: 1.6198e+01,  Validation Loss: 1.4802e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 268:  Train Loss: 1.6097e+01,  Validation Loss: 1.2236e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 269:  Train Loss: 1.6312e+01,  Validation Loss: 1.2922e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 270:  Train Loss: 1.4977e+01,  Validation Loss: 1.4174e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 271:  Train Loss: 1.3949e+01,  Validation Loss: 1.3300e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 272:  Train Loss: 1.3979e+01,  Validation Loss: 1.7240e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 273:  Train Loss: 1.3772e+01,  Validation Loss: 1.0874e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 274:  Train Loss: 1.2828e+01,  Validation Loss: 1.2639e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 275:  Train Loss: 1.2648e+01,  Validation Loss: 1.3662e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 276:  Train Loss: 1.1901e+01,  Validation Loss: 1.1101e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 277:  Train Loss: 1.1888e+01,  Validation Loss: 1.1948e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 278:  Train Loss: 1.2568e+01,  Validation Loss: 1.3696e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 279:  Train Loss: 1.1355e+01,  Validation Loss: 8.8678e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 280:  Train Loss: 1.1130e+01,  Validation Loss: 9.3456e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 281:  Train Loss: 1.1670e+01,  Validation Loss: 1.1483e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 282:  Train Loss: 1.0453e+01,  Validation Loss: 1.0697e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch 283:  Train Loss: 1.0543e+01,  Validation Loss: 9.2133e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 284:  Train Loss: 1.0387e+01,  Validation Loss: 1.1174e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 285:  Train Loss: 9.9263e+00,  Validation Loss: 8.7416e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 286:  Train Loss: 9.4444e+00,  Validation Loss: 7.1028e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 287:  Train Loss: 9.1976e+00,  Validation Loss: 7.7230e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 288:  Train Loss: 8.7668e+00,  Validation Loss: 7.6954e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 289:  Train Loss: 8.6475e+00,  Validation Loss: 7.1853e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 290:  Train Loss: 8.2462e+00,  Validation Loss: 7.6445e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 291:  Train Loss: 8.1700e+00,  Validation Loss: 1.0802e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 292:  Train Loss: 7.8056e+00,  Validation Loss: 6.6084e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 293:  Train Loss: 7.6528e+00,  Validation Loss: 7.2320e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 294:  Train Loss: 6.9752e+00,  Validation Loss: 6.4506e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 295:  Train Loss: 6.9973e+00,  Validation Loss: 6.4220e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 296:  Train Loss: 6.6738e+00,  Validation Loss: 5.7882e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 297:  Train Loss: 6.6916e+00,  Validation Loss: 6.9007e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 298:  Train Loss: 6.4394e+00,  Validation Loss: 5.8373e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 299:  Train Loss: 6.1178e+00,  Validation Loss: 4.7517e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 300:  Train Loss: 5.5022e+00,  Validation Loss: 6.6227e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Traininng Stopped. Time elapsed: 12.90s
# Training dimension 2...
# Epoch   1:  Train Loss: 1.0102e+04,  Validation Loss: 1.4894e+02,  Epoch Time: 0.14s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.3918e+02,  Validation Loss: 1.3034e+02,  Epoch Time: 0.05s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 1.2443e+02,  Validation Loss: 1.1741e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.1312e+02,  Validation Loss: 1.0753e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 1.0294e+02,  Validation Loss: 9.8672e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 9.3420e+01,  Validation Loss: 8.8859e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 8.5001e+01,  Validation Loss: 8.2242e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 7.7367e+01,  Validation Loss: 7.4617e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch   9:  Train Loss: 7.0813e+01,  Validation Loss: 6.7294e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch  10:  Train Loss: 6.4542e+01,  Validation Loss: 6.4090e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch  11:  Train Loss: 5.8513e+01,  Validation Loss: 5.6870e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch  12:  Train Loss: 5.4433e+01,  Validation Loss: 4.8486e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch  13:  Train Loss: 4.8709e+01,  Validation Loss: 4.5745e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch  14:  Train Loss: 4.4319e+01,  Validation Loss: 4.1302e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch  15:  Train Loss: 4.0589e+01,  Validation Loss: 3.9946e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch  16:  Train Loss: 1.6743e+01,  Validation Loss: 1.5333e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch  17:  Train Loss: 5.3304e+02,  Validation Loss: 3.2161e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch  18:  Train Loss: 2.1939e+02,  Validation Loss: 1.3129e+02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch  19:  Train Loss: 9.1274e+01,  Validation Loss: 5.6801e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch  20:  Train Loss: 4.4423e+01,  Validation Loss: 3.1690e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch  21:  Train Loss: 2.8730e+01,  Validation Loss: 2.5748e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch  22:  Train Loss: 2.2710e+01,  Validation Loss: 2.1678e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch  23:  Train Loss: 2.1035e+01,  Validation Loss: 1.7570e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch  24:  Train Loss: 2.0320e+01,  Validation Loss: 2.1053e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch  25:  Train Loss: 1.9310e+01,  Validation Loss: 1.7552e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch  26:  Train Loss: 1.8259e+01,  Validation Loss: 1.8282e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch  27:  Train Loss: 1.8364e+01,  Validation Loss: 1.7075e+01,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.079553
# Epoch  28:  Train Loss: 1.7256e+01,  Validation Loss: 1.7893e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  29:  Train Loss: 1.6956e+01,  Validation Loss: 1.5436e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  30:  Train Loss: 1.6116e+01,  Validation Loss: 1.5763e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  31:  Train Loss: 1.6548e+01,  Validation Loss: 1.4903e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  32:  Train Loss: 1.5260e+01,  Validation Loss: 1.6686e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  33:  Train Loss: 1.4800e+01,  Validation Loss: 1.2782e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  34:  Train Loss: 1.4192e+01,  Validation Loss: 1.5537e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  35:  Train Loss: 1.3105e+01,  Validation Loss: 1.4594e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  36:  Train Loss: 1.2300e+01,  Validation Loss: 1.3778e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  37:  Train Loss: 1.2586e+01,  Validation Loss: 1.1796e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  38:  Train Loss: 1.3216e+01,  Validation Loss: 1.2835e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch  39:  Train Loss: 1.3404e+01,  Validation Loss: 1.4556e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch  40:  Train Loss: 1.2767e+01,  Validation Loss: 1.3326e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch  41:  Train Loss: 1.2619e+01,  Validation Loss: 1.2161e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch  42:  Train Loss: 1.2478e+01,  Validation Loss: 1.1486e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch  43:  Train Loss: 1.1985e+01,  Validation Loss: 1.1549e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch  44:  Train Loss: 1.1285e+01,  Validation Loss: 1.1256e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch  45:  Train Loss: 1.1864e+01,  Validation Loss: 1.0976e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch  46:  Train Loss: 1.0692e+01,  Validation Loss: 9.6102e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch  47:  Train Loss: 1.0680e+01,  Validation Loss: 9.8140e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch  48:  Train Loss: 9.8797e+00,  Validation Loss: 8.3719e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch  49:  Train Loss: 1.0445e+01,  Validation Loss: 1.0192e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch  50:  Train Loss: 1.0158e+01,  Validation Loss: 8.0872e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch  51:  Train Loss: 9.8350e+00,  Validation Loss: 1.1414e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch  52:  Train Loss: 9.6451e+00,  Validation Loss: 9.5912e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch  53:  Train Loss: 8.9098e+00,  Validation Loss: 9.5975e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch  54:  Train Loss: 8.2501e+00,  Validation Loss: 8.6026e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch  55:  Train Loss: 8.3627e+00,  Validation Loss: 8.7256e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch  56:  Train Loss: 8.4613e+00,  Validation Loss: 6.8168e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch  57:  Train Loss: 7.9774e+00,  Validation Loss: 1.0138e+01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch  58:  Train Loss: 7.7070e+00,  Validation Loss: 8.3290e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  59:  Train Loss: 7.4541e+00,  Validation Loss: 6.7179e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  60:  Train Loss: 7.2227e+00,  Validation Loss: 6.7235e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  61:  Train Loss: 6.7891e+00,  Validation Loss: 5.6657e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  62:  Train Loss: 6.5200e+00,  Validation Loss: 7.2486e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  63:  Train Loss: 6.0543e+00,  Validation Loss: 5.7329e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  64:  Train Loss: 5.9806e+00,  Validation Loss: 6.0643e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  65:  Train Loss: 5.5735e+00,  Validation Loss: 5.1680e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  66:  Train Loss: 5.4714e+00,  Validation Loss: 5.4936e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  67:  Train Loss: 5.0196e+00,  Validation Loss: 4.9881e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  68:  Train Loss: 5.4594e+00,  Validation Loss: 5.5550e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch  69:  Train Loss: 5.7848e+00,  Validation Loss: 5.3425e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch  70:  Train Loss: 5.3153e+00,  Validation Loss: 4.9976e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch  71:  Train Loss: 5.1033e+00,  Validation Loss: 6.2947e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch  72:  Train Loss: 5.0406e+00,  Validation Loss: 3.7256e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch  73:  Train Loss: 4.9088e+00,  Validation Loss: 4.2951e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch  74:  Train Loss: 4.8972e+00,  Validation Loss: 4.9314e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch  75:  Train Loss: 4.4611e+00,  Validation Loss: 4.8389e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch  76:  Train Loss: 4.7597e+00,  Validation Loss: 3.0810e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch  77:  Train Loss: 4.4249e+00,  Validation Loss: 4.8996e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch  78:  Train Loss: 4.5061e+00,  Validation Loss: 4.8693e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch  79:  Train Loss: 4.1195e+00,  Validation Loss: 3.9932e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch  80:  Train Loss: 4.1807e+00,  Validation Loss: 4.1789e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch  81:  Train Loss: 3.9819e+00,  Validation Loss: 3.5163e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch  82:  Train Loss: 4.1102e+00,  Validation Loss: 3.0015e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch  83:  Train Loss: 3.9943e+00,  Validation Loss: 3.6929e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch  84:  Train Loss: 3.7985e+00,  Validation Loss: 3.9704e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch  85:  Train Loss: 3.8520e+00,  Validation Loss: 4.8408e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch  86:  Train Loss: 3.5264e+00,  Validation Loss: 3.6919e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch  87:  Train Loss: 3.8431e+00,  Validation Loss: 3.4935e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch  88:  Train Loss: 3.5618e+00,  Validation Loss: 3.6965e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  89:  Train Loss: 3.4541e+00,  Validation Loss: 3.1848e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.08
# Epoch  90:  Train Loss: 3.5458e+00,  Validation Loss: 3.6154e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch  91:  Train Loss: 3.3669e+00,  Validation Loss: 3.7192e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  92:  Train Loss: 3.3454e+00,  Validation Loss: 3.3120e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  93:  Train Loss: 3.3003e+00,  Validation Loss: 3.0430e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  94:  Train Loss: 3.1422e+00,  Validation Loss: 3.1700e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  95:  Train Loss: 3.1954e+00,  Validation Loss: 3.5059e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  96:  Train Loss: 3.0204e+00,  Validation Loss: 3.1588e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch  97:  Train Loss: 2.9599e+00,  Validation Loss: 2.9827e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# ...
# Epoch 169:  Train Loss: 1.4226e+00,  Validation Loss: 1.9211e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 170:  Train Loss: 1.4102e+00,  Validation Loss: 1.0804e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 171:  Train Loss: 1.4178e+00,  Validation Loss: 1.5496e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 172:  Train Loss: 1.4299e+00,  Validation Loss: 1.4655e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 173:  Train Loss: 1.3301e+00,  Validation Loss: 1.5407e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 174:  Train Loss: 1.2878e+00,  Validation Loss: 1.2864e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 175:  Train Loss: 1.3638e+00,  Validation Loss: 1.6324e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 176:  Train Loss: 1.3150e+00,  Validation Loss: 1.4618e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 177:  Train Loss: 1.2848e+00,  Validation Loss: 1.4895e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 178:  Train Loss: 1.2237e+00,  Validation Loss: 1.1169e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 179:  Train Loss: 1.2506e+00,  Validation Loss: 1.0711e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 180:  Train Loss: 1.2580e+00,  Validation Loss: 1.5305e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 181:  Train Loss: 1.2101e+00,  Validation Loss: 9.2191e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 182:  Train Loss: 1.1288e+00,  Validation Loss: 1.0654e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 183:  Train Loss: 1.1224e+00,  Validation Loss: 1.0749e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 184:  Train Loss: 1.0344e+00,  Validation Loss: 1.0538e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 185:  Train Loss: 1.0945e+00,  Validation Loss: 1.2277e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 186:  Train Loss: 1.0056e+00,  Validation Loss: 9.0432e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 187:  Train Loss: 9.7397e-01,  Validation Loss: 1.0958e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 188:  Train Loss: 1.0365e+00,  Validation Loss: 9.0091e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 189:  Train Loss: 1.0627e+00,  Validation Loss: 9.7173e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 190:  Train Loss: 1.1989e+00,  Validation Loss: 1.0444e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 191:  Train Loss: 1.0501e+00,  Validation Loss: 1.1532e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 192:  Train Loss: 1.0560e+00,  Validation Loss: 1.0242e+00,  Epoch Time: 0.05s,  Current Pruning Threshold: 0.010678
# Epoch 193:  Train Loss: 9.3545e-01,  Validation Loss: 9.9039e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 194:  Train Loss: 9.7177e-01,  Validation Loss: 9.4508e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 195:  Train Loss: 9.5496e-01,  Validation Loss: 9.6403e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 196:  Train Loss: 9.4362e-01,  Validation Loss: 9.7248e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 197:  Train Loss: 8.8812e-01,  Validation Loss: 1.0608e+00,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 198:  Train Loss: 8.4739e-01,  Validation Loss: 7.9417e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 199:  Train Loss: 8.9849e-01,  Validation Loss: 9.6402e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 200:  Train Loss: 8.5726e-01,  Validation Loss: 5.6273e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 201:  Train Loss: 8.4411e-01,  Validation Loss: 9.3039e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 202:  Train Loss: 7.8844e-01,  Validation Loss: 8.7517e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 203:  Train Loss: 8.3641e-01,  Validation Loss: 7.7629e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 204:  Train Loss: 8.0752e-01,  Validation Loss: 6.6522e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 205:  Train Loss: 8.1689e-01,  Validation Loss: 6.8384e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 206:  Train Loss: 7.9504e-01,  Validation Loss: 6.7967e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 207:  Train Loss: 7.8275e-01,  Validation Loss: 7.9441e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 208:  Train Loss: 7.3095e-01,  Validation Loss: 6.6359e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 209:  Train Loss: 6.8945e-01,  Validation Loss: 6.4262e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 210:  Train Loss: 6.9369e-01,  Validation Loss: 5.4589e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 211:  Train Loss: 6.6341e-01,  Validation Loss: 6.2226e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 212:  Train Loss: 6.6794e-01,  Validation Loss: 7.2163e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 213:  Train Loss: 6.4455e-01,  Validation Loss: 6.4061e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 214:  Train Loss: 6.3355e-01,  Validation Loss: 5.5722e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 215:  Train Loss: 6.0479e-01,  Validation Loss: 6.3546e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 216:  Train Loss: 6.0191e-01,  Validation Loss: 5.7769e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 217:  Train Loss: 5.1658e-01,  Validation Loss: 5.1097e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 218:  Train Loss: 5.1783e-01,  Validation Loss: 4.8748e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 219:  Train Loss: 5.5200e-01,  Validation Loss: 4.0873e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 220:  Train Loss: 6.8021e-01,  Validation Loss: 5.6504e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 221:  Train Loss: 5.8408e-01,  Validation Loss: 5.1487e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 222:  Train Loss: 5.4507e-01,  Validation Loss: 5.7039e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch 223:  Train Loss: 5.1498e-01,  Validation Loss: 5.1224e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 224:  Train Loss: 5.4673e-01,  Validation Loss: 5.0641e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 225:  Train Loss: 5.1973e-01,  Validation Loss: 5.1037e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 226:  Train Loss: 4.9253e-01,  Validation Loss: 5.6656e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 227:  Train Loss: 4.9570e-01,  Validation Loss: 5.6499e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 228:  Train Loss: 4.8832e-01,  Validation Loss: 4.7569e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 229:  Train Loss: 4.5373e-01,  Validation Loss: 3.6440e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 230:  Train Loss: 4.5490e-01,  Validation Loss: 3.5140e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 231:  Train Loss: 4.2502e-01,  Validation Loss: 3.5528e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 232:  Train Loss: 4.3673e-01,  Validation Loss: 4.0595e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 233:  Train Loss: 4.2092e-01,  Validation Loss: 4.3162e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 234:  Train Loss: 4.0720e-01,  Validation Loss: 4.2851e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 235:  Train Loss: 4.0112e-01,  Validation Loss: 3.6759e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 236:  Train Loss: 4.0461e-01,  Validation Loss: 3.9023e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 237:  Train Loss: 3.6803e-01,  Validation Loss: 3.5358e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 238:  Train Loss: 3.7969e-01,  Validation Loss: 3.9800e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 239:  Train Loss: 3.7769e-01,  Validation Loss: 3.5557e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 240:  Train Loss: 3.6535e-01,  Validation Loss: 3.4572e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 241:  Train Loss: 3.5415e-01,  Validation Loss: 3.5558e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 242:  Train Loss: 3.5197e-01,  Validation Loss: 3.4520e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 243:  Train Loss: 3.1546e-01,  Validation Loss: 2.8664e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 244:  Train Loss: 3.2639e-01,  Validation Loss: 3.1750e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 245:  Train Loss: 3.1858e-01,  Validation Loss: 3.2769e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 246:  Train Loss: 2.9152e-01,  Validation Loss: 2.5942e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 247:  Train Loss: 2.7344e-01,  Validation Loss: 3.3004e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 248:  Train Loss: 2.7143e-01,  Validation Loss: 2.2106e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 249:  Train Loss: 2.8102e-01,  Validation Loss: 2.5861e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 250:  Train Loss: 3.8463e-01,  Validation Loss: 3.1734e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 251:  Train Loss: 2.7136e-01,  Validation Loss: 2.3851e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 252:  Train Loss: 2.6027e-01,  Validation Loss: 2.8367e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch 253:  Train Loss: 2.4575e-01,  Validation Loss: 2.6003e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 254:  Train Loss: 2.4625e-01,  Validation Loss: 2.4210e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 255:  Train Loss: 2.4176e-01,  Validation Loss: 2.7165e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 256:  Train Loss: 2.2355e-01,  Validation Loss: 2.0623e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 257:  Train Loss: 2.1672e-01,  Validation Loss: 2.8214e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 258:  Train Loss: 2.1970e-01,  Validation Loss: 1.5678e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 259:  Train Loss: 2.1347e-01,  Validation Loss: 1.8540e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 260:  Train Loss: 1.9252e-01,  Validation Loss: 2.3268e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 261:  Train Loss: 2.0423e-01,  Validation Loss: 1.7127e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 262:  Train Loss: 1.9605e-01,  Validation Loss: 2.2565e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 263:  Train Loss: 1.9403e-01,  Validation Loss: 1.9340e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 264:  Train Loss: 1.8147e-01,  Validation Loss: 1.9730e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 265:  Train Loss: 1.7894e-01,  Validation Loss: 1.7686e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 266:  Train Loss: 1.6991e-01,  Validation Loss: 1.4577e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 267:  Train Loss: 1.6954e-01,  Validation Loss: 1.3772e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 268:  Train Loss: 1.6442e-01,  Validation Loss: 1.5325e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 269:  Train Loss: 1.6576e-01,  Validation Loss: 1.7867e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 270:  Train Loss: 1.6071e-01,  Validation Loss: 1.4997e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 271:  Train Loss: 1.5058e-01,  Validation Loss: 1.5657e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 272:  Train Loss: 1.4448e-01,  Validation Loss: 1.8250e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 273:  Train Loss: 1.2412e-01,  Validation Loss: 1.2471e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 274:  Train Loss: 1.2040e-01,  Validation Loss: 1.1001e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 275:  Train Loss: 1.2253e-01,  Validation Loss: 1.0736e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 276:  Train Loss: 1.1896e-01,  Validation Loss: 1.2268e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 277:  Train Loss: 1.1057e-01,  Validation Loss: 1.2216e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0
# Epoch 278:  Train Loss: 1.0588e-01,  Validation Loss: 1.1306e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.00044677
# Epoch 279:  Train Loss: 1.1501e-01,  Validation Loss: 1.3758e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0017771
# Epoch 280:  Train Loss: 1.4963e-01,  Validation Loss: 1.2035e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0039612
# Epoch 281:  Train Loss: 1.0704e-01,  Validation Loss: 9.7606e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.0069504
# Epoch 282:  Train Loss: 1.1095e-01,  Validation Loss: 8.1073e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.010678
# Epoch 283:  Train Loss: 1.0584e-01,  Validation Loss: 1.0744e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.01506
# Epoch 284:  Train Loss: 1.0070e-01,  Validation Loss: 8.2330e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.02
# Epoch 285:  Train Loss: 1.0134e-01,  Validation Loss: 1.0179e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.025386
# Epoch 286:  Train Loss: 8.5639e-02,  Validation Loss: 9.0958e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.031099
# Epoch 287:  Train Loss: 9.1331e-02,  Validation Loss: 5.5340e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.037011
# Epoch 288:  Train Loss: 8.0506e-02,  Validation Loss: 1.0270e-01,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.042989
# Epoch 289:  Train Loss: 8.2204e-02,  Validation Loss: 9.5466e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.048901
# Epoch 290:  Train Loss: 8.1843e-02,  Validation Loss: 7.4977e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.054614
# Epoch 291:  Train Loss: 7.6033e-02,  Validation Loss: 7.5561e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06
# Epoch 292:  Train Loss: 7.9496e-02,  Validation Loss: 5.5751e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.06494
# Epoch 293:  Train Loss: 7.3408e-02,  Validation Loss: 6.5025e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.069322
# Epoch 294:  Train Loss: 6.9302e-02,  Validation Loss: 7.0845e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.07305
# Epoch 295:  Train Loss: 7.1204e-02,  Validation Loss: 7.5791e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.076039
# Epoch 296:  Train Loss: 6.7212e-02,  Validation Loss: 6.7262e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.078223
# Epoch 297:  Train Loss: 6.4959e-02,  Validation Loss: 6.2075e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.079553
# Epoch 298:  Train Loss: 6.2916e-02,  Validation Loss: 5.1906e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 299:  Train Loss: 6.3702e-02,  Validation Loss: 4.6777e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Epoch 300:  Train Loss: 5.9564e-02,  Validation Loss: 6.0142e-02,  Epoch Time: 0.04s,  Current Pruning Threshold: 0.08
# Traininng Stopped. Time elapsed: 12.78s

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_set_labels(N):
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
def coefficient_reconstruction(dim_index,
                                weights, 
                                minimum_coefficient_threshold = 1e-5,
                                coefficient_output_digits = 10, 
                                enable_coefficient_sorting = False):
    
    max_neurons = max(max(len(layer) for layer in SREINet) for SREINet in weights)
    
    labels = generate_set_labels(max_neurons - 1) # number of states = number of neurons - 1

    def explore_path(SREINet_index, layer, neuron, weight_product, label_counts, non_zero_paths):
        """
        Recursively explores non-zero paths in a neural network.
        """
        if layer == len(weights[SREINet_index]) - 1:
            non_zero_paths.append((label_counts, weight_product))
            return

        for next_neuron, weight in enumerate(weights[SREINet_index][layer][neuron]):
            if abs(weight) <= 1e-15:
                # Skip recursion if the weight is zero (if one weight is zero, the whole path will be eliminated)
                continue  
            new_weight_product = weight_product * weight
            next_label_counts = label_counts.copy()
            next_label_counts[labels[next_neuron]] = next_label_counts.get(labels[next_neuron], 0) + 1
            explore_path(SREINet_index, layer + 1, next_neuron, new_weight_product, next_label_counts, non_zero_paths)
    
    #beginning of the algorithm
    all_SREINet_products = []
    for SREINet_index, _ in enumerate(weights):
        non_zero_paths = []
        #collect all non-zero paths
        for neuron_index in range(len(weights[SREINet_index][0])):
            label_counts = {labels[neuron_index]: 1}
            explore_path(SREINet_index, 0, neuron_index, 1, label_counts, non_zero_paths)
        
        #sum up the products with identical composite nonlinear/linear terms
        SREINet_products = {}
        for label_counts, weight_product in non_zero_paths:
            label_counts_key = frozenset(label_counts.items())
            if label_counts_key in SREINet_products:
                SREINet_products[label_counts_key] += weight_product
            else:
                SREINet_products[label_counts_key] = weight_product
        
        #remove the negligible composite terms
        SREINet_products = {k: v for k, v in SREINet_products.items() if abs(v) >= minimum_coefficient_threshold}
        
        if enable_coefficient_sorting:
            #sort the composite terms by their absolute values
            sorted_SREINet_products = dict(sorted(SREINet_products.items(), key=lambda item: abs(item[1]), reverse=True))
        else:
            sorted_SREINet_products = SREINet_products

        all_SREINet_products.append(sorted_SREINet_products)

    #output formatting
    labeled_all_SREINet_products = []
    for SREINet_index, sorted_SREINet_products in enumerate(all_SREINet_products):
        SREINet_product_strings = []
        for key, value in sorted_SREINet_products.items():
            labels_list = []
            only_constant = len(key) == 1 and any(label == 'Constant' for label, _ in key)
            
            for label, count in sorted(key):
                if label == 'Constant' and len(key) > 1:
                    continue
                if label != 'Constant' and count > 1:
                    labels_list.append(f"{label}^{count}")
                elif label == 'Constant' or count == 1:
                    labels_list.append(label if label != 'Constant' else '')
            
            label_str = '*'.join(filter(None, labels_list))
                        
            # Apply coefficient threshold if enabled
            formatted_value = f"{abs(value):.{coefficient_output_digits}g}"

            term_str = label_str if formatted_value == '1' else f"{formatted_value}*{label_str}" if not only_constant else formatted_value if formatted_value != '1' else ''
            sign = '+' if value >= 0 else '-'
            if SREINet_product_strings or value < 0:
                term_str = f" {sign} {term_str}"
            else:
                term_str = term_str
            SREINet_product_strings.append(term_str)

        formatted_output = ''.join(SREINet_product_strings)
        layer_prefix = f"(x{SREINet_index+dim_index+1})'= "
        full_output = layer_prefix + formatted_output
        labeled_all_SREINet_products.append(full_output)

    return labeled_all_SREINet_products

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
for i in range(len(weights_list)):
    path_products = coefficient_reconstruction(i,weights_list[i], 
                                            minimum_coefficient_threshold = 1e-2,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
# Out:
# (x1)'= 0.3245450186 - 1.060479721*x1 + 0.6229989215*x2 + 0.67655879*x3 - 1.662546056*x1^2 + 0.5925032027*x1*x2 + 0.07496467594*x1*x3 + 0.424842032*x2^2 + 0.3387101459*x2*x3 - 0.9073136208*x1^3 + 1.219957536*x1^2*x2 + 0.1202371041*x1^2*x3 + 3.308343784*x1*x2^2 - 0.4165974614*x1*x2*x3 - 0.103467363*x2^2*x3 + 0.1218319813*x3^2 - 0.09974241756*x2*x3^2
# (x2)'= 0.283173875 - 1.374702786*x1 + 0.5584612842*x2 + 0.8101442894*x3 + 0.5053963244*x1^2 - 0.1613756571*x1*x2 + 0.283213134*x1*x3 + 0.4146272002*x2^2 - 0.2293336024*x2*x3 + 0.5326824094*x1^3 - 2.458399238*x1^2*x2 + 0.06905461148*x1^2*x3 + 4.634131325*x1*x2^2 - 0.4579755338*x1*x2*x3 - 0.1941041521*x2^3 - 0.4127302569*x2^2*x3 + 0.09785995434*x3^2 - 0.1027192322*x2*x3^2

# %%
denominator_SREIENet_weights_list[1]
# Out:
# [[array([[-0.05333758],
#          [-0.        ],
#          [-0.        ]], dtype=float32)]]

# %%
for i in range(len(denominator_SREIENet_weights_list)):
    path_products = coefficient_reconstruction(i,denominator_SREIENet_weights_list[i], 
                                            minimum_coefficient_threshold = 0,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
# Out:
# (x1)'=  + x1 + x2
# (x2)'=  + x1 + x2

# %% [markdown]
# ### **Validation**

# %%
import matplotlib.pyplot as plt

# validation: need to draw the output of each dimension independently
dim_to_plot = 1
index = dim_to_plot - 1

#Form NN predictions
NN_output = np.zeros((dx_train.shape[0], dx_train.shape[1]))
for i, weight in enumerate(weights_list):
    model.get_layer('SREINet').set_weights(weight[0])
    output = model.predict(training_input_for_sim)
    NN_output[:,i:i+1] = output


#validate the first trajoctory if there are many
plt.plot(t_arr, NN_output[:,index][:t_arr.shape[0]], 'r', label='NN Prediction')
plt.plot(t_arr, dx_train[:,index][:t_arr.shape[0]], 'k', label='Expected Output')


#pick the last point of the simulation output and use it as the initial condition for the next simulation
x0 = x_train[:t_arr.shape[0]][-1]
t0= t_arr[-1]
myDG = DG.DataGenerator(x0,T=data_T+t0, dt=data_dt, t0=t0)
new_t_arr, new_x, new_dx, guessed_multiplicative_order = myDG.generate_dataset_by_model_name(MY_MODEL)

new_input = new_x

new_NN_output= np.zeros((new_dx.shape[0], new_dx.shape[1]))
for i, weight in enumerate(weights_list):
    model.get_layer('SREINet').set_weights(weight[0])
    output = model.predict(new_input)
    new_NN_output[:,i:i+1] = output


#new_NN_output = model.predict(new_input)
plt.plot(new_t_arr, new_NN_output[:,index], "r--", label='NN Prediction')
plt.plot(new_t_arr, new_dx[:,index], "k--", label='Expected Output')
plt.title("Response of dimension " + str(dim_to_plot))
plt.show()
# Out:
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 189us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 173us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 173us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 174us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 190us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 189us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 171us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 167us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 176us/step
# 1875/1875 [==============================] - 0s 170us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 169us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 168us/step
# 1875/1875 [==============================] - 0s 169us/step
# 313/313 [==============================] - 0s 182us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 182us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 176us/step
# 313/313 [==============================] - 0s 177us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 180us/step
# 313/313 [==============================] - 0s 182us/step
# 313/313 [==============================] - 0s 179us/step
# 313/313 [==============================] - 0s 178us/step
# 313/313 [==============================] - 0s 181us/step
# 313/313 [==============================] - 0s 179us/step

# %% [markdown]
# ## **VI. Output**

# %%
#save data
#NN configurations -> #NN layers, #NN neurons
#data configurations -> #data points, #data dimensions
#optimizer configurations -> #learning rate, #decay rate
#training configurations -> #NN training epochs, callbacks
#record loss values
#save the info into a spreadsheet

import pandas as pd

df = pd.DataFrame({
    'ODE model': [MY_MODEL],
    'data initial conditions': [data_initial_conditions],
    'data length (T)': [data_T],
    'data resolution (dt)': [data_dt],
    'learning rate': [learning_rate],
    'Guess highest-order polynomial': [guess_highest_order_polynomial],
    'input dimension': [x_train.shape[1]],
    'mini_batch_size': [MINI_BATCH_SIZE],
    'Layer Neurons per activation fns': [layer_neuron_nums_per_act_fn],
    'Data Points': [training_input.shape[0]],
    'loss function': [LOSS_FUNCTION],
    'Total Training Epochs': [NUM_EPOCHS],
    'last lost value': [history['loss'][-1]],
    'weight threshold for pruning': [PRUNING_WEIGHT_THRESHOLD],
    'loss threshold for early stopping': [EARLY_STOPPING_LOSS_THRESHOLD],
})

# %%
#write df to the first sheet of the excel file
#write to folder named data

opt_folder = 'output'
# Create the folder if it doesn't exist
os.makedirs(opt_folder, exist_ok=True)

with pd.ExcelWriter(os.path.join(opt_folder,'nn_configurations.xlsx')) as writer:

    df.to_excel(writer, sheet_name='configuration', index=False)

    #save the loss and validation history to the second sheet of the excel file
    df2 = pd.DataFrame(history)
    df2.to_excel(writer, sheet_name='loss_history', index=False)

    #save reconstructed weights to the third sheet of the excel file

    df3 = []

    for i in range(len(weights_list)):
        path_products = coefficient_reconstruction(i,
                                                    weights_list[i], 
                                                    minimum_coefficient_threshold = 1e-4,
                                                    coefficient_output_digits = 10, 
                                                    enable_coefficient_sorting = False)


        # Convert path_products to a DataFrame
        temp_df = pd.DataFrame(path_products)

        # Append temp_df to df3
        df3.append(temp_df)

    df3 = pd.concat(df3, ignore_index=True)
    df3.to_excel(writer, sheet_name='reconstructed_weights', index=False)

# %%
from scipy.io import savemat
#concatenate t_arr, x_train, dx_train, and NN_output and save it as a mat file

#pate t_arr such that it has the same shape as x_train, dx_train, and NN_output
tem_t_arr = t_arr
for i in range(num_traj-1):
    tem_t_arr = np.concatenate((tem_t_arr, t_arr), axis=0) 
t_arr = tem_t_arr

m_data = np.concatenate((t_arr, x_train, dx_train, NN_output), axis=1)
savemat(os.path.join(opt_folder,'train_data.mat'), {'data': m_data})

v_data = np.concatenate((new_t_arr, new_x, new_dx, new_NN_output), axis=1)
savemat(os.path.join(opt_folder,'validation_data.mat'), {'data': v_data})
