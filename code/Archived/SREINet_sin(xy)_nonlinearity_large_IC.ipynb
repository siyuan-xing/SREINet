# %% [markdown]
# ## **Lorenz 96 Model Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
import matplotlib.pyplot as plt

def odefun(t, y):
    x, v = y
    dxdt = v 
    dvdt = -x - 0.1*v - np.sin(x * v)
    return [dxdt, dvdt]

# Generate multiple initial conditions (same as before)
t_span = (0, 30)                      # time interval
num_trajectories = 5                 # number of different trajectories
dt = 0.005                            # time step

# Generate multiple initial conditions
initial_conditions = [(2.0, 0)]

# Initialize DataGenerator with correct parameters
myDG = DG.DataGenerator(
    initial_conditions=initial_conditions,  # multiple initial conditions
    T=t_span[1],                     # end time
    dt=dt,                           # time step
    t0=t_span[0],                    # start time
    noise_level=0.0,                 # no noise for now
    random_state=42                  # for reproducibility
)

# FIXED: Generate trajectories manually (avoiding the bug in generate_dataset_by_custom_ODEs)
x_train_list = []
dx_train_list = []

for ic in initial_conditions:
    # Generate trajectory for each initial condition
    temp_x, temp_dx = myDG.generate_ode_traj_with_ic(odefun, ic, myDG.derivative_mode)
    x_train_list.append(temp_x)
    dx_train_list.append(temp_dx)

# Combine all trajectories
x_train = np.vstack(x_train_list)
dx_train = np.vstack(dx_train_list)
t_arr = np.arange(myDG.t0, myDG.T, myDG.dt)

# Visualize the trajectories - Phase space plot only
plt.figure(figsize=(8, 6))

plt.title('Phase Space: All Trajectories', fontsize=14)
plt.xlabel('Position (x)', fontsize=12)
plt.ylabel('Velocity (v)', fontsize=12)

# Plot each trajectory with different colors
time_points_per_traj = len(t_arr)
colors = plt.cm.tab10(np.linspace(0, 1, len(initial_conditions)))

for i in range(len(initial_conditions)):
    start_idx = i * time_points_per_traj
    end_idx = (i + 1) * time_points_per_traj
    traj_x = x_train[start_idx:end_idx, 0]
    traj_v = x_train[start_idx:end_idx, 1]
    plt.plot(traj_x, traj_v, color=colors[i], alpha=0.7, linewidth=1.5,
             label=f'Traj {i+1}' if i < 5 else "")

plt.tight_layout()
plt.show()

# Prepare data for training
training_input, training_output = x_train, dx_train 
training_input_for_sim = training_input.copy() # Save copy for simulation

# Shuffle data (mixing all trajectories)
training_input, training_output = myDG.shuffleData(training_input, training_output)

print(f"Training input shape: {training_input.shape}")
print(f"Training output shape: {training_output.shape}")
# Out:
# Training input shape: (6000, 2)
# Training output shape: (6000, 2)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 32
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables)
dim = training_input.shape[1] 

guess_highest_order_polynomial = 6 # depth of SREINet

layer_depth = guess_highest_order_polynomial

# The grid size of each dimension
layer_neuron_nums_per_act_fn = [dim] * layer_depth

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn,
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=0.1, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

def reinitialize_model_weights(model):
    if hasattr(model.layers[1], 'reinitialize_weights'):
            tf.random.set_seed(42) 
            model.layers[1].reinitialize_weights()
    else:
        print("SREINet does not have a reinitialize_weights() function.")

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Training with Pruning**

# %%
import time
np.set_printoptions(threshold=np.inf)

# Define a training step function
@tf.function
def train_step(model, optimizer, loss_fn, inputs, targets, binary_mask):        
    with tf.GradientTape() as tape:
        # Generate predictions and calculate loss
        predictions = model(inputs, training=False)
        loss = loss_fn(targets, predictions)   
        
    # Calculate gradients and update model weights
    gradients = tape.gradient(loss, model.trainable_variables)        

    # Assuming binary_masks_ones is a list of binary masks created for each trainable variable
    masked_gradients = [tf.multiply(grad, mask) for grad, mask in zip(gradients, binary_mask)]

    optimizer.apply_gradients(zip(masked_gradients, model.trainable_variables))

    return loss

# Define a validation step function
@tf.function
def val_step(model, loss_fn, inputs, targets):
    # Generate predictions and calculate loss for validation data
    predictions = model(inputs, training=False)
    # predictions = model(inputs, training=False) 
    v_loss = loss_fn(targets, predictions)
    # Record the validation loss
    return v_loss   

def SREINet_fit_w_pruning(
    model,              # TensorFlow model to be trained
    training_input,     # Input features for training
    training_output,    # Target outputs for training
    batch_size,         # Number of samples per batch of computation
    validation_split,   # Fraction of data to be used as validation set
    epochs,             # Number of complete passes through the training dataset
    optimizer,          # Optimization algorithm for updating weights
    loss_fn,            # Loss function to measure model's performance
    pruning_schedule,   # Pruning schedule for gradually increasing the sparsity level
    data_type='float32',    # Data type of the tensors (default: 'float32')
    callbacks=None,         # List of callbacks for custom actions at various stages of training
    early_stopping_loss_threshold=0,       # Threshold for early stopping based on training and validation loss
    early_stopping_pruning_threshold=0,    # Threshold for early stopping based on pruning schedule
    verbose=0               # Verbosity mode (0 = silent, 1 = progress bar, etc.)
):
    # Cast the training input and output to the specified data type
    training_input = tf.cast(training_input, data_type)
    training_output = tf.cast(training_output, data_type)

    # Shuffle and batch the dataset, then split it into training and validation sets
    full_dataset = tf.data.Dataset.from_tensor_slices((training_input, training_output)).shuffle(buffer_size=1024)
    total_samples = training_input.shape[0]
    train_samples = int(total_samples * (1 - validation_split))
    
    # Apply the data type casting for each batch in the datasets
    train_dataset = full_dataset.take(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))
    val_dataset = full_dataset.skip(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))

    # Initialize metrics for tracking training and validation loss
    train_loss = tf.keras.metrics.Mean(name='train_loss', dtype=data_type)
    val_loss = tf.keras.metrics.Mean(name='val_loss', dtype=data_type)
    
    # Parameters initialization
    binary_mask = [tf.ones_like(var) for var in model.trainable_variables]

    def generate_binary_mask_and_prune_weight(model, pruning_weight_threshold):
        binary_masks = []  # Initialize list to hold binary masks
        
        # Iterate over each variable to apply the pruning threshold and generate masks
        for var in model.trainable_variables:
            # Generate a binary mask where weights above the PRUNING_WEIGHT_THRESHOLD are marked with 1, others with 0
            mask = tf.cast(tf.abs(var) >= pruning_weight_threshold, var.dtype)

            # Update the mask at position (0, 0) to be 1 using tf.tensor_scatter_nd_update (To Avoid the constant term being pruned)
            indices = tf.constant([[0, 0]])  # Specify the indices to update
            updates = tf.constant([1], dtype=mask.dtype)  # Specify the value to update
            mask = tf.tensor_scatter_nd_update(mask, indices, updates)

            binary_masks.append(mask)  # Add the generated mask to the list            

            # Apply mask to modify weights by setting weights below PRUNING_WEIGHT_THRESHOLD to zero
            modified_weight = var * mask
            var.assign(modified_weight)            
        return binary_masks

    # Prepare a dictionary to track the training history
    history = {'loss': [], 'val_loss': []}

    # Before the training loop starts
    if callbacks:
        for callback in callbacks:
            # Assign the model to the callback
            callback.set_model(model)

            # Manually setting params before calling any methods that might depend on them
            callback.params = {
                'epochs': epochs,  # Number of epochs
                # You can add more parameters here as needed
            }

            # Now call on_train_begin with all properties set
            callback.on_train_begin(logs={'loss_threshold': early_stopping_loss_threshold})

    training_start_time = time.time()
    # Execute the training loop
    for epoch in range(epochs):
        # Notify callbacks that the epoch has started
        if callbacks:
            epoch_logs = {}
            for callback in callbacks:
                callback.on_epoch_begin(epoch, logs=epoch_logs)

        if verbose: 
            eopoch_start_time = time.time()

        # Reset state of metrics at the start of each epoch
        train_loss.reset_states()
        val_loss.reset_states()

        # Retrieve the current pruning schedule threshold
        current_pruning_threshold = pruning_schedule[epoch]
        binary_mask = generate_binary_mask_and_prune_weight(model, current_pruning_threshold)
        
        layer_losses_sum = None
        layer_indices = [i for i, layer in enumerate(model.layers) if layer.trainable]
        # Process each batch in the training dataset
        for train_inputs, train_targets in train_dataset:           
            loss = train_step(model = model, 
                            optimizer = optimizer, 
                            loss_fn = loss_fn,
                            inputs = train_inputs, 
                            targets = train_targets, 
                            binary_mask = binary_mask)    
            # Record the loss
            train_loss(loss)

        # Process each batch in the validation dataset
        for val_inputs, val_targets in val_dataset:
            v_loss = val_step(model = model, 
                                loss_fn = loss_fn,
                                inputs = val_inputs, 
                                targets = val_targets)
            val_loss(v_loss)

        # Append the average losses for this epoch to the history
        history['loss'].append(train_loss.result().numpy())
        history['val_loss'].append(val_loss.result().numpy())
        #calculate the average of val_loss
        
        # Current Losses
        current_train_loss = train_loss.result().numpy()
        current_val_loss = val_loss.result().numpy()

        # Notify callbacks that the epoch has ended
        epoch_logs = {'loss': current_train_loss, 'val_loss': current_val_loss}
        if callbacks:
            for callback in callbacks:
                callback.on_epoch_end(epoch, logs=epoch_logs)
    
        if verbose:
            epoch_time = time.time() - eopoch_start_time
            total_layers = len(model.layers)
            trainable_layer_count = sum(1 for layer in model.layers if layer.trainable)
            print(f"Epoch {epoch + 1:3.0f}:"
                f"  Train Loss: {current_train_loss:9.4e}"
                f",  Validation Loss: {current_val_loss:9.4e}"
                # f",  Trainable Layers ({trainable_layer_count}/{total_layers})"
                f",  Epoch Time: {epoch_time:.2f}s"  
                f",  Current Pruning Threshold: {current_pruning_threshold:.5g}")    
            
        if model.stop_training: # Stop training if all the layers are untrianable
            break   

        # Check for early stopping
        if current_train_loss < early_stopping_loss_threshold and current_pruning_threshold > early_stopping_pruning_threshold:
            print(f"Early stopping at epoch {epoch+1} as train loss {current_val_loss:.12f} is below the threshold {early_stopping_loss_threshold:.12f}")
            break


    # After the training loop ends
    training_time = time.time() - training_start_time
    print(f'Traininng Stopped. Time elapsed: {training_time:.2f}s')
    if callbacks:
        for callback in callbacks:
            callback.on_train_end(logs={'final_loss': current_train_loss, 'final_val_loss': current_val_loss})
    

    # Return the history containing training and validation losses
    return history

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.04
N_PERIODS = 6
PRUNING_EPOCHS_PER_PERIOD = 40
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_schedule as ps

# Define the pruning schedule
pruning_schedule = ps.pruning_schedule_ramp(maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD, 
                                                    steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                                                    num_periods=N_PERIODS, 
                                                    #zero_percentage=0.10,
                                                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
callbacks = []

EARLY_STOPPING_LOSS_THRESHOLD = 1e-7   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.02

training_histories = []
weights_list = []

# %%
#change 0 to a other number if you want to start training from other dimensions
for i in range(0, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    reinitialize_model_weights(model)
    output = training_output[:, i:i+1]

    history = SREINet_fit_w_pruning(
        model,                   # Model to train
        training_input,             # Input data for training
        output,                     # Output data for training
        batch_size=MINI_BATCH_SIZE, # Number of samples per gradient update
        validation_split=0.20,      # Fraction of the training data to be used as validation data
        epochs=round(NUM_EPOCHS),   # Number of times the entire training dataset is passed through the model
        optimizer=my_optimizer,     # Optimizer to use for training
        pruning_schedule = pruning_schedule, # Pruning schedule for gradually increasing the sparsity level
        loss_fn=loss_fn,            # Loss function to use for training
        data_type=MY_DATA_TYPE,     # Data type to use for training
        callbacks= callbacks,       # List of callbacks to apply during training
        early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,# Threshold for early stopping (Layer Based)
        early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD, # Threshold for early stopping (Pruning Based)
        verbose=1                   # Hide the epoch steps
    )
    
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([model.get_layer('SREINet').get_weights()])
# Out:
# Training dimension 1...
# Epoch   1:  Train Loss: 3.7022e-01,  Validation Loss: 3.2746e-01,  Epoch Time: 0.42s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 2.5269e-01,  Validation Loss: 2.0968e-01,  Epoch Time: 0.13s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 2.0361e-01,  Validation Loss: 1.7640e-01,  Epoch Time: 0.14s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.6707e-01,  Validation Loss: 1.4221e-01,  Epoch Time: 0.13s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 1.3831e-01,  Validation Loss: 1.2125e-01,  Epoch Time: 0.13s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 1.2292e-01,  Validation Loss: 1.2045e-01,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 1.1932e-01,  Validation Loss: 1.1864e-01,  Epoch Time: 0.13s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 1.1579e-01,  Validation Loss: 1.0754e-01,  Epoch Time: 0.13s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 1.1334e-01,  Validation Loss: 1.0524e-01,  Epoch Time: 0.13s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 1.0993e-01,  Validation Loss: 9.8141e-02,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch  11:  Train Loss: 1.0571e-01,  Validation Loss: 9.7395e-02,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.00046759
# Epoch  12:  Train Loss: 1.0228e-01,  Validation Loss: 9.5492e-02,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch  13:  Train Loss: 9.2680e-02,  Validation Loss: 8.8359e-02,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.0018485
# Epoch  14:  Train Loss: 7.1175e-02,  Validation Loss: 4.9653e-02,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch  15:  Train Loss: 3.2280e-02,  Validation Loss: 2.4148e-02,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.0040781
# Epoch  16:  Train Loss: 1.9604e-02,  Validation Loss: 1.6814e-02,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.0054801
# Epoch  17:  Train Loss: 1.3711e-02,  Validation Loss: 1.1720e-02,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch  18:  Train Loss: 9.5286e-03,  Validation Loss: 7.4326e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch  19:  Train Loss: 6.1013e-03,  Validation Loss: 4.6941e-03,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.010632
# Epoch  20:  Train Loss: 3.6420e-03,  Validation Loss: 2.6910e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch  21:  Train Loss: 2.1531e-03,  Validation Loss: 1.8627e-03,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.014649
# Epoch  22:  Train Loss: 1.4515e-03,  Validation Loss: 1.2605e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch  23:  Train Loss: 1.0616e-03,  Validation Loss: 9.1979e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.018917
# Epoch  24:  Train Loss: 8.1934e-04,  Validation Loss: 7.9001e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.021083
# Epoch  25:  Train Loss: 6.6039e-04,  Validation Loss: 6.3041e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.023236
# Epoch  26:  Train Loss: 5.4245e-04,  Validation Loss: 4.9835e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.025351
# Epoch  27:  Train Loss: 4.5722e-04,  Validation Loss: 4.7930e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.027403
# Epoch  28:  Train Loss: 3.8635e-04,  Validation Loss: 3.5824e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.029368
# Epoch  29:  Train Loss: 3.3819e-04,  Validation Loss: 3.4840e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.031224
# Epoch  30:  Train Loss: 2.9788e-04,  Validation Loss: 2.8624e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.032948
# Epoch  31:  Train Loss: 2.6911e-04,  Validation Loss: 2.4284e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.03452
# Epoch  32:  Train Loss: 2.4146e-04,  Validation Loss: 2.2210e-04,  Epoch Time: 0.14s,  Current Pruning Threshold: 0.035922
# Epoch  33:  Train Loss: 2.0946e-04,  Validation Loss: 2.0385e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.037137
# Epoch  34:  Train Loss: 1.8370e-04,  Validation Loss: 1.7323e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038152
# Epoch  35:  Train Loss: 2.6442e-04,  Validation Loss: 2.2628e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.038953
# Epoch  36:  Train Loss: 1.9801e-04,  Validation Loss: 1.8188e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039532
# Epoch  37:  Train Loss: 1.7144e-04,  Validation Loss: 1.5540e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.039883
# Epoch  38:  Train Loss: 1.4448e-04,  Validation Loss: 1.3519e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  39:  Train Loss: 1.2417e-04,  Validation Loss: 1.2195e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.04
# Epoch  40:  Train Loss: 1.0670e-04,  Validation Loss: 9.7234e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  41:  Train Loss: 8.2155e-05,  Validation Loss: 7.0673e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 6.6313e-05,  Validation Loss: 5.6443e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 5.6546e-05,  Validation Loss: 5.0954e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 5.2626e-05,  Validation Loss: 5.2639e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 4.3842e-05,  Validation Loss: 4.1697e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 3.9403e-05,  Validation Loss: 3.6423e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 3.5602e-05,  Validation Loss: 3.0829e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 3.0598e-05,  Validation Loss: 2.8468e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 2.7277e-05,  Validation Loss: 2.4774e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 2.4722e-05,  Validation Loss: 2.3045e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch  51:  Train Loss: 2.1808e-05,  Validation Loss: 2.0254e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00046759
# Epoch  52:  Train Loss: 1.9915e-05,  Validation Loss: 1.8415e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch  53:  Train Loss: 1.7819e-05,  Validation Loss: 1.5661e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0018485
# Epoch  54:  Train Loss: 1.5624e-05,  Validation Loss: 1.4896e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch  55:  Train Loss: 1.3568e-05,  Validation Loss: 1.7919e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0040781
# Epoch  56:  Train Loss: 1.2330e-05,  Validation Loss: 1.0821e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0054801
# Epoch  57:  Train Loss: 1.0471e-05,  Validation Loss: 9.7255e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch  58:  Train Loss: 1.0095e-05,  Validation Loss: 8.9747e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch  59:  Train Loss: 8.6425e-06,  Validation Loss: 7.9091e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.010632
# Epoch  60:  Train Loss: 8.0257e-06,  Validation Loss: 7.6351e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch  61:  Train Loss: 7.3480e-06,  Validation Loss: 6.1554e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.014649
# Epoch  62:  Train Loss: 6.3204e-06,  Validation Loss: 6.3059e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch  63:  Train Loss: 5.4781e-06,  Validation Loss: 6.4906e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.018917
# Epoch  64:  Train Loss: 7.5700e-06,  Validation Loss: 5.2810e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.021083
# Epoch  65:  Train Loss: 6.5829e-06,  Validation Loss: 4.6381e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.023236
# Epoch  66:  Train Loss: 4.7291e-06,  Validation Loss: 4.7816e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.025351
# Epoch  67:  Train Loss: 4.0491e-06,  Validation Loss: 3.6777e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.027403
# Epoch  68:  Train Loss: 3.7379e-06,  Validation Loss: 2.8644e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.029368
# Epoch  69:  Train Loss: 3.2722e-06,  Validation Loss: 2.9114e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.031224
# Epoch  70:  Train Loss: 3.2622e-06,  Validation Loss: 2.5162e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.032948
# Epoch  71:  Train Loss: 3.4120e-05,  Validation Loss: 3.4452e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.03452
# Epoch  72:  Train Loss: 4.4210e-06,  Validation Loss: 2.9573e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.035922
# Epoch  73:  Train Loss: 2.8731e-06,  Validation Loss: 3.8415e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.037137
# Epoch  74:  Train Loss: 2.6300e-06,  Validation Loss: 2.3222e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038152
# Epoch  75:  Train Loss: 2.4080e-06,  Validation Loss: 2.7895e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038953
# Epoch  76:  Train Loss: 2.3160e-06,  Validation Loss: 1.9140e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039532
# Epoch  77:  Train Loss: 2.0033e-06,  Validation Loss: 1.9686e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039883
# Epoch  78:  Train Loss: 2.1851e-06,  Validation Loss: 2.0534e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  79:  Train Loss: 2.1728e-06,  Validation Loss: 2.0892e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.04
# Epoch  80:  Train Loss: 1.6554e-06,  Validation Loss: 1.4461e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  81:  Train Loss: 1.5635e-06,  Validation Loss: 1.1365e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  82:  Train Loss: 1.7142e-06,  Validation Loss: 3.8558e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  83:  Train Loss: 1.5244e-06,  Validation Loss: 1.0171e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  84:  Train Loss: 1.4433e-06,  Validation Loss: 9.4512e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  85:  Train Loss: 1.5521e-06,  Validation Loss: 1.1659e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  86:  Train Loss: 9.5221e-07,  Validation Loss: 6.9626e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  87:  Train Loss: 1.1707e-06,  Validation Loss: 1.0442e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  88:  Train Loss: 9.8199e-07,  Validation Loss: 6.1039e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  89:  Train Loss: 1.2107e-06,  Validation Loss: 1.0539e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  90:  Train Loss: 7.6561e-07,  Validation Loss: 5.5204e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch  91:  Train Loss: 1.0353e-06,  Validation Loss: 3.1452e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00046759
# Epoch  92:  Train Loss: 1.0433e-06,  Validation Loss: 7.3642e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch  93:  Train Loss: 7.8895e-07,  Validation Loss: 5.0634e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0018485
# Epoch  94:  Train Loss: 5.6798e-07,  Validation Loss: 4.1817e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch  95:  Train Loss: 1.1151e-06,  Validation Loss: 6.4399e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0040781
# Epoch  96:  Train Loss: 7.3735e-07,  Validation Loss: 4.4596e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0054801
# Epoch  97:  Train Loss: 4.6733e-07,  Validation Loss: 4.8434e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch  98:  Train Loss: 4.2904e-07,  Validation Loss: 1.0131e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch  99:  Train Loss: 6.6828e-07,  Validation Loss: 2.4606e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.010632
# Epoch 100:  Train Loss: 5.4279e-07,  Validation Loss: 3.6195e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch 101:  Train Loss: 6.3510e-07,  Validation Loss: 3.5082e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.014649
# Epoch 102:  Train Loss: 4.0474e-07,  Validation Loss: 3.8132e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch 103:  Train Loss: 3.3101e-07,  Validation Loss: 2.7397e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.018917
# Epoch 104:  Train Loss: 2.4800e-07,  Validation Loss: 1.3576e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.021083
# Epoch 105:  Train Loss: 1.2585e-06,  Validation Loss: 2.3965e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.023236
# Epoch 106:  Train Loss: 1.9453e-07,  Validation Loss: 2.2775e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.025351
# Epoch 107:  Train Loss: 3.8116e-07,  Validation Loss: 2.6099e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.027403
# Epoch 108:  Train Loss: 2.2110e-07,  Validation Loss: 3.4979e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.029368
# Epoch 109:  Train Loss: 2.2008e-07,  Validation Loss: 9.4914e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.031224
# Epoch 110:  Train Loss: 3.6295e-07,  Validation Loss: 1.3791e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.032948
# Epoch 111:  Train Loss: 2.7393e-07,  Validation Loss: 2.9279e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.03452
# Epoch 112:  Train Loss: 7.9201e-07,  Validation Loss: 2.9085e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.035922
# Epoch 113:  Train Loss: 7.4364e-07,  Validation Loss: 1.3495e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.037137
# Epoch 114:  Train Loss: 1.2561e-06,  Validation Loss: 2.3801e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038152
# Epoch 115:  Train Loss: 1.6183e-06,  Validation Loss: 2.2727e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038953
# Epoch 116:  Train Loss: 1.3427e-07,  Validation Loss: 7.7617e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039532
# Epoch 117:  Train Loss: 1.5427e-07,  Validation Loss: 7.8440e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039883
# Epoch 118:  Train Loss: 2.1221e-07,  Validation Loss: 5.0040e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 119:  Train Loss: 1.4960e-07,  Validation Loss: 1.2767e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 120:  Train Loss: 1.7548e-07,  Validation Loss: 1.2754e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 121:  Train Loss: 6.4744e-06,  Validation Loss: 1.1315e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 122:  Train Loss: 2.9116e-07,  Validation Loss: 4.0795e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 123:  Train Loss: 1.1525e-07,  Validation Loss: 5.2191e-08,  Epoch Time: 0.13s,  Current Pruning Threshold: 0
# Epoch 124:  Train Loss: 6.4982e-08,  Validation Loss: 5.2368e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 125:  Train Loss: 5.4874e-08,  Validation Loss: 1.0819e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 126:  Train Loss: 7.7427e-08,  Validation Loss: 8.5525e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 127:  Train Loss: 1.3741e-07,  Validation Loss: 4.8403e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 128:  Train Loss: 7.5389e-08,  Validation Loss: 4.6272e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 129:  Train Loss: 8.6047e-07,  Validation Loss: 7.8122e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 130:  Train Loss: 2.2243e-07,  Validation Loss: 3.1002e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch 131:  Train Loss: 3.6993e-08,  Validation Loss: 4.8327e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00046759
# Epoch 132:  Train Loss: 1.2715e-07,  Validation Loss: 3.0499e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch 133:  Train Loss: 1.3676e-07,  Validation Loss: 5.4120e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0018485
# Epoch 134:  Train Loss: 1.6842e-06,  Validation Loss: 1.0475e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch 135:  Train Loss: 7.6658e-07,  Validation Loss: 4.6642e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0040781
# Epoch 136:  Train Loss: 3.5318e-07,  Validation Loss: 1.1431e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0054801
# Epoch 137:  Train Loss: 1.5356e-07,  Validation Loss: 3.2982e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch 138:  Train Loss: 4.9645e-08,  Validation Loss: 5.3358e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch 139:  Train Loss: 4.0971e-08,  Validation Loss: 2.4298e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.010632
# Epoch 140:  Train Loss: 5.5776e-08,  Validation Loss: 2.9087e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch 141:  Train Loss: 1.3493e-07,  Validation Loss: 1.0652e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.014649
# Epoch 142:  Train Loss: 7.2177e-07,  Validation Loss: 1.1798e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch 143:  Train Loss: 4.5839e-08,  Validation Loss: 7.1573e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.018917
# Epoch 144:  Train Loss: 4.6037e-08,  Validation Loss: 2.0515e-08,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.021083
# Early stopping at epoch 144 as train loss 0.000000020515 is below the threshold 0.000000100000
# Traininng Stopped. Time elapsed: 18.24s
# Training dimension 2...
# Epoch   1:  Train Loss: 3.6749e-01,  Validation Loss: 2.6396e-01,  Epoch Time: 0.19s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 1.7196e-01,  Validation Loss: 8.8474e-02,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 3.3380e-02,  Validation Loss: 1.5631e-02,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 1.1789e-02,  Validation Loss: 9.4871e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 8.3415e-03,  Validation Loss: 7.3341e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 6.6095e-03,  Validation Loss: 5.9235e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 5.4925e-03,  Validation Loss: 4.5955e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 4.4470e-03,  Validation Loss: 3.8119e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 3.5634e-03,  Validation Loss: 3.2614e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 2.9115e-03,  Validation Loss: 2.4504e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch  11:  Train Loss: 2.3654e-03,  Validation Loss: 2.1953e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00046759
# Epoch  12:  Train Loss: 2.0316e-03,  Validation Loss: 1.8359e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch  13:  Train Loss: 1.8175e-03,  Validation Loss: 1.6888e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0018485
# Epoch  14:  Train Loss: 1.5905e-03,  Validation Loss: 1.5009e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch  15:  Train Loss: 1.4252e-03,  Validation Loss: 1.3802e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0040781
# Epoch  16:  Train Loss: 1.2718e-03,  Validation Loss: 1.1719e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0054801
# Epoch  17:  Train Loss: 1.1060e-03,  Validation Loss: 1.0875e-03,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch  18:  Train Loss: 9.8731e-04,  Validation Loss: 9.4375e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch  19:  Train Loss: 8.6856e-04,  Validation Loss: 7.4923e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.010632
# Epoch  20:  Train Loss: 7.3905e-04,  Validation Loss: 6.7000e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch  21:  Train Loss: 6.4600e-04,  Validation Loss: 6.5399e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.014649
# Epoch  22:  Train Loss: 5.4385e-04,  Validation Loss: 5.2957e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch  23:  Train Loss: 4.8121e-04,  Validation Loss: 5.1529e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.018917
# Epoch  24:  Train Loss: 4.3941e-04,  Validation Loss: 4.3870e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.021083
# Epoch  25:  Train Loss: 4.1847e-04,  Validation Loss: 3.8937e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.023236
# Epoch  26:  Train Loss: 3.7535e-04,  Validation Loss: 4.3027e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.025351
# Epoch  27:  Train Loss: 3.6082e-04,  Validation Loss: 3.5376e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.027403
# Epoch  28:  Train Loss: 3.4470e-04,  Validation Loss: 3.2146e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.029368
# Epoch  29:  Train Loss: 3.2104e-04,  Validation Loss: 3.4655e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.031224
# Epoch  30:  Train Loss: 3.0454e-04,  Validation Loss: 3.0417e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.032948
# Epoch  31:  Train Loss: 2.9070e-04,  Validation Loss: 2.9814e-04,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.03452
# Epoch  32:  Train Loss: 2.7659e-04,  Validation Loss: 2.8049e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.035922
# Epoch  33:  Train Loss: 2.7049e-04,  Validation Loss: 3.1702e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.037137
# Epoch  34:  Train Loss: 2.6155e-04,  Validation Loss: 2.7237e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038152
# Epoch  35:  Train Loss: 2.6224e-04,  Validation Loss: 2.8438e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038953
# Epoch  36:  Train Loss: 2.2907e-04,  Validation Loss: 2.3823e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039532
# Epoch  37:  Train Loss: 2.2715e-04,  Validation Loss: 2.0323e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039883
# Epoch  38:  Train Loss: 2.1683e-04,  Validation Loss: 2.1270e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  39:  Train Loss: 2.1348e-04,  Validation Loss: 1.9325e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  40:  Train Loss: 2.1036e-04,  Validation Loss: 2.0092e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  41:  Train Loss: 1.8561e-04,  Validation Loss: 1.8569e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 1.7925e-04,  Validation Loss: 1.6754e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 1.5310e-04,  Validation Loss: 1.3559e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 1.4021e-04,  Validation Loss: 1.2863e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 1.1881e-04,  Validation Loss: 1.2758e-04,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 1.0335e-04,  Validation Loss: 9.3000e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 9.1700e-05,  Validation Loss: 7.4089e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 7.3626e-05,  Validation Loss: 7.6997e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 7.4775e-05,  Validation Loss: 5.2688e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 6.0624e-05,  Validation Loss: 6.3049e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch  51:  Train Loss: 5.7496e-05,  Validation Loss: 4.6458e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00046759
# Epoch  52:  Train Loss: 5.1608e-05,  Validation Loss: 5.4056e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch  53:  Train Loss: 4.2447e-05,  Validation Loss: 8.0483e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0018485
# Epoch  54:  Train Loss: 3.8656e-05,  Validation Loss: 3.0084e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch  55:  Train Loss: 2.8692e-05,  Validation Loss: 3.2626e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0040781
# Epoch  56:  Train Loss: 2.7176e-05,  Validation Loss: 2.7999e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0054801
# Epoch  57:  Train Loss: 2.4299e-05,  Validation Loss: 2.3061e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch  58:  Train Loss: 2.1412e-05,  Validation Loss: 1.6657e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch  59:  Train Loss: 2.2533e-05,  Validation Loss: 2.9911e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.010632
# Epoch  60:  Train Loss: 1.8826e-05,  Validation Loss: 1.6921e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch  61:  Train Loss: 1.7891e-05,  Validation Loss: 1.3140e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.014649
# Epoch  62:  Train Loss: 1.5400e-05,  Validation Loss: 1.5549e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch  63:  Train Loss: 1.4139e-05,  Validation Loss: 1.7440e-05,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.018917
# Epoch  64:  Train Loss: 1.3090e-05,  Validation Loss: 1.2186e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.021083
# Epoch  65:  Train Loss: 1.1131e-05,  Validation Loss: 9.3998e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.023236
# Epoch  66:  Train Loss: 1.0317e-05,  Validation Loss: 1.1558e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.025351
# Epoch  67:  Train Loss: 1.0029e-05,  Validation Loss: 7.1344e-06,  Epoch Time: 0.16s,  Current Pruning Threshold: 0.027403
# Epoch  68:  Train Loss: 8.4217e-06,  Validation Loss: 8.4065e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.029368
# Epoch  69:  Train Loss: 7.9309e-06,  Validation Loss: 5.2922e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.031224
# Epoch  70:  Train Loss: 8.3496e-06,  Validation Loss: 7.8832e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.032948
# Epoch  71:  Train Loss: 9.0816e-06,  Validation Loss: 5.1017e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.03452
# Epoch  72:  Train Loss: 5.5152e-06,  Validation Loss: 5.5487e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.035922
# Epoch  73:  Train Loss: 6.0335e-06,  Validation Loss: 5.1117e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.037137
# Epoch  74:  Train Loss: 5.9031e-06,  Validation Loss: 4.6691e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038152
# Epoch  75:  Train Loss: 6.6171e-06,  Validation Loss: 3.0236e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038953
# Epoch  76:  Train Loss: 4.5417e-06,  Validation Loss: 2.9368e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039532
# Epoch  77:  Train Loss: 3.8997e-06,  Validation Loss: 4.4203e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039883
# Epoch  78:  Train Loss: 1.5220e-05,  Validation Loss: 3.5537e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  79:  Train Loss: 3.2406e-06,  Validation Loss: 2.8797e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  80:  Train Loss: 3.5927e-06,  Validation Loss: 2.1206e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch  81:  Train Loss: 3.5422e-06,  Validation Loss: 3.9621e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  82:  Train Loss: 2.6659e-06,  Validation Loss: 2.9533e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  83:  Train Loss: 5.2544e-06,  Validation Loss: 9.0562e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  84:  Train Loss: 4.0938e-06,  Validation Loss: 2.4737e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  85:  Train Loss: 4.7419e-06,  Validation Loss: 2.0375e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  86:  Train Loss: 1.6975e-06,  Validation Loss: 2.2720e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  87:  Train Loss: 1.5998e-06,  Validation Loss: 1.2068e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  88:  Train Loss: 2.4728e-06,  Validation Loss: 3.5959e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  89:  Train Loss: 2.5375e-06,  Validation Loss: 1.2464e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch  90:  Train Loss: 6.3131e-06,  Validation Loss: 3.4759e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch  91:  Train Loss: 1.9479e-06,  Validation Loss: 1.0427e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00046759
# Epoch  92:  Train Loss: 1.2312e-06,  Validation Loss: 3.7240e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch  93:  Train Loss: 8.6738e-06,  Validation Loss: 9.0454e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0018485
# Epoch  94:  Train Loss: 1.8904e-06,  Validation Loss: 2.3051e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch  95:  Train Loss: 3.8487e-06,  Validation Loss: 2.3730e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0040781
# Epoch  96:  Train Loss: 1.9202e-05,  Validation Loss: 1.2720e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0054801
# Epoch  97:  Train Loss: 1.9839e-06,  Validation Loss: 8.5332e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch  98:  Train Loss: 1.1943e-06,  Validation Loss: 8.2541e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch  99:  Train Loss: 1.8049e-06,  Validation Loss: 2.0801e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.010632
# Epoch 100:  Train Loss: 2.1464e-06,  Validation Loss: 1.2070e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch 101:  Train Loss: 1.4696e-06,  Validation Loss: 5.1478e-07,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.014649
# Epoch 102:  Train Loss: 5.5269e-06,  Validation Loss: 1.1951e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch 103:  Train Loss: 2.5804e-06,  Validation Loss: 1.0189e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.018917
# Epoch 104:  Train Loss: 2.4665e-06,  Validation Loss: 1.1332e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.021083
# Epoch 105:  Train Loss: 1.2557e-06,  Validation Loss: 1.2541e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.023236
# Epoch 106:  Train Loss: 2.2162e-06,  Validation Loss: 2.4388e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.025351
# Epoch 107:  Train Loss: 1.4354e-06,  Validation Loss: 2.1328e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.027403
# Epoch 108:  Train Loss: 1.1131e-05,  Validation Loss: 3.1525e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.029368
# Epoch 109:  Train Loss: 1.0389e-05,  Validation Loss: 1.0645e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.031224
# Epoch 110:  Train Loss: 2.2268e-06,  Validation Loss: 3.9817e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.032948
# Epoch 111:  Train Loss: 1.5415e-06,  Validation Loss: 1.3261e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.03452
# Epoch 112:  Train Loss: 3.9923e-06,  Validation Loss: 1.9722e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.035922
# Epoch 113:  Train Loss: 2.5735e-06,  Validation Loss: 1.8738e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.037137
# Epoch 114:  Train Loss: 1.6803e-06,  Validation Loss: 1.1474e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038152
# Epoch 115:  Train Loss: 4.5616e-06,  Validation Loss: 1.3678e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.038953
# Epoch 116:  Train Loss: 2.1133e-06,  Validation Loss: 3.5496e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039532
# Epoch 117:  Train Loss: 2.1414e-05,  Validation Loss: 2.7961e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.039883
# Epoch 118:  Train Loss: 4.0635e-06,  Validation Loss: 1.4128e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 119:  Train Loss: 1.8235e-06,  Validation Loss: 1.5479e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.04
# Epoch 120:  Train Loss: 1.3883e-06,  Validation Loss: 4.3455e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.04
# Epoch 121:  Train Loss: 4.9595e-06,  Validation Loss: 1.9241e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0
# Epoch 122:  Train Loss: 5.8234e-06,  Validation Loss: 9.8163e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 123:  Train Loss: 4.8520e-06,  Validation Loss: 4.3238e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 124:  Train Loss: 3.8626e-06,  Validation Loss: 1.5381e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 125:  Train Loss: 2.0577e-06,  Validation Loss: 1.3920e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 126:  Train Loss: 1.8303e-06,  Validation Loss: 1.1671e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 127:  Train Loss: 3.0860e-06,  Validation Loss: 3.3805e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 128:  Train Loss: 5.1933e-06,  Validation Loss: 6.0293e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 129:  Train Loss: 2.3116e-06,  Validation Loss: 1.9318e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0
# Epoch 130:  Train Loss: 1.7569e-06,  Validation Loss: 1.3837e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch 131:  Train Loss: 1.9394e-06,  Validation Loss: 1.1073e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00046759
# Epoch 132:  Train Loss: 2.0684e-06,  Validation Loss: 1.6817e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch 133:  Train Loss: 6.4532e-06,  Validation Loss: 6.4657e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0018485
# Epoch 134:  Train Loss: 1.2184e-06,  Validation Loss: 2.6405e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch 135:  Train Loss: 1.8806e-06,  Validation Loss: 2.8669e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.0040781
# Epoch 136:  Train Loss: 1.3278e-05,  Validation Loss: 1.3915e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0054801
# Epoch 137:  Train Loss: 2.1263e-06,  Validation Loss: 2.5476e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch 138:  Train Loss: 1.2770e-06,  Validation Loss: 1.7860e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch 139:  Train Loss: 9.5191e-07,  Validation Loss: 1.5204e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.010632
# Epoch 140:  Train Loss: 2.6148e-06,  Validation Loss: 2.4204e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch 141:  Train Loss: 1.9367e-05,  Validation Loss: 7.2201e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.014649
# Epoch 142:  Train Loss: 2.2257e-06,  Validation Loss: 8.2899e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch 143:  Train Loss: 1.2667e-06,  Validation Loss: 1.1875e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.018917
# Epoch 144:  Train Loss: 9.2522e-07,  Validation Loss: 7.6298e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.021083
# Epoch 145:  Train Loss: 3.0357e-06,  Validation Loss: 2.6052e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.023236
# Epoch 146:  Train Loss: 1.8277e-06,  Validation Loss: 1.0319e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.025351
# Epoch 147:  Train Loss: 1.6795e-06,  Validation Loss: 2.0359e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.027403
# Epoch 148:  Train Loss: 3.3501e-06,  Validation Loss: 9.6221e-07,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.029368
# Epoch 149:  Train Loss: 1.1985e-06,  Validation Loss: 1.1136e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.031224
# Epoch 150:  Train Loss: 1.3750e-06,  Validation Loss: 1.5203e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.032948
# Epoch 151:  Train Loss: 3.3877e-06,  Validation Loss: 2.0902e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.03452
# Epoch 152:  Train Loss: 2.5541e-06,  Validation Loss: 3.0006e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.035922
# Epoch 153:  Train Loss: 6.3467e-06,  Validation Loss: 1.4870e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.037137
# Epoch 154:  Train Loss: 1.3764e-06,  Validation Loss: 2.2257e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038152
# Epoch 155:  Train Loss: 3.2910e-06,  Validation Loss: 1.2952e-05,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.038953
# Epoch 156:  Train Loss: 5.5996e-06,  Validation Loss: 8.5964e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039532
# Epoch 157:  Train Loss: 3.7072e-06,  Validation Loss: 2.7438e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039883
# Epoch 158:  Train Loss: 2.1774e-06,  Validation Loss: 8.3245e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 159:  Train Loss: 1.0722e-06,  Validation Loss: 9.9881e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 160:  Train Loss: 3.7872e-06,  Validation Loss: 3.4884e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 161:  Train Loss: 1.9299e-06,  Validation Loss: 9.6852e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 162:  Train Loss: 2.4640e-05,  Validation Loss: 1.6851e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 163:  Train Loss: 4.3188e-06,  Validation Loss: 1.2977e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 164:  Train Loss: 1.1540e-06,  Validation Loss: 1.1873e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 165:  Train Loss: 1.0668e-06,  Validation Loss: 1.0564e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 166:  Train Loss: 1.7634e-06,  Validation Loss: 4.3907e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 167:  Train Loss: 2.2297e-06,  Validation Loss: 9.9788e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 168:  Train Loss: 1.9971e-06,  Validation Loss: 1.3112e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 169:  Train Loss: 1.1484e-06,  Validation Loss: 1.3503e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 170:  Train Loss: 1.8763e-06,  Validation Loss: 1.8603e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch 171:  Train Loss: 2.5909e-06,  Validation Loss: 9.6582e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00046759
# Epoch 172:  Train Loss: 1.5123e-05,  Validation Loss: 8.0528e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch 173:  Train Loss: 9.8105e-07,  Validation Loss: 6.6095e-07,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.0018485
# Epoch 174:  Train Loss: 9.9165e-07,  Validation Loss: 1.3911e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch 175:  Train Loss: 1.2185e-06,  Validation Loss: 1.2072e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0040781
# Epoch 176:  Train Loss: 1.2634e-06,  Validation Loss: 1.7678e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0054801
# Epoch 177:  Train Loss: 2.7364e-06,  Validation Loss: 4.6809e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch 178:  Train Loss: 2.7014e-06,  Validation Loss: 4.4202e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch 179:  Train Loss: 1.6100e-06,  Validation Loss: 8.6334e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.010632
# Epoch 180:  Train Loss: 7.2927e-06,  Validation Loss: 1.2196e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch 181:  Train Loss: 2.4860e-06,  Validation Loss: 9.3734e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.014649
# Epoch 182:  Train Loss: 1.6884e-06,  Validation Loss: 1.8465e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch 183:  Train Loss: 1.6611e-06,  Validation Loss: 1.3261e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.018917
# Epoch 184:  Train Loss: 2.9361e-06,  Validation Loss: 3.4004e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.021083
# Epoch 185:  Train Loss: 2.2764e-06,  Validation Loss: 1.3753e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.023236
# Epoch 186:  Train Loss: 1.2482e-06,  Validation Loss: 1.2312e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.025351
# Epoch 187:  Train Loss: 1.0607e-05,  Validation Loss: 3.4645e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.027403
# Epoch 188:  Train Loss: 2.1797e-06,  Validation Loss: 6.3636e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.029368
# Epoch 189:  Train Loss: 1.2102e-06,  Validation Loss: 3.8863e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.031224
# Epoch 190:  Train Loss: 6.1079e-06,  Validation Loss: 1.7741e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.032948
# Epoch 191:  Train Loss: 1.5889e-06,  Validation Loss: 4.3627e-06,  Epoch Time: 0.13s,  Current Pruning Threshold: 0.03452
# Epoch 192:  Train Loss: 2.0943e-06,  Validation Loss: 7.3431e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.035922
# Epoch 193:  Train Loss: 1.5688e-06,  Validation Loss: 9.2956e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.037137
# Epoch 194:  Train Loss: 1.0594e-06,  Validation Loss: 1.7074e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038152
# Epoch 195:  Train Loss: 1.0930e-06,  Validation Loss: 6.9703e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038953
# Epoch 196:  Train Loss: 1.4017e-06,  Validation Loss: 2.0978e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039532
# Epoch 197:  Train Loss: 5.6372e-06,  Validation Loss: 1.0333e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039883
# Epoch 198:  Train Loss: 7.8887e-06,  Validation Loss: 2.4080e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 199:  Train Loss: 1.6093e-06,  Validation Loss: 3.7432e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 200:  Train Loss: 1.6671e-06,  Validation Loss: 1.1924e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 201:  Train Loss: 6.6794e-06,  Validation Loss: 7.3040e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 202:  Train Loss: 5.9594e-06,  Validation Loss: 2.0980e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 203:  Train Loss: 3.6644e-06,  Validation Loss: 1.9181e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 204:  Train Loss: 5.5203e-06,  Validation Loss: 1.3667e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 205:  Train Loss: 1.7682e-06,  Validation Loss: 1.5571e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 206:  Train Loss: 1.4789e-06,  Validation Loss: 2.8034e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 207:  Train Loss: 2.7048e-06,  Validation Loss: 5.4651e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 208:  Train Loss: 1.1906e-06,  Validation Loss: 1.0382e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 209:  Train Loss: 1.9029e-06,  Validation Loss: 2.7296e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0
# Epoch 210:  Train Loss: 2.0670e-06,  Validation Loss: 8.7697e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00011724
# Epoch 211:  Train Loss: 1.4810e-05,  Validation Loss: 4.5677e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.00046759
# Epoch 212:  Train Loss: 1.3069e-06,  Validation Loss: 4.8205e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0010469
# Epoch 213:  Train Loss: 1.9586e-06,  Validation Loss: 2.0175e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0018485
# Epoch 214:  Train Loss: 1.5795e-06,  Validation Loss: 7.9876e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0028629
# Epoch 215:  Train Loss: 7.4816e-07,  Validation Loss: 8.4375e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0040781
# Epoch 216:  Train Loss: 1.9946e-06,  Validation Loss: 5.3026e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0054801
# Epoch 217:  Train Loss: 1.9006e-06,  Validation Loss: 1.4991e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0070523
# Epoch 218:  Train Loss: 1.3526e-06,  Validation Loss: 2.0001e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.0087763
# Epoch 219:  Train Loss: 3.6123e-06,  Validation Loss: 1.4589e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.010632
# Epoch 220:  Train Loss: 9.2889e-06,  Validation Loss: 2.1654e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.012597
# Epoch 221:  Train Loss: 4.4462e-06,  Validation Loss: 6.8625e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.014649
# Epoch 222:  Train Loss: 1.6131e-06,  Validation Loss: 4.4214e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.016764
# Epoch 223:  Train Loss: 1.3904e-06,  Validation Loss: 9.3390e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.018917
# Epoch 224:  Train Loss: 9.6952e-07,  Validation Loss: 1.2813e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.021083
# Epoch 225:  Train Loss: 1.6444e-06,  Validation Loss: 2.6580e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.023236
# Epoch 226:  Train Loss: 1.4979e-06,  Validation Loss: 2.2514e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.025351
# Epoch 227:  Train Loss: 1.4085e-06,  Validation Loss: 6.5876e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.027403
# Epoch 228:  Train Loss: 3.0974e-06,  Validation Loss: 1.8365e-05,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.029368
# Epoch 229:  Train Loss: 5.4818e-06,  Validation Loss: 7.0024e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.031224
# Epoch 230:  Train Loss: 1.7913e-06,  Validation Loss: 2.8169e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.032948
# Epoch 231:  Train Loss: 3.2607e-06,  Validation Loss: 8.6479e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.03452
# Epoch 232:  Train Loss: 2.4006e-06,  Validation Loss: 1.0336e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.035922
# Epoch 233:  Train Loss: 1.7635e-06,  Validation Loss: 3.9384e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.037137
# Epoch 234:  Train Loss: 2.1650e-06,  Validation Loss: 1.7638e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038152
# Epoch 235:  Train Loss: 6.0013e-06,  Validation Loss: 2.5320e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.038953
# Epoch 236:  Train Loss: 2.3945e-06,  Validation Loss: 6.0658e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039532
# Epoch 237:  Train Loss: 1.0299e-06,  Validation Loss: 4.6065e-07,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.039883
# Epoch 238:  Train Loss: 1.8276e-06,  Validation Loss: 4.0563e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 239:  Train Loss: 1.4847e-06,  Validation Loss: 2.7733e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Epoch 240:  Train Loss: 4.3458e-06,  Validation Loss: 1.3834e-06,  Epoch Time: 0.12s,  Current Pruning Threshold: 0.04
# Traininng Stopped. Time elapsed: 29.80s

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_set_labels(N):
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)] + [f'cos(x{i})' for i in range(1, N+1)] + [f'sin(x{i})' for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
def coefficient_reconstruction(dim_index,
                                weights, 
                                minimum_coefficient_threshold = 1e-5,
                                coefficient_output_digits = 10, 
                                enable_coefficient_sorting = False):
    
    max_neurons = max(max(len(layer) for layer in SREINet) for SREINet in weights)
    
    labels = generate_set_labels(max_neurons - 1) # number of states = number of neurons - 1

    def explore_path(SREINet_index, layer, neuron, weight_product, label_counts, non_zero_paths):
        """
        Recursively explores non-zero paths in a neural network.
        """
        if layer == len(weights[SREINet_index]) - 1:
            non_zero_paths.append((label_counts, weight_product))
            return

        for next_neuron, weight in enumerate(weights[SREINet_index][layer][neuron]):
            if abs(weight) <= 1e-15:
                # Skip recursion if the weight is zero (if one weight is zero, the whole path will be eliminated)
                continue  
            new_weight_product = weight_product * weight
            next_label_counts = label_counts.copy()
            next_label_counts[labels[next_neuron]] = next_label_counts.get(labels[next_neuron], 0) + 1
            explore_path(SREINet_index, layer + 1, next_neuron, new_weight_product, next_label_counts, non_zero_paths)
    
    #beginning of the algorithm
    all_SREINet_products = []
    for SREINet_index, _ in enumerate(weights):
        non_zero_paths = []
        #collect all non-zero paths
        for neuron_index in range(len(weights[SREINet_index][0])):
            label_counts = {labels[neuron_index]: 1}
            explore_path(SREINet_index, 0, neuron_index, 1, label_counts, non_zero_paths)
        
        #sum up the products with identical composite nonlinear/linear terms
        SREINet_products = {}
        for label_counts, weight_product in non_zero_paths:
            label_counts_key = frozenset(label_counts.items())
            if label_counts_key in SREINet_products:
                SREINet_products[label_counts_key] += weight_product
            else:
                SREINet_products[label_counts_key] = weight_product
        
        #remove the negligible composite terms
        SREINet_products = {k: v for k, v in SREINet_products.items() if abs(v) >= minimum_coefficient_threshold}
        
        if enable_coefficient_sorting:
            #sort the composite terms by their absolute values
            sorted_SREINet_products = dict(sorted(SREINet_products.items(), key=lambda item: abs(item[1]), reverse=True))
        else:
            sorted_SREINet_products = SREINet_products

        all_SREINet_products.append(sorted_SREINet_products)

    #output formatting
    labeled_all_SREINet_products = []
    for SREINet_index, sorted_SREINet_products in enumerate(all_SREINet_products):
        SREINet_product_strings = []
        for key, value in sorted_SREINet_products.items():
            labels_list = []
            only_constant = len(key) == 1 and any(label == 'Constant' for label, _ in key)
            
            for label, count in sorted(key):
                if label == 'Constant' and len(key) > 1:
                    continue
                if label != 'Constant' and count > 1:
                    labels_list.append(f"{label}^{count}")
                elif label == 'Constant' or count == 1:
                    labels_list.append(label if label != 'Constant' else '')
            
            label_str = '*'.join(filter(None, labels_list))
                        
            # Apply coefficient threshold if enabled
            formatted_value = f"{abs(value):.{coefficient_output_digits}g}"

            term_str = label_str if formatted_value == '1' else f"{formatted_value}*{label_str}" if not only_constant else formatted_value if formatted_value != '1' else ''
            sign = '+' if value >= 0 else '-'
            if SREINet_product_strings or value < 0:
                term_str = f" {sign} {term_str}"
            else:
                term_str = term_str
            SREINet_product_strings.append(term_str)

        formatted_output = ''.join(SREINet_product_strings)
        layer_prefix = f"(x{SREINet_index+dim_index+1})'= "
        full_output = layer_prefix + formatted_output
        labeled_all_SREINet_products.append(full_output)

    return labeled_all_SREINet_products

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
for i in range(len(weights_list)):
    path_products = coefficient_reconstruction(i,weights_list[i], 
                                            minimum_coefficient_threshold = 5e-2,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
# Out:
# (x1)'= 0.9996087562*x2
# (x2)'=  - 1.001667704*x1 - 0.1006691341*x2 - 1.004280065*x1*x2 + 0.151748844*x1^3*x2^3

# %% [markdown]
# ### **Validation**

# %%
params = {
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 600,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 14, # was 10
    'legend.fontsize': 12, # was 10
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'text.usetex': False,
    #'figure.figsize': [7, 4],
    'font.family': 'Helvetica',
    #'text.latex.preamble': r'\usepackage{amsmath}',  # Optional, for advanced math symbols
    #'axes.labelweight': 'bold'
    }
import matplotlib

matplotlib.rcParams.update(params)

# %%
def identifed_ode(t, x):
    x1, x2 = x
    dx1dt = 0.9997657044*x2 
    dx2dt = - 1.001667704*x1 - 0.1006691341*x2 - 1.004280065*x1*x2 + 0.151748844*x1**3*x2**3 # copy from the identified model, replace ^ by **
    return [dx1dt, dx2dt]

#validation using training initial conditions
y0 = initial_conditions[0]
val_DG = DG.DataGenerator(
    initial_conditions=[y0],         # list of ICs
    T=t_span[1],                     # end time
    dt=dt,                           # time step
    t0=t_span[0],                    # start time
    noise_level=0.0,                 # no noise for now
    random_state=42                  # for reproducibility
)

val_x, val_dx = val_DG.generate_ode_traj_with_ic(identifed_ode, y0)

true_x, true_y = myDG.generate_ode_traj_with_ic(odefun, y0)

plt.plot(true_x[:,0], true_x[:,1], label='True',color='black')

plt.plot(val_x[:,0], val_x[:,1], label='Identified',color='red',linestyle='--')
plt.plot(true_x[0,0], true_x[0,1], 'bo', markersize=8)

plt.annotate('IC', (true_x[0,0], true_x[0,1]), 
             xytext=(5, 8), textcoords='offset points',
             fontsize=12, ha='left')

plt.xlim([-2.2,2.6])
plt.xticks([-2.2, -1.0, 0.2, 1.4, 2.6])
plt.ylim([-1.5,2.5])
plt.yticks([-1.5, -0.5, 0.5, 1.5, 2.5])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.tick_params(direction='in', length=6, width=1)
plt.tick_params(axis='y', pad=10)
plt.tick_params(axis='x', pad=10)

plt.show()

# %%
# validation using different initial conditions
val_y0 = [0.0, 2.5]

val_DG = DG.DataGenerator(
    initial_conditions=[val_y0],         # list of ICs
    T=t_span[1],                     # end time
    dt=dt,                           # time step
    t0=t_span[0],                    # start time
    noise_level=0.0,                 # no noise for now
    random_state=42                  # for reproducibility
)

val_x, val_dx = val_DG.generate_ode_traj_with_ic(identifed_ode, val_y0)

true_x, true_y = myDG.generate_ode_traj_with_ic(odefun, val_y0)

plt.plot(true_x[:,0], true_x[:,1], label='True',color='black')

plt.plot(val_x[:,0], val_x[:,1], label='Identified',color='red',linestyle='--')

plt.plot(true_x[0,0], true_x[0,1], 'bo', markersize=8)

plt.annotate('IC', (true_x[0,0], true_x[0,1]), 
             xytext=(5, 8), textcoords='offset points',
             fontsize=12, ha='left')

plt.xlim([-1.6,2])
plt.xticks([-1.6, -0.7, 0.2, 1.1, 2])
plt.ylim([-1.5,3.0])
plt.yticks([-1.5, 0, 1.5, 3.0])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.tick_params(direction='in', length=6, width=1)
plt.tick_params(axis='y', pad=10)
plt.tick_params(axis='x', pad=10)

plt.show()

# %%
# validation using different initial conditions
val_y0 = [2.6, 0.0]

val_DG = DG.DataGenerator(
    initial_conditions=[val_y0],         # list of ICs
    T=t_span[1],                     # end time
    dt=dt,                           # time step
    t0=t_span[0],                    # start time
    noise_level=0.0,                 # no noise for now
    random_state=42                  # for reproducibility
)

val_x, val_dx = val_DG.generate_ode_traj_with_ic(identifed_ode, val_y0)

true_x, true_y = myDG.generate_ode_traj_with_ic(odefun, val_y0)

plt.plot(true_x[:,0], true_x[:,1], label='True',color='black')

plt.plot(val_x[:,0], val_x[:,1], label='Identified',color='red',linestyle='--')

plt.plot(true_x[0,0], true_x[0,1], 'bo', markersize=8)

plt.annotate('IC', (true_x[0,0], true_x[0,1]), 
             xytext=(5, 8), textcoords='offset points',
             fontsize=12, ha='left')

plt.xlim([-3,3])
plt.xticks([-3, -1.5, 0, 1.5, 3])
plt.ylim([-4.5,3.5])
plt.yticks([-4.5, -2.5, -0.5, 1.5, 3.5])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.tick_params(direction='in', length=6, width=1)
plt.tick_params(axis='y', pad=10)
plt.tick_params(axis='x', pad=10)

plt.show()

# %% [markdown]
# ## Vector field

# %%
def identifed_vector_field(x1, x2):
    dx1dt = 0.9997657044*x2 
    dx2dt = - 1.001667704*x1 - 0.1006691341*x2 - 1.004280065*x1*x2 + 0.151748844*x1**3*x2**3
    return dx1dt, dx2dt

x1_range = np.linspace(-1.5, 1.5, 15)  
x2_range = np.linspace(-1.5, 1.5, 15)
X1, X2 = np.meshgrid(x1_range, x2_range)

# 直接向量化计算
DX, DV = identifed_vector_field(X1, X2)

# 绘制矢量场
plt.quiver(X1, X2, DX, DV, alpha=0.5, color='red', scale=15, width=0.003)

# %%
def true_vector_field(x1, x2):
    dx1dt = 0.9997657044*x2 
    dx2dt = - 1.001667704*x1 - 0.1006691341*x2 - np.sin(x1*x2)
    return dx1dt, dx2dt

x1_range = np.linspace(-1.5, 1.5, 15)  
x2_range = np.linspace(-1.5, 1.5, 15)
X1, X2 = np.meshgrid(x1_range, x2_range)

# 直接向量化计算
DX, DV = identifed_vector_field(X1, X2)

# 绘制矢量场
plt.quiver(X1, X2, DX, DV, alpha=0.5, color='black', scale=15, width=0.003)

plt.show()
