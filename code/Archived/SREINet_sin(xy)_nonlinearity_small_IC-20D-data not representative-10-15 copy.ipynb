# %% [markdown]
# ## **SREINet dealing with nonseparable multivariate candidate functions**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append("../utilities")

# Import necessary libraries
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG

# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

def odefun_scalable(t, x, n_oscillators=10, coupling_strength=1.0, damping=0.1, nonlinear_strength=1.0):
    """
    Scalable ODE function for n coupled oscillators with sin(x_i * x_{i+1}) nearest neighbor nonlinearity
    
    Parameters:
    t: time
    x: state vector [x1, x1', x2, x2', ..., xn, xn']
    n_oscillators: number of oscillators
    coupling_strength: strength of linear coupling between adjacent oscillators
    damping: damping coefficient
    nonlinear_strength: strength of nonlinear coupling with nearest neighbor only
    
    Returns:
    dx/dt: time derivative of state vector
    
    Each oscillator i follows:
    x_i' = x_i'
    x_i'' = -x_i - damping*x_i' + coupling_strength*0.1*(x_{i-1} + x_{i+1} - 2*x_i) - nonlinear_strength*sin(x_i * x_{i+1})
    """
    n = n_oscillators
    dx = np.zeros_like(x)
    
    # For each oscillator i, we have:
    # x[2*i] = position of oscillator i
    # x[2*i+1] = velocity of oscillator i
    
    for i in range(n):
        pos_idx = 2 * i      # position index
        vel_idx = 2 * i + 1  # velocity index
        
        # Position derivative = velocity
        dx[pos_idx] = x[vel_idx]
        
        # Velocity derivative = acceleration
        # Basic oscillator: -x_i
        acceleration = -x[pos_idx]
        
        # Damping: -damping * x_i'
        acceleration -= damping * x[vel_idx]
        
        # Linear coupling with neighbors (periodic boundary conditions)
        prev_i = (i - 1) % n
        next_i = (i + 1) % n
        acceleration -= coupling_strength * 0.1 * (x[2*prev_i] + x[2*next_i] - 2*x[pos_idx])
        
        #acceleration -= nonlinear_strength * 0.2*np.sin(x[pos_idx] * x[vel_idx])
        
        dx[vel_idx] = acceleration
    
    return dx


# Configuration parameters
n_oscillators = 3  # Change this to scale the system
t_span = (0, 30)                    

# Generate initial conditions for n oscillators
# Each oscillator needs [position, velocity]
np.random.seed(42)  # for reproducibility
y0 = []
for i in range(n_oscillators):
    # Small random initial positions and velocities
    pos = 2.0 * np.random.randn()
    vel = 0.5 * np.random.randn()
    y0.extend([pos, vel])

dt = 0.01


# Initialize DataGenerator with correct parameters
myDG = DG.DataGenerator(
    initial_conditions=[y0],         # list of ICs
    T=t_span[1],                     # end time
    dt=dt,                           # time step
    t0=t_span[0],                    # start time
    random_state=42                  # for reproducibility
)

# Create a wrapper function for the scalable ODE with fixed parameters
def ode_wrapper(t, x):
    return odefun_scalable(t, x, n_oscillators=n_oscillators, 
                          coupling_strength=1.0, damping=0.2, nonlinear_strength=1.0)

x_train, dx_train = myDG.generate_ode_traj_with_ic(ode_wrapper, y0)

t_arr = np.arange(myDG.t0, myDG.T, myDG.dt)

# Plot trajectories for the first few oscillators
plt.figure(figsize=(12, 8))

# Plot phase space for first 3 oscillators
for i in range(min(3, n_oscillators)):
    plt.subplot(2, 3, i+1)
    pos_idx = 2 * i
    vel_idx = 2 * i + 1
    plt.plot(x_train[:, pos_idx], x_train[:, vel_idx])
    plt.xlabel(f'x{i+1} position')
    plt.ylabel(f'x{i+1} velocity')
    plt.title(f'Oscillator {i+1} Phase Space')

# Plot time series for first 3 oscillators
for i in range(min(3, n_oscillators)):
    plt.subplot(2, 3, i+4)
    pos_idx = 2 * i
    plt.plot(t_arr, x_train[:, pos_idx])
    plt.xlabel('Time')
    plt.ylabel(f'x{i+1} position')
    plt.title(f'Oscillator {i+1} Time Series')

plt.tight_layout()
plt.show()


#Shuffle data
training_input, training_output = x_train, dx_train
# Optionally, save a copy of the training input for simulation
training_input_for_sim = training_input.copy() # Saving a copy of training input for simulation (Before shuffling)

#shuffle data

training_input, training_output = myDG.shuffleData(training_input, training_output)

print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)
# Out:
# Training input shape: (3000, 6)
# Training output shape: (3000, 6)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 128
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables)
dim = training_input.shape[1] 

guess_highest_order_polynomial = 2 # depth of SREINet

layer_depth = guess_highest_order_polynomial

layer_neuron_nums_per_act_fn = [dim] * layer_depth

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn, 
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=0.1, seed=42), # stddev should be tuned for deep SREINet to avoid vanishing gradients
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

def reinitialize_model_weights(model):
    if hasattr(model.layers[1], 'reinitialize_weights'):
            tf.random.set_seed(np.random.randint(10000))
            model.layers[1].reinitialize_weights()
    else:
        print("SREINet does not have a reinitialize_weights() function.")

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Training with Pruning**

# %%
import time
np.set_printoptions(threshold=np.inf)

# Define a training step function
@tf.function
def train_step(model, optimizer, loss_fn, inputs, targets, binary_mask):        
    with tf.GradientTape() as tape:
        # Generate predictions and calculate loss
        predictions = model(inputs, training=False)
        loss = loss_fn(targets, predictions)   
        
    # Calculate gradients and update model weights
    gradients = tape.gradient(loss, model.trainable_variables)        

    masked_gradients = [tf.multiply(grad, mask) for grad, mask in zip(gradients, binary_mask)]

    optimizer.apply_gradients(zip(masked_gradients, model.trainable_variables))

    return loss

# Define a validation step function
@tf.function
def val_step(model, loss_fn, inputs, targets):
    # Generate predictions and calculate loss for validation data
    predictions = model(inputs, training=False)
    # predictions = model(inputs, training=False) 
    v_loss = loss_fn(targets, predictions)
    # Record the validation loss
    return v_loss   

def SREINet_fit_w_pruning(
    model,              # TensorFlow model to be trained
    training_input,     # Input features for training
    training_output,    # Target outputs for training
    batch_size,         # Number of samples per batch of computation
    validation_split,   # Fraction of data to be used as validation set
    epochs,             # Number of complete passes through the training dataset
    optimizer,          # Optimization algorithm for updating weights
    loss_fn,            # Loss function to measure model's performance
    pruning_schedule,   # Pruning schedule for gradually increasing the sparsity level
    data_type='float32',    # Data type of the tensors (default: 'float32')
    callbacks=None,         # List of callbacks for custom actions at various stages of training
    early_stopping_loss_threshold=0,       # Threshold for early stopping based on training and validation loss
    early_stopping_pruning_threshold=0,    # Threshold for early stopping based on pruning schedule
    verbose=0               # Verbosity mode (0 = silent, 1 = progress bar, etc.)
):
    # Cast the training input and output to the specified data type
    training_input = tf.cast(training_input, data_type)
    training_output = tf.cast(training_output, data_type)

    # Shuffle and batch the dataset, then split it into training and validation sets
    full_dataset = tf.data.Dataset.from_tensor_slices((training_input, training_output)).shuffle(buffer_size=1024)
    total_samples = training_input.shape[0]
    train_samples = int(total_samples * (1 - validation_split))
    
    # Apply the data type casting for each batch in the datasets
    train_dataset = full_dataset.take(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))
    val_dataset = full_dataset.skip(train_samples).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))

    # Initialize metrics for tracking training and validation loss
    train_loss = tf.keras.metrics.Mean(name='train_loss', dtype=data_type)
    val_loss = tf.keras.metrics.Mean(name='val_loss', dtype=data_type)
    
    # Parameters initialization
    binary_mask = [tf.ones_like(var) for var in model.trainable_variables]

    def generate_binary_mask_and_prune_weight(model, pruning_weight_threshold):
        binary_masks = []  # Initialize list to hold binary masks
        
        # Iterate over each variable to apply the pruning threshold and generate masks
        for var in model.trainable_variables:
            # Generate a binary mask where weights above the PRUNING_WEIGHT_THRESHOLD are marked with 1, others with 0
            mask = tf.cast(tf.abs(var) >= pruning_weight_threshold, var.dtype)

            # Update the mask at position (0, 0) to be 1 using tf.tensor_scatter_nd_update (To Avoid the constant term being pruned)
            indices = tf.constant([[0, 0]])  # Specify the indices to update
            updates = tf.constant([1], dtype=mask.dtype)  # Specify the value to update
            mask = tf.tensor_scatter_nd_update(mask, indices, updates)

            binary_masks.append(mask)  # Add the generated mask to the list            

            # Apply mask to modify weights by setting weights below PRUNING_WEIGHT_THRESHOLD to zero
            modified_weight = var * mask
            var.assign(modified_weight)            
        return binary_masks

    # Prepare a dictionary to track the training history
    history = {'loss': [], 'val_loss': []}

    # Before the training loop starts
    if callbacks:
        for callback in callbacks:
            # Assign the model to the callback
            callback.set_model(model)

            # Manually setting params before calling any methods that might depend on them
            callback.params = {
                'epochs': epochs,  # Number of epochs
                # You can add more parameters here as needed
            }

            # Now call on_train_begin with all properties set
            callback.on_train_begin(logs={'loss_threshold': early_stopping_loss_threshold})

    training_start_time = time.time()
    # Execute the training loop
    for epoch in range(epochs):
        # Notify callbacks that the epoch has started
        if callbacks:
            epoch_logs = {}
            for callback in callbacks:
                callback.on_epoch_begin(epoch, logs=epoch_logs)

        if verbose: 
            eopoch_start_time = time.time()

        # Reset state of metrics at the start of each epoch
        train_loss.reset_states()
        val_loss.reset_states()

        # Re-shuffle training data for this epoch
        train_dataset = full_dataset.take(train_samples).shuffle(buffer_size=train_samples, seed=epoch).batch(batch_size).map(lambda x, y: (tf.cast(x, data_type), tf.cast(y, data_type)))

        # Retrieve the current pruning schedule threshold
        current_pruning_threshold = pruning_schedule[epoch]
        binary_mask = generate_binary_mask_and_prune_weight(model, current_pruning_threshold)
        
        layer_losses_sum = None
        layer_indices = [i for i, layer in enumerate(model.layers) if layer.trainable]
        # Process each batch in the training dataset
        for train_inputs, train_targets in train_dataset:           
            loss = train_step(model = model, 
                            optimizer = optimizer, 
                            loss_fn = loss_fn,
                            inputs = train_inputs, 
                            targets = train_targets, 
                            binary_mask = binary_mask)    
            # Record the loss
            train_loss(loss)

        # Process each batch in the validation dataset
        for val_inputs, val_targets in val_dataset:
            v_loss = val_step(model = model, 
                                loss_fn = loss_fn,
                                inputs = val_inputs, 
                                targets = val_targets)
            val_loss(v_loss)

        # Append the average losses for this epoch to the history
        history['loss'].append(train_loss.result().numpy())
        history['val_loss'].append(val_loss.result().numpy())
        #calculate the average of val_loss
        
        # Current Losses
        current_train_loss = train_loss.result().numpy()
        current_val_loss = val_loss.result().numpy()

        # Notify callbacks that the epoch has ended
        epoch_logs = {'loss': current_train_loss, 'val_loss': current_val_loss}
        if callbacks:
            for callback in callbacks:
                callback.on_epoch_end(epoch, logs=epoch_logs)
    
        if verbose:
            epoch_time = time.time() - eopoch_start_time
            total_layers = len(model.layers)
            trainable_layer_count = sum(1 for layer in model.layers if layer.trainable)
            print(f"Epoch {epoch + 1:3.0f}:"
                f"  Train Loss: {current_train_loss:9.4e}"
                f",  Validation Loss: {current_val_loss:9.4e}"
                # f",  Trainable Layers ({trainable_layer_count}/{total_layers})"
                f",  Epoch Time: {epoch_time:.2f}s"  
                f",  Current Pruning Threshold: {current_pruning_threshold:.5g}")    
            
        if model.stop_training: # Stop training if all the layers are untrianable
            break   

        # Check for early stopping
        if current_train_loss < early_stopping_loss_threshold and current_pruning_threshold > early_stopping_pruning_threshold:
            print(f"Early stopping at epoch {epoch+1} as train loss {current_val_loss:.12f} is below the threshold {early_stopping_loss_threshold:.12f}")
            break

    # After the training loop ends
    training_time = time.time() - training_start_time
    print(f'Traininng Stopped. Time elapsed: {training_time:.2f}s')
    if callbacks:
        for callback in callbacks:
            callback.on_train_end(logs={'final_loss': current_train_loss, 'final_val_loss': current_val_loss})
    
    # Return the history containing training and validation losses
    return history

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.08 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 15
PRUNING_EPOCHS_PER_PERIOD = 40
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_schedule as ps

# Define the pruning schedule
pruning_schedule = ps.pruning_schedule_ramp(maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD, 
                                                    steps_per_period=PRUNING_EPOCHS_PER_PERIOD, 
                                                    num_periods=N_PERIODS, 
                                                    #zero_percentage=0.10,
                                                    show_plot=True)

# %% [markdown]
# ### Training

# %%
#Setup
callbacks = []

EARLY_STOPPING_LOSS_THRESHOLD = 1e-14   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.02

training_histories = []
weights_list = []

# %%
#change 0 to a other number if you want to start training from other dimensions
for i in range(0, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    reinitialize_model_weights(model)
    output = training_output[:, i:i+1]

    history = SREINet_fit_w_pruning(
        model,                   # Model to train
        training_input,             # Input data for training
        output,                     # Output data for training
        batch_size=MINI_BATCH_SIZE, # Number of samples per gradient update
        validation_split=0.20,      # Fraction of the training data to be used as validation data
        epochs=round(NUM_EPOCHS),   # Number of times the entire training dataset is passed through the model
        optimizer=my_optimizer,     # Optimizer to use for training
        pruning_schedule = pruning_schedule, # Pruning schedule for gradually increasing the sparsity level
        loss_fn=loss_fn,            # Loss function to use for training
        data_type=MY_DATA_TYPE,     # Data type to use for training
        callbacks= callbacks,       # List of callbacks to apply during training
        early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,# Threshold for early stopping (Layer Based)
        early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD, # Threshold for early stopping (Pruning Based)
        verbose=1                   # Hide the epoch steps
    )
    
    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([model.get_layer('SREINet').get_weights()])
# Out:
# Training dimension 1...
# Epoch   1:  Train Loss: 9.7529e-02,  Validation Loss: 3.7837e-02,  Epoch Time: 0.08s,  Current Pruning Threshold: 0
# Epoch   2:  Train Loss: 2.0401e-02,  Validation Loss: 9.1617e-03,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch   3:  Train Loss: 5.1737e-03,  Validation Loss: 2.7836e-03,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch   4:  Train Loss: 2.0061e-03,  Validation Loss: 1.4263e-03,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch   5:  Train Loss: 1.1535e-03,  Validation Loss: 9.7525e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch   6:  Train Loss: 8.4117e-04,  Validation Loss: 7.0918e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch   7:  Train Loss: 6.7531e-04,  Validation Loss: 5.6323e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch   8:  Train Loss: 5.7172e-04,  Validation Loss: 5.7183e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch   9:  Train Loss: 4.9206e-04,  Validation Loss: 4.2253e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  10:  Train Loss: 4.2846e-04,  Validation Loss: 4.1033e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch  11:  Train Loss: 3.7673e-04,  Validation Loss: 3.2160e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00093518
# Epoch  12:  Train Loss: 3.3613e-04,  Validation Loss: 3.1866e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0020939
# Epoch  13:  Train Loss: 3.0165e-04,  Validation Loss: 2.6215e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.003697
# Epoch  14:  Train Loss: 2.6455e-04,  Validation Loss: 2.5672e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch  15:  Train Loss: 2.3284e-04,  Validation Loss: 2.0215e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0081563
# Epoch  16:  Train Loss: 2.1260e-04,  Validation Loss: 2.0174e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.01096
# Epoch  17:  Train Loss: 1.8387e-04,  Validation Loss: 1.6997e-04,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.014105
# Epoch  18:  Train Loss: 1.7138e-04,  Validation Loss: 1.5142e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.017553
# Epoch  19:  Train Loss: 1.4559e-04,  Validation Loss: 1.3130e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.021264
# Epoch  20:  Train Loss: 1.2534e-04,  Validation Loss: 1.1262e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.025194
# Epoch  21:  Train Loss: 1.0485e-04,  Validation Loss: 9.8142e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.029299
# Epoch  22:  Train Loss: 1.8146e-04,  Validation Loss: 1.3192e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch  23:  Train Loss: 1.4323e-04,  Validation Loss: 1.1326e-04,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.037834
# Epoch  24:  Train Loss: 1.7763e-04,  Validation Loss: 1.2441e-04,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.042166
# Epoch  25:  Train Loss: 2.0313e-04,  Validation Loss: 8.4914e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.046471
# Epoch  26:  Train Loss: 1.5821e-04,  Validation Loss: 8.9140e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch  27:  Train Loss: 1.4403e-04,  Validation Loss: 8.0445e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch  28:  Train Loss: 5.9349e-05,  Validation Loss: 4.4672e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.058736
# Epoch  29:  Train Loss: 4.5071e-05,  Validation Loss: 4.3968e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.062447
# Epoch  30:  Train Loss: 6.4720e-05,  Validation Loss: 5.4240e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch  31:  Train Loss: 1.1021e-04,  Validation Loss: 6.0517e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.06904
# Epoch  32:  Train Loss: 6.2270e-04,  Validation Loss: 2.3241e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch  33:  Train Loss: 1.5310e-04,  Validation Loss: 9.2816e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch  34:  Train Loss: 6.8771e-05,  Validation Loss: 5.7673e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.076303
# Epoch  35:  Train Loss: 1.9435e-04,  Validation Loss: 7.1481e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.077906
# Epoch  36:  Train Loss: 1.0671e-04,  Validation Loss: 6.1908e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079065
# Epoch  37:  Train Loss: 5.0532e-05,  Validation Loss: 3.6652e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079766
# Epoch  38:  Train Loss: 3.8307e-05,  Validation Loss: 3.4027e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch  39:  Train Loss: 3.4000e-05,  Validation Loss: 3.2503e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch  40:  Train Loss: 3.0767e-05,  Validation Loss: 3.2540e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch  41:  Train Loss: 2.7157e-05,  Validation Loss: 2.6299e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  42:  Train Loss: 2.2518e-05,  Validation Loss: 1.9476e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  43:  Train Loss: 1.9446e-05,  Validation Loss: 1.7490e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch  44:  Train Loss: 1.6841e-05,  Validation Loss: 1.5643e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch  45:  Train Loss: 1.6164e-05,  Validation Loss: 1.6606e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch  46:  Train Loss: 1.5141e-05,  Validation Loss: 1.2784e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  47:  Train Loss: 1.4426e-05,  Validation Loss: 1.3285e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  48:  Train Loss: 1.4094e-05,  Validation Loss: 1.3096e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  49:  Train Loss: 1.3391e-05,  Validation Loss: 1.1601e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  50:  Train Loss: 1.3405e-05,  Validation Loss: 1.4003e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch  51:  Train Loss: 1.2682e-05,  Validation Loss: 1.1715e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00093518
# Epoch  52:  Train Loss: 1.2502e-05,  Validation Loss: 1.2010e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0020939
# Epoch  53:  Train Loss: 1.2565e-05,  Validation Loss: 1.2742e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.003697
# Epoch  54:  Train Loss: 1.4820e-05,  Validation Loss: 1.3391e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch  55:  Train Loss: 1.5177e-05,  Validation Loss: 1.4715e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0081563
# Epoch  56:  Train Loss: 1.3375e-05,  Validation Loss: 1.1867e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.01096
# Epoch  57:  Train Loss: 1.3318e-05,  Validation Loss: 1.4400e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.014105
# Epoch  58:  Train Loss: 1.2956e-05,  Validation Loss: 1.1271e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.017553
# Epoch  59:  Train Loss: 1.2593e-05,  Validation Loss: 1.2744e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.021264
# Epoch  60:  Train Loss: 1.2253e-05,  Validation Loss: 1.1307e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.025194
# Epoch  61:  Train Loss: 1.1652e-05,  Validation Loss: 1.1981e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.029299
# Epoch  62:  Train Loss: 1.1371e-05,  Validation Loss: 1.0705e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch  63:  Train Loss: 1.1598e-05,  Validation Loss: 1.1532e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.037834
# Epoch  64:  Train Loss: 1.0920e-05,  Validation Loss: 1.0396e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch  65:  Train Loss: 2.0828e-05,  Validation Loss: 1.7205e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.046471
# Epoch  66:  Train Loss: 1.7501e-05,  Validation Loss: 1.7933e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch  67:  Train Loss: 1.7003e-05,  Validation Loss: 1.6230e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch  68:  Train Loss: 2.1925e-05,  Validation Loss: 2.0077e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.058736
# Epoch  69:  Train Loss: 1.8612e-05,  Validation Loss: 2.0235e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch  70:  Train Loss: 1.7483e-05,  Validation Loss: 1.7317e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch  71:  Train Loss: 1.6702e-05,  Validation Loss: 1.5932e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.06904
# Epoch  72:  Train Loss: 1.5916e-05,  Validation Loss: 1.6187e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch  73:  Train Loss: 5.0788e-05,  Validation Loss: 2.3548e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch  74:  Train Loss: 1.4850e-05,  Validation Loss: 1.1641e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.076303
# Epoch  75:  Train Loss: 1.0648e-05,  Validation Loss: 9.3061e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.077906
# Epoch  76:  Train Loss: 9.3801e-06,  Validation Loss: 8.7655e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079065
# Epoch  77:  Train Loss: 8.7349e-06,  Validation Loss: 8.5102e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079766
# Epoch  78:  Train Loss: 8.2022e-06,  Validation Loss: 7.9723e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch  79:  Train Loss: 7.8872e-06,  Validation Loss: 7.8580e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch  80:  Train Loss: 7.4968e-06,  Validation Loss: 7.3156e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch  81:  Train Loss: 6.8057e-06,  Validation Loss: 6.1234e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  82:  Train Loss: 5.7317e-06,  Validation Loss: 4.7425e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  83:  Train Loss: 4.8624e-06,  Validation Loss: 4.7577e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  84:  Train Loss: 4.4091e-06,  Validation Loss: 3.8259e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch  85:  Train Loss: 4.2035e-06,  Validation Loss: 3.9819e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  86:  Train Loss: 3.9616e-06,  Validation Loss: 3.7648e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  87:  Train Loss: 3.7009e-06,  Validation Loss: 3.6874e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  88:  Train Loss: 3.5487e-06,  Validation Loss: 3.6296e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  89:  Train Loss: 3.4803e-06,  Validation Loss: 3.2614e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch  90:  Train Loss: 3.2945e-06,  Validation Loss: 3.0164e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch  91:  Train Loss: 3.2015e-06,  Validation Loss: 3.1475e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00093518
# Epoch  92:  Train Loss: 3.5441e-06,  Validation Loss: 2.9360e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0020939
# Epoch  93:  Train Loss: 6.5081e-06,  Validation Loss: 4.9371e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.003697
# Epoch  94:  Train Loss: 4.8864e-06,  Validation Loss: 4.4670e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch  95:  Train Loss: 4.8067e-06,  Validation Loss: 4.7450e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0081563
# Epoch  96:  Train Loss: 4.3742e-06,  Validation Loss: 4.3242e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.01096
# Epoch  97:  Train Loss: 4.3523e-06,  Validation Loss: 4.0038e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.014105
# Epoch  98:  Train Loss: 5.6037e-06,  Validation Loss: 5.4327e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.017553
# Epoch  99:  Train Loss: 5.2672e-06,  Validation Loss: 4.5992e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.021264
# Epoch 100:  Train Loss: 4.8818e-06,  Validation Loss: 5.0871e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.025194
# Epoch 101:  Train Loss: 4.9580e-06,  Validation Loss: 4.6183e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.029299
# Epoch 102:  Train Loss: 4.8383e-06,  Validation Loss: 4.5830e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch 103:  Train Loss: 4.5823e-06,  Validation Loss: 4.1218e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.037834
# Epoch 104:  Train Loss: 4.5501e-06,  Validation Loss: 4.5201e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch 105:  Train Loss: 4.4068e-06,  Validation Loss: 4.3591e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.046471
# Epoch 106:  Train Loss: 4.3819e-06,  Validation Loss: 4.1385e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch 107:  Train Loss: 4.1873e-06,  Validation Loss: 4.3173e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.054806
# Epoch 108:  Train Loss: 4.2708e-06,  Validation Loss: 3.9107e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.058736
# Epoch 109:  Train Loss: 4.1319e-06,  Validation Loss: 4.1404e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch 110:  Train Loss: 4.0537e-06,  Validation Loss: 3.8515e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 111:  Train Loss: 4.0312e-06,  Validation Loss: 4.0055e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.06904
# Epoch 112:  Train Loss: 4.0371e-06,  Validation Loss: 3.9683e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch 113:  Train Loss: 3.9136e-06,  Validation Loss: 4.2925e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch 114:  Train Loss: 3.8593e-06,  Validation Loss: 3.7870e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.076303
# Epoch 115:  Train Loss: 3.6423e-06,  Validation Loss: 3.8086e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.077906
# Epoch 116:  Train Loss: 3.8149e-06,  Validation Loss: 3.4725e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079065
# Epoch 117:  Train Loss: 3.7007e-06,  Validation Loss: 3.4773e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079766
# Epoch 118:  Train Loss: 3.6224e-06,  Validation Loss: 3.4431e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 119:  Train Loss: 3.5902e-06,  Validation Loss: 3.7320e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 120:  Train Loss: 3.5161e-06,  Validation Loss: 3.4911e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 121:  Train Loss: 3.5019e-06,  Validation Loss: 3.1553e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 122:  Train Loss: 3.2195e-06,  Validation Loss: 2.9560e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 123:  Train Loss: 3.0012e-06,  Validation Loss: 3.1341e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 124:  Train Loss: 2.7983e-06,  Validation Loss: 2.7279e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 125:  Train Loss: 2.7302e-06,  Validation Loss: 2.6352e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 126:  Train Loss: 2.5924e-06,  Validation Loss: 2.4858e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 127:  Train Loss: 2.4302e-06,  Validation Loss: 2.4676e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 128:  Train Loss: 2.3679e-06,  Validation Loss: 2.2744e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 129:  Train Loss: 2.2217e-06,  Validation Loss: 2.5239e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 130:  Train Loss: 2.1479e-06,  Validation Loss: 1.9023e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch 131:  Train Loss: 2.4517e-06,  Validation Loss: 2.1364e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.00093518
# Epoch 132:  Train Loss: 2.4276e-06,  Validation Loss: 2.1952e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0020939
# Epoch 133:  Train Loss: 2.6863e-06,  Validation Loss: 2.3584e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.003697
# Epoch 134:  Train Loss: 2.5451e-06,  Validation Loss: 2.2465e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch 135:  Train Loss: 3.9664e-06,  Validation Loss: 3.1401e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0081563
# Epoch 136:  Train Loss: 3.6467e-06,  Validation Loss: 3.5876e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.01096
# Epoch 137:  Train Loss: 3.3300e-06,  Validation Loss: 3.2460e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.014105
# Epoch 138:  Train Loss: 3.2261e-06,  Validation Loss: 2.8586e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.017553
# Epoch 139:  Train Loss: 3.1971e-06,  Validation Loss: 2.9787e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.021264
# Epoch 140:  Train Loss: 3.2100e-06,  Validation Loss: 3.0266e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.025194
# Epoch 141:  Train Loss: 3.1463e-06,  Validation Loss: 2.8770e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.029299
# Epoch 142:  Train Loss: 3.1330e-06,  Validation Loss: 3.0659e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch 143:  Train Loss: 3.0613e-06,  Validation Loss: 3.2928e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.037834
# Epoch 144:  Train Loss: 2.9867e-06,  Validation Loss: 3.0841e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.042166
# Epoch 145:  Train Loss: 3.0243e-06,  Validation Loss: 3.0154e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.046471
# Epoch 146:  Train Loss: 3.0324e-06,  Validation Loss: 2.9028e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch 147:  Train Loss: 2.9907e-06,  Validation Loss: 3.0068e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.054806
# Epoch 148:  Train Loss: 2.9481e-06,  Validation Loss: 2.7841e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.058736
# Epoch 149:  Train Loss: 2.8760e-06,  Validation Loss: 2.8895e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch 150:  Train Loss: 2.9374e-06,  Validation Loss: 2.8909e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 151:  Train Loss: 2.8881e-06,  Validation Loss: 2.7263e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.06904
# Epoch 152:  Train Loss: 2.7862e-06,  Validation Loss: 2.9640e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch 153:  Train Loss: 2.7361e-06,  Validation Loss: 2.8944e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch 154:  Train Loss: 2.8239e-06,  Validation Loss: 2.6920e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.076303
# Epoch 155:  Train Loss: 2.8085e-06,  Validation Loss: 2.6656e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.077906
# Epoch 156:  Train Loss: 2.7089e-06,  Validation Loss: 2.7411e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079065
# Epoch 157:  Train Loss: 2.7666e-06,  Validation Loss: 2.7786e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079766
# Epoch 158:  Train Loss: 2.7262e-06,  Validation Loss: 2.7920e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 159:  Train Loss: 2.8051e-06,  Validation Loss: 2.7999e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 160:  Train Loss: 2.7128e-06,  Validation Loss: 2.6797e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 161:  Train Loss: 2.6388e-06,  Validation Loss: 2.6845e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 162:  Train Loss: 2.4499e-06,  Validation Loss: 2.4804e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 163:  Train Loss: 2.2531e-06,  Validation Loss: 2.2183e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 164:  Train Loss: 2.1463e-06,  Validation Loss: 1.9559e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 165:  Train Loss: 2.0127e-06,  Validation Loss: 1.9245e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 166:  Train Loss: 1.8886e-06,  Validation Loss: 1.8186e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 167:  Train Loss: 1.8136e-06,  Validation Loss: 1.8972e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 168:  Train Loss: 1.6840e-06,  Validation Loss: 1.7503e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 169:  Train Loss: 1.5556e-06,  Validation Loss: 1.5888e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 170:  Train Loss: 1.4995e-06,  Validation Loss: 1.3072e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch 171:  Train Loss: 1.4452e-06,  Validation Loss: 1.3331e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.00093518
# Epoch 172:  Train Loss: 1.6322e-06,  Validation Loss: 1.3320e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0020939
# Epoch 173:  Train Loss: 2.1780e-06,  Validation Loss: 1.6899e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.003697
# Epoch 174:  Train Loss: 1.7755e-06,  Validation Loss: 1.6167e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch 175:  Train Loss: 1.8428e-06,  Validation Loss: 1.6440e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0081563
# Epoch 176:  Train Loss: 4.3087e-06,  Validation Loss: 2.6633e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.01096
# Epoch 177:  Train Loss: 2.7405e-06,  Validation Loss: 2.5201e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.014105
# Epoch 178:  Train Loss: 2.5440e-06,  Validation Loss: 2.4927e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.017553
# Epoch 179:  Train Loss: 2.4150e-06,  Validation Loss: 2.5154e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.021264
# Epoch 180:  Train Loss: 2.3872e-06,  Validation Loss: 2.3575e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.025194
# Epoch 181:  Train Loss: 2.4139e-06,  Validation Loss: 2.4453e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.029299
# Epoch 182:  Train Loss: 2.3922e-06,  Validation Loss: 2.4702e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch 183:  Train Loss: 2.3527e-06,  Validation Loss: 2.3410e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.037834
# Epoch 184:  Train Loss: 2.2636e-06,  Validation Loss: 2.2985e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch 185:  Train Loss: 2.2737e-06,  Validation Loss: 2.0449e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.046471
# Epoch 186:  Train Loss: 2.2898e-06,  Validation Loss: 2.2208e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch 187:  Train Loss: 2.2866e-06,  Validation Loss: 2.3280e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch 188:  Train Loss: 2.2559e-06,  Validation Loss: 2.1685e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.058736
# Epoch 189:  Train Loss: 2.2094e-06,  Validation Loss: 1.9339e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.062447
# Epoch 190:  Train Loss: 2.2133e-06,  Validation Loss: 2.0925e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 191:  Train Loss: 2.2380e-06,  Validation Loss: 2.1003e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.06904
# Epoch 192:  Train Loss: 2.1910e-06,  Validation Loss: 2.1432e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.071844
# Epoch 193:  Train Loss: 2.1875e-06,  Validation Loss: 2.1450e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.074274
# Epoch 194:  Train Loss: 2.0959e-06,  Validation Loss: 2.0310e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.076303
# Epoch 195:  Train Loss: 2.1411e-06,  Validation Loss: 1.9390e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.077906
# Epoch 196:  Train Loss: 2.1475e-06,  Validation Loss: 1.8210e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079065
# Epoch 197:  Train Loss: 2.0804e-06,  Validation Loss: 2.1249e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079766
# Epoch 198:  Train Loss: 2.0640e-06,  Validation Loss: 2.0365e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 199:  Train Loss: 2.0762e-06,  Validation Loss: 1.8847e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 200:  Train Loss: 2.0228e-06,  Validation Loss: 1.8785e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 201:  Train Loss: 1.9588e-06,  Validation Loss: 1.6616e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 202:  Train Loss: 1.7605e-06,  Validation Loss: 1.5854e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 203:  Train Loss: 1.6392e-06,  Validation Loss: 1.7540e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 204:  Train Loss: 1.4859e-06,  Validation Loss: 1.3378e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 205:  Train Loss: 1.3710e-06,  Validation Loss: 1.2554e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 206:  Train Loss: 1.2395e-06,  Validation Loss: 1.0822e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 207:  Train Loss: 1.1473e-06,  Validation Loss: 9.9617e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 208:  Train Loss: 1.0608e-06,  Validation Loss: 1.0452e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 209:  Train Loss: 9.6988e-07,  Validation Loss: 9.3585e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 210:  Train Loss: 9.0300e-07,  Validation Loss: 9.3587e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch 211:  Train Loss: 8.1662e-07,  Validation Loss: 7.8949e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.00093518
# Epoch 212:  Train Loss: 1.1728e-06,  Validation Loss: 9.1340e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0020939
# Epoch 213:  Train Loss: 1.7024e-06,  Validation Loss: 1.1801e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.003697
# Epoch 214:  Train Loss: 1.4422e-06,  Validation Loss: 1.1081e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch 215:  Train Loss: 1.0950e-06,  Validation Loss: 9.8519e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0081563
# Epoch 216:  Train Loss: 9.7442e-07,  Validation Loss: 9.1924e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.01096
# Epoch 217:  Train Loss: 4.1974e-06,  Validation Loss: 2.4591e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.014105
# Epoch 218:  Train Loss: 2.0591e-06,  Validation Loss: 1.7729e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.017553
# Epoch 219:  Train Loss: 1.8586e-06,  Validation Loss: 1.7393e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.021264
# Epoch 220:  Train Loss: 1.7933e-06,  Validation Loss: 1.7263e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.025194
# Epoch 221:  Train Loss: 1.7214e-06,  Validation Loss: 1.6917e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.029299
# Epoch 222:  Train Loss: 1.6498e-06,  Validation Loss: 1.6973e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch 223:  Train Loss: 1.6514e-06,  Validation Loss: 1.5468e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.037834
# Epoch 224:  Train Loss: 1.6592e-06,  Validation Loss: 1.5922e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch 225:  Train Loss: 1.6745e-06,  Validation Loss: 1.5239e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.046471
# Epoch 226:  Train Loss: 1.6359e-06,  Validation Loss: 1.4405e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch 227:  Train Loss: 1.6280e-06,  Validation Loss: 1.7236e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch 228:  Train Loss: 1.5727e-06,  Validation Loss: 1.5146e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.058736
# Epoch 229:  Train Loss: 1.5752e-06,  Validation Loss: 1.4840e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch 230:  Train Loss: 1.5703e-06,  Validation Loss: 1.4227e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 231:  Train Loss: 1.5263e-06,  Validation Loss: 1.4227e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.06904
# Epoch 232:  Train Loss: 1.5202e-06,  Validation Loss: 1.3534e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch 233:  Train Loss: 1.4901e-06,  Validation Loss: 1.4364e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch 234:  Train Loss: 1.5103e-06,  Validation Loss: 1.5213e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.076303
# Epoch 235:  Train Loss: 1.4856e-06,  Validation Loss: 1.4506e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.077906
# Epoch 236:  Train Loss: 1.4253e-06,  Validation Loss: 1.2863e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079065
# Epoch 237:  Train Loss: 1.4271e-06,  Validation Loss: 1.4345e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079766
# Epoch 238:  Train Loss: 1.4604e-06,  Validation Loss: 1.3611e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 239:  Train Loss: 2.8074e-05,  Validation Loss: 1.0730e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 240:  Train Loss: 7.8017e-06,  Validation Loss: 5.8090e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 241:  Train Loss: 3.1325e-06,  Validation Loss: 1.5071e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 242:  Train Loss: 1.1952e-06,  Validation Loss: 9.8295e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 243:  Train Loss: 9.2775e-07,  Validation Loss: 7.7640e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 244:  Train Loss: 7.4306e-07,  Validation Loss: 6.2222e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 245:  Train Loss: 6.0258e-07,  Validation Loss: 5.4291e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 246:  Train Loss: 5.4679e-07,  Validation Loss: 4.6385e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 247:  Train Loss: 4.8192e-07,  Validation Loss: 4.4957e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 248:  Train Loss: 4.2363e-07,  Validation Loss: 4.2881e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 249:  Train Loss: 3.6600e-07,  Validation Loss: 3.4217e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 250:  Train Loss: 3.2064e-07,  Validation Loss: 3.2038e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch 251:  Train Loss: 3.0751e-07,  Validation Loss: 2.7763e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.00093518
# Epoch 252:  Train Loss: 3.3678e-07,  Validation Loss: 2.8047e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0020939
# Epoch 253:  Train Loss: 4.6341e-07,  Validation Loss: 3.2720e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.003697
# Epoch 254:  Train Loss: 7.8100e-07,  Validation Loss: 4.2694e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch 255:  Train Loss: 1.2327e-06,  Validation Loss: 6.9405e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0081563
# Epoch 256:  Train Loss: 2.3854e-06,  Validation Loss: 1.3768e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.01096
# Epoch 257:  Train Loss: 3.6674e-06,  Validation Loss: 2.9488e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.014105
# Epoch 258:  Train Loss: 2.1448e-06,  Validation Loss: 1.8742e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.017553
# Epoch 259:  Train Loss: 1.5864e-06,  Validation Loss: 1.3290e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.021264
# Epoch 260:  Train Loss: 1.2439e-06,  Validation Loss: 1.1312e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.025194
# Epoch 261:  Train Loss: 1.1013e-06,  Validation Loss: 9.6004e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.029299
# Epoch 262:  Train Loss: 9.7400e-07,  Validation Loss: 9.5333e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.033529
# Epoch 263:  Train Loss: 9.2995e-07,  Validation Loss: 8.5423e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.037834
# Epoch 264:  Train Loss: 8.6694e-07,  Validation Loss: 8.3300e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch 265:  Train Loss: 8.3996e-07,  Validation Loss: 7.4004e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.046471
# Epoch 266:  Train Loss: 1.5540e-05,  Validation Loss: 8.9479e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch 267:  Train Loss: 3.7435e-05,  Validation Loss: 1.0741e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch 268:  Train Loss: 8.0890e-06,  Validation Loss: 5.4759e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.058736
# Epoch 269:  Train Loss: 4.6441e-06,  Validation Loss: 4.3405e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.062447
# Epoch 270:  Train Loss: 3.8255e-06,  Validation Loss: 3.4628e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 271:  Train Loss: 1.0629e-05,  Validation Loss: 6.5024e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.06904
# Epoch 272:  Train Loss: 5.9552e-06,  Validation Loss: 5.4492e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.071844
# Epoch 273:  Train Loss: 4.9742e-06,  Validation Loss: 4.6431e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch 274:  Train Loss: 4.8070e-06,  Validation Loss: 4.5287e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.076303
# Epoch 275:  Train Loss: 4.5937e-06,  Validation Loss: 4.0773e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.077906
# Epoch 276:  Train Loss: 4.2342e-06,  Validation Loss: 4.0210e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079065
# Epoch 277:  Train Loss: 2.5660e-04,  Validation Loss: 1.4248e-04,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079766
# Epoch 278:  Train Loss: 1.3031e-04,  Validation Loss: 1.0108e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 279:  Train Loss: 8.3671e-05,  Validation Loss: 6.4543e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 280:  Train Loss: 5.7926e-05,  Validation Loss: 4.9786e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 281:  Train Loss: 2.6280e-05,  Validation Loss: 6.9418e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 282:  Train Loss: 4.3916e-06,  Validation Loss: 3.0127e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 283:  Train Loss: 1.6732e-06,  Validation Loss: 9.0077e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 284:  Train Loss: 7.5135e-07,  Validation Loss: 6.2679e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 285:  Train Loss: 5.2203e-07,  Validation Loss: 4.7822e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 286:  Train Loss: 3.6742e-07,  Validation Loss: 3.2081e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 287:  Train Loss: 2.7212e-07,  Validation Loss: 2.3557e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 288:  Train Loss: 2.0625e-07,  Validation Loss: 1.7605e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 289:  Train Loss: 1.6374e-07,  Validation Loss: 1.5186e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 290:  Train Loss: 1.3517e-07,  Validation Loss: 1.3247e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.00023448
# Epoch 291:  Train Loss: 1.1450e-07,  Validation Loss: 9.9312e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00093518
# Epoch 292:  Train Loss: 2.0388e-07,  Validation Loss: 1.3216e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0020939
# Epoch 293:  Train Loss: 1.6964e-06,  Validation Loss: 4.5624e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.003697
# Epoch 294:  Train Loss: 1.4174e-06,  Validation Loss: 6.4970e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch 295:  Train Loss: 4.1112e-06,  Validation Loss: 1.3227e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0081563
# Epoch 296:  Train Loss: 5.1604e-06,  Validation Loss: 2.7179e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.01096
# Epoch 297:  Train Loss: 2.0972e-06,  Validation Loss: 1.3920e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.014105
# Epoch 298:  Train Loss: 4.6178e-05,  Validation Loss: 2.6278e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.017553
# Epoch 299:  Train Loss: 2.1889e-05,  Validation Loss: 1.6221e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.021264
# Epoch 300:  Train Loss: 1.3884e-05,  Validation Loss: 1.1243e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.025194
# Epoch 301:  Train Loss: 8.8933e-06,  Validation Loss: 7.3376e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.029299
# Epoch 302:  Train Loss: 8.3195e-06,  Validation Loss: 6.2604e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch 303:  Train Loss: 5.6649e-06,  Validation Loss: 5.6383e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.037834
# Epoch 304:  Train Loss: 4.3682e-06,  Validation Loss: 4.3295e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.042166
# Epoch 305:  Train Loss: 3.6205e-06,  Validation Loss: 3.2741e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.046471
# Epoch 306:  Train Loss: 3.0891e-06,  Validation Loss: 2.7865e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.050701
# Epoch 307:  Train Loss: 2.6931e-06,  Validation Loss: 2.4156e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.054806
# Epoch 308:  Train Loss: 9.5065e-05,  Validation Loss: 2.1716e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.058736
# Epoch 309:  Train Loss: 1.5741e-05,  Validation Loss: 8.7970e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch 310:  Train Loss: 6.4245e-06,  Validation Loss: 4.5847e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 311:  Train Loss: 4.5116e-06,  Validation Loss: 3.9289e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.06904
# Epoch 312:  Train Loss: 3.7593e-06,  Validation Loss: 3.2144e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.071844
# Epoch 313:  Train Loss: 3.3707e-06,  Validation Loss: 3.2110e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.074274
# Epoch 314:  Train Loss: 2.8853e-06,  Validation Loss: 2.6234e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.076303
# Epoch 315:  Train Loss: 1.3398e-04,  Validation Loss: 5.3692e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.077906
# Epoch 316:  Train Loss: 7.8495e-05,  Validation Loss: 2.1879e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079065
# Epoch 317:  Train Loss: 1.1872e-05,  Validation Loss: 7.3914e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079766
# Epoch 318:  Train Loss: 3.9520e-06,  Validation Loss: 2.1188e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 319:  Train Loss: 2.1522e-06,  Validation Loss: 1.8890e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 320:  Train Loss: 1.8387e-06,  Validation Loss: 1.9357e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 321:  Train Loss: 8.4450e-07,  Validation Loss: 3.2165e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 322:  Train Loss: 2.8515e-07,  Validation Loss: 1.6985e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 323:  Train Loss: 1.6162e-07,  Validation Loss: 1.5397e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 324:  Train Loss: 9.8393e-08,  Validation Loss: 7.9024e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 325:  Train Loss: 6.9686e-08,  Validation Loss: 5.3324e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 326:  Train Loss: 5.6421e-08,  Validation Loss: 5.2256e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 327:  Train Loss: 4.2742e-08,  Validation Loss: 3.7812e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 328:  Train Loss: 3.7661e-08,  Validation Loss: 3.2302e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 329:  Train Loss: 2.7278e-08,  Validation Loss: 2.4014e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 330:  Train Loss: 2.4130e-08,  Validation Loss: 1.7889e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.00023448
# Epoch 331:  Train Loss: 2.1838e-07,  Validation Loss: 8.8863e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.00093518
# Epoch 332:  Train Loss: 4.6693e-07,  Validation Loss: 3.3207e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0020939
# Epoch 333:  Train Loss: 5.3046e-07,  Validation Loss: 1.5658e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.003697
# Epoch 334:  Train Loss: 9.9655e-07,  Validation Loss: 4.8153e-07,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.0057257
# Epoch 335:  Train Loss: 2.6700e-06,  Validation Loss: 1.3925e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0081563
# Epoch 336:  Train Loss: 1.5844e-06,  Validation Loss: 1.4764e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.01096
# Epoch 337:  Train Loss: 1.3564e-06,  Validation Loss: 1.3615e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.014105
# Epoch 338:  Train Loss: 1.3290e-06,  Validation Loss: 1.2987e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.017553
# Epoch 339:  Train Loss: 1.3047e-06,  Validation Loss: 1.2767e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.021264
# Epoch 340:  Train Loss: 1.2504e-06,  Validation Loss: 9.8605e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.025194
# Epoch 341:  Train Loss: 1.1953e-06,  Validation Loss: 1.2579e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.029299
# Epoch 342:  Train Loss: 1.2130e-06,  Validation Loss: 1.0735e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch 343:  Train Loss: 1.1774e-06,  Validation Loss: 1.2094e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.037834
# Epoch 344:  Train Loss: 1.1548e-06,  Validation Loss: 1.0699e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch 345:  Train Loss: 1.1729e-06,  Validation Loss: 1.1997e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.046471
# Epoch 346:  Train Loss: 1.1402e-06,  Validation Loss: 1.2356e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch 347:  Train Loss: 1.1803e-06,  Validation Loss: 1.1306e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.054806
# Epoch 348:  Train Loss: 1.1744e-06,  Validation Loss: 1.1696e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.058736
# Epoch 349:  Train Loss: 1.1664e-06,  Validation Loss: 1.1284e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.062447
# Epoch 350:  Train Loss: 1.1103e-06,  Validation Loss: 1.1539e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 351:  Train Loss: 1.1127e-06,  Validation Loss: 1.0532e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.06904
# Epoch 352:  Train Loss: 1.1442e-06,  Validation Loss: 1.0950e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch 353:  Train Loss: 1.0938e-06,  Validation Loss: 9.8927e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.074274
# Epoch 354:  Train Loss: 1.1345e-06,  Validation Loss: 1.1517e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.076303
# Epoch 355:  Train Loss: 1.1199e-06,  Validation Loss: 1.1361e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.077906
# Epoch 356:  Train Loss: 1.0973e-06,  Validation Loss: 1.0222e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079065
# Epoch 357:  Train Loss: 1.1136e-06,  Validation Loss: 1.0712e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.079766
# Epoch 358:  Train Loss: 1.1255e-06,  Validation Loss: 1.0014e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 359:  Train Loss: 1.0863e-06,  Validation Loss: 9.7285e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 360:  Train Loss: 1.0900e-06,  Validation Loss: 1.0835e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 361:  Train Loss: 5.9394e-07,  Validation Loss: 4.4485e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 362:  Train Loss: 3.2473e-07,  Validation Loss: 1.9387e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 363:  Train Loss: 1.7470e-07,  Validation Loss: 9.8777e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 364:  Train Loss: 7.9718e-08,  Validation Loss: 6.6029e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 365:  Train Loss: 5.2844e-08,  Validation Loss: 4.1236e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 366:  Train Loss: 3.7002e-08,  Validation Loss: 3.0714e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 367:  Train Loss: 3.0975e-08,  Validation Loss: 2.2134e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 368:  Train Loss: 2.0903e-08,  Validation Loss: 1.4632e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 369:  Train Loss: 1.4146e-08,  Validation Loss: 1.3023e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 370:  Train Loss: 1.1373e-08,  Validation Loss: 1.0412e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch 371:  Train Loss: 4.5547e-08,  Validation Loss: 2.3004e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00093518
# Epoch 372:  Train Loss: 4.0353e-07,  Validation Loss: 2.0079e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0020939
# Epoch 373:  Train Loss: 3.3218e-07,  Validation Loss: 1.9228e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.003697
# Epoch 374:  Train Loss: 9.1908e-07,  Validation Loss: 4.5589e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch 375:  Train Loss: 2.7862e-07,  Validation Loss: 1.4275e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.0081563
# Epoch 376:  Train Loss: 2.4249e-06,  Validation Loss: 1.5460e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.01096
# Epoch 377:  Train Loss: 1.2434e-06,  Validation Loss: 1.0613e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.014105
# Epoch 378:  Train Loss: 1.1372e-06,  Validation Loss: 9.6928e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.017553
# Epoch 379:  Train Loss: 1.0627e-06,  Validation Loss: 1.0167e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.021264
# Epoch 380:  Train Loss: 1.0549e-06,  Validation Loss: 1.1649e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.025194
# Epoch 381:  Train Loss: 1.1039e-06,  Validation Loss: 9.8861e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.029299
# Epoch 382:  Train Loss: 1.0527e-06,  Validation Loss: 9.5945e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.033529
# Epoch 383:  Train Loss: 1.0429e-06,  Validation Loss: 1.0437e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.037834
# Epoch 384:  Train Loss: 1.0500e-06,  Validation Loss: 1.0120e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.042166
# Epoch 385:  Train Loss: 1.0577e-06,  Validation Loss: 1.0430e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.046471
# Epoch 386:  Train Loss: 1.0375e-06,  Validation Loss: 1.1491e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch 387:  Train Loss: 1.0012e-06,  Validation Loss: 1.0885e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch 388:  Train Loss: 9.8289e-07,  Validation Loss: 1.0297e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.058736
# Epoch 389:  Train Loss: 1.0277e-06,  Validation Loss: 1.0853e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch 390:  Train Loss: 1.0413e-06,  Validation Loss: 8.6994e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 391:  Train Loss: 9.6984e-07,  Validation Loss: 9.4031e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.06904
# Epoch 392:  Train Loss: 1.0206e-06,  Validation Loss: 1.0755e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch 393:  Train Loss: 1.0261e-06,  Validation Loss: 1.0053e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch 394:  Train Loss: 9.5139e-07,  Validation Loss: 9.5984e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.076303
# Epoch 395:  Train Loss: 1.0064e-06,  Validation Loss: 1.0120e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.077906
# ...
# Epoch  62:  Train Loss: 8.4185e-05,  Validation Loss: 8.3676e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch  63:  Train Loss: 7.9122e-05,  Validation Loss: 7.6133e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.037834
# Epoch  64:  Train Loss: 7.4676e-05,  Validation Loss: 7.4170e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch  65:  Train Loss: 7.1886e-05,  Validation Loss: 6.9382e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.046471
# Epoch  66:  Train Loss: 7.2106e-05,  Validation Loss: 6.6205e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.050701
# Epoch  67:  Train Loss: 9.0984e-05,  Validation Loss: 8.7681e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch  68:  Train Loss: 8.2656e-05,  Validation Loss: 8.7414e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.058736
# Epoch  69:  Train Loss: 8.0616e-05,  Validation Loss: 7.7459e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch  70:  Train Loss: 8.0465e-05,  Validation Loss: 8.0267e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch  71:  Train Loss: 7.7957e-05,  Validation Loss: 7.6765e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.06904
# Epoch  72:  Train Loss: 7.8757e-05,  Validation Loss: 7.6297e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch  73:  Train Loss: 7.8475e-05,  Validation Loss: 7.4692e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch  74:  Train Loss: 7.6202e-05,  Validation Loss: 7.6542e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.076303
# Epoch  75:  Train Loss: 7.6802e-05,  Validation Loss: 7.8804e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.077906
# Epoch  76:  Train Loss: 7.4687e-05,  Validation Loss: 7.6079e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079065
# Epoch  77:  Train Loss: 7.5210e-05,  Validation Loss: 7.7862e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079766
# Epoch  78:  Train Loss: 7.5938e-05,  Validation Loss: 7.7216e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch  79:  Train Loss: 7.5526e-05,  Validation Loss: 7.9524e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch  80:  Train Loss: 7.4414e-05,  Validation Loss: 7.4217e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch  81:  Train Loss: 5.7375e-05,  Validation Loss: 3.9345e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  82:  Train Loss: 2.8134e-05,  Validation Loss: 1.6494e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  83:  Train Loss: 1.1364e-05,  Validation Loss: 7.1961e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  84:  Train Loss: 4.9795e-06,  Validation Loss: 3.0233e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  85:  Train Loss: 2.1403e-06,  Validation Loss: 1.4447e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  86:  Train Loss: 1.0919e-06,  Validation Loss: 7.9423e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  87:  Train Loss: 6.3963e-07,  Validation Loss: 5.0619e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  88:  Train Loss: 4.2170e-07,  Validation Loss: 3.2178e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  89:  Train Loss: 3.0265e-07,  Validation Loss: 2.5688e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch  90:  Train Loss: 2.3715e-07,  Validation Loss: 1.9437e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch  91:  Train Loss: 2.2899e-07,  Validation Loss: 2.0810e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00093518
# Epoch  92:  Train Loss: 8.9123e-07,  Validation Loss: 3.5424e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0020939
# Epoch  93:  Train Loss: 5.2063e-07,  Validation Loss: 2.2627e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.003697
# Epoch  94:  Train Loss: 4.9459e-06,  Validation Loss: 2.2643e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch  95:  Train Loss: 2.2413e-06,  Validation Loss: 1.0932e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0081563
# Epoch  96:  Train Loss: 1.0772e-05,  Validation Loss: 3.7855e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.01096
# Epoch  97:  Train Loss: 1.0016e-05,  Validation Loss: 4.6081e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.014105
# Epoch  98:  Train Loss: 5.5460e-05,  Validation Loss: 2.4828e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.017553
# Epoch  99:  Train Loss: 1.8445e-05,  Validation Loss: 1.4220e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.021264
# Epoch 100:  Train Loss: 1.0579e-05,  Validation Loss: 7.5542e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.025194
# Epoch 101:  Train Loss: 6.4956e-06,  Validation Loss: 5.5334e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.029299
# Epoch 102:  Train Loss: 4.7306e-06,  Validation Loss: 4.1237e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch 103:  Train Loss: 3.4840e-06,  Validation Loss: 3.2517e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.037834
# Epoch 104:  Train Loss: 2.7461e-06,  Validation Loss: 2.5706e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch 105:  Train Loss: 2.3074e-06,  Validation Loss: 2.1106e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.046471
# Epoch 106:  Train Loss: 2.0030e-06,  Validation Loss: 1.8022e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.050701
# Epoch 107:  Train Loss: 1.7702e-06,  Validation Loss: 1.6916e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch 108:  Train Loss: 1.6588e-06,  Validation Loss: 1.5727e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.058736
# Epoch 109:  Train Loss: 2.2160e-05,  Validation Loss: 8.8275e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch 110:  Train Loss: 5.6687e-06,  Validation Loss: 4.1367e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 111:  Train Loss: 2.6465e-05,  Validation Loss: 1.4975e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.06904
# Epoch 112:  Train Loss: 2.1265e-05,  Validation Loss: 1.3856e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch 113:  Train Loss: 1.2842e-05,  Validation Loss: 1.1120e-05,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch 114:  Train Loss: 4.2430e-04,  Validation Loss: 1.4876e-04,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.076303
# Epoch 115:  Train Loss: 5.9792e-04,  Validation Loss: 3.4871e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.077906
# Epoch 116:  Train Loss: 2.6427e-04,  Validation Loss: 1.8989e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079065
# Epoch 117:  Train Loss: 1.9668e-04,  Validation Loss: 1.7989e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079766
# Epoch 118:  Train Loss: 2.8241e-04,  Validation Loss: 2.2175e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 119:  Train Loss: 1.8646e-04,  Validation Loss: 1.5510e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 120:  Train Loss: 1.5470e-04,  Validation Loss: 1.3820e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 121:  Train Loss: 7.4258e-05,  Validation Loss: 3.2233e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 122:  Train Loss: 1.2165e-05,  Validation Loss: 4.8940e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 123:  Train Loss: 2.9000e-06,  Validation Loss: 1.3419e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 124:  Train Loss: 6.6907e-07,  Validation Loss: 2.7822e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 125:  Train Loss: 1.9184e-07,  Validation Loss: 1.2337e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 126:  Train Loss: 1.0400e-07,  Validation Loss: 8.1162e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 127:  Train Loss: 7.6530e-08,  Validation Loss: 7.3178e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 128:  Train Loss: 6.7167e-08,  Validation Loss: 6.2883e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 129:  Train Loss: 5.5029e-08,  Validation Loss: 5.1424e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 130:  Train Loss: 5.1402e-08,  Validation Loss: 5.0695e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.00023448
# Epoch 131:  Train Loss: 1.2607e-07,  Validation Loss: 7.0163e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00093518
# Epoch 132:  Train Loss: 6.3952e-07,  Validation Loss: 3.0947e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0020939
# Epoch 133:  Train Loss: 7.1649e-07,  Validation Loss: 3.5972e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.003697
# Epoch 134:  Train Loss: 3.7706e-06,  Validation Loss: 1.6463e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch 135:  Train Loss: 1.3316e-06,  Validation Loss: 6.7109e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0081563
# Epoch 136:  Train Loss: 2.3085e-06,  Validation Loss: 3.5494e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.01096
# Epoch 137:  Train Loss: 2.5808e-07,  Validation Loss: 4.4803e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.014105
# Epoch 138:  Train Loss: 2.1622e-05,  Validation Loss: 5.2959e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.017553
# Epoch 139:  Train Loss: 3.4955e-06,  Validation Loss: 7.2977e-07,  Epoch Time: 0.06s,  Current Pruning Threshold: 0.021264
# Epoch 140:  Train Loss: 6.0516e-07,  Validation Loss: 2.4900e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.025194
# Epoch 141:  Train Loss: 2.2698e-04,  Validation Loss: 1.5250e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.029299
# Epoch 142:  Train Loss: 1.7024e-04,  Validation Loss: 1.4687e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch 143:  Train Loss: 1.5856e-04,  Validation Loss: 1.4698e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.037834
# Epoch 144:  Train Loss: 1.5945e-04,  Validation Loss: 1.6177e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch 145:  Train Loss: 1.5497e-04,  Validation Loss: 1.4847e-04,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.046471
# Epoch 146:  Train Loss: 1.6027e-04,  Validation Loss: 1.4772e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch 147:  Train Loss: 1.5524e-04,  Validation Loss: 1.7318e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch 148:  Train Loss: 1.5969e-04,  Validation Loss: 1.5867e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.058736
# Epoch 149:  Train Loss: 1.5365e-04,  Validation Loss: 1.5975e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch 150:  Train Loss: 1.5275e-04,  Validation Loss: 1.4682e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 151:  Train Loss: 1.5603e-04,  Validation Loss: 1.4973e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.06904
# Epoch 152:  Train Loss: 1.4914e-04,  Validation Loss: 1.5021e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.071844
# Epoch 153:  Train Loss: 1.5390e-04,  Validation Loss: 1.4567e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.074274
# Epoch 154:  Train Loss: 1.5363e-04,  Validation Loss: 1.3881e-04,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.076303
# Epoch 155:  Train Loss: 1.5503e-04,  Validation Loss: 1.5093e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.077906
# Epoch 156:  Train Loss: 1.5703e-04,  Validation Loss: 1.4278e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079065
# Epoch 157:  Train Loss: 1.5509e-04,  Validation Loss: 1.5792e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.079766
# Epoch 158:  Train Loss: 1.5717e-04,  Validation Loss: 1.5285e-04,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 159:  Train Loss: 1.5951e-04,  Validation Loss: 1.5083e-04,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.08
# Epoch 160:  Train Loss: 1.5554e-04,  Validation Loss: 1.4445e-04,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.08
# Epoch 161:  Train Loss: 6.3639e-05,  Validation Loss: 1.4210e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 162:  Train Loss: 8.0602e-06,  Validation Loss: 3.1995e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 163:  Train Loss: 2.1717e-06,  Validation Loss: 1.0144e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 164:  Train Loss: 3.7892e-07,  Validation Loss: 1.1344e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 165:  Train Loss: 9.3602e-08,  Validation Loss: 4.6847e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 166:  Train Loss: 3.0785e-08,  Validation Loss: 2.2641e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 167:  Train Loss: 2.0363e-08,  Validation Loss: 1.8337e-08,  Epoch Time: 0.02s,  Current Pruning Threshold: 0
# Epoch 168:  Train Loss: 1.6694e-08,  Validation Loss: 1.5892e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 169:  Train Loss: 1.4132e-08,  Validation Loss: 1.2936e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0
# Epoch 170:  Train Loss: 3.7383e-08,  Validation Loss: 2.2202e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00023448
# Epoch 171:  Train Loss: 6.6163e-08,  Validation Loss: 2.9092e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.00093518
# Epoch 172:  Train Loss: 3.0875e-08,  Validation Loss: 1.1392e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0020939
# Epoch 173:  Train Loss: 1.5062e-06,  Validation Loss: 1.6456e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.003697
# Epoch 174:  Train Loss: 6.0545e-07,  Validation Loss: 2.6900e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0057257
# Epoch 175:  Train Loss: 1.1373e-07,  Validation Loss: 2.2891e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.0081563
# Epoch 176:  Train Loss: 2.0486e-06,  Validation Loss: 5.2319e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.01096
# Epoch 177:  Train Loss: 4.7883e-06,  Validation Loss: 2.2828e-06,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.014105
# Epoch 178:  Train Loss: 9.0943e-07,  Validation Loss: 4.2220e-07,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.017553
# Epoch 179:  Train Loss: 7.7765e-05,  Validation Loss: 2.8982e-05,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.021264
# Epoch 180:  Train Loss: 1.2188e-05,  Validation Loss: 2.2089e-06,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.025194
# Epoch 181:  Train Loss: 1.1217e-06,  Validation Loss: 1.7105e-07,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.029299
# Epoch 182:  Train Loss: 1.3529e-07,  Validation Loss: 4.0371e-08,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.033529
# Epoch 183:  Train Loss: 2.5043e-08,  Validation Loss: 8.5556e-09,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.037834
# Epoch 184:  Train Loss: 3.4680e-09,  Validation Loss: 5.6732e-10,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.042166
# Epoch 185:  Train Loss: 2.2325e-10,  Validation Loss: 8.9147e-11,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.046471
# Epoch 186:  Train Loss: 3.4960e-11,  Validation Loss: 1.9624e-11,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.050701
# Epoch 187:  Train Loss: 8.0978e-12,  Validation Loss: 2.2646e-12,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.054806
# Epoch 188:  Train Loss: 9.0486e-13,  Validation Loss: 2.6023e-13,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.058736
# Epoch 189:  Train Loss: 9.0166e-14,  Validation Loss: 4.3147e-14,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.062447
# Epoch 190:  Train Loss: 1.8420e-14,  Validation Loss: 6.0278e-15,  Epoch Time: 0.03s,  Current Pruning Threshold: 0.065895
# Epoch 191:  Train Loss: 4.1535e-15,  Validation Loss: 1.5626e-15,  Epoch Time: 0.02s,  Current Pruning Threshold: 0.06904
# Early stopping at epoch 191 as train loss 0.000000000000 is below the threshold 0.000000000000
# Traininng Stopped. Time elapsed: 4.96s

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_set_labels(N):
    """
    Generate labels for variables up to dimension N
    For n-oscillator system, each oscillator has position and velocity
    """
    return ['Constant'] + [f'x{i}' for i in range(1, N+1)]

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
def coefficient_reconstruction(dim_index,
                                weights, 
                                minimum_coefficient_threshold = 1e-5,
                                coefficient_output_digits = 10, 
                                enable_coefficient_sorting = False):
    
    max_neurons = max(max(len(layer) for layer in SREINet) for SREINet in weights)
    
    labels = generate_set_labels(max_neurons - 1) # number of states = number of neurons - 1

    def explore_path(SREINet_index, layer, neuron, weight_product, label_counts, non_zero_paths):
        """
        Recursively explores non-zero paths in a neural network.
        """
        if layer == len(weights[SREINet_index]) - 1:
            non_zero_paths.append((label_counts, weight_product))
            return

        for next_neuron, weight in enumerate(weights[SREINet_index][layer][neuron]):
            if abs(weight) <= 1e-15:
                # Skip recursion if the weight is zero (if one weight is zero, the whole path will be eliminated)
                continue  
            new_weight_product = weight_product * weight
            next_label_counts = label_counts.copy()
            next_label_counts[labels[next_neuron]] = next_label_counts.get(labels[next_neuron], 0) + 1
            explore_path(SREINet_index, layer + 1, next_neuron, new_weight_product, next_label_counts, non_zero_paths)
    
    #beginning of the algorithm
    all_SREINet_products = []
    for SREINet_index, _ in enumerate(weights):
        non_zero_paths = []
        #collect all non-zero paths
        for neuron_index in range(len(weights[SREINet_index][0])):
            label_counts = {labels[neuron_index]: 1}
            explore_path(SREINet_index, 0, neuron_index, 1, label_counts, non_zero_paths)
        
        #sum up the products with identical composite nonlinear/linear terms
        SREINet_products = {}
        for label_counts, weight_product in non_zero_paths:
            label_counts_key = frozenset(label_counts.items())
            if label_counts_key in SREINet_products:
                SREINet_products[label_counts_key] += weight_product
            else:
                SREINet_products[label_counts_key] = weight_product
        
        #remove the negligible composite terms
        SREINet_products = {k: v for k, v in SREINet_products.items() if abs(v) >= minimum_coefficient_threshold}
        
        if enable_coefficient_sorting:
            #sort the composite terms by their absolute values
            sorted_SREINet_products = dict(sorted(SREINet_products.items(), key=lambda item: abs(item[1]), reverse=True))
        else:
            sorted_SREINet_products = SREINet_products

        all_SREINet_products.append(sorted_SREINet_products)

    #output formatting
    labeled_all_SREINet_products = []
    for SREINet_index, sorted_SREINet_products in enumerate(all_SREINet_products):
        SREINet_product_strings = []
        for key, value in sorted_SREINet_products.items():
            labels_list = []
            only_constant = len(key) == 1 and any(label == 'Constant' for label, _ in key)
            
            for label, count in sorted(key):
                if label == 'Constant' and len(key) > 1:
                    continue
                if label != 'Constant' and count > 1:
                    labels_list.append(f"{label}^{count}")
                elif label == 'Constant' or count == 1:
                    labels_list.append(label if label != 'Constant' else '')
            
            label_str = '*'.join(filter(None, labels_list))
                        
            # Apply coefficient threshold if enabled
            formatted_value = f"{abs(value):.{coefficient_output_digits}g}"

            term_str = label_str if formatted_value == '1' else f"{formatted_value}*{label_str}" if not only_constant else formatted_value if formatted_value != '1' else ''
            sign = '+' if value >= 0 else '-'
            if SREINet_product_strings or value < 0:
                term_str = f" {sign} {term_str}"
            else:
                term_str = term_str
            SREINet_product_strings.append(term_str)

        formatted_output = ''.join(SREINet_product_strings)
        layer_prefix = f"(x{SREINet_index+dim_index+1})'= "
        full_output = layer_prefix + formatted_output
        labeled_all_SREINet_products.append(full_output)

    return labeled_all_SREINet_products

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
for i in range(len(weights_list)):
    path_products = coefficient_reconstruction(i,weights_list[i], 
                                            minimum_coefficient_threshold = 5e-2,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")
# Out:
# (x1)'= 0.533251062*x2 + 0.3247116506*x6 + 0.3391864896*x1 - 0.3391868472*x3 + 0.1420374811*x4
# (x2)'=  - 0.4411981776*x1 + 0.108446613*x2 - 0.3084463477*x4 - 0.3066978678*x5 - 0.2521037459*x3
# (x3)'= 0.6574563384*x2 + 0.5274459571*x4 - 0.2624698281*x5 + 0.2624705732*x1 - 0.1849024147*x6
# (x4)'=  - 0.5120723099*x1 + 0.1789484769*x2 - 0.4879276901*x3 - 0.1506415159*x4 - 0.2283069193*x6
# (x5)'=  - 0.220448792*x1 + 0.3033537716*x2 + 0.2204483002*x3 - 0.09231347591*x4 + 0.7889600098*x6
# (x6)'=  - 0.2232589722*x1 + 0.07934722304*x2 - 0.7767412364*x5 - 0.2793470025*x6

# %% [markdown]
# ### **Validation**

# %%
params = {
    'image.origin': 'lower',
    'image.interpolation': 'nearest',
    'image.cmap': 'gray',
    'axes.grid': False,
    'savefig.dpi': 600,  # to adjust notebook inline plot size
    'axes.labelsize': 16, # fontsize for x and y labels (was 10)
    'axes.titlesize': 16,
    'font.size': 14, # was 10
    'legend.fontsize': 12, # was 10
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
    'text.usetex': False,
    #'figure.figsize': [7, 4],
    'font.family': 'Helvetica',
    #'text.latex.preamble': r'\usepackage{amsmath}',  # Optional, for advanced math symbols
    #'axes.labelweight': 'bold'
    }
import matplotlib

matplotlib.rcParams.update(params)

# %%
def identified_ode(t, x):
    x1, x2, x3, x4, x5, x6 = x
    dx1 = 0.533251062*x2 + 0.3247116506*x6 + 0.3391864896*x1 - 0.3391868472*x3 + 0.1420374811*x4
    dx2 =  - 0.4411981776*x1 + 0.108446613*x2 - 0.3084463477*x4 - 0.3066978678*x5 - 0.2521037459*x3
    dx3 = 0.6574563384*x2 + 0.5274459571*x4 - 0.2624698281*x5 + 0.2624705732*x1 - 0.1849024147*x6
    dx4 =  - 0.5120723099*x1 + 0.1789484769*x2 - 0.4879276901*x3 - 0.1506415159*x4 - 0.2283069193*x6
    dx5 =  - 0.220448792*x1 + 0.3033537716*x2 + 0.2204483002*x3 - 0.09231347591*x4 + 0.7889600098*x6
    dx6 =  - 0.2232589722*x1 + 0.07934722304*x2 - 0.7767412364*x5 - 0.2793470025*x6

    return [dx1, dx2, dx3, dx4, dx5, dx6]


# Validation using training initial conditions
val_DG = DG.DataGenerator(
    initial_conditions=[y0],         # list of ICs
    T=t_span[1],                     # end time
    dt=dt,                           # time step
    t0=t_span[0],                    # start time
    noise_level=0.0,                 # no noise for now
    random_state=42                  # for reproducibility
)

val_x, val_dx = val_DG.generate_ode_traj_with_ic(identified_ode, y0)
true_x, true_dx = myDG.generate_ode_traj_with_ic(ode_wrapper, y0)

# Plot validation results for first few oscillators
plt.figure(figsize=(15, 10))

# Plot phase space comparison for first 3 oscillators
for i in range(min(3, n_oscillators)):
    plt.subplot(2, 3, i+1)
    pos_idx = 2 * i
    vel_idx = 2 * i + 1
    
    plt.plot(true_x[:, pos_idx], true_x[:, vel_idx], 
             label='Ground Truth', color='black', linewidth=2)
    plt.plot(val_x[:, pos_idx], val_x[:, vel_idx], 
             label='Identified Model', color='red', linestyle='--')
    plt.plot(true_x[0, pos_idx], true_x[0, vel_idx], 'bo', markersize=8)
    
    plt.annotate('IC', (true_x[0, pos_idx], true_x[0, vel_idx]), 
                 xytext=(5, 8), textcoords='offset points',
                 fontsize=10, ha='left')
    
    plt.xlabel(f'x{i+1} position')
    plt.ylabel(f'x{i+1} velocity')
    plt.title(f'Oscillator {i+1} Phase Space')
    plt.tick_params(direction='in', length=6, width=1)
    if i == 0:
        plt.legend()

# Plot time series comparison for first 3 oscillators
for i in range(min(3, n_oscillators)):
    plt.subplot(2, 3, i+4)
    pos_idx = 2 * i
    
    plt.plot(t_arr, true_x[:, pos_idx], 
             label='Ground Truth', color='black', linewidth=2)
    plt.plot(t_arr, val_x[:, pos_idx], 
             label='Identified Model', color='red', linestyle='--')
    
    plt.xlabel('Time')
    plt.ylabel(f'x{i+1} position')
    plt.title(f'Oscillator {i+1} Time Series')
    plt.tick_params(direction='in', length=6, width=1)
    if i == 0:
        plt.legend()

plt.tight_layout()
plt.show()

# Calculate and display validation errors
position_errors = []
velocity_errors = []

for i in range(n_oscillators):
    pos_idx = 2 * i
    vel_idx = 2 * i + 1
    
    pos_error = np.mean((true_x[:, pos_idx] - val_x[:, pos_idx])**2)
    vel_error = np.mean((true_x[:, vel_idx] - val_x[:, vel_idx])**2)
    
    position_errors.append(pos_error)
    velocity_errors.append(vel_error)

print(f"Validation Results for {n_oscillators} oscillators:")
print(f"Average position MSE: {np.mean(position_errors):.2e}")
print(f"Average velocity MSE: {np.mean(velocity_errors):.2e}")
print(f"Total system MSE: {np.mean(position_errors + velocity_errors):.2e}")
# Out:
# Validation Results for 3 oscillators:
# Average position MSE: 6.56e-07
# Average velocity MSE: 3.57e-07
# Total system MSE: 5.07e-07

# %%
# Additional validation with different initial conditions for n-oscillator system
print("Testing with different initial conditions...")

# Generate new initial conditions with larger perturbations
np.random.seed(123)  # different seed for validation
val_y0 = []
for i in range(n_oscillators):
    # Larger random initial positions and velocities for validation
    pos = 0.3 * np.random.randn()
    vel = 0.3 * np.random.randn()
    val_y0.extend([pos, vel])

print(f"Validation initial conditions: {val_y0[:6]}...")

val_DG = DG.DataGenerator(
    initial_conditions=[val_y0],         # list of ICs
    T=t_span[1],                     # end time
    dt=dt,                           # time step
    t0=t_span[0],                    # start time
    noise_level=0.0,                 # no noise for now
    random_state=123                 # different random state
)

# Create wrapper with validation ICs
def ode_wrapper_val(t, x):
    return odefun_scalable(t, x, n_oscillators=n_oscillators, 
                          coupling_strength=1.0, damping=0.1, nonlinear_strength=1.0)

val_x, val_dx = val_DG.generate_ode_traj_with_ic(identified_ode, val_y0)
true_x_val, true_dx_val = val_DG.generate_ode_traj_with_ic(ode_wrapper_val, val_y0)

# Calculate validation errors with different ICs
val_position_errors = []
val_velocity_errors = []

for i in range(n_oscillators):
    pos_idx = 2 * i
    vel_idx = 2 * i + 1
    
    pos_error = np.mean((true_x_val[:, pos_idx] - val_x[:, pos_idx])**2)
    vel_error = np.mean((true_x_val[:, vel_idx] - val_x[:, vel_idx])**2)
    
    val_position_errors.append(pos_error)
    val_velocity_errors.append(vel_error)

print(f"Validation with different ICs - {n_oscillators} oscillators:")
print(f"Average position MSE: {np.mean(val_position_errors):.2e}")
print(f"Average velocity MSE: {np.mean(val_velocity_errors):.2e}")
print(f"Total system MSE: {np.mean(val_position_errors + val_velocity_errors):.2e}")

# Plot comparison for first oscillator only
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
pos_idx = 0
vel_idx = 1
plt.plot(true_x_val[:, pos_idx], true_x_val[:, vel_idx], 
         label='Ground Truth', color='black', linewidth=2)
plt.plot(val_x[:, pos_idx], val_x[:, vel_idx], 
         label='Identified Model', color='red', linestyle='--')
plt.plot(true_x_val[0, pos_idx], true_x_val[0, vel_idx], 'bo', markersize=8)
plt.xlabel('x1 position')
plt.ylabel('x1 velocity')
plt.title('First Oscillator - Different IC')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(t_arr, true_x_val[:, pos_idx], 
         label='Ground Truth', color='black', linewidth=2)
plt.plot(t_arr, val_x[:, pos_idx], 
         label='Identified Model', color='red', linestyle='--')
plt.xlabel('Time')
plt.ylabel('x1 position')
plt.title('First Oscillator Time Series - Different IC')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Testing with different initial conditions...
# Validation initial conditions: [-0.32568918099016836, 0.2992036339750757, 0.08489354941559761, -0.4518884141754276, -0.1735800755905609, 0.4954309611291453]...
# Validation with different ICs - 3 oscillators:
# Average position MSE: 3.62e+03
# Average velocity MSE: 1.93e+03
# Total system MSE: 2.78e+03
