# %% [markdown]
# ## **Lotka-Volterra Network Model Learned by SREINet**

# %% [markdown]
# ## **I. Setup and Preprocessing**

# %%
# Import os library to access environment variables and operating system functionalities
import os

# Set environment variable to avoid duplicate library errors, specifically for OpenMP
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Set TensorFlow log level to '2' to suppress most messages except warnings and errors
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import sys
sys.path.append(os.path.abspath(".."))
sys.path.append(os.path.abspath("../../utilities"))

# Import necessary libraries for deep learning and numerical computation
import tensorflow as tf
import numpy as np
from SREINet import * 
import DataGenerator as DG


# Print a formatted message to the terminal to display current time, date, and TensorFlow version
print("**********************************************")
print("*                                            *")
print("*    Tensorflow Version: " + tf.__version__ + "              *")
print("*                                            *")
print("**********************************************")

from packaging import version
if version.parse(tf.__version__) < version.parse('2.10.0') and version.parse(tf.__version__) > version.parse('2.15.0'):
    print("Error: Tensorflow version is lower than 2.10.0 or higher than 2.15.0 Please use Tensorflow 2.10.0 - 2.15.0")
    sys.exit()

MY_DATA_TYPE = 'float32'
# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)
# Out:
# **********************************************
# *                                            *
# *    Tensorflow Version: 2.15.0              *
# *                                            *
# **********************************************

# %% [markdown]
# ### **1.2 Training Data**

# %% [markdown]
# #### Create dataset

# %%
# Specify the model type
from lotka_volterra_network import lotka_volterra_network
from network_generator import generate_erdos_renyi_network

MY_DATA_TYPE = 'float32'

# Set the desired data type
tf.keras.backend.set_floatx(MY_DATA_TYPE)

# Generate data based on the specified model type
n_nodes = 20
edge_probability = 0.2
seed = 123

edge_list, adjacency, degrees = generate_erdos_renyi_network(n_nodes, edge_probability, seed=seed)

print(f"Generated ER network with {n_nodes} nodes and {edge_list.shape[0]} edges")

np.random.seed(seed)
num_traj = 8

initial_conditions = []
for _ in range(num_traj):
    prey0 = np.random.uniform(0.5, 3, size=n_nodes)
    predator0 = np.random.uniform(0.5, 3, size=n_nodes)
    initial_state = np.concatenate([prey0, predator0])
    initial_conditions.append(initial_state)

data_T = 200.0       # Length of the data (T)
data_dt = 0.02      # Resolution of the data (dt)
myDG = DG.DataGenerator(initial_conditions, T=data_T, dt=data_dt, derivative_mode="exact")

def lotka_vector_field(t, state, edge_list):
    return lotka_volterra_network(
        t,
        state,
        edge_list,
        coupling_strength_prey=0.1,
        coupling_strength_predator=0.1,
    )

t_arr, x_train, dx_train = myDG.generate_dataset_by_custom_ODEs(
    lotka_vector_field,
    edge_list,
    method='RK45'
)

#plot x_train and dx_train
import matplotlib.pyplot as plt
plt.plot(x_train, dx_train)
plt.show()

#Shuffle data
training_input, training_output = x_train, dx_train
training_input_for_sim = training_input.copy()  # Save a copy for validation

print("Training input shape:", training_input.shape)
print("Training output shape:", training_output.shape)

MY_MODEL = "Lotka-Volterra network (ER)"
data_initial_conditions = initial_conditions
guess_highest_order_polynomial = 3
ode_function = lotka_vector_field
network_arguments = (edge_list,)
# Out:
# Generated ER network with 20 nodes and 38 edges
# Training input shape: (80000, 40)
# Training output shape: (80000, 40)

# %% [markdown]
# ### **1.3 Hyperparameters**

# %%
# Set mini-batch size
MINI_BATCH_SIZE = 64
learning_rate = 0.001

# %% [markdown]
# ### **1.4 Model Architecture Definitions**

# %% [markdown]
# **SREINet Parameters**

# %%
# Assign dim to be the 2nd dimension of the training data (number of input variables)
dim = training_input.shape[1] 

guessed_multiplicative_order = 3
# The grid size of each dimension
layer_depth = guessed_multiplicative_order
layer_neuron_nums_per_act_fn = [dim] * layer_depth
print(layer_neuron_nums_per_act_fn) # these numbers exclude the constant term
# Out:
# [40, 40, 40]

# %% [markdown]
# ## **II. Model and Training Preparation**

# %% [markdown]
# ### **2.1 Create the SREINet Model**

# %%
my_activation = [lambda x:x]
inputs = tf.keras.layers.Input(shape=(dim,), dtype=MY_DATA_TYPE)
model = SREINet(layer_neuron_nums_per_act_fn,
                     activations=my_activation,
                     weight_initializer=tf.initializers.random_normal(stddev=1e-5, seed=42),
                     data_type=MY_DATA_TYPE,
                     name='SREINet')
output = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=output)

# %% [markdown]
# ### **2.2 Loss Function**

# %%
LOSS_FUNCTION = 'mse' #This can be 'MSE', 'LASSO', or 'RIDGE' or 'ElasticNet'(case insensitive)

from loss import *

# Example of selecting a loss function
loss_fn = myLoss(model, LOSS_FUNCTION)

# %% [markdown]
# ### **2.3 Optimizer**

# %%
my_optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)  # Create an Adam optimizer with the defined learning rate
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# ### **2.4 Trainer**

# %%
np.set_printoptions(threshold=np.inf)

from sreinet_trainer import SREINetTrainer

trainer = SREINetTrainer(
    model,
    my_optimizer,
    loss_fn,
    data_type=MY_DATA_TYPE,
    random_seed=42,
)

# %% [markdown]
# ## **III.Training the Model**

# %% [markdown]
# #### **Pruning Profile**

# %%
MAX_WEIGHT_PRUNING_THRESHOLD = 0.10 #Threshold for 10D Lorenz 96 model. Uses linear prune schedule
N_PERIODS = 50
PRUNING_EPOCHS_PER_PERIOD = 30
NUM_EPOCHS = PRUNING_EPOCHS_PER_PERIOD * N_PERIODS

import pruning_scheduler as ps

pruning_scheduler = ps.PruningScheduler(
    steps_per_period=PRUNING_EPOCHS_PER_PERIOD,
    num_periods=N_PERIODS,
    maximum_threshold=MAX_WEIGHT_PRUNING_THRESHOLD,
    show_plot=True,
)

# %% [markdown]
# ### Training

# %%
#Setup
callbacks = []

EARLY_STOPPING_LOSS_THRESHOLD = 1e-10   # Threshold for early stopping (Layer Based)
EARLY_STOPPING_PRUNING_THRESHOLD = 0.005

training_histories = []
weights_list = []

# %%
#change 0 to a other number if you want to start training from other dimensions
for i in range(0, training_output.shape[1]):
    print(f"Training dimension {i + 1}...")
    
    trainer.reset_trainer_and_model_weights(i)
    output = training_output[:, i:i+1]

    history = trainer.fit(
        training_input,
        output,
        batch_size=MINI_BATCH_SIZE,
        validation_split=0.20,
        epochs=round(NUM_EPOCHS),
        pruning_scheduler=pruning_scheduler,
        callbacks=callbacks,
        early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
        early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
        shuffle_per_epoch=False,
        patience_periods=15,
        verbose=1,
    )

    training_histories.append(history)

    # Retrieve the weights of the trained model
    weights_list.append([trainer.get_best_weights()])
# Out:
# Training dimension 1...
# Epoch   1 (Period 1):  Train Loss: 1.225e+00,  Validation Loss: 2.709e-02,  Epoch Time: 0.87s,  Current Pruning Threshold: 0
# Epoch   2 (Period 1):  Train Loss: 2.797e-02,  Validation Loss: 2.699e-02,  Epoch Time: 0.83s,  Current Pruning Threshold: 2.9961e-05
# Epoch   3 (Period 1):  Train Loss: 2.362e-02,  Validation Loss: 1.880e-02,  Epoch Time: 0.82s,  Current Pruning Threshold: 8.0168e-05
# Epoch   4 (Period 1):  Train Loss: 2.194e-02,  Validation Loss: 1.608e-02,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00016424
# Epoch   5 (Period 1):  Train Loss: 2.014e-02,  Validation Loss: 1.224e-02,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00030487
# Epoch   6 (Period 1):  Train Loss: 1.674e-02,  Validation Loss: 1.712e-02,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00053966
# Epoch   7 (Period 1):  Train Loss: 1.834e-02,  Validation Loss: 1.738e-02,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00093039
# Epoch   8 (Period 1):  Train Loss: 1.393e-02,  Validation Loss: 8.624e-03,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0015773
# Epoch   9 (Period 1):  Train Loss: 1.165e-02,  Validation Loss: 7.081e-03,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.0026389
# Epoch  10 (Period 1):  Train Loss: 9.963e-03,  Validation Loss: 6.501e-03,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0043565
# Epoch  11 (Period 1):  Train Loss: 9.424e-03,  Validation Loss: 4.687e-03,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.0070727
# Epoch  12 (Period 1):  Train Loss: 5.517e-03,  Validation Loss: 2.522e-03,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.011216
# Epoch  13 (Period 1):  Train Loss: 1.478e-02,  Validation Loss: 3.255e-03,  Epoch Time: 0.81s,  Current Pruning Threshold: 0.017201
# Epoch  14 (Period 1):  Train Loss: 6.482e-03,  Validation Loss: 2.858e-03,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.025201
# Epoch  15 (Period 1):  Train Loss: 1.578e-02,  Validation Loss: 2.859e-03,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.034851
# Epoch  16 (Period 1):  Train Loss: 5.187e-03,  Validation Loss: 4.266e-03,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.045149
# Epoch  17 (Period 1):  Train Loss: 3.884e-03,  Validation Loss: 3.455e-03,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.054799
# Epoch  18 (Period 1):  Train Loss: 1.201e-02,  Validation Loss: 2.867e-03,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.062799
# Epoch  19 (Period 1):  Train Loss: 2.982e-03,  Validation Loss: 2.247e-03,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.068784
# Epoch  20 (Period 1):  Train Loss: 2.406e-03,  Validation Loss: 1.958e-03,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.072927
# Epoch  21 (Period 1):  Train Loss: 2.084e-03,  Validation Loss: 1.743e-03,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.075643
# Epoch  22 (Period 1):  Train Loss: 1.669e-03,  Validation Loss: 1.358e-03,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.077361
# Epoch  23 (Period 1):  Train Loss: 1.273e-03,  Validation Loss: 1.207e-03,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.078423
# Epoch  24 (Period 1):  Train Loss: 9.641e-04,  Validation Loss: 9.030e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07907
# Epoch  25 (Period 1):  Train Loss: 8.254e-04,  Validation Loss: 6.413e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.07946
# Epoch  26 (Period 1):  Train Loss: 7.225e-04,  Validation Loss: 6.109e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.079695
# Epoch  27 (Period 1):  Train Loss: 7.341e-04,  Validation Loss: 6.244e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.079836
# Epoch  28 (Period 1):  Train Loss: 5.546e-04,  Validation Loss: 5.710e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.07992
# Epoch  29 (Period 1):  Train Loss: 5.162e-04,  Validation Loss: 4.467e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07997
# Epoch  30 (Period 1):  Train Loss: 5.552e-04,  Validation Loss: 7.049e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.08
# Epoch  31 (Period 2):  Train Loss: 2.397e-01,  Validation Loss: 1.016e-03,  Epoch Time: 0.78s,  Current Pruning Threshold: 0
# Epoch  32 (Period 2):  Train Loss: 8.361e-04,  Validation Loss: 6.379e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 2.9961e-05
# Epoch  33 (Period 2):  Train Loss: 6.170e-04,  Validation Loss: 5.457e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 8.0168e-05
# Epoch  34 (Period 2):  Train Loss: 5.264e-04,  Validation Loss: 3.675e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00016424
# Epoch  35 (Period 2):  Train Loss: 4.506e-04,  Validation Loss: 3.056e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.00030487
# Epoch  36 (Period 2):  Train Loss: 6.453e-04,  Validation Loss: 2.433e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00053966
# Epoch  37 (Period 2):  Train Loss: 5.135e-04,  Validation Loss: 3.683e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00093039
# Epoch  38 (Period 2):  Train Loss: 3.803e-04,  Validation Loss: 4.157e-04,  Epoch Time: 0.84s,  Current Pruning Threshold: 0.0015773
# Epoch  39 (Period 2):  Train Loss: 3.936e-04,  Validation Loss: 1.921e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.0026389
# Epoch  40 (Period 2):  Train Loss: 2.032e-04,  Validation Loss: 1.224e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0043565
# Epoch  41 (Period 2):  Train Loss: 1.724e-04,  Validation Loss: 1.069e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.0070727
# Epoch  42 (Period 2):  Train Loss: 4.440e-04,  Validation Loss: 1.243e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.011216
# Epoch  43 (Period 2):  Train Loss: 2.606e-04,  Validation Loss: 1.341e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.017201
# Epoch  44 (Period 2):  Train Loss: 2.197e-04,  Validation Loss: 1.472e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.025201
# Epoch  45 (Period 2):  Train Loss: 2.019e-04,  Validation Loss: 1.578e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.034851
# Epoch  46 (Period 2):  Train Loss: 1.833e-04,  Validation Loss: 1.672e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.045149
# Epoch  47 (Period 2):  Train Loss: 3.138e-04,  Validation Loss: 1.771e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.054799
# Epoch  48 (Period 2):  Train Loss: 2.729e-04,  Validation Loss: 2.227e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.062799
# Epoch  49 (Period 2):  Train Loss: 2.625e-04,  Validation Loss: 2.076e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.068784
# Epoch  50 (Period 2):  Train Loss: 2.346e-04,  Validation Loss: 5.032e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.072927
# Epoch  51 (Period 2):  Train Loss: 2.627e-04,  Validation Loss: 2.259e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.075643
# Epoch  52 (Period 2):  Train Loss: 2.358e-04,  Validation Loss: 2.395e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.077361
# Epoch  53 (Period 2):  Train Loss: 3.090e-04,  Validation Loss: 2.146e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.078423
# Epoch  54 (Period 2):  Train Loss: 3.975e-04,  Validation Loss: 2.591e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07907
# Epoch  55 (Period 2):  Train Loss: 3.242e-04,  Validation Loss: 2.641e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07946
# Epoch  56 (Period 2):  Train Loss: 2.876e-04,  Validation Loss: 2.698e-04,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.079695
# Epoch  57 (Period 2):  Train Loss: 2.633e-04,  Validation Loss: 2.280e-04,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.079836
# Epoch  58 (Period 2):  Train Loss: 2.999e-04,  Validation Loss: 2.860e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07992
# Epoch  59 (Period 2):  Train Loss: 2.561e-04,  Validation Loss: 2.236e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.07997
# Epoch  60 (Period 2):  Train Loss: 7.168e-03,  Validation Loss: 1.581e-03,  Epoch Time: 0.83s,  Current Pruning Threshold: 0.08
# Epoch  61 (Period 3):  Train Loss: 7.832e-02,  Validation Loss: 4.338e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0
# Epoch  62 (Period 3):  Train Loss: 3.876e-04,  Validation Loss: 3.189e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 2.9961e-05
# Epoch  63 (Period 3):  Train Loss: 3.283e-04,  Validation Loss: 3.313e-04,  Epoch Time: 0.81s,  Current Pruning Threshold: 8.0168e-05
# Epoch  64 (Period 3):  Train Loss: 5.414e-04,  Validation Loss: 5.408e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00016424
# Epoch  65 (Period 3):  Train Loss: 5.929e-04,  Validation Loss: 4.193e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00030487
# Epoch  66 (Period 3):  Train Loss: 4.608e-04,  Validation Loss: 2.336e-03,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00053966
# Epoch  67 (Period 3):  Train Loss: 6.499e-04,  Validation Loss: 1.663e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00093039
# Epoch  68 (Period 3):  Train Loss: 4.914e-04,  Validation Loss: 9.760e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0015773
# Epoch  69 (Period 3):  Train Loss: 2.863e-04,  Validation Loss: 1.964e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0026389
# Epoch  70 (Period 3):  Train Loss: 2.146e-04,  Validation Loss: 1.402e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0043565
# Epoch  71 (Period 3):  Train Loss: 3.393e-04,  Validation Loss: 8.426e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0070727
# Epoch  72 (Period 3):  Train Loss: 4.943e-04,  Validation Loss: 1.331e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.011216
# Epoch  73 (Period 3):  Train Loss: 2.018e-04,  Validation Loss: 1.154e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.017201
# Epoch  74 (Period 3):  Train Loss: 7.350e-04,  Validation Loss: 2.606e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.025201
# Epoch  75 (Period 3):  Train Loss: 2.634e-04,  Validation Loss: 2.427e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.034851
# Epoch  76 (Period 3):  Train Loss: 2.234e-04,  Validation Loss: 1.840e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.045149
# Epoch  77 (Period 3):  Train Loss: 2.284e-04,  Validation Loss: 1.705e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.054799
# Epoch  78 (Period 3):  Train Loss: 1.838e-04,  Validation Loss: 1.503e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.062799
# Epoch  79 (Period 3):  Train Loss: 1.549e-04,  Validation Loss: 1.320e-04,  Epoch Time: 0.82s,  Current Pruning Threshold: 0.068784
# Epoch  80 (Period 3):  Train Loss: 2.729e-04,  Validation Loss: 1.428e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.072927
# Epoch  81 (Period 3):  Train Loss: 6.628e-04,  Validation Loss: 3.148e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.075643
# Epoch  82 (Period 3):  Train Loss: 3.164e-04,  Validation Loss: 2.956e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.077361
# Epoch  83 (Period 3):  Train Loss: 2.757e-04,  Validation Loss: 2.251e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.078423
# Epoch  84 (Period 3):  Train Loss: 2.646e-04,  Validation Loss: 2.452e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07907
# Epoch  85 (Period 3):  Train Loss: 2.101e-04,  Validation Loss: 1.869e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07946
# Epoch  86 (Period 3):  Train Loss: 1.835e-04,  Validation Loss: 2.301e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.079695
# Epoch  87 (Period 3):  Train Loss: 1.666e-04,  Validation Loss: 1.579e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.079836
# Epoch  88 (Period 3):  Train Loss: 1.492e-04,  Validation Loss: 1.236e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.07992
# Epoch  89 (Period 3):  Train Loss: 1.866e-04,  Validation Loss: 1.199e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07997
# Epoch  90 (Period 3):  Train Loss: 1.232e-04,  Validation Loss: 1.120e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.08
# Epoch  91 (Period 4):  Train Loss: 2.775e-01,  Validation Loss: 1.219e-03,  Epoch Time: 0.79s,  Current Pruning Threshold: 0
# Epoch  92 (Period 4):  Train Loss: 9.792e-04,  Validation Loss: 7.011e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 2.9961e-05
# Epoch  93 (Period 4):  Train Loss: 5.039e-04,  Validation Loss: 3.755e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 8.0168e-05
# Epoch  94 (Period 4):  Train Loss: 2.778e-04,  Validation Loss: 1.904e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00016424
# Epoch  95 (Period 4):  Train Loss: 1.902e-04,  Validation Loss: 1.055e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00030487
# Epoch  96 (Period 4):  Train Loss: 3.167e-04,  Validation Loss: 1.549e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00053966
# Epoch  97 (Period 4):  Train Loss: 3.104e-04,  Validation Loss: 8.336e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00093039
# Epoch  98 (Period 4):  Train Loss: 1.693e-04,  Validation Loss: 4.730e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0015773
# Epoch  99 (Period 4):  Train Loss: 5.091e-04,  Validation Loss: 3.882e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0026389
# Epoch 100 (Period 4):  Train Loss: 1.709e-04,  Validation Loss: 4.653e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0043565
# Epoch 101 (Period 4):  Train Loss: 9.134e-05,  Validation Loss: 5.272e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0070727
# Epoch 102 (Period 4):  Train Loss: 1.443e-04,  Validation Loss: 5.922e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.011216
# Epoch 103 (Period 4):  Train Loss: 7.735e-05,  Validation Loss: 6.723e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.017201
# Epoch 104 (Period 4):  Train Loss: 9.088e-05,  Validation Loss: 5.995e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.025201
# Epoch 105 (Period 4):  Train Loss: 1.523e-04,  Validation Loss: 7.665e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.034851
# Epoch 106 (Period 4):  Train Loss: 8.422e-05,  Validation Loss: 7.456e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.045149
# Epoch 107 (Period 4):  Train Loss: 8.292e-05,  Validation Loss: 7.054e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.054799
# Epoch 108 (Period 4):  Train Loss: 8.005e-05,  Validation Loss: 7.282e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.062799
# Epoch 109 (Period 4):  Train Loss: 8.149e-04,  Validation Loss: 9.057e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.068784
# Epoch 110 (Period 4):  Train Loss: 8.078e-05,  Validation Loss: 7.664e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.072927
# Epoch 111 (Period 4):  Train Loss: 7.064e-05,  Validation Loss: 6.049e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.075643
# Epoch 112 (Period 4):  Train Loss: 6.630e-05,  Validation Loss: 6.211e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.077361
# Epoch 113 (Period 4):  Train Loss: 6.514e-05,  Validation Loss: 6.976e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.078423
# Epoch 114 (Period 4):  Train Loss: 6.433e-05,  Validation Loss: 5.686e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07907
# Epoch 115 (Period 4):  Train Loss: 6.455e-05,  Validation Loss: 5.669e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07946
# Epoch 116 (Period 4):  Train Loss: 6.667e-05,  Validation Loss: 5.839e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079695
# Epoch 117 (Period 4):  Train Loss: 6.157e-05,  Validation Loss: 5.477e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079836
# Epoch 118 (Period 4):  Train Loss: 6.091e-05,  Validation Loss: 5.808e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07992
# Epoch 119 (Period 4):  Train Loss: 7.527e-05,  Validation Loss: 7.081e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.07997
# Epoch 120 (Period 4):  Train Loss: 5.707e-05,  Validation Loss: 5.864e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.08
# Epoch 121 (Period 5):  Train Loss: 5.837e-02,  Validation Loss: 2.622e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0
# Epoch 122 (Period 5):  Train Loss: 1.272e-04,  Validation Loss: 1.054e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 2.9961e-05
# Epoch 123 (Period 5):  Train Loss: 6.188e-05,  Validation Loss: 4.287e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 8.0168e-05
# Epoch 124 (Period 5):  Train Loss: 6.803e-05,  Validation Loss: 4.620e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00016424
# Epoch 125 (Period 5):  Train Loss: 3.430e-04,  Validation Loss: 1.276e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00030487
# Epoch 126 (Period 5):  Train Loss: 1.765e-04,  Validation Loss: 2.132e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00053966
# Epoch 127 (Period 5):  Train Loss: 2.143e-04,  Validation Loss: 2.149e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00093039
# Epoch 128 (Period 5):  Train Loss: 1.216e-04,  Validation Loss: 1.968e-03,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0015773
# Epoch 129 (Period 5):  Train Loss: 1.763e-04,  Validation Loss: 2.176e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0026389
# Epoch 130 (Period 5):  Train Loss: 6.643e-04,  Validation Loss: 2.902e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0043565
# Epoch 131 (Period 5):  Train Loss: 1.009e-04,  Validation Loss: 3.344e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.0070727
# Epoch 132 (Period 5):  Train Loss: 1.427e-04,  Validation Loss: 6.108e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.011216
# Epoch 133 (Period 5):  Train Loss: 7.182e-05,  Validation Loss: 6.293e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.017201
# Epoch 134 (Period 5):  Train Loss: 5.736e-05,  Validation Loss: 5.205e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.025201
# Epoch 135 (Period 5):  Train Loss: 5.517e-05,  Validation Loss: 5.381e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.034851
# Epoch 136 (Period 5):  Train Loss: 5.822e-05,  Validation Loss: 5.476e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.045149
# Epoch 137 (Period 5):  Train Loss: 5.711e-05,  Validation Loss: 5.125e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.054799
# Epoch 138 (Period 5):  Train Loss: 5.474e-05,  Validation Loss: 5.259e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.062799
# Epoch 139 (Period 5):  Train Loss: 5.847e-05,  Validation Loss: 5.252e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.068784
# Epoch 140 (Period 5):  Train Loss: 5.646e-05,  Validation Loss: 5.365e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.072927
# Epoch 141 (Period 5):  Train Loss: 5.778e-05,  Validation Loss: 8.225e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.075643
# Epoch 142 (Period 5):  Train Loss: 5.802e-05,  Validation Loss: 5.851e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.077361
# Epoch 143 (Period 5):  Train Loss: 5.729e-05,  Validation Loss: 5.909e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.078423
# Epoch 144 (Period 5):  Train Loss: 5.883e-05,  Validation Loss: 5.366e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07907
# Epoch 145 (Period 5):  Train Loss: 5.442e-05,  Validation Loss: 5.525e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07946
# Epoch 146 (Period 5):  Train Loss: 5.901e-05,  Validation Loss: 5.483e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079695
# Epoch 147 (Period 5):  Train Loss: 5.739e-05,  Validation Loss: 5.418e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079836
# Epoch 148 (Period 5):  Train Loss: 5.646e-05,  Validation Loss: 5.463e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.07992
# Epoch 149 (Period 5):  Train Loss: 5.760e-05,  Validation Loss: 5.052e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.07997
# Epoch 150 (Period 5):  Train Loss: 5.760e-05,  Validation Loss: 5.431e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.08
# Epoch 151 (Period 6):  Train Loss: 8.437e-02,  Validation Loss: 1.339e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0
# Epoch 152 (Period 6):  Train Loss: 1.036e-04,  Validation Loss: 8.154e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 2.9961e-05
# Epoch 153 (Period 6):  Train Loss: 6.602e-05,  Validation Loss: 4.548e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 8.0168e-05
# Epoch 154 (Period 6):  Train Loss: 4.094e-05,  Validation Loss: 2.576e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00016424
# Epoch 155 (Period 6):  Train Loss: 1.217e-04,  Validation Loss: 2.293e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00030487
# Epoch 156 (Period 6):  Train Loss: 7.829e-05,  Validation Loss: 1.541e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00053966
# Epoch 157 (Period 6):  Train Loss: 1.342e-04,  Validation Loss: 1.982e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00093039
# Epoch 158 (Period 6):  Train Loss: 4.122e-05,  Validation Loss: 9.912e-06,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0015773
# Epoch 159 (Period 6):  Train Loss: 8.801e-05,  Validation Loss: 1.089e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0026389
# Epoch 160 (Period 6):  Train Loss: 5.446e-05,  Validation Loss: 1.133e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0043565
# Epoch 161 (Period 6):  Train Loss: 4.168e-05,  Validation Loss: 1.065e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0070727
# Epoch 162 (Period 6):  Train Loss: 1.767e-04,  Validation Loss: 5.386e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.011216
# Epoch 163 (Period 6):  Train Loss: 5.929e-05,  Validation Loss: 4.742e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.017201
# Epoch 164 (Period 6):  Train Loss: 5.477e-05,  Validation Loss: 4.893e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.025201
# Epoch 165 (Period 6):  Train Loss: 6.389e-05,  Validation Loss: 4.585e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.034851
# Epoch 166 (Period 6):  Train Loss: 5.566e-05,  Validation Loss: 5.281e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.045149
# Epoch 167 (Period 6):  Train Loss: 5.411e-05,  Validation Loss: 4.822e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.054799
# Epoch 168 (Period 6):  Train Loss: 5.850e-05,  Validation Loss: 5.430e-05,  Epoch Time: 0.82s,  Current Pruning Threshold: 0.062799
# Epoch 169 (Period 6):  Train Loss: 5.878e-05,  Validation Loss: 7.476e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.068784
# Epoch 170 (Period 6):  Train Loss: 5.767e-05,  Validation Loss: 5.910e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.072927
# Epoch 171 (Period 6):  Train Loss: 5.586e-05,  Validation Loss: 5.047e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.075643
# Epoch 172 (Period 6):  Train Loss: 5.561e-05,  Validation Loss: 5.620e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.077361
# Epoch 173 (Period 6):  Train Loss: 5.731e-05,  Validation Loss: 4.854e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.078423
# Epoch 174 (Period 6):  Train Loss: 5.598e-05,  Validation Loss: 4.645e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.07907
# Epoch 175 (Period 6):  Train Loss: 5.528e-05,  Validation Loss: 5.150e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07946
# Epoch 176 (Period 6):  Train Loss: 5.645e-05,  Validation Loss: 5.154e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.079695
# Epoch 177 (Period 6):  Train Loss: 5.574e-05,  Validation Loss: 5.045e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.079836
# Epoch 178 (Period 6):  Train Loss: 5.819e-05,  Validation Loss: 5.186e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07992
# Epoch 179 (Period 6):  Train Loss: 5.448e-05,  Validation Loss: 5.227e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07997
# Epoch 180 (Period 6):  Train Loss: 5.785e-05,  Validation Loss: 6.280e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.08
# Epoch 181 (Period 7):  Train Loss: 1.369e-01,  Validation Loss: 8.638e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0
# Epoch 182 (Period 7):  Train Loss: 6.387e-04,  Validation Loss: 6.227e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 2.9961e-05
# Epoch 183 (Period 7):  Train Loss: 3.613e-04,  Validation Loss: 1.950e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 8.0168e-05
# Epoch 184 (Period 7):  Train Loss: 1.939e-04,  Validation Loss: 9.563e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00016424
# Epoch 185 (Period 7):  Train Loss: 1.858e-04,  Validation Loss: 6.077e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00030487
# Epoch 186 (Period 7):  Train Loss: 4.466e-04,  Validation Loss: 6.081e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00053966
# Epoch 187 (Period 7):  Train Loss: 1.340e-04,  Validation Loss: 3.674e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00093039
# Epoch 188 (Period 7):  Train Loss: 8.085e-05,  Validation Loss: 1.874e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.0015773
# Epoch 189 (Period 7):  Train Loss: 1.026e-04,  Validation Loss: 3.133e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.0026389
# Epoch 190 (Period 7):  Train Loss: 5.981e-05,  Validation Loss: 1.701e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.0043565
# Epoch 191 (Period 7):  Train Loss: 5.347e-05,  Validation Loss: 2.624e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0070727
# Epoch 192 (Period 7):  Train Loss: 1.017e-04,  Validation Loss: 4.744e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.011216
# Epoch 193 (Period 7):  Train Loss: 5.728e-05,  Validation Loss: 5.097e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.017201
# Epoch 194 (Period 7):  Train Loss: 5.388e-05,  Validation Loss: 6.494e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.025201
# Epoch 195 (Period 7):  Train Loss: 5.503e-05,  Validation Loss: 5.514e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.034851
# Epoch 196 (Period 7):  Train Loss: 5.613e-05,  Validation Loss: 4.939e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.045149
# Epoch 197 (Period 7):  Train Loss: 5.594e-05,  Validation Loss: 5.323e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.054799
# Epoch 198 (Period 7):  Train Loss: 5.538e-05,  Validation Loss: 5.171e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.062799
# Epoch 199 (Period 7):  Train Loss: 5.739e-05,  Validation Loss: 6.351e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.068784
# Epoch 200 (Period 7):  Train Loss: 5.735e-05,  Validation Loss: 5.123e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.072927
# Epoch 201 (Period 7):  Train Loss: 5.654e-05,  Validation Loss: 5.144e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.075643
# Epoch 202 (Period 7):  Train Loss: 5.714e-05,  Validation Loss: 5.879e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.077361
# Epoch 203 (Period 7):  Train Loss: 5.663e-05,  Validation Loss: 7.661e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.078423
# Epoch 204 (Period 7):  Train Loss: 5.694e-05,  Validation Loss: 5.419e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.07907
# Epoch 205 (Period 7):  Train Loss: 5.751e-05,  Validation Loss: 5.723e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07946
# Epoch 206 (Period 7):  Train Loss: 5.692e-05,  Validation Loss: 5.114e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079695
# Epoch 207 (Period 7):  Train Loss: 5.736e-05,  Validation Loss: 5.384e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079836
# Epoch 208 (Period 7):  Train Loss: 5.639e-05,  Validation Loss: 6.054e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07992
# Epoch 209 (Period 7):  Train Loss: 5.569e-05,  Validation Loss: 5.148e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07997
# Epoch 210 (Period 7):  Train Loss: 5.671e-05,  Validation Loss: 5.179e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.08
# Epoch 211 (Period 8):  Train Loss: 4.148e-02,  Validation Loss: 9.734e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0
# Epoch 212 (Period 8):  Train Loss: 5.352e-04,  Validation Loss: 2.466e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 2.9961e-05
# Epoch 213 (Period 8):  Train Loss: 2.059e-04,  Validation Loss: 9.435e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 8.0168e-05
# Epoch 214 (Period 8):  Train Loss: 2.911e-04,  Validation Loss: 5.601e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.00016424
# Epoch 215 (Period 8):  Train Loss: 2.919e-04,  Validation Loss: 8.780e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.00030487
# Epoch 216 (Period 8):  Train Loss: 3.505e-04,  Validation Loss: 1.247e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00053966
# Epoch 217 (Period 8):  Train Loss: 3.039e-04,  Validation Loss: 3.447e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.00093039
# Epoch 218 (Period 8):  Train Loss: 1.970e-04,  Validation Loss: 7.297e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.0015773
# Epoch 219 (Period 8):  Train Loss: 1.272e-04,  Validation Loss: 2.072e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.0026389
# Epoch 220 (Period 8):  Train Loss: 3.989e-05,  Validation Loss: 7.551e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.0043565
# Epoch 221 (Period 8):  Train Loss: 3.123e-05,  Validation Loss: 1.353e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0070727
# Epoch 222 (Period 8):  Train Loss: 1.900e-04,  Validation Loss: 3.239e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.011216
# Epoch 223 (Period 8):  Train Loss: 1.009e-04,  Validation Loss: 5.955e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.017201
# Epoch 224 (Period 8):  Train Loss: 7.194e-05,  Validation Loss: 4.879e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.025201
# Epoch 225 (Period 8):  Train Loss: 5.343e-05,  Validation Loss: 5.722e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.034851
# Epoch 226 (Period 8):  Train Loss: 5.564e-05,  Validation Loss: 5.031e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.045149
# Epoch 227 (Period 8):  Train Loss: 5.448e-05,  Validation Loss: 7.069e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.054799
# Epoch 228 (Period 8):  Train Loss: 5.715e-05,  Validation Loss: 5.556e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.062799
# Epoch 229 (Period 8):  Train Loss: 5.736e-05,  Validation Loss: 5.224e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.068784
# Epoch 230 (Period 8):  Train Loss: 5.467e-05,  Validation Loss: 9.085e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.072927
# Epoch 231 (Period 8):  Train Loss: 5.603e-05,  Validation Loss: 5.069e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.075643
# Epoch 232 (Period 8):  Train Loss: 5.592e-05,  Validation Loss: 5.272e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.077361
# Epoch 233 (Period 8):  Train Loss: 5.683e-05,  Validation Loss: 1.124e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.078423
# Epoch 234 (Period 8):  Train Loss: 5.589e-05,  Validation Loss: 4.748e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.07907
# Epoch 235 (Period 8):  Train Loss: 5.772e-05,  Validation Loss: 5.377e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.07946
# Epoch 236 (Period 8):  Train Loss: 5.777e-05,  Validation Loss: 5.433e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.079695
# Epoch 237 (Period 8):  Train Loss: 5.728e-05,  Validation Loss: 6.336e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079836
# Epoch 238 (Period 8):  Train Loss: 5.794e-05,  Validation Loss: 5.823e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07992
# Epoch 239 (Period 8):  Train Loss: 5.840e-05,  Validation Loss: 5.168e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.07997
# Epoch 240 (Period 8):  Train Loss: 5.566e-05,  Validation Loss: 4.816e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.08
# Epoch 241 (Period 9):  Train Loss: 3.587e-02,  Validation Loss: 2.434e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0
# Epoch 242 (Period 9):  Train Loss: 1.873e-04,  Validation Loss: 9.338e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 2.9961e-05
# Epoch 243 (Period 9):  Train Loss: 1.266e-04,  Validation Loss: 4.929e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 8.0168e-05
# Epoch 244 (Period 9):  Train Loss: 3.227e-04,  Validation Loss: 7.542e-04,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.00016424
# Epoch 245 (Period 9):  Train Loss: 3.441e-04,  Validation Loss: 4.628e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00030487
# Epoch 246 (Period 9):  Train Loss: 4.366e-04,  Validation Loss: 5.575e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00053966
# Epoch 247 (Period 9):  Train Loss: 1.386e-04,  Validation Loss: 4.722e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.00093039
# Epoch 248 (Period 9):  Train Loss: 2.149e-04,  Validation Loss: 7.490e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0015773
# Epoch 249 (Period 9):  Train Loss: 1.234e-04,  Validation Loss: 2.592e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0026389
# Epoch 250 (Period 9):  Train Loss: 5.444e-05,  Validation Loss: 1.388e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0043565
# Epoch 251 (Period 9):  Train Loss: 3.882e-04,  Validation Loss: 1.566e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.0070727
# Epoch 252 (Period 9):  Train Loss: 3.430e-04,  Validation Loss: 3.270e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.011216
# Epoch 253 (Period 9):  Train Loss: 2.639e-04,  Validation Loss: 5.851e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.017201
# Epoch 254 (Period 9):  Train Loss: 5.911e-05,  Validation Loss: 5.025e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.025201
# Epoch 255 (Period 9):  Train Loss: 5.387e-05,  Validation Loss: 4.991e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.034851
# Epoch 256 (Period 9):  Train Loss: 5.529e-05,  Validation Loss: 5.271e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.045149
# Epoch 257 (Period 9):  Train Loss: 5.697e-05,  Validation Loss: 5.392e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.054799
# Epoch 258 (Period 9):  Train Loss: 5.519e-05,  Validation Loss: 6.072e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.062799
# Epoch 259 (Period 9):  Train Loss: 5.498e-05,  Validation Loss: 6.276e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.068784
# Epoch 260 (Period 9):  Train Loss: 5.644e-05,  Validation Loss: 4.922e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.072927
# Epoch 261 (Period 9):  Train Loss: 5.687e-05,  Validation Loss: 5.203e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.075643
# Epoch 262 (Period 9):  Train Loss: 5.696e-05,  Validation Loss: 5.552e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.077361
# Epoch 263 (Period 9):  Train Loss: 5.867e-05,  Validation Loss: 6.128e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.078423
# Epoch 264 (Period 9):  Train Loss: 5.657e-05,  Validation Loss: 4.486e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07907
# Epoch 265 (Period 9):  Train Loss: 5.556e-05,  Validation Loss: 6.614e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07946
# Epoch 266 (Period 9):  Train Loss: 5.775e-05,  Validation Loss: 5.622e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079695
# Epoch 267 (Period 9):  Train Loss: 5.661e-05,  Validation Loss: 5.539e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079836
# Epoch 268 (Period 9):  Train Loss: 5.712e-05,  Validation Loss: 7.060e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07992
# Epoch 269 (Period 9):  Train Loss: 5.544e-05,  Validation Loss: 5.812e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.07997
# Epoch 270 (Period 9):  Train Loss: 5.564e-05,  Validation Loss: 5.457e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.08
# Epoch 271 (Period 10):  Train Loss: 3.166e-02,  Validation Loss: 1.266e-04,  Epoch Time: 0.76s,  Current Pruning Threshold: 0
# Epoch 272 (Period 10):  Train Loss: 1.144e-04,  Validation Loss: 6.219e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 2.9961e-05
# Epoch 273 (Period 10):  Train Loss: 1.040e-04,  Validation Loss: 1.040e-04,  Epoch Time: 0.76s,  Current Pruning Threshold: 8.0168e-05
# Epoch 274 (Period 10):  Train Loss: 5.526e-04,  Validation Loss: 1.089e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00016424
# Epoch 275 (Period 10):  Train Loss: 3.472e-04,  Validation Loss: 4.288e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.00030487
# Epoch 276 (Period 10):  Train Loss: 4.122e-04,  Validation Loss: 6.061e-04,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.00053966
# Epoch 277 (Period 10):  Train Loss: 3.294e-04,  Validation Loss: 3.732e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00093039
# Epoch 278 (Period 10):  Train Loss: 7.053e-04,  Validation Loss: 5.230e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0015773
# Epoch 279 (Period 10):  Train Loss: 1.522e-04,  Validation Loss: 8.323e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0026389
# Epoch 280 (Period 10):  Train Loss: 4.324e-05,  Validation Loss: 7.053e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0043565
# Epoch 281 (Period 10):  Train Loss: 1.129e-03,  Validation Loss: 3.033e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0070727
# Epoch 282 (Period 10):  Train Loss: 1.047e-04,  Validation Loss: 2.475e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.011216
# Epoch 283 (Period 10):  Train Loss: 2.907e-04,  Validation Loss: 6.800e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.017201
# Epoch 284 (Period 10):  Train Loss: 6.711e-05,  Validation Loss: 5.734e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.025201
# Epoch 285 (Period 10):  Train Loss: 5.530e-05,  Validation Loss: 4.695e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.034851
# Epoch 286 (Period 10):  Train Loss: 5.503e-05,  Validation Loss: 4.953e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.045149
# Epoch 287 (Period 10):  Train Loss: 5.662e-05,  Validation Loss: 5.712e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.054799
# Epoch 288 (Period 10):  Train Loss: 5.647e-05,  Validation Loss: 6.688e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.062799
# Epoch 289 (Period 10):  Train Loss: 5.459e-05,  Validation Loss: 5.188e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.068784
# Epoch 290 (Period 10):  Train Loss: 5.745e-05,  Validation Loss: 7.201e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.072927
# Epoch 291 (Period 10):  Train Loss: 5.664e-05,  Validation Loss: 6.136e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.075643
# Epoch 292 (Period 10):  Train Loss: 5.768e-05,  Validation Loss: 5.300e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.077361
# Epoch 293 (Period 10):  Train Loss: 5.703e-05,  Validation Loss: 5.868e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.078423
# Epoch 294 (Period 10):  Train Loss: 5.787e-05,  Validation Loss: 5.061e-05,  Epoch Time: 0.86s,  Current Pruning Threshold: 0.07907
# Epoch 295 (Period 10):  Train Loss: 5.561e-05,  Validation Loss: 5.631e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07946
# Epoch 296 (Period 10):  Train Loss: 5.692e-05,  Validation Loss: 5.223e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.079695
# Epoch 297 (Period 10):  Train Loss: 5.472e-05,  Validation Loss: 6.372e-05,  Epoch Time: 0.81s,  Current Pruning Threshold: 0.079836
# Epoch 298 (Period 10):  Train Loss: 5.583e-05,  Validation Loss: 5.840e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07992
# Epoch 299 (Period 10):  Train Loss: 5.628e-05,  Validation Loss: 5.874e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07997
# Epoch 300 (Period 10):  Train Loss: 5.698e-05,  Validation Loss: 5.675e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.08
# Epoch 301 (Period 11):  Train Loss: 1.003e-01,  Validation Loss: 1.305e-03,  Epoch Time: 0.80s,  Current Pruning Threshold: 0
# Epoch 302 (Period 11):  Train Loss: 7.751e-04,  Validation Loss: 2.848e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 2.9961e-05
# Epoch 303 (Period 11):  Train Loss: 2.374e-04,  Validation Loss: 1.308e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 8.0168e-05
# Epoch 304 (Period 11):  Train Loss: 1.114e-04,  Validation Loss: 1.472e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00016424
# Epoch 305 (Period 11):  Train Loss: 2.061e-04,  Validation Loss: 8.057e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00030487
# Epoch 306 (Period 11):  Train Loss: 1.796e-04,  Validation Loss: 2.904e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00053966
# Epoch 307 (Period 11):  Train Loss: 1.824e-04,  Validation Loss: 3.786e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00093039
# Epoch 308 (Period 11):  Train Loss: 1.108e-04,  Validation Loss: 4.024e-05,  Epoch Time: 0.81s,  Current Pruning Threshold: 0.0015773
# Epoch 309 (Period 11):  Train Loss: 5.645e-05,  Validation Loss: 1.720e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0026389
# Epoch 310 (Period 11):  Train Loss: 9.555e-05,  Validation Loss: 1.493e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0043565
# Epoch 311 (Period 11):  Train Loss: 5.506e-05,  Validation Loss: 2.260e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0070727
# Epoch 312 (Period 11):  Train Loss: 1.630e-04,  Validation Loss: 3.798e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.011216
# Epoch 313 (Period 11):  Train Loss: 6.859e-05,  Validation Loss: 5.127e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.017201
# Epoch 314 (Period 11):  Train Loss: 5.885e-05,  Validation Loss: 7.422e-05,  Epoch Time: 0.82s,  Current Pruning Threshold: 0.025201
# Epoch 315 (Period 11):  Train Loss: 5.485e-05,  Validation Loss: 5.294e-05,  Epoch Time: 0.81s,  Current Pruning Threshold: 0.034851
# Epoch 316 (Period 11):  Train Loss: 5.552e-05,  Validation Loss: 5.606e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.045149
# Epoch 317 (Period 11):  Train Loss: 5.715e-05,  Validation Loss: 5.274e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.054799
# Epoch 318 (Period 11):  Train Loss: 5.730e-05,  Validation Loss: 4.974e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.062799
# Epoch 319 (Period 11):  Train Loss: 5.637e-05,  Validation Loss: 6.004e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.068784
# Epoch 320 (Period 11):  Train Loss: 5.713e-05,  Validation Loss: 5.174e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.072927
# Epoch 321 (Period 11):  Train Loss: 5.438e-05,  Validation Loss: 4.774e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.075643
# Epoch 322 (Period 11):  Train Loss: 5.783e-05,  Validation Loss: 6.257e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.077361
# Epoch 323 (Period 11):  Train Loss: 5.580e-05,  Validation Loss: 5.532e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.078423
# Epoch 324 (Period 11):  Train Loss: 5.479e-05,  Validation Loss: 6.746e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07907
# Epoch 325 (Period 11):  Train Loss: 5.780e-05,  Validation Loss: 5.137e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07946
# Epoch 326 (Period 11):  Train Loss: 5.562e-05,  Validation Loss: 5.078e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.079695
# Epoch 327 (Period 11):  Train Loss: 5.531e-05,  Validation Loss: 5.298e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079836
# Epoch 328 (Period 11):  Train Loss: 5.732e-05,  Validation Loss: 5.027e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07992
# Epoch 329 (Period 11):  Train Loss: 5.604e-05,  Validation Loss: 5.780e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07997
# Epoch 330 (Period 11):  Train Loss: 5.667e-05,  Validation Loss: 5.545e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.08
# Epoch 331 (Period 12):  Train Loss: 1.178e-01,  Validation Loss: 5.121e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0
# Epoch 332 (Period 12):  Train Loss: 3.578e-04,  Validation Loss: 2.427e-04,  Epoch Time: 0.76s,  Current Pruning Threshold: 2.9961e-05
# Epoch 333 (Period 12):  Train Loss: 1.847e-04,  Validation Loss: 1.120e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 8.0168e-05
# Epoch 334 (Period 12):  Train Loss: 1.081e-04,  Validation Loss: 1.489e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00016424
# Epoch 335 (Period 12):  Train Loss: 1.123e-04,  Validation Loss: 8.530e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00030487
# Epoch 336 (Period 12):  Train Loss: 2.590e-04,  Validation Loss: 2.827e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00053966
# Epoch 337 (Period 12):  Train Loss: 2.774e-04,  Validation Loss: 4.549e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00093039
# Epoch 338 (Period 12):  Train Loss: 3.501e-05,  Validation Loss: 1.345e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0015773
# Epoch 339 (Period 12):  Train Loss: 1.712e-04,  Validation Loss: 1.422e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0026389
# Epoch 340 (Period 12):  Train Loss: 1.248e-04,  Validation Loss: 2.331e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0043565
# Epoch 341 (Period 12):  Train Loss: 7.355e-05,  Validation Loss: 1.885e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0070727
# Epoch 342 (Period 12):  Train Loss: 6.356e-05,  Validation Loss: 2.465e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.011216
# Epoch 343 (Period 12):  Train Loss: 1.428e-04,  Validation Loss: 5.217e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.017201
# Epoch 344 (Period 12):  Train Loss: 5.497e-05,  Validation Loss: 5.295e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.025201
# Epoch 345 (Period 12):  Train Loss: 5.563e-05,  Validation Loss: 5.296e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.034851
# Epoch 346 (Period 12):  Train Loss: 5.596e-05,  Validation Loss: 6.008e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.045149
# Epoch 347 (Period 12):  Train Loss: 5.653e-05,  Validation Loss: 5.188e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.054799
# Epoch 348 (Period 12):  Train Loss: 5.631e-05,  Validation Loss: 5.158e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.062799
# Epoch 349 (Period 12):  Train Loss: 5.540e-05,  Validation Loss: 6.003e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.068784
# Epoch 350 (Period 12):  Train Loss: 5.734e-05,  Validation Loss: 4.963e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.072927
# Epoch 351 (Period 12):  Train Loss: 5.615e-05,  Validation Loss: 6.175e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.075643
# Epoch 352 (Period 12):  Train Loss: 5.666e-05,  Validation Loss: 5.371e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.077361
# Epoch 353 (Period 12):  Train Loss: 5.579e-05,  Validation Loss: 5.761e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.078423
# Epoch 354 (Period 12):  Train Loss: 5.653e-05,  Validation Loss: 5.147e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07907
# Epoch 355 (Period 12):  Train Loss: 5.686e-05,  Validation Loss: 8.227e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07946
# Epoch 356 (Period 12):  Train Loss: 5.557e-05,  Validation Loss: 5.687e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079695
# Epoch 357 (Period 12):  Train Loss: 5.663e-05,  Validation Loss: 5.650e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.079836
# Epoch 358 (Period 12):  Train Loss: 5.714e-05,  Validation Loss: 8.949e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.07992
# Epoch 359 (Period 12):  Train Loss: 5.649e-05,  Validation Loss: 5.152e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.07997
# Epoch 360 (Period 12):  Train Loss: 5.612e-05,  Validation Loss: 5.221e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.08
# Epoch 361 (Period 13):  Train Loss: 6.946e-02,  Validation Loss: 9.866e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0
# Epoch 362 (Period 13):  Train Loss: 7.808e-05,  Validation Loss: 4.902e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 2.9961e-05
# Epoch 363 (Period 13):  Train Loss: 4.333e-05,  Validation Loss: 4.158e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 8.0168e-05
# Epoch 364 (Period 13):  Train Loss: 3.064e-05,  Validation Loss: 2.278e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00016424
# Epoch 365 (Period 13):  Train Loss: 4.210e-05,  Validation Loss: 4.494e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00030487
# Epoch 366 (Period 13):  Train Loss: 1.811e-04,  Validation Loss: 2.260e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00053966
# Epoch 367 (Period 13):  Train Loss: 1.569e-04,  Validation Loss: 6.433e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00093039
# Epoch 368 (Period 13):  Train Loss: 1.716e-05,  Validation Loss: 8.752e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0015773
# Epoch 369 (Period 13):  Train Loss: 3.900e-05,  Validation Loss: 3.191e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0026389
# Epoch 370 (Period 13):  Train Loss: 5.640e-05,  Validation Loss: 9.241e-06,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0043565
# Epoch 371 (Period 13):  Train Loss: 4.222e-05,  Validation Loss: 1.323e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0070727
# Epoch 372 (Period 13):  Train Loss: 2.013e-04,  Validation Loss: 6.006e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.011216
# Epoch 373 (Period 13):  Train Loss: 5.652e-05,  Validation Loss: 5.721e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.017201
# Epoch 374 (Period 13):  Train Loss: 5.581e-05,  Validation Loss: 5.519e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.025201
# Epoch 375 (Period 13):  Train Loss: 5.637e-05,  Validation Loss: 7.118e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.034851
# Epoch 376 (Period 13):  Train Loss: 5.778e-05,  Validation Loss: 6.049e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.045149
# Epoch 377 (Period 13):  Train Loss: 5.616e-05,  Validation Loss: 6.556e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.054799
# Epoch 378 (Period 13):  Train Loss: 5.696e-05,  Validation Loss: 5.708e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.062799
# Epoch 379 (Period 13):  Train Loss: 5.762e-05,  Validation Loss: 5.939e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.068784
# Epoch 380 (Period 13):  Train Loss: 5.708e-05,  Validation Loss: 5.130e-05,  Epoch Time: 0.83s,  Current Pruning Threshold: 0.072927
# Epoch 381 (Period 13):  Train Loss: 5.749e-05,  Validation Loss: 5.124e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.075643
# Epoch 382 (Period 13):  Train Loss: 5.798e-05,  Validation Loss: 6.243e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.077361
# Epoch 383 (Period 13):  Train Loss: 5.548e-05,  Validation Loss: 1.111e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.078423
# Epoch 384 (Period 13):  Train Loss: 5.327e-05,  Validation Loss: 5.547e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.07907
# Epoch 385 (Period 13):  Train Loss: 5.757e-05,  Validation Loss: 6.123e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07946
# Epoch 386 (Period 13):  Train Loss: 5.699e-05,  Validation Loss: 4.991e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.079695
# Epoch 387 (Period 13):  Train Loss: 5.743e-05,  Validation Loss: 7.152e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.079836
# Epoch 388 (Period 13):  Train Loss: 5.565e-05,  Validation Loss: 5.586e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07992
# Epoch 389 (Period 13):  Train Loss: 5.581e-05,  Validation Loss: 5.876e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.07997
# Epoch 390 (Period 13):  Train Loss: 5.679e-05,  Validation Loss: 5.042e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.08
# Epoch 391 (Period 14):  Train Loss: 6.027e-02,  Validation Loss: 6.669e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0
# Epoch 392 (Period 14):  Train Loss: 5.349e-04,  Validation Loss: 3.274e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 2.9961e-05
# Epoch 393 (Period 14):  Train Loss: 2.275e-04,  Validation Loss: 2.786e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 8.0168e-05
# Epoch 394 (Period 14):  Train Loss: 1.427e-04,  Validation Loss: 1.358e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.00016424
# Epoch 395 (Period 14):  Train Loss: 3.391e-04,  Validation Loss: 1.169e-02,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00030487
# Epoch 396 (Period 14):  Train Loss: 5.886e-04,  Validation Loss: 1.656e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00053966
# Epoch 397 (Period 14):  Train Loss: 2.467e-04,  Validation Loss: 5.000e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.00093039
# Epoch 398 (Period 14):  Train Loss: 2.627e-04,  Validation Loss: 8.194e-04,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0015773
# Epoch 399 (Period 14):  Train Loss: 1.528e-04,  Validation Loss: 3.386e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0026389
# Epoch 400 (Period 14):  Train Loss: 6.018e-05,  Validation Loss: 3.900e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0043565
# Epoch 401 (Period 14):  Train Loss: 8.700e-04,  Validation Loss: 1.767e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.0070727
# Epoch 402 (Period 14):  Train Loss: 5.580e-05,  Validation Loss: 1.380e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.011216
# Epoch 403 (Period 14):  Train Loss: 3.653e-04,  Validation Loss: 7.774e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.017201
# Epoch 404 (Period 14):  Train Loss: 8.886e-05,  Validation Loss: 6.081e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.025201
# Epoch 405 (Period 14):  Train Loss: 7.495e-05,  Validation Loss: 5.394e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.034851
# Epoch 406 (Period 14):  Train Loss: 5.613e-05,  Validation Loss: 6.885e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.045149
# Epoch 407 (Period 14):  Train Loss: 5.641e-05,  Validation Loss: 5.343e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.054799
# Epoch 408 (Period 14):  Train Loss: 5.578e-05,  Validation Loss: 5.204e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.062799
# Epoch 409 (Period 14):  Train Loss: 5.654e-05,  Validation Loss: 4.966e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.068784
# Epoch 410 (Period 14):  Train Loss: 5.823e-05,  Validation Loss: 5.298e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.072927
# Epoch 411 (Period 14):  Train Loss: 5.739e-05,  Validation Loss: 5.499e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.075643
# Epoch 412 (Period 14):  Train Loss: 5.664e-05,  Validation Loss: 5.855e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.077361
# Epoch 413 (Period 14):  Train Loss: 5.714e-05,  Validation Loss: 5.926e-05,  Epoch Time: 0.79s,  Current Pruning Threshold: 0.078423
# Epoch 414 (Period 14):  Train Loss: 5.778e-05,  Validation Loss: 5.821e-05,  Epoch Time: 0.80s,  Current Pruning Threshold: 0.07907
# Epoch 415 (Period 14):  Train Loss: 5.580e-05,  Validation Loss: 4.842e-05,  Epoch Time: 0.78s,  Current Pruning Threshold: 0.07946
# Epoch 416 (Period 14):  Train Loss: 5.624e-05,  Validation Loss: 6.269e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.079695
# Epoch 417 (Period 14):  Train Loss: 5.592e-05,  Validation Loss: 4.780e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.079836
# Epoch 418 (Period 14):  Train Loss: 5.788e-05,  Validation Loss: 5.938e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.07992
# Epoch 419 (Period 14):  Train Loss: 5.711e-05,  Validation Loss: 4.856e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.07997
# Epoch 420 (Period 14):  Train Loss: 5.701e-05,  Validation Loss: 5.892e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.08
# Epoch 421 (Period 15):  Train Loss: 3.271e-02,  Validation Loss: 2.024e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0
# Epoch 422 (Period 15):  Train Loss: 1.263e-04,  Validation Loss: 8.283e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 2.9961e-05
# Epoch 423 (Period 15):  Train Loss: 3.073e-04,  Validation Loss: 5.887e-04,  Epoch Time: 0.79s,  Current Pruning Threshold: 8.0168e-05
# Epoch 424 (Period 15):  Train Loss: 1.548e-04,  Validation Loss: 3.503e-04,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.00016424
# Epoch 425 (Period 15):  Train Loss: 3.015e-04,  Validation Loss: 1.125e-04,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.00030487
# Epoch 426 (Period 15):  Train Loss: 2.324e-04,  Validation Loss: 5.466e-05,  Epoch Time: 0.76s,  Current Pruning Threshold: 0.00053966
# Epoch 427 (Period 15):  Train Loss: 2.873e-04,  Validation Loss: 3.831e-05,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.00093039
# Epoch 428 (Period 15):  Train Loss: 1.525e-04,  Validation Loss: 3.671e-04,  Epoch Time: 0.77s,  Current Pruning Threshold: 0.0015773
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 8
#       5 trainer.reset_trainer_and_model_weights(i)
#       6 output = training_output[:, i:i+1]
# ----> 8 history = trainer.fit(
#       9     training_input,
#      10     output,
#      11     batch_size=MINI_BATCH_SIZE,
#      12     validation_split=0.20,
#      13     epochs=round(NUM_EPOCHS),
#      14     pruning_scheduler=pruning_scheduler,
#      15     callbacks=callbacks,
#      16     early_stopping_loss_threshold=EARLY_STOPPING_LOSS_THRESHOLD,
#      17     early_stopping_pruning_threshold=EARLY_STOPPING_PRUNING_THRESHOLD,
#      18     shuffle_per_epoch=False,
#      19     patience_periods=15,
#      20     verbose=1,
#      21 )
#      23 training_histories.append(history)
#      25 # Retrieve the weights of the trained model
#
# File ~/Library/CloudStorage/GoogleDrive-siyuanxing9132@gmail.com/My Drive/A-Research/A-Cal Poly/2023-NN-SINDY/paper-NC/SREINet-Git/code/utilities/sreinet_trainer.py:178, in SREINetTrainer.fit(self, training_input, training_output, batch_size, validation_split, epochs, pruning_scheduler, callbacks, early_stopping_loss_threshold, early_stopping_pruning_threshold, patience_periods, improvement_threshold, verbose, print_every_n_epochs, shuffle_per_epoch)
#     175     epoch_train_dataset = train_dataset.shuffle(buffer_size=min(train_samples, 10000), seed=epoch_seed).batch(batch_size)
#     177 # Training
# --> 178 for train_inputs, train_targets in epoch_train_dataset:
#     179     loss = self._train_step(train_inputs, train_targets, binary_mask)
#     180     train_loss(loss)
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:810, in OwnedIterator.__next__(self)
#     808 def __next__(self):
#     809   try:
# --> 810     return self._next_internal()
#     811   except errors.OutOfRangeError:
#     812     raise StopIteration
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:756, in OwnedIterator._next_internal(self)
#     754 autograph_status = autograph_ctx.control_status_ctx().status
#     755 autograph_disabled = autograph_status == autograph_ctx.Status.DISABLED
# --> 756 if not context.executing_eagerly() and autograph_disabled:
#     757   self._get_next_call_count += 1
#     758   if self._get_next_call_count > GET_NEXT_CALL_ERROR_THRESHOLD:
#
# File /opt/anaconda3/envs/sreinet/lib/python3.10/site-packages/tensorflow/python/eager/context.py:2293, in executing_eagerly()
#    2289   """Returns the operation seed generated based on global seed."""
#    2290   return context()._internal_operation_seed()  # pylint: disable=protected-access
# -> 2293 @tf_export("executing_eagerly", v1=[])
#    2294 def executing_eagerly():
#    2295   """Checks whether the current thread has eager execution enabled.
#    2296
#    2297   Eager execution is enabled by default and this API returns `True`
#    (...)
#    2345     `True` if the current thread has eager execution enabled.
#    2346   """
#    2347   ctx = context_safe()
#
# KeyboardInterrupt:

# %% [markdown]
# ## **IV. Coefficient Reconstructor (SREINet)**

# %% [markdown]
# #### `generate_set_labels`

# %%
def generate_set_labels(N):
    labels = ['Constant']
    for i in range(1, N+1):
        labels.extend([f'x{i}', f'y{i}', f'z{i}'])
    return labels

# %% [markdown]
# #### `coefficient_reconstruction`

# %%
def coefficient_reconstruction(dim_index,
                                weights, 
                                minimum_coefficient_threshold = 1e-5,
                                coefficient_output_digits = 10, 
                                enable_coefficient_sorting = False):
    
    max_neurons = max(max(len(layer) for layer in SREINet) for SREINet in weights)
    
    labels = generate_set_labels(max_neurons - 1) # number of states = number of neurons - 1

    def explore_path(SREINet_index, layer, neuron, weight_product, label_counts, non_zero_paths):
        """
        Recursively explores non-zero paths in a neural network.
        """
        if layer == len(weights[SREINet_index]) - 1:
            non_zero_paths.append((label_counts, weight_product))
            return

        for next_neuron, weight in enumerate(weights[SREINet_index][layer][neuron]):
            if abs(weight) <= 1e-15:
                # Skip recursion if the weight is zero (if one weight is zero, the whole path will be eliminated)
                continue  
            new_weight_product = weight_product * weight
            next_label_counts = label_counts.copy()
            next_label_counts[labels[next_neuron]] = next_label_counts.get(labels[next_neuron], 0) + 1
            explore_path(SREINet_index, layer + 1, next_neuron, new_weight_product, next_label_counts, non_zero_paths)
    
    #beginning of the algorithm
    all_SREINet_products = []
    for SREINet_index, _ in enumerate(weights):
        non_zero_paths = []
        #collect all non-zero paths
        for neuron_index in range(len(weights[SREINet_index][0])):
            label_counts = {labels[neuron_index]: 1}
            explore_path(SREINet_index, 0, neuron_index, 1, label_counts, non_zero_paths)
        
        #sum up the products with identical composite nonlinear/linear terms
        SREINet_products = {}
        for label_counts, weight_product in non_zero_paths:
            label_counts_key = frozenset(label_counts.items())
            if label_counts_key in SREINet_products:
                SREINet_products[label_counts_key] += weight_product
            else:
                SREINet_products[label_counts_key] = weight_product
        
        #remove the negligible composite terms
        SREINet_products = {k: v for k, v in SREINet_products.items() if abs(v) >= minimum_coefficient_threshold}
        
        if enable_coefficient_sorting:
            #sort the composite terms by their absolute values
            sorted_SREINet_products = dict(sorted(SREINet_products.items(), key=lambda item: abs(item[1]), reverse=True))
        else:
            sorted_SREINet_products = SREINet_products

        all_SREINet_products.append(sorted_SREINet_products)

    #output formatting
    labeled_all_SREINet_products = []
    for SREINet_index, sorted_SREINet_products in enumerate(all_SREINet_products):
        SREINet_product_strings = []
        for key, value in sorted_SREINet_products.items():
            labels_list = []
            only_constant = len(key) == 1 and any(label == 'Constant' for label, _ in key)
            
            for label, count in sorted(key):
                if label == 'Constant' and len(key) > 1:
                    continue
                if label != 'Constant' and count > 1:
                    labels_list.append(f"{label}^{count}")
                elif label == 'Constant' or count == 1:
                    labels_list.append(label if label != 'Constant' else '')
            
            label_str = '*'.join(filter(None, labels_list))
                        
            # Apply coefficient threshold if enabled
            formatted_value = f"{abs(value):.{coefficient_output_digits}g}"

            term_str = label_str if formatted_value == '1' else f"{formatted_value}*{label_str}" if not only_constant else formatted_value if formatted_value != '1' else ''
            sign = '+' if value >= 0 else '-'
            if SREINet_product_strings or value < 0:
                term_str = f" {sign} {term_str}"
            else:
                term_str = term_str
            SREINet_product_strings.append(term_str)

        formatted_output = ''.join(SREINet_product_strings)
        layer_prefix = f"(x{SREINet_index+dim_index+1})'= "
        full_output = layer_prefix + formatted_output
        labeled_all_SREINet_products.append(full_output)

    return labeled_all_SREINet_products

# %% [markdown]
# ## **V. Results**
# ### **Identified Model**

# %%
for i in range(len(weights_list)):
    path_products = coefficient_reconstruction(i,weights_list[i], 
                                            minimum_coefficient_threshold = 1e-5,
                                            coefficient_output_digits = 10, 
                                            enable_coefficient_sorting = False)
    
    for index, dimension in enumerate(path_products):
        print(f"{dimension}")

# %% [markdown]
# ### **Validation**

# %%
import matplotlib.pyplot as plt

# validation: need to draw the output of each dimension independently
dim_to_plot = 1
index = dim_to_plot - 1

#Form NN predictions
NN_output = np.zeros((dx_train.shape[0], dx_train.shape[1]))
for i, weight in enumerate(weights_list):
    model.set_weights(weight[0])
    output = model.predict(training_input_for_sim)
    NN_output[:,i:i+1] = output

#validate the first trajectory if there are many
plt.plot(t_arr, NN_output[:,index][:t_arr.shape[0]], 'r', label='NN Prediction')
plt.plot(t_arr, dx_train[:,index][:t_arr.shape[0]], 'k', label='Expected Output')

#pick the last point of the simulation output and use it as the initial condition for the next simulation
x0 = x_train[:t_arr.shape[0]][-1]
t0 = t_arr[-1]
validation_generator = DG.DataGenerator(x0, T=data_T + t0, dt=data_dt, t0=t0)
new_t_arr, new_x, new_dx = validation_generator.generate_dataset_by_custom_ODEs(
    ode_function,
    *network_arguments,
    method='RK45'
)

new_input = new_x

new_NN_output = np.zeros((new_dx.shape[0], new_dx.shape[1]))
for i, weight in enumerate(weights_list):
    model.set_weights(weight[0])
    output = model.predict(new_input)
    new_NN_output[:,i:i+1] = output

plt.plot(new_t_arr, new_NN_output[:,index], "r--", label='NN Prediction')
plt.plot(new_t_arr, new_dx[:,index], "k--", label='Expected Output')
plt.title("Response of dimension " + str(dim_to_plot))
plt.legend()
plt.show()

# %% [markdown]
# ## **VI. Output**

# %%
#save data
#NN configurations -> #NN layers, #NN neurons
#data configurations -> #data points, #data dimensions
#optimizer configurations -> #learning rate, #decay rate
#training configurations -> #NN training epochs, callbacks
#record loss values
#save the info into a spreadsheet

import pandas as pd

df = pd.DataFrame({
    'ODE model': [MY_MODEL],
    'data initial conditions': [data_initial_conditions],
    'data length (T)': [data_T],
    'data resolution (dt)': [data_dt],
    'learning rate': [learning_rate],
    'Guess highest-order polynomial': [guess_highest_order_polynomial],
    'input dimension': [x_train.shape[1]],
    'mini_batch_size': [MINI_BATCH_SIZE],
    'Layer Neurons per activation fns': [layer_neuron_nums_per_act_fn],
    'Data Points': [training_input.shape[0]],
    'loss function': [LOSS_FUNCTION],
    'Total Training Epochs': [NUM_EPOCHS],
    'last lost value': [history['loss'][-1]],
    'weight threshold for pruning': [PRUNING_WEIGHT_THRESHOLD],
    'loss threshold for early stopping': [EARLY_STOPPING_LOSS_THRESHOLD],
})

# %%
#write df to the first sheet of the excel file
#write to folder named data

opt_folder = 'output'
# Create the folder if it doesn't exist
os.makedirs(opt_folder, exist_ok=True)

with pd.ExcelWriter(os.path.join(opt_folder,'nn_configurations.xlsx')) as writer:

    df.to_excel(writer, sheet_name='configuration', index=False)

    #save the loss and validation history to the second sheet of the excel file
    df2 = pd.DataFrame(history)
    df2.to_excel(writer, sheet_name='loss_history', index=False)

    #save reconstructed weights to the third sheet of the excel file

    df3 = []

    for i in range(len(weights_list)):
        path_products = coefficient_reconstruction(i,
                                                    weights_list[i], 
                                                    minimum_coefficient_threshold = 1e-4,
                                                    coefficient_output_digits = 10, 
                                                    enable_coefficient_sorting = False)


        # Convert path_products to a DataFrame
        temp_df = pd.DataFrame(path_products)

        # Append temp_df to df3
        df3.append(temp_df)

    df3 = pd.concat(df3, ignore_index=True)
    df3.to_excel(writer, sheet_name='reconstructed_weights', index=False)

# %%
from scipy.io import savemat
#concatenate t_arr, x_train, dx_train, and NN_output and save it as a mat file

#pate t_arr such that it has the same shape as x_train, dx_train, and NN_output
tem_t_arr = t_arr
for i in range(num_traj-1):
    tem_t_arr = np.concatenate((tem_t_arr, t_arr), axis=0) 
t_arr = tem_t_arr

m_data = np.concatenate((t_arr, x_train, dx_train, NN_output), axis=1)
savemat(os.path.join(opt_folder,'train_data.mat'), {'data': m_data})

v_data = np.concatenate((new_t_arr, new_x, new_dx, new_NN_output), axis=1)
savemat(os.path.join(opt_folder,'validation_data.mat'), {'data': v_data})
